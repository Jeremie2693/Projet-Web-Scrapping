# %% [markdown]
# # Projet Webscraping Axel & Jeremie

# %% [markdown]
# Importation des librairies

# %%
import requests
import pandas as pd
import json
from datetime import datetime
from datetime import date
from bs4 import BeautifulSoup
import numpy as np

# %% [markdown]
# Premier test de requete sur l'api sur une seule ville (Paris) voir ce que ça donne

# %%
r = requests.get("https://nominatim.openstreetmap.org/?q=Paris&format=json")
r.json()
# Out:
# [{'place_id': 297417241,
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#   'osm_type': 'relation',
#   'osm_id': 7444,
#   'boundingbox': ['48.8155755', '48.902156', '2.224122', '2.4697602'],
#   'lat': '48.8588897',
#   'lon': '2.3200410217200766',
#   'display_name': 'Paris, Île-de-France, France métropolitaine, France',
#   'class': 'boundary',
#   'type': 'administrative',
#   'importance': 0.9417101715588673,
#   'icon': 'https://nominatim.openstreetmap.org/ui/mapicons/poi_boundary_administrative.p.20.png'},
#  {'place_id': 298001902,
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#   'osm_type': 'relation',
#   'osm_id': 71525,
#   'boundingbox': ['48.8155755', '48.902156', '2.224122', '2.4697602'],
#   'lat': '48.8534951',
#   'lon': '2.3483915',
#   'display_name': 'Paris, Île-de-France, France métropolitaine, France',
#   'class': 'boundary',
#   'type': 'administrative',
#   'importance': 0.9417101715588673,
#   'icon': 'https://nominatim.openstreetmap.org/ui/mapicons/poi_boundary_administrative.p.20.png'},
#  {'place_id': 297598847,
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#   'osm_type': 'relation',
#   'osm_id': 115357,
#   'boundingbox': ['33.6206345', '33.7383866', '-95.6279396', '-95.4354115'],
#   'lat': '33.6617962',
#   'lon': '-95.555513',
#   'display_name': 'Paris, Lamar County, Texas, 75460, United States',
#   'class': 'boundary',
#   'type': 'administrative',
#   'importance': 0.6061645097134651,
#   'icon': 'https://nominatim.openstreetmap.org/ui/mapicons/poi_boundary_administrative.p.20.png'},
#  {'place_id': 298261832,
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#   'osm_type': 'relation',
#   'osm_id': 130722,
#   'boundingbox': ['38.164922', '38.238271', '-84.307326', '-84.232089'],
#   'lat': '38.2097987',
#   'lon': '-84.2529869',
#   'display_name': 'Paris, Bourbon County, Kentucky, 40361, United States',
#   'class': 'boundary',
#   'type': 'administrative',
#   'importance': 0.5586843760767399,
#   'icon': 'https://nominatim.openstreetmap.org/ui/mapicons/poi_boundary_administrative.p.20.png'},
#  {'place_id': 298345402,
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#   'osm_type': 'relation',
#   'osm_id': 1641193,
#   'boundingbox': ['48.8155755', '48.902156', '2.224122', '2.4697602'],
#   'lat': '48.8588897',
#   'lon': '2.3200410217200766',
#   'display_name': 'Paris, Île-de-France, France métropolitaine, France',
#   'class': 'boundary',
#   'type': 'administrative',
#   'importance': 0.5383953917728153,
#   'icon': 'https://nominatim.openstreetmap.org/ui/mapicons/poi_boundary_administrative.p.20.png'},
#  {'place_id': 297561157,
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#   'osm_type': 'relation',
#   'osm_id': 197171,
#   'boundingbox': ['36.266003', '36.329016', '-88.367113', '-88.265067'],
#   'lat': '36.3019461',
#   'lon': '-88.3258578',
#   'display_name': 'Paris, Henry County, West Tennessee, Tennessee, United States',
#   'class': 'boundary',
#   'type': 'administrative',
#   'importance': 0.5250690427980547,
#   'icon': 'https://nominatim.openstreetmap.org/ui/mapicons/poi_boundary_administrative.p.20.png'},
#  {'place_id': 297651784,
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#   'osm_type': 'relation',
#   'osm_id': 126166,
#   'boundingbox': ['39.581493', '39.649981', '-87.721046', '-87.649203'],
#   'lat': '39.611146',
#   'lon': '-87.6961374',
#   'display_name': 'Paris, Edgar County, Illinois, 61944, United States',
#   'class': 'boundary',
#   'type': 'administrative',
#   'importance': 0.5244799592274194,
#   'icon': 'https://nominatim.openstreetmap.org/ui/mapicons/poi_boundary_administrative.p.20.png'},
#  {'place_id': 299079910,
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#   'osm_type': 'relation',
#   'osm_id': 12165996,
#   'boundingbox': ['44.1754185', '44.3124081', '-70.566213', '-70.414966'],
#   'lat': '44.259954',
#   'lon': '-70.500641',
#   'display_name': 'Paris, Oxford County, Maine, 04281, United States',
#   'class': 'boundary',
#   'type': 'administrative',
#   'importance': 0.5190701377223524,
#   'icon': 'https://nominatim.openstreetmap.org/ui/mapicons/poi_boundary_administrative.p.20.png'},
#  {'place_id': 298902894,
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#   'osm_type': 'relation',
#   'osm_id': 6678712,
#   'boundingbox': ['35.2681485', '35.3065882', '-93.761965', '-93.6755169'],
#   'lat': '35.2920325',
#   'lon': '-93.7299173',
#   'display_name': 'Paris, Logan County, Arkansas, 72855, United States',
#   'class': 'boundary',
#   'type': 'administrative',
#   'importance': 0.5136706902956424,
#   'icon': 'https://nominatim.openstreetmap.org/ui/mapicons/poi_boundary_administrative.p.20.png'},
#  {'place_id': 298421083,
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#   'osm_type': 'relation',
#   'osm_id': 3669583,
#   'boundingbox': ['42.935665', '43.023448', '-75.327514', '-75.207338'],
#   'lat': '43.0006253',
#   'lon': '-75.3137775',
#   'display_name': 'Town of Paris, Oneida County, New York, United States',
#   'class': 'boundary',
#   'type': 'administrative',
#   'importance': 0.5048929025730893,
#   'icon': 'https://nominatim.openstreetmap.org/ui/mapicons/poi_boundary_administrative.p.20.png'}]

# %% [markdown]
# Récupéré son adresse IP automatiquement puis trouver l'endroit sa localisation.

# %% [markdown]
# On envoie une requete a une api apify pour récupérer son adresse ip.

# %% [markdown]
# ### Adresse Ip

# %%
import requests
ip = requests.get('https://api.ipify.org').text

# %% [markdown]
# On trouve sa localisation par rapport a cette adresse ip

# %% [markdown]
# On a pas réussi a trouver de bon outil pour pouvoir récupéré par rapport a l'ip la localisation de l'appareil qui utilise l'outil. On passe donc par un site et on scrap en utilisant Sélénium son résultat. Bien que le résulat donné peut ne pas être assez précis, cela nous suffira pour calculer la distance entre la personne et l'hotel.
# Pour résumé on scrape l'ip qu'on trouve sur une api, et sur un notre site on scrappe le résultat de la localisation, on doit écrire l'ip trouvé dans une barre de recherche et chercher la localisation en coordonée avec l'api openstreetmap.

# %%
from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager
import time

# %%
options = webdriver.ChromeOptions() 
options.add_argument('-headless') 
options.add_argument('-no-sandbox') 
options.add_argument('-disable-dev-shm-usage') 
options.add_argument("enable-automation") 
options.add_argument("--window-size=1920,1080") 
options.add_argument("--disable-extensions") 
options.add_argument("--dns-prefetch-disable") 
options.add_argument("--disable-gpu")
#driver = webdriver.Chrome('/usr/local/bin/chromedriver', options = options)
driver = webdriver.Chrome('/Users/macbook/.wdm/drivers/chromedriver/mac64/108.0.5359.71/chromedriver', options = options)
#driver  = webdriver.Chrome(ChromeDriverManager().install())

web_link ="https://mon-adresse-ip.fr/localiser-une-adresse-ip/"
driver.get(web_link)
#On cherche la barre de recherche
search_bar=driver.find_element_by_xpath('/html/body/div[2]/section[1]/div/div/div[1]/form/div/div[1]/input')
#on rempli la barre de recherche par l'adresse Ip
search_bar.send_keys(ip)
bouton_research=driver.find_element_by_xpath("/html/body/div[3]/section[1]/div/div/div[1]/form/div/div[2]/button")
#On clique sur le bouton rechercher
bouton_research.click()
time.sleep(10)

# %% [markdown]
# ### Localisation de la personne

# %% [markdown]
# Localisation ville

# %%
adresse = driver.find_element_by_xpath("/html/body/div[3]/section[1]/div/div/div[2]").text
adresse
# Out:
# "L'adresse IP 176.138.138.120 se situe à Le Perreux-sur-Marne, France"

# %% [markdown]
# Nettoyage du résultat

# %%
adresse= adresse.split("à ")[1]
adresse
# Out:
# 'Le Perreux-sur-Marne, France'

# %% [markdown]
# Localisation coordonnée de la ville trouvé

# %%
from geopy.geocoders import Nominatim
geolocator = Nominatim(user_agent="geoapiExercises")
location = geolocator.geocode(adresse)
print(location.latitude, location.longitude)
# Out:
# 48.840627 2.5077111

# %% [markdown]
# # On stoppe le driver

# %%
driver.quit()

# %% [markdown]
# ## Scrapper les 35 villes les plus touristiques :

# %% [markdown]
# On veut se concentrer sur les meilleurs villes, les villes les plus touristiques de france. D'après le <a href="https://one-week-in.com/35-cities-to-visit-in-france/" target="_blank">One Week In.com</a> On a les 35 villes les plus visité de France. On va les scrapper

# %%
url        = "https://one-week-in.com/35-cities-to-visit-in-france/"
requesting = requests.get(url)
soup       = BeautifulSoup(requesting.content, "html.parser")

# %% [markdown]
# ### Liste des villes à étudier sur le projet

# %%
liste_element=soup.findAll('ol')[0].findAll('a')
cities_list = [place.text for place in liste_element]
cities_list
# Out:
# ['Mont Saint Michel',
#  'St Malo',
#  'Bayeux',
#  'Le Havre',
#  'Rouen',
#  'Paris',
#  'Amiens',
#  'Lille',
#  'Strasbourg',
#  'Chateau du Haut Koenigsbourg',
#  'Colmar',
#  'Eguisheim',
#  'Besancon',
#  'Dijon',
#  'Annecy',
#  'Grenoble',
#  'Lyon',
#  'Verdon Gorge',
#  'Bormes les Mimosas',
#  'Cassis',
#  'Marseille',
#  'Aix en Provence',
#  'Avignon',
#  'Uzès',
#  'Nímes',
#  'Aigues Mortes',
#  'Saintes Maries de la mer',
#  'Collioure',
#  'Carcassonne',
#  'Ariege',
#  'Toulouse',
#  'Montauban',
#  'Biarritz',
#  'Bayonne',
#  'La Rochelle']

# %% [markdown]
# On applique maintenant sur la cities_list grâce à une loop pour obtenir les coordonées des villes grace a une API nominatim.openstreetmap

# %%
city_coordinate = []

for gps in cities_list:
    r = requests.get("https://nominatim.openstreetmap.org/search?q={}&format=json".format(gps))
    dic_gps = r.json()
    city_lat = float(dic_gps[0]['lat'])
    city_lon = float(dic_gps[0]['lon'])
    city_coordinate.append([city_lat,city_lon])

# %% [markdown]
# Petit visu du résultat des latitudes et longitudes obtenus

# %%
city_coordinate
# Out:
# [[48.6359541, -1.511459954959514],
#  [48.649518, -2.0260409],
#  [49.2764624, -0.7024738],
#  [49.4938975, 0.1079732],
#  [49.4404591, 1.0939658],
#  [48.8588897, 2.3200410217200766],
#  [49.8941708, 2.2956951],
#  [50.6365654, 3.0635282],
#  [48.584614, 7.7507127],
#  [48.249489800000006, 7.34429620253195],
#  [48.0777517, 7.3579641],
#  [48.0447968, 7.3079618],
#  [47.2380222, 6.0243622],
#  [47.3215806, 5.0414701],
#  [45.8992348, 6.1288847],
#  [45.1875602, 5.7357819],
#  [45.7578137, 4.8320114],
#  [43.7496562, 6.3285616],
#  [43.1506968, 6.3419285],
#  [43.2140359, 5.5396318],
#  [43.2961743, 5.3699525],
#  [43.5298424, 5.4474738],
#  [43.9492493, 4.8059012],
#  [44.0121279, 4.4196718],
#  [43.8374249, 4.3600687],
#  [43.5658225, 4.1912837],
#  [43.4522771, 4.4287172],
#  [42.52505, 3.0831554],
#  [43.2130358, 2.3491069],
#  [42.9455368, 1.4065544156065486],
#  [43.6044622, 1.4442469],
#  [44.0175835, 1.3549991],
#  [43.471143749999996, -1.552726590666314],
#  [43.4945144, -1.4736657],
#  [46.1591126, -1.1520434]]

# %% [markdown]
# On veut maintenant transformer notre cities_list en DataFrame et y ajouter les lat/lon concernées

# %%
df = pd.DataFrame(cities_list)
df.columns = ['Cities']
df.head()
# Out:
#               Cities
# 0  Mont Saint Michel
# 1            St Malo
# 2             Bayeux
# 3           Le Havre
# 4              Rouen

# %% [markdown]
# Comme pour la liste des villes, on convertit nos colonnes lat et lon (listes) en Dataframe

# %%
lat_lon = pd.DataFrame(city_coordinate)
lat_lon.columns = ['Latitude', 'Longitude']

lat_lon.head()
# Out:
#     Latitude  Longitude
# 0  48.635954  -1.511460
# 1  48.649518  -2.026041
# 2  49.276462  -0.702474
# 3  49.493898   0.107973
# 4  49.440459   1.093966

# %% [markdown]
# On associe notre DF lat_lon avec la colonne du nom des villes afin d'en faire un seul DF

# %%
lat_lon['Cities']=cities_list

# %%
lat_lon.head()
# Out:
#     Latitude  Longitude             Cities
# 0  48.635954  -1.511460  Mont Saint Michel
# 1  48.649518  -2.026041            St Malo
# 2  49.276462  -0.702474             Bayeux
# 3  49.493898   0.107973           Le Havre
# 4  49.440459   1.093966              Rouen

# %% [markdown]
# On réorganise l'ordre des colonnes pour un df plus esthétique

# %%
lat_lon = lat_lon.iloc[:, [2,0,1]]
lat_lon
# Out:
#                           Cities   Latitude  Longitude
# 0              Mont Saint Michel  48.635954  -1.511460
# 1                        St Malo  48.649518  -2.026041
# 2                         Bayeux  49.276462  -0.702474
# 3                       Le Havre  49.493898   0.107973
# 4                          Rouen  49.440459   1.093966
# 5                          Paris  48.858890   2.320041
# 6                         Amiens  49.894171   2.295695
# 7                          Lille  50.636565   3.063528
# 8                     Strasbourg  48.584614   7.750713
# 9   Chateau du Haut Koenigsbourg  48.249490   7.344296
# 10                        Colmar  48.077752   7.357964
# 11                     Eguisheim  48.044797   7.307962
# 12                      Besancon  47.238022   6.024362
# 13                         Dijon  47.321581   5.041470
# 14                        Annecy  45.899235   6.128885
# 15                      Grenoble  45.187560   5.735782
# 16                          Lyon  45.757814   4.832011
# 17                  Verdon Gorge  43.749656   6.328562
# 18            Bormes les Mimosas  43.150697   6.341928
# 19                        Cassis  43.214036   5.539632
# 20                     Marseille  43.296174   5.369953
# 21               Aix en Provence  43.529842   5.447474
# 22                       Avignon  43.949249   4.805901
# 23                          Uzès  44.012128   4.419672
# 24                         Nímes  43.837425   4.360069
# 25                 Aigues Mortes  43.565823   4.191284
# 26      Saintes Maries de la mer  43.452277   4.428717
# 27                     Collioure  42.525050   3.083155
# 28                   Carcassonne  43.213036   2.349107
# 29                        Ariege  42.945537   1.406554
# 30                      Toulouse  43.604462   1.444247
# 31                     Montauban  44.017584   1.354999
# 32                      Biarritz  43.471144  -1.552727
# 33                       Bayonne  43.494514  -1.473666
# 34                   La Rochelle  46.159113  -1.152043

# %%
# On récolte les colonnes importantes qui vont nous servir pour la future boucle

Latitude = lat_lon['Latitude'].tolist()
Longitude = lat_lon['Longitude'].tolist()

# Petit test sur les listes Latitude et Longitude voir ce que ça donnerait dans une loop
# On voit que la loop passe bien sur les 35 lignes concernées, on peut maintenant l'appliquer sur notre
# nouvel request (API météo)

# %% [markdown]
# # Données Météo

# %% [markdown]
# Créer une boucle pour répéter la météo sur les 35 villes de la 'cities_list' grâce à l'API OpenWeatherMap

# %% [markdown]
# Clé de l'API OpenWeatherMap

# %%
api_key = "918a35b1534d62a40849c70979c2e98b"

# %%
weather_json = []

for i in range(len(Latitude)):
    #print(Latitude[i], Longitude[i])
    # Le request qu'on fera agir sur l'URL de l'API
    r_weather = requests.get("https://api.openweathermap.org/data/2.5/onecall?lat={}&lon={}&units=metric&exclude=minutely,hourly,alerts&appid={}".format(Latitude[i], Longitude[i], api_key))  
    
    # Faire un requests pour essayer de saisir le JSON sur l'URL 
    dic_weather = r_weather.json()
    
    # Une nouvelle boucle est nécessaire pour répéter cette request maintenant sur 7j
    for week in range(1,8):
        Lat_ = float(lat_lon['Latitude'][i])
        Lon_ = float(lat_lon['Longitude'][i])
        Météo = dic_weather["daily"][week]["weather"][0]["description"]
        Température = dic_weather["daily"][week]["temp"]["day"]
        Humidité = dic_weather["daily"][week]["humidity"]
        Vent = dic_weather["daily"][week]["wind_speed"]
        Date = dic_weather['daily'][week]['dt']
        Timestamp = dic_weather['daily'][week]['dt']
        Date = datetime.fromtimestamp(int(Timestamp))

             # Dictionnaire pour la météo
        dictionnaire = {'Latitude': Lat_,
                        'Longitude': Lon_,
                        'Weather': Météo,
                        'Temperature': Température,
                        'Humidity': Humidité,
                        'Wind': Vent,
                        'Date': Date

                        }

    # récupération de tous les résultats
        weather_json.append(dictionnaire)
        

    

weather_json
# Out:
# [{'Latitude': 48.6359541,
#   'Longitude': -1.511459954959514,
#   'Weather': 'light rain',
#   'Temperature': 5.52,
#   'Humidity': 79,
#   'Wind': 3.47,
#   'Date': datetime.datetime(2023, 1, 19, 13, 0)},
#  {'Latitude': 48.6359541,
#   'Longitude': -1.511459954959514,
#   'Weather': 'broken clouds',
#   'Temperature': 5.11,
#   'Humidity': 70,
#   'Wind': 1.81,
#   'Date': datetime.datetime(2023, 1, 20, 13, 0)},
#  {'Latitude': 48.6359541,
#   'Longitude': -1.511459954959514,
#   'Weather': 'clear sky',
#   'Temperature': 4.82,
#   'Humidity': 71,
#   'Wind': 2.47,
#   'Date': datetime.datetime(2023, 1, 21, 13, 0)},
#  {'Latitude': 48.6359541,
#   'Longitude': -1.511459954959514,
#   'Weather': 'overcast clouds',
#   'Temperature': 4.85,
#   'Humidity': 75,
#   'Wind': 2.04,
#   'Date': datetime.datetime(2023, 1, 22, 13, 0)},
#  {'Latitude': 48.6359541,
#   'Longitude': -1.511459954959514,
#   'Weather': 'light rain',
#   'Temperature': 4.38,
#   'Humidity': 90,
#   'Wind': 4.1,
#   'Date': datetime.datetime(2023, 1, 23, 13, 0)},
#  {'Latitude': 48.6359541,
#   'Longitude': -1.511459954959514,
#   'Weather': 'light rain',
#   'Temperature': 5.85,
#   'Humidity': 86,
#   'Wind': 3.12,
#   'Date': datetime.datetime(2023, 1, 24, 13, 0)},
#  {'Latitude': 48.6359541,
#   'Longitude': -1.511459954959514,
#   'Weather': 'light rain',
#   'Temperature': 3.55,
#   'Humidity': 89,
#   'Wind': 2.66,
#   'Date': datetime.datetime(2023, 1, 25, 13, 0)},
#  {'Latitude': 48.649518,
#   'Longitude': -2.0260409,
#   'Weather': 'light rain',
#   'Temperature': 6.16,
#   'Humidity': 71,
#   'Wind': 7.14,
#   'Date': datetime.datetime(2023, 1, 19, 13, 0)},
#  {'Latitude': 48.649518,
#   'Longitude': -2.0260409,
#   'Weather': 'light rain',
#   'Temperature': 5.68,
#   'Humidity': 70,
#   'Wind': 4.53,
#   'Date': datetime.datetime(2023, 1, 20, 13, 0)},
#  {'Latitude': 48.649518,
#   'Longitude': -2.0260409,
#   'Weather': 'few clouds',
#   'Temperature': 4.93,
#   'Humidity': 66,
#   'Wind': 3.06,
#   'Date': datetime.datetime(2023, 1, 21, 13, 0)},
#  {'Latitude': 48.649518,
#   'Longitude': -2.0260409,
#   'Weather': 'overcast clouds',
#   'Temperature': 5.65,
#   'Humidity': 73,
#   'Wind': 2.29,
#   'Date': datetime.datetime(2023, 1, 22, 13, 0)},
#  {'Latitude': 48.649518,
#   'Longitude': -2.0260409,
#   'Weather': 'light rain',
#   'Temperature': 5.86,
#   'Humidity': 92,
#   'Wind': 5,
#   'Date': datetime.datetime(2023, 1, 23, 13, 0)},
#  {'Latitude': 48.649518,
#   'Longitude': -2.0260409,
#   'Weather': 'light rain',
#   'Temperature': 6.08,
#   'Humidity': 90,
#   'Wind': 4.84,
#   'Date': datetime.datetime(2023, 1, 24, 13, 0)},
#  {'Latitude': 48.649518,
#   'Longitude': -2.0260409,
#   'Weather': 'light rain',
#   'Temperature': 5.91,
#   'Humidity': 94,
#   'Wind': 3.74,
#   'Date': datetime.datetime(2023, 1, 25, 13, 0)},
#  {'Latitude': 49.2764624,
#   'Longitude': -0.7024738,
#   'Weather': 'light rain',
#   'Temperature': 5.02,
#   'Humidity': 75,
#   'Wind': 4.35,
#   'Date': datetime.datetime(2023, 1, 19, 13, 0)},
#  {'Latitude': 49.2764624,
#   'Longitude': -0.7024738,
#   'Weather': 'rain and snow',
#   'Temperature': 4.9,
#   'Humidity': 68,
#   'Wind': 3.19,
#   'Date': datetime.datetime(2023, 1, 20, 13, 0)},
#  {'Latitude': 49.2764624,
#   'Longitude': -0.7024738,
#   'Weather': 'light rain',
#   'Temperature': 5.75,
#   'Humidity': 67,
#   'Wind': 3.34,
#   'Date': datetime.datetime(2023, 1, 21, 13, 0)},
#  {'Latitude': 49.2764624,
#   'Longitude': -0.7024738,
#   'Weather': 'light rain',
#   'Temperature': 3.66,
#   'Humidity': 77,
#   'Wind': 3.05,
#   'Date': datetime.datetime(2023, 1, 22, 13, 0)},
#  {'Latitude': 49.2764624,
#   'Longitude': -0.7024738,
#   'Weather': 'light rain',
#   'Temperature': 3.91,
#   'Humidity': 88,
#   'Wind': 3.66,
#   'Date': datetime.datetime(2023, 1, 23, 13, 0)},
#  {'Latitude': 49.2764624,
#   'Longitude': -0.7024738,
#   'Weather': 'light rain',
#   'Temperature': 5.84,
#   'Humidity': 81,
#   'Wind': 3.08,
#   'Date': datetime.datetime(2023, 1, 24, 13, 0)},
#  {'Latitude': 49.2764624,
#   'Longitude': -0.7024738,
#   'Weather': 'light rain',
#   'Temperature': 4.68,
#   'Humidity': 95,
#   'Wind': 5.65,
#   'Date': datetime.datetime(2023, 1, 25, 13, 0)},
#  {'Latitude': 49.4938975,
#   'Longitude': 0.1079732,
#   'Weather': 'light rain',
#   'Temperature': 6.2,
#   'Humidity': 57,
#   'Wind': 6.39,
#   'Date': datetime.datetime(2023, 1, 19, 13, 0)},
#  {'Latitude': 49.4938975,
#   'Longitude': 0.1079732,
#   'Weather': 'light rain',
#   'Temperature': 5.22,
#   'Humidity': 55,
#   'Wind': 5.14,
#   'Date': datetime.datetime(2023, 1, 20, 13, 0)},
#  {'Latitude': 49.4938975,
#   'Longitude': 0.1079732,
#   'Weather': 'light rain',
#   'Temperature': 6.09,
#   'Humidity': 63,
#   'Wind': 6.57,
#   'Date': datetime.datetime(2023, 1, 21, 13, 0)},
#  {'Latitude': 49.4938975,
#   'Longitude': 0.1079732,
#   'Weather': 'few clouds',
#   'Temperature': 3.03,
#   'Humidity': 71,
#   'Wind': 5.3,
#   'Date': datetime.datetime(2023, 1, 22, 13, 0)},
#  {'Latitude': 49.4938975,
#   'Longitude': 0.1079732,
#   'Weather': 'overcast clouds',
#   'Temperature': 5.72,
#   'Humidity': 81,
#   'Wind': 4.36,
#   'Date': datetime.datetime(2023, 1, 23, 13, 0)},
#  {'Latitude': 49.4938975,
#   'Longitude': 0.1079732,
#   'Weather': 'light rain',
#   'Temperature': 4.29,
#   'Humidity': 69,
#   'Wind': 4.39,
#   'Date': datetime.datetime(2023, 1, 24, 13, 0)},
#  {'Latitude': 49.4938975,
#   'Longitude': 0.1079732,
#   'Weather': 'light rain',
#   'Temperature': 4.15,
#   'Humidity': 71,
#   'Wind': 7.83,
#   'Date': datetime.datetime(2023, 1, 25, 13, 0)},
#  {'Latitude': 49.4404591,
#   'Longitude': 1.0939658,
#   'Weather': 'overcast clouds',
#   'Temperature': 4.56,
#   'Humidity': 78,
#   'Wind': 2.53,
#   'Date': datetime.datetime(2023, 1, 19, 13, 0)},
#  {'Latitude': 49.4404591,
#   'Longitude': 1.0939658,
#   'Weather': 'light snow',
#   'Temperature': 4.08,
#   'Humidity': 68,
#   'Wind': 2.18,
#   'Date': datetime.datetime(2023, 1, 20, 13, 0)},
#  {'Latitude': 49.4404591,
#   'Longitude': 1.0939658,
#   'Weather': 'light rain',
#   'Temperature': 5.04,
#   'Humidity': 75,
#   'Wind': 3.19,
#   'Date': datetime.datetime(2023, 1, 21, 13, 0)},
#  {'Latitude': 49.4404591,
#   'Longitude': 1.0939658,
#   'Weather': 'clear sky',
#   'Temperature': 3.08,
#   'Humidity': 68,
#   'Wind': 2.62,
#   'Date': datetime.datetime(2023, 1, 22, 13, 0)},
#  {'Latitude': 49.4404591,
#   'Longitude': 1.0939658,
#   'Weather': 'light rain',
#   'Temperature': 3.22,
#   'Humidity': 92,
#   'Wind': 1.84,
#   'Date': datetime.datetime(2023, 1, 23, 13, 0)},
#  {'Latitude': 49.4404591,
#   'Longitude': 1.0939658,
#   'Weather': 'clear sky',
#   'Temperature': 3.24,
#   'Humidity': 69,
#   'Wind': 2.81,
#   'Date': datetime.datetime(2023, 1, 24, 13, 0)},
#  {'Latitude': 49.4404591,
#   'Longitude': 1.0939658,
#   'Weather': 'light rain',
#   'Temperature': 3.94,
#   'Humidity': 66,
#   'Wind': 4.03,
#   'Date': datetime.datetime(2023, 1, 25, 13, 0)},
#  {'Latitude': 48.8588897,
#   'Longitude': 2.3200410217200766,
#   'Weather': 'light snow',
#   'Temperature': 4.17,
#   'Humidity': 72,
#   'Wind': 2.43,
#   'Date': datetime.datetime(2023, 1, 19, 13, 0)},
#  {'Latitude': 48.8588897,
#   'Longitude': 2.3200410217200766,
#   'Weather': 'light snow',
#   'Temperature': 3.95,
#   'Humidity': 61,
#   'Wind': 2.18,
#   'Date': datetime.datetime(2023, 1, 20, 13, 0)},
#  {'Latitude': 48.8588897,
#   'Longitude': 2.3200410217200766,
#   'Weather': 'clear sky',
#   'Temperature': 4.14,
#   'Humidity': 66,
#   'Wind': 2.76,
#   'Date': datetime.datetime(2023, 1, 21, 13, 0)},
#  {'Latitude': 48.8588897,
#   'Longitude': 2.3200410217200766,
#   'Weather': 'clear sky',
#   'Temperature': 2.98,
#   'Humidity': 65,
#   'Wind': 3.83,
#   'Date': datetime.datetime(2023, 1, 22, 13, 0)},
#  {'Latitude': 48.8588897,
#   'Longitude': 2.3200410217200766,
#   'Weather': 'scattered clouds',
#   'Temperature': 4.23,
#   'Humidity': 67,
#   'Wind': 2.33,
#   'Date': datetime.datetime(2023, 1, 23, 13, 0)},
#  {'Latitude': 48.8588897,
#   'Longitude': 2.3200410217200766,
#   'Weather': 'clear sky',
#   'Temperature': 3.25,
#   'Humidity': 57,
#   'Wind': 2.45,
#   'Date': datetime.datetime(2023, 1, 24, 13, 0)},
#  {'Latitude': 48.8588897,
#   'Longitude': 2.3200410217200766,
#   'Weather': 'broken clouds',
#   'Temperature': 3.98,
#   'Humidity': 69,
#   'Wind': 1.8,
#   'Date': datetime.datetime(2023, 1, 25, 13, 0)},
#  {'Latitude': 49.8941708,
#   'Longitude': 2.2956951,
#   'Weather': 'light snow',
#   'Temperature': 4.92,
#   'Humidity': 65,
#   'Wind': 4.24,
#   'Date': datetime.datetime(2023, 1, 19, 13, 0)},
#  {'Latitude': 49.8941708,
#   'Longitude': 2.2956951,
#   'Weather': 'clear sky',
#   'Temperature': 3.95,
#   'Humidity': 62,
#   'Wind': 2.59,
#   'Date': datetime.datetime(2023, 1, 20, 13, 0)},
#  {'Latitude': 49.8941708,
#   'Longitude': 2.2956951,
#   'Weather': 'few clouds',
#   'Temperature': 4.48,
#   'Humidity': 78,
#   'Wind': 4.29,
#   'Date': datetime.datetime(2023, 1, 21, 13, 0)},
#  {'Latitude': 49.8941708,
#   'Longitude': 2.2956951,
#   'Weather': 'broken clouds',
#   'Temperature': 4.05,
#   'Humidity': 71,
#   'Wind': 4.98,
#   'Date': datetime.datetime(2023, 1, 22, 13, 0)},
#  {'Latitude': 49.8941708,
#   'Longitude': 2.2956951,
#   'Weather': 'scattered clouds',
#   'Temperature': 4.28,
#   'Humidity': 58,
#   'Wind': 2.73,
#   'Date': datetime.datetime(2023, 1, 23, 13, 0)},
#  {'Latitude': 49.8941708,
#   'Longitude': 2.2956951,
#   'Weather': 'clear sky',
#   'Temperature': 2.95,
#   'Humidity': 63,
#   'Wind': 2.62,
#   'Date': datetime.datetime(2023, 1, 24, 13, 0)},
#  {'Latitude': 49.8941708,
#   'Longitude': 2.2956951,
#   'Weather': 'light rain',
#   'Temperature': 3.98,
#   'Humidity': 62,
#   'Wind': 5.79,
#   'Date': datetime.datetime(2023, 1, 25, 13, 0)},
#  {'Latitude': 50.6365654,
#   'Longitude': 3.0635282,
#   'Weather': 'light snow',
#   'Temperature': 3.64,
#   'Humidity': 71,
#   'Wind': 4.54,
#   'Date': datetime.datetime(2023, 1, 19, 12, 0)},
#  {'Latitude': 50.6365654,
#   'Longitude': 3.0635282,
#   'Weather': 'clear sky',
#   'Temperature': 3.23,
#   'Humidity': 66,
#   'Wind': 3.45,
#   'Date': datetime.datetime(2023, 1, 20, 12, 0)},
#  {'Latitude': 50.6365654,
#   'Longitude': 3.0635282,
#   'Weather': 'light rain',
#   'Temperature': 5.68,
#   'Humidity': 78,
#   'Wind': 4.38,
#   'Date': datetime.datetime(2023, 1, 21, 12, 0)},
#  {'Latitude': 50.6365654,
#   'Longitude': 3.0635282,
#   'Weather': 'broken clouds',
#   'Temperature': 5.77,
#   'Humidity': 63,
#   'Wind': 5.16,
#   'Date': datetime.datetime(2023, 1, 22, 12, 0)},
#  {'Latitude': 50.6365654,
#   'Longitude': 3.0635282,
#   'Weather': 'overcast clouds',
#   'Temperature': 3.76,
#   'Humidity': 78,
#   'Wind': 4.31,
#   'Date': datetime.datetime(2023, 1, 23, 12, 0)},
#  {'Latitude': 50.6365654,
#   'Longitude': 3.0635282,
#   'Weather': 'clear sky',
#   'Temperature': 3.09,
#   'Humidity': 60,
#   'Wind': 2.12,
#   'Date': datetime.datetime(2023, 1, 24, 12, 0)},
#  {'Latitude': 50.6365654,
#   'Longitude': 3.0635282,
#   'Weather': 'light rain',
#   'Temperature': 3.48,
#   'Humidity': 65,
#   'Wind': 5.82,
#   'Date': datetime.datetime(2023, 1, 25, 12, 0)},
#  {'Latitude': 48.584614,
#   'Longitude': 7.7507127,
#   'Weather': 'overcast clouds',
#   'Temperature': 1.36,
#   'Humidity': 77,
#   'Wind': 3.66,
#   'Date': datetime.datetime(2023, 1, 19, 12, 0)},
#  {'Latitude': 48.584614,
#   'Longitude': 7.7507127,
#   'Weather': 'overcast clouds',
#   'Temperature': 1.06,
#   'Humidity': 79,
#   'Wind': 1.84,
#   'Date': datetime.datetime(2023, 1, 20, 12, 0)},
#  {'Latitude': 48.584614,
#   'Longitude': 7.7507127,
#   'Weather': 'light snow',
#   'Temperature': 1.27,
#   'Humidity': 74,
#   'Wind': 1.44,
#   'Date': datetime.datetime(2023, 1, 21, 12, 0)},
#  {'Latitude': 48.584614,
#   'Longitude': 7.7507127,
#   'Weather': 'snow',
#   'Temperature': -0.09,
#   'Humidity': 94,
#   'Wind': 4.45,
#   'Date': datetime.datetime(2023, 1, 22, 12, 0)},
#  {'Latitude': 48.584614,
#   'Longitude': 7.7507127,
#   'Weather': 'light snow',
#   'Temperature': 0.47,
#   'Humidity': 94,
#   'Wind': 3.09,
#   'Date': datetime.datetime(2023, 1, 23, 12, 0)},
#  {'Latitude': 48.584614,
#   'Longitude': 7.7507127,
#   'Weather': 'broken clouds',
#   'Temperature': 0.34,
#   'Humidity': 95,
#   'Wind': 4.1,
#   'Date': datetime.datetime(2023, 1, 24, 12, 0)},
#  {'Latitude': 48.584614,
#   'Longitude': 7.7507127,
#   'Weather': 'overcast clouds',
#   'Temperature': 2.39,
#   'Humidity': 95,
#   'Wind': 2.28,
#   'Date': datetime.datetime(2023, 1, 25, 12, 0)},
#  {'Latitude': 48.249489800000006,
#   'Longitude': 7.34429620253195,
#   'Weather': 'overcast clouds',
#   'Temperature': -1.4,
#   'Humidity': 78,
#   'Wind': 2.02,
#   'Date': datetime.datetime(2023, 1, 19, 12, 0)},
#  {'Latitude': 48.249489800000006,
#   'Longitude': 7.34429620253195,
#   'Weather': 'overcast clouds',
#   'Temperature': -1.49,
#   'Humidity': 78,
#   'Wind': 1.72,
#   'Date': datetime.datetime(2023, 1, 20, 12, 0)},
#  {'Latitude': 48.249489800000006,
#   'Longitude': 7.34429620253195,
#   'Weather': 'light snow',
#   'Temperature': -1.21,
#   'Humidity': 78,
#   'Wind': 1.77,
#   'Date': datetime.datetime(2023, 1, 21, 12, 0)},
#  {'Latitude': 48.249489800000006,
#   'Longitude': 7.34429620253195,
#   'Weather': 'snow',
#   'Temperature': -3.26,
#   'Humidity': 90,
#   'Wind': 2.35,
#   'Date': datetime.datetime(2023, 1, 22, 12, 0)},
#  {'Latitude': 48.249489800000006,
#   'Longitude': 7.34429620253195,
#   'Weather': 'light snow',
#   'Temperature': -1.93,
#   'Humidity': 95,
#   'Wind': 2.02,
#   'Date': datetime.datetime(2023, 1, 23, 12, 0)},
#  {'Latitude': 48.249489800000006,
#   'Longitude': 7.34429620253195,
#   'Weather': 'broken clouds',
#   'Temperature': -2.29,
#   'Humidity': 93,
#   'Wind': 2.94,
#   'Date': datetime.datetime(2023, 1, 24, 12, 0)},
#  {'Latitude': 48.249489800000006,
#   'Longitude': 7.34429620253195,
#   'Weather': 'overcast clouds',
#   'Temperature': 0.35,
#   'Humidity': 97,
#   'Wind': 1.75,
#   'Date': datetime.datetime(2023, 1, 25, 12, 0)},
#  {'Latitude': 48.0777517,
#   'Longitude': 7.3579641,
#   'Weather': 'broken clouds',
#   'Temperature': 1.84,
#   'Humidity': 76,
#   'Wind': 2.61,
#   'Date': datetime.datetime(2023, 1, 19, 12, 0)},
#  {'Latitude': 48.0777517,
#   'Longitude': 7.3579641,
#   'Weather': 'broken clouds',
#   'Temperature': 1.39,
#   'Humidity': 78,
#   'Wind': 1.85,
#   'Date': datetime.datetime(2023, 1, 20, 12, 0)},
#  {'Latitude': 48.0777517,
#   'Longitude': 7.3579641,
#   'Weather': 'light snow',
#   'Temperature': 1.68,
#   'Humidity': 76,
#   'Wind': 1.6,
#   'Date': datetime.datetime(2023, 1, 21, 12, 0)},
#  {'Latitude': 48.0777517,
#   'Longitude': 7.3579641,
#   'Weather': 'snow',
#   'Temperature': 0.17,
#   'Humidity': 88,
#   'Wind': 2.75,
#   'Date': datetime.datetime(2023, 1, 22, 12, 0)},
#  {'Latitude': 48.0777517,
#   'Longitude': 7.3579641,
#   'Weather': 'light snow',
#   'Temperature': 0.96,
#   'Humidity': 93,
#   'Wind': 2.67,
#   'Date': datetime.datetime(2023, 1, 23, 12, 0)},
#  {'Latitude': 48.0777517,
#   'Longitude': 7.3579641,
#   'Weather': 'broken clouds',
#   'Temperature': 0.69,
#   'Humidity': 89,
#   'Wind': 3.76,
#   'Date': datetime.datetime(2023, 1, 24, 12, 0)},
#  {'Latitude': 48.0777517,
#   'Longitude': 7.3579641,
#   'Weather': 'overcast clouds',
#   'Temperature': 3.19,
#   'Humidity': 95,
#   'Wind': 2.32,
#   'Date': datetime.datetime(2023, 1, 25, 12, 0)},
#  {'Latitude': 48.0447968,
#   'Longitude': 7.3079618,
#   'Weather': 'broken clouds',
#   'Temperature': 1.97,
#   'Humidity': 76,
#   'Wind': 2.23,
#   'Date': datetime.datetime(2023, 1, 19, 12, 0)},
#  {'Latitude': 48.0447968,
#   'Longitude': 7.3079618,
#   'Weather': 'broken clouds',
#   'Temperature': 1.49,
#   'Humidity': 79,
#   'Wind': 1.79,
#   'Date': datetime.datetime(2023, 1, 20, 12, 0)},
#  {'Latitude': 48.0447968,
#   'Longitude': 7.3079618,
#   'Weather': 'light snow',
#   'Temperature': 1.72,
#   'Humidity': 76,
#   'Wind': 1.74,
#   'Date': datetime.datetime(2023, 1, 21, 12, 0)},
#  {'Latitude': 48.0447968,
#   'Longitude': 7.3079618,
#   'Weather': 'light snow',
#   'Temperature': 0.4,
#   'Humidity': 85,
#   'Wind': 2.4,
#   'Date': datetime.datetime(2023, 1, 22, 12, 0)},
#  {'Latitude': 48.0447968,
#   'Longitude': 7.3079618,
#   'Weather': 'light snow',
#   'Temperature': 1.19,
#   'Humidity': 92,
#   'Wind': 2.47,
#   'Date': datetime.datetime(2023, 1, 23, 12, 0)},
#  {'Latitude': 48.0447968,
#   'Longitude': 7.3079618,
#   'Weather': 'broken clouds',
#   'Temperature': 0.96,
#   'Humidity': 88,
#   'Wind': 3.61,
#   'Date': datetime.datetime(2023, 1, 24, 12, 0)},
#  {'Latitude': 48.0447968,
#   'Longitude': 7.3079618,
#   'Weather': 'overcast clouds',
#   'Temperature': 3.46,
#   'Humidity': 94,
#   'Wind': 2.2,
#   'Date': datetime.datetime(2023, 1, 25, 12, 0)},
#  {'Latitude': 47.2380222,
#   'Longitude': 6.0243622,
#   'Weather': 'overcast clouds',
#   'Temperature': 0.3,
#   'Humidity': 87,
#   'Wind': 3.45,
#   'Date': datetime.datetime(2023, 1, 19, 12, 0)},
#  {'Latitude': 47.2380222,
#   'Longitude': 6.0243622,
#   'Weather': 'light snow',
#   'Temperature': 0.79,
#   'Humidity': 74,
#   'Wind': 2.85,
#   'Date': datetime.datetime(2023, 1, 20, 12, 0)},
#  {'Latitude': 47.2380222,
#   'Longitude': 6.0243622,
#   'Weather': 'scattered clouds',
#   'Temperature': 1.19,
#   'Humidity': 74,
#   'Wind': 2.95,
#   'Date': datetime.datetime(2023, 1, 21, 12, 0)},
#  {'Latitude': 47.2380222,
#   'Longitude': 6.0243622,
#   'Weather': 'snow',
#   'Temperature': 0.55,
#   'Humidity': 73,
#   'Wind': 2.82,
#   'Date': datetime.datetime(2023, 1, 22, 12, 0)},
#  {'Latitude': 47.2380222,
#   'Longitude': 6.0243622,
#   'Weather': 'snow',
#   'Temperature': 0.76,
#   'Humidity': 94,
#   'Wind': 2.53,
#   'Date': datetime.datetime(2023, 1, 23, 12, 0)},
#  {'Latitude': 47.2380222,
#   'Longitude': 6.0243622,
#   'Weather': 'scattered clouds',
#   'Temperature': 0.4,
#   'Humidity': 87,
#   'Wind': 4.24,
#   'Date': datetime.datetime(2023, 1, 24, 12, 0)},
#  {'Latitude': 47.2380222,
#   'Longitude': 6.0243622,
#   'Weather': 'overcast clouds',
#   'Temperature': 0.91,
#   'Humidity': 98,
#   'Wind': 1.83,
#   'Date': datetime.datetime(2023, 1, 25, 12, 0)},
#  {'Latitude': 47.3215806,
#   'Longitude': 5.0414701,
#   'Weather': 'light snow',
#   'Temperature': 1,
#   'Humidity': 82,
#   'Wind': 2.11,
#   'Date': datetime.datetime(2023, 1, 19, 12, 0)},
#  {'Latitude': 47.3215806,
#   'Longitude': 5.0414701,
#   'Weather': 'snow',
#   'Temperature': 0.76,
#   'Humidity': 84,
#   'Wind': 3.54,
#   'Date': datetime.datetime(2023, 1, 20, 12, 0)},
#  {'Latitude': 47.3215806,
#   'Longitude': 5.0414701,
#   'Weather': 'scattered clouds',
#   'Temperature': 1.13,
#   'Humidity': 74,
#   'Wind': 4.7,
#   'Date': datetime.datetime(2023, 1, 21, 12, 0)},
#  {'Latitude': 47.3215806,
#   'Longitude': 5.0414701,
#   'Weather': 'overcast clouds',
#   'Temperature': 0.48,
#   'Humidity': 76,
#   'Wind': 5.28,
#   'Date': datetime.datetime(2023, 1, 22, 12, 0)},
#  {'Latitude': 47.3215806,
#   'Longitude': 5.0414701,
#   'Weather': 'light snow',
#   'Temperature': 1.87,
#   'Humidity': 83,
#   'Wind': 5.53,
#   'Date': datetime.datetime(2023, 1, 23, 12, 0)},
#  {'Latitude': 47.3215806,
#   'Longitude': 5.0414701,
#   'Weather': 'few clouds',
#   'Temperature': 1.3,
#   'Humidity': 76,
#   'Wind': 4.12,
#   'Date': datetime.datetime(2023, 1, 24, 12, 0)},
#  {'Latitude': 47.3215806,
#   'Longitude': 5.0414701,
#   'Weather': 'overcast clouds',
#   'Temperature': 2.88,
#   'Humidity': 83,
#   'Wind': 2.91,
#   'Date': datetime.datetime(2023, 1, 25, 12, 0)},
#  {'Latitude': 45.8992348,
#   'Longitude': 6.1288847,
#   'Weather': 'few clouds',
#   'Temperature': -0.69,
#   'Humidity': 80,
#   'Wind': 1.74,
#   'Date': datetime.datetime(2023, 1, 19, 12, 0)},
#  {'Latitude': 45.8992348,
#   'Longitude': 6.1288847,
#   'Weather': 'light snow',
#   'Temperature': -0.58,
#   'Humidity': 86,
#   'Wind': 2.59,
#   'Date': datetime.datetime(2023, 1, 20, 12, 0)},
#  {'Latitude': 45.8992348,
#   'Longitude': 6.1288847,
#   'Weather': 'light snow',
#   'Temperature': -1,
#   'Humidity': 83,
#   'Wind': 3.28,
#   'Date': datetime.datetime(2023, 1, 21, 12, 0)},
#  {'Latitude': 45.8992348,
#   'Longitude': 6.1288847,
#   'Weather': 'light snow',
#   'Temperature': -0.6,
#   'Humidity': 80,
#   'Wind': 1.91,
#   'Date': datetime.datetime(2023, 1, 22, 12, 0)},
#  {'Latitude': 45.8992348,
#   'Longitude': 6.1288847,
#   'Weather': 'light snow',
#   'Temperature': 0.29,
#   'Humidity': 87,
#   'Wind': 2.77,
#   'Date': datetime.datetime(2023, 1, 23, 12, 0)},
#  {'Latitude': 45.8992348,
#   'Longitude': 6.1288847,
#   'Weather': 'light snow',
#   'Temperature': -0.09,
#   'Humidity': 84,
#   'Wind': 1.74,
#   'Date': datetime.datetime(2023, 1, 24, 12, 0)},
#  {'Latitude': 45.8992348,
#   'Longitude': 6.1288847,
#   'Weather': 'light snow',
#   'Temperature': 1.59,
#   'Humidity': 87,
#   'Wind': 1.65,
#   'Date': datetime.datetime(2023, 1, 25, 12, 0)},
#  {'Latitude': 45.1875602,
#   'Longitude': 5.7357819,
#   'Weather': 'clear sky',
#   'Temperature': 1.29,
#   'Humidity': 77,
#   'Wind': 2.67,
#   'Date': datetime.datetime(2023, 1, 19, 12, 0)},
#  {'Latitude': 45.1875602,
#   'Longitude': 5.7357819,
#   'Weather': 'light snow',
#   'Temperature': 0.44,
#   'Humidity': 85,
#   'Wind': 3.09,
#   'Date': datetime.datetime(2023, 1, 20, 12, 0)},
#  {'Latitude': 45.1875602,
#   'Longitude': 5.7357819,
#   'Weather': 'light snow',
#   'Temperature': -0.29,
#   'Humidity': 82,
#   'Wind': 2.94,
#   'Date': datetime.datetime(2023, 1, 21, 12, 0)},
#  {'Latitude': 45.1875602,
#   'Longitude': 5.7357819,
#   'Weather': 'light snow',
#   'Temperature': 0.24,
#   'Humidity': 79,
#   'Wind': 3.58,
#   'Date': datetime.datetime(2023, 1, 22, 12, 0)},
#  {'Latitude': 45.1875602,
#   'Longitude': 5.7357819,
#   'Weather': 'light snow',
#   'Temperature': 1.24,
#   'Humidity': 86,
#   'Wind': 3.37,
#   'Date': datetime.datetime(2023, 1, 23, 12, 0)},
#  {'Latitude': 45.1875602,
#   'Longitude': 5.7357819,
#   'Weather': 'light snow',
#   'Temperature': 1.31,
#   'Humidity': 83,
#   'Wind': 2.01,
#   'Date': datetime.datetime(2023, 1, 24, 12, 0)},
#  {'Latitude': 45.1875602,
#   'Longitude': 5.7357819,
#   'Weather': 'broken clouds',
#   'Temperature': 2.35,
#   'Humidity': 85,
#   'Wind': 1.95,
#   'Date': datetime.datetime(2023, 1, 25, 12, 0)},
#  {'Latitude': 45.7578137,
#   'Longitude': 4.8320114,
#   'Weather': 'light snow',
#   'Temperature': 1.56,
#   'Humidity': 80,
#   'Wind': 2.43,
#   'Date': datetime.datetime(2023, 1, 19, 12, 0)},
#  {'Latitude': 45.7578137,
#   'Longitude': 4.8320114,
#   'Weather': 'snow',
#   'Temperature': 1.84,
#   'Humidity': 77,
#   'Wind': 5.32,
#   'Date': datetime.datetime(2023, 1, 20, 12, 0)},
#  {'Latitude': 45.7578137,
#   'Longitude': 4.8320114,
#   'Weather': 'broken clouds',
#   'Temperature': 1.85,
#   'Humidity': 71,
#   'Wind': 6.42,
#   'Date': datetime.datetime(2023, 1, 21, 12, 0)},
#  {'Latitude': 45.7578137,
#   'Longitude': 4.8320114,
#   'Weather': 'light snow',
#   'Temperature': 0.79,
#   'Humidity': 76,
#   'Wind': 4.9,
#   'Date': datetime.datetime(2023, 1, 22, 12, 0)},
#  {'Latitude': 45.7578137,
#   'Longitude': 4.8320114,
#   'Weather': 'light snow',
#   'Temperature': 2.41,
#   'Humidity': 72,
#   'Wind': 5.53,
#   'Date': datetime.datetime(2023, 1, 23, 12, 0)},
#  {'Latitude': 45.7578137,
#   'Longitude': 4.8320114,
#   'Weather': 'overcast clouds',
#   'Temperature': 0.51,
#   'Humidity': 73,
#   'Wind': 4.98,
#   'Date': datetime.datetime(2023, 1, 24, 12, 0)},
#  {'Latitude': 45.7578137,
#   'Longitude': 4.8320114,
#   'Weather': 'light snow',
#   'Temperature': 1,
#   'Humidity': 79,
#   'Wind': 2.51,
#   'Date': datetime.datetime(2023, 1, 25, 12, 0)},
#  {'Latitude': 43.7496562,
#   'Longitude': 6.3285616,
#   'Weather': 'clear sky',
#   'Temperature': 1.2,
#   'Humidity': 28,
#   'Wind': 4.46,
#   'Date': datetime.datetime(2023, 1, 19, 12, 0)},
#  {'Latitude': 43.7496562,
#   'Longitude': 6.3285616,
#   'Weather': 'clear sky',
#   'Temperature': 1.77,
#   'Humidity': 21,
#   'Wind': 3.03,
#   'Date': datetime.datetime(2023, 1, 20, 12, 0)},
#  {'Latitude': 43.7496562,
#   'Longitude': 6.3285616,
#   'Weather': 'few clouds',
#   'Temperature': 3.54,
#   'Humidity': 22,
#   'Wind': 2.41,
#   'Date': datetime.datetime(2023, 1, 21, 12, 0)},
#  {'Latitude': 43.7496562,
#   'Longitude': 6.3285616,
#   'Weather': 'scattered clouds',
#   'Temperature': 3.9,
#   'Humidity': 18,
#   'Wind': 2.3,
#   'Date': datetime.datetime(2023, 1, 22, 12, 0)},
#  {'Latitude': 43.7496562,
#   'Longitude': 6.3285616,
#   'Weather': 'few clouds',
#   'Temperature': 5.32,
#   'Humidity': 22,
#   'Wind': 2.71,
#   'Date': datetime.datetime(2023, 1, 23, 12, 0)},
#  {'Latitude': 43.7496562,
#   'Longitude': 6.3285616,
#   'Weather': 'broken clouds',
#   'Temperature': 5.35,
#   'Humidity': 38,
#   'Wind': 2.07,
#   'Date': datetime.datetime(2023, 1, 24, 12, 0)},
#  {'Latitude': 43.7496562,
#   'Longitude': 6.3285616,
#   'Weather': 'overcast clouds',
#   'Temperature': 6.44,
#   'Humidity': 46,
#   'Wind': 1.78,
#   'Date': datetime.datetime(2023, 1, 25, 12, 0)},
#  {'Latitude': 43.1506968,
#   'Longitude': 6.3419285,
#   'Weather': 'clear sky',
#   'Temperature': 6.91,
#   'Humidity': 37,
#   'Wind': 13.61,
#   'Date': datetime.datetime(2023, 1, 19, 12, 0)},
#  {'Latitude': 43.1506968,
#   'Longitude': 6.3419285,
#   'Weather': 'clear sky',
#   'Temperature': 5.64,
#   'Humidity': 40,
#   'Wind': 5.55,
#   'Date': datetime.datetime(2023, 1, 20, 12, 0)},
#  {'Latitude': 43.1506968,
#   'Longitude': 6.3419285,
#   'Weather': 'scattered clouds',
#   'Temperature': 7.68,
#   'Humidity': 30,
#   'Wind': 3.41,
#   'Date': datetime.datetime(2023, 1, 21, 12, 0)},
#  {'Latitude': 43.1506968,
#   'Longitude': 6.3419285,
#   'Weather': 'clear sky',
#   'Temperature': 8.17,
#   'Humidity': 25,
#   'Wind': 3.36,
#   'Date': datetime.datetime(2023, 1, 22, 12, 0)},
#  {'Latitude': 43.1506968,
#   'Longitude': 6.3419285,
#   'Weather': 'broken clouds',
#   'Temperature': 7.2,
#   'Humidity': 33,
#   'Wind': 3.79,
#   'Date': datetime.datetime(2023, 1, 23, 12, 0)},
#  {'Latitude': 43.1506968,
#   'Longitude': 6.3419285,
#   'Weather': 'light rain',
#   'Temperature': 9.91,
#   'Humidity': 42,
#   'Wind': 3.51,
#   'Date': datetime.datetime(2023, 1, 24, 12, 0)},
#  {'Latitude': 43.1506968,
#   'Longitude': 6.3419285,
#   'Weather': 'overcast clouds',
#   'Temperature': 11.09,
#   'Humidity': 53,
#   'Wind': 3.59,
#   'Date': datetime.datetime(2023, 1, 25, 12, 0)},
#  {'Latitude': 43.2140359,
#   'Longitude': 5.5396318,
#   'Weather': 'clear sky',
#   'Temperature': 6.29,
#   'Humidity': 59,
#   'Wind': 15.37,
#   'Date': datetime.datetime(2023, 1, 19, 12, 0)},
#  {'Latitude': 43.2140359,
#   'Longitude': 5.5396318,
#   'Weather': 'clear sky',
#   'Temperature': 6.21,
#   'Humidity': 54,
#   'Wind': 12.58,
#   'Date': datetime.datetime(2023, 1, 20, 12, 0)},
#  {'Latitude': 43.2140359,
#   'Longitude': 5.5396318,
#   'Weather': 'clear sky',
#   'Temperature': 6.82,
#   'Humidity': 32,
#   'Wind': 6.34,
#   'Date': datetime.datetime(2023, 1, 21, 12, 0)},
#  {'Latitude': 43.2140359,
#   'Longitude': 5.5396318,
#   'Weather': 'clear sky',
#   'Temperature': 7.14,
#   'Humidity': 35,
#   'Wind': 6.17,
#   'Date': datetime.datetime(2023, 1, 22, 12, 0)},
#  {'Latitude': 43.2140359,
#   'Longitude': 5.5396318,
#   'Weather': 'broken clouds',
#   'Temperature': 6.26,
#   'Humidity': 44,
#   'Wind': 5.48,
#   'Date': datetime.datetime(2023, 1, 23, 12, 0)},
#  {'Latitude': 43.2140359,
#   'Longitude': 5.5396318,
#   'Weather': 'broken clouds',
#   'Temperature': 9.12,
#   'Humidity': 40,
#   'Wind': 3.28,
#   'Date': datetime.datetime(2023, 1, 24, 12, 0)},
#  {'Latitude': 43.2140359,
#   'Longitude': 5.5396318,
#   'Weather': 'overcast clouds',
#   'Temperature': 10,
#   'Humidity': 60,
#   'Wind': 3.88,
#   'Date': datetime.datetime(2023, 1, 25, 12, 0)},
#  {'Latitude': 43.2961743,
#   'Longitude': 5.3699525,
#   'Weather': 'clear sky',
#   'Temperature': 6.23,
#   'Humidity': 60,
#   'Wind': 14.86,
#   'Date': datetime.datetime(2023, 1, 19, 12, 0)},
#  {'Latitude': 43.2961743,
#   'Longitude': 5.3699525,
#   'Weather': 'clear sky',
#   'Temperature': 6,
#   'Humidity': 58,
#   'Wind': 13.96,
#   'Date': datetime.datetime(2023, 1, 20, 12, 0)},
#  {'Latitude': 43.2961743,
#   'Longitude': 5.3699525,
#   'Weather': 'clear sky',
#   'Temperature': 6.12,
#   'Humidity': 38,
#   'Wind': 8.37,
#   'Date': datetime.datetime(2023, 1, 21, 12, 0)},
#  {'Latitude': 43.2961743,
#   'Longitude': 5.3699525,
#   'Weather': 'clear sky',
#   'Temperature': 6.17,
#   'Humidity': 40,
#   'Wind': 8.03,
#   'Date': datetime.datetime(2023, 1, 22, 12, 0)},
#  {'Latitude': 43.2961743,
#   'Longitude': 5.3699525,
#   'Weather': 'scattered clouds',
#   'Temperature': 5.89,
#   'Humidity': 51,
#   'Wind': 7.12,
#   'Date': datetime.datetime(2023, 1, 23, 12, 0)},
#  {'Latitude': 43.2961743,
#   'Longitude': 5.3699525,
#   'Weather': 'broken clouds',
#   'Temperature': 7.96,
#   'Humidity': 43,
#   'Wind': 4.95,
#   'Date': datetime.datetime(2023, 1, 24, 12, 0)},
#  {'Latitude': 43.2961743,
#   'Longitude': 5.3699525,
#   'Weather': 'overcast clouds',
#   'Temperature': 9.51,
#   'Humidity': 54,
#   'Wind': 4.6,
#   'Date': datetime.datetime(2023, 1, 25, 12, 0)},
#  {'Latitude': 43.5298424,
#   'Longitude': 5.4474738,
#   'Weather': 'clear sky',
#   'Temperature': 4.63,
#   'Humidity': 53,
#   'Wind': 9.73,
#   'Date': datetime.datetime(2023, 1, 19, 12, 0)},
#  {'Latitude': 43.5298424,
#   'Longitude': 5.4474738,
#   'Weather': 'clear sky',
#   'Temperature': 4.64,
#   'Humidity': 47,
#   'Wind': 9.18,
#   'Date': datetime.datetime(2023, 1, 20, 12, 0)},
#  {'Latitude': 43.5298424,
#   'Longitude': 5.4474738,
#   'Weather': 'clear sky',
#   'Temperature': 4.53,
#   'Humidity': 32,
#   'Wind': 2.94,
#   'Date': datetime.datetime(2023, 1, 21, 12, 0)},
#  {'Latitude': 43.5298424,
#   'Longitude': 5.4474738,
#   'Weather': 'clear sky',
#   'Temperature': 4.71,
#   'Humidity': 33,
#   'Wind': 3.71,
#   'Date': datetime.datetime(2023, 1, 22, 12, 0)},
#  {'Latitude': 43.5298424,
#   'Longitude': 5.4474738,
#   'Weather': 'few clouds',
#   'Temperature': 4.56,
#   'Humidity': 43,
#   'Wind': 3,
#   'Date': datetime.datetime(2023, 1, 23, 12, 0)},
#  {'Latitude': 43.5298424,
#   'Longitude': 5.4474738,
#   'Weather': 'broken clouds',
#   'Temperature': 6.37,
#   'Humidity': 36,
#   'Wind': 2.19,
#   'Date': datetime.datetime(2023, 1, 24, 12, 0)},
#  {'Latitude': 43.5298424,
#   'Longitude': 5.4474738,
#   'Weather': 'broken clouds',
#   'Temperature': 8.71,
#   'Humidity': 41,
#   'Wind': 1.91,
#   'Date': datetime.datetime(2023, 1, 25, 12, 0)},
#  {'Latitude': 43.9492493,
#   'Longitude': 4.8059012,
#   'Weather': 'clear sky',
#   'Temperature': 5.46,
#   'Humidity': 56,
#   'Wind': 9.12,
#   'Date': datetime.datetime(2023, 1, 19, 12, 0)},
#  {'Latitude': 43.9492493,
#   'Longitude': 4.8059012,
#   'Weather': 'clear sky',
#   'Temperature': 4.64,
#   'Humidity': 61,
#   'Wind': 11.62,
#   'Date': datetime.datetime(2023, 1, 20, 12, 0)},
#  {'Latitude': 43.9492493,
#   'Longitude': 4.8059012,
#   'Weather': 'clear sky',
#   'Temperature': 3.63,
#   'Humidity': 55,
#   'Wind': 12.13,
#   'Date': datetime.datetime(2023, 1, 21, 12, 0)},
#  {'Latitude': 43.9492493,
#   'Longitude': 4.8059012,
#   'Weather': 'clear sky',
#   'Temperature': 3.74,
#   'Humidity': 59,
#   'Wind': 13.51,
#   'Date': datetime.datetime(2023, 1, 22, 12, 0)},
#  {'Latitude': 43.9492493,
#   'Longitude': 4.8059012,
#   'Weather': 'few clouds',
#   'Temperature': 4.86,
#   'Humidity': 60,
#   'Wind': 13.39,
#   'Date': datetime.datetime(2023, 1, 23, 12, 0)},
#  {'Latitude': 43.9492493,
#   'Longitude': 4.8059012,
#   'Weather': 'scattered clouds',
#   'Temperature': 4.36,
#   'Humidity': 54,
#   'Wind': 10.7,
#   'Date': datetime.datetime(2023, 1, 24, 12, 0)},
#  {'Latitude': 43.9492493,
#   'Longitude': 4.8059012,
#   'Weather': 'broken clouds',
#   'Temperature': 5.47,
#   'Humidity': 57,
#   'Wind': 8.53,
#   'Date': datetime.datetime(2023, 1, 25, 12, 0)},
#  {'Latitude': 44.0121279,
#   'Longitude': 4.4196718,
#   'Weather': 'clear sky',
#   'Temperature': 6.22,
#   'Humidity': 45,
#   'Wind': 6.76,
#   'Date': datetime.datetime(2023, 1, 19, 12, 0)},
#  {'Latitude': 44.0121279,
#   'Longitude': 4.4196718,
#   'Weather': 'clear sky',
#   'Temperature': 5.9,
#   'Humidity': 49,
#   'Wind': 9.2,
#   'Date': datetime.datetime(2023, 1, 20, 12, 0)},
#  {'Latitude': 44.0121279,
#   'Longitude': 4.4196718,
#   'Weather': 'clear sky',
#   'Temperature': 3.92,
#   'Humidity': 55,
#   'Wind': 11.3,
#   'Date': datetime.datetime(2023, 1, 21, 12, 0)},
#  {'Latitude': 44.0121279,
#   'Longitude': 4.4196718,
#   'Weather': 'clear sky',
#   'Temperature': 4.98,
#   'Humidity': 51,
#   'Wind': 9.84,
#   'Date': datetime.datetime(2023, 1, 22, 12, 0)},
#  {'Latitude': 44.0121279,
#   'Longitude': 4.4196718,
#   'Weather': 'clear sky',
#   'Temperature': 5.77,
#   'Humidity': 53,
#   'Wind': 10.36,
#   'Date': datetime.datetime(2023, 1, 23, 12, 0)},
#  {'Latitude': 44.0121279,
#   'Longitude': 4.4196718,
#   'Weather': 'scattered clouds',
#   'Temperature': 4.1,
#   'Humidity': 55,
#   'Wind': 9.41,
#   'Date': datetime.datetime(2023, 1, 24, 12, 0)},
#  {'Latitude': 44.0121279,
#   'Longitude': 4.4196718,
#   'Weather': 'broken clouds',
#   'Temperature': 4.94,
#   'Humidity': 55,
#   'Wind': 8.52,
#   'Date': datetime.datetime(2023, 1, 25, 12, 0)},
#  {'Latitude': 43.8374249,
#   'Longitude': 4.3600687,
#   'Weather': 'clear sky',
#   'Temperature': 6.73,
#   'Humidity': 44,
#   'Wind': 5.99,
#   'Date': datetime.datetime(2023, 1, 19, 12, 0)},
#  {'Latitude': 43.8374249,
#   'Longitude': 4.3600687,
#   'Weather': 'clear sky',
#   'Temperature': 6.77,
#   'Humidity': 44,
#   'Wind': 8.5,
#   'Date': datetime.datetime(2023, 1, 20, 12, 0)},
#  {'Latitude': 43.8374249,
#   'Longitude': 4.3600687,
#   'Weather': 'clear sky',
#   'Temperature': 4.96,
#   'Humidity': 50,
#   'Wind': 10.52,
#   'Date': datetime.datetime(2023, 1, 21, 12, 0)},
#  {'Latitude': 43.8374249,
#   'Longitude': 4.3600687,
#   'Weather': 'clear sky',
#   'Temperature': 6.04,
#   'Humidity': 45,
#   'Wind': 9.03,
#   'Date': datetime.datetime(2023, 1, 22, 12, 0)},
#  {'Latitude': 43.8374249,
#   'Longitude': 4.3600687,
#   'Weather': 'clear sky',
#   'Temperature': 6.82,
#   'Humidity': 47,
#   'Wind': 9.33,
#   'Date': datetime.datetime(2023, 1, 23, 12, 0)},
#  {'Latitude': 43.8374249,
#   'Longitude': 4.3600687,
#   'Weather': 'scattered clouds',
#   'Temperature': 5,
#   'Humidity': 52,
#   'Wind': 8.05,
#   'Date': datetime.datetime(2023, 1, 24, 12, 0)},
#  {'Latitude': 43.8374249,
#   'Longitude': 4.3600687,
#   'Weather': 'broken clouds',
#   'Temperature': 5.95,
#   'Humidity': 51,
#   'Wind': 7.47,
#   'Date': datetime.datetime(2023, 1, 25, 12, 0)},
#  {'Latitude': 43.5658225,
#   'Longitude': 4.1912837,
#   'Weather': 'clear sky',
#   'Temperature': 7.35,
#   'Humidity': 47,
#   'Wind': 7.88,
#   'Date': datetime.datetime(2023, 1, 19, 12, 0)},
#  {'Latitude': 43.5658225,
#   'Longitude': 4.1912837,
#   'Weather': 'clear sky',
#   'Temperature': 7.71,
#   'Humidity': 45,
#   'Wind': 9.12,
#   'Date': datetime.datetime(2023, 1, 20, 12, 0)},
#  {'Latitude': 43.5658225,
#   'Longitude': 4.1912837,
#   'Weather': 'clear sky',
#   'Temperature': 6.58,
#   'Humidity': 47,
#   'Wind': 9.86,
#   'Date': datetime.datetime(2023, 1, 21, 12, 0)},
#  {'Latitude': 43.5658225,
#   'Longitude': 4.1912837,
#   'Weather': 'clear sky',
#   'Temperature': 7.38,
#   'Humidity': 41,
#   'Wind': 8.65,
#   'Date': datetime.datetime(2023, 1, 22, 12, 0)},
#  {'Latitude': 43.5658225,
#   'Longitude': 4.1912837,
#   'Weather': 'few clouds',
#   'Temperature': 8.11,
#   'Humidity': 43,
#   'Wind': 8.73,
#   'Date': datetime.datetime(2023, 1, 23, 12, 0)},
#  {'Latitude': 43.5658225,
#   'Longitude': 4.1912837,
#   'Weather': 'scattered clouds',
#   'Temperature': 5.92,
#   'Humidity': 52,
#   'Wind': 6.5,
#   'Date': datetime.datetime(2023, 1, 24, 12, 0)},
#  {'Latitude': 43.5658225,
#   'Longitude': 4.1912837,
#   'Weather': 'broken clouds',
#   'Temperature': 6.97,
#   'Humidity': 49,
#   'Wind': 6.33,
#   'Date': datetime.datetime(2023, 1, 25, 12, 0)},
#  {'Latitude': 43.4522771,
#   'Longitude': 4.4287172,
#   'Weather': 'clear sky',
#   'Temperature': 7.18,
#   'Humidity': 51,
#   'Wind': 9.22,
#   'Date': datetime.datetime(2023, 1, 19, 12, 0)},
#  {'Latitude': 43.4522771,
#   'Longitude': 4.4287172,
#   'Weather': 'clear sky',
#   'Temperature': 7.36,
#   'Humidity': 50,
#   'Wind': 11.65,
#   'Date': datetime.datetime(2023, 1, 20, 12, 0)},
#  {'Latitude': 43.4522771,
#   'Longitude': 4.4287172,
#   'Weather': 'clear sky',
#   'Temperature': 5.18,
#   'Humidity': 59,
#   'Wind': 13.94,
#   'Date': datetime.datetime(2023, 1, 21, 12, 0)},
#  {'Latitude': 43.4522771,
#   'Longitude': 4.4287172,
#   'Weather': 'clear sky',
#   'Temperature': 6.56,
#   'Humidity': 54,
#   'Wind': 13.61,
#   'Date': datetime.datetime(2023, 1, 22, 12, 0)},
#  {'Latitude': 43.4522771,
#   'Longitude': 4.4287172,
#   'Weather': 'scattered clouds',
#   'Temperature': 7.64,
#   'Humidity': 51,
#   'Wind': 13.55,
#   'Date': datetime.datetime(2023, 1, 23, 12, 0)},
#  {'Latitude': 43.4522771,
#   'Longitude': 4.4287172,
#   'Weather': 'scattered clouds',
#   'Temperature': 5.53,
#   'Humidity': 59,
#   'Wind': 12.53,
#   'Date': datetime.datetime(2023, 1, 24, 12, 0)},
#  {'Latitude': 43.4522771,
#   'Longitude': 4.4287172,
#   'Weather': 'overcast clouds',
#   'Temperature': 6.47,
#   'Humidity': 59,
#   'Wind': 10.21,
#   'Date': datetime.datetime(2023, 1, 25, 12, 0)},
#  {'Latitude': 42.52505,
#   'Longitude': 3.0831554,
#   'Weather': 'clear sky',
#   'Temperature': 8.82,
#   'Humidity': 47,
#   'Wind': 10.7,
#   'Date': datetime.datetime(2023, 1, 19, 12, 0)},
#  {'Latitude': 42.52505,
#   'Longitude': 3.0831554,
#   'Weather': 'scattered clouds',
#   'Temperature': 6.81,
#   'Humidity': 61,
#   'Wind': 13.68,
#   'Date': datetime.datetime(2023, 1, 20, 12, 0)},
#  {'Latitude': 42.52505,
#   'Longitude': 3.0831554,
#   'Weather': 'clear sky',
#   'Temperature': 7.18,
#   'Humidity': 41,
#   'Wind': 14.91,
#   'Date': datetime.datetime(2023, 1, 21, 12, 0)},
#  {'Latitude': 42.52505,
#   'Longitude': 3.0831554,
#   'Weather': 'clear sky',
#   'Temperature': 7.32,
#   'Humidity': 46,
#   'Wind': 15.18,
#   'Date': datetime.datetime(2023, 1, 22, 12, 0)},
#  {'Latitude': 42.52505,
#   'Longitude': 3.0831554,
#   'Weather': 'clear sky',
#   'Temperature': 7.34,
#   'Humidity': 46,
#   'Wind': 15.4,
#   'Date': datetime.datetime(2023, 1, 23, 12, 0)},
#  {'Latitude': 42.52505,
#   'Longitude': 3.0831554,
#   'Weather': 'few clouds',
#   'Temperature': 8.05,
#   'Humidity': 50,
#   'Wind': 13.48,
#   'Date': datetime.datetime(2023, 1, 24, 12, 0)},
#  {'Latitude': 42.52505,
#   'Longitude': 3.0831554,
#   'Weather': 'overcast clouds',
#   'Temperature': 9.06,
#   'Humidity': 49,
#   'Wind': 9.19,
#   'Date': datetime.datetime(2023, 1, 25, 12, 0)},
#  {'Latitude': 43.2130358,
#   'Longitude': 2.3491069,
#   'Weather': 'rain and snow',
#   'Temperature': 4.74,
#   'Humidity': 86,
#   'Wind': 7.4,
#   'Date': datetime.datetime(2023, 1, 19, 13, 0)},
#  {'Latitude': 43.2130358,
#   'Longitude': 2.3491069,
#   'Weather': 'light snow',
#   'Temperature': 4.11,
#   'Humidity': 79,
#   'Wind': 7.55,
#   'Date': datetime.datetime(2023, 1, 20, 13, 0)},
#  {'Latitude': 43.2130358,
#   'Longitude': 2.3491069,
#   'Weather': 'few clouds',
#   'Temperature': 3.44,
#   'Humidity': 62,
#   'Wind': 8.44,
#   'Date': datetime.datetime(2023, 1, 21, 13, 0)},
#  {'Latitude': 43.2130358,
#   'Longitude': 2.3491069,
#   'Weather': 'overcast clouds',
#   'Temperature': 3.66,
#   'Humidity': 65,
#   'Wind': 8.69,
#   'Date': datetime.datetime(2023, 1, 22, 13, 0)},
#  {'Latitude': 43.2130358,
#   'Longitude': 2.3491069,
#   'Weather': 'broken clouds',
#   'Temperature': 3.6,
#   'Humidity': 64,
#   'Wind': 9.38,
#   'Date': datetime.datetime(2023, 1, 23, 13, 0)},
#  {'Latitude': 43.2130358,
#   'Longitude': 2.3491069,
#   'Weather': 'scattered clouds',
#   'Temperature': 4.73,
#   'Humidity': 63,
#   'Wind': 7.7,
#   'Date': datetime.datetime(2023, 1, 24, 13, 0)},
#  {'Latitude': 43.2130358,
#   'Longitude': 2.3491069,
#   'Weather': 'broken clouds',
#   'Temperature': 4.47,
#   'Humidity': 67,
#   'Wind': 7.26,
#   'Date': datetime.datetime(2023, 1, 25, 13, 0)},
#  {'Latitude': 42.9455368,
#   'Longitude': 1.4065544156065486,
#   'Weather': 'snow',
#   'Temperature': -1.35,
#   'Humidity': 82,
#   'Wind': 2.58,
#   'Date': datetime.datetime(2023, 1, 19, 13, 0)},
#  {'Latitude': 42.9455368,
#   'Longitude': 1.4065544156065486,
#   'Weather': 'snow',
#   'Temperature': -3.18,
#   'Humidity': 92,
#   'Wind': 2.59,
#   'Date': datetime.datetime(2023, 1, 20, 13, 0)},
#  {'Latitude': 42.9455368,
#   'Longitude': 1.4065544156065486,
#   'Weather': 'scattered clouds',
#   'Temperature': -4.11,
#   'Humidity': 77,
#   'Wind': 3.06,
#   'Date': datetime.datetime(2023, 1, 21, 13, 0)},
#  {'Latitude': 42.9455368,
#   'Longitude': 1.4065544156065486,
#   'Weather': 'broken clouds',
#   'Temperature': -3.42,
#   'Humidity': 73,
#   'Wind': 2.55,
#   'Date': datetime.datetime(2023, 1, 22, 13, 0)},
#  {'Latitude': 42.9455368,
#   'Longitude': 1.4065544156065486,
#   'Weather': 'few clouds',
#   'Temperature': -3.31,
#   'Humidity': 71,
#   'Wind': 3.2,
#   'Date': datetime.datetime(2023, 1, 23, 13, 0)},
#  {'Latitude': 42.9455368,
#   'Longitude': 1.4065544156065486,
#   'Weather': 'clear sky',
#   'Temperature': -1.83,
#   'Humidity': 69,
#   'Wind': 2.62,
#   'Date': datetime.datetime(2023, 1, 24, 13, 0)},
#  {'Latitude': 42.9455368,
#   'Longitude': 1.4065544156065486,
#   'Weather': 'broken clouds',
#   'Temperature': -1.25,
#   'Humidity': 78,
#   'Wind': 2.62,
#   'Date': datetime.datetime(2023, 1, 25, 13, 0)},
#  {'Latitude': 43.6044622,
#   'Longitude': 1.4442469,
#   'Weather': 'moderate rain',
#   'Temperature': 5.08,
#   'Humidity': 82,
#   'Wind': 5.56,
#   'Date': datetime.datetime(2023, 1, 19, 13, 0)},
#  {'Latitude': 43.6044622,
#   'Longitude': 1.4442469,
#   'Weather': 'overcast clouds',
#   'Temperature': 4.08,
#   'Humidity': 67,
#   'Wind': 5,
#   'Date': datetime.datetime(2023, 1, 20, 13, 0)},
#  {'Latitude': 43.6044622,
#   'Longitude': 1.4442469,
#   'Weather': 'clear sky',
#   'Temperature': 3.6,
#   'Humidity': 53,
#   'Wind': 5.72,
#   'Date': datetime.datetime(2023, 1, 21, 13, 0)},
#  {'Latitude': 43.6044622,
#   'Longitude': 1.4442469,
#   'Weather': 'few clouds',
#   'Temperature': 3.83,
#   'Humidity': 63,
#   'Wind': 5.38,
#   'Date': datetime.datetime(2023, 1, 22, 13, 0)},
#  {'Latitude': 43.6044622,
#   'Longitude': 1.4442469,
#   'Weather': 'scattered clouds',
#   'Temperature': 3.93,
#   'Humidity': 60,
#   'Wind': 6.12,
#   'Date': datetime.datetime(2023, 1, 23, 13, 0)},
#  {'Latitude': 43.6044622,
#   'Longitude': 1.4442469,
#   'Weather': 'scattered clouds',
#   'Temperature': 4.38,
#   'Humidity': 59,
#   'Wind': 5.39,
#   'Date': datetime.datetime(2023, 1, 24, 13, 0)},
#  {'Latitude': 43.6044622,
#   'Longitude': 1.4442469,
#   'Weather': 'overcast clouds',
#   'Temperature': 4.23,
#   'Humidity': 65,
#   'Wind': 5.32,
#   'Date': datetime.datetime(2023, 1, 25, 13, 0)},
#  {'Latitude': 44.0175835,
#   'Longitude': 1.3549991,
#   'Weather': 'light rain',
#   'Temperature': 5.28,
#   'Humidity': 79,
#   'Wind': 4.06,
#   'Date': datetime.datetime(2023, 1, 19, 13, 0)},
#  {'Latitude': 44.0175835,
#   'Longitude': 1.3549991,
#   'Weather': 'overcast clouds',
#   'Temperature': 5.82,
#   'Humidity': 58,
#   'Wind': 5.05,
#   'Date': datetime.datetime(2023, 1, 20, 13, 0)},
#  {'Latitude': 44.0175835,
#   'Longitude': 1.3549991,
#   'Weather': 'clear sky',
#   'Temperature': 4.25,
#   'Humidity': 50,
#   'Wind': 5.09,
#   'Date': datetime.datetime(2023, 1, 21, 13, 0)},
#  {'Latitude': 44.0175835,
#   'Longitude': 1.3549991,
#   'Weather': 'few clouds',
#   'Temperature': 4.38,
#   'Humidity': 61,
#   'Wind': 5.34,
#   'Date': datetime.datetime(2023, 1, 22, 13, 0)},
#  {'Latitude': 44.0175835,
#   'Longitude': 1.3549991,
#   'Weather': 'few clouds',
#   'Temperature': 3.8,
#   'Humidity': 61,
#   'Wind': 5.63,
#   'Date': datetime.datetime(2023, 1, 23, 13, 0)},
#  {'Latitude': 44.0175835,
#   'Longitude': 1.3549991,
#   'Weather': 'clear sky',
#   'Temperature': 4.29,
#   'Humidity': 58,
#   'Wind': 4.44,
#   'Date': datetime.datetime(2023, 1, 24, 13, 0)},
#  {'Latitude': 44.0175835,
#   'Longitude': 1.3549991,
#   'Weather': 'broken clouds',
#   'Temperature': 3.94,
#   'Humidity': 66,
#   'Wind': 4.28,
#   'Date': datetime.datetime(2023, 1, 25, 13, 0)},
#  {'Latitude': 43.471143749999996,
#   'Longitude': -1.552726590666314,
#   'Weather': 'moderate rain',
#   'Temperature': 6.46,
#   'Humidity': 89,
#   'Wind': 12.17,
#   'Date': datetime.datetime(2023, 1, 19, 13, 0)},
#  {'Latitude': 43.471143749999996,
#   'Longitude': -1.552726590666314,
#   'Weather': 'overcast clouds',
#   'Temperature': 6.84,
#   'Humidity': 69,
#   'Wind': 3.83,
#   'Date': datetime.datetime(2023, 1, 20, 13, 0)},
#  {'Latitude': 43.471143749999996,
#   'Longitude': -1.552726590666314,
#   'Weather': 'clear sky',
#   'Temperature': 4.65,
#   'Humidity': 68,
#   'Wind': 2.9,
#   'Date': datetime.datetime(2023, 1, 21, 13, 0)},
#  {'Latitude': 43.471143749999996,
#   'Longitude': -1.552726590666314,
#   'Weather': 'clear sky',
#   'Temperature': 4.27,
#   'Humidity': 59,
#   'Wind': 2.28,
#   'Date': datetime.datetime(2023, 1, 22, 13, 0)},
#  {'Latitude': 43.471143749999996,
#   'Longitude': -1.552726590666314,
#   'Weather': 'light rain',
#   'Temperature': 6.2,
#   'Humidity': 62,
#   'Wind': 2.7,
#   'Date': datetime.datetime(2023, 1, 23, 13, 0)},
#  {'Latitude': 43.471143749999996,
#   'Longitude': -1.552726590666314,
#   'Weather': 'light rain',
#   'Temperature': 5.6,
#   'Humidity': 73,
#   'Wind': 3.51,
#   'Date': datetime.datetime(2023, 1, 24, 13, 0)},
#  {'Latitude': 43.471143749999996,
#   'Longitude': -1.552726590666314,
#   'Weather': 'light rain',
#   'Temperature': 6.87,
#   'Humidity': 75,
#   'Wind': 3.59,
#   'Date': datetime.datetime(2023, 1, 25, 13, 0)},
#  {'Latitude': 43.4945144,
#   'Longitude': -1.4736657,
#   'Weather': 'moderate rain',
#   'Temperature': 6.74,
#   'Humidity': 90,
#   'Wind': 11.78,
#   'Date': datetime.datetime(2023, 1, 19, 13, 0)},
#  {'Latitude': 43.4945144,
#   'Longitude': -1.4736657,
#   'Weather': 'overcast clouds',
#   'Temperature': 7.26,
#   'Humidity': 68,
#   'Wind': 3.71,
#   'Date': datetime.datetime(2023, 1, 20, 13, 0)},
#  {'Latitude': 43.4945144,
#   'Longitude': -1.4736657,
#   'Weather': 'clear sky',
#   'Temperature': 5.21,
#   'Humidity': 66,
#   'Wind': 2.61,
#   'Date': datetime.datetime(2023, 1, 21, 13, 0)},
#  {'Latitude': 43.4945144,
#   'Longitude': -1.4736657,
#   'Weather': 'clear sky',
#   'Temperature': 4.81,
#   'Humidity': 57,
#   'Wind': 2.26,
#   'Date': datetime.datetime(2023, 1, 22, 13, 0)},
#  {'Latitude': 43.4945144,
#   'Longitude': -1.4736657,
#   'Weather': 'light rain',
#   'Temperature': 6.8,
#   'Humidity': 61,
#   'Wind': 2.71,
#   'Date': datetime.datetime(2023, 1, 23, 13, 0)},
#  {'Latitude': 43.4945144,
#   'Longitude': -1.4736657,
#   'Weather': 'light rain',
#   'Temperature': 5.99,
#   'Humidity': 72,
#   'Wind': 3.31,
#   'Date': datetime.datetime(2023, 1, 24, 13, 0)},
#  {'Latitude': 43.4945144,
#   'Longitude': -1.4736657,
#   'Weather': 'light rain',
#   'Temperature': 7.2,
#   'Humidity': 75,
#   'Wind': 3.19,
#   'Date': datetime.datetime(2023, 1, 25, 13, 0)},
#  {'Latitude': 46.1591126,
#   'Longitude': -1.1520434,
#   'Weather': 'moderate rain',
#   'Temperature': 5.74,
#   'Humidity': 86,
#   'Wind': 7.76,
#   'Date': datetime.datetime(2023, 1, 19, 13, 0)},
#  {'Latitude': 46.1591126,
#   'Longitude': -1.1520434,
#   'Weather': 'broken clouds',
#   'Temperature': 4.96,
#   'Humidity': 70,
#   'Wind': 3.77,
#   'Date': datetime.datetime(2023, 1, 20, 13, 0)},
#  {'Latitude': 46.1591126,
#   'Longitude': -1.1520434,
#   'Weather': 'clear sky',
#   'Temperature': 4.04,
#   'Humidity': 62,
#   'Wind': 3.59,
#   'Date': datetime.datetime(2023, 1, 21, 13, 0)},
#  {'Latitude': 46.1591126,
#   'Longitude': -1.1520434,
#   'Weather': 'scattered clouds',
#   'Temperature': 4.26,
#   'Humidity': 73,
#   'Wind': 3.78,
#   'Date': datetime.datetime(2023, 1, 22, 13, 0)},
#  {'Latitude': 46.1591126,
#   'Longitude': -1.1520434,
#   'Weather': 'light rain',
#   'Temperature': 4.75,
#   'Humidity': 75,
#   'Wind': 3.04,
#   'Date': datetime.datetime(2023, 1, 23, 13, 0)},
#  {'Latitude': 46.1591126,
#   'Longitude': -1.1520434,
#   'Weather': 'light rain',
#   'Temperature': 5,
#   'Humidity': 70,
#   'Wind': 5.29,
#   'Date': datetime.datetime(2023, 1, 24, 13, 0)},
#  {'Latitude': 46.1591126,
#   'Longitude': -1.1520434,
#   'Weather': 'few clouds',
#   'Temperature': 5.07,
#   'Humidity': 74,
#   'Wind': 4.38,
#   'Date': datetime.datetime(2023, 1, 25, 13, 0)}]

# %% [markdown]
# weather_json étant une liste, on le convertit en DF pour un tableau plus esthétique

# %%
weather_week = pd.DataFrame(weather_json)

# On a trouvé le temps sur 7j mais sans le nom des villes

weather_week
# Out:
#       Latitude  Longitude           Weather  Temperature  Humidity  Wind  \
# 0    48.635954  -1.511460        light rain         5.52        79  3.47
# 1    48.635954  -1.511460     broken clouds         5.11        70  1.81
# 2    48.635954  -1.511460         clear sky         4.82        71  2.47
# 3    48.635954  -1.511460   overcast clouds         4.85        75  2.04
# 4    48.635954  -1.511460        light rain         4.38        90  4.10
# ..         ...        ...               ...          ...       ...   ...
# 240  46.159113  -1.152043         clear sky         4.04        62  3.59
# 241  46.159113  -1.152043  scattered clouds         4.26        73  3.78
# 242  46.159113  -1.152043        light rain         4.75        75  3.04
# 243  46.159113  -1.152043        light rain         5.00        70  5.29
# 244  46.159113  -1.152043        few clouds         5.07        74  4.38
#
#                    Date
# 0   2023-01-19 13:00:00
# 1   2023-01-20 13:00:00
# 2   2023-01-21 13:00:00
# 3   2023-01-22 13:00:00
# 4   2023-01-23 13:00:00
# ..                  ...
# 240 2023-01-21 13:00:00
# 241 2023-01-22 13:00:00
# 242 2023-01-23 13:00:00
# 243 2023-01-24 13:00:00
# 244 2023-01-25 13:00:00
#
# [245 rows x 7 columns]

# %% [markdown]
# On fait une jointure est nécessaire pour relier les DF 'lat_lon' et 'weather_week'

# %%
final_result = pd.merge(lat_lon, weather_week, on=["Latitude", "Longitude"])

# %%
dic_weather.keys()
# Out:
# dict_keys(['lat', 'lon', 'timezone', 'timezone_offset', 'current', 'daily'])

# %% [markdown]
# # Tableau final météo des 35 villes (cities_list) sur 7j :

# %%
final_result
# Out:
#                 Cities   Latitude  Longitude           Weather  Temperature  \
# 0    Mont Saint Michel  48.635954  -1.511460        light rain         5.52
# 1    Mont Saint Michel  48.635954  -1.511460     broken clouds         5.11
# 2    Mont Saint Michel  48.635954  -1.511460         clear sky         4.82
# 3    Mont Saint Michel  48.635954  -1.511460   overcast clouds         4.85
# 4    Mont Saint Michel  48.635954  -1.511460        light rain         4.38
# ..                 ...        ...        ...               ...          ...
# 240        La Rochelle  46.159113  -1.152043         clear sky         4.04
# 241        La Rochelle  46.159113  -1.152043  scattered clouds         4.26
# 242        La Rochelle  46.159113  -1.152043        light rain         4.75
# 243        La Rochelle  46.159113  -1.152043        light rain         5.00
# 244        La Rochelle  46.159113  -1.152043        few clouds         5.07
#
#      Humidity  Wind                Date
# 0          79  3.47 2023-01-19 13:00:00
# 1          70  1.81 2023-01-20 13:00:00
# 2          71  2.47 2023-01-21 13:00:00
# 3          75  2.04 2023-01-22 13:00:00
# 4          90  4.10 2023-01-23 13:00:00
# ..        ...   ...                 ...
# 240        62  3.59 2023-01-21 13:00:00
# 241        73  3.78 2023-01-22 13:00:00
# 242        75  3.04 2023-01-23 13:00:00
# 243        70  5.29 2023-01-24 13:00:00
# 244        74  4.38 2023-01-25 13:00:00
#
# [245 rows x 8 columns]

# %% [markdown]
# # Exemple de prévision a Paris :

# %% [markdown]
# On a les prévisions des temperatures pour les 7 prochains jours.

# %%
ville="Paris"

# %%
prevision_paris=final_result[final_result["Cities"]==ville]
prevision_paris
# Out:
#    Cities  Latitude  Longitude           Weather  Temperature  Humidity  Wind  \
# 35  Paris  48.85889   2.320041        light snow         4.17        72  2.43
# 36  Paris  48.85889   2.320041        light snow         3.95        61  2.18
# 37  Paris  48.85889   2.320041         clear sky         4.14        66  2.76
# 38  Paris  48.85889   2.320041         clear sky         2.98        65  3.83
# 39  Paris  48.85889   2.320041  scattered clouds         4.23        67  2.33
# 40  Paris  48.85889   2.320041         clear sky         3.25        57  2.45
# 41  Paris  48.85889   2.320041     broken clouds         3.98        69  1.80
#
#                   Date
# 35 2023-01-19 13:00:00
# 36 2023-01-20 13:00:00
# 37 2023-01-21 13:00:00
# 38 2023-01-22 13:00:00
# 39 2023-01-23 13:00:00
# 40 2023-01-24 13:00:00
# 41 2023-01-25 13:00:00

# %% [markdown]
# On met la date en index

# %%
prevision_paris.set_index("Date",inplace=True)

# %% [markdown]
# ### Visualisation de l'évolution de la température sur une semaine

# %%
import matplotlib.pyplot as plt

# %%
prevision_paris["Temperature"].plot()
plt.title(f"Evolution de la température dans la ville de {ville}")
plt.show()

# %% [markdown]
# ### Visualisation de l'évolution de l'humidité sur une semaine

# %%
prevision_paris["Humidity"].plot()
plt.title(f"Evolution de l'Humidité dans la ville de {ville}")
plt.show()

# %% [markdown]
# ### Visualisation de l'évolution du vent sur une semaine

# %%
prevision_paris["Wind"].plot()
plt.title(f"Evolution de la force de vent dans la ville de {ville}")
plt.show()

# %% [markdown]
# On normalise les variables :

# %%
max_=prevision_paris[["Temperature","Humidity","Wind"]].max()
min_=prevision_paris[["Temperature","Humidity","Wind"]].min()

# %%
prevision_paris_normalized=(prevision_paris[["Temperature","Humidity","Wind"]]-min_)/(max_-min_)
prevision_paris_normalized
# Out:
#                      Temperature  Humidity      Wind
# Date
# 2023-01-19 13:00:00        0.952  1.000000  0.310345
# 2023-01-20 13:00:00        0.776  0.266667  0.187192
# 2023-01-21 13:00:00        0.928  0.600000  0.472906
# 2023-01-22 13:00:00        0.000  0.533333  1.000000
# 2023-01-23 13:00:00        1.000  0.666667  0.261084
# 2023-01-24 13:00:00        0.216  0.000000  0.320197
# 2023-01-25 13:00:00        0.800  0.800000  0.000000

# %%
prevision_paris_normalized.plot()
plt.title(f"Evolution des Températures, Humidité, Wind normalisé dans la ville de {ville}")
plt.show()

# %% [markdown]
# ## Prévision Météo dans la localisation de la personne :

# %% [markdown]
# Localisation de la personne

# %%
print(location.latitude, location.longitude)
# Out:
# 48.840627 2.5077111

# %%
ville=location[0].split(",")[0]
ville
# Out:
# 'Le Perreux-sur-Marne'

# %%
r_weather = requests.get("https://api.openweathermap.org/data/2.5/onecall?lat={}&lon={}&units=metric&exclude=minutely,hourly,alerts&appid={}".format(Lat_, Lon_, api_key))  

dic_weather = r_weather.json()

prevision_json = []

week_prevision=dic_weather["daily"]
week_prevision

for day in week_prevision:
    Météo = day["weather"][0]["description"]
    Température = day["temp"]["day"]
    Humidité = day["humidity"]
    Vent = day["wind_speed"]
    Date = day['dt']
    Timestamp = day['dt']
    Date = datetime.fromtimestamp(int(Timestamp))
    
    dictionnaire = {'Latitude': Lat_,
                    'Longitude': Lon_,
                    'Weather': Météo,
                    'Temperature': Température,
                    'Humidity': Humidité,
                    'Wind': Vent,
                    'Date': Date

                    }
    prevision_json.append(dictionnaire)

# %% [markdown]
# ### On transforme les résultats en dataframe

# %%
location_prevision=pd.DataFrame(prevision_json)
location_prevision['city']=ville
location_prevision
# Out:
#     Latitude  Longitude           Weather  Temperature  Humidity   Wind  \
# 0  46.159113  -1.152043        light rain         3.61        89  10.49
# 1  46.159113  -1.152043     moderate rain         5.74        86   7.76
# 2  46.159113  -1.152043     broken clouds         4.96        70   3.77
# 3  46.159113  -1.152043         clear sky         4.04        62   3.59
# 4  46.159113  -1.152043  scattered clouds         4.26        73   3.78
# 5  46.159113  -1.152043        light rain         4.75        75   3.04
# 6  46.159113  -1.152043        light rain         5.00        70   5.29
# 7  46.159113  -1.152043        few clouds         5.07        74   4.38
#
#                  Date                  city
# 0 2023-01-18 13:00:00  Le Perreux-sur-Marne
# 1 2023-01-19 13:00:00  Le Perreux-sur-Marne
# 2 2023-01-20 13:00:00  Le Perreux-sur-Marne
# 3 2023-01-21 13:00:00  Le Perreux-sur-Marne
# 4 2023-01-22 13:00:00  Le Perreux-sur-Marne
# 5 2023-01-23 13:00:00  Le Perreux-sur-Marne
# 6 2023-01-24 13:00:00  Le Perreux-sur-Marne
# 7 2023-01-25 13:00:00  Le Perreux-sur-Marne

# %%
location_prevision.set_index("Date",inplace=True)

# %%
location_prevision["Wind"].plot()
plt.title(f"Evolution de la force de vent dans la ville de {ville}")
plt.show()
location_prevision["Temperature"].plot()
plt.title(f"Evolution de la température dans la ville de {ville}")
plt.show()
location_prevision["Humidity"].plot()
plt.title(f"Evolution de l'Humidité dans la ville de {ville}")
plt.show()

# %% [markdown]
# En normalisant

# %%
max_=location_prevision[["Temperature","Humidity","Wind"]].max()
min_=location_prevision[["Temperature","Humidity","Wind"]].min()

# %%
location_prevision_normalized=(location_prevision[["Temperature","Humidity","Wind"]]-min_)/(max_-min_)
location_prevision_normalized
# Out:
#                      Temperature  Humidity      Wind
# Date
# 2023-01-18 13:00:00     0.000000  1.000000  1.000000
# 2023-01-19 13:00:00     1.000000  0.888889  0.633557
# 2023-01-20 13:00:00     0.633803  0.296296  0.097987
# 2023-01-21 13:00:00     0.201878  0.000000  0.073826
# 2023-01-22 13:00:00     0.305164  0.407407  0.099329
# 2023-01-23 13:00:00     0.535211  0.481481  0.000000
# 2023-01-24 13:00:00     0.652582  0.296296  0.302013
# 2023-01-25 13:00:00     0.685446  0.444444  0.179866

# %%
location_prevision_normalized.plot()
plt.title(f"Evolution des Températures, Humidité, Wind normalisé dans la ville de {ville}")
plt.show()

# %% [markdown]
# ## Prediciton du meilleur moment pour partir

# %% [markdown]
# Généralement le meilleur moment pour partir en voiture est généralement le moment ou l'humidité et le vent sont le plus faible. L'humidité et le vent ralenti la voiture, la circulation et augmente le danger.
# On déconseille aussi quand il y a de la neige et de la pluie, donc il faut vérifier que dans la météo il ne pleuve pas ou il ne neige pas.

# %%
def find_best_moment_travel(dataframe):
    # Filter out rows where 'Weather' column contains 'rain' or 'snow'
    filtered_df = dataframe[~dataframe['Weather'].str.contains('rain|snow', case=False, na=False)]
    
    # Find the row with minimum values of 'Wind' and 'Humidity' columns
    best_line = filtered_df.loc[(filtered_df['Wind'] == filtered_df['Wind'].min()) & (filtered_df['Humidity'] == filtered_df['Humidity'].min())]
    
    return best_line

# %% [markdown]
# Pour transformer la météo en francais

# %%
from googletrans import Translator
translator = Translator()

# %% [markdown]
# ## Meilleur moment pour partir suivant votre localisation est :

# %%
meilleur_moment=find_best_moment_travel(location_prevision)
print(f"Le meilleur moment pour partir en toute sécurité est le {meilleur_moment.index.strftime('%Y-%m-%d')[0]}")
print(f"La météo sera {translator.translate(meilleur_moment.Weather.values[0],src='en',dest='fr').text}")
print(f"La temperature sera de {meilleur_moment.Temperature.values[0]}")
print(f"L'humidité sera de {meilleur_moment.Humidity.values[0]}")
print(f"Le vent sera de {meilleur_moment.Wind.values[0]}")
# Out:
# Le meilleur moment pour partir en toute sécurité est le 2023-01-21
# La météo sera ciel clair
# La temperature sera de 4.04
# L'humidité sera de 62
# Le vent sera de 3.59

# %% [markdown]
# # Liste des villes avec la meilleur météo les 7 prochains jours

# %% [markdown]
# On va regarder dans le tableau des prévisions météo des 35 villes, les 5 villes les plus chaudes dans les 7 prochains jour.

# %%
parametre='Temperature'

# %%
best_cities_list = final_result.groupby('Cities').agg({parametre: [max,np.mean]})
best_cities_list.columns
# Out:
# MultiIndex([('Temperature',  'max'),
#             ('Temperature', 'mean')],
#            )

# %%
best_cities_list.head()
# Out:
#                 Temperature
#                         max      mean
# Cities
# Aigues Mortes          8.11  7.145714
# Aix en Provence        8.71  5.450000
# Amiens                 4.92  4.087143
# Annecy                 1.59 -0.154286
# Ariege                -1.25 -2.635714

# %% [markdown]
# Liste des 5  villes avec meilleure température les 7 prochains jours, c'est a dire la moyenne de température la plus élevée.

# %%
best_five = best_cities_list.sort_values([("Temperature", "mean")], ascending = False)

best_five = best_five.head()

best_five
# Out:
#                    Temperature
#                            max      mean
# Cities
# Bormes les Mimosas       11.09  8.085714
# Collioure                 9.06  7.797143
# Cassis                   10.00  7.405714
# Aigues Mortes             8.11  7.145714
# Marseille                 9.51  6.840000

# %% [markdown]
# On peut changer les paramètres de recherches, et décider si on veut les meilleurs destinations, avec le moins d'humidité ou de vent.

# %% [markdown]
# On généralise la fonction en lui donnant une liste de colonne a effectuer l'agregation

# %%
def agregate_cities_parameters(dataset,parametre):
    if len(parametre)>0:
        best_cities_list = dataset.groupby('Cities').agg(dict(zip(parametre,len(parametre)*[[max,min,np.mean]])))
    else:
        return "erreur choose at least one parameter"
    return best_cities_list

# %% [markdown]
# Fonction pour trouver les meilleurs villes suivant les paramètres que l'on veut.

# %%
def best_cities_parameters(dataset,parametre,temperature_param="max",humidity_param="min",wind_param="min"):
    
    parametre_meteo_asc={"Temperature":False,"Humidity":True,"Wind":True}
    parametre_meteo={"Temperature":("Temperature", temperature_param),"Humidity":("Humidity", humidity_param),"Wind":("Wind", wind_param)}
    
    Ascending_list=pd.Series(parametre).map(parametre_meteo_asc).to_list()

    best_cities_list=agregate_cities_parameters(dataset,parametre)
    
    if temperature_param=="mean" or humidity_param=="mean" or wind_param=="mean":
        best_cities_list=best_cities_list.sort_values(list(zip(parametre,len(parametre)*["mean"])), ascending = Ascending_list )
    else:        
        best_cities_list=best_cities_list.sort_values(pd.Series(parametre).map(parametre_meteo).to_list(), ascending = Ascending_list )

    best_five = best_cities_list.head()
    
    return best_five

# %% [markdown]
# ### la température moyennes, maximal et minimale, des 35 villes, les  7 prochains jours

# %%
parametre=['Temperature']

# %%
best_cities_list=agregate_cities_parameters(final_result,parametre)

# %%
best_cities_list.head()
# Out:
#                 Temperature
#                         max   min      mean
# Cities
# Aigues Mortes          8.11  5.92  7.145714
# Aix en Provence        8.71  4.53  5.450000
# Amiens                 4.92  2.95  4.087143
# Annecy                 1.59 -1.00 -0.154286
# Ariege                -1.25 -4.11 -2.635714

# %% [markdown]
# ### Liste des 5  villes avec les meilleure maxiamle température les 7 prochains jours

# %%
best_cities_parameters(final_result,parametre)
# Out:
#                    Temperature
#                            max   min      mean
# Cities
# Bormes les Mimosas       11.09  5.64  8.085714
# Cassis                   10.00  6.21  7.405714
# Marseille                 9.51  5.89  6.840000
# Collioure                 9.06  6.81  7.797143
# Aix en Provence           8.71  4.53  5.450000

# %% [markdown]
# ### Liste des 5  villes avec les meilleure moyenne de température les 7 prochains jours

# %%
best_cities_parameters(final_result,parametre,temperature_param="mean")
# Out:
#                    Temperature
#                            max   min      mean
# Cities
# Bormes les Mimosas       11.09  5.64  8.085714
# Collioure                 9.06  6.81  7.797143
# Cassis                   10.00  6.21  7.405714
# Aigues Mortes             8.11  5.92  7.145714
# Marseille                 9.51  5.89  6.840000

# %% [markdown]
# ### Liste des 5  villes avec le moins d'humidité et de vent les 7 prochains jours

# %%
parametre=['Humidity','Wind']

# %%
best_cities_list=agregate_cities_parameters(final_result,parametre)
best_cities_list.head()
# Out:
#                 Humidity                 Wind
#                      max min       mean   max   min      mean
# Cities
# Aigues Mortes         52  41  46.285714  9.86  6.33  8.152857
# Aix en Provence       53  32  40.714286  9.73  1.91  4.665714
# Amiens                78  58  65.571429  5.79  2.59  3.891429
# Annecy                87  80  83.857143  3.28  1.65  2.240000
# Ariege                92  69  77.428571  3.20  2.55  2.745714

# %% [markdown]
# On définit les paramètres météo c'est a dire suivant les paramètres que l'on choisi on met le parametre suivant que l'on optimal. Il va de soit que l'on veut avoir le max de température,le minimun d'humidité, et le minimun de vent. On doit aussi paramétriser l'ordre de tri car on veut un tableau des plus grandes températures au plus petites mais le vent et humidité du min au max. Donc on a pas le meme ascending. On doit mapper sur la liste de parametre pour être varriable

# %%
temperature_param="max"
humidity_param="min"
wind_param="min"
parametre_meteo={"Temperature":("Temperature", temperature_param),"Humidity":("Humidity", humidity_param),"Wind":("Wind", wind_param)}
parametre_meteo_asc={"Temperature":False,"Humidity":True,"Wind":True}

# %% [markdown]
# ### Liste des 5  villes avec les plus faibles humidité, vent, les 7 prochains jours

# %%
best_cities_list.sort_values(pd.Series(parametre).map(parametre_meteo).to_list(), ascending = pd.Series(parametre).map(parametre_meteo_asc).to_list()).head()
# Out:
#                    Humidity                  Wind
#                         max min       mean    max   min      mean
# Cities
# Verdon Gorge             46  18  27.857143   4.46  1.78  2.680000
# Bormes les Mimosas       53  25  37.142857  13.61  3.36  5.260000
# Aix en Provence          53  32  40.714286   9.73  1.91  4.665714
# Cassis                   60  32  46.285714  15.37  3.28  7.585714
# Marseille                60  38  49.142857  14.86  4.60  8.841429

# %% [markdown]
# ### Liste des 5  villes avec les meilleures humidité, vent, moyennant les 7 prochains jours

# %%
best_cities_parameters(final_result,parametre,humidity_param="mean",wind_param="mean")
# Out:
#                    Humidity                  Wind
#                         max min       mean    max   min      mean
# Cities
# Verdon Gorge             46  18  27.857143   4.46  1.78  2.680000
# Bormes les Mimosas       53  25  37.142857  13.61  3.36  5.260000
# Aix en Provence          53  32  40.714286   9.73  1.91  4.665714
# Cassis                   60  32  46.285714  15.37  3.28  7.585714
# Aigues Mortes            52  41  46.285714   9.86  6.33  8.152857

# %% [markdown]
# ### Liste des 5  villes avec les meilleures températures,humidité, vent, les 7 prochains jours

# %%
parametre=['Temperature','Humidity','Wind']

# %%
best_cities_parameters(final_result,parametre,temperature_param="max",humidity_param="min",wind_param="min")
# Out:
#                    Temperature                 Humidity                  Wind  \
#                            max   min      mean      max min       mean    max
# Cities
# Bormes les Mimosas       11.09  5.64  8.085714       53  25  37.142857  13.61
# Cassis                   10.00  6.21  7.405714       60  32  46.285714  15.37
# Marseille                 9.51  5.89  6.840000       60  38  49.142857  14.86
# Collioure                 9.06  6.81  7.797143       61  41  48.571429  15.40
# Aix en Provence           8.71  4.53  5.450000       53  32  40.714286   9.73
#
#
#                      min       mean
# Cities
# Bormes les Mimosas  3.36   5.260000
# Cassis              3.28   7.585714
# Marseille           4.60   8.841429
# Collioure           9.19  13.220000
# Aix en Provence     1.91   4.665714

# %% [markdown]
# ### Liste des 5  villes avec les meilleures températures,humidité, vent, moyennant les 7 prochains jours

# %%
best_cities_parameters(final_result,parametre,temperature_param="mean",humidity_param="mean",wind_param="mean")
# Out:
#                    Temperature                 Humidity                  Wind  \
#                            max   min      mean      max min       mean    max
# Cities
# Bormes les Mimosas       11.09  5.64  8.085714       53  25  37.142857  13.61
# Collioure                 9.06  6.81  7.797143       61  41  48.571429  15.40
# Cassis                   10.00  6.21  7.405714       60  32  46.285714  15.37
# Aigues Mortes             8.11  5.92  7.145714       52  41  46.285714   9.86
# Marseille                 9.51  5.89  6.840000       60  38  49.142857  14.86
#
#
#                      min       mean
# Cities
# Bormes les Mimosas  3.36   5.260000
# Collioure           9.19  13.220000
# Cassis              3.28   7.585714
# Aigues Mortes       6.33   8.152857
# Marseille           4.60   8.841429

# %% [markdown]
# On voit que certaines villes changent en fonction du paramètre que l'on choisit

# %% [markdown]
# ## Prediction de la meilleur date de réservation de vacances

# %% [markdown]
# Ici on essaie de prédire la meilleure date de vaccances dans les 5 villes que l'on a trouvé. On va par rapport au villes que l'on a trouvé regardé la date majoritaire qui a la moyenne la moyenne sur la température la plus élevé et de vent et d'humidité la plus faible

# %% [markdown]
# On paramétrise notre décision avec le parametre, ici on garde les 3 colonnes.

# %%
parametre=['Temperature', 'Humidity', 'Wind']

# %%
list_best_cities=best_cities_parameters(final_result,parametre,temperature_param="mean",humidity_param="mean",wind_param="mean")

# %%
list_best_cities.index
# Out:
# Index(['Bormes les Mimosas', 'Collioure', 'Cassis', 'Aigues Mortes',
#        'Marseille'],
#       dtype='object', name='Cities')

# %%
tab_prevision_best_cities=final_result[final_result["Cities"].apply(lambda x: x in list_best_cities.index)]
tab_prevision_best_cities.head()
# Out:
#                  Cities   Latitude  Longitude           Weather  Temperature  \
# 126  Bormes les Mimosas  43.150697   6.341928         clear sky         6.91
# 127  Bormes les Mimosas  43.150697   6.341928         clear sky         5.64
# 128  Bormes les Mimosas  43.150697   6.341928  scattered clouds         7.68
# 129  Bormes les Mimosas  43.150697   6.341928         clear sky         8.17
# 130  Bormes les Mimosas  43.150697   6.341928     broken clouds         7.20
#
#      Humidity   Wind                Date
# 126        37  13.61 2023-01-19 12:00:00
# 127        40   5.55 2023-01-20 12:00:00
# 128        30   3.41 2023-01-21 12:00:00
# 129        25   3.36 2023-01-22 12:00:00
# 130        33   3.79 2023-01-23 12:00:00

# %%
tab_mean=tab_prevision_best_cities.groupby("Date").mean()[parametre]
tab_mean
# Out:
#                      Temperature  Humidity    Wind
# Date
# 2023-01-19 12:00:00        7.120      50.0  12.484
# 2023-01-20 12:00:00        6.474      51.6  10.978
# 2023-01-21 12:00:00        6.876      37.6   8.578
# 2023-01-22 12:00:00        7.236      37.4   8.278
# 2023-01-23 12:00:00        6.960      43.4   8.104
# 2023-01-24 12:00:00        8.192      45.4   6.344
# 2023-01-25 12:00:00        9.326      53.0   5.518

# %%
tab_mean.sort_values(parametre,ascending=[False,True,True])
# Out:
#                      Temperature  Humidity    Wind
# Date
# 2023-01-25 12:00:00        9.326      53.0   5.518
# 2023-01-24 12:00:00        8.192      45.4   6.344
# 2023-01-22 12:00:00        7.236      37.4   8.278
# 2023-01-19 12:00:00        7.120      50.0  12.484
# 2023-01-23 12:00:00        6.960      43.4   8.104
# 2023-01-21 12:00:00        6.876      37.6   8.578
# 2023-01-20 12:00:00        6.474      51.6  10.978

# %%
tab_mean.sort_values(parametre,ascending=[False,True,True]).head(1)
# Out:
#                      Temperature  Humidity   Wind
# Date
# 2023-01-25 12:00:00        9.326      53.0  5.518

# %%
best_date=tab_mean.sort_values(["Temperature","Humidity","Wind"],ascending=[False,True,True]).head(1).index.strftime('%Y-%m-%d')[0]
print(f"La meilleur date pour réserver dans les 7 prochains jour est {best_date} suivant les paramètres : ", ", ".join(parametre))
# Out:
# La meilleur date pour réserver dans les 7 prochains jour est 2023-01-25 suivant les paramètres :  Temperature, Humidity, Wind

# %% [markdown]
# ## Prediction avec la météo
# Un autre moyen est de compter par jour le nombre de météo identique, et de voir quelle jour clear sky est la météo majoritaire.

# %%
tab_meteo=tab_prevision_best_cities.groupby(["Date","Weather"]).count()
tab_meteo
# Out:
#                                       Cities  Latitude  Longitude  \
# Date                Weather
# 2023-01-19 12:00:00 clear sky              5         5          5
# 2023-01-20 12:00:00 clear sky              4         4          4
#                     scattered clouds       1         1          1
# 2023-01-21 12:00:00 clear sky              4         4          4
#                     scattered clouds       1         1          1
# 2023-01-22 12:00:00 clear sky              5         5          5
# 2023-01-23 12:00:00 broken clouds          2         2          2
#                     clear sky              1         1          1
#                     few clouds             1         1          1
#                     scattered clouds       1         1          1
# 2023-01-24 12:00:00 broken clouds          2         2          2
#                     few clouds             1         1          1
#                     light rain             1         1          1
#                     scattered clouds       1         1          1
# 2023-01-25 12:00:00 broken clouds          1         1          1
#                     overcast clouds        4         4          4
#
#                                       Temperature  Humidity  Wind
# Date                Weather
# 2023-01-19 12:00:00 clear sky                   5         5     5
# 2023-01-20 12:00:00 clear sky                   4         4     4
#                     scattered clouds            1         1     1
# 2023-01-21 12:00:00 clear sky                   4         4     4
#                     scattered clouds            1         1     1
# 2023-01-22 12:00:00 clear sky                   5         5     5
# 2023-01-23 12:00:00 broken clouds               2         2     2
#                     clear sky                   1         1     1
#                     few clouds                  1         1     1
#                     scattered clouds            1         1     1
# 2023-01-24 12:00:00 broken clouds               2         2     2
#                     few clouds                  1         1     1
#                     light rain                  1         1     1
#                     scattered clouds            1         1     1
# 2023-01-25 12:00:00 broken clouds               1         1     1
#                     overcast clouds             4         4     4

# %%
best_meteo_day=tab_meteo.loc[tab_meteo.index.get_level_values("Weather") == "clear sky"].idxmax()[0][0].strftime('%Y-%m-%d')

# %%
print(f"La meilleur date pour réserver dans les 7 prochains jour est {best_meteo_day} suivant la météo")
# Out:
# La meilleur date pour réserver dans les 7 prochains jour est 2023-01-19 suivant la météo

# %% [markdown]
# # Scrapping Booking.com

# %% [markdown]
# On scrappe les hotels des 5 villes avec le paramètre que l'on a choisi pour les 7 prochains jours.

# %% [markdown]
# ### On récupère le nom des villes qui ont les meilleurs paramètres que l'on a choisi précédement
#
# C'est sur ces villes que l'on va scrapper les Hotels sur Booking.com

# %%
best_five_list = list(best_cities_parameters(final_result,parametre,temperature_param="mean",humidity_param="mean",wind_param="mean").index)
best_five_list
# Out:
# ['Bormes les Mimosas', 'Collioure', 'Cassis', 'Aigues Mortes', 'Marseille']

# %% [markdown]
# On va scrapper avec Beautiful Soup en changeant l'adresse url pour scrapper les hotels de la page principal

# %%
booking_list = []

for hotels in range(len(best_five_list)):
    villes = best_five_list[hotels]
    #Id = hotels
    r_booking = requests.get('https://www.booking.com/searchresults.fr.html?ss={}'.format(best_five_list[hotels]), headers = {'User-Agent': 'Mozilla/5.0 (Linux; Android 6.0; Nexus 5 Build/MRA58N) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/108.0.0.0 Mobile Safari/537.36'})
    soup = BeautifulSoup(r_booking.content)
    link=soup.a
    hotel_url = soup.select('a.f348c1e3be')
    hotels_url = [x.get('href') for x in hotel_url]
    hotel_description = [element.get_text().replace('\n','') for element in soup.find_all('div','d8eab2cf7f')]
    hotel_address = [element.get_text().replace('\n','') for element in soup.find_all('span','a51f4b5adb')]
    hotel_score = [element.get_text().replace('\n','') for element in soup.find_all('span','d8eab2cf7f f0d4d6a2f5 e46e88563a')]
    nom_hotel= [element.get_text().replace('\n','') for element in soup.find_all('h2','f9afbb0024 f0d4d6a2f5 fda3b74d0d')]
    
    booking_dict = {
                        'Cities': best_five_list,
                        'Hotels': nom_hotel,
                        'Hotels URL': hotels_url,
                        'Hotel addresses': hotel_address,
                        'Hotels description': hotel_description,
                        'Hotels rating': hotel_score

                        }

    # récupération de tous les résultats
    booking_list.append(booking_dict)

# %%
options = webdriver.ChromeOptions() 
#options.add_argument('-headless') 
options.add_argument('-no-sandbox') 
options.add_argument('-disable-dev-shm-usage') 
options.add_argument("enable-automation") 
options.add_argument("--window-size=1920,1080") 
options.add_argument("--disable-extensions") 
options.add_argument("--dns-prefetch-disable") 
options.add_argument("--disable-gpu")
#driver = webdriver.Chrome('/usr/local/bin/chromedriver', options = options)
driver = webdriver.Chrome('/Users/macbook/.wdm/drivers/chromedriver/mac64/108.0.5359.71/chromedriver', options = options)

web_link ='https://www.booking.com/searchresults.fr.html?ss={}'.format(best_five_list[4])
driver.get(web_link)

# %% [markdown]
# ## Scrapping des hotels sur une seule ville  Exemple de Marseille

# %% [markdown]
# On a fait avec beautiful soup avant mais on perd des informations, car certtaines informations sont irrécupérable en html simple. Ici on scrappe avec sélénium qui nous permet de scrapper plus simplement. Surtout qu'on aura besoin de cela pour rajouter des pré-filtres pour le scrapping des hotels

# %%
list_hotels=[]
hotels_nom=driver.find_elements_by_class_name("dd023375f5")
url_hotels=driver.find_elements_by_class_name("dd023375f5")
addresses=driver.find_elements_by_class_name("a1fbd102d9")
descriptions=driver.find_elements_by_class_name("b1e6dd8416")[::2] 
avis=driver.find_elements_by_class_name("e46e88563a")
notes=driver.find_elements_by_class_name("d10a6220b4")

for elt in zip(hotels_nom,url_hotels,addresses,descriptions,avis,notes):
    nom=elt[0].text.split("\n")[0]
    lien=elt[1].find_elements_by_class_name('e13098a59f')[0].get_attribute("href")
    addresse=elt[2].text.split('Indiquer')[0]
    description=elt[3].find_elements_by_class_name("d8eab2cf7f")[-1].text
    avis=elt[4].text.strip()
    note=elt[5].text
    lepetitplus=re.sub(r"eP","e, P",elt[2].text.split('carte')[-1])
    
    hotel = {'Hotels' : nom, 'Hotels URL' : lien,"Hotel addresses":addresse, "Hotels descriptions": description,"Hotels opinions":avis,'Hotels ratings': note,"lepetitplus":lepetitplus}
    list_hotels.append(hotel)

# %%
df_Hotels=pd.DataFrame(list_hotels)

# %%
df_Hotels
# Out:
#                                                Hotels  \
# 0                 Hôtel Maison Montgrand - Vieux Port
# 1   Maisons du Monde Hôtel & Suites - Marseille Vi...
# 2   LE PANIER ENCHANTÉ - Suites & Loft - Terrasse ...
# 3   Maison 3 chambres gde terrasse proche vieux po...
# 4                                 Marseillement votre
# 5                  Toyoko INN Marseille Saint Charles
# 6   Holiday Inn Express Marseille Saint Charles, a...
# 7                    Ibis Marseille Centre Prefecture
# 8                    Vieux Port République Cannebiére
# 9                                        Hôtel Hermès
# 10                   Citadines Prado Chanot Marseille
# 11                                  Loft Luxe Liberté
# 12                              Residhotel Vieux Port
# 13           Le Dolce Vita T2 CityCenter Wifi-Netflix
# 14                                         Le Phoceen
# 15  LE PRIVILIANE - Bel et grand appartement idéal...
# 16            HORIZON MER - Splendide vue Mer et îles
# 17                            Les Floralies Canebière
# 18  Appart'City Confort Marseille Centre Prado Vel...
# 19                 Aparthotel Adagio Marseille Timone
# 20                  Residhome Marseille Saint-Charles
# 21   Aparthotel Adagio Access Marseille Saint Charles
# 22                     RENTY Côté Parc Parking inclus
# 23  Superb flat with balcony in the centre of Mars...
# 24  Superbe appart 3 p, 10 mn de la plage avec pis...
#
#                                            Hotels URL  \
# 0   https://www.booking.com/hotel/fr/montgrand.fr....
# 1   https://www.booking.com/hotel/fr/maisondumonde...
# 2   https://www.booking.com/hotel/fr/le-panier-enc...
# 3   https://www.booking.com/hotel/fr/maison-de-vil...
# 4   https://www.booking.com/hotel/fr/votre-adresse...
# 5   https://www.booking.com/hotel/fr/toyoko-inn-ma...
# 6   https://www.booking.com/hotel/fr/holiday-inn-e...
# 7   https://www.booking.com/hotel/fr/premiere-clas...
# 8   https://www.booking.com/hotel/fr/vieux-port-47...
# 9   https://www.booking.com/hotel/fr/hermes.fr.htm...
# 10  https://www.booking.com/hotel/fr/citadines-apa...
# 11  https://www.booking.com/hotel/fr/loft-luxe-lib...
# 12  https://www.booking.com/hotel/fr/residhotel-vi...
# 13  https://www.booking.com/hotel/fr/le-dolce-vita...
# 14  https://www.booking.com/hotel/fr/le-phoceen.fr...
# 15  https://www.booking.com/hotel/fr/le-priviliane...
# 16  https://www.booking.com/hotel/fr/horizon-mer-s...
# 17  https://www.booking.com/hotel/fr/les-floralies...
# 18  https://www.booking.com/hotel/fr/seven-urban-s...
# 19  https://www.booking.com/hotel/fr/hipark-reside...
# 20  https://www.booking.com/hotel/fr/residhome-mar...
# 21  https://www.booking.com/hotel/fr/adagio-city-a...
# 22  https://www.booking.com/hotel/fr/renty-cote-pa...
# 23  https://www.booking.com/hotel/fr/superb-flat-w...
# 24  https://www.booking.com/hotel/fr/superbe-appar...
#
#                          Hotel addresses  \
# 0   Vieux Port - La Canebière, Marseille
# 1   Vieux Port - La Canebière, Marseille
# 2   Vieux Port - La Canebière, Marseille
# 3                              Marseille
# 4               Saint-Charles, Marseille
# 5               Saint-Charles, Marseille
# 6               Saint-Charles, Marseille
# 7    Castellane et Préfecture, Marseille
# 8   Vieux Port - La Canebière, Marseille
# 9   Vieux Port - La Canebière, Marseille
# 10             Prado - Périer, Marseille
# 11              Saint-Charles, Marseille
# 12  Vieux Port - La Canebière, Marseille
# 13           Baille-La Timone, Marseille
# 14  Vieux Port - La Canebière, Marseille
# 15  Vieux Port - La Canebière, Marseille
# 16                La Corniche, Marseille
# 17  Vieux Port - La Canebière, Marseille
# 18             Prado - Périer, Marseille
# 19           Baille-La Timone, Marseille
# 20              Saint-Charles, Marseille
# 21              Saint-Charles, Marseille
# 22   Chanot - Stade Vélodrome, Marseille
# 23  Vieux Port - La Canebière, Marseille
# 24          Borely-Bonneveine, Marseille
#
#                                   Hotels descriptions Hotels opinions  \
# 0   Doté d'une terrasse spacieuse, d'un terrain de...       Très bien
# 1   Surplombant le Vieux-Port, l’établissement Mai...       Très bien
# 2   Situé dans le centre de Marseille, à 2,8 km de...            Bien
# 3   Située à Marseille, à seulement 3 km de la sta...            Bien
# 4   Situé à Marseille, à 2,9 km de la plage des Ca...       Très bien
# 5   Situé à Marseille, à seulement 5 minutes à pie...            Bien
# 6   L'Holiday Inn Express Marseille Saint Charles ...            Bien
# 7   L’Ibis Marseille Centre Préfecture met à votre...            Bien
# 8   Situé à Marseille, à 1,9 km de la plage des Ca...         Superbe
# 9   L'hôtel Hermès se situe à seulement 35 mètres ...            Bien
# 10  L'hôtel Citadines Prado Chanot Marseille est s...       Très bien
# 11  Situé à Marseille, à 2,9 km de la plage des Ca...            Bien
# 12  Le Residhotel Vieux Port se situe dans le cent...            Bien
# 13  Doté d'une connexion Wi-Fi gratuite et offrant...            Note
# 14  Situé dans le centre de Marseille, à proximité...       Très bien
# 15  Situé dans le centre de Marseille, à 2,4 km de...       Très bien
# 16  Situé à Marseille, à 400 mètres de la plage de...        Fabuleux
# 17  Situé dans le centre de Marseille, l'établisse...    Exceptionnel
# 18  L'Appart'City Confort Marseille Centre Prado V...            Bien
# 19  L'Aparthotel Adagio Marseille Timone propose d...            Bien
# 20  Le Residhome Marseille Saint-Charles est situé...            Bien
# 21  L'Aparthotel Adagio Access Marseille Saint Cha...            Bien
# 22  Situé dans le quartier Chanot - Stade Vélodrom...         Superbe
# 23  Le Superb flat with balcony in the centre of M...            Bien
# 24  Dans le quartier Borely-Bonneveine de Marseill...        Fabuleux
#
#    Hotels ratings                        lepetitplus
# 0             8,0  0,8 km du centre, Proche du métro
# 1             8,4  0,5 km du centre, Proche du métro
# 2             7,9  0,9 km du centre, Proche du métro
# 3             7,3                     2 km du centre
# 4             8,3   450 m du centre, Proche du métro
# 5             7,8  0,7 km du centre, Proche du métro
# 6             7,8  0,5 km du centre, Proche du métro
# 7             7,0  0,8 km du centre, Proche du métro
# 8             8,7   400 m du centre, Proche du métro
# 9             7,9  0,5 km du centre, Proche du métro
# 10            8,0  2,7 km du centre, Proche du métro
# 11            7,3   450 m du centre, Proche du métro
# 12            7,3   450 m du centre, Proche du métro
# 13            5,2  1,2 km du centre, Proche du métro
# 14            8,1  0,8 km du centre, Proche du métro
# 15            8,4  0,6 km du centre, Proche du métro
# 16            9,4                   2,8 km du centre
# 17            9,5   300 m du centre, Proche du métro
# 18            7,6  2,3 km du centre, Proche du métro
# 19            7,7  2,3 km du centre, Proche du métro
# 20            7,8   450 m du centre, Proche du métro
# 21            7,4  0,8 km du centre, Proche du métro
# 22            8,7                   2,4 km du centre
# 23            7,8  0,6 km du centre, Proche du métro
# 24            9,1                   5,3 km du centre

# %% [markdown]
# ## Scrapping sur toutes les villes choisi

# %% [markdown]
# Avec Sélénium on va scrapper tout les hotels des 5 villes qui nous intéresse et de la premiere page associé a bookin.com, suivant le pré filtre que l'on donne (ici aucun).

# %%
def Scrapp_hotels(best_five_list):
    
    list_hotels=[]
    
    for ville in best_five_list:
        
        options = webdriver.ChromeOptions() 
        
        #options.add_argument('-headless') 
        options.add_argument('-no-sandbox') 
        options.add_argument('-disable-dev-shm-usage') 
        options.add_argument("enable-automation") 
        options.add_argument("--window-size=1920,1080") 
        options.add_argument("--disable-extensions") 
        options.add_argument("--dns-prefetch-disable") 
        options.add_argument("--disable-gpu")
        #driver = webdriver.Chrome('/usr/local/bin/chromedriver', options = options)
        driver = webdriver.Chrome('/Users/macbook/.wdm/drivers/chromedriver/mac64/108.0.5359.71/chromedriver', options = options)
        
        web_link ='https://www.booking.com/searchresults.fr.html?ss={}'.format(ville)
       
        driver.get(web_link)
        
        
        hotels_nom=driver.find_elements_by_class_name("dd023375f5")
        url_hotels=driver.find_elements_by_class_name("dd023375f5")
        addresses=driver.find_elements_by_class_name("a1fbd102d9")
        descriptions=driver.find_elements_by_class_name("b1e6dd8416")[::2] 
        avis=driver.find_elements_by_class_name("e46e88563a")
        notes=driver.find_elements_by_class_name("d10a6220b4")
        
        for elt in zip(hotels_nom,url_hotels,addresses,descriptions,avis,notes):
            nom=elt[0].text.split("\n")[0]
            lien=elt[1].find_elements_by_class_name('e13098a59f')[0].get_attribute("href")
            addresse=elt[2].text.split('Indiquer')[0]
            description=elt[3].find_elements_by_class_name("d8eab2cf7f")[-1].text
            avis=elt[4].text.strip()
            note=elt[5].text
            lepetitplus=re.sub(r"eP","e, P",elt[2].text.split('carte')[-1])
            
            hotel = {'cities':ville,'Hotels' : nom, 'Hotels URL' : lien,"Hotel addresses":addresse, "Hotels descriptions": description,"Hotels opinions":avis,'Hotels ratings': note,"lepetitplus":lepetitplus}
            list_hotels.append(hotel)
            
        
        
        driver.quit()
    
    return pd.DataFrame(list_hotels)

# %%
df_Hotels=Scrapp_hotels(best_five_list)

# %% [markdown]
# # Résultat Scrapping

# %%
df_Hotels
# Out:
#                  cities                                             Hotels  \
# 0    Bormes les Mimosas                                      La Lavandière
# 1    Bormes les Mimosas  maison vacance Médiévale Bormes-les-Mimosas vi...
# 2    Bormes les Mimosas  A deux pas de la plage de la Faviere - Parking...
# 3    Bormes les Mimosas                                Terrasse sur la mer
# 4    Bormes les Mimosas  Appartement Bormes-les-Mimosas, 3 pièces, 5 pe...
# ..                  ...                                                ...
# 108           Marseille                  Residhome Marseille Saint-Charles
# 109           Marseille   Aparthotel Adagio Access Marseille Saint Charles
# 110           Marseille                     RENTY Côté Parc Parking inclus
# 111           Marseille  Superb flat with balcony in the centre of Mars...
# 112           Marseille  Superbe appart 3 p, 10 mn de la plage avec pis...
#
#                                             Hotels URL  \
# 0    https://www.booking.com/hotel/fr/la-lavandiere...
# 1    https://www.booking.com/hotel/fr/maison-vacanc...
# 2    https://www.booking.com/hotel/fr/la-faviere-a-...
# 3    https://www.booking.com/hotel/fr/terrasse-sur-...
# 4    https://www.booking.com/hotel/fr/appartement-b...
# ..                                                 ...
# 108  https://www.booking.com/hotel/fr/residhome-mar...
# 109  https://www.booking.com/hotel/fr/adagio-city-a...
# 110  https://www.booking.com/hotel/fr/renty-cote-pa...
# 111  https://www.booking.com/hotel/fr/superb-flat-w...
# 112  https://www.booking.com/hotel/fr/superbe-appar...
#
#                           Hotel addresses  \
# 0                      Bormes-les-Mimosas
# 1                      Bormes-les-Mimosas
# 2                      Bormes-les-Mimosas
# 3                      Bormes-les-Mimosas
# 4                      Bormes-les-Mimosas
# ..                                    ...
# 108              Saint-Charles, Marseille
# 109              Saint-Charles, Marseille
# 110   Chanot - Stade Vélodrome, Marseille
# 111  Vieux Port - La Canebière, Marseille
# 112          Borely-Bonneveine, Marseille
#
#                                    Hotels descriptions  Hotels opinions  \
# 0    Offrant une vue sur la mer, La Lavandière est ...        Très bien
# 1                                29 expériences vécues        Très bien
# 2    Terrasse sur la mer is a property with a priva...  Exceptionnel 10
# 3    L'hôtel Paradis occupe un bâtiment datant de 1...         Fabuleux
# 4    Le POSEIDON - 2 pièces - 32 m2 - Piscine et ga...          Superbe
# ..                                                 ...              ...
# 108  Le Residhome Marseille Saint-Charles est situé...             Bien
# 109  L'Aparthotel Adagio Access Marseille Saint Cha...             Bien
# 110  Situé dans le quartier Chanot - Stade Vélodrom...          Superbe
# 111  Le Superb flat with balcony in the centre of M...             Bien
# 112  Dans le quartier Borely-Bonneveine de Marseill...         Fabuleux
#
#     Hotels ratings                          lepetitplus
# 0              8,5  1,1 km du centre, Plage à proximité
# 1              8,0    50 m du centre, Plage à proximité
# 2              9,4                     3,2 km du centre
# 3              8,6  3,7 km du centre, Plage à proximité
# 4              6,9  3,3 km du centre, Plage à proximité
# ..             ...                                  ...
# 108            7,8     450 m du centre, Proche du métro
# 109            7,4    0,8 km du centre, Proche du métro
# 110            8,7                     2,4 km du centre
# 111            7,8    0,6 km du centre, Proche du métro
# 112            9,1                     5,3 km du centre
#
# [113 rows x 8 columns]

# %%
# Conversion de notre liste scrappy en DF
booking_soup = pd.DataFrame(booking_list)
booking_soup
# Out:
#                                               Cities  \
# 0  [Bormes les Mimosas, Collioure, Cassis, Aigues...
# 1  [Bormes les Mimosas, Collioure, Cassis, Aigues...
# 2  [Bormes les Mimosas, Collioure, Cassis, Aigues...
# 3  [Bormes les Mimosas, Collioure, Cassis, Aigues...
# 4  [Bormes les Mimosas, Collioure, Cassis, Aigues...
#
#                                               Hotels  \
# 0  [Les embruns, Studio au cœur du port de La Fav...
# 1  [La Frégate, Hôtel Triton, Les Suites de Colli...
# 2  [Appart Bianca T2 - Terrasse - Parking - Calme...
# 3  [Résidence Odalys Le Mas des Flamants, Hôtel S...
# 4  [Hôtel Maison Montgrand - Vieux Port, Maisons ...
#
#                                           Hotels URL  \
# 0  [https://www.booking.com/hotel/fr/les-embruns-...
# 1  [https://www.booking.com/hotel/fr/la-fra-c-gat...
# 2  [https://www.booking.com/hotel/fr/appart-bianc...
# 3  [https://www.booking.com/hotel/fr/residence-le...
# 4  [https://www.booking.com/hotel/fr/montgrand.fr...
#
#                                      Hotel addresses  \
# 0  [Bormes-les-Mimosas • 3,3 km du centre, À 500 ...
# 1  [Collioure • 200 m du centre, À 150 m de la pl...
# 2  [Cassis • 1,5 km du centre, À 900 m de la plag...
# 3  [Aigues-Mortes • 1,1 km du centre, Établisseme...
# 4  [Vieux Port - La Canebière, Marseille • 0,8 km...
#
#                                   Hotels description  \
# 0  [Hébergement géré par un particulier, 9,3, Bor...
# 1  [, 8,2, Collioure • 200 m du centre, À 150 m d...
# 2  [Cassis • 1,5 km du centre, À 900 m de la plag...
# 3  [8,0, Aigues-Mortes • 1,1 km du centre, Établi...
# 4  [, 8,0, Vieux Port - La Canebière, Marseille •...
#
#                                        Hotels rating
# 0  [ Fabuleux ,  Exceptionnel,  Très bien,  Super...
# 1  [ Très bien,  Bien ,  Fabuleux ,  Bien ,  Supe...
# 2  [ Fabuleux ,  Très bien,  Superbe,  Très bien,...
# 3  [ Très bien,  Très bien,  Très bien,  Fabuleux...
# 4  [ Très bien,  Très bien,  Bien ,  Très bien,  ...

# %%
# Explode sur nos colonnes pour briser les listes comprises dans chaque cellule du DF

booking1 = booking_soup['Hotels'].explode('Hotels').reset_index()
#print(booking1)

booking2 = booking_soup['Hotel addresses'].explode('Hotel addresses').reset_index()
#print(booking2)

booking3 = booking_soup['Hotels URL'].explode('Hotels URL').reset_index()
#print(booking3)

booking4 = booking_soup['Hotels description'].explode('Hotels description').reset_index()
#print(booking4)

booking5 = booking_soup['Hotels rating'].explode('Hotels rating').reset_index()
#print(booking5)

# %%
# On merge nos DF grâce à la colonne commune : 'index'

booking_test = booking1.merge(booking2).merge(booking3).merge(booking4)

booking_test
# Out:
#     index                                             Hotels  \
# 0       0                                      La Lavandière
# 1       1                                    HomeStay Bormes
# 2       2                                   Le petit atelier
# 3       3  Charmant Appartement avec Vue panoramique Mer ...
# 4       4                                      Hôtel Paradis
# ..    ...                                                ...
# 95     95                                      Hotel Camille
# 96     96             Appartement calme à deux pas de la mer
# 97     97                              Oh! Campings La Brise
# 98     98                              Auberge de la Fadaise
# 99     99                           L'Estrambord de Camargue
#
#                                       Hotel addresses  \
# 0               Bormes-les-Mimosas • 1,1 km du centre
# 1                                À 1,5 km de la plage
# 2               Bormes-les-Mimosas • 1,2 km du centre
# 3               Bormes-les-Mimosas • 1,1 km du centre
# 4                                À 1,6 km de la plage
# ..                                                ...
# 95        Saint-Charles, Marseille • 0,7 km du centre
# 96         Prado - Périer, Marseille • 2 km du centre
# 97  Vieux Port - La Canebière, Marseille • 1,6 km ...
# 98        Saint-Charles, Marseille • 0,5 km du centre
# 99  Vieux Port - La Canebière, Marseille • 0,5 km ...
#
#                                            Hotels URL  \
# 0   https://www.booking.com/hotel/fr/la-lavandiere...
# 1   https://www.booking.com/hotel/fr/homestay-borm...
# 2   https://www.booking.com/hotel/fr/le-petit-atel...
# 3   https://www.booking.com/hotel/fr/bormes-les-mi...
# 4   https://www.booking.com/hotel/fr/paradis.fr.ht...
# ..                                                ...
# 95  https://www.booking.com/hotel/fr/camille.fr.ht...
# 96  https://www.booking.com/hotel/fr/appartement-c...
# 97  https://www.booking.com/hotel/fr/oh-campings-l...
# 98  https://www.booking.com/hotel/fr/auberge-de-la...
# 99  https://www.booking.com/hotel/fr/l-39-estrambo...
#
#                        Hotels description
# 0
# 1   Bormes-les-Mimosas • 1,1 km du centre
# 2                    À 1,5 km de la plage
# 3                                     9,6
# 4   Bormes-les-Mimosas • 1,2 km du centre
# ..                                    ...
# 95    Hébergement géré par un particulier
# 96                                    7,7
# 97               Cassis • 100 m du centre
# 98                    À 150 m de la plage
# 99    Hébergement géré par un particulier
#
# [100 rows x 5 columns]

# %%
# On attribue les villes aux lignes respectives

booking_test.loc[:20, 'Cities'] = 'Bormes les Mimosas'

booking_test.loc[20:39, 'Cities'] = 'Cassis'

booking_test.loc[40:59, 'Cities'] = 'Marseille'

booking_test.loc[60:79, 'Cities'] = 'Aix en Provence'

booking_test.loc[80:99, 'Cities'] = 'Saintes Maries de la mer'

# %%
# On réorganise l'ordre des colonnes pour un df plus esthétique
booking_test = booking_test.iloc[:, [0,5,1,2,3,4]]

booking_test
# Out:
#     index                                         Hotels URL  \
# 0       0  https://www.booking.com/hotel/fr/la-lavandiere...
# 1       1  https://www.booking.com/hotel/fr/homestay-borm...
# 2       2  https://www.booking.com/hotel/fr/le-petit-atel...
# 3       3  https://www.booking.com/hotel/fr/bormes-les-mi...
# 4       4  https://www.booking.com/hotel/fr/paradis.fr.ht...
# ..    ...                                                ...
# 95     95  https://www.booking.com/hotel/fr/camille.fr.ht...
# 96     96  https://www.booking.com/hotel/fr/appartement-c...
# 97     97  https://www.booking.com/hotel/fr/oh-campings-l...
# 98     98  https://www.booking.com/hotel/fr/auberge-de-la...
# 99     99  https://www.booking.com/hotel/fr/l-39-estrambo...
#
#                        Hotels description                    Cities  \
# 0                                                Bormes les Mimosas
# 1   Bormes-les-Mimosas • 1,1 km du centre        Bormes les Mimosas
# 2                    À 1,5 km de la plage        Bormes les Mimosas
# 3                                     9,6        Bormes les Mimosas
# 4   Bormes-les-Mimosas • 1,2 km du centre        Bormes les Mimosas
# ..                                    ...                       ...
# 95    Hébergement géré par un particulier  Saintes Maries de la mer
# 96                                    7,7  Saintes Maries de la mer
# 97               Cassis • 100 m du centre  Saintes Maries de la mer
# 98                    À 150 m de la plage  Saintes Maries de la mer
# 99    Hébergement géré par un particulier  Saintes Maries de la mer
#
#                                                Hotels  \
# 0                                       La Lavandière
# 1                                     HomeStay Bormes
# 2                                    Le petit atelier
# 3   Charmant Appartement avec Vue panoramique Mer ...
# 4                                       Hôtel Paradis
# ..                                                ...
# 95                                      Hotel Camille
# 96             Appartement calme à deux pas de la mer
# 97                              Oh! Campings La Brise
# 98                              Auberge de la Fadaise
# 99                           L'Estrambord de Camargue
#
#                                       Hotel addresses
# 0               Bormes-les-Mimosas • 1,1 km du centre
# 1                                À 1,5 km de la plage
# 2               Bormes-les-Mimosas • 1,2 km du centre
# 3               Bormes-les-Mimosas • 1,1 km du centre
# 4                                À 1,6 km de la plage
# ..                                                ...
# 95        Saint-Charles, Marseille • 0,7 km du centre
# 96         Prado - Périer, Marseille • 2 km du centre
# 97  Vieux Port - La Canebière, Marseille • 1,6 km ...
# 98        Saint-Charles, Marseille • 0,5 km du centre
# 99  Vieux Port - La Canebière, Marseille • 0,5 km ...
#
# [100 rows x 6 columns]

# %% [markdown]
# ### Affichage des 35 villes Scrapper

# %%
import plotly.express as px
from plotly import graph_objs as go
import plotly.io as pio
pio.renderers.default = "iframe" # to be replaced by "iframe" if working on JULIE

# %%
list_column = ['Cities', 'Weather']

fig = px.scatter_mapbox(final_result, 
                        lat="Latitude", 
                        lon="Longitude", 
                        color="Temperature", 
                        size="Latitude", 
                        zoom=3.5, 
                        mapbox_style = "carto-positron",
                        hover_data=list_column,
                    )
fig.show()
# Out:
# <iframe
#     scrolling="no"
#     width="100%"
#     height="545px"
#     src="iframe_figures/figure_29.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %% [markdown]
# ## Les 5 Villes que l'on choisi pour scrapper les hotels

# %% [markdown]
# On ne peut pas scrapper la localisation de l'hotel sur la page principale, on va devoir a chaque fois prendre le lien de l'hotel et scrapper sa géolocalisation sur la carte

# %%
url_list = booking3['Hotels URL'].tolist()

modified_url_list = []
for url in url_list:
    index = url.index('?')
    modified_url = url[:index]
    modified_url_list.append(modified_url)
    
url_list = modified_url_list

url_list
# Out:
# ['https://www.booking.com/hotel/fr/la-lavandiere-bormes-les-mimosas.fr.html',
#  'https://www.booking.com/hotel/fr/homestay-bormes-bormes-les-mimosas.fr.html',
#  'https://www.booking.com/hotel/fr/le-petit-atelier-bormes-les-mimosas1234567891011121314151617.fr.html',
#  'https://www.booking.com/hotel/fr/bormes-les-mimosas-appartement-vue-mer-4-pers.fr.html',
#  'https://www.booking.com/hotel/fr/paradis.fr.html',
#  'https://www.booking.com/hotel/fr/studio-spacieux-proche-plage-wi-fi-climatisation.fr.html',
#  'https://www.booking.com/hotel/fr/hostellerie-du-cigalou.fr.html',
#  'https://www.booking.com/hotel/fr/hotel-la-voile-fr.fr.html',
#  'https://www.booking.com/hotel/fr/coeur-de-village-bormes-les-mimosas.fr.html',
#  'https://www.booking.com/hotel/fr/appart-isa-amp-marc-t2-avec-rez-de-jardin-bus-aeroport-tout-equipe-pour-4-person.fr.html',
#  'https://www.booking.com/hotel/fr/les-terrasses-bormes-les-mimosas.fr.html',
#  'https://www.booking.com/hotel/fr/eden-rose-grand-bw-premier-collection.fr.html',
#  'https://www.booking.com/hotel/fr/le-domaine-du-mirage.fr.html',
#  'https://www.booking.com/hotel/fr/magnifique-maison-de-village-clim-vue-mer-8-pers.fr.html',
#  'https://www.booking.com/hotel/fr/new-life.fr.html',
#  'https://www.booking.com/hotel/fr/le-hameau-de-la-nicolinia-re.fr.html',
#  'https://www.booking.com/hotel/fr/apartement-la-faviere-bormes-les-mimosas.fr.html',
#  'https://www.booking.com/hotel/fr/217-rue-des-iris.fr.html',
#  'https://www.booking.com/hotel/fr/maison-bormes-les-mimosas-3-pieces-4-personnes-fr-1-308-141.fr.html',
#  'https://www.booking.com/hotel/fr/assklan.fr.html',
#  'https://www.booking.com/hotel/fr/le-reve-bleu-cassis.fr.html',
#  'https://www.booking.com/hotel/fr/le-cleli.fr.html',
#  'https://www.booking.com/hotel/fr/villa-l-39-icone.fr.html',
#  'https://www.booking.com/hotel/fr/appartement-du-pecheur-a-cassis-a-10-metres-du-port.fr.html',
#  'https://www.booking.com/hotel/fr/la-douceur-de-cassis.fr.html',
#  'https://www.booking.com/hotel/fr/la-perle-de-cassis-47-grande-terrasse-vue-mer-centre-ville-spacieux-sur-le-port.fr.html',
#  'https://www.booking.com/hotel/fr/le-duplex-cassis.fr.html',
#  'https://www.booking.com/hotel/fr/echo-des-flots.fr.html',
#  'https://www.booking.com/hotel/fr/le-camelia-cassis.fr.html',
#  'https://www.booking.com/hotel/fr/le-chemin-de-belle-fille.fr.html',
#  'https://www.booking.com/hotel/fr/clos-du-petit-ja-c-sus.fr.html',
#  'https://www.booking.com/hotel/fr/cassis-jardin-prive-ds-le-centre-parking-plage-a-500m.fr.html',
#  'https://www.booking.com/hotel/fr/sea-and-sun-cassis.fr.html',
#  'https://www.booking.com/hotel/fr/une-terrasse-sur-la-mer-cassis.fr.html',
#  'https://www.booking.com/hotel/fr/du-grand-jardin.fr.html',
#  'https://www.booking.com/hotel/fr/cassis-4pers-vue-mer-wifi-tennis-parking-piscine.fr.html',
#  'https://www.booking.com/hotel/fr/chez-mamouska.fr.html',
#  'https://www.booking.com/hotel/fr/la-rade-centre-ville-balcon-clim-neuf.fr.html',
#  'https://www.booking.com/hotel/fr/cassisdream.fr.html',
#  'https://www.booking.com/hotel/fr/sea-home.fr.html',
#  'https://www.booking.com/hotel/fr/montgrand.fr.html',
#  'https://www.booking.com/hotel/fr/maisondumondehotelandsuitesmarseille.fr.html',
#  'https://www.booking.com/hotel/fr/le-panier-enchante-suites-amp-spa.fr.html',
#  'https://www.booking.com/hotel/fr/toyoko-inn-marseille-saint-charles.fr.html',
#  'https://www.booking.com/hotel/fr/appt-t3-tout-neuf-metro-perier-calme-parking.fr.html',
#  'https://www.booking.com/hotel/fr/charmant-appartement-4-pers-2-ch-centre-proche-mer.fr.html',
#  'https://www.booking.com/hotel/fr/holiday-inn-express-marseille-saint-charles.fr.html',
#  'https://www.booking.com/hotel/fr/hermes.fr.html',
#  'https://www.booking.com/hotel/fr/premiere-classe-marseille-centre-xml.fr.html',
#  'https://www.booking.com/hotel/fr/montempo-marseille-centre.fr.html',
#  'https://www.booking.com/hotel/fr/residhome-marseille-saint-charles.fr.html',
#  'https://www.booking.com/hotel/fr/seven-urban-suites.fr.html',
#  'https://www.booking.com/hotel/fr/vieux-port-47-les-augustins.fr.html',
#  'https://www.booking.com/hotel/fr/residhotel-vieux-port.fr.html',
#  'https://www.booking.com/hotel/fr/les-jardins-du-ga-c-na-c-ral.fr.html',
#  'https://www.booking.com/hotel/fr/pullman-palm-beach-marseille.fr.html',
#  'https://www.booking.com/hotel/fr/citadines-aparthotel-marseilleprado.fr.html',
#  'https://www.booking.com/hotel/fr/staycity-aparthotels-centre-vieux-port.fr.html',
#  'https://www.booking.com/hotel/fr/vertigo-vieux-port-marseille.fr.html',
#  'https://www.booking.com/hotel/fr/citadines-aparthotel-marseillepradochanot.fr.html',
#  'https://www.booking.com/hotel/fr/appartements-lucas-de-montigny.fr.html',
#  'https://www.booking.com/hotel/fr/appartement-le-paradiso-le-charme-et-le-calme-en-plein-centre-ville.fr.html',
#  'https://www.booking.com/hotel/fr/une-oasis-au-pays-de-cezanne.fr.html',
#  'https://www.booking.com/hotel/fr/le-mas-des-pignes.fr.html',
#  'https://www.booking.com/hotel/fr/ersextius-ib-aix-en-provence.fr.html',
#  'https://www.booking.com/hotel/fr/luxueux-studio-aix-historique-pavillon-vendome.fr.html',
#  'https://www.booking.com/hotel/fr/t2-aix-en-provence-aix-en-provence1.fr.html',
#  'https://www.booking.com/hotel/fr/studio-centre-historique.fr.html',
#  'https://www.booking.com/hotel/fr/granet-studio.fr.html',
#  'https://www.booking.com/hotel/fr/ma-place-au-sud-aix-centre.fr.html',
#  'https://www.booking.com/hotel/fr/appartement-coeur-historique-aix.fr.html',
#  'https://www.booking.com/hotel/fr/le-bedarride.fr.html',
#  'https://www.booking.com/hotel/fr/appartement-luxe-terrasse-climatisation-centre-d-aix.fr.html',
#  'https://www.booking.com/hotel/fr/aix-en-provence-charmant-studio-proche-toutes-comodites-et-axes-routiers-linges.fr.html',
#  'https://www.booking.com/hotel/fr/renaissance-aix-en-provence.fr.html',
#  'https://www.booking.com/hotel/fr/a-balcony-in-the-heart-of-aix-en-provence.fr.html',
#  'https://www.booking.com/hotel/fr/charming-apartment-with-balcony-and-garage-near-the-city-center-of-aix.fr.html',
#  'https://www.booking.com/hotel/fr/appartement-aix-centre-historique-sauna-jacuzzi-balneo-privatif.fr.html',
#  'https://www.booking.com/hotel/fr/zola-studio.fr.html',
#  'https://www.booking.com/hotel/fr/royal-mirabeau.fr.html',
#  'https://www.booking.com/hotel/fr/le-castelet-les-saintes-maries-de-la-mer.fr.html',
#  'https://www.booking.com/hotel/fr/casa-marina-saintes-maries-de-la-mer.fr.html',
#  'https://www.booking.com/hotel/fr/thalacap-camargue.fr.html',
#  'https://www.booking.com/hotel/fr/le-dauphin-bleu.fr.html',
#  'https://www.booking.com/hotel/fr/oh-campings.fr.html',
#  'https://www.booking.com/hotel/fr/mas-de-pioch.fr.html',
#  'https://www.booking.com/hotel/fr/les-palmiers-en-camargue.fr.html',
#  'https://www.booking.com/hotel/fr/les-rizieres.fr.html',
#  'https://www.booking.com/hotel/fr/ra-c-sidence-palma.fr.html',
#  'https://www.booking.com/hotel/fr/abrivado.fr.html',
#  'https://www.booking.com/hotel/fr/auberge-cavaliere-saintes-maries-de-la-mer.fr.html',
#  'https://www.booking.com/hotel/fr/ha-tel-les-arcades.fr.html',
#  'https://www.booking.com/hotel/fr/mangio-fango.fr.html',
#  'https://www.booking.com/hotel/fr/le-neptune-en-camargue.fr.html',
#  'https://www.booking.com/hotel/fr/l-39-appartement-de-l-39-eglise.fr.html',
#  'https://www.booking.com/hotel/fr/camille.fr.html',
#  'https://www.booking.com/hotel/fr/appartement-calme-a-deux-pas-de-la-mer.fr.html',
#  'https://www.booking.com/hotel/fr/oh-campings-la-brise.fr.html',
#  'https://www.booking.com/hotel/fr/auberge-de-la-fadaise.fr.html',
#  'https://www.booking.com/hotel/fr/l-39-estrambord-de-camargue.fr.html']

# %%
r_adresses = requests.get('{}'.format(url_list[0]), headers = {'User-Agent': 'Mozilla/5.0 (Linux; Android 6.0; Nexus 5 Build/MRA58N) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/108.0.0.0 Mobile Safari/537.36'})
soup = BeautifulSoup(r_adresses.content, "html.parser")

# %%
link = soup.find_all('p',{"class":"address address_clean"})

# %%
link = soup.find('p', class_='address address_clean').find(id='hotel_address')
# Out:
#   Input In [108]
#     link = soup.find('p', class='address address_clean').find(id='hotel_address')
#                           ^
# SyntaxError: invalid syntax

# %%
print(link)
# Out:
# None

# %%
from lxml import etree

# %%
dom = etree.HTML(str(soup))
dom
# Out:
# <Element html at 0x7f973d951fc0>

# %%
dom = etree.HTML(str(soup))
print(dom.xpath('//*[@id="hotel_address"]'))
# Out:
# []

# %%
latlng = link['data-atlas-latlng']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [55], in <cell line: 1>()
# ----> 1 latlng = link['data-atlas-latlng']
#
# TypeError: 'NoneType' object is not subscriptable

# %%
soup.select('#show_map')
# Out:
# <!DOCTYPE html>
# <!--
# You know you could be getting paid to poke around in our code?
# We're hiring designers and developers to work in Amsterdam:
# https://careers.booking.com/
# --><!-- mdot-548 --><html class="no-js" lang="fr">
# <head>
# <link crossorigin="" href="https://cf.bstatic.com" rel="dns-prefetch"/>
# <link crossorigin="" href="https://cf.bstatic.com" rel="dns-prefetch"/>
# <script nonce="jsicrug1FljeF7D" type="text/javascript">
# document.addEventListener('DOMContentLoaded', function () {
# /**
# * provides the current user's cookie consent
# * in order to use it:
# * 1. inline privacy/cookieConsent.js in the page you need to use it.
# * please note that this library relies on window.PCM.isCountryNeedCookieBanner to be initialised
# * before using (calling getValue function) it
# * 2. in your js file:
# *
# * var privacyCookieConsent = B.require('privacyCookieConsent');
# * var consent = privacyCookieConsent.getValue();
# */
# B.define('privacyCookieConsent', function () {
# var consentGroupIsAllowed = {
# analytical: 'C0002%3A1',
# marketing: 'C0004%3A1'
# };
# var optanonConsentCookieName = 'OptanonConsent';
# var optanonBoxClosedCookieName = 'OptanonAlertBoxClosed';
# var halfOfYearMillis = 180 * 24 * 60 * 60 * 1000;
# function isDefined(value) {
# return value && value !== "undefined";
# }
# function parseConsentToObject(consent) {
# var result = {};
# if (typeof consent === 'string') {
# var parts = consent.split('&');
# parts.forEach(function (part) {
# var keyAndValue = part.split('=');
# result[keyAndValue[0]] = keyAndValue[1];
# });
# }
# return result;
# }
# function isConsentValid(consent, alertBoxClosed) {
# return isDefined(consent) &&
# isDefined(alertBoxClosed) &&
# new Date() - new Date(alertBoxClosed) <= halfOfYearMillis;
# }
# function getCookie(name) {
# name += "=";
# var cookies = document.cookie.split(";");
# for (var i = 0; i < cookies.length; i += 1) {
# var cookie = cookies[i];
# while (cookie.charAt(0) === " ") {
# cookie = cookie.substring(1, cookie.length);
# }
# if (cookie.indexOf(name) === 0) {
# return cookie.substring(name.length, cookie.length);
# }
# }
# return null;
# }
# function doesGeolocationRequireBanner() {
# // In case window.PCM is not defined, fallback to opt-out
# return window.PCM ? window.PCM.isCountryNeedCookieBanner : true;
# }
# function getExplicitConsent() {
# var consent = getCookie(optanonConsentCookieName);
# var alertBoxClosed = getCookie(optanonBoxClosedCookieName);
# if (isConsentValid(consent, alertBoxClosed)) {
# var consentObject = parseConsentToObject(consent);
# return Object
# .keys(consentGroupIsAllowed)
# .map(function (purpose) {
# var result = {};
# result[purpose] = consentObject.groups.indexOf(consentGroupIsAllowed[purpose]) > -1;
# return result;
# })
# .reduce(
# function (result, currentValue) {
# return Object.assign(result, currentValue);
# }, {
# functional: true
# }
# );
# }
# }
# function getImplicitConsent() {
# var consentValue = !doesGeolocationRequireBanner();
# return {
# functional: true,
# analytical: consentValue,
# marketing: consentValue
# };
# }
# function getValue() {
# var consent = getExplicitConsent();
# if (!consent) {
# consent = getImplicitConsent();
# }
# return consent;
# }
# return {
# getValue: getValue
# };
# });
# //c360 javascript tracker first iteration
# //sends a track request to c360 http tracker
# //in order to use it:
# //1. inline the c360Tracker.js in the page you need to use it
# //2. in your js file:
# //
# // var c360Tracker = B.require('c360Tracker');
# // var event = {
# // action_name:"accommodation_checkout_confirmation_viewed",
# // action_version :"0.2.0",
# // content : { "transaction_id" : 123434},
# // user : { "BKNG_user_id": 123434}
# // };
# // c360Tracker.track(event);
# B.define('c360Tracker', function () {
# var enrichedContext = {};
# var configuration = {
# validateInput: false
# };
# var track = function (event) {
# if (event == null) {
# return "event object is null or empty";
# } else {
# //if (enrichedContext.userID != null) {
# // event.user = {BKNG_user_id: enrichedContext.userID};
# //}
# var validationResult = new ValidationResult(true);
# if (configuration.validateInput) {
# validationResult = validateInput(event);
# }
# if (!validationResult.success) {
# return validationResult.message;
# }
# send(event);
# }
# };
# function send(data) {
# data.context = enrichedContext;
# data.tracker = {
# tracker_name: "C360JSTracker",
# tracker_type: "Client",
# tracker_version: "0.1.0"
# };
# return $.ajax({
# url: '/c360/v1/track',
# type: 'POST',
# data: JSON.stringify(data),
# });
# }
# enrich();
# var scheme =
# {
# "type": "object",
# "properties": {
# "action_name": {
# "type": "string",
# "description": "action name (ex. element viewed)",
# },
# "action_version": {
# "type": "string",
# "description": "action version"
# },
# "content": {
# "type": "object",
# "description": "content defined by the registered producer scheme"
# }
# }
# };
# function ValidationResult(success, message) {
# this.success = success;
# this.message = message;
# }
# function validateInput(event) {
# var result = validateObject(event, scheme);
# return result;
# }
# function validateObject(obj, scheme) {
# if (scheme.properties != null) {
# var propsArray = Object.getOwnPropertyNames(scheme.properties);
# for (var i = 0; i < propsArray.length; i++) {
# var propertyName = propsArray[i];
# if (obj[propertyName] == null) {
# return new ValidationResult(false, "property " + propertyName + " is not defined");
# }
# if (scheme.properties[propertyName].type == "object") {
# var validationResult = validateObject(obj[propertyName], scheme.properties[propertyName]);
# if (validationResult.success === false) {
# return validationResult;
# }
# }
# }
# }
# return new ValidationResult(true);
# }
# function enrich() {
# enrichedContext = {
# page: {
# page_referrer: document.referrer,
# page_url: window.location.href,
# page_title: document.title
# },
# local: {
# currency: B.env.b_selected_currency
# },
# };
# //if (B.env.b_user_genius_status != null && B.env.b_user_genius_status.b_user_id != null)
# // enrichedContext.userID = B.env.b_user_genius_status.b_user_id;
# }
# return {
# track: track
# };
# });
# })
# </script>
# <script nonce="jsicrug1FljeF7D" src="https://cdn.cookielaw.org/consent/3ea94870-d4b1-483a-b1d2-faf1d982bb31/OtAutoBlock.js" type="text/javascript"></script>
# <script nonce="jsicrug1FljeF7D" type="text/javascript">
# (function () {
# document.addEventListener('cookie_banner_closed', function(e) {
# if (window.PCM && window.B && window.B.et) {
# window.B.et.goal((window.PCM.Marketing || window.PCM.Analytical) ? 'cookie_consent_accepted_policy_banner' : 'cookie_consent_declined_policy_banner');
# }
# });
# document.addEventListener('click', function(e) {
# if (e.target && e.target.classList.contains('ot-preference-center-footer')) {
# e.preventDefault();
# Optanon && Optanon.ToggleInfoDisplay();
# }
# });
# })();
# </script>
# <script nonce="jsicrug1FljeF7D" type="text/javascript">
# window.PCM = {
# isCountryNeedCookieBanner: 1,
# loadStartedAt: 1673304642
# }
# </script>
# <script data-domain-script="3ea94870-d4b1-483a-b1d2-faf1d982bb31" nonce="jsicrug1FljeF7D" src="https://cf.bstatic.com/libs/privacy-consent/releases/2.1.36/customer/cookie-banner.min.js" type="text/javascript"></script>
# <link crossorigin="" href="https://shelves.booking.com/" rel="preconnect"/>
# <meta charset="utf-8"/>
# <script nonce="jsicrug1FljeF7D">
# document.documentElement.className = document.documentElement.className.replace(/\bno-js\b/, 'has-js js-is-loading');
# </script>
# <meta content="origin-when-cross-origin" name="referrer"/>
# <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <style id="top_bar_inline_style"> html {  background: url("...") 0 0 repeat-x;  } </style><script nonce="jsicrug1FljeF7D">(function(d) { var b = d.createElement('body'); d.documentElement.appendChild(b); window.__temporary_body = b; }(document));</script>
# <script nonce="jsicrug1FljeF7D"> function b_cors_check(supported) { var value = supported ? 1 : 0; if (!/(^|;)\s*cors_js=/.test(document.cookie)) { var d = new Date(); d.setTime(d.getTime() + 60 * 60 * 24 * 365 * 1000); var cookieDomain = '.booking.com' || '.booking.com'; document.cookie = 'cors_js=' + value +'; domain=' + cookieDomain + '; path=/; expires=' + d.toGMTString(); } if (!value) { location.reload(); } } </script>
# <script nonce="jsicrug1FljeF7D">(function(d) { d.addEventListener('error', function(e) { if (e.target && e.target.classList.contains('crossorigin-check-js')) { b_cors_check(false); } }, true); })(document); </script>
# <script async="" class="crossorigin-check-js" crossorigin="" nonce="jsicrug1FljeF7D" src="https://cf.bstatic.com/static/js/crossorigin_check_cloudfront_sd/2454015045ef79168d452ff4e7f30bdadff0aa81.js"></script>
# <script nonce="jsicrug1FljeF7D">
# ;(function() {
# window.b_early_errors = window.b_early_errors || [];
# window.onerror = function() {
# window.b_early_errors.push(arguments);
# };
# }());
#  </script>
# <script nonce="jsicrug1FljeF7D">(function(d) { d.addEventListener('load', function(e) { if (e.target && e.target.classList.contains('stylesheet-preload')) { e.target.rel='stylesheet'; } }, true); })(document); </script>
# <style nonce="jsicrug1FljeF7D">template,.g-hidden{display:none !important}p.error{line-height:18px;color:#A30000;font-weight:bold;margin:10px}html.no-js .no-js-hidden{display:none}body.rtlcss{direction:rtl}.no-js .js-loading-hidden,.js-is-loading .js-loading-hidden,.css-is-loading .css-loading-hidden{display:none !important}.no-js .js-loading-invisible,.js-is-loading .js-loading-invisible,.css-is-loading .css-loading-invisible{visibility:hidden !important}.css-loading-inline-visible{display:none !important}.css-is-loading .css-loading-inline-visible{display:inline-block !important}.searchbox_redesign select[disabled]{color:#BDBDBD}body,div,dl,dt,dd,ul,ol,li,h1,h2,h3,h4,h5,h6,pre,form,fieldset,input,textarea,p,blockquote,th,td{margin:0;padding:0}fieldset,img{border:0}address,caption,cite,code,dfn,em,strong,th,var{font-style:normal;font-weight:normal}q:before,q:after{content:''}abbr,acronym{border:0}body,input,select,button,textarea{font-family:BlinkMacSystemFont,-apple-system,Segoe UI,Roboto,Helvetica,Arial,sans-serif}.rtl,.rtlcss{direction:rtl}.ltr{direction:ltr}.rtlcss .bui-carousel__next,.rtlcss .bui-carousel__prev{transform:scaleX(-1)}body>img,body>iframe[src*="doubleclick.net"]{display:block;margin-top:-1px}a{color:var(--bui_color_action_foreground)}a:link{text-decoration:underline}ol,ul{list-style:none}body{background:var(--bui_color_white);color:#333333;-webkit-text-size-adjust:100%}table{border-collapse:collapse;border-spacing:0}th{text-align:left}.rtlcss th{text-align:right}h1,h2,h3,h4,h5,h6{font-weight:normal}h1{font-weight:bold;margin:10px}h2{font-weight:bold;display:block;margin:0;padding-left:10px;padding-top:2px}.header_profile_btn{font-size:22px;font-weight:normal;padding-left:10px;padding-right:10px;width:auto}.header_profile_btn__genius{font-size:13px}.header_profile_btn .bicon{color:var(--bui_color_white)}.header_profile_btn__genius--svg{padding:0 3px}.genius-profile-icon--svg{margin-top:5px}.searchbox_dest.input_clear_button_input::-webkit-search-cancel-button,.input_destination.input_clear_button_input::-webkit-search-cancel-button{display:none}.input_clear_button{-webkit-tap-highlight-color:rgba(0,0,0,0);background:transparent;border:0;color:#999999;height:100%;font-size:12px;padding:0;opacity:0;outline:none;position:absolute;top:0;transition:opacity .25s;width:38px;z-index:5}.ltr .input_clear_button{padding-left:7px;right:0}.rtl .input_clear_button{padding-right:7px;left:0}.rtlcss .input_clear_button{padding-right:7px;left:0}.searchbox_redesign--destination-focused .input_clear_button,.has-dest-value .input_clear_button,.gps-possible .input_clear_button{opacity:1}.input_clear_button:active{color:var(--bui_color_black);background-color:transparent}.cookie-warning{font-size:13px;display:flex;overflow:hidden;max-height:500px;transition:opacity .3s,max-height 0s .3s;color:var(--bui_color_white);background:#212121;box-shadow:inset 0 -1px var(--bui_color_black);flex-flow:row-reverse nowrap;align-items:center}.cookie-warning__flag{position:absolute;opacity:0}.cookie-warning__flag:checked + .cookie-warning{max-height:0;opacity:0}.cookie-warning__text{overflow:hidden;flex:1 1 auto}.cookie-warning__text,.cookie-warning__close{margin:10px}.cookie-warning__close{padding:4px 6px;border-radius:5px;background:#0071C2;flex:0 0 auto}.cookie-warning__close:active{background:#BAD4F7}.cookie-warning.site-header--sticky{margin-top:40px}.cookie-warning-v2{z-index:1003;position:fixed;bottom:0;left:0;width:100%;background-color:var(--bui_color_white);border-top:1px solid #E6E6E6;text-align:left;color:#333333}.cookie-warning-v2__banner{padding:4px 10px 0 10px;@apply --bui_font_body_2}.cookie-warning-v2__banner-title{margin-bottom:8px}.cookie-warning-v2__more-details,.cookie-warning-v2__settings{z-index:400;overflow-x:auto}.cookie-warning-v2__footer{margin-top:16px}.cookie-warning-v2__footer--text-center{text-align:center}.cookie-warning-v2__header{margin-top:16px}.cookie-warning-v2__header-paragraph{margin:14px 0}.cookie-warning-v ...
# <link href="https://cf.bstatic.com/mobile/css/core_cloudfront_sd.iq_ltr/3bb21c0e928d519db4d47c8cfd94e312a3ab3967.css" rel="stylesheet"/>
# <link href="https://cf.bstatic.com/mobile/css/app_cloudfront_sd.iq_ltr/e16be98e129831fa6c30dbd237d88e38571b5ec1.css" rel="stylesheet"/>
# <link href="https://cf.bstatic.com/mobile/css/hotel_cloudfront_sd.iq_ltr/75ef1bd9193a6bbd6a7c51a81739887cd181cf62.css" rel="stylesheet"/>
# <link href="https://cf.bstatic.com/mobile/css/iq_m_type_overrides_cloudfront_sd.iq_ltr/f02caf6b2406afbf6d7eb2fa20a77b92f18d062f.css" rel="stylesheet"/>
# <link as="script" crossorigin="" href="https://cf.bstatic.com/mobile/js/core-deps-inlinedet_cloudfront_sd/97754f5bf295ed27240e6fb859eb624545b055b1.js" nonce="jsicrug1FljeF7D" rel="preload"/>
# <link as="script" crossorigin="" href="https://cf.bstatic.com/mobile/js/core_cloudfront_sd/d3f18df59f626fe9824a288059ff18e54ff0e45f.js" nonce="jsicrug1FljeF7D" rel="preload"/>
# <link as="script" crossorigin="" href="https://cf.bstatic.com/mobile/js/app_cloudfront_sd/bb33649b75c2b045c42414344e1ad03c5ff509ca.js" nonce="jsicrug1FljeF7D" rel="preload"/>
# <link as="script" crossorigin="" href="https://cf.bstatic.com/mobile/js/hotel_cloudfront_sd/97f17ca1b98d3c589759912079788ee1175dbfda.js" nonce="jsicrug1FljeF7D" rel="preload"/>
# <link as="script" crossorigin="" href="https://cf.bstatic.com/static/js/error_catcher_bec_cloudfront_sd/0acd2ada6c74d5dec978a04ea837952bdf050cd2.js" nonce="jsicrug1FljeF7D" rel="preload"/>
# <script nonce="jsicrug1FljeF7D"> if( window.performance && performance.measure && 'b-stylesheets') { performance.measure('b-stylesheets'); } </script><link href="https://www.booking.com/hotel/fr/homestay-bormes-bormes-les-mimosas.en-gb.html" hreflang="en-gb" rel="alternate" title="English (UK)" type="text/html"/>
# <link href="https://www.booking.com/hotel/fr/homestay-bormes-bormes-les-mimosas.html" hreflang="en-us" rel="alternate" title="English (US)" type="text/html"/>
# <link href="https://www.booking.com/hotel/fr/homestay-bormes-bormes-les-mimosas.de.html" hreflang="de" rel="alternate" title="Deutsch" type="text/html"/>
# <link href="https://www.booking.com/hotel/fr/homestay-bormes-bormes-les-mimosas.nl.html" hreflang="nl" rel="alternate" title="Nederlands" type="text/html"/>
# <link href="https://www.booking.com/hotel/fr/homestay-bormes-bormes-les-mimosas.fr.html" hreflang="fr" rel="alternate" title="Français" type="text/html"/>
# <link href="https://www.booking.com/hotel/fr/homestay-bormes-bormes-les-mimosas.es.html" hreflang="es" rel="alternate" title="Español" type="text/html"/>
# <link href="https://www.booking.com/hotel/fr/homestay-bormes-bormes-les-mimosas.es-ar.html" hreflang="es-ar" rel="alternate" title="Español (AR)" type="text/html"/>
# <link href="https://www.booking.com/hotel/fr/homestay-bormes-bormes-les-mimosas.es-mx.html" hreflang="es-mx" rel="alternate" title="Español (MX)" type="text/html"/>
# <link href="https://www.booking.com/hotel/fr/homestay-bormes-bormes-les-mimosas.ca.html" hreflang="ca" rel="alternate" title="Català" type="text/html"/>
# <link href="https://www.booking.com/hotel/fr/homestay-bormes-bormes-les-mimosas.it.html" hreflang="it" rel="alternate" title="Italiano" type="text/html"/>
# <link href="https://www.booking.com/hotel/fr/homestay-bormes-bormes-les-mimosas.pt-pt.html" hreflang="pt-pt" rel="alternate" title="Português (PT)" type="text/html"/>
# <link href="https://www.booking.com/hotel/fr/homestay-bormes-bormes-les-mimosas.pt-br.html" hreflang="pt-br" rel="alternate" title="Português (BR)" type="text/html"/>
# <link href="https://www.booking.com/hotel/fr/homestay-bormes-bormes-les-mimosas.no.html" hreflang="no" rel="alternate" title="Norsk" type="text/html"/>
# <link href="https://www.booking.com/hotel/fr/homestay-bormes-bormes-les-mimosas.fi.html" hreflang="fi" rel="alternate" title="Suomi" type="text/html"/>
# <link href="https://www.booking.com/hotel/fr/homestay-bormes-bormes-les-mimosas.sv.html" hreflang="sv" rel="alternate" title="Svenska" type="text/html"/>
# <link href="https://www.booking.com/hotel/fr/homestay-bormes-bormes-les-mimosas.da.html" hreflang="da" rel="alternate" title="Dansk" type="text/html"/>
# <link href="https://www.booking.com/hotel/fr/homestay-bormes-bormes-les-mimosas.cs.html" hreflang="cs" rel="alternate" title="Čeština" type="text/html"/>
# <link href="https://www.booking.com/hotel/fr/homestay-bormes-bormes-les-mimosas.hu.html" hreflang="hu" rel="alternate" title="Magyar" type="text/html"/>
# <link href="https://www.booking.com/hotel/fr/homestay-bormes-bormes-les-mimosas.ro.html" hreflang="ro" rel="alternate" title="Română" type="text/html"/>
# <link href="https://www.booking.com/hotel/fr/homestay-bormes-bormes-les-mimosas.ja.html" hreflang="ja" rel="alternate" title="日本語" type="text/html"/>
# <link href="https://www.booking.com/hotel/fr/homestay-bormes-bormes-les-mimosas.zh-cn.html" hreflang="zh-cn" rel="alternate" title="简体中文" type="text/html"/>
# <link href="https://www.booking.com/hotel/fr/homestay-bormes-bormes-les-mimosas.zh-tw.html" hreflang="zh-tw" rel="alternate" title="繁體中文" type="text/html"/>
# <link href="https://www.booking.com/hotel/fr/homestay-bormes-bormes-les-mimosas.pl.html" hreflang="pl" rel="alternate" title="Polski" type="text/html"/>
# <link href="https://www.booking.com/hotel/fr/homestay-bormes-bormes-les-mimosas.el.html" hreflang="el" rel="alternate" title="Ελληνικά" type="text/html"/>
# <link href="https://www.booking.com/hotel/fr/homestay-bormes-bormes-les-mimosas.ru.html" hreflang="ru" rel="alternate" title="Русский" type="text/html"/>
# <link href="https://www.booking.com/hotel/fr/homestay-bormes-bormes-les-mimosas.tr.html" hreflang="tr" rel="alternate" title="Türkçe" type="text/html"/>
# <link href="https://www.booking.com/hotel/fr/homestay-bormes-bormes-les-mimosas.bg.html" hreflang="bg" rel="alternate" title="Български" type="text/html"/>
# <link href="https://www.booking.com/hotel/fr/homestay-bormes-bormes-les-mimosas.ar.html" hreflang="ar" rel="alternate" title="العربية" type="text/html"/>
# <link href="https://www.booking.com/hotel/fr/homestay-bormes-bormes-les-mimosas.ko.html" hreflang="ko" rel="alternate" title="한국어" type="text/html"/>
# <link href="https://www.booking.com/hotel/fr/homestay-bormes-bormes-les-mimosas.he.html" hreflang="he" rel="alternate" title="עברית" type="text/html"/>
# <link href="https://www.booking.com/hotel/fr/homestay-bormes-bormes-les-mimosas.lv.html" hreflang="lv" rel="alternate" title="Latviski" type="text/html"/>
# <link href="https://www.booking.com/hotel/fr/homestay-bormes-bormes-les-mimosas.uk.html" hreflang="uk" rel="alternate" title="Українська" type="text/html"/>
# <link href="https://www.booking.com/hotel/fr/homestay-bormes-bormes-les-mimosas.id.html" hreflang="id" rel="alternate" title="Bahasa Indonesia" type="text/html"/>
# <link href="https://www.booking.com/hotel/fr/homestay-bormes-bormes-les-mimosas.ms.html" hreflang="ms" rel="alternate" title="Bahasa Malaysia" type="text/html"/>
# <link href="https://www.booking.com/hotel/fr/homestay-bormes-bormes-les-mimosas.th.html" hreflang="th" rel="alternate" title="ภาษาไทย" type="text/html"/>
# <link href="https://www.booking.com/hotel/fr/homestay-bormes-bormes-les-mimosas.et.html" hreflang="et" rel="alternate" title="Eesti" type="text/html"/>
# <link href="https://www.booking.com/hotel/fr/homestay-bormes-bormes-les-mimosas.hr.html" hreflang="hr" rel="alternate" title="Hrvatski" type="text/html"/>
# <link href="https://www.booking.com/hotel/fr/homestay-bormes-bormes-les-mimosas.lt.html" hreflang="lt" rel="alternate" title="Lietuvių" type="text/html"/>
# <link href="https://www.booking.com/hotel/fr/homestay-bormes-bormes-les-mimosas.sk.html" hreflang="sk" rel="alternate" title="Slovenčina" type="text/html"/>
# <link href="https://www.booking.com/hotel/fr/homestay-bormes-bormes-les-mimosas.sr.html" hreflang="sr" rel="alternate" title="Srpski" type="text/html"/>
# <link href="https://www.booking.com/hotel/fr/homestay-bormes-bormes-les-mimosas.sl.html" hreflang="sl" rel="alternate" title="Slovenščina" type="text/html"/>
# <link href="https://www.booking.com/hotel/fr/homestay-bormes-bormes-les-mimosas.vi.html" hreflang="vi" rel="alternate" title="Tiếng Việt" type="text/html"/>
# <link href="https://www.booking.com/hotel/fr/homestay-bormes-bormes-les-mimosas.tl.html" hreflang="tl" rel="alternate" title="Filipino" type="text/html"/>
# <link href="https://www.booking.com/hotel/fr/homestay-bormes-bormes-les-mimosas.is.html" hreflang="is" rel="alternate" title="Íslenska" type="text/html"/>
# <script nonce="jsicrug1FljeF7D">
# (function(){
# document.addEventListener('DOMContentLoaded', function(e) {
# window._pxAppId = 'PXikKuL2RM';
# setTimeout(function() {
# var pxs = document.createElement('script');
# pxs.crossOrigin = 'anonymous';
# pxs.nonce = 'jsicrug1FljeF7D';
# pxs.src = 'https://cf.bstatic.com/libs/perimeterx/px.v7.6.9.min.js';
# document.head.appendChild(pxs);
# }, 750);
# });
# }());
# </script>
# <script nonce="jsicrug1FljeF7D" type="text/javascript">
# window.cspViolationsCount = 0;
# if ('SecurityPolicyViolationEvent' in window) {
# document.addEventListener("securitypolicyviolation", (e) => {
# if (navigator.userAgent.indexOf('Safari') != -1 && navigator.userAgent.indexOf('Chrome') == -1) {
# window.cspViolationsCount++;
# } else if (e.disposition === 'enforce') {
# window.cspViolationsCount++;
# }
# });
# }
# </script>
# <script nonce="jsicrug1FljeF7D" type="application/ld+json">
# {
#    "url" : "https://www.booking.com/hotel/fr/homestay-bormes-bormes-les-mimosas.fr.html",
#    "hasMap" : "https://maps.googleapis.com/maps/api/staticmap?zoom=15&center=43.1464450,6.3277240&markers=color:blue%7c43.1464450,6.3277240&sensor=false&size=1600x1200&client=gme-booking&channel=booking-frontend&signature=Iq2nVOOxsPTbDosqGMXeKhM7KXY=",
#    "aggregateRating" : {
#       "bestRating" : 10,
#       "@type" : "AggregateRating",
#       "ratingValue" : 9.6,
#       "reviewCount" : 115
#    },
#    "name" : "HomeStay Bormes",
#    "description" : "Offrant une vue sur la piscine, le HomeStay Bormes est situé à Bormes-les-Mimosas, à 37 km de la gare de Toulon.",
#    "@type" : "Hotel",
#    "address" : {
#       "@type" : "PostalAddress",
#       "postalCode" : "83230",
#       "addressCountry" : "France",
#       "addressLocality" : "322 Rue des Icares",
#       "addressRegion" : "Provence-Alpes-Côte d'Azur",
#       "streetAddress" : "322 Rue des Icares, 83230 Bormes-les-Mimosas, France"
#    },
#    "@context" : "http://schema.org",
#    "priceRange" : "Tarifs à partir de € 144 par nuit pour les dates à venir (nous ajustons nos tarifs)",
#    "image" : "https://cf.bstatic.com/xdata/images/hotel/max500/253944201.jpg?k=9d5245f251e0484f75a38c814d4026c5b034626e2901466e6106eade750b9046&o=&hp=1"
# }
# </script>
# <script nonce="jsicrug1FljeF7D">(function(b, s) { if (b) { document.documentElement.removeChild(b); if (s) { setTimeout(function() { s.parentNode.removeChild(s); }, 0); } delete window.__temporary_body; } }(window.__temporary_body, document.getElementById('top_bar_inline_style')));</script>
# <link data-chunk="client" href="https://cf.bstatic.com/psb/capla/static/css/bui-react.9ad30b1f.css" nonce="jsicrug1FljeF7D" rel="stylesheet"/><link data-chunk="components-PropertyHighlights-PropertyHighlights" href="https://cf.bstatic.com/psb/capla/static/css/759.68faa5a3.chunk.css" nonce="jsicrug1FljeF7D" rel="stylesheet"/><link data-chunk="components-PropertyTypeBadge-PropertyTypeBadge" href="https://cf.bstatic.com/psb/capla/static/css/1159.644068bb.chunk.css" nonce="jsicrug1FljeF7D" rel="stylesheet"/><link data-chunk="components-BHQualityClassificationBanner-BHQualityClassificationBannerMobile" href="https://cf.bstatic.com/psb/capla/static/css/2417.53844c65.chunk.css" nonce="jsicrug1FljeF7D" rel="stylesheet"/><link data-chunk="components-ReviewBlock-ReviewBlockHeaderMobile-ReviewBlockHeaderMobile" href="https://cf.bstatic.com/psb/capla/static/css/5258.cc2a9c52.chunk.css" nonce="jsicrug1FljeF7D" rel="stylesheet"/><link data-chunk="components-PropertyFeaturedReviews-PropertyFeaturedReviewsMobile-PropertyFeaturedReviewsMobile" href="https://cf.bstatic.com/psb/capla/static/css/9340.c6d5f2bc.chunk.css" nonce="jsicrug1FljeF7D" rel="stylesheet"/><link data-chunk="components-PropertyReviewSubscores-PropertyReviewSubscores" href="https://cf.bstatic.com/psb/capla/static/css/9563.31e4e34d.chunk.css" nonce="jsicrug1FljeF7D" rel="stylesheet"/><link data-chunk="components-PropertyReviewSubscoresPanel-PropertyReviewSubscoresPanel" href="https://cf.bstatic.com/psb/capla/static/css/2659.31e4e34d.chunk.css" nonce="jsicrug1FljeF7D" rel="stylesheet"/><link data-chunk="components-PropertyHealthSafety-PropertyHealthSafetyMobile-PropertyHealthSafetyMobile" href="https://cf.bstatic.com/psb/capla/static/css/4945.c1757387.chunk.css" nonce="jsicrug1FljeF7D" rel="stylesheet"/><link data-chunk="components-PropertyHeaderName-PropertyHeaderName" href="https://cf.bstatic.com/psb/capla/static/css/9599.da64fcc8.chunk.css" nonce="jsicrug1FljeF7D" rel="stylesheet"/><link data-chunk="components-QualityRating-QualityRating" href="https://cf.bstatic.com/psb/capla/static/css/6389.e079c644.chunk.css" nonce="jsicrug1FljeF7D" rel="stylesheet"/><link data-chunk="components-PropertySectionCPC-PropertySectionCPCMobile-PropertySectionCPCMobile" href="https://cf.bstatic.com/psb/capla/static/css/9863.29dc74b7.chunk.css" nonce="jsicrug1FljeF7D" rel="stylesheet"/><link data-chunk="components-PropertyHostProfile-PropertyHostProfileMobile-PropertyHostProfileMobile" href="https://cf.bstatic.com/psb/capla/static/css/4952.a200b848.chunk.css" nonce="jsicrug1FljeF7D" rel="stylesheet"/><link data-chunk="components-PropertyLocationBlock-PropertyLocationBlockMobile-PropertyLocationBlockMobile" href="https://cf.bstatic.com/psb/capla/static/css/1267.e09e75df.chunk.css" nonce="jsicrug1FljeF7D" rel="stylesheet"/><link data-chunk="components-SustainabilityBanner-SustainabilityBannerMobile-SustainabilityBannerMobile" href="https://cf.bstatic.com/psb/capla/static/css/8822.6be19048.chunk.css" nonce="jsicrug1FljeF7D" rel="stylesheet"/><link data-chunk="components-TravelProud-TravelProudBannerMobile" href="https://cf.bstatic.com/psb/capla/static/css/7027.9938cd01.chunk.css" nonce="jsicrug1FljeF7D" rel="stylesheet"/><link data-chunk="components-SustainabilityBadge-SustainabilityBadge" href="https://cf.bstatic.com/psb/capla/static/css/4093.af1418b5.chunk.css" nonce="jsicrug1FljeF7D" rel="stylesheet"/><link data-chunk="components-TripTypeLabelsInfo-PilotBeachBannerMobile-PilotBeachBannerMobile" href="https://cf.bstatic.com/psb/capla/static/css/7918.2b450a0d.chunk.css" nonce="jsicrug1FljeF7D" rel="stylesheet"/><link data-chunk="components-TripTypeLabelsInfo-NonPilotBeachBannerMobile-NonPilotBeachBannerMobile" href="https://cf.bstatic.com/psb/capla/static/css/7439.9938cd01.chunk.css" nonce="jsicrug1FljeF7D" rel="stylesheet"/><link data-chunk="components-TripTypesHotelPage-TopBeachNearbyEntryPointMobile-TopBeachNearbyEntryPointMobile" href="https://cf.bstatic.com/psb/capla/static/css/8355.9938cd01.c ...
# <title>HomeStay Bormes, Bormes-les-Mimosas – Tarifs 2023</title>
# <meta content="Offrant une vue sur la piscine, le HomeStay Bormes est situé à Bormes-les-Mimosas, à 37 km de la gare de Toulon." name="description"/>
# <meta content="HomeStay Bormes, Bormes-les-Mimosas, France, R:Provence-Alpes-Côte d'Azur, Hôtel, Hôtels" name="keywords"/>
# <meta content="index,follow" name="robots"/>
# <link href="https://www.booking.com/hotel/fr/homestay-bormes-bormes-les-mimosas.fr.html" rel="canonical"/>
# <link href="android-app://com.booking/booking/hotel/3981214?affiliate_id=375119" rel="alternate"/>
# <meta content="UmFuZG9tSVYw-47krxxm3fMvCx0niQQiqmo_q9kY7jlXCHm01agqNW3lt34sBzAe7DU3CFPb9ikSQ5nqgSDyjtgH1HNNDjE5oJRtRQV0FsBui8KnIgG4VuAO5CYW0YdRTNqL1WaM14VmOBjkX-lQmlWuLKc3e2Mis4oqW69IU0ZW8264VwPeUYOMTo4xpp2M6EXr-jPt1r3G-VZFHc2bDCPWht_MhFkRDrOh8gWGOK7SyDQpp9Ct4PsShs_FCwsr2q4GkCfV2hU-Uy9mWftQEBsk72PF4-B_ZGoDZf6qu5iPy2lSiYmNH9f6nno80JHRTFiaWBSoK_pPLPcdM9u1D9QEYxmGl7Irw4-J35iMvCxcqI04B1JfA8Tso6vWNTL3XLcE8bF7BUroz4tvcMHIQxkGKmjkAPdfS4CxMNKrbiHUlugqCq4fVR_EPd1yzv3wBNZbSF2vKUo0tqKmPAipzr1cUOibaMseX0ACN7VBdjs" name="booking-verification"/>
# <meta content="367003839" name="twitter:app:id:iphone"/>
# <meta content="Booking.com Hotel Reservations Worldwide &amp; Hotel Deals" name="twitter:app:name:ipad"/>
# <meta content="367003839" name="twitter:app:id:ipad"/>
# <meta content="Booking.com Hotel Reservations" name="twitter:app:name:googleplay"/>
# <meta content="com.booking" name="twitter:app:id:googleplay"/>
# <meta content="367003839" property="al:ios:app_store_id"/>
# <meta content="Booking.com Hotel Reservations" property="al:ios:app_name"/>
# <meta content="Booking.com Hotel Reservation" property="al:android:app_name"/>
# <meta content="com.booking" property="al:android:package"/>
# <meta content="HomeStay Bormes, Bormes-les-Mimosas, France" name="twitter:title"/>
# <meta content="Offrant une vue sur la piscine, le HomeStay Bormes est situé à Bormes-les-Mimosas, à 37 km de la gare de Toulon." name="twitter:description"/>
# <meta content="https://cf.bstatic.com/xdata/images/hotel/max1024x768/253944201.jpg?k=9d5245f251e0484f75a38c814d4026c5b034626e2901466e6106eade750b9046&amp;o=&amp;hp=1" name="twitter:image"/>
# <meta content="https://www.booking.com/hotel/fr/homestay-bormes-bormes-les-mimosas.html?aid=375119&amp;label=gen173nr-1VCAsoTUIiaG9tZXN0YXktYm9ybWVzLWJvcm1lcy1sZXMtbWltb3Nhc0gNWARoTYgBApgBDbgBCcgBEdgBAegBAfgBAogCAagCA7gCwrTynQbAAgLSAiRkZmY4ZTRmMC0wNmJmLTQyMzYtYjJhNi01MTdmNmY3NTNjZmHYAgbgAgE" name="twitter:app:url:iphone"/>
# <meta content="https://www.booking.com/hotel/fr/homestay-bormes-bormes-les-mimosas.html?aid=375119&amp;label=gen173nr-1VCAsoTUIiaG9tZXN0YXktYm9ybWVzLWJvcm1lcy1sZXMtbWltb3Nhc0gNWARoTYgBApgBDbgBCcgBEdgBAegBAfgBAogCAagCA7gCwrTynQbAAgLSAiRkZmY4ZTRmMC0wNmJmLTQyMzYtYjJhNi01MTdmNmY3NTNjZmHYAgbgAgE" name="twitter:app:url:ipad"/>
# <meta content="https://www.booking.com/hotel/fr/homestay-bormes-bormes-les-mimosas.html?aid=375119&amp;label=gen173nr-1VCAsoTUIiaG9tZXN0YXktYm9ybWVzLWJvcm1lcy1sZXMtbWltb3Nhc0gNWARoTYgBApgBDbgBCcgBEdgBAegBAfgBAogCAagCA7gCwrTynQbAAgLSAiRkZmY4ZTRmMC0wNmJmLTQyMzYtYjJhNi01MTdmNmY3NTNjZmHYAgbgAgE" name="twitter:app:url:googleplay"/>
# <meta content="https://www.booking.com/hotel/fr/homestay-bormes-bormes-les-mimosas.html?aid=375119&amp;label=gen173nr-1VCAsoTUIiaG9tZXN0YXktYm9ybWVzLWJvcm1lcy1sZXMtbWltb3Nhc0gNWARoTYgBApgBDbgBCcgBEdgBAegBAfgBAogCAagCA7gCwrTynQbAAgLSAiRkZmY4ZTRmMC0wNmJmLTQyMzYtYjJhNi01MTdmNmY3NTNjZmHYAgbgAgE" property="al:ios:url"/>
# <meta content="https://www.booking.com/hotel/fr/homestay-bormes-bormes-les-mimosas.html?aid=375119&amp;label=gen173nr-1VCAsoTUIiaG9tZXN0YXktYm9ybWVzLWJvcm1lcy1sZXMtbWltb3Nhc0gNWARoTYgBApgBDbgBCcgBEdgBAegBAfgBAogCAagCA7gCwrTynQbAAgLSAiRkZmY4ZTRmMC0wNmJmLTQyMzYtYjJhNi01MTdmNmY3NTNjZmHYAgbgAgE" property="al:android:url"/>
# <meta content="website" property="og:type"/>
# <meta content="HomeStay Bormes" property="og:title"/>
# <meta content="Offrant une vue sur la piscine, le HomeStay Bormes est situ&amp;eacute; &amp;agrave; Bormes-les-Mimosas, &amp;agrave; 37 km de la gare de Toulon." property="og:description"/>
# <meta content="https://cf.bstatic.com/xdata/images/hotel/max1024x768/253944201.jpg?k=9d5245f251e0484f75a38c814d4026c5b034626e2901466e6106eade750b9046&amp;o=&amp;hp=1" property="og:image"/>
# <meta content="https://www.booking.com/hotel/fr/homestay-bormes-bormes-les-mimosas.fr.html" property="og:url"/>
# <meta content="summary_large_image" name="twitter:card"/>
# <meta content="@bookingcom" name="twitter:site"/>
# <meta content="@bookingcom" name="twitter:creator"/>
# <meta content="yes" name="apple-touch-fullscreen"/>
# <meta content="no" name="apple-mobile-web-app-capable"/>
# <meta content="telephone=no" name="format-detection"/>
# <link href="https://cf.bstatic.com/static/img/favicon/ebc77706da3aae4aee7b05dadf182390f0d26d11.ico" rel="shortcut icon"/>
# <link href="https://cf.bstatic.com/static/img/apple-touch-icon_new_lrg/c9b35bf29a75cac2f430f80a5d4bc7fd961d21a7.png" rel="apple-touch-icon"/>
# </head>
# <body class="bookings2 hotel colada fr b_lang_fr new_cta not_webview supportsfixed sevenup ltr mobile_progressive_device offline-message-alternative bp-temp-old-base site_is_mdot m_neutral_bg" data-bui-theme="legacy-light" id="b2hotelPage">
# <div style="display:none;">gogless</div>
# <svg style="display: none"><symbol aria-hidden="true" focusable="false" id="icon-streamline-account_user" role="presentation" viewbox="0 0 24 24"><path d="M16.5 9.75a4.5 4.5 0 1 1-9 0 4.5 4.5 0 0 1 9 0zm1.5 0a6 6 0 1 0-12 0 6 6 0 0 0 12 0zm1.445 10.597c-4.086-4.111-10.732-4.132-14.844-.046l-.046.046a.75.75 0 0 0 1.064 1.058l.04-.04a8.996 8.996 0 0 1 12.722.04.75.75 0 0 0 1.064-1.058zM22.5 12c0 5.799-4.701 10.5-10.5 10.5S1.5 17.799 1.5 12 6.201 1.5 12 1.5 22.5 6.201 22.5 12zm1.5 0c0-6.627-5.373-12-12-12S0 5.373 0 12s5.373 12 12 12 12-5.373 12-12z"></path></symbol><symbol aria-hidden="true" focusable="false" id="icon-streamline-lines_horizontal" role="presentation" viewbox="0 0 24 24"><path d="M2.25 18.753h19.5a.75.75 0 0 0 0-1.5H2.25a.75.75 0 0 0 0 1.5zm0-6h19.5a.75.75 0 0 0 0-1.5H2.25a.75.75 0 0 0 0 1.5zm0-6h19.5a.75.75 0 0 0 0-1.5H2.25a.75.75 0 0 0 0 1.5z"></path></symbol><symbol aria-hidden="true" focusable="false" id="icon-iconset-navarrow_down" role="presentation" viewbox="0 0 128 128"><path d="M64 88L33.2 57.2a4 4 0 0 1 5.6-5.7L64 76.7l25.2-25.2a4 4 0 0 1 5.6 5.7z"></path></symbol><symbol aria-hidden="true" focusable="false" id="icon-fonticon-occupancy" role="presentation" viewbox="0 0 32 32">
# <path d="M21.545 7.285c0 4.032-3.264 7.29-7.29 7.29s-7.29-3.258-7.29-7.29C6.964 3.259 10.229 0 14.254 0s7.291 3.259 7.291 7.285z"></path>
# <path d="M26.378 19.219c-2.041-.952-6.945-1.525-12.035-1.507h-.191c-5.083-.016-9.987.555-12.029 1.507-1.217.555-2.143 1.989-1.999 3.317L.622 32h27.255l.499-9.464c.14-1.329-.787-2.761-1.998-3.317z"></path>
# </symbol><symbol aria-hidden="true" focusable="false" id="icon-iconset-thumbs_up_square" role="presentation" viewbox="0 0 128 128"><path d="M112 8H16a8 8 0 0 0-8 8v96a8 8 0 0 0 8 8h96a8 8 0 0 0 8-8V16a8 8 0 0 0-8-8zM48 96H24V58h24zm56-25a8.7 8.7 0 0 1-2 6 8.9 8.9 0 0 1 1 4 6.9 6.9 0 0 1-5 7c-.5 4-4.8 8-9 8H56V58l10.3-23.3a5.4 5.4 0 0 1 10.1 2.7 10.3 10.3 0 0 1-.6 2.7L72 52h23c4.5 0 9 3.5 9 8a9.2 9.2 0 0 1-2 5.3 7.5 7.5 0 0 1 2 5.7z"></path></symbol><symbol aria-hidden="true" focusable="false" id="icon-streamline-arrow_nav_left" role="presentation" viewbox="0 0 24 24"><path d="M14.55 18a.74.74 0 0 1-.53-.22l-5-5A1.08 1.08 0 0 1 8.7 12a1.1 1.1 0 0 1 .3-.78l5-5a.75.75 0 0 1 1.06 0 .74.74 0 0 1 0 1.06L10.36 12l4.72 4.72a.74.74 0 0 1 0 1.06.73.73 0 0 1-.53.22zm-4.47-5.72zm0-.57z"></path></symbol><symbol aria-hidden="true" focusable="false" id="icon-iconset-navarrow_left" role="presentation" viewbox="0 0 128 128"><path d="M73.7 96a4 4 0 0 1-2.9-1.2L40 64l30.8-30.8a4 4 0 0 1 5.7 5.6L51.3 64l25.2 25.2a4 4 0 0 1-2.8 6.8z"></path></symbol><symbol aria-hidden="true" focusable="false" id="icon-fonticon-search" role="presentation" viewbox="0 0 33 32">
# <path d="M31.909 27.615L21.725 17.431a11.284 11.284 0 0 0 1.727-5.994C23.452 5.121 18.277 0 11.895 0 5.512 0 .339 5.121.339 11.437c0 6.32 5.173 11.439 11.556 11.439 2.287 0 4.413-.666 6.207-1.8l10.174 10.173a2.567 2.567 0 0 0 3.631-.001 2.568 2.568 0 0 0 .002-3.633zm-20.014-9.098c-3.95 0-7.151-3.17-7.151-7.08 0-3.909 3.201-7.078 7.151-7.078s7.152 3.17 7.152 7.078c0 3.91-3.202 7.08-7.152 7.08z"></path>
# </symbol><symbol aria-hidden="true" focusable="false" id="icon-iconset-navarrow_right" role="presentation" viewbox="0 0 128 128"><path d="M54.3 96a4 4 0 0 1-2.8-6.8L76.7 64 51.5 38.8a4 4 0 0 1 5.7-5.6L88 64 57.2 94.8a4 4 0 0 1-2.9 1.2z"></path></symbol></svg>
# <div class="gta-header-banner" data-component="dismissible-item/block" data-item-id="gta_smart_banner">
# <button aria-label="Fermer" class="gta-header-banner__close js-close" type="button">
# <svg class="bk-icon -iconset-close" fill="#333333" height="20" role="presentation" width="20"><use xlink:href="#icon-iconset-close"></use></svg>
# </button>
# <div class="gta-header-banner__icon">
# <img alt="Booking" height="60" src="https://cf.bstatic.com/mobile/images/gta/iphone_app_icon/6a9bd9ce320f24431aa007112917bc9d029be5e0.png" width="60"/>
# </div>
# <div class="gta-header-banner__info">
# <div class="gta-header-banner__title">
# Booking.com
# </div>
# <div class="gta-header-banner__rating-stars">
# <img alt="" border="0" height="15" src="https://cf.bstatic.com/mobile/images/app-marketing/5_stars_2x/aadd2a6faac828024cfa33a8a13dd0b49332e317.png" width="81"/>
# 4,8
# </div>
# <div class="gta-header-banner__rating-nr">
# 785 k notes
# </div>
# </div>
# <div class="gta-header-banner__cta">
# <a class="gta-header-banner__btn" href="https://www.booking.com/apps.fr.html?label=gen173nr-1FCAsoTUIiaG9tZXN0YXktYm9ybWVzLWJvcm1lcy1sZXMtbWltb3Nhc0gNWARoTYgBApgBDbgBCcgBEdgBAegBAfgBAogCAagCA7gCwrTynQbAAgHSAiRkZmY4ZTRmMC0wNmJmLTQyMzYtYjJhNi01MTdmNmY3NTNjZmHYAgXgAgE&amp;amp;sid=63cdf545ef892bc149a03bff162aaa08&amp;amp;app_install=1&amp;amp;lang=fr&amp;amp;site=mdot&amp;amp;page=hotel&amp;amp;placement=GeneralHeaderNew&amp;amp;device=direct&amp;amp;etseed=52616e646f6d49562473646523287d610aca762bfbc0adb16e6182a17b05f533ad6174b83a4bf3f0a9261b77040652a9a1964eecd17341fe425d78559b19d23b&amp;amp;hoff=hotel&amp;amp;dest_countrycode=fr&amp;amp;hotel_id=3981214&amp;amp;room1=A,A" target="_blank">
# Installer
# </a>
# </div>
# </div>
# <div data-component="security/csp_exp_tracker" data-exp-hash="dLcXJeITPMOaOMfXLMEO" style="display: none;"></div>
# <div id="main_container">
# <div class="js-main-content" id="main_content">
# <header class="bui-header bui-header--logo-large js-site-header bui-u-hidden-print">
# <nav class="bui-header__bar">
# <div class="bui-header__main">
# <div class="bui-group bui-group--inline bui-group--small bui-button-group">
# <div class="bui-group__item">
# <a aria-label="Retour" class="bui-button bui-button--light bui-traveller-header__back" href="/searchresults.fr.html?label=gen173nr-1FCAsoTUIiaG9tZXN0YXktYm9ybWVzLWJvcm1lcy1sZXMtbWltb3Nhc0gNWARoTYgBApgBDbgBCcgBEdgBAegBAfgBAogCAagCA7gCwrTynQbAAgHSAiRkZmY4ZTRmMC0wNmJmLTQyMzYtYjJhNi01MTdmNmY3NTNjZmHYAgXgAgE&amp;sid=63cdf545ef892bc149a03bff162aaa08&amp;city=-1413801;checkin=;checkout=;highlighted_hotels=3981214;">
# <span aria-hidden="true" class="bui-button__icon bui-icon bui-icon--larger">
# <svg class="bk-icon -streamline-arrow_nav_left" height="24" width="24"><use xlink:href="#icon-streamline-arrow_nav_left"></use></svg>
# </span>
# </a>
# </div>
# </div>
# <a aria-label="Retour" class="bui-button bui-button--light bui-traveller-header__back-dynamic js-site-header--back">
# <span aria-hidden="true" class="bui-button__icon bui-icon bui-icon--larger">
# <svg class="bk-icon -streamline-arrow_nav_left" height="24" width="24"><use xlink:href="#icon-streamline-arrow_nav_left"></use></svg>
# </span>
# </a>
# </div>
# <div class="bui-group bui-group--inline bui-group--small bui-group--align-end bui-group--vertical-align-middle bui-button-group">
# <div class="bui-group__item">
# <a aria-label="Se connecter" class="bui-button bui-traveller-header__profile bui-button--light bui-button--large js-header-login-link js-header-signin-notification" data-et-click="
# customGoal:YTTHbXNLPVIRPQHUYJWcRQFdLHe:3
# customGoal:YTBUIHOdVLBQRMebfTINfTKe:3
# " data-track-event="header_profile_btn" href="https://account.booking.com/auth/oauth2?state=UvABogA4v8XA-1zqIi292gLzyx9kmmIUcpjBfFgYFHsuLU0N5BGfsXaKM6ZWO-iTLPVtmK9BD5EmYqpLNbcQLqm-LxoDSHR7xJKVjeeYSmlnsfsKbt0NGhiaaGquyV3YrYc5eBarMxZj-1aY0DaHoLeXI9JUjy4E0FejupUZ99G-UA6aUWi4ZgVM00NttmtJ78ayCJIzBcZ_CI9gC0Wvv7eevd2wh33Moo-oZZLow-Hp58s8AyzP_FmzWbexaiZ6ou9I2o3e-C7ZlhAzJrtkfbFF_AIGJLpT7Oxv97hyoalDD74Ox-PDdysPZgyELtMvUdc7&amp;response_type=code&amp;aid=304142&amp;lang=fr&amp;bkng_action=hotel&amp;dt=1673304643&amp;redirect_uri=https%3A%2F%2Fsecure.booking.com%2Flogin.html%3Fop%3Doauth_return&amp;client_id=vO1Kblk7xX9tUn2cpZLS" type="button">
# <span class="bui-button__icon bui-bubble-container">
# <span aria-hidden="true" class="bui-icon bui-icon--large">
# <svg class="bk-icon -streamline-account_user" height="24" width="24"><use xlink:href="#icon-streamline-account_user"></use></svg>
# </span>
# <span class="bui-bubble bui-bubble-container__value bui-bubble--destructive bui-u-hidden js-bui-traveller-header__profile-icon"></span>
# </span>
# </a>
# </div>
# <div class="bui-group__item">
# <button aria-label="Plus de liens, paramètres et assistance" class="bui-button bui-button--light bui-button--large" data-bui-component="Modal.HeaderAsync" data-et-click="
# customGoal:YTTHbXNLPVIRPQHUYJWcRQFdLHe:1
# customGoal:YTBUIHOdBOcaGPaVHXT:5
# customGoal:YTBUIHOdVLBQRMebfTINfTKe:1
# " data-modal-aria-label="Plus de liens, paramètres et assistance" data-modal-arrow-navigation="true" data-modal-close-aria-label="Ferme le menu" data-modal-fill="true" data-modal-full-screen="true" data-modal-header-async-url="/navigation.fr.html?label=gen173nr-1FCAsoTUIiaG9tZXN0YXktYm9ybWVzLWJvcm1lcy1sZXMtbWltb3Nhc0gNWARoTYgBApgBDbgBCcgBEdgBAegBAfgBAogCAagCA7gCwrTynQbAAgHSAiRkZmY4ZTRmMC0wNmJmLTQyMzYtYjJhNi01MTdmNmY3NTNjZmHYAgXgAgE&amp;sid=63cdf545ef892bc149a03bff162aaa08&amp;lang=fr&amp;origin=%2Fhotel%2Ffr%2Fhomestay-bormes-bormes-les-mimosas.fr.html%3Flabel%3Dgen173nr-1FCAsoTUIiaG9tZXN0YXktYm9ybWVzLWJvcm1lcy1sZXMtbWltb3Nhc0gNWARoTYgBApgBDbgBCcgBEdgBAegBAfgBAogCAagCA7gCwrTynQbAAgHSAiRkZmY4ZTRmMC0wNmJmLTQyMzYtYjJhNi01MTdmNmY3NTNjZmHYAgXgAgE%26sid%3D63cdf545ef892bc149a03bff162aaa08%26dist%3D0%3Broom1%3DA%252CA%3Bsb_price_type%3Dtotal%3Btype%3Dtotal%26&amp;origin_action=hotel&amp;;is_ajax=1">
# <span class="bui-button__icon">
# <span aria-hidden="true" class="bui-icon bui-icon--large">
# <svg class="bk-icon -streamline-lines_horizontal" height="24" width="24"><use xlink:href="#icon-streamline-lines_horizontal"></use></svg>
# </span>
# </span>
# </button>
# </div>
# </div>
# </nav>
# </header>
# <div class="tabbed-nav--content tab-active" data-tab-id="main">
# <div class="coronavirus-main-funnel-banner bui-alert--info">
# <div class="bui-alert bui-alert--info" role="status">
# <span class="bui-alert__icon" role="presentation">
# <svg class="bk-icon -streamline-info_sign" fill="&lt;TMPL_V bui_color_complement&gt;" height="24" width="24"><use xlink:href="#icon-streamline-info_sign"></use></svg>
# </span>
# <div class="bui-alert__description js-coronavirus-banner is-collapsed">
# <span class="bui-alert__title js-coronavirus-banner-collapse-button">
# Assistance coronavirus (COVID-19)
# <svg class="bk-icon -streamline-arrow_nav_up" height="24" width="24"><use xlink:href="#icon-streamline-arrow_nav_up"></use></svg>
# </span>
# <p class="bui-alert__text">
# Obtenez les conseils de voyage dont vous avez besoin et consultez les éventuelles restrictions de déplacements avant de partir.
# </p>
# <p class="bui-alert__text">
# <a class="bui-link bui-link--primary" href="https://www.booking.com/covid-19.html?aid=304142&amp;label=gen173nr-1FCAsoTUIiaG9tZXN0YXktYm9ybWVzLWJvcm1lcy1sZXMtbWltb3Nhc0gNWARoTYgBApgBDbgBCcgBEdgBAegBAfgBAogCAagCA7gCwrTynQbAAgHSAiRkZmY4ZTRmMC0wNmJmLTQyMzYtYjJhNi01MTdmNmY3NTNjZmHYAgXgAgE" target="_blank">
# En savoir plus
# </a>
# </p>
# </div>
# </div>
# </div>
# <style>
# .partner_header_wrapper .sw_loyalty_copy { display: none; }
# </style>
# <svg aria-hidden="true" class="bk-icon -genius-new_identity-genius_badge" focusable="false" height="174" role="presentation" style="display:none;" viewbox="0 0 434 174" width="434">
# <g>
# <path d="M418.964 0H14.6335C6.65829 0 0.193115 6.46518 0.193115 14.4404V158.844C0.193115 166.819 6.65829 173.285 14.6335 173.285H418.964C426.939 173.285 433.404 166.819 433.404 158.844V14.4404C433.404 6.46518 426.939 0 418.964 0Z" fill="#004CB8"></path>
# <path d="M375.643 112.057C375.651 112.911 375.418 113.75 374.971 114.478C374.524 115.206 373.881 115.793 373.116 116.173C371.061 117.213 368.774 117.71 366.473 117.617C363.367 117.862 360.262 117.13 357.592 115.523C355.323 114.154 353.571 112.072 352.611 109.602C352.551 109.35 352.431 109.116 352.26 108.921C352.09 108.726 351.874 108.575 351.632 108.483C351.39 108.39 351.129 108.358 350.871 108.39C350.614 108.421 350.368 108.515 350.156 108.664L341.13 112.635C340.869 112.706 340.627 112.837 340.425 113.019C340.223 113.2 340.067 113.426 339.969 113.679C339.87 113.932 339.833 114.205 339.859 114.475C339.885 114.745 339.975 115.005 340.12 115.234C342.038 119.7 345.325 123.441 349.506 125.92C354.638 128.933 360.527 130.412 366.473 130.18C372.448 130.368 378.324 128.621 383.224 125.198C385.473 123.727 387.315 121.711 388.577 119.338C389.839 116.965 390.481 114.312 390.444 111.624C390.444 101.997 383.657 96.1488 370.083 94.079C366.842 93.6288 363.696 92.6533 360.769 91.1909C358.603 90.1801 356.148 88.8082 356.148 87.2198C356.194 86.4783 356.458 85.7669 356.908 85.1757C357.358 84.5845 357.973 84.14 358.676 83.8985C360.848 83.0046 363.187 82.5861 365.535 82.6711C367.779 82.6622 370.001 83.1271 372.054 84.0353C374.107 84.9435 375.945 86.2747 377.448 87.9418C377.63 88.1318 377.849 88.283 378.09 88.3863C378.332 88.4896 378.593 88.5429 378.856 88.5429C379.119 88.5429 379.379 88.4896 379.621 88.3863C379.863 88.283 380.082 88.1318 380.264 87.9418L386.69 82.1657C386.936 82.0362 387.148 81.8492 387.307 81.6204C387.466 81.3917 387.568 81.128 387.603 80.8517C387.639 80.5754 387.607 80.2946 387.511 80.0331C387.415 79.7717 387.257 79.5373 387.051 79.3498C382.053 74.4653 375.569 71.3872 368.625 70.6026C361.681 69.8179 354.673 71.3716 348.712 75.0177C346.74 76.4007 345.146 78.2548 344.074 80.4112C343.002 82.5675 342.487 84.9577 342.574 87.3642C342.567 89.4267 343.001 91.4669 343.848 93.3475C344.695 95.2281 345.935 96.9054 347.484 98.2667C351.292 101.398 355.888 103.422 360.769 104.115C364.771 104.676 368.681 105.769 372.394 107.364C373.334 107.744 374.143 108.391 374.72 109.225C375.297 110.059 375.618 111.043 375.643 112.057Z" fill="white"></path>
# <path d="M282.575 107.509C282.412 110.486 282.839 113.467 283.83 116.279C284.821 119.092 286.358 121.681 288.351 123.899C290.419 125.929 292.885 127.51 295.594 128.541C298.303 129.573 301.196 130.032 304.091 129.891C306.536 129.936 308.973 129.595 311.311 128.881C313.006 128.39 314.631 127.686 316.149 126.787C317.577 125.778 318.951 124.693 320.264 123.538L321.636 126.859C321.861 127.389 322.248 127.834 322.74 128.132C323.232 128.43 323.806 128.566 324.38 128.52H333.766C334.021 128.556 334.281 128.532 334.525 128.451C334.769 128.369 334.991 128.232 335.173 128.05C335.355 127.868 335.493 127.646 335.574 127.401C335.656 127.157 335.679 126.897 335.643 126.642V73.7906C335.635 73.5591 335.579 73.3319 335.478 73.1236C335.377 72.9152 335.233 72.7303 335.056 72.5807C334.879 72.4312 334.673 72.3202 334.451 72.255C334.229 72.1898 333.996 72.1718 333.766 72.2021H321.853C321.598 72.166 321.338 72.1897 321.094 72.2712C320.849 72.3528 320.627 72.49 320.445 72.6721C320.263 72.8542 320.126 73.0761 320.044 73.3203C319.963 73.5646 319.939 73.8244 319.975 74.0794V110.18C318.697 112.152 316.942 113.768 314.871 114.879C312.801 115.99 310.484 116.559 308.134 116.534C306.791 116.632 305.442 116.423 304.191 115.922C302.94 115.422 301.82 114.644 300.914 113.646C299.138 111.504 298.235 108.771 298.387 105.993V73.7906C298.387 72.5631 297.665 71.9133 296.365 71.9133H284.596C283.297 71.9133 282.575 72.5631 282.575 73.7906V107.509Z" fill="white"></path>
# ...
# <path d="M26.347 18.465V-.049H8.531s-4.97.233-4.97 4.745h4.273v13.769h18.514z"></path>
# <path d="M29.196 18.465V-.049h17.816s4.97.233 4.97 4.745h-4.273v13.769H29.195z"></path>
# <path d="M50.558 7.784s.712-2.136 2.848-2.136 2.848 2.136 2.848 2.136v21.363s0 2.136-3.56 2.136H1.424s-2.136.712-2.136-2.848V7.784S0 5.648 2.136 5.648s2.848 2.136 2.848 2.136V23.45c0 .075-.712 2.136 2.136 2.136h40.589c2.974 0 2.848-2.848 2.848-2.848V7.784z"></path>
# <path d="M26.347 23.841v-3.24H7.833v1.424s.071 1.815 1.815 1.815h16.699z"></path>
# <path d="M29.196 23.841v-3.24H47.71v1.424s-.071 1.815-1.815 1.815H29.196z"></path>
# </symbol><symbol aria-hidden="true" focusable="false" id="icon-iconset-city" role="presentation" viewbox="0 0 128 128"><path d="M24 88h8v16h-8zm0-16h8V56h-8zm32 32h8V88h-8zm0-32h8V56h-8zm0-32h8V24h-8zm64 16v60a4 4 0 0 1-4 4H12a4 4 0 0 1-4-4V44a4 4 0 0 1 4-4h28V12a4 4 0 0 1 4-4h32a4 4 0 0 1 4 4v58.3l5.2-5.1a4 4 0 0 1 5.6 0l5.2 5.1V56a4 4 0 0 1 .3-1.5l8-20a4 4 0 0 1 7.4 0l8 20a4 4 0 0 1 .3 1.5zM16 112h24V48H16zm32 0h24V16H48v96zm32 0h16V81.7l-8-8-8 8zm32-55.2l-4-10-4 10V112h8z"></path></symbol><symbol aria-hidden="true" focusable="false" id="icon-iconset-warning" role="presentation" viewbox="0 0 128 128"><path d="M64 8a56 56 0 1 0 56 56A56 56 0 0 0 64 8zm0 91a8 8 0 1 1 8-8 8 8 0 0 1-8 8zm8-61l-5 39h-6l-5-39a8 8 0 1 1 16 0z"></path></symbol><symbol aria-hidden="true" focusable="false" id="icon-streamline-transport_bus_front" role="presentation" viewbox="0 0 24 24"><path d="M4.5 20.213v1.5a2.25 2.25 0 0 0 4.5 0v-1.5a.75.75 0 0 0-1.5 0v1.5a.75.75 0 0 1-1.5 0v-1.5a.75.75 0 0 0-1.5 0zm13.5 0v1.5a.75.75 0 0 1-1.5 0v-1.5a.75.75 0 0 0-1.5 0v1.5a2.25 2.25 0 0 0 4.5 0v-1.5a.75.75 0 0 0-1.5 0zm1.5-1.5a.75.75 0 0 1-.75.75H5.25a.75.75 0 0 1-.75-.75v-13.5a3.75 3.75 0 0 1 3.75-3.75h7.5a3.75 3.75 0 0 1 3.75 3.75v13.5zm1.5 0v-13.5c0-2.9-2.35-5.25-5.25-5.25h-7.5A5.25 5.25 0 0 0 3 5.213v13.5a2.25 2.25 0 0 0 2.25 2.25h13.5a2.25 2.25 0 0 0 2.25-2.25zM9.75 4.463h4.5a.75.75 0 0 0 0-1.5h-4.5a.75.75 0 0 0 0 1.5zm-6 3h16.5l-.75-.75v7.5l.75-.75H3.75l.75.75v-7.5l-.75.75zm0-1.5a.75.75 0 0 0-.75.75v7.5c0 .414.336.75.75.75h16.5a.75.75 0 0 0 .75-.75v-7.5a.75.75 0 0 0-.75-.75H3.75zm3 12h3a.75.75 0 0 0 0-1.5h-3a.75.75 0 0 0 0 1.5zm7.5 0h3a.75.75 0 0 0 0-1.5h-3a.75.75 0 0 0 0 1.5zm-10.5-10.5h-1.5A2.25 2.25 0 0 0 0 9.713v4.5a.75.75 0 0 0 1.5 0v-4.5a.75.75 0 0 1 .75-.75h1.5a.75.75 0 0 0 0-1.5zm16.5 1.5h1.5a.75.75 0 0 1 .75.75v4.5a.75.75 0 0 0 1.5 0v-4.5a2.25 2.25 0 0 0-2.25-2.25h-1.5a.75.75 0 0 0 0 1.5z"></path></symbol><symbol aria-hidden="true" focusable="false" id="icon-iconset-compass" role="presentation" viewbox="0 0 128 128"><path d="M64 8a56 56 0 1 0 56 56A56 56 0 0 0 64 8zm0 104a48 48 0 1 1 48-48 48 48 0 0 1-48 48zm-6-84a6 6 0 1 1 6 6 6 6 0 0 1-6-6zm12 72a6 6 0 1 1-6-6 6 6 0 0 1 6 6zM28 70a6 6 0 1 1 6-6 6 6 0 0 1-6 6zm78-6a6 6 0 1 1-6-6 6 6 0 0 1 6 6zM95.5 35.7a2 2 0 0 0-.2-2.6l-.4-.4a2 2 0 0 0-2.6-.2L66.7 48.2a16 16 0 0 0-18.5 18.5L32.5 92.3a2 2 0 0 0 .2 2.6l.4.4a2 2 0 0 0 2.6.2l25.6-15.7a16 16 0 0 0 18.5-18.5zM64 72a8 8 0 1 1 8-8 8 8 0 0 1-8 8z"></path></symbol><symbol aria-hidden="true" focusable="false" id="icon-streamline-house-chimney-alt" role="presentation" viewbox="0 0 24 24"><path d="M3.004 13.923v8.25c0 .414.336.75.75.75h6a.75.75 0 0 0 .75-.75v-6a.75.75 0 0 1 .75-.75h1.5a.75.75 0 0 1 .75.75v6c0 .414.336.75.75.75h6a.75.75 0 0 0 .75-.75v-8.25a.75.75 0 0 0-1.5 0v8.25l.75-.75h-6l.75.75v-6a2.25 2.25 0 0 0-2.25-2.25h-1.5a2.25 2.25 0 0 0-2.25 2.25v6l.75-.75h-6l.75.75v-8.25a.75.75 0 0 0-1.5 0zm-1.72-.97l10.19-10.189a.75.75 0 0 1 1.06 0l10.19 10.19a.75.75 0 1 0 1.06-1.061L13.595 1.703a2.25 2.25 0 0 0-3.181 0L.224 11.894a.75.75 0 0 0 1.06 1.06zm15.97-7.28v-1.5l-.75.75h3.75l-.75-.75v5.25a.75.75 0 0 0 1.5 0v-5.25a.75.75 0 0 0-.75-.75h-3.75a.75.75 0 0 0-.75.75v1.5a.75.75 0 0 0 1.5 0z"></path></symbol><symbol aria-hidden="true" focusable="false" id="icon-streamline-fridge" role="presentation" viewbox="0 0 24 24"><path d="M19.5 11.25v9.451a.299.299 0 0 1-.299.299H4.799a.299.299 0 0 1-.299-.299V1.799c0-.165.134-.299.299-.299h14.402c.165 0 .299.134.299.299v9.451zm1.5 0V1.799C21 .805 20.195 0 19.201 0H4.799C3.805 0 3 .805 3 1.799v18.902c0 .994.805 1.799 1.799 1.799h14.402c.994 0 1.799-.805 1.799-1.799V11.25zM6 21.75v1.5a.75.75 0 0 0 1.5 0v-1.5a.75.75 0 0 0-1.5 0zm10.5 0v1.5a.75.75 0 0 0 1.5 0v-1.5a.75.75 0 0 0-1.5 0zM3.75 9h16.5a.75.75 0 0 0 0-1.5H3.75a.75.75 0 0 0 0 1.5zM6 12.75v4.5a.75.75 0 0 0 1.5 0v-4.5a.75.75 0 0 0-1.5 0zm0-9v1.5a.75.75 0 0 0 1.5 0v-1.5a.75.75 0 0 0-1.5 0z"></path></symbol><symbol aria-hidden="true" focusable="false" id="icon-streamline-spa_c ...
# <link href="https://cf.bstatic.com/mobile/css/core_critical_cloudfront_sd.iq_ltr/9470bc8e42256b88b55fa309bed04c4c811e76b5.css" rel="prefetch"/>
# <link href="https://cf.bstatic.com/mobile/css/searchresults_no_filters_cloudfront_sd.iq_ltr/d7a795e9664724c6be913d6ef3718c1ba995f91e.css" rel="prefetch"/>
# <link href="https://cf.bstatic.com/mobile/js/searchresults_cloudfront_sd/f363de7fb0dba77ff856788400d5adc9dce825ec.js" rel="prefetch"/>
# <link href="https://cf.bstatic.com/static/js/et_cloudfront_sd/a5c838dc6079df69f699e35761fd372c0f92ce73.js" rel="prefetch"/>
# <script nonce="jsicrug1FljeF7D">/*eslint no-console: "off"*/
# (function() {
# // Impact mesurement
# window.addEventListener('load', impactRecordLoadTime);
# function impactRecordLoadTime() {
# try {
# if (performance.timing.loadEventEnd == 0) return setTimeout(impactRecordLoadTime, 1000);
# var delta = performance.timing.loadEventEnd - performance.timing.connectStart;
# localStorage.reloadClock = parseInt(localStorage.reloadClock || 0, 10) + delta;
# localStorage.reloadCount = parseInt(localStorage.reloadCount || 0, 10) + 1;
# } catch (o_O) {}
# }
# function impactHasHotReloadActive() {
# try {
# localStorage.reloadHasUsedHotComponent = true;
# } catch (o_O) {}
# }
# var loader = B.require('component/loader');
# // ------------------------------------------------------------------------
# // Toast Config
# function toast(message) {
# var id = 'hot-reload-toast';
# var previousToast = document.getElementById(id);
# if (previousToast) previousToast.remove();
# var toast = document.createElement('div');
# toast.id = id;
# Object.assign(toast.style, {
# background: 'rgba(0,0,0,0.9)',
# boxShadow: '0 2px -2px rgba(0,0,0,0.4)',
# color: '#fff',
# font: 'normal 14px/1.5 sans-serif',
# padding: '8px 12px',
# borderRadius: '4px',
# position: 'fixed',
# bottom: '-30px',
# left: '50%',
# transform: 'translateX(-50%)',
# transition: 'all .2s ease-in-out',
# zIndex: 999999
# });
# toast.textContent = message;
# console.info(message);
# document.body.appendChild(toast);
# setTimeout(function() {
# toast.style.bottom = '40px';
# }, 10);
# setTimeout(function() {
# toast.style.bottom = '-50px';
# }, 2200);
# setTimeout(function() {
# toast.remove();
# }, 2500);
# }
# var Toast = {
# wsStarted: function() {
# toast('Hot reload started');
# },
# wsDisconnected: function() {
# toast('WebSocket server disconnected');
# },
# wsSuccess: function() {
# toast('Hot Reload starting');
# },
# wsFail: function() {
# toast('Failed starting hot reload');
# },
# reloadHTML: function(id) {
# toast('HTML code reloaded - id: ' + id);
# },
# reloadCSS: function() {
# toast('CSS code reloaded');
# },
# reloadJS: function(file, name) {
# toast('JS code reloaded - ' + file + ' - ' + name);
# }
# };
# // ------------------------------------------------------------------------
# // Reload actions
# var Reload = {
# HTML: function reloadHTML(newComponent, attributes) {
# var componentsToReload = [].slice.call(document.querySelectorAll('[data-hot-reload-id]'));
# componentsToReload.forEach(function(componentToReload) {
# if (componentToReload.dataset.hotReloadId === attributes['id']) {
# fetch('https://book.dqs.booking.com/dev/render_tmpl_fiddle', {
# method: 'POST',
# mode: 'cors',
# headers: {
# 'Content-Type': 'application/json; charset=utf-8'
# },
# body: JSON.stringify({
# tmpl: newComponent,
# tmpl_data: JSON.stringify(attributes)
# })
# })
# .then(function(response) {
# return response.json();
# })
# .then(function _reloadHTML(response) {
# componentToReload.innerHTML = response.result;
# Toast.reloadHTML(attributes['id']);
# });
# }
# });
# },
# CSS: function reloadCSS() {
# var links = [].slice.call(document.querySelectorAll('link[rel="stylesheet"][href*="bstatic.com"]'));
# var newLinksOnload = links.map(function(link) {
# return new Promise(function(resolve, reject) {
# var newLink = link.cloneNode();
# document.head.appendChild(newLink);
# newLink.onload = resolve;
# newLink.onerror = resolve;
# return newLink;
# });
# });
# Promise.all(newLinksOnload).then(function() {
# links.forEach(function(link) {
# if (link.parentNode) {
# link.parentNode.removeChild(link);
# }
# });
# });
# Toast.reloadCSS();
# },
# JS: function reloadJS(file, name) {
# var id = btoa(name);
# var url = hotURL(file);
# var elements = $('[data-component=' + name + ']');
# var script = document.getElementById(id);
# if (script) script.remove();
# // 1. destroy existing instances
# elements.each(function(i, node) {
# var self = $(node);
# var c = loader.getComponent(node);
# c && c._destroy && c._destroy();
# self.removeData('component-instance-' + name);
# // Remove event-map delegate listeners
# self.off('*');
# // Clone root node to get rid of all DOM modifications / event listeners
# self.replaceWith(this.cloneNode(true));
# });
# // damn you component-loader.loadAsync !
# setTimeout(function() {
# var componentName = 'component/' + name;
# // 2. remove component module definition
# delete B.require._defined[componentName];
# // 3. load new definition and initialize
# script = document.createElement('script');
# script.onload = function() {
# elements = $('[data-component=' + name + ']');
# if (elements.length) {
# elements.component(name);
# }
# // elements.component(name);
# };
# script.src = url;
# document.getElementsByTagName('head')[0].appendChild(script);
# Toast.reloadJS(file, componentName);
# }, 20);
# }
# };
# function hotReloadCSS(file) {
# var id = btoa(file);
# var url = hotURL(file);
# var link = document.getElementById(id);
# if (!link) {
# var link = createLinkStylesheet(url, id);
# } else {
# forceLinkReload(link);
# }
# }
# function reloadRequestHandler(message) {
# var data = parseJSON(message.data);
# console.info('hot-reload:', data);
# if (!data) return console.error('Could not parse message', message);
# switch (data.type) {
# case 'reload-html':
# return Reload.HTML(data.data.source, data.data.attributes);
# case 'reload-css':
# return Reload.CSS();
# case 'reload-css-inline':
# return hotReloadCSS(data.path);
# case 'reload-js-component':
# return Reload.JS(data.path, data.component);
# case 'full':
# window.location.reload();
# }
# }
# // ------------------------------------------------------------------------
# // WebSocket Config
# function Watcher(options) {
# this.host = (options && options.host) || 'wss://' + location.hostname;
# this.port = (options && options.port) || '3000';
# this.ws = null;
# this.wsURL = this.host + ':' + this.port;
# this.timer = null;
# this.pingInterval = 5000;
# }
# Watcher.prototype.connect = function() {
# if (!window.WebSocket) return Toast.wsStarted();
# if (this.connected) return Toast.wsSuccess();
# var ws = (this.ws = new WebSocket(this.wsURL));
# ws.onopen = this.openHandler.bind(this);
# ws.onclose = this.closeHandler.bind(this);
# ws.onmessage = this.messageHandler.bind(this);
# ws.onerror = this.errorHandler.bind(this);
# };
# Watcher.prototype.disconnect = function() {
# this.ws.close();
# this.connected = false;
# Toast.wsDisconnected();
# };
# Watcher.prototype.start = function() {
# this.connect();
# };
# Watcher.prototype.stop = function() {
# this.disconnect();
# Toast.wsDisconnected();
# };
# Watcher.prototype.openHandler = function() {
# this.connected = true;
# Toast.wsStarted();
# impactHasHotReloadActive();
# };
# Watcher.prototype.closeHandler = function() {
# if (this.connected) Toast.wsDisconnected();
# this.connected = false;
# };
# Watcher.prototype.errorHandler = function(err) {
# if (this.ws.readyState == WebSocket.CLOSING || this.ws.readyState == WebSocket.CLOSED) {
# Toast.wsFail();
# }
# };
# Watcher.prototype.messageHandler = reloadRequestHandler;
# // ------------------------------------------------------------------------
# // Helpers
# function parseJSON(data) {
# try {
# return JSON.parse(data);
# } catch (o_O) {}
# }
# function hotURL(file) {
# return '//' + location.host.replace('booking.com', 'bstatic.com') + '/dev/' + file + '?t=' + Date.now();
# }
# // ------------------------------------------------------------------------
# // CSS Link Helpers
# function forceLinkReload(linkElement) {
# linkElement.href = linkElement.href.replace(/\?.*|$/m, '?t=' + Date.now());
# }
# function createLinkStylesheet(url, id) {
# var link = document.createElement('link');
# if (id) link.id = id;
# link.rel = 'stylesheet';
# link.href = url;
# document.getElementsByTagName('head')[0].appendChild(link);
# }
# // ------------------------------------------------------------------------
# // Hot Reload Config
# window.hotreload = function() {
# var isLocal = /[?&]hotreload=localhost/.test(location.search);
# var kvmAddress = 'https://cf.bstatic.com'.replace('https://', 'wss://').replace('bstatic', 'booking');
# var options = isLocal ? { host: 'ws://localhost' } : { host: kvmAddress };
# new Watcher(options).start();
# };
# var keys = [];
# window.addEventListener(
# 'keydown',
# function(e) {
# if (e.key === 'r') {
# keys.push('r');
# if (keys.length === 3) {
# window.hotreload();
# keys.length = 0;
# }
# } else {
# keys.length = 0;
# }
# },
# false
# );
# if (/[?&]hotreload/.test(location.search)) {
# window.hotreload();
# }
# }());
# </script>
# <span id="req_info" style="display:none;">1657630,1656050|2,1655910,1656050,1625600,1656050|4,1657780</span>
# </div></div></body>
# </html>

# %%
'''adresses_json = []

for i in range(len(url_list)):
    ID = i
    r_adresses = requests.get('https://www.booking.com{}'.format(url_list[i]), headers = {'User-Agent': 'Mozilla/5.0 (Linux; Android 6.0; Nexus 5 Build/MRA58N) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/108.0.0.0 Mobile Safari/537.36'})
    soup = BeautifulSoup(r_adresses.content)
    link = soup.select('a.show_map')
    hotel_adresse = [element.get('data-coords') for element in soup.select('#show_map')][0]
    adresse_lat = float(hotel_adresse.split(",")[1])
    adresse_lon = float(hotel_adresse.split(",")[0])
    adresses_json.append([adresse_lat,adresse_lon])
    
adresses_json

# Conversion de notre liste de coordonnées en DF
hotels_lat_lon = DataFrame(adresses_json)'''
# Out:
# 'adresses_json = []\n\nfor i in range(len(url_list)):\n    ID = i\n    r_adresses = requests.get(\'https://www.booking.com{}\'.format(url_list[i]), headers = {\'User-Agent\': \'Mozilla/5.0 (Linux; Android 6.0; Nexus 5 Build/MRA58N) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/108.0.0.0 Mobile Safari/537.36\'})\n    soup = BeautifulSoup(r_adresses.content)\n    link = soup.select(\'a.show_map\')\n    hotel_adresse = [element.get(\'data-coords\') for element in soup.select(\'#show_map\')][0]\n    adresse_lat = float(hotel_adresse.split(",")[1])\n    adresse_lon = float(hotel_adresse.split(",")[0])\n    adresses_json.append([adresse_lat,adresse_lon])\n    \nadresses_json\n\n# Conversion de notre liste de coordonnées en DF\nhotels_lat_lon = DataFrame(adresses_json)'

# %%
r_adresses = requests.get(URL, headers = {'User-Agent': 'Mozilla/5.0 (Linux; Android 6.0; Nexus 5 Build/MRA58N) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/108.0.0.0 Mobile Safari/537.36'})
soup = BeautifulSoup(r_adresses.content, "html.parser")

# %%
URL
# Out:
# 'https://www.booking.com/hotel/fr/la-lavandiere-bormes-les-mimosas.fr.html'

# %%
soup.findAll('p',{'class',"address address_clean"})[0].find('a').get('data-atlas-latlng')
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Input In [59], in <cell line: 1>()
# ----> 1 soup.findAll('p',{'class',"address address_clean"})[0].find('a').get('data-atlas-latlng')
#
# IndexError: list index out of range

# %%
import requests
from bs4 import BeautifulSoup

URL = 'https://www.booking.com/hotel/fr/la-lavandiere-bormes-les-mimosas.fr.html'
page = requests.get(URL)

soup = BeautifulSoup(page.content, "html.parser")
soup.findAll('p',{'class',"address address_clean"})[0].find('a').get('data-atlas-latlng')
# Out:
# '43.14385490,6.35181560'

# %%
start = time.time()
adresses_json = []

for URL in url_list:
    ID = i
    r_adresses = requests.get(URL)
    soup = BeautifulSoup(r_adresses.content, "html.parser")
    #link = soup.find_all('a', attrs={'id': 'hotel_header'})
    #hotel_loc = soup.find_all('a.jq_tooltip loc_block_link_underline_fix bui-link show_on_map_hp_link show_map_hp_link')
    #hotel_adresse = [x.get('data-atlas-latlng') for x in hotel_loc][0]
    hotel_adresse=soup.findAll('p',{'class',"address address_clean"})[0].find('a').get('data-atlas-latlng')
    #print(hotel_adresse)
    adresse_lat = float(hotel_adresse.split(",")[0])
    adresse_lon = float(hotel_adresse.split(",")[1])
    adresses_json.append([adresse_lat,adresse_lon])
    
adresses_json
end = time.time()
print('Elapsed time: {}'.format(end - start))

# Conversion de notre liste de coordonnées en DF
hotels_lat_lon = DataFrame(adresses_json)
# Out:
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# File /opt/anaconda3/lib/python3.8/site-packages/urllib3/connection.py:174, in HTTPConnection._new_conn(self)
#     173 try:
# --> 174     conn = connection.create_connection(
#     175         (self._dns_host, self.port), self.timeout, **extra_kw
#     176     )
#     178 except SocketTimeout:
#
# File /opt/anaconda3/lib/python3.8/site-packages/urllib3/util/connection.py:72, in create_connection(address, timeout, source_address, socket_options)
#      68     return six.raise_from(
#      69         LocationParseError(u"'%s', label empty or too long" % host), None
#      70     )
# ---> 72 for res in socket.getaddrinfo(host, port, family, socket.SOCK_STREAM):
#      73     af, socktype, proto, canonname, sa = res
#
# File /opt/anaconda3/lib/python3.8/socket.py:918, in getaddrinfo(host, port, family, type, proto, flags)
#     917 addrlist = []
# --> 918 for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
#     919     af, socktype, proto, canonname, sa = res
#
# gaierror: [Errno 8] nodename nor servname provided, or not known
#
# During handling of the above exception, another exception occurred:
#
# NewConnectionError                        Traceback (most recent call last)
# File /opt/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py:703, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     702 # Make the request on the httplib connection object.
# --> 703 httplib_response = self._make_request(
#     704     conn,
#     705     method,
#     706     url,
#     707     timeout=timeout_obj,
#     708     body=body,
#     709     headers=headers,
#     710     chunked=chunked,
#     711 )
#     713 # If we're going to release the connection in ``finally:``, then
#     714 # the response doesn't need to know about the connection. Otherwise
#     715 # it will also try to release it and we'll have a double-release
#     716 # mess.
#
# File /opt/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py:386, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     385 try:
# --> 386     self._validate_conn(conn)
#     387 except (SocketTimeout, BaseSSLError) as e:
#     388     # Py2 raises this as a BaseSSLError, Py3 raises it as socket timeout.
#
# File /opt/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py:1040, in HTTPSConnectionPool._validate_conn(self, conn)
#    1039 if not getattr(conn, "sock", None):  # AppEngine might not have  `.sock`
# -> 1040     conn.connect()
#    1042 if not conn.is_verified:
#
# File /opt/anaconda3/lib/python3.8/site-packages/urllib3/connection.py:358, in HTTPSConnection.connect(self)
#     356 def connect(self):
#     357     # Add certificate verification
# --> 358     conn = self._new_conn()
#     359     hostname = self.host
#
# File /opt/anaconda3/lib/python3.8/site-packages/urllib3/connection.py:186, in HTTPConnection._new_conn(self)
#     185 except SocketError as e:
# --> 186     raise NewConnectionError(
#     187         self, "Failed to establish a new connection: %s" % e
#     188     )
#     190 return conn
#
# NewConnectionError: <urllib3.connection.HTTPSConnection object at 0x7f96c14a91c0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known
#
# During handling of the above exception, another exception occurred:
#
# MaxRetryError                             Traceback (most recent call last)
# File /opt/anaconda3/lib/python3.8/site-packages/requests/adapters.py:440, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     439 if not chunked:
# --> 440     resp = conn.urlopen(
#     441         method=request.method,
#     442         url=url,
#     443         body=request.body,
#     444         headers=request.headers,
#     445         redirect=False,
#     446         assert_same_host=False,
#     447         preload_content=False,
#     448         decode_content=False,
#     449         retries=self.max_retries,
#     450         timeout=timeout
#     451     )
#     453 # Send the request.
#     454 else:
#
# File /opt/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py:785, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     783     e = ProtocolError("Connection aborted.", e)
# --> 785 retries = retries.increment(
#     786     method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#     787 )
#     788 retries.sleep()
#
# File /opt/anaconda3/lib/python3.8/site-packages/urllib3/util/retry.py:592, in Retry.increment(self, method, url, response, error, _pool, _stacktrace)
#     591 if new_retry.is_exhausted():
# --> 592     raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     594 log.debug("Incremented Retry for (url='%s'): %r", url, new_retry)
#
# MaxRetryError: HTTPSConnectionPool(host='www.booking.com', port=443): Max retries exceeded with url: /hotel/fr/paradis.fr.html (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7f96c14a91c0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# Input In [99], in <cell line: 4>()
#       4 for URL in url_list:
#       5     ID = i
# ----> 6     r_adresses = requests.get(URL)
#       7     soup = BeautifulSoup(r_adresses.content, "html.parser")
#       8     #link = soup.find_all('a', attrs={'id': 'hotel_header'})
#       9     #hotel_loc = soup.find_all('a.jq_tooltip loc_block_link_underline_fix bui-link show_on_map_hp_link show_map_hp_link')
#      10     #hotel_adresse = [x.get('data-atlas-latlng') for x in hotel_loc][0]
#
# File /opt/anaconda3/lib/python3.8/site-packages/requests/api.py:75, in get(url, params, **kwargs)
#      64 def get(url, params=None, **kwargs):
#      65     r"""Sends a GET request.
#      66
#      67     :param url: URL for the new :class:`Request` object.
#    (...)
#      72     :rtype: requests.Response
#      73     """
# ---> 75     return request('get', url, params=params, **kwargs)
#
# File /opt/anaconda3/lib/python3.8/site-packages/requests/api.py:61, in request(method, url, **kwargs)
#      57 # By using the 'with' statement we are sure the session is closed, thus we
#      58 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      59 # cases, and look like a memory leak in others.
#      60 with sessions.Session() as session:
# ---> 61     return session.request(method=method, url=url, **kwargs)
#
# File /opt/anaconda3/lib/python3.8/site-packages/requests/sessions.py:529, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     524 send_kwargs = {
#     525     'timeout': timeout,
#     526     'allow_redirects': allow_redirects,
#     527 }
#     528 send_kwargs.update(settings)
# --> 529 resp = self.send(prep, **send_kwargs)
#     531 return resp
#
# File /opt/anaconda3/lib/python3.8/site-packages/requests/sessions.py:645, in Session.send(self, request, **kwargs)
#     642 start = preferred_clock()
#     644 # Send the request
# --> 645 r = adapter.send(request, **kwargs)
#     647 # Total elapsed time of the request (approximately)
#     648 elapsed = preferred_clock() - start
#
# File /opt/anaconda3/lib/python3.8/site-packages/requests/adapters.py:519, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     515     if isinstance(e.reason, _SSLError):
#     516         # This branch is for urllib3 v1.22 and later.
#     517         raise SSLError(e, request=request)
# --> 519     raise ConnectionError(e, request=request)
#     521 except ClosedPoolError as e:
#     522     raise ConnectionError(e, request=request)
#
# ConnectionError: HTTPSConnectionPool(host='www.booking.com', port=443): Max retries exceeded with url: /hotel/fr/paradis.fr.html (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7f96c14a91c0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))

# %%
# On nomme nos colonnes pour pouvoir merger par la suite avec le DF précédent
hotels_lat_lon.columns = ['Latitude', 'Longitude']

hotels_lat_lon.columns

# %%
# Afin de pouvoir merger, il faut une colonne en commun, donc on crée une colonne 'index'
hotels_lat_lon['index'] = hotels_lat_lon.index
hotels_lat_lon

# %%
# On merge notre nouveau DF (lat-long des hotels) avec celui des infos_hotels
booking_adress_result = booking_test.merge(hotels_lat_lon)

# On réorganise l'ordre des colonnes pour un df plus esthétique
booking_adress_result = booking_adress_result.iloc[:, [0,6,7,1,5,2,3,4]]

booking_adress_result

# %%
hotels_column = ['Cities','Hotels']

fig = px.scatter_mapbox(booking_adress_result, 
                        lat="Latitude", 
                        lon="Longitude", 
                        color="note", 
                        size="Longitude", 
                        zoom=3.5, 
                        mapbox_style = "carto-positron",
                        hover_data=hotels_column,
                    )
fig.show()
# Out:
# <iframe
#     scrolling="no"
#     width="100%"
#     height="545px"
#     src="iframe_figures/figure_72.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
import time

# %%
start = time.time()
notes_json = []

for URL in url_list:
    ID = i
    r_adresses = requests.get(URL)
    soup = BeautifulSoup(r_adresses.content, "html.parser")
    elm=soup.findAll('div',{'class',"hotel_large_photp_score featured_review_score js-fly-content-tooltip hp_lightbox_score_block"})
    if len(elm)!=0:
        hotel_note=elm[0].get('data-review-score')

    else :
        hotel_note=' '
    notes_json.append([hotel_note])

#notes_json
end = time.time()
print('Elapsed time: {}'.format(end - start))

# Conversion de notre liste de coordonnées en DF
DF_notes = DataFrame(notes_json)
# Out:
# Elapsed time: 350.2283868789673

# %%
DF_notes.columns = ['note']
DF_notes.columns
# Out:
# Index(['note'], dtype='object')

# %%
booking_adress_result = pd.merge(booking_adress_result,DF_notes, left_index = True, right_index = True)

# %%
booking_adress_result
# Out:
#                                               Hotels URL  \
# index
# 0      https://www.booking.com/hotel/fr/la-lavandiere...
# 1      https://www.booking.com/hotel/fr/homestay-borm...
# 2      https://www.booking.com/hotel/fr/le-petit-atel...
# 3      https://www.booking.com/hotel/fr/bormes-les-mi...
# 4      https://www.booking.com/hotel/fr/paradis.fr.ht...
# ...                                                  ...
# 95     https://www.booking.com/hotel/fr/camille.fr.ht...
# 96     https://www.booking.com/hotel/fr/appartement-c...
# 97     https://www.booking.com/hotel/fr/oh-campings-l...
# 98     https://www.booking.com/hotel/fr/auberge-de-la...
# 99     https://www.booking.com/hotel/fr/l-39-estrambo...
#
#                           Hotels description                    Cities  \
# index
# 0                                                   Bormes les Mimosas
# 1      Bormes-les-Mimosas • 1,1 km du centre        Bormes les Mimosas
# 2                       À 1,5 km de la plage        Bormes les Mimosas
# 3                                        9,6        Bormes les Mimosas
# 4      Bormes-les-Mimosas • 1,2 km du centre        Bormes les Mimosas
# ...                                      ...                       ...
# 95       Hébergement géré par un particulier  Saintes Maries de la mer
# 96                                       7,7  Saintes Maries de la mer
# 97                  Cassis • 100 m du centre  Saintes Maries de la mer
# 98                       À 150 m de la plage  Saintes Maries de la mer
# 99       Hébergement géré par un particulier  Saintes Maries de la mer
#
#                                                   Hotels  \
# index
# 0                                          La Lavandière
# 1                                        HomeStay Bormes
# 2                                       Le petit atelier
# 3      Charmant Appartement avec Vue panoramique Mer ...
# 4                                          Hôtel Paradis
# ...                                                  ...
# 95                                         Hotel Camille
# 96                Appartement calme à deux pas de la mer
# 97                                 Oh! Campings La Brise
# 98                                 Auberge de la Fadaise
# 99                              L'Estrambord de Camargue
#
#                                          Hotel addresses  note    0
# index
# 0                  Bormes-les-Mimosas • 1,1 km du centre   0.0
# 1                                   À 1,5 km de la plage   9.6  9.6
# 2                  Bormes-les-Mimosas • 1,2 km du centre   8.9  8.9
# 3                  Bormes-les-Mimosas • 1,1 km du centre   7.7  7.7
# 4                                   À 1,6 km de la plage   8.0    8
# ...                                                  ...   ...  ...
# 95           Saint-Charles, Marseille • 0,7 km du centre   7.9  7.9
# 96            Prado - Périer, Marseille • 2 km du centre   8.2  8.2
# 97     Vieux Port - La Canebière, Marseille • 1,6 km ...   7.6  7.6
# 98           Saint-Charles, Marseille • 0,5 km du centre   8.3  8.3
# 99     Vieux Port - La Canebière, Marseille • 0,5 km ...   8.4  8.4
#
# [100 rows x 7 columns]

# %%
booking_adress_result["note"]=booking_adress_result["note"].replace('None',0).replace('',0).apply(lambda x : float(x))

# %%
booking_adress_result
# Out:
#                                               Hotels URL  \
# index
# 0      https://www.booking.com/hotel/fr/la-lavandiere...
# 1      https://www.booking.com/hotel/fr/homestay-borm...
# 2      https://www.booking.com/hotel/fr/le-petit-atel...
# 3      https://www.booking.com/hotel/fr/bormes-les-mi...
# 4      https://www.booking.com/hotel/fr/paradis.fr.ht...
# ...                                                  ...
# 95     https://www.booking.com/hotel/fr/camille.fr.ht...
# 96     https://www.booking.com/hotel/fr/appartement-c...
# 97     https://www.booking.com/hotel/fr/oh-campings-l...
# 98     https://www.booking.com/hotel/fr/auberge-de-la...
# 99     https://www.booking.com/hotel/fr/l-39-estrambo...
#
#                           Hotels description                    Cities  \
# index
# 0                                                   Bormes les Mimosas
# 1      Bormes-les-Mimosas • 1,1 km du centre        Bormes les Mimosas
# 2                       À 1,5 km de la plage        Bormes les Mimosas
# 3                                        9,6        Bormes les Mimosas
# 4      Bormes-les-Mimosas • 1,2 km du centre        Bormes les Mimosas
# ...                                      ...                       ...
# 95       Hébergement géré par un particulier  Saintes Maries de la mer
# 96                                       7,7  Saintes Maries de la mer
# 97                  Cassis • 100 m du centre  Saintes Maries de la mer
# 98                       À 150 m de la plage  Saintes Maries de la mer
# 99       Hébergement géré par un particulier  Saintes Maries de la mer
#
#                                                   Hotels  \
# index
# 0                                          La Lavandière
# 1                                        HomeStay Bormes
# 2                                       Le petit atelier
# 3      Charmant Appartement avec Vue panoramique Mer ...
# 4                                          Hôtel Paradis
# ...                                                  ...
# 95                                         Hotel Camille
# 96                Appartement calme à deux pas de la mer
# 97                                 Oh! Campings La Brise
# 98                                 Auberge de la Fadaise
# 99                              L'Estrambord de Camargue
#
#                                          Hotel addresses  note    0
# index
# 0                  Bormes-les-Mimosas • 1,1 km du centre   0.0
# 1                                   À 1,5 km de la plage   9.6  9.6
# 2                  Bormes-les-Mimosas • 1,2 km du centre   8.9  8.9
# 3                  Bormes-les-Mimosas • 1,1 km du centre   7.7  7.7
# 4                                   À 1,6 km de la plage   8.0    8
# ...                                                  ...   ...  ...
# 95           Saint-Charles, Marseille • 0,7 km du centre   7.9  7.9
# 96            Prado - Périer, Marseille • 2 km du centre   8.2  8.2
# 97     Vieux Port - La Canebière, Marseille • 1,6 km ...   7.6  7.6
# 98           Saint-Charles, Marseille • 0,5 km du centre   8.3  8.3
# 99     Vieux Port - La Canebière, Marseille • 0,5 km ...   8.4  8.4
#
# [100 rows x 7 columns]

# %%
hotels_column = ['Cities','Hotels']

fig = px.scatter_mapbox(booking_adress_result, 
                        lat="Latitude", 
                        lon="Longitude", 
                        color="note", 
                        size="Longitude", 
                        zoom=3.5, 
                        mapbox_style = "carto-positron",
                        hover_data=hotels_column,
                    )
fig.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [96], in <cell line: 3>()
#       1 hotels_column = ['Cities','Hotels']
# ----> 3 fig = px.scatter_mapbox(booking_adress_result,
#       4                         lat="Latitude",
#       5                         lon="Longitude",
#       6                         color="note",
#       7                         size="Longitude",
#       8                         zoom=3.5,
#       9                         mapbox_style = "carto-positron",
#      10                         hover_data=hotels_column,
#      11                     )
#      12 fig.show()
#
# File /opt/anaconda3/lib/python3.8/site-packages/plotly/express/_chart_types.py:1126, in scatter_mapbox(data_frame, lat, lon, color, text, hover_name, hover_data, custom_data, size, animation_frame, animation_group, category_orders, labels, color_discrete_sequence, color_discrete_map, color_continuous_scale, range_color, color_continuous_midpoint, opacity, size_max, zoom, center, mapbox_style, title, template, width, height)
#    1093 def scatter_mapbox(
#    1094     data_frame=None,
#    1095     lat=None,
#    (...)
#    1120     height=None,
#    1121 ):
#    1122     """
#    1123     In a Mapbox scatter plot, each row of `data_frame` is represented by a
#    1124     symbol mark on a Mapbox map.
#    1125     """
# -> 1126     return make_figure(args=locals(), constructor=go.Scattermapbox)
#
# File /opt/anaconda3/lib/python3.8/site-packages/plotly/express/_core.py:1861, in make_figure(args, constructor, trace_patch, layout_patch)
#    1858 layout_patch = layout_patch or {}
#    1859 apply_default_cascade(args)
# -> 1861 args = build_dataframe(args, constructor)
#    1862 if constructor in [go.Treemap, go.Sunburst] and args["path"] is not None:
#    1863     args = process_dataframe_hierarchy(args)
#
# File /opt/anaconda3/lib/python3.8/site-packages/plotly/express/_core.py:1377, in build_dataframe(args, constructor)
#    1374     args["color"] = None
#    1375 # now that things have been prepped, we do the systematic rewriting of `args`
# -> 1377 df_output, wide_id_vars = process_args_into_dataframe(
#    1378     args, wide_mode, var_name, value_name
#    1379 )
#    1381 # now that `df_output` exists and `args` contains only references, we complete
#    1382 # the special-case and wide-mode handling by further rewriting args and/or mutating
#    1383 # df_output
#    1385 count_name = _escape_col_name(df_output, "count", [var_name, value_name])
#
# File /opt/anaconda3/lib/python3.8/site-packages/plotly/express/_core.py:1183, in process_args_into_dataframe(args, wide_mode, var_name, value_name)
#    1181         if argument == "index":
#    1182             err_msg += "\n To use the index, pass it in directly as `df.index`."
# -> 1183         raise ValueError(err_msg)
#    1184 elif length and len(df_input[argument]) != length:
#    1185     raise ValueError(
#    1186         "All arguments should have the same length. "
#    1187         "The length of column argument `df[%s]` is %d, whereas the "
#    (...)
#    1194         )
#    1195     )
#
# ValueError: Value of 'size' is not the name of a column in 'data_frame'. Expected one of ['Hotels URL', 'Hotels description', 'Cities', 'Hotels', 'Hotel addresses', 'note', 0] but received: Longitude

# %%
booking_adress_result
# Out:
#     index                                         Hotels URL  \
# 0       0  https://www.booking.com/hotel/fr/la-lavandiere...
# 1       1  https://www.booking.com/hotel/fr/homestay-borm...
# 2       2  https://www.booking.com/hotel/fr/le-petit-atel...
# 3       3  https://www.booking.com/hotel/fr/bormes-les-mi...
# 4       4  https://www.booking.com/hotel/fr/paradis.fr.ht...
# ..    ...                                                ...
# 95     95  https://www.booking.com/hotel/fr/camille.fr.ht...
# 96     96  https://www.booking.com/hotel/fr/appartement-c...
# 97     97  https://www.booking.com/hotel/fr/oh-campings-l...
# 98     98  https://www.booking.com/hotel/fr/auberge-de-la...
# 99     99  https://www.booking.com/hotel/fr/l-39-estrambo...
#
#                        Hotels description                    Cities  \
# 0                                                Bormes les Mimosas
# 1   Bormes-les-Mimosas • 1,1 km du centre        Bormes les Mimosas
# 2                    À 1,5 km de la plage        Bormes les Mimosas
# 3                                     9,6        Bormes les Mimosas
# 4   Bormes-les-Mimosas • 1,2 km du centre        Bormes les Mimosas
# ..                                    ...                       ...
# 95    Hébergement géré par un particulier  Saintes Maries de la mer
# 96                                    7,7  Saintes Maries de la mer
# 97               Cassis • 100 m du centre  Saintes Maries de la mer
# 98                    À 150 m de la plage  Saintes Maries de la mer
# 99    Hébergement géré par un particulier  Saintes Maries de la mer
#
#                                                Hotels  \
# 0                                       La Lavandière
# 1                                     HomeStay Bormes
# 2                                    Le petit atelier
# 3   Charmant Appartement avec Vue panoramique Mer ...
# 4                                       Hôtel Paradis
# ..                                                ...
# 95                                      Hotel Camille
# 96             Appartement calme à deux pas de la mer
# 97                              Oh! Campings La Brise
# 98                              Auberge de la Fadaise
# 99                           L'Estrambord de Camargue
#
#                                       Hotel addresses  note
# 0               Bormes-les-Mimosas • 1,1 km du centre   0.0
# 1                                À 1,5 km de la plage   9.6
# 2               Bormes-les-Mimosas • 1,2 km du centre   8.9
# 3               Bormes-les-Mimosas • 1,1 km du centre   7.7
# 4                                À 1,6 km de la plage   8.0
# ..                                                ...   ...
# 95        Saint-Charles, Marseille • 0,7 km du centre   7.9
# 96         Prado - Périer, Marseille • 2 km du centre   8.2
# 97  Vieux Port - La Canebière, Marseille • 1,6 km ...   7.6
# 98        Saint-Charles, Marseille • 0,5 km du centre   8.3
# 99  Vieux Port - La Canebière, Marseille • 0,5 km ...   8.4
#
# [100 rows x 7 columns]

# %%
booking_adress_result.set_index('index',inplace=True)

# %%
a=booking_adress_result.groupby('Cities').mean().sort_values('note',ascending=False)
a
# Out:
#                            note
# Cities
# Cassis                    8.385
# Saintes Maries de la mer  8.105
# Aix en Provence           7.930
# Bormes les Mimosas        7.645
# Marseille                 7.480

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
fig;ax = plt.subplots(figsize=(20,10))
ax=sns.barplot(x=a.index,y=a["note"])
plt.setp(ax.get_xticklabels(), rotation=30)
plt.show()

# %%
from geolocation.main import Geolocation
geo_location = Geolocation()
location = geo_location.get_geolocation()
print(location)

# %%
#dataset.to_csv(csv_geolocalisation, sep=‘\t’)
lat_lon.to_csv('geolocalisation.csv',encoding='utf-8',index=False)
final_result.to_csv('meteo.csv',encoding='utf-8',index=False)
booking_test.to_csv('booking_test.csv',encoding='utf-8',index=False)
booking_adress_result.to_csv('booking_adress_result.csv',encoding='utf-8',index=False, sep='\t')

# %%
# !pip install boto3 -q

import boto3

# %%
session = boto3.Session(aws_access_key_id= 'AKIARSCTXCHBRSH442PH',
                        aws_secret_access_key= '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')

# %%
s3 = session.resource("s3")
bucket = s3.create_bucket(Bucket="api-kayak-project")

# %%
import pandas as pd

data = pd.read_csv('meteo.csv')
csv = data.to_csv()
put_object = bucket.put_object(Key="meteo.csv", Body=csv)

# %%
data = pd.read_csv('booking_test.csv')
csv = data.to_csv()
put_object = bucket.put_object(Key="booking_test.csv", Body=csv)

# %%
data = pd.read_csv('booking_adress_result.csv', delimiter='tab')
csv = data.to_csv()
put_object = bucket.put_object(Key="booking_adress_result.csv", Body=csv)

# %%
# !pip install psycopg2-binary -q
from sqlalchemy import create_engine
engine = create_engine('postgresql+psycopg2://postgres:berechit95170!@database-1.cvqthc8jtrkz.eu-west-3.rds.amazonaws.com/postgres', echo=True)

# %%
meteo = pd.read_csv('meteo.csv')
booking_hotels = pd.read_csv('booking_test.csv')

# %%
meteo.to_sql('35cities_weather', engine)
booking_hotels.to_sql('5best_cities_hotels',engine)
