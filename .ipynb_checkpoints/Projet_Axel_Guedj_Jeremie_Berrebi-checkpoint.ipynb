# %% [markdown]
# # Projet Webscraping Axel & Jeremie

# %% [markdown]
# Importation des librairies

# %%
import requests
import pandas as pd
import json
from datetime import datetime
from datetime import date
from bs4 import BeautifulSoup
import numpy as np

# %% [markdown]
# Premier test de requete sur l'api sur une seule ville (Paris) voir ce que ça donne

# %%
r = requests.get("https://nominatim.openstreetmap.org/?q=Paris&format=json")
r.json()
# Out:
# [{'place_id': 297417241,
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#   'osm_type': 'relation',
#   'osm_id': 7444,
#   'boundingbox': ['48.8155755', '48.902156', '2.224122', '2.4697602'],
#   'lat': '48.8588897',
#   'lon': '2.3200410217200766',
#   'display_name': 'Paris, Île-de-France, France métropolitaine, France',
#   'class': 'boundary',
#   'type': 'administrative',
#   'importance': 0.9417101715588673,
#   'icon': 'https://nominatim.openstreetmap.org/ui/mapicons/poi_boundary_administrative.p.20.png'},
#  {'place_id': 298001902,
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#   'osm_type': 'relation',
#   'osm_id': 71525,
#   'boundingbox': ['48.8155755', '48.902156', '2.224122', '2.4697602'],
#   'lat': '48.8534951',
#   'lon': '2.3483915',
#   'display_name': 'Paris, Île-de-France, France métropolitaine, France',
#   'class': 'boundary',
#   'type': 'administrative',
#   'importance': 0.9417101715588673,
#   'icon': 'https://nominatim.openstreetmap.org/ui/mapicons/poi_boundary_administrative.p.20.png'},
#  {'place_id': 297598847,
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#   'osm_type': 'relation',
#   'osm_id': 115357,
#   'boundingbox': ['33.6206345', '33.7383866', '-95.6279396', '-95.4354115'],
#   'lat': '33.6617962',
#   'lon': '-95.555513',
#   'display_name': 'Paris, Lamar County, Texas, 75460, United States',
#   'class': 'boundary',
#   'type': 'administrative',
#   'importance': 0.6061645097134651,
#   'icon': 'https://nominatim.openstreetmap.org/ui/mapicons/poi_boundary_administrative.p.20.png'},
#  {'place_id': 298261832,
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#   'osm_type': 'relation',
#   'osm_id': 130722,
#   'boundingbox': ['38.164922', '38.238271', '-84.307326', '-84.232089'],
#   'lat': '38.2097987',
#   'lon': '-84.2529869',
#   'display_name': 'Paris, Bourbon County, Kentucky, 40361, United States',
#   'class': 'boundary',
#   'type': 'administrative',
#   'importance': 0.5586843760767399,
#   'icon': 'https://nominatim.openstreetmap.org/ui/mapicons/poi_boundary_administrative.p.20.png'},
#  {'place_id': 298345402,
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#   'osm_type': 'relation',
#   'osm_id': 1641193,
#   'boundingbox': ['48.8155755', '48.902156', '2.224122', '2.4697602'],
#   'lat': '48.8588897',
#   'lon': '2.3200410217200766',
#   'display_name': 'Paris, Île-de-France, France métropolitaine, France',
#   'class': 'boundary',
#   'type': 'administrative',
#   'importance': 0.5383953917728153,
#   'icon': 'https://nominatim.openstreetmap.org/ui/mapicons/poi_boundary_administrative.p.20.png'},
#  {'place_id': 297561157,
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#   'osm_type': 'relation',
#   'osm_id': 197171,
#   'boundingbox': ['36.266003', '36.329016', '-88.367113', '-88.265067'],
#   'lat': '36.3019461',
#   'lon': '-88.3258578',
#   'display_name': 'Paris, Henry County, West Tennessee, Tennessee, United States',
#   'class': 'boundary',
#   'type': 'administrative',
#   'importance': 0.5250690427980547,
#   'icon': 'https://nominatim.openstreetmap.org/ui/mapicons/poi_boundary_administrative.p.20.png'},
#  {'place_id': 297651784,
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#   'osm_type': 'relation',
#   'osm_id': 126166,
#   'boundingbox': ['39.581493', '39.649981', '-87.721046', '-87.649203'],
#   'lat': '39.611146',
#   'lon': '-87.6961374',
#   'display_name': 'Paris, Edgar County, Illinois, 61944, United States',
#   'class': 'boundary',
#   'type': 'administrative',
#   'importance': 0.5244799592274194,
#   'icon': 'https://nominatim.openstreetmap.org/ui/mapicons/poi_boundary_administrative.p.20.png'},
#  {'place_id': 299079910,
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#   'osm_type': 'relation',
#   'osm_id': 12165996,
#   'boundingbox': ['44.1754185', '44.3124081', '-70.566213', '-70.414966'],
#   'lat': '44.259954',
#   'lon': '-70.500641',
#   'display_name': 'Paris, Oxford County, Maine, 04281, United States',
#   'class': 'boundary',
#   'type': 'administrative',
#   'importance': 0.5190701377223524,
#   'icon': 'https://nominatim.openstreetmap.org/ui/mapicons/poi_boundary_administrative.p.20.png'},
#  {'place_id': 298902894,
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#   'osm_type': 'relation',
#   'osm_id': 6678712,
#   'boundingbox': ['35.2681485', '35.3065882', '-93.761965', '-93.6755169'],
#   'lat': '35.2920325',
#   'lon': '-93.7299173',
#   'display_name': 'Paris, Logan County, Arkansas, 72855, United States',
#   'class': 'boundary',
#   'type': 'administrative',
#   'importance': 0.5136706902956424,
#   'icon': 'https://nominatim.openstreetmap.org/ui/mapicons/poi_boundary_administrative.p.20.png'},
#  {'place_id': 298421083,
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#   'osm_type': 'relation',
#   'osm_id': 3669583,
#   'boundingbox': ['42.935665', '43.023448', '-75.327514', '-75.207338'],
#   'lat': '43.0006253',
#   'lon': '-75.3137775',
#   'display_name': 'Town of Paris, Oneida County, New York, United States',
#   'class': 'boundary',
#   'type': 'administrative',
#   'importance': 0.5048929025730893,
#   'icon': 'https://nominatim.openstreetmap.org/ui/mapicons/poi_boundary_administrative.p.20.png'}]

# %% [markdown]
# Récupéré son adresse IP automatiquement puis trouver l'endroit sa localisation.

# %% [markdown]
# On envoie une requete a une api apify pour récupérer son adresse ip.

# %% [markdown]
# ### Adresse Ip

# %%
import requests
ip = requests.get('https://api.ipify.org').text
# Out:
# 176.138.138.120

# %% [markdown]
# On trouve sa localisation par rapport a cette adresse ip

# %% [markdown]
# On a pas réussi a trouver de bon outil pour pouvoir récupéré par rapport a l'ip la localisation de l'appareil qui utilise l'outil. On passe donc par un site et on scrap en utilisant Sélénium son résultat. Bien que le résulat donné peut ne pas être assez précis, cela nous suffira pour calculer la distance entre la personne et l'hotel.

# %%
from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager
import time

# %%
options = webdriver.ChromeOptions() 
options.add_argument('-headless') 
options.add_argument('-no-sandbox') 
options.add_argument('-disable-dev-shm-usage') 
options.add_argument("enable-automation") 
options.add_argument("--window-size=1920,1080") 
options.add_argument("--disable-extensions") 
options.add_argument("--dns-prefetch-disable") 
options.add_argument("--disable-gpu")
#driver = webdriver.Chrome('/usr/local/bin/chromedriver', options = options)
driver = webdriver.Chrome('/Users/macbook/.wdm/drivers/chromedriver/mac64/108.0.5359.71/chromedriver', options = options)
#driver  = webdriver.Chrome(ChromeDriverManager().install())

web_link ="https://mon-adresse-ip.fr/localiser-une-adresse-ip/"
driver.get(web_link)
#On cherche la barre de recherche
search_bar=driver.find_element_by_xpath('/html/body/div[2]/section[1]/div/div/div[1]/form/div/div[1]/input')
#on rempli la barre de recherche par l'adresse Ip
search_bar.send_keys(ip)
bouton_research=driver.find_element_by_xpath("/html/body/div[3]/section[1]/div/div/div[1]/form/div/div[2]/button")
#On clique sur le bouton rechercher
bouton_research.click()
time.sleep(10)

# %% [markdown]
# ### Localisation de la personne

# %% [markdown]
# Localisation ville

# %%
adresse = driver.find_element_by_xpath("/html/body/div[3]/section[1]/div/div/div[2]").text
adresse= adresse.split("à ")[1]
adresse
# Out:
# 'Le Perreux-sur-Marne, France'

# %% [markdown]
# Localisation coordonnée

# %%
from geopy.geocoders import Nominatim
geolocator = Nominatim(user_agent="geoapiExercises")
location = geolocator.geocode(adresse)
print(location.latitude, location.longitude)
# Out:
# 48.840627 2.5077111

# %% [markdown]
# ## Scrapper les 35 villes les plus touristiques :

# %% [markdown]
# On veut se concentrer sur les meilleurs villes, les villes les plus touristiques de france. D'après le <a href="https://one-week-in.com/35-cities-to-visit-in-france/" target="_blank">One Week In.com</a> On a les 35 villes les plus visité de France. On va les scrapper

# %%
url        = "https://one-week-in.com/35-cities-to-visit-in-france/"
requesting = requests.get(url)
soup       = BeautifulSoup(requesting.content, "html.parser")

# %% [markdown]
# ### Liste des villes à étudier sur le projet

# %%
liste_element=soup.findAll('ol')[0].findAll('a')
cities_list = [place.text for place in liste_element]
cities_list
# Out:
# ['Mont Saint Michel',
#  'St Malo',
#  'Bayeux',
#  'Le Havre',
#  'Rouen',
#  'Paris',
#  'Amiens',
#  'Lille',
#  'Strasbourg',
#  'Chateau du Haut Koenigsbourg',
#  'Colmar',
#  'Eguisheim',
#  'Besancon',
#  'Dijon',
#  'Annecy',
#  'Grenoble',
#  'Lyon',
#  'Verdon Gorge',
#  'Bormes les Mimosas',
#  'Cassis',
#  'Marseille',
#  'Aix en Provence',
#  'Avignon',
#  'Uzès',
#  'Nímes',
#  'Aigues Mortes',
#  'Saintes Maries de la mer',
#  'Collioure',
#  'Carcassonne',
#  'Ariege',
#  'Toulouse',
#  'Montauban',
#  'Biarritz',
#  'Bayonne',
#  'La Rochelle']

# %% [markdown]
# On applique maintenant sur la cities_list grâce à une loop pour obtenir les coordonées des villes grace a une API nominatim.openstreetmap

# %%
city_coordinate = []

for gps in cities_list:
    r = requests.get("https://nominatim.openstreetmap.org/search?q={}&format=json".format(gps))
    dic_gps = r.json()
    city_lat = float(dic_gps[0]['lat'])
    city_lon = float(dic_gps[0]['lon'])
    city_coordinate.append([city_lat,city_lon])

# %% [markdown]
# Petit visu du résultat des latitudes et longitudes obtenus

# %%
city_coordinate
# Out:
# [[48.6359541, -1.511459954959514],
#  [48.649518, -2.0260409],
#  [49.2764624, -0.7024738],
#  [49.4938975, 0.1079732],
#  [49.4404591, 1.0939658],
#  [48.8588897, 2.3200410217200766],
#  [49.8941708, 2.2956951],
#  [50.6365654, 3.0635282],
#  [48.584614, 7.7507127],
#  [48.249489800000006, 7.34429620253195],
#  [48.0777517, 7.3579641],
#  [48.0447968, 7.3079618],
#  [47.2380222, 6.0243622],
#  [47.3215806, 5.0414701],
#  [45.8992348, 6.1288847],
#  [45.1875602, 5.7357819],
#  [45.7578137, 4.8320114],
#  [43.7496562, 6.3285616],
#  [43.1506968, 6.3419285],
#  [43.2140359, 5.5396318],
#  [43.2961743, 5.3699525],
#  [43.5298424, 5.4474738],
#  [43.9492493, 4.8059012],
#  [44.0121279, 4.4196718],
#  [43.8374249, 4.3600687],
#  [43.5658225, 4.1912837],
#  [43.4522771, 4.4287172],
#  [42.52505, 3.0831554],
#  [43.2130358, 2.3491069],
#  [42.9455368, 1.4065544156065486],
#  [43.6044622, 1.4442469],
#  [44.0175835, 1.3549991],
#  [43.471143749999996, -1.552726590666314],
#  [43.4945144, -1.4736657],
#  [46.1591126, -1.1520434]]

# %% [markdown]
# On veut maintenant transformer notre cities_list en DataFrame et y ajouter les lat/lon concernées

# %%
df = pd.DataFrame(cities_list)
df.columns = ['Cities']
df.head()
# Out:
#               Cities
# 0  Mont Saint Michel
# 1            St Malo
# 2             Bayeux
# 3           Le Havre
# 4              Rouen

# %% [markdown]
# Comme pour la liste des villes, on convertit nos colonnes lat et lon (listes) en Dataframe

# %%
lat_lon = DataFrame(city_coordinate)
lat_lon.columns = ['Latitude', 'Longitude']

lat_lon.head()
# Out:
#     Latitude  Longitude
# 0  48.635954  -1.511460
# 1  48.649518  -2.026041
# 2  49.276462  -0.702474
# 3  49.493898   0.107973
# 4  49.440459   1.093966

# %% [markdown]
# On associe notre DF lat_lon avec la colonne du nom des villes afin d'en faire un seul DF

# %%
lat_lon['Cities']=cities_list

# %%
lat_lon.head()
# Out:
#     Latitude  Longitude             Cities
# 0  48.635954  -1.511460  Mont Saint Michel
# 1  48.649518  -2.026041            St Malo
# 2  49.276462  -0.702474             Bayeux
# 3  49.493898   0.107973           Le Havre
# 4  49.440459   1.093966              Rouen

# %% [markdown]
# On réorganise l'ordre des colonnes pour un df plus esthétique

# %%
lat_lon = lat_lon.iloc[:, [2,0,1]]
lat_lon
# Out:
#                           Cities   Latitude  Longitude
# 0              Mont Saint Michel  48.635954  -1.511460
# 1                        St Malo  48.649518  -2.026041
# 2                         Bayeux  49.276462  -0.702474
# 3                       Le Havre  49.493898   0.107973
# 4                          Rouen  49.440459   1.093966
# 5                          Paris  48.858890   2.320041
# 6                         Amiens  49.894171   2.295695
# 7                          Lille  50.636565   3.063528
# 8                     Strasbourg  48.584614   7.750713
# 9   Chateau du Haut Koenigsbourg  48.249490   7.344296
# 10                        Colmar  48.077752   7.357964
# 11                     Eguisheim  48.044797   7.307962
# 12                      Besancon  47.238022   6.024362
# 13                         Dijon  47.321581   5.041470
# 14                        Annecy  45.899235   6.128885
# 15                      Grenoble  45.187560   5.735782
# 16                          Lyon  45.757814   4.832011
# 17              Gorges du Verdon  43.749656   6.328562
# 18            Bormes les Mimosas  43.150697   6.341928
# 19                        Cassis  43.214036   5.539632
# 20                     Marseille  43.296174   5.369953
# 21               Aix en Provence  43.529842   5.447474
# 22                       Avignon  43.949249   4.805901
# 23                          Uzes  44.012128   4.419672
# 24                         Nimes  43.837425   4.360069
# 25                 Aigues Mortes  43.565823   4.191284
# 26      Saintes Maries de la mer  43.452277   4.428717
# 27                     Collioure  42.525050   3.083155
# 28                   Carcassonne  43.213036   2.349107
# 29                        Ariege  42.945537   1.406554
# 30                      Toulouse  43.604462   1.444247
# 31                     Montauban  44.017584   1.354999
# 32                      Biarritz  43.471144  -1.552727
# 33                       Bayonne  43.494514  -1.473666
# 34                   La Rochelle  46.159113  -1.152043

# %%
for x in lat_lon:
    print(x)
# Out:
# Cities
# Latitude
# Longitude

# %%
# On récolte les colonnes importantes qui vont nous servir pour la future boucle

Latitude = lat_lon['Latitude'].tolist()
Longitude = lat_lon['Longitude'].tolist()

# Petit test sur les listes Latitude et Longitude voir ce que ça donnerait dans une loop
# On voit que la loop passe bien sur les 35 lignes concernées, on peut maintenant l'appliquer sur notre
# nouvel request (API météo)

for i in range(len(Latitude)):
    print(Latitude[i], Longitude[i])
# Out:
# 48.6359541 -1.511459954959514
# 48.649518 -2.0260409
# 49.2764624 -0.7024738
# 49.4938975 0.1079732
# 49.4404591 1.0939658
# 48.8588897 2.3200410217200766
# 49.8941708 2.2956951
# 50.6365654 3.0635282
# 48.584614 7.7507127
# 48.249489800000006 7.34429620253195
# 48.0777517 7.3579641
# 48.0447968 7.3079618
# 47.2380222 6.0243622
# 47.3215806 5.0414701
# 45.8992348 6.1288847
# 45.1875602 5.7357819
# 45.7578137 4.8320114
# 43.7496562 6.3285616
# 43.1506968 6.3419285
# 43.2140359 5.5396318
# 43.2961743 5.3699525
# 43.5298424 5.4474738
# 43.9492493 4.8059012
# 44.0121279 4.4196718
# 43.8374249 4.3600687
# 43.5658225 4.1912837
# 43.4522771 4.4287172
# 42.52505 3.0831554
# 43.2130358 2.3491069
# 42.9455368 1.4065544156065486
# 43.6044622 1.4442469
# 44.0175835 1.3549991
# 43.471143749999996 -1.552726590666314
# 43.4945144 -1.4736657
# 46.1591126 -1.1520434

# %%
# Créer une boucle pour répéter la météo sur les 35 villes de la 'cities_list' grâce à l'API OpenWeatherMap

# Clé de l'API OpenWeatherMap
api_key = "918a35b1534d62a40849c70979c2e98b"

weather_json = []

for i in range(len(Latitude)):
    print(Latitude[i], Longitude[i])
    # Le request qu'on fera agir sur l'URL de l'API
    r_weather = requests.get("https://api.openweathermap.org/data/2.5/onecall?lat={}&lon={}&units=metric&exclude=minutely,hourly,alerts&appid={}".format(Latitude[i], Longitude[i], api_key))  
    
    # Faire un requests pour essayer de saisir le JSON sur l'URL 
    dic_weather = r_weather.json()
    
    # Une nouvelle boucle est nécessaire pour répéter cette request maintenant sur 7j
    for week in range(1,8):
        Lat_ = float(lat_lon['Latitude'][i])
        Lon_ = float(lat_lon['Longitude'][i])
        Météo = dic_weather["daily"][week]["weather"][0]["description"]
        Température = dic_weather["current"]["temp"]
        Humidité = dic_weather["daily"][week]["humidity"]
        Vent = dic_weather["daily"][week]["wind_speed"]
        Date = dic_weather['daily'][week]['dt']
        Timestamp = dic_weather['daily'][week]['dt']
        Date = datetime.fromtimestamp(int(Timestamp))

             # Dictionnaire pour la météo
        dictionnaire = {'Latitude': Lat_,
                        'Longitude': Lon_,
                        'Weather': Météo,
                        'Temperature': Température,
                        'Humidity': Humidité,
                        'Wind': Vent,
                        'Date': Date

                        }

    # récupération de tous les résultats
        weather_json.append(dictionnaire)
        

    

weather_json
# Out:
# 48.6359541 -1.511459954959514
# 48.649518 -2.0260409
# 49.2764624 -0.7024738
# 49.4938975 0.1079732
# 49.4404591 1.0939658
# 48.8588897 2.3200410217200766
# 49.8941708 2.2956951
# 50.6365654 3.0635282
# 48.584614 7.7507127
# 48.249489800000006 7.34429620253195
# 48.0777517 7.3579641
# 48.0447968 7.3079618
# 47.2380222 6.0243622
# 47.3215806 5.0414701
# 45.8992348 6.1288847
# 45.1875602 5.7357819
# 45.7578137 4.8320114
# 43.7496562 6.3285616
# 43.1506968 6.3419285
# 43.2140359 5.5396318
# 43.2961743 5.3699525
# 43.5298424 5.4474738
# 43.9492493 4.8059012
# 44.0121279 4.4196718
# 43.8374249 4.3600687
# 43.5658225 4.1912837
# 43.4522771 4.4287172
# 42.52505 3.0831554
# 43.2130358 2.3491069
# 42.9455368 1.4065544156065486
# 43.6044622 1.4442469
# 44.0175835 1.3549991
# 43.471143749999996 -1.552726590666314
# 43.4945144 -1.4736657
# 46.1591126 -1.1520434
# [{'Latitude': 48.6359541,
#   'Longitude': -1.511459954959514,
#   'Weather': 'moderate rain',
#   'Temperature': 8.39,
#   'Humidity': 81,
#   'Wind': 9.82,
#   'Date': datetime.datetime(2023, 1, 12, 13, 0)},
#  {'Latitude': 48.6359541,
#   'Longitude': -1.511459954959514,
#   'Weather': 'light rain',
#   'Temperature': 8.39,
#   'Humidity': 77,
#   'Wind': 8.17,
#   'Date': datetime.datetime(2023, 1, 13, 13, 0)},
#  {'Latitude': 48.6359541,
#   'Longitude': -1.511459954959514,
#   'Weather': 'moderate rain',
#   'Temperature': 8.39,
#   'Humidity': 93,
#   'Wind': 10.1,
#   'Date': datetime.datetime(2023, 1, 14, 13, 0)},
#  {'Latitude': 48.6359541,
#   'Longitude': -1.511459954959514,
#   'Weather': 'light rain',
#   'Temperature': 8.39,
#   'Humidity': 71,
#   'Wind': 8.35,
#   'Date': datetime.datetime(2023, 1, 15, 13, 0)},
#  {'Latitude': 48.6359541,
#   'Longitude': -1.511459954959514,
#   'Weather': 'moderate rain',
#   'Temperature': 8.39,
#   'Humidity': 90,
#   'Wind': 14.03,
#   'Date': datetime.datetime(2023, 1, 16, 13, 0)},
#  {'Latitude': 48.6359541,
#   'Longitude': -1.511459954959514,
#   'Weather': 'light rain',
#   'Temperature': 8.39,
#   'Humidity': 86,
#   'Wind': 11.27,
#   'Date': datetime.datetime(2023, 1, 17, 13, 0)},
#  {'Latitude': 48.6359541,
#   'Longitude': -1.511459954959514,
#   'Weather': 'rain and snow',
#   'Temperature': 8.39,
#   'Humidity': 80,
#   'Wind': 11.23,
#   'Date': datetime.datetime(2023, 1, 18, 13, 0)},
#  {'Latitude': 48.649518,
#   'Longitude': -2.0260409,
#   'Weather': 'moderate rain',
#   'Temperature': 8.13,
#   'Humidity': 78,
#   'Wind': 11.12,
#   'Date': datetime.datetime(2023, 1, 12, 13, 0)},
#  {'Latitude': 48.649518,
#   'Longitude': -2.0260409,
#   'Weather': 'broken clouds',
#   'Temperature': 8.13,
#   'Humidity': 75,
#   'Wind': 10.17,
#   'Date': datetime.datetime(2023, 1, 13, 13, 0)},
#  {'Latitude': 48.649518,
#   'Longitude': -2.0260409,
#   'Weather': 'moderate rain',
#   'Temperature': 8.13,
#   'Humidity': 88,
#   'Wind': 11.38,
#   'Date': datetime.datetime(2023, 1, 14, 13, 0)},
#  {'Latitude': 48.649518,
#   'Longitude': -2.0260409,
#   'Weather': 'light rain',
#   'Temperature': 8.13,
#   'Humidity': 66,
#   'Wind': 10.36,
#   'Date': datetime.datetime(2023, 1, 15, 13, 0)},
#  {'Latitude': 48.649518,
#   'Longitude': -2.0260409,
#   'Weather': 'moderate rain',
#   'Temperature': 8.13,
#   'Humidity': 88,
#   'Wind': 16.73,
#   'Date': datetime.datetime(2023, 1, 16, 13, 0)},
#  {'Latitude': 48.649518,
#   'Longitude': -2.0260409,
#   'Weather': 'light rain',
#   'Temperature': 8.13,
#   'Humidity': 78,
#   'Wind': 12.98,
#   'Date': datetime.datetime(2023, 1, 17, 13, 0)},
#  {'Latitude': 48.649518,
#   'Longitude': -2.0260409,
#   'Weather': 'rain and snow',
#   'Temperature': 8.13,
#   'Humidity': 77,
#   'Wind': 13.99,
#   'Date': datetime.datetime(2023, 1, 18, 13, 0)},
#  {'Latitude': 49.2764624,
#   'Longitude': -0.7024738,
#   'Weather': 'moderate rain',
#   'Temperature': 9.14,
#   'Humidity': 81,
#   'Wind': 11.89,
#   'Date': datetime.datetime(2023, 1, 12, 13, 0)},
#  {'Latitude': 49.2764624,
#   'Longitude': -0.7024738,
#   'Weather': 'clear sky',
#   'Temperature': 9.14,
#   'Humidity': 74,
#   'Wind': 10.28,
#   'Date': datetime.datetime(2023, 1, 13, 13, 0)},
#  {'Latitude': 49.2764624,
#   'Longitude': -0.7024738,
#   'Weather': 'light rain',
#   'Temperature': 9.14,
#   'Humidity': 87,
#   'Wind': 12.62,
#   'Date': datetime.datetime(2023, 1, 14, 13, 0)},
#  {'Latitude': 49.2764624,
#   'Longitude': -0.7024738,
#   'Weather': 'rain and snow',
#   'Temperature': 9.14,
#   'Humidity': 68,
#   'Wind': 9.93,
#   'Date': datetime.datetime(2023, 1, 15, 13, 0)},
#  {'Latitude': 49.2764624,
#   'Longitude': -0.7024738,
#   'Weather': 'rain and snow',
#   'Temperature': 9.14,
#   'Humidity': 90,
#   'Wind': 13.8,
#   'Date': datetime.datetime(2023, 1, 16, 13, 0)},
#  {'Latitude': 49.2764624,
#   'Longitude': -0.7024738,
#   'Weather': 'moderate rain',
#   'Temperature': 9.14,
#   'Humidity': 90,
#   'Wind': 11.24,
#   'Date': datetime.datetime(2023, 1, 17, 13, 0)},
#  {'Latitude': 49.2764624,
#   'Longitude': -0.7024738,
#   'Weather': 'rain and snow',
#   'Temperature': 9.14,
#   'Humidity': 89,
#   'Wind': 12.16,
#   'Date': datetime.datetime(2023, 1, 18, 13, 0)},
#  {'Latitude': 49.4938975,
#   'Longitude': 0.1079732,
#   'Weather': 'moderate rain',
#   'Temperature': 9.51,
#   'Humidity': 82,
#   'Wind': 13.25,
#   'Date': datetime.datetime(2023, 1, 12, 13, 0)},
#  {'Latitude': 49.4938975,
#   'Longitude': 0.1079732,
#   'Weather': 'light rain',
#   'Temperature': 9.51,
#   'Humidity': 75,
#   'Wind': 12.83,
#   'Date': datetime.datetime(2023, 1, 13, 13, 0)},
#  {'Latitude': 49.4938975,
#   'Longitude': 0.1079732,
#   'Weather': 'light rain',
#   'Temperature': 9.51,
#   'Humidity': 87,
#   'Wind': 12.27,
#   'Date': datetime.datetime(2023, 1, 14, 13, 0)},
#  {'Latitude': 49.4938975,
#   'Longitude': 0.1079732,
#   'Weather': 'light rain',
#   'Temperature': 9.51,
#   'Humidity': 71,
#   'Wind': 12.4,
#   'Date': datetime.datetime(2023, 1, 15, 13, 0)},
#  {'Latitude': 49.4938975,
#   'Longitude': 0.1079732,
#   'Weather': 'moderate rain',
#   'Temperature': 9.51,
#   'Humidity': 80,
#   'Wind': 16.3,
#   'Date': datetime.datetime(2023, 1, 16, 13, 0)},
#  {'Latitude': 49.4938975,
#   'Longitude': 0.1079732,
#   'Weather': 'moderate rain',
#   'Temperature': 9.51,
#   'Humidity': 77,
#   'Wind': 13.65,
#   'Date': datetime.datetime(2023, 1, 17, 13, 0)},
#  {'Latitude': 49.4938975,
#   'Longitude': 0.1079732,
#   'Weather': 'rain and snow',
#   'Temperature': 9.51,
#   'Humidity': 85,
#   'Wind': 13.26,
#   'Date': datetime.datetime(2023, 1, 18, 13, 0)},
#  {'Latitude': 49.4404591,
#   'Longitude': 1.0939658,
#   'Weather': 'moderate rain',
#   'Temperature': 9.61,
#   'Humidity': 80,
#   'Wind': 10.38,
#   'Date': datetime.datetime(2023, 1, 12, 13, 0)},
#  {'Latitude': 49.4404591,
#   'Longitude': 1.0939658,
#   'Weather': 'moderate rain',
#   'Temperature': 9.61,
#   'Humidity': 74,
#   'Wind': 9.44,
#   'Date': datetime.datetime(2023, 1, 13, 13, 0)},
#  {'Latitude': 49.4404591,
#   'Longitude': 1.0939658,
#   'Weather': 'light rain',
#   'Temperature': 9.61,
#   'Humidity': 83,
#   'Wind': 9.94,
#   'Date': datetime.datetime(2023, 1, 14, 13, 0)},
#  {'Latitude': 49.4404591,
#   'Longitude': 1.0939658,
#   'Weather': 'light rain',
#   'Temperature': 9.61,
#   'Humidity': 69,
#   'Wind': 9.78,
#   'Date': datetime.datetime(2023, 1, 15, 13, 0)},
#  {'Latitude': 49.4404591,
#   'Longitude': 1.0939658,
#   'Weather': 'rain and snow',
#   'Temperature': 9.61,
#   'Humidity': 71,
#   'Wind': 12.63,
#   'Date': datetime.datetime(2023, 1, 16, 13, 0)},
#  {'Latitude': 49.4404591,
#   'Longitude': 1.0939658,
#   'Weather': 'rain and snow',
#   'Temperature': 9.61,
#   'Humidity': 93,
#   'Wind': 8.84,
#   'Date': datetime.datetime(2023, 1, 17, 13, 0)},
#  {'Latitude': 49.4404591,
#   'Longitude': 1.0939658,
#   'Weather': 'rain and snow',
#   'Temperature': 9.61,
#   'Humidity': 81,
#   'Wind': 9.76,
#   'Date': datetime.datetime(2023, 1, 18, 13, 0)},
#  {'Latitude': 48.8588897,
#   'Longitude': 2.3200410217200766,
#   'Weather': 'light rain',
#   'Temperature': 9.94,
#   'Humidity': 82,
#   'Wind': 7.66,
#   'Date': datetime.datetime(2023, 1, 12, 12, 0)},
#  {'Latitude': 48.8588897,
#   'Longitude': 2.3200410217200766,
#   'Weather': 'moderate rain',
#   'Temperature': 9.94,
#   'Humidity': 68,
#   'Wind': 7.33,
#   'Date': datetime.datetime(2023, 1, 13, 12, 0)},
#  {'Latitude': 48.8588897,
#   'Longitude': 2.3200410217200766,
#   'Weather': 'moderate rain',
#   'Temperature': 9.94,
#   'Humidity': 90,
#   'Wind': 7.78,
#   'Date': datetime.datetime(2023, 1, 14, 12, 0)},
#  {'Latitude': 48.8588897,
#   'Longitude': 2.3200410217200766,
#   'Weather': 'light rain',
#   'Temperature': 9.94,
#   'Humidity': 62,
#   'Wind': 7,
#   'Date': datetime.datetime(2023, 1, 15, 12, 0)},
#  {'Latitude': 48.8588897,
#   'Longitude': 2.3200410217200766,
#   'Weather': 'rain and snow',
#   'Temperature': 9.94,
#   'Humidity': 60,
#   'Wind': 10.4,
#   'Date': datetime.datetime(2023, 1, 16, 13, 0)},
#  {'Latitude': 48.8588897,
#   'Longitude': 2.3200410217200766,
#   'Weather': 'rain and snow',
#   'Temperature': 9.94,
#   'Humidity': 68,
#   'Wind': 8.37,
#   'Date': datetime.datetime(2023, 1, 17, 13, 0)},
#  {'Latitude': 48.8588897,
#   'Longitude': 2.3200410217200766,
#   'Weather': 'rain and snow',
#   'Temperature': 9.94,
#   'Humidity': 62,
#   'Wind': 9.28,
#   'Date': datetime.datetime(2023, 1, 18, 13, 0)},
#  {'Latitude': 49.8941708,
#   'Longitude': 2.2956951,
#   'Weather': 'moderate rain',
#   'Temperature': 8.79,
#   'Humidity': 83,
#   'Wind': 11.18,
#   'Date': datetime.datetime(2023, 1, 12, 12, 0)},
#  {'Latitude': 49.8941708,
#   'Longitude': 2.2956951,
#   'Weather': 'moderate rain',
#   'Temperature': 8.79,
#   'Humidity': 76,
#   'Wind': 10.42,
#   'Date': datetime.datetime(2023, 1, 13, 12, 0)},
#  {'Latitude': 49.8941708,
#   'Longitude': 2.2956951,
#   'Weather': 'light rain',
#   'Temperature': 8.79,
#   'Humidity': 83,
#   'Wind': 11.35,
#   'Date': datetime.datetime(2023, 1, 14, 12, 0)},
#  {'Latitude': 49.8941708,
#   'Longitude': 2.2956951,
#   'Weather': 'light rain',
#   'Temperature': 8.79,
#   'Humidity': 75,
#   'Wind': 11.1,
#   'Date': datetime.datetime(2023, 1, 15, 12, 0)},
#  {'Latitude': 49.8941708,
#   'Longitude': 2.2956951,
#   'Weather': 'rain and snow',
#   'Temperature': 8.79,
#   'Humidity': 71,
#   'Wind': 12.76,
#   'Date': datetime.datetime(2023, 1, 16, 13, 0)},
#  {'Latitude': 49.8941708,
#   'Longitude': 2.2956951,
#   'Weather': 'rain and snow',
#   'Temperature': 8.79,
#   'Humidity': 76,
#   'Wind': 9.28,
#   'Date': datetime.datetime(2023, 1, 17, 13, 0)},
#  {'Latitude': 49.8941708,
#   'Longitude': 2.2956951,
#   'Weather': 'rain and snow',
#   'Temperature': 8.79,
#   'Humidity': 85,
#   'Wind': 10.37,
#   'Date': datetime.datetime(2023, 1, 18, 13, 0)},
#  {'Latitude': 50.6365654,
#   'Longitude': 3.0635282,
#   'Weather': 'light rain',
#   'Temperature': 8.39,
#   'Humidity': 83,
#   'Wind': 11.63,
#   'Date': datetime.datetime(2023, 1, 12, 12, 0)},
#  {'Latitude': 50.6365654,
#   'Longitude': 3.0635282,
#   'Weather': 'moderate rain',
#   'Temperature': 8.39,
#   'Humidity': 70,
#   'Wind': 10.14,
#   'Date': datetime.datetime(2023, 1, 13, 12, 0)},
#  {'Latitude': 50.6365654,
#   'Longitude': 3.0635282,
#   'Weather': 'light rain',
#   'Temperature': 8.39,
#   'Humidity': 89,
#   'Wind': 9.97,
#   'Date': datetime.datetime(2023, 1, 14, 12, 0)},
#  {'Latitude': 50.6365654,
#   'Longitude': 3.0635282,
#   'Weather': 'light rain',
#   'Temperature': 8.39,
#   'Humidity': 76,
#   'Wind': 10.94,
#   'Date': datetime.datetime(2023, 1, 15, 12, 0)},
#  {'Latitude': 50.6365654,
#   'Longitude': 3.0635282,
#   'Weather': 'rain and snow',
#   'Temperature': 8.39,
#   'Humidity': 66,
#   'Wind': 11.99,
#   'Date': datetime.datetime(2023, 1, 16, 12, 0)},
#  {'Latitude': 50.6365654,
#   'Longitude': 3.0635282,
#   'Weather': 'light rain',
#   'Temperature': 8.39,
#   'Humidity': 61,
#   'Wind': 8.23,
#   'Date': datetime.datetime(2023, 1, 17, 12, 0)},
#  {'Latitude': 50.6365654,
#   'Longitude': 3.0635282,
#   'Weather': 'rain and snow',
#   'Temperature': 8.39,
#   'Humidity': 76,
#   'Wind': 7.43,
#   'Date': datetime.datetime(2023, 1, 18, 12, 0)},
#  {'Latitude': 48.584614,
#   'Longitude': 7.7507127,
#   'Weather': 'overcast clouds',
#   'Temperature': 10.4,
#   'Humidity': 74,
#   'Wind': 7.39,
#   'Date': datetime.datetime(2023, 1, 12, 12, 0)},
#  {'Latitude': 48.584614,
#   'Longitude': 7.7507127,
#   'Weather': 'moderate rain',
#   'Temperature': 10.4,
#   'Humidity': 62,
#   'Wind': 6.96,
#   'Date': datetime.datetime(2023, 1, 13, 12, 0)},
#  {'Latitude': 48.584614,
#   'Longitude': 7.7507127,
#   'Weather': 'moderate rain',
#   'Temperature': 10.4,
#   'Humidity': 77,
#   'Wind': 8.74,
#   'Date': datetime.datetime(2023, 1, 14, 12, 0)},
#  {'Latitude': 48.584614,
#   'Longitude': 7.7507127,
#   'Weather': 'moderate rain',
#   'Temperature': 10.4,
#   'Humidity': 86,
#   'Wind': 7.76,
#   'Date': datetime.datetime(2023, 1, 15, 12, 0)},
#  {'Latitude': 48.584614,
#   'Longitude': 7.7507127,
#   'Weather': 'rain and snow',
#   'Temperature': 10.4,
#   'Humidity': 60,
#   'Wind': 10.76,
#   'Date': datetime.datetime(2023, 1, 16, 12, 0)},
#  {'Latitude': 48.584614,
#   'Longitude': 7.7507127,
#   'Weather': 'moderate rain',
#   'Temperature': 10.4,
#   'Humidity': 69,
#   'Wind': 10.97,
#   'Date': datetime.datetime(2023, 1, 17, 12, 0)},
#  {'Latitude': 48.584614,
#   'Longitude': 7.7507127,
#   'Weather': 'moderate rain',
#   'Temperature': 10.4,
#   'Humidity': 88,
#   'Wind': 9.59,
#   'Date': datetime.datetime(2023, 1, 18, 12, 0)},
#  {'Latitude': 48.249489800000006,
#   'Longitude': 7.34429620253195,
#   'Weather': 'overcast clouds',
#   'Temperature': 7.12,
#   'Humidity': 81,
#   'Wind': 5.12,
#   'Date': datetime.datetime(2023, 1, 12, 12, 0)},
#  {'Latitude': 48.249489800000006,
#   'Longitude': 7.34429620253195,
#   'Weather': 'moderate rain',
#   'Temperature': 7.12,
#   'Humidity': 73,
#   'Wind': 5.69,
#   'Date': datetime.datetime(2023, 1, 13, 12, 0)},
#  {'Latitude': 48.249489800000006,
#   'Longitude': 7.34429620253195,
#   'Weather': 'moderate rain',
#   'Temperature': 7.12,
#   'Humidity': 79,
#   'Wind': 5.55,
#   'Date': datetime.datetime(2023, 1, 14, 12, 0)},
#  {'Latitude': 48.249489800000006,
#   'Longitude': 7.34429620253195,
#   'Weather': 'moderate rain',
#   'Temperature': 7.12,
#   'Humidity': 89,
#   'Wind': 6.22,
#   'Date': datetime.datetime(2023, 1, 15, 12, 0)},
#  {'Latitude': 48.249489800000006,
#   'Longitude': 7.34429620253195,
#   'Weather': 'light snow',
#   'Temperature': 7.12,
#   'Humidity': 72,
#   'Wind': 7.24,
#   'Date': datetime.datetime(2023, 1, 16, 12, 0)},
#  {'Latitude': 48.249489800000006,
#   'Longitude': 7.34429620253195,
#   'Weather': 'rain and snow',
#   'Temperature': 7.12,
#   'Humidity': 77,
#   'Wind': 8.32,
#   'Date': datetime.datetime(2023, 1, 17, 12, 0)},
#  {'Latitude': 48.249489800000006,
#   'Longitude': 7.34429620253195,
#   'Weather': 'rain and snow',
#   'Temperature': 7.12,
#   'Humidity': 98,
#   'Wind': 7.66,
#   'Date': datetime.datetime(2023, 1, 18, 12, 0)},
#  {'Latitude': 48.0777517,
#   'Longitude': 7.3579641,
#   'Weather': 'overcast clouds',
#   'Temperature': 10.59,
#   'Humidity': 80,
#   'Wind': 6,
#   'Date': datetime.datetime(2023, 1, 12, 12, 0)},
#  {'Latitude': 48.0777517,
#   'Longitude': 7.3579641,
#   'Weather': 'moderate rain',
#   'Temperature': 10.59,
#   'Humidity': 77,
#   'Wind': 6.08,
#   'Date': datetime.datetime(2023, 1, 13, 12, 0)},
#  {'Latitude': 48.0777517,
#   'Longitude': 7.3579641,
#   'Weather': 'moderate rain',
#   'Temperature': 10.59,
#   'Humidity': 77,
#   'Wind': 6.23,
#   'Date': datetime.datetime(2023, 1, 14, 12, 0)},
#  {'Latitude': 48.0777517,
#   'Longitude': 7.3579641,
#   'Weather': 'moderate rain',
#   'Temperature': 10.59,
#   'Humidity': 87,
#   'Wind': 7.13,
#   'Date': datetime.datetime(2023, 1, 15, 12, 0)},
#  {'Latitude': 48.0777517,
#   'Longitude': 7.3579641,
#   'Weather': 'light snow',
#   'Temperature': 10.59,
#   'Humidity': 69,
#   'Wind': 7.97,
#   'Date': datetime.datetime(2023, 1, 16, 12, 0)},
#  {'Latitude': 48.0777517,
#   'Longitude': 7.3579641,
#   'Weather': 'rain and snow',
#   'Temperature': 10.59,
#   'Humidity': 79,
#   'Wind': 9.35,
#   'Date': datetime.datetime(2023, 1, 17, 12, 0)},
#  {'Latitude': 48.0777517,
#   'Longitude': 7.3579641,
#   'Weather': 'rain and snow',
#   'Temperature': 10.59,
#   'Humidity': 84,
#   'Wind': 8.85,
#   'Date': datetime.datetime(2023, 1, 18, 12, 0)},
#  {'Latitude': 48.0447968,
#   'Longitude': 7.3079618,
#   'Weather': 'overcast clouds',
#   'Temperature': 10.39,
#   'Humidity': 81,
#   'Wind': 5.57,
#   'Date': datetime.datetime(2023, 1, 12, 12, 0)},
#  {'Latitude': 48.0447968,
#   'Longitude': 7.3079618,
#   'Weather': 'moderate rain',
#   'Temperature': 10.39,
#   'Humidity': 78,
#   'Wind': 5.86,
#   'Date': datetime.datetime(2023, 1, 13, 12, 0)},
#  {'Latitude': 48.0447968,
#   'Longitude': 7.3079618,
#   'Weather': 'moderate rain',
#   'Temperature': 10.39,
#   'Humidity': 76,
#   'Wind': 5.91,
#   'Date': datetime.datetime(2023, 1, 14, 12, 0)},
#  {'Latitude': 48.0447968,
#   'Longitude': 7.3079618,
#   'Weather': 'moderate rain',
#   'Temperature': 10.39,
#   'Humidity': 86,
#   'Wind': 6.86,
#   'Date': datetime.datetime(2023, 1, 15, 12, 0)},
#  {'Latitude': 48.0447968,
#   'Longitude': 7.3079618,
#   'Weather': 'light snow',
#   'Temperature': 10.39,
#   'Humidity': 71,
#   'Wind': 7.51,
#   'Date': datetime.datetime(2023, 1, 16, 12, 0)},
#  {'Latitude': 48.0447968,
#   'Longitude': 7.3079618,
#   'Weather': 'rain and snow',
#   'Temperature': 10.39,
#   'Humidity': 81,
#   'Wind': 9.11,
#   'Date': datetime.datetime(2023, 1, 17, 12, 0)},
#  {'Latitude': 48.0447968,
#   'Longitude': 7.3079618,
#   'Weather': 'rain and snow',
#   'Temperature': 10.39,
#   'Humidity': 85,
#   'Wind': 8.27,
#   'Date': datetime.datetime(2023, 1, 18, 12, 0)},
#  {'Latitude': 47.2380222,
#   'Longitude': 6.0243622,
#   'Weather': 'overcast clouds',
#   'Temperature': 8.54,
#   'Humidity': 81,
#   'Wind': 6.44,
#   'Date': datetime.datetime(2023, 1, 12, 12, 0)},
#  {'Latitude': 47.2380222,
#   'Longitude': 6.0243622,
#   'Weather': 'moderate rain',
#   'Temperature': 8.54,
#   'Humidity': 93,
#   'Wind': 7.88,
#   'Date': datetime.datetime(2023, 1, 13, 12, 0)},
#  {'Latitude': 47.2380222,
#   'Longitude': 6.0243622,
#   'Weather': 'light rain',
#   'Temperature': 8.54,
#   'Humidity': 76,
#   'Wind': 8.38,
#   'Date': datetime.datetime(2023, 1, 14, 12, 0)},
#  {'Latitude': 47.2380222,
#   'Longitude': 6.0243622,
#   'Weather': 'rain and snow',
#   'Temperature': 8.54,
#   'Humidity': 99,
#   'Wind': 9.62,
#   'Date': datetime.datetime(2023, 1, 15, 12, 0)},
#  {'Latitude': 47.2380222,
#   'Longitude': 6.0243622,
#   'Weather': 'snow',
#   'Temperature': 8.54,
#   'Humidity': 90,
#   'Wind': 10.04,
#   'Date': datetime.datetime(2023, 1, 16, 12, 0)},
#  {'Latitude': 47.2380222,
#   'Longitude': 6.0243622,
#   'Weather': 'moderate rain',
#   'Temperature': 8.54,
#   'Humidity': 89,
#   'Wind': 12.34,
#   'Date': datetime.datetime(2023, 1, 17, 12, 0)},
#  {'Latitude': 47.2380222,
#   'Longitude': 6.0243622,
#   'Weather': 'rain and snow',
#   'Temperature': 8.54,
#   'Humidity': 86,
#   'Wind': 10.67,
#   'Date': datetime.datetime(2023, 1, 18, 12, 0)},
#  {'Latitude': 47.3215806,
#   'Longitude': 5.0414701,
#   'Weather': 'overcast clouds',
#   'Temperature': 5.84,
#   'Humidity': 85,
#   'Wind': 6.65,
#   'Date': datetime.datetime(2023, 1, 12, 12, 0)},
#  {'Latitude': 47.3215806,
#   'Longitude': 5.0414701,
#   'Weather': 'moderate rain',
#   'Temperature': 5.84,
#   'Humidity': 68,
#   'Wind': 7.76,
#   'Date': datetime.datetime(2023, 1, 13, 12, 0)},
#  {'Latitude': 47.3215806,
#   'Longitude': 5.0414701,
#   'Weather': 'light rain',
#   'Temperature': 5.84,
#   'Humidity': 88,
#   'Wind': 8.73,
#   'Date': datetime.datetime(2023, 1, 14, 12, 0)},
#  {'Latitude': 47.3215806,
#   'Longitude': 5.0414701,
#   'Weather': 'moderate rain',
#   'Temperature': 5.84,
#   'Humidity': 84,
#   'Wind': 7.35,
#   'Date': datetime.datetime(2023, 1, 15, 12, 0)},
#  {'Latitude': 47.3215806,
#   'Longitude': 5.0414701,
#   'Weather': 'light snow',
#   'Temperature': 5.84,
#   'Humidity': 69,
#   'Wind': 12.83,
#   'Date': datetime.datetime(2023, 1, 16, 12, 0)},
#  {'Latitude': 47.3215806,
#   'Longitude': 5.0414701,
#   'Weather': 'rain and snow',
#   'Temperature': 5.84,
#   'Humidity': 79,
#   'Wind': 11.56,
#   'Date': datetime.datetime(2023, 1, 17, 12, 0)},
#  {'Latitude': 47.3215806,
#   'Longitude': 5.0414701,
#   'Weather': 'moderate rain',
#   'Temperature': 5.84,
#   'Humidity': 97,
#   'Wind': 10.28,
#   'Date': datetime.datetime(2023, 1, 18, 12, 0)},
#  {'Latitude': 45.8992348,
#   'Longitude': 6.1288847,
#   'Weather': 'overcast clouds',
#   'Temperature': 3.17,
#   'Humidity': 79,
#   'Wind': 1.39,
#   'Date': datetime.datetime(2023, 1, 12, 12, 0)},
#  {'Latitude': 45.8992348,
#   'Longitude': 6.1288847,
#   'Weather': 'moderate rain',
#   'Temperature': 3.17,
#   'Humidity': 97,
#   'Wind': 2.17,
#   'Date': datetime.datetime(2023, 1, 13, 12, 0)},
#  {'Latitude': 45.8992348,
#   'Longitude': 6.1288847,
#   'Weather': 'light rain',
#   'Temperature': 3.17,
#   'Humidity': 80,
#   'Wind': 2.5,
#   'Date': datetime.datetime(2023, 1, 14, 12, 0)},
#  {'Latitude': 45.8992348,
#   'Longitude': 6.1288847,
#   'Weather': 'rain and snow',
#   'Temperature': 3.17,
#   'Humidity': 99,
#   'Wind': 2.99,
#   'Date': datetime.datetime(2023, 1, 15, 12, 0)},
#  {'Latitude': 45.8992348,
#   'Longitude': 6.1288847,
#   'Weather': 'snow',
#   'Temperature': 3.17,
#   'Humidity': 82,
#   'Wind': 3.27,
#   'Date': datetime.datetime(2023, 1, 16, 12, 0)},
#  {'Latitude': 45.8992348,
#   'Longitude': 6.1288847,
#   'Weather': 'rain and snow',
#   'Temperature': 3.17,
#   'Humidity': 91,
#   'Wind': 4.73,
#   'Date': datetime.datetime(2023, 1, 17, 12, 0)},
#  {'Latitude': 45.8992348,
#   'Longitude': 6.1288847,
#   'Weather': 'rain and snow',
#   'Temperature': 3.17,
#   'Humidity': 96,
#   'Wind': 3.27,
#   'Date': datetime.datetime(2023, 1, 18, 12, 0)},
#  {'Latitude': 45.1875602,
#   'Longitude': 5.7357819,
#   'Weather': 'overcast clouds',
#   'Temperature': 7.09,
#   'Humidity': 75,
#   'Wind': 2.03,
#   'Date': datetime.datetime(2023, 1, 12, 12, 0)},
#  {'Latitude': 45.1875602,
#   'Longitude': 5.7357819,
#   'Weather': 'moderate rain',
#   'Temperature': 7.09,
#   'Humidity': 95,
#   'Wind': 1.95,
#   'Date': datetime.datetime(2023, 1, 13, 12, 0)},
#  {'Latitude': 45.1875602,
#   'Longitude': 5.7357819,
#   'Weather': 'light rain',
#   'Temperature': 7.09,
#   'Humidity': 70,
#   'Wind': 2.34,
#   'Date': datetime.datetime(2023, 1, 14, 12, 0)},
#  {'Latitude': 45.1875602,
#   'Longitude': 5.7357819,
#   'Weather': 'rain and snow',
#   'Temperature': 7.09,
#   'Humidity': 99,
#   'Wind': 2.7,
#   'Date': datetime.datetime(2023, 1, 15, 12, 0)},
#  {'Latitude': 45.1875602,
#   'Longitude': 5.7357819,
#   'Weather': 'light snow',
#   'Temperature': 7.09,
#   'Humidity': 87,
#   'Wind': 2.94,
#   'Date': datetime.datetime(2023, 1, 16, 12, 0)},
#  {'Latitude': 45.1875602,
#   'Longitude': 5.7357819,
#   'Weather': 'rain and snow',
#   'Temperature': 7.09,
#   'Humidity': 85,
#   'Wind': 4.26,
#   'Date': datetime.datetime(2023, 1, 17, 12, 0)},
#  {'Latitude': 45.1875602,
#   'Longitude': 5.7357819,
#   'Weather': 'rain and snow',
#   'Temperature': 7.09,
#   'Humidity': 97,
#   'Wind': 3.35,
#   'Date': datetime.datetime(2023, 1, 18, 12, 0)},
#  {'Latitude': 45.7578137,
#   'Longitude': 4.8320114,
#   'Weather': 'overcast clouds',
#   'Temperature': 7.24,
#   'Humidity': 69,
#   'Wind': 2.17,
#   'Date': datetime.datetime(2023, 1, 12, 12, 0)},
#  {'Latitude': 45.7578137,
#   'Longitude': 4.8320114,
#   'Weather': 'light rain',
#   'Temperature': 7.24,
#   'Humidity': 85,
#   'Wind': 2.93,
#   'Date': datetime.datetime(2023, 1, 13, 12, 0)},
#  {'Latitude': 45.7578137,
#   'Longitude': 4.8320114,
#   'Weather': 'light rain',
#   'Temperature': 7.24,
#   'Humidity': 74,
#   'Wind': 4.33,
#   'Date': datetime.datetime(2023, 1, 14, 12, 0)},
#  {'Latitude': 45.7578137,
#   'Longitude': 4.8320114,
#   'Weather': 'moderate rain',
#   'Temperature': 7.24,
#   'Humidity': 93,
#   'Wind': 5.13,
#   'Date': datetime.datetime(2023, 1, 15, 12, 0)},
#  {'Latitude': 45.7578137,
#   'Longitude': 4.8320114,
#   'Weather': 'rain and snow',
#   'Temperature': 7.24,
#   'Humidity': 53,
#   'Wind': 6.34,
#   'Date': datetime.datetime(2023, 1, 16, 12, 0)},
#  {'Latitude': 45.7578137,
#   'Longitude': 4.8320114,
#   'Weather': 'light rain',
#   'Temperature': 7.24,
#   'Humidity': 54,
#   'Wind': 8.49,
#   'Date': datetime.datetime(2023, 1, 17, 12, 0)},
#  {'Latitude': 45.7578137,
#   'Longitude': 4.8320114,
#   'Weather': 'light rain',
#   'Temperature': 7.24,
#   'Humidity': 87,
#   'Wind': 8.03,
#   'Date': datetime.datetime(2023, 1, 18, 12, 0)},
#  {'Latitude': 43.7496562,
#   'Longitude': 6.3285616,
#   'Weather': 'overcast clouds',
#   'Temperature': 3.07,
#   'Humidity': 42,
#   'Wind': 3.43,
#   'Date': datetime.datetime(2023, 1, 12, 12, 0)},
#  {'Latitude': 43.7496562,
#   'Longitude': 6.3285616,
#   'Weather': 'broken clouds',
#   'Temperature': 3.07,
#   'Humidity': 61,
#   'Wind': 6.32,
#   'Date': datetime.datetime(2023, 1, 13, 12, 0)},
#  {'Latitude': 43.7496562,
#   'Longitude': 6.3285616,
#   'Weather': 'broken clouds',
#   'Temperature': 3.07,
#   'Humidity': 40,
#   'Wind': 2.35,
#   'Date': datetime.datetime(2023, 1, 14, 12, 0)},
#  {'Latitude': 43.7496562,
#   'Longitude': 6.3285616,
#   'Weather': 'overcast clouds',
#   'Temperature': 3.07,
#   'Humidity': 66,
#   'Wind': 3.06,
#   'Date': datetime.datetime(2023, 1, 15, 12, 0)},
#  {'Latitude': 43.7496562,
#   'Longitude': 6.3285616,
#   'Weather': 'clear sky',
#   'Temperature': 3.07,
#   'Humidity': 45,
#   'Wind': 10.25,
#   'Date': datetime.datetime(2023, 1, 16, 12, 0)},
#  {'Latitude': 43.7496562,
#   'Longitude': 6.3285616,
#   'Weather': 'rain and snow',
#   'Temperature': 3.07,
#   'Humidity': 89,
#   'Wind': 4.25,
#   'Date': datetime.datetime(2023, 1, 17, 12, 0)},
#  {'Latitude': 43.7496562,
#   'Longitude': 6.3285616,
#   'Weather': 'light rain',
#   'Temperature': 3.07,
#   'Humidity': 99,
#   'Wind': 2.73,
#   'Date': datetime.datetime(2023, 1, 18, 12, 0)},
#  {'Latitude': 43.1506968,
#   'Longitude': 6.3419285,
#   'Weather': 'overcast clouds',
#   'Temperature': 7.81,
#   'Humidity': 52,
#   'Wind': 7.69,
#   'Date': datetime.datetime(2023, 1, 12, 12, 0)},
#  {'Latitude': 43.1506968,
#   'Longitude': 6.3419285,
#   'Weather': 'broken clouds',
#   'Temperature': 7.81,
#   'Humidity': 57,
#   'Wind': 9.79,
#   'Date': datetime.datetime(2023, 1, 13, 12, 0)},
#  {'Latitude': 43.1506968,
#   'Longitude': 6.3419285,
#   'Weather': 'overcast clouds',
#   'Temperature': 7.81,
#   'Humidity': 49,
#   'Wind': 3.61,
#   'Date': datetime.datetime(2023, 1, 14, 12, 0)},
#  {'Latitude': 43.1506968,
#   'Longitude': 6.3419285,
#   'Weather': 'light rain',
#   'Temperature': 7.81,
#   'Humidity': 84,
#   'Wind': 5.36,
#   'Date': datetime.datetime(2023, 1, 15, 12, 0)},
#  {'Latitude': 43.1506968,
#   'Longitude': 6.3419285,
#   'Weather': 'clear sky',
#   'Temperature': 7.81,
#   'Humidity': 44,
#   'Wind': 12.4,
#   'Date': datetime.datetime(2023, 1, 16, 12, 0)},
#  {'Latitude': 43.1506968,
#   'Longitude': 6.3419285,
#   'Weather': 'light rain',
#   'Temperature': 7.81,
#   'Humidity': 66,
#   'Wind': 8.76,
#   'Date': datetime.datetime(2023, 1, 17, 12, 0)},
#  {'Latitude': 43.1506968,
#   'Longitude': 6.3419285,
#   'Weather': 'light rain',
#   'Temperature': 7.81,
#   'Humidity': 74,
#   'Wind': 5.58,
#   'Date': datetime.datetime(2023, 1, 18, 12, 0)},
#  {'Latitude': 43.2140359,
#   'Longitude': 5.5396318,
#   'Weather': 'broken clouds',
#   'Temperature': 9.22,
#   'Humidity': 53,
#   'Wind': 14.07,
#   'Date': datetime.datetime(2023, 1, 12, 12, 0)},
#  {'Latitude': 43.2140359,
#   'Longitude': 5.5396318,
#   'Weather': 'broken clouds',
#   'Temperature': 9.22,
#   'Humidity': 61,
#   'Wind': 12.82,
#   'Date': datetime.datetime(2023, 1, 13, 12, 0)},
#  {'Latitude': 43.2140359,
#   'Longitude': 5.5396318,
#   'Weather': 'overcast clouds',
#   'Temperature': 9.22,
#   'Humidity': 50,
#   'Wind': 10.13,
#   'Date': datetime.datetime(2023, 1, 14, 12, 0)},
#  {'Latitude': 43.2140359,
#   'Longitude': 5.5396318,
#   'Weather': 'overcast clouds',
#   'Temperature': 9.22,
#   'Humidity': 75,
#   'Wind': 9.96,
#   'Date': datetime.datetime(2023, 1, 15, 12, 0)},
#  {'Latitude': 43.2140359,
#   'Longitude': 5.5396318,
#   'Weather': 'clear sky',
#   'Temperature': 9.22,
#   'Humidity': 51,
#   'Wind': 13.6,
#   'Date': datetime.datetime(2023, 1, 16, 12, 0)},
#  {'Latitude': 43.2140359,
#   'Longitude': 5.5396318,
#   'Weather': 'moderate rain',
#   'Temperature': 9.22,
#   'Humidity': 65,
#   'Wind': 9.26,
#   'Date': datetime.datetime(2023, 1, 17, 12, 0)},
#  {'Latitude': 43.2140359,
#   'Longitude': 5.5396318,
#   'Weather': 'light rain',
#   'Temperature': 9.22,
#   'Humidity': 69,
#   'Wind': 7.07,
#   'Date': datetime.datetime(2023, 1, 18, 12, 0)},
#  {'Latitude': 43.2961743,
#   'Longitude': 5.3699525,
#   'Weather': 'broken clouds',
#   'Temperature': 7.43,
#   'Humidity': 56,
#   'Wind': 14.62,
#   'Date': datetime.datetime(2023, 1, 12, 12, 0)},
#  {'Latitude': 43.2961743,
#   'Longitude': 5.3699525,
#   'Weather': 'broken clouds',
#   'Temperature': 7.43,
#   'Humidity': 62,
#   'Wind': 11.98,
#   'Date': datetime.datetime(2023, 1, 13, 12, 0)},
#  {'Latitude': 43.2961743,
#   'Longitude': 5.3699525,
#   'Weather': 'overcast clouds',
#   'Temperature': 7.43,
#   'Humidity': 51,
#   'Wind': 10.57,
#   'Date': datetime.datetime(2023, 1, 14, 12, 0)},
#  {'Latitude': 43.2961743,
#   'Longitude': 5.3699525,
#   'Weather': 'overcast clouds',
#   'Temperature': 7.43,
#   'Humidity': 72,
#   'Wind': 11.73,
#   'Date': datetime.datetime(2023, 1, 15, 12, 0)},
#  {'Latitude': 43.2961743,
#   'Longitude': 5.3699525,
#   'Weather': 'clear sky',
#   'Temperature': 7.43,
#   'Humidity': 51,
#   'Wind': 13.47,
#   'Date': datetime.datetime(2023, 1, 16, 12, 0)},
#  {'Latitude': 43.2961743,
#   'Longitude': 5.3699525,
#   'Weather': 'moderate rain',
#   'Temperature': 7.43,
#   'Humidity': 60,
#   'Wind': 8.72,
#   'Date': datetime.datetime(2023, 1, 17, 12, 0)},
#  {'Latitude': 43.2961743,
#   'Longitude': 5.3699525,
#   'Weather': 'light rain',
#   'Temperature': 7.43,
#   'Humidity': 68,
#   'Wind': 7.33,
#   'Date': datetime.datetime(2023, 1, 18, 12, 0)},
#  {'Latitude': 43.5298424,
#   'Longitude': 5.4474738,
#   'Weather': 'broken clouds',
#   'Temperature': 4.63,
#   'Humidity': 57,
#   'Wind': 10.34,
#   'Date': datetime.datetime(2023, 1, 12, 12, 0)},
#  {'Latitude': 43.5298424,
#   'Longitude': 5.4474738,
#   'Weather': 'broken clouds',
#   'Temperature': 4.63,
#   'Humidity': 59,
#   'Wind': 8.18,
#   'Date': datetime.datetime(2023, 1, 13, 12, 0)},
#  {'Latitude': 43.5298424,
#   'Longitude': 5.4474738,
#   'Weather': 'overcast clouds',
#   'Temperature': 4.63,
#   'Humidity': 46,
#   'Wind': 4.18,
#   'Date': datetime.datetime(2023, 1, 14, 12, 0)},
#  {'Latitude': 43.5298424,
#   'Longitude': 5.4474738,
#   'Weather': 'overcast clouds',
#   'Temperature': 4.63,
#   'Humidity': 59,
#   'Wind': 5.22,
#   'Date': datetime.datetime(2023, 1, 15, 12, 0)},
#  {'Latitude': 43.5298424,
#   'Longitude': 5.4474738,
#   'Weather': 'clear sky',
#   'Temperature': 4.63,
#   'Humidity': 48,
#   'Wind': 9.01,
#   'Date': datetime.datetime(2023, 1, 16, 12, 0)},
#  {'Latitude': 43.5298424,
#   'Longitude': 5.4474738,
#   'Weather': 'moderate rain',
#   'Temperature': 4.63,
#   'Humidity': 65,
#   'Wind': 5.24,
#   'Date': datetime.datetime(2023, 1, 17, 12, 0)},
#  {'Latitude': 43.5298424,
#   'Longitude': 5.4474738,
#   'Weather': 'light rain',
#   'Temperature': 4.63,
#   'Humidity': 78,
#   'Wind': 3.3,
#   'Date': datetime.datetime(2023, 1, 18, 12, 0)},
#  {'Latitude': 43.9492493,
#   'Longitude': 4.8059012,
#   'Weather': 'overcast clouds',
#   'Temperature': 3.9,
#   'Humidity': 59,
#   'Wind': 6.14,
#   'Date': datetime.datetime(2023, 1, 12, 12, 0)},
#  {'Latitude': 43.9492493,
#   'Longitude': 4.8059012,
#   'Weather': 'overcast clouds',
#   'Temperature': 3.9,
#   'Humidity': 62,
#   'Wind': 6.6,
#   'Date': datetime.datetime(2023, 1, 13, 12, 0)},
#  {'Latitude': 43.9492493,
#   'Longitude': 4.8059012,
#   'Weather': 'broken clouds',
#   'Temperature': 3.9,
#   'Humidity': 55,
#   'Wind': 5.79,
#   'Date': datetime.datetime(2023, 1, 14, 12, 0)},
#  {'Latitude': 43.9492493,
#   'Longitude': 4.8059012,
#   'Weather': 'overcast clouds',
#   'Temperature': 3.9,
#   'Humidity': 71,
#   'Wind': 8.93,
#   'Date': datetime.datetime(2023, 1, 15, 12, 0)},
#  {'Latitude': 43.9492493,
#   'Longitude': 4.8059012,
#   'Weather': 'clear sky',
#   'Temperature': 3.9,
#   'Humidity': 47,
#   'Wind': 6.16,
#   'Date': datetime.datetime(2023, 1, 16, 12, 0)},
#  {'Latitude': 43.9492493,
#   'Longitude': 4.8059012,
#   'Weather': 'light rain',
#   'Temperature': 3.9,
#   'Humidity': 64,
#   'Wind': 4.38,
#   'Date': datetime.datetime(2023, 1, 17, 12, 0)},
#  {'Latitude': 43.9492493,
#   'Longitude': 4.8059012,
#   'Weather': 'light rain',
#   'Temperature': 3.9,
#   'Humidity': 69,
#   'Wind': 5.44,
#   'Date': datetime.datetime(2023, 1, 18, 12, 0)},
#  {'Latitude': 44.0121279,
#   'Longitude': 4.4196718,
#   'Weather': 'overcast clouds',
#   'Temperature': 5.63,
#   'Humidity': 59,
#   'Wind': 4.26,
#   'Date': datetime.datetime(2023, 1, 12, 12, 0)},
#  {'Latitude': 44.0121279,
#   'Longitude': 4.4196718,
#   'Weather': 'overcast clouds',
#   'Temperature': 5.63,
#   'Humidity': 65,
#   'Wind': 4.43,
#   'Date': datetime.datetime(2023, 1, 13, 12, 0)},
#  {'Latitude': 44.0121279,
#   'Longitude': 4.4196718,
#   'Weather': 'overcast clouds',
#   'Temperature': 5.63,
#   'Humidity': 61,
#   'Wind': 3.58,
#   'Date': datetime.datetime(2023, 1, 14, 12, 0)},
#  {'Latitude': 44.0121279,
#   'Longitude': 4.4196718,
#   'Weather': 'overcast clouds',
#   'Temperature': 5.63,
#   'Humidity': 76,
#   'Wind': 7.27,
#   'Date': datetime.datetime(2023, 1, 15, 12, 0)},
#  {'Latitude': 44.0121279,
#   'Longitude': 4.4196718,
#   'Weather': 'light rain',
#   'Temperature': 5.63,
#   'Humidity': 42,
#   'Wind': 5.21,
#   'Date': datetime.datetime(2023, 1, 16, 12, 0)},
#  {'Latitude': 44.0121279,
#   'Longitude': 4.4196718,
#   'Weather': 'light rain',
#   'Temperature': 5.63,
#   'Humidity': 55,
#   'Wind': 5.25,
#   'Date': datetime.datetime(2023, 1, 17, 12, 0)},
#  {'Latitude': 44.0121279,
#   'Longitude': 4.4196718,
#   'Weather': 'light rain',
#   'Temperature': 5.63,
#   'Humidity': 72,
#   'Wind': 6.17,
#   'Date': datetime.datetime(2023, 1, 18, 12, 0)},
#  {'Latitude': 43.8374249,
#   'Longitude': 4.3600687,
#   'Weather': 'overcast clouds',
#   'Temperature': 6.22,
#   'Humidity': 56,
#   'Wind': 5.24,
#   'Date': datetime.datetime(2023, 1, 12, 12, 0)},
#  {'Latitude': 43.8374249,
#   'Longitude': 4.3600687,
#   'Weather': 'overcast clouds',
#   'Temperature': 6.22,
#   'Humidity': 61,
#   'Wind': 5.11,
#   'Date': datetime.datetime(2023, 1, 13, 12, 0)},
#  {'Latitude': 43.8374249,
#   'Longitude': 4.3600687,
#   'Weather': 'overcast clouds',
#   'Temperature': 6.22,
#   'Humidity': 59,
#   'Wind': 3.47,
#   'Date': datetime.datetime(2023, 1, 14, 12, 0)},
#  {'Latitude': 43.8374249,
#   'Longitude': 4.3600687,
#   'Weather': 'overcast clouds',
#   'Temperature': 6.22,
#   'Humidity': 73,
#   'Wind': 7.14,
#   'Date': datetime.datetime(2023, 1, 15, 12, 0)},
#  {'Latitude': 43.8374249,
#   'Longitude': 4.3600687,
#   'Weather': 'clear sky',
#   'Temperature': 6.22,
#   'Humidity': 40,
#   'Wind': 5.84,
#   'Date': datetime.datetime(2023, 1, 16, 12, 0)},
#  {'Latitude': 43.8374249,
#   'Longitude': 4.3600687,
#   'Weather': 'light rain',
#   'Temperature': 6.22,
#   'Humidity': 48,
#   'Wind': 5.32,
#   'Date': datetime.datetime(2023, 1, 17, 12, 0)},
#  {'Latitude': 43.8374249,
#   'Longitude': 4.3600687,
#   'Weather': 'light rain',
#   'Temperature': 6.22,
#   'Humidity': 71,
#   'Wind': 5.95,
#   'Date': datetime.datetime(2023, 1, 18, 12, 0)},
#  {'Latitude': 43.5658225,
#   'Longitude': 4.1912837,
#   'Weather': 'broken clouds',
#   'Temperature': 6.98,
#   'Humidity': 58,
#   'Wind': 7.01,
#   'Date': datetime.datetime(2023, 1, 12, 12, 0)},
#  {'Latitude': 43.5658225,
#   'Longitude': 4.1912837,
#   'Weather': 'overcast clouds',
#   'Temperature': 6.98,
#   'Humidity': 60,
#   'Wind': 8.64,
#   'Date': datetime.datetime(2023, 1, 13, 12, 0)},
#  {'Latitude': 43.5658225,
#   'Longitude': 4.1912837,
#   'Weather': 'overcast clouds',
#   'Temperature': 6.98,
#   'Humidity': 63,
#   'Wind': 4.02,
#   'Date': datetime.datetime(2023, 1, 14, 12, 0)},
#  {'Latitude': 43.5658225,
#   'Longitude': 4.1912837,
#   'Weather': 'light rain',
#   'Temperature': 6.98,
#   'Humidity': 69,
#   'Wind': 6.68,
#   'Date': datetime.datetime(2023, 1, 15, 12, 0)},
#  {'Latitude': 43.5658225,
#   'Longitude': 4.1912837,
#   'Weather': 'clear sky',
#   'Temperature': 6.98,
#   'Humidity': 47,
#   'Wind': 8.6,
#   'Date': datetime.datetime(2023, 1, 16, 12, 0)},
#  {'Latitude': 43.5658225,
#   'Longitude': 4.1912837,
#   'Weather': 'light rain',
#   'Temperature': 6.98,
#   'Humidity': 52,
#   'Wind': 9.03,
#   'Date': datetime.datetime(2023, 1, 17, 12, 0)},
#  {'Latitude': 43.5658225,
#   'Longitude': 4.1912837,
#   'Weather': 'light rain',
#   'Temperature': 6.98,
#   'Humidity': 74,
#   'Wind': 7.84,
#   'Date': datetime.datetime(2023, 1, 18, 12, 0)},
#  {'Latitude': 43.4522771,
#   'Longitude': 4.4287172,
#   'Weather': 'overcast clouds',
#   'Temperature': 6.57,
#   'Humidity': 60,
#   'Wind': 8.67,
#   'Date': datetime.datetime(2023, 1, 12, 12, 0)},
#  {'Latitude': 43.4522771,
#   'Longitude': 4.4287172,
#   'Weather': 'overcast clouds',
#   'Temperature': 6.57,
#   'Humidity': 63,
#   'Wind': 9.49,
#   'Date': datetime.datetime(2023, 1, 13, 12, 0)},
#  {'Latitude': 43.4522771,
#   'Longitude': 4.4287172,
#   'Weather': 'overcast clouds',
#   'Temperature': 6.57,
#   'Humidity': 67,
#   'Wind': 5.72,
#   'Date': datetime.datetime(2023, 1, 14, 12, 0)},
#  {'Latitude': 43.4522771,
#   'Longitude': 4.4287172,
#   'Weather': 'light rain',
#   'Temperature': 6.57,
#   'Humidity': 76,
#   'Wind': 10.02,
#   'Date': datetime.datetime(2023, 1, 15, 12, 0)},
#  {'Latitude': 43.4522771,
#   'Longitude': 4.4287172,
#   'Weather': 'clear sky',
#   'Temperature': 6.57,
#   'Humidity': 49,
#   'Wind': 9.39,
#   'Date': datetime.datetime(2023, 1, 16, 12, 0)},
#  {'Latitude': 43.4522771,
#   'Longitude': 4.4287172,
#   'Weather': 'light rain',
#   'Temperature': 6.57,
#   'Humidity': 52,
#   'Wind': 11.23,
#   'Date': datetime.datetime(2023, 1, 17, 12, 0)},
#  {'Latitude': 43.4522771,
#   'Longitude': 4.4287172,
#   'Weather': 'light rain',
#   'Temperature': 6.57,
#   'Humidity': 74,
#   'Wind': 9.34,
#   'Date': datetime.datetime(2023, 1, 18, 12, 0)},
#  {'Latitude': 42.52505,
#   'Longitude': 3.0831554,
#   'Weather': 'broken clouds',
#   'Temperature': 7.18,
#   'Humidity': 51,
#   'Wind': 9.57,
#   'Date': datetime.datetime(2023, 1, 12, 12, 0)},
#  {'Latitude': 42.52505,
#   'Longitude': 3.0831554,
#   'Weather': 'overcast clouds',
#   'Temperature': 7.18,
#   'Humidity': 44,
#   'Wind': 6.17,
#   'Date': datetime.datetime(2023, 1, 13, 12, 0)},
#  {'Latitude': 42.52505,
#   'Longitude': 3.0831554,
#   'Weather': 'broken clouds',
#   'Temperature': 7.18,
#   'Humidity': 41,
#   'Wind': 2.63,
#   'Date': datetime.datetime(2023, 1, 14, 12, 0)},
#  {'Latitude': 42.52505,
#   'Longitude': 3.0831554,
#   'Weather': 'light rain',
#   'Temperature': 7.18,
#   'Humidity': 68,
#   'Wind': 10.27,
#   'Date': datetime.datetime(2023, 1, 15, 12, 0)},
#  {'Latitude': 42.52505,
#   'Longitude': 3.0831554,
#   'Weather': 'light rain',
#   'Temperature': 7.18,
#   'Humidity': 42,
#   'Wind': 10.06,
#   'Date': datetime.datetime(2023, 1, 16, 12, 0)},
#  {'Latitude': 42.52505,
#   'Longitude': 3.0831554,
#   'Weather': 'light rain',
#   'Temperature': 7.18,
#   'Humidity': 63,
#   'Wind': 4.94,
#   'Date': datetime.datetime(2023, 1, 17, 12, 0)},
#  {'Latitude': 42.52505,
#   'Longitude': 3.0831554,
#   'Weather': 'light rain',
#   'Temperature': 7.18,
#   'Humidity': 67,
#   'Wind': 7.78,
#   'Date': datetime.datetime(2023, 1, 18, 12, 0)},
#  {'Latitude': 43.2130358,
#   'Longitude': 2.3491069,
#   'Weather': 'broken clouds',
#   'Temperature': 4.09,
#   'Humidity': 74,
#   'Wind': 6.14,
#   'Date': datetime.datetime(2023, 1, 12, 12, 0)},
#  {'Latitude': 43.2130358,
#   'Longitude': 2.3491069,
#   'Weather': 'overcast clouds',
#   'Temperature': 4.09,
#   'Humidity': 68,
#   'Wind': 7.04,
#   'Date': datetime.datetime(2023, 1, 13, 12, 0)},
#  {'Latitude': 43.2130358,
#   'Longitude': 2.3491069,
#   'Weather': 'overcast clouds',
#   'Temperature': 4.09,
#   'Humidity': 45,
#   'Wind': 2.75,
#   'Date': datetime.datetime(2023, 1, 14, 12, 0)},
#  {'Latitude': 43.2130358,
#   'Longitude': 2.3491069,
#   'Weather': 'light rain',
#   'Temperature': 4.09,
#   'Humidity': 90,
#   'Wind': 7.83,
#   'Date': datetime.datetime(2023, 1, 15, 12, 0)},
#  {'Latitude': 43.2130358,
#   'Longitude': 2.3491069,
#   'Weather': 'light rain',
#   'Temperature': 4.09,
#   'Humidity': 79,
#   'Wind': 7.31,
#   'Date': datetime.datetime(2023, 1, 16, 13, 0)},
#  {'Latitude': 43.2130358,
#   'Longitude': 2.3491069,
#   'Weather': 'light rain',
#   'Temperature': 4.09,
#   'Humidity': 73,
#   'Wind': 6.58,
#   'Date': datetime.datetime(2023, 1, 17, 13, 0)},
#  {'Latitude': 43.2130358,
#   'Longitude': 2.3491069,
#   'Weather': 'light rain',
#   'Temperature': 4.09,
#   'Humidity': 69,
#   'Wind': 8.07,
#   'Date': datetime.datetime(2023, 1, 18, 13, 0)},
#  {'Latitude': 42.9455368,
#   'Longitude': 1.4065544156065486,
#   'Weather': 'broken clouds',
#   'Temperature': 6.91,
#   'Humidity': 50,
#   'Wind': 2.43,
#   'Date': datetime.datetime(2023, 1, 12, 13, 0)},
#  {'Latitude': 42.9455368,
#   'Longitude': 1.4065544156065486,
#   'Weather': 'overcast clouds',
#   'Temperature': 6.91,
#   'Humidity': 69,
#   'Wind': 2.67,
#   'Date': datetime.datetime(2023, 1, 13, 13, 0)},
#  {'Latitude': 42.9455368,
#   'Longitude': 1.4065544156065486,
#   'Weather': 'overcast clouds',
#   'Temperature': 6.91,
#   'Humidity': 52,
#   'Wind': 2.79,
#   'Date': datetime.datetime(2023, 1, 14, 13, 0)},
#  {'Latitude': 42.9455368,
#   'Longitude': 1.4065544156065486,
#   'Weather': 'rain and snow',
#   'Temperature': 6.91,
#   'Humidity': 97,
#   'Wind': 2.7,
#   'Date': datetime.datetime(2023, 1, 15, 13, 0)},
#  {'Latitude': 42.9455368,
#   'Longitude': 1.4065544156065486,
#   'Weather': 'light snow',
#   'Temperature': 6.91,
#   'Humidity': 67,
#   'Wind': 2.75,
#   'Date': datetime.datetime(2023, 1, 16, 13, 0)},
#  {'Latitude': 42.9455368,
#   'Longitude': 1.4065544156065486,
#   'Weather': 'rain and snow',
#   'Temperature': 6.91,
#   'Humidity': 96,
#   'Wind': 2.67,
#   'Date': datetime.datetime(2023, 1, 17, 13, 0)},
#  {'Latitude': 42.9455368,
#   'Longitude': 1.4065544156065486,
#   'Weather': 'snow',
#   'Temperature': 6.91,
#   'Humidity': 66,
#   'Wind': 2.9,
#   'Date': datetime.datetime(2023, 1, 18, 13, 0)},
#  {'Latitude': 43.6044622,
#   'Longitude': 1.4442469,
#   'Weather': 'overcast clouds',
#   'Temperature': 4.97,
#   'Humidity': 71,
#   'Wind': 3.54,
#   'Date': datetime.datetime(2023, 1, 12, 13, 0)},
#  {'Latitude': 43.6044622,
#   'Longitude': 1.4442469,
#   'Weather': 'overcast clouds',
#   'Temperature': 4.97,
#   'Humidity': 71,
#   'Wind': 5.92,
#   'Date': datetime.datetime(2023, 1, 13, 13, 0)},
#  {'Latitude': 43.6044622,
#   'Longitude': 1.4442469,
#   'Weather': 'overcast clouds',
#   'Temperature': 4.97,
#   'Humidity': 45,
#   'Wind': 3.24,
#   'Date': datetime.datetime(2023, 1, 14, 13, 0)},
#  {'Latitude': 43.6044622,
#   'Longitude': 1.4442469,
#   'Weather': 'light rain',
#   'Temperature': 4.97,
#   'Humidity': 90,
#   'Wind': 4.37,
#   'Date': datetime.datetime(2023, 1, 15, 13, 0)},
#  {'Latitude': 43.6044622,
#   'Longitude': 1.4442469,
#   'Weather': 'light rain',
#   'Temperature': 4.97,
#   'Humidity': 73,
#   'Wind': 6.22,
#   'Date': datetime.datetime(2023, 1, 16, 13, 0)},
#  {'Latitude': 43.6044622,
#   'Longitude': 1.4442469,
#   'Weather': 'light rain',
#   'Temperature': 4.97,
#   'Humidity': 66,
#   'Wind': 9.33,
#   'Date': datetime.datetime(2023, 1, 17, 13, 0)},
#  {'Latitude': 43.6044622,
#   'Longitude': 1.4442469,
#   'Weather': 'moderate rain',
#   'Temperature': 4.97,
#   'Humidity': 58,
#   'Wind': 7.87,
#   'Date': datetime.datetime(2023, 1, 18, 13, 0)},
#  {'Latitude': 44.0175835,
#   'Longitude': 1.3549991,
#   'Weather': 'overcast clouds',
#   'Temperature': 9.47,
#   'Humidity': 79,
#   'Wind': 2.83,
#   'Date': datetime.datetime(2023, 1, 12, 13, 0)},
#  {'Latitude': 44.0175835,
#   'Longitude': 1.3549991,
#   'Weather': 'light rain',
#   'Temperature': 9.47,
#   'Humidity': 80,
#   'Wind': 5.8,
#   'Date': datetime.datetime(2023, 1, 13, 13, 0)},
#  {'Latitude': 44.0175835,
#   'Longitude': 1.3549991,
#   'Weather': 'overcast clouds',
#   'Temperature': 9.47,
#   'Humidity': 61,
#   'Wind': 3.39,
#   'Date': datetime.datetime(2023, 1, 14, 13, 0)},
#  {'Latitude': 44.0175835,
#   'Longitude': 1.3549991,
#   'Weather': 'light rain',
#   'Temperature': 9.47,
#   'Humidity': 88,
#   'Wind': 5.28,
#   'Date': datetime.datetime(2023, 1, 15, 13, 0)},
#  {'Latitude': 44.0175835,
#   'Longitude': 1.3549991,
#   'Weather': 'broken clouds',
#   'Temperature': 9.47,
#   'Humidity': 74,
#   'Wind': 7,
#   'Date': datetime.datetime(2023, 1, 16, 13, 0)},
#  {'Latitude': 44.0175835,
#   'Longitude': 1.3549991,
#   'Weather': 'light rain',
#   'Temperature': 9.47,
#   'Humidity': 67,
#   'Wind': 11.67,
#   'Date': datetime.datetime(2023, 1, 17, 13, 0)},
#  {'Latitude': 44.0175835,
#   'Longitude': 1.3549991,
#   'Weather': 'moderate rain',
#   'Temperature': 9.47,
#   'Humidity': 83,
#   'Wind': 10.01,
#   'Date': datetime.datetime(2023, 1, 18, 13, 0)},
#  {'Latitude': 43.471143749999996,
#   'Longitude': -1.552726590666314,
#   'Weather': 'overcast clouds',
#   'Temperature': 12.75,
#   'Humidity': 66,
#   'Wind': 3.1,
#   'Date': datetime.datetime(2023, 1, 12, 13, 0)},
#  {'Latitude': 43.471143749999996,
#   'Longitude': -1.552726590666314,
#   'Weather': 'overcast clouds',
#   'Temperature': 12.75,
#   'Humidity': 75,
#   'Wind': 4.5,
#   'Date': datetime.datetime(2023, 1, 13, 13, 0)},
#  {'Latitude': 43.471143749999996,
#   'Longitude': -1.552726590666314,
#   'Weather': 'overcast clouds',
#   'Temperature': 12.75,
#   'Humidity': 68,
#   'Wind': 6.22,
#   'Date': datetime.datetime(2023, 1, 14, 13, 0)},
#  {'Latitude': 43.471143749999996,
#   'Longitude': -1.552726590666314,
#   'Weather': 'moderate rain',
#   'Temperature': 12.75,
#   'Humidity': 83,
#   'Wind': 7.26,
#   'Date': datetime.datetime(2023, 1, 15, 13, 0)},
#  {'Latitude': 43.471143749999996,
#   'Longitude': -1.552726590666314,
#   'Weather': 'light rain',
#   'Temperature': 12.75,
#   'Humidity': 77,
#   'Wind': 8,
#   'Date': datetime.datetime(2023, 1, 16, 13, 0)},
#  {'Latitude': 43.471143749999996,
#   'Longitude': -1.552726590666314,
#   'Weather': 'moderate rain',
#   'Temperature': 12.75,
#   'Humidity': 79,
#   'Wind': 7.43,
#   'Date': datetime.datetime(2023, 1, 17, 13, 0)},
#  {'Latitude': 43.471143749999996,
#   'Longitude': -1.552726590666314,
#   'Weather': 'moderate rain',
#   'Temperature': 12.75,
#   'Humidity': 73,
#   'Wind': 14.12,
#   'Date': datetime.datetime(2023, 1, 18, 13, 0)},
#  {'Latitude': 43.4945144,
#   'Longitude': -1.4736657,
#   'Weather': 'overcast clouds',
#   'Temperature': 12.99,
#   'Humidity': 68,
#   'Wind': 2.86,
#   'Date': datetime.datetime(2023, 1, 12, 13, 0)},
#  {'Latitude': 43.4945144,
#   'Longitude': -1.4736657,
#   'Weather': 'overcast clouds',
#   'Temperature': 12.99,
#   'Humidity': 74,
#   'Wind': 4.16,
#   'Date': datetime.datetime(2023, 1, 13, 13, 0)},
#  {'Latitude': 43.4945144,
#   'Longitude': -1.4736657,
#   'Weather': 'overcast clouds',
#   'Temperature': 12.99,
#   'Humidity': 66,
#   'Wind': 5.68,
#   'Date': datetime.datetime(2023, 1, 14, 13, 0)},
#  {'Latitude': 43.4945144,
#   'Longitude': -1.4736657,
#   'Weather': 'moderate rain',
#   'Temperature': 12.99,
#   'Humidity': 84,
#   'Wind': 6.7,
#   'Date': datetime.datetime(2023, 1, 15, 13, 0)},
#  {'Latitude': 43.4945144,
#   'Longitude': -1.4736657,
#   'Weather': 'moderate rain',
#   'Temperature': 12.99,
#   'Humidity': 77,
#   'Wind': 7.29,
#   'Date': datetime.datetime(2023, 1, 16, 13, 0)},
#  {'Latitude': 43.4945144,
#   'Longitude': -1.4736657,
#   'Weather': 'moderate rain',
#   'Temperature': 12.99,
#   'Humidity': 78,
#   'Wind': 6.75,
#   'Date': datetime.datetime(2023, 1, 17, 13, 0)},
#  {'Latitude': 43.4945144,
#   'Longitude': -1.4736657,
#   'Weather': 'moderate rain',
#   'Temperature': 12.99,
#   'Humidity': 74,
#   'Wind': 13.07,
#   'Date': datetime.datetime(2023, 1, 18, 13, 0)},
#  {'Latitude': 46.1591126,
#   'Longitude': -1.1520434,
#   'Weather': 'moderate rain',
#   'Temperature': 11.07,
#   'Humidity': 82,
#   'Wind': 11.43,
#   'Date': datetime.datetime(2023, 1, 12, 13, 0)},
#  {'Latitude': 46.1591126,
#   'Longitude': -1.1520434,
#   'Weather': 'light rain',
#   'Temperature': 11.07,
#   'Humidity': 74,
#   'Wind': 12.76,
#   'Date': datetime.datetime(2023, 1, 13, 13, 0)},
#  {'Latitude': 46.1591126,
#   'Longitude': -1.1520434,
#   'Weather': 'moderate rain',
#   'Temperature': 11.07,
#   'Humidity': 87,
#   'Wind': 13.72,
#   'Date': datetime.datetime(2023, 1, 14, 13, 0)},
#  {'Latitude': 46.1591126,
#   'Longitude': -1.1520434,
#   'Weather': 'moderate rain',
#   'Temperature': 11.07,
#   'Humidity': 61,
#   'Wind': 8.62,
#   'Date': datetime.datetime(2023, 1, 15, 13, 0)},
#  {'Latitude': 46.1591126,
#   'Longitude': -1.1520434,
#   'Weather': 'moderate rain',
#   'Temperature': 11.07,
#   'Humidity': 69,
#   'Wind': 18.82,
#   'Date': datetime.datetime(2023, 1, 16, 13, 0)},
#  {'Latitude': 46.1591126,
#   'Longitude': -1.1520434,
#   'Weather': 'moderate rain',
#   'Temperature': 11.07,
#   'Humidity': 66,
#   'Wind': 13.38,
#   'Date': datetime.datetime(2023, 1, 17, 13, 0)},
#  {'Latitude': 46.1591126,
#   'Longitude': -1.1520434,
#   'Weather': 'moderate rain',
#   'Temperature': 11.07,
#   'Humidity': 79,
#   'Wind': 14.54,
#   'Date': datetime.datetime(2023, 1, 18, 13, 0)}]

# %%
# weather_json étant une liste, on le convertit en DF pour un tableau plus esthétique

weather_week = DataFrame(weather_json)

# On a trouvé le temps sur 7j mais sans le nom des villes

weather_week
# Out:
#       Latitude  Longitude        Weather  Temperature  Humidity   Wind  \
# 0    48.635954  -1.511460  moderate rain         8.39        81   9.82
# 1    48.635954  -1.511460     light rain         8.39        77   8.17
# 2    48.635954  -1.511460  moderate rain         8.39        93  10.10
# 3    48.635954  -1.511460     light rain         8.39        71   8.35
# 4    48.635954  -1.511460  moderate rain         8.39        90  14.03
# ..         ...        ...            ...          ...       ...    ...
# 240  46.159113  -1.152043  moderate rain        11.07        87  13.72
# 241  46.159113  -1.152043  moderate rain        11.07        61   8.62
# 242  46.159113  -1.152043  moderate rain        11.07        69  18.82
# 243  46.159113  -1.152043  moderate rain        11.07        66  13.38
# 244  46.159113  -1.152043  moderate rain        11.07        79  14.54
#
#                    Date
# 0   2023-01-12 13:00:00
# 1   2023-01-13 13:00:00
# 2   2023-01-14 13:00:00
# 3   2023-01-15 13:00:00
# 4   2023-01-16 13:00:00
# ..                  ...
# 240 2023-01-14 13:00:00
# 241 2023-01-15 13:00:00
# 242 2023-01-16 13:00:00
# 243 2023-01-17 13:00:00
# 244 2023-01-18 13:00:00
#
# [245 rows x 7 columns]

# %%
# Une jointure est nécessaire pour relier les DF 'lat_lon' et 'weather_week'

final_result = pd.merge(lat_lon, weather_week, on=["Latitude", "Longitude"])

# %%
dic_weather.keys()
# Out:
# dict_keys(['lat', 'lon', 'timezone', 'timezone_offset', 'current', 'daily'])

# %%
# Notre résultat append de la loop météo étant une liste de dictionnaire, on souhaite en tirer les clés
# concernées et les séparer en différentes colonnes pour chaque ville

weather = []
temp = []
hum = []
wind = []
date = []

for _dict in weather_json:
    weather.append(_dict['Weather'])
    temp.append(_dict['Temperature'])
    hum.append(_dict['Humidity'])
    wind.append(_dict['Wind'])
    date.append(_dict['Date'])
    
    print(weather)

lat_lon['Weather'] = weather
lat_lon['Temperature (°C)'] = temp
lat_lon['Humidity'] = hum
lat_lon['Wind'] = wind
lat_lon['Date'] = date
# Out:
# ['moderate rain']
# ['moderate rain', 'light rain']
# ['moderate rain', 'light rain', 'moderate rain']
# ['moderate rain', 'light rain', 'moderate rain', 'light rain']
# ['moderate rain', 'light rain', 'moderate rain', 'light rain', 'moderate rain']
# ['moderate rain', 'light rain', 'moderate rain', 'light rain', 'moderate rain', 'light rain']
# ['moderate rain', 'light rain', 'moderate rain', 'light rain', 'moderate rain', 'light rain', 'rain and snow']
# ['moderate rain', 'light rain', 'moderate rain', 'light rain', 'moderate rain', 'light rain', 'rain and snow', 'moderate rain']
# ['moderate rain', 'light rain', 'moderate rain', 'light rain', 'moderate rain', 'light rain', 'rain and snow', 'moderate rain', 'broken clouds']
# ['moderate rain', 'light rain', 'moderate rain', 'light rain', 'moderate rain', 'light rain', 'rain and snow', 'moderate rain', 'broken clouds', 'moderate rain']
# ['moderate rain', 'light rain', 'moderate rain', 'light rain', 'moderate rain', 'light rain', 'rain and snow', 'moderate rain', 'broken clouds', 'moderate rain', 'light rain']
# ['moderate rain', 'light rain', 'moderate rain', 'light rain', 'moderate rain', 'light rain', 'rain and snow', 'moderate rain', 'broken clouds', 'moderate rain', 'light rain', 'moderate rain']
# ['moderate rain', 'light rain', 'moderate rain', 'light rain', 'moderate rain', 'light rain', 'rain and snow', 'moderate rain', 'broken clouds', 'moderate rain', 'light rain', 'moderate rain', 'light rain']
# ['moderate rain', 'light rain', 'moderate rain', 'light rain', 'moderate rain', 'light rain', 'rain and snow', 'moderate rain', 'broken clouds', 'moderate rain', 'light rain', 'moderate rain', 'light rain', 'rain and snow']
# ['moderate rain', 'light rain', 'moderate rain', 'light rain', 'moderate rain', 'light rain', 'rain and snow', 'moderate rain', 'broken clouds', 'moderate rain', 'light rain', 'moderate rain', 'light rain', 'rain and snow', 'moderate rain']
# ['moderate rain', 'light rain', 'moderate rain', 'light rain', 'moderate rain', 'light rain', 'rain and snow', 'moderate rain', 'broken clouds', 'moderate rain', 'light rain', 'moderate rain', 'light rain', 'rain and snow', 'moderate rain', 'clear sky']
# ['moderate rain', 'light rain', 'moderate rain', 'light rain', 'moderate rain', 'light rain', 'rain and snow', 'moderate rain', 'broken clouds', 'moderate rain', 'light rain', 'moderate rain', 'light rain', 'rain and snow', 'moderate rain', 'clear sky', 'light rain']
# ['moderate rain', 'light rain', 'moderate rain', 'light rain', 'moderate rain', 'light rain', 'rain and snow', 'moderate rain', 'broken clouds', 'moderate rain', 'light rain', 'moderate rain', 'light rain', 'rain and snow', 'moderate rain', 'clear sky', 'light rain', 'rain and snow']
# ['moderate rain', 'light rain', 'moderate rain', 'light rain', 'moderate rain', 'light rain', 'rain and snow', 'moderate rain', 'broken clouds', 'moderate rain', 'light rain', 'moderate rain', 'light rain', 'rain and snow', 'moderate rain', 'clear sky', 'light rain', 'rain and snow', 'rain and snow']
# ['moderate rain', 'light rain', 'moderate rain', 'light rain', 'moderate rain', 'light rain', 'rain and snow', 'moderate rain', 'broken clouds', 'moderate rain', 'light rain', 'moderate rain', 'light rain', 'rain and snow', 'moderate rain', 'clear sky', 'light rain', 'rain and snow', 'rain and snow', 'moderate rain']
# ['moderate rain', 'light rain', 'moderate rain', 'light rain', 'moderate rain', 'light rain', 'rain and snow', 'moderate rain', 'broken clouds', 'moderate rain', 'light rain', 'moderate rain', 'light rain', 'rain and snow', 'moderate rain', 'clear sky', 'light rain', 'rain and snow', 'rain and snow', 'moderate rain', 'rain and snow']
# ['moderate rain', 'light rain', 'moderate rain', 'light rain', 'moderate rain', 'light rain', 'rain and snow', 'moderate rain', 'broken clouds', 'moderate rain', 'light rain', 'moderate rain', 'light rain', 'rain and snow', 'moderate rain', 'clear sky', 'light rain', 'rain and snow', 'rain and snow', 'moderate rain', 'rain and snow', 'moderate rain']
# ['moderate rain', 'light rain', 'moderate rain', 'light rain', 'moderate rain', 'light rain', 'rain and snow', 'moderate rain', 'broken clouds', 'moderate rain', 'light rain', 'moderate rain', 'light rain', 'rain and snow', 'moderate rain', 'clear sky', 'light rain', 'rain and snow', 'rain and snow', 'moderate rain', 'rain and snow', 'moderate rain', 'light rain']
# ['moderate rain', 'light rain', 'moderate rain', 'light rain', 'moderate rain', 'light rain', 'rain and snow', 'moderate rain', 'broken clouds', 'moderate rain', 'light rain', 'moderate rain', 'light rain', 'rain and snow', 'moderate rain', 'clear sky', 'light rain', 'rain and snow', 'rain and snow', 'moderate rain', 'rain and snow', 'moderate rain', 'light rain', 'light rain']
# ['moderate rain', 'light rain', 'moderate rain', 'light rain', 'moderate rain', 'light rain', 'rain and snow', 'moderate rain', 'broken clouds', 'moderate rain', 'light rain', 'moderate rain', 'light rain', 'rain and snow', 'moderate rain', 'clear sky', 'light rain', 'rain and snow', 'rain and snow', 'moderate rain', 'rain and snow', 'moderate rain', 'light rain', 'light rain', 'light rain']
# ['moderate rain', 'light rain', 'moderate rain', 'light rain', 'moderate rain', 'light rain', 'rain and snow', 'moderate rain', 'broken clouds', 'moderate rain', 'light rain', 'moderate rain', 'light rain', 'rain and snow', 'moderate rain', 'clear sky', 'light rain', 'rain and snow', 'rain and snow', 'moderate rain', 'rain and snow', 'moderate rain', 'light rain', 'light rain', 'light rain', 'moderate rain']
# ['moderate rain', 'light rain', 'moderate rain', 'light rain', 'moderate rain', 'light rain', 'rain and snow', 'moderate rain', 'broken clouds', 'moderate rain', 'light rain', 'moderate rain', 'light rain', 'rain and snow', 'moderate rain', 'clear sky', 'light rain', 'rain and snow', 'rain and snow', 'moderate rain', 'rain and snow', 'moderate rain', 'light rain', 'light rain', 'light rain', 'moderate rain', 'moderate rain']
# ['moderate rain', 'light rain', 'moderate rain', 'light rain', 'moderate rain', 'light rain', 'rain and snow', 'moderate rain', 'broken clouds', 'moderate rain', 'light rain', 'moderate rain', 'light rain', 'rain and snow', 'moderate rain', 'clear sky', 'light rain', 'rain and snow', 'rain and snow', 'moderate rain', 'rain and snow', 'moderate rain', 'light rain', 'light rain', 'light rain', 'moderate rain', 'moderate rain', 'rain and snow']
# ['moderate rain', 'light rain', 'moderate rain', 'light rain', 'moderate rain', 'light rain', 'rain and snow', 'moderate rain', 'broken clouds', 'moderate rain', 'light rain', 'moderate rain', 'light rain', 'rain and snow', 'moderate rain', 'clear sky', 'light rain', 'rain and snow', 'rain and snow', 'moderate rain', 'rain and snow', 'moderate rain', 'light rain', 'light rain', 'light rain', 'moderate rain', 'moderate rain', 'rain and snow', 'moderate rain']
# ['moderate rain', 'light rain', 'moderate rain', 'light rain', 'moderate rain', 'light rain', 'rain and snow', 'moderate rain', 'broken clouds', 'moderate rain', 'light rain', 'moderate rain', 'light rain', 'rain and snow', 'moderate rain', 'clear sky', 'light rain', 'rain and snow', 'rain and snow', 'moderate rain', 'rain and snow', 'moderate rain', 'light rain', 'light rain', 'light rain', 'moderate rain', 'moderate rain', 'rain and snow', 'moderate rain', 'moderate rain']
# ['moderate rain', 'light rain', 'moderate rain', 'light rain', 'moderate rain', 'light rain', 'rain and snow', 'moderate rain', 'broken clouds', 'moderate rain', 'light rain', 'moderate rain', 'light rain', 'rain and snow', 'moderate rain', 'clear sky', 'light rain', 'rain and snow', 'rain and snow', 'moderate rain', 'rain and snow', 'moderate rain', 'light rain', 'light rain', 'light rain', 'moderate rain', 'moderate rain', 'rain and snow', 'moderate rain', 'moderate rain', 'light rain']
# ['moderate rain', 'light rain', 'moderate rain', 'light rain', 'moderate rain', 'light rain', 'rain and snow', 'moderate rain', 'broken clouds', 'moderate rain', 'light rain', 'moderate rain', 'light rain', 'rain and snow', 'moderate rain', 'clear sky', 'light rain', 'rain and snow', 'rain and snow', 'moderate rain', 'rain and snow', 'moderate rain', 'light rain', 'light rain', 'light rain', 'moderate rain', 'moderate rain', 'rain and snow', 'moderate rain', 'moderate rain', 'light rain', 'light rain']
# ['moderate rain', 'light rain', 'moderate rain', 'light rain', 'moderate rain', 'light rain', 'rain and snow', 'moderate rain', 'broken clouds', 'moderate rain', 'light rain', 'moderate rain', 'light rain', 'rain and snow', 'moderate rain', 'clear sky', 'light rain', 'rain and snow', 'rain and snow', 'moderate rain', 'rain and snow', 'moderate rain', 'light rain', 'light rain', 'light rain', 'moderate rain', 'moderate rain', 'rain and snow', 'moderate rain', 'moderate rain', 'light rain', 'light rain', 'rain and snow']
# ['moderate rain', 'light rain', 'moderate rain', 'light rain', 'moderate rain', 'light rain', 'rain and snow', 'moderate rain', 'broken clouds', 'moderate rain', 'light rain', 'moderate rain', 'light rain', 'rain and snow', 'moderate rain', 'clear sky', 'light rain', 'rain and snow', 'rain and snow', 'moderate rain', 'rain and snow', 'moderate rain', 'light rain', 'light rain', 'light rain', 'moderate rain', 'moderate rain', 'rain and snow', 'moderate rain', 'moderate rain', 'light rain', 'light rain', 'rain and snow', 'rain and snow']
# ['moderate rain', 'light rain', 'moderate rain', 'light rain', 'moderate rain', 'light rain', 'rain and snow', 'moderate rain', 'broken clouds', 'moderate rain', 'light rain', 'moderate rain', 'light rain', 'rain and snow', 'moderate rain', 'clear sky', 'light rain', 'rain and snow', 'rain and snow', 'moderate rain', 'rain and snow', 'moderate rain', 'light rain', 'light rain', 'light rain', 'moderate rain', 'moderate rain', 'rain and snow', 'moderate rain', 'moderate rain', 'light rain', 'light rain', 'rain and snow', 'rain and snow', 'rain and snow']
# ['moderate rain', 'light rain', 'moderate rain', 'light rain', 'moderate rain', 'light rain', 'rain and snow', 'moderate rain', 'broken clouds', 'moderate rain', 'light rain', 'moderate rain', 'light rain', 'rain and snow', 'moderate rain', 'clear sky', 'light rain', 'rain and snow', 'rain and snow', 'moderate rain', 'rain and snow', 'moderate rain', 'light rain', 'light rain', 'light rain', 'moderate rain', 'moderate rain', 'rain and snow', 'moderate rain', 'moderate rain', 'light rain', 'light rain', 'rain and snow', 'rain and snow', 'rain and snow', 'light rain']
# ['moderate rain', 'light rain', 'moderate rain', 'light rain', 'moderate rain', 'light rain', 'rain and snow', 'moderate rain', 'broken clouds', 'moderate rain', 'light rain', 'moderate rain', 'light rain', 'rain and snow', 'moderate rain', 'clear sky', 'light rain', 'rain and snow', 'rain and snow', 'moderate rain', 'rain and snow', 'moderate rain', 'light rain', 'light rain', 'light rain', 'moderate rain', 'moderate rain', 'rain and snow', 'moderate rain', 'moderate rain', 'light rain', 'light rain', 'rain and snow', 'rain and snow', 'rain and snow', 'light rain', 'moderate rain']
# ['moderate rain', 'light rain', 'moderate rain', 'light rain', 'moderate rain', 'light rain', 'rain and snow', 'moderate rain', 'broken clouds', 'moderate rain', 'light rain', 'moderate rain', 'light rain', 'rain and snow', 'moderate rain', 'clear sky', 'light rain', 'rain and snow', 'rain and snow', 'moderate rain', 'rain and snow', 'moderate rain', 'light rain', 'light rain', 'light rain', 'moderate rain', 'moderate rain', 'rain and snow', 'moderate rain', 'moderate rain', 'light rain', 'light rain', 'rain and snow', 'rain and snow', 'rain and snow', 'light rain', 'moderate rain', 'moderate rain']
# ['moderate rain', 'light rain', 'moderate rain', 'light rain', 'moderate rain', 'light rain', 'rain and snow', 'moderate rain', 'broken clouds', 'moderate rain', 'light rain', 'moderate rain', 'light rain', 'rain and snow', 'moderate rain', 'clear sky', 'light rain', 'rain and snow', 'rain and snow', 'moderate rain', 'rain and snow', 'moderate rain', 'light rain', 'light rain', 'light rain', 'moderate rain', 'moderate rain', 'rain and snow', 'moderate rain', 'moderate rain', 'light rain', 'light rain', 'rain and snow', 'rain and snow', 'rain and snow', 'light rain', 'moderate rain', 'moderate rain', 'light rain']
# ['moderate rain', 'light rain', 'moderate rain', 'light rain', 'moderate rain', 'light rain', 'rain and snow', 'moderate rain', 'broken clouds', 'moderate rain', 'light rain', 'moderate rain', 'light rain', 'rain and snow', 'moderate rain', 'clear sky', 'light rain', 'rain and snow', 'rain and snow', 'moderate rain', 'rain and snow', 'moderate rain', 'light rain', 'light rain', 'light rain', 'moderate rain', 'moderate rain', 'rain and snow', 'moderate rain', 'moderate rain', 'light rain', 'light rain', 'rain and snow', 'rain and snow', 'rain and snow', 'light rain', 'moderate rain', 'moderate rain', 'light rain', 'rain and snow']
# ['moderate rain', 'light rain', 'moderate rain', 'light rain', 'moderate rain', 'light rain', 'rain and snow', 'moderate rain', 'broken clouds', 'moderate rain', 'light rain', 'moderate rain', 'light rain', 'rain and snow', 'moderate rain', 'clear sky', 'light rain', 'rain and snow', 'rain and snow', 'moderate rain', 'rain and snow', 'moderate rain', 'light rain', 'light rain', 'light rain', 'moderate rain', 'moderate rain', 'rain and snow', 'moderate rain', 'moderate rain', 'light rain', 'light rain', 'rain and snow', 'rain and snow', 'rain and snow', 'light rain', 'moderate rain', 'moderate rain', 'light rain', 'rain and snow', 'rain and snow']
# ['moderate rain', 'light rain', 'moderate rain', 'light rain', 'moderate rain', 'light rain', 'rain and snow', 'moderate rain', 'broken clouds', 'moderate rain', 'light rain', 'moderate rain', 'light rain', 'rain and snow', 'moderate rain', 'clear sky', 'light rain', 'rain and snow', 'rain and snow', 'moderate rain', 'rain and snow', 'moderate rain', 'light rain', 'light rain', 'light rain', 'moderate rain', 'moderate rain', 'rain and snow', 'moderate rain', 'moderate rain', 'light rain', 'light rain', 'rain and snow', 'rain and snow', 'rain and snow', 'light rain', 'moderate rain', 'moderate rain', 'light rain', 'rain and snow', 'rain and snow', 'rain and snow']
# ['moderate rain', 'light rain', 'moderate rain', 'light rain', 'moderate rain', 'light rain', 'rain and snow', 'moderate rain', 'broken clouds', 'moderate rain', 'light rain', 'moderate rain', 'light rain', 'rain and snow', 'moderate rain', 'clear sky', 'light rain', 'rain and snow', 'rain and snow', 'moderate rain', 'rain and snow', 'moderate rain', 'light rain', 'light rain', 'light rain', 'moderate rain', 'moderate rain', 'rain and snow', 'moderate rain', 'moderate rain', 'light rain', 'light rain', 'rain and snow', 'rain and snow', 'rain and snow', 'light rain', 'moderate rain', 'moderate rain', 'light rain', 'rain and snow', 'rain and snow', 'rain and snow', 'moderate rain']
# ['moderate rain', 'light rain', 'moderate rain', 'light rain', 'moderate rain', 'light rain', 'rain and snow', 'moderate rain', 'broken clouds', 'moderate rain', 'light rain', 'moderate rain', 'light rain', 'rain and snow', 'moderate rain', 'clear sky', 'light rain', 'rain and snow', 'rain and snow', 'moderate rain', 'rain and snow', 'moderate rain', 'light rain', 'light rain', 'light rain', 'moderate rain', 'moderate rain', 'rain and snow', 'moderate rain', 'moderate rain', 'light rain', 'light rain', 'rain and snow', 'rain and snow', 'rain and snow', 'light rain', 'moderate rain', 'moderate rain', 'light rain', 'rain and snow', 'rain and snow', 'rain and snow', 'moderate rain', 'moderate rain']
# ['moderate rain', 'light rain', 'moderate rain', 'light rain', 'moderate rain', 'light rain', 'rain and snow', 'moderate rain', 'broken clouds', 'moderate rain', 'light rain', 'moderate rain', 'light rain', 'rain and snow', 'moderate rain', 'clear sky', 'light rain', 'rain and snow', 'rain and snow', 'moderate rain', 'rain and snow', 'moderate rain', 'light rain', 'light rain', 'light rain', 'moderate rain', 'moderate rain', 'rain and snow', 'moderate rain', 'moderate rain', 'light rain', 'light rain', 'rain and snow', 'rain and snow', 'rain and snow', 'light rain', 'moderate rain', 'moderate rain', 'light rain', 'rain and snow', 'rain and snow', 'rain and snow', 'moderate rain', 'moderate rain', 'light rain']
# ['moderate rain', 'light rain', 'moderate rain', 'light rain', 'moderate rain', 'light rain', 'rain and snow', 'moderate rain', 'broken clouds', 'moderate rain', 'light rain', 'moderate rain', 'light rain', 'rain and snow', 'moderate rain', 'clear sky', 'light rain', 'rain and snow', 'rain and snow', 'moderate rain', 'rain and snow', 'moderate rain', 'light rain', 'light rain', 'light rain', 'moderate rain', 'moderate rain', 'rain and snow', 'moderate rain', 'moderate rain', 'light rain', 'light rain', 'rain and snow', 'rain and snow', 'rain and snow', 'light rain', 'moderate rain', 'moderate rain', 'light rain', 'rain and snow', 'rain and snow', 'rain and snow', 'moderate rain', 'moderate rain', 'light rain', 'light rain']
# ['moderate rain', 'light rain', 'moderate rain', 'light rain', 'moderate rain', 'light rain', 'rain and snow', 'moderate rain', 'broken clouds', 'moderate rain', 'light rain', 'moderate rain', 'light rain', 'rain and snow', 'moderate rain', 'clear sky', 'light rain', 'rain and snow', 'rain and snow', 'moderate rain', 'rain and snow', 'moderate rain', 'light rain', 'light rain', 'light rain', 'moderate rain', 'moderate rain', 'rain and snow', 'moderate rain', 'moderate rain', 'light rain', 'light rain', 'rain and snow', 'rain and snow', 'rain and snow', 'light rain', 'moderate rain', 'moderate rain', 'light rain', 'rain and snow', 'rain and snow', 'rain and snow', 'moderate rain', 'moderate rain', 'light rain', 'light rain', 'rain and snow']
# ['moderate rain', 'light rain', 'moderate rain', 'light rain', 'moderate rain', 'light rain', 'rain and snow', 'moderate rain', 'broken clouds', 'moderate rain', 'light rain', 'moderate rain', 'light rain', 'rain and snow', 'moderate rain', 'clear sky', 'light rain', 'rain and snow', 'rain and snow', 'moderate rain', 'rain and snow', 'moderate rain', 'light rain', 'light rain', 'light rain', 'moderate rain', 'moderate rain', 'rain and snow', 'moderate rain', 'moderate rain', 'light rain', 'light rain', 'rain and snow', 'rain and snow', 'rain and snow', 'light rain', 'moderate rain', 'moderate rain', 'light rain', 'rain and snow', 'rain and snow', 'rain and snow', 'moderate rain', 'moderate rain', 'light rain', 'light rain', 'rain and snow', 'rain and snow']
# ['moderate rain', 'light rain', 'moderate rain', 'light rain', 'moderate rain', 'light rain', 'rain and snow', 'moderate rain', 'broken clouds', 'moderate rain', 'light rain', 'moderate rain', 'light rain', 'rain and snow', 'moderate rain', 'clear sky', 'light rain', 'rain and snow', 'rain and snow', 'moderate rain', 'rain and snow', 'moderate rain', 'light rain', 'light rain', 'light rain', 'moderate rain', 'moderate rain', 'rain and snow', 'moderate rain', 'moderate rain', 'light rain', 'light rain', 'rain and snow', 'rain and snow', 'rain and snow', 'light rain', 'moderate rain', 'moderate rain', 'light rain', 'rain and snow', 'rain and snow', 'rain and snow', 'moderate rain', 'moderate rain', 'light rain', 'light rain', 'rain and snow', 'rain and snow', 'rain and snow']
# ['moderate rain', 'light rain', 'moderate rain', 'light rain', 'moderate rain', 'light rain', 'rain and snow', 'moderate rain', 'broken clouds', 'moderate rain', 'light rain', 'moderate rain', 'light rain', 'rain and snow', 'moderate rain', 'clear sky', 'light rain', 'rain and snow', 'rain and snow', 'moderate rain', 'rain and snow', 'moderate rain', 'light rain', 'light rain', 'light rain', 'moderate rain', 'moderate rain', 'rain and snow', 'moderate rain', 'moderate rain', 'light rain', 'light rain', 'rain and snow', 'rain and snow', 'rain and snow', 'light rain', 'moderate rain', 'moderate rain', 'light rain', 'rain and snow', 'rain and snow', 'rain and snow', 'moderate rain', 'moderate rain', 'light rain', 'light rain', 'rain and snow', 'rain and snow', 'rain and snow', 'light rain']
# ['moderate rain', 'light rain', 'moderate rain', 'light rain', 'moderate rain', 'light rain', 'rain and snow', 'moderate rain', 'broken clouds', 'moderate rain', 'light rain', 'moderate rain', 'light rain', 'rain and snow', 'moderate rain', 'clear sky', 'light rain', 'rain and snow', 'rain and snow', 'moderate rain', 'rain and snow', 'moderate rain', 'light rain', 'light rain', 'light rain', 'moderate rain', 'moderate rain', 'rain and snow', 'moderate rain', 'moderate rain', 'light rain', 'light rain', 'rain and snow', 'rain and snow', 'rain and snow', 'light rain', 'moderate rain', 'moderate rain', 'light rain', 'rain and snow', 'rain and snow', 'rain and snow', 'moderate rain', 'moderate rain', 'light rain', 'light rain', 'rain and snow', 'rain and snow', 'rain and snow', 'light rain', 'moderate rain']
# ['moderate rain', 'light rain', 'moderate rain', 'light rain', 'moderate rain', 'light rain', 'rain and snow', 'moderate rain', 'broken clouds', 'moderate rain', 'light rain', 'moderate rain', 'light rain', 'rain and snow', 'moderate rain', 'clear sky', 'light rain', 'rain and snow', 'rain and snow', 'moderate rain', 'rain and snow', 'moderate rain', 'light rain', 'light rain', 'light rain', 'moderate rain', 'moderate rain', 'rain and snow', 'moderate rain', 'moderate rain', 'light rain', 'light rain', 'rain and snow', 'rain and snow', 'rain and snow', 'light rain', 'moderate rain', 'moderate rain', 'light rain', 'rain and snow', 'rain and snow', 'rain and snow', 'moderate rain', 'moderate rain', 'light rain', 'light rain', 'rain and snow', 'rain and snow', 'rain and snow', 'light rain', 'moderate rain', 'light rain']
# ['moderate rain', 'light rain', 'moderate rain', 'light rain', 'moderate rain', 'light rain', 'rain and snow', 'moderate rain', 'broken clouds', 'moderate rain', 'light rain', 'moderate rain', 'light rain', 'rain and snow', 'moderate rain', 'clear sky', 'light rain', 'rain and snow', 'rain and snow', 'moderate rain', 'rain and snow', 'moderate rain', 'light rain', 'light rain', 'light rain', 'moderate rain', 'moderate rain', 'rain and snow', 'moderate rain', 'moderate rain', 'light rain', 'light rain', 'rain and snow', 'rain and snow', 'rain and snow', 'light rain', 'moderate rain', 'moderate rain', 'light rain', 'rain and snow', 'rain and snow', 'rain and snow', 'moderate rain', 'moderate rain', 'light rain', 'light rain', 'rain and snow', 'rain and snow', 'rain and snow', 'light rain', 'moderate rain', 'light rain', 'light rain']
# ['moderate rain', 'light rain', 'moderate rain', 'light rain', 'moderate rain', 'light rain', 'rain and snow', 'moderate rain', 'broken clouds', 'moderate rain', 'light rain', 'moderate rain', 'light rain', 'rain and snow', 'moderate rain', 'clear sky', 'light rain', 'rain and snow', 'rain and snow', 'moderate rain', 'rain and snow', 'moderate rain', 'light rain', 'light rain', 'light rain', 'moderate rain', 'moderate rain', 'rain and snow', 'moderate rain', 'moderate rain', 'light rain', 'light rain', 'rain and snow', 'rain and snow', 'rain and snow', 'light rain', 'moderate rain', 'moderate rain', 'light rain', 'rain and snow', 'rain and snow', 'rain and snow', 'moderate rain', 'moderate rain', 'light rain', 'light rain', 'rain and snow', 'rain and snow', 'rain and snow', 'light rain', 'moderate rain', 'light rain', 'light rain', 'rain and snow']
# ['moderate rain', 'light rain', 'moderate rain', 'light rain', 'moderate rain', 'light rain', 'rain and snow', 'moderate rain', 'broken clouds', 'moderate rain', 'light rain', 'moderate rain', 'light rain', 'rain and snow', 'moderate rain', 'clear sky', 'light rain', 'rain and snow', 'rain and snow', 'moderate rain', 'rain and snow', 'moderate rain', 'light rain', 'light rain', 'light rain', 'moderate rain', 'moderate rain', 'rain and snow', 'moderate rain', 'moderate rain', 'light rain', 'light rain', 'rain and snow', 'rain and snow', 'rain and snow', 'light rain', 'moderate rain', 'moderate rain', 'light rain', 'rain and snow', 'rain and snow', 'rain and snow', 'moderate rain', 'moderate rain', 'light rain', 'light rain', 'rain and snow', 'rain and snow', 'rain and snow', 'light rain', 'moderate rain', 'light rain', 'light rain', 'rain and snow', 'light rain']
# ['moderate rain', 'light rain', 'moderate rain', 'light rain', 'moderate rain', 'light rain', 'rain and snow', 'moderate rain', 'broken clouds', 'moderate rain', 'light rain', 'moderate rain', 'light rain', 'rain and snow', 'moderate rain', 'clear sky', 'light rain', 'rain and snow', 'rain and snow', 'moderate rain', 'rain and snow', 'moderate rain', 'light rain', 'light rain', 'light rain', 'moderate rain', 'moderate rain', 'rain and snow', 'moderate rain', 'moderate rain', 'light rain', 'light rain', 'rain and snow', 'rain and snow', 'rain and snow', 'light rain', 'moderate rain', 'moderate rain', 'light rain', 'rain and snow', 'rain and snow', 'rain and snow', 'moderate rain', 'moderate rain', 'light rain', 'light rain', 'rain and snow', 'rain and snow', 'rain and snow', 'light rain', 'moderate rain', 'light rain', 'light rain', 'rain and snow', 'light rain', 'rain and snow']
# ['moderate rain', 'light rain', 'moderate rain', 'light rain', 'moderate rain', 'light rain', 'rain and snow', 'moderate rain', 'broken clouds', 'moderate rain', 'light rain', 'moderate rain', 'light rain', 'rain and snow', 'moderate rain', 'clear sky', 'light rain', 'rain and snow', 'rain and snow', 'moderate rain', 'rain and snow', 'moderate rain', 'light rain', 'light rain', 'light rain', 'moderate rain', 'moderate rain', 'rain and snow', 'moderate rain', 'moderate rain', 'light rain', 'light rain', 'rain and snow', 'rain and snow', 'rain and snow', 'light rain', 'moderate rain', 'moderate rain', 'light rain', 'rain and snow', 'rain and snow', 'rain and snow', 'moderate rain', 'moderate rain', 'light rain', 'light rain', 'rain and snow', 'rain and snow', 'rain and snow', 'light rain', 'moderate rain', 'light rain', 'light rain', 'rain and snow', 'light rain', 'rain and snow', 'overcast clouds']
# ['moderate rain', 'light rain', 'moderate rain', 'light rain', 'moderate rain', 'light rain', 'rain and snow', 'moderate rain', 'broken clouds', 'moderate rain', 'light rain', 'moderate rain', 'light rain', 'rain and snow', 'moderate rain', 'clear sky', 'light rain', 'rain and snow', 'rain and snow', 'moderate rain', 'rain and snow', 'moderate rain', 'light rain', 'light rain', 'light rain', 'moderate rain', 'moderate rain', 'rain and snow', 'moderate rain', 'moderate rain', 'light rain', 'light rain', 'rain and snow', 'rain and snow', 'rain and snow', 'light rain', 'moderate rain', 'moderate rain', 'light rain', 'rain and snow', 'rain and snow', 'rain and snow', 'moderate rain', 'moderate rain', 'light rain', 'light rain', 'rain and snow', 'rain and snow', 'rain and snow', 'light rain', 'moderate rain', 'light rain', 'light rain', 'rain and snow', 'light rain', 'rain and snow', 'overcast clouds', 'moderate rain']
# ['moderate rain', 'light rain', 'moderate rain', 'light rain', 'moderate rain', 'light rain', 'rain and snow', 'moderate rain', 'broken clouds', 'moderate rain', 'light rain', 'moderate rain', 'light rain', 'rain and snow', 'moderate rain', 'clear sky', 'light rain', 'rain and snow', 'rain and snow', 'moderate rain', 'rain and snow', 'moderate rain', 'light rain', 'light rain', 'light rain', 'moderate rain', 'moderate rain', 'rain and snow', 'moderate rain', 'moderate rain', 'light rain', 'light rain', 'rain and snow', 'rain and snow', 'rain and snow', 'light rain', 'moderate rain', 'moderate rain', 'light rain', 'rain and snow', 'rain and snow', 'rain and snow', 'moderate rain', 'moderate rain', 'light rain', 'light rain', 'rain and snow', 'rain and snow', 'rain and snow', 'light rain', 'moderate rain', 'light rain', 'light rain', 'rain and snow', 'light rain', 'rain and snow', 'overcast clouds', 'moderate rain', 'moderate rain']
# ['moderate rain', 'light rain', 'moderate rain', 'light rain', 'moderate rain', 'light rain', 'rain and snow', 'moderate rain', 'broken clouds', 'moderate rain', 'light rain', 'moderate rain', 'light rain', 'rain and snow', 'moderate rain', 'clear sky', 'light rain', 'rain and snow', 'rain and snow', 'moderate rain', 'rain and snow', 'moderate rain', 'light rain', 'light rain', 'light rain', 'moderate rain', 'moderate rain', 'rain and snow', 'moderate rain', 'moderate rain', 'light rain', 'light rain', 'rain and snow', 'rain and snow', 'rain and snow', 'light rain', 'moderate rain', 'moderate rain', 'light rain', 'rain and snow', 'rain and snow', 'rain and snow', 'moderate rain', 'moderate rain', 'light rain', 'light rain', 'rain and snow', 'rain and snow', 'rain and snow', 'light rain', 'moderate rain', 'light rain', 'light rain', 'rain and snow', 'light rain', 'rain and snow', 'overcast clouds', 'moderate rain', 'moderate rain', 'moderate rain']
# ['moderate rain', 'light rain', 'moderate rain', 'light rain', 'moderate rain', 'light rain', 'rain and snow', 'moderate rain', 'broken clouds', 'moderate rain', 'light rain', 'moderate rain', 'light rain', 'rain and snow', 'moderate rain', 'clear sky', 'light rain', 'rain and snow', 'rain and snow', 'moderate rain', 'rain and snow', 'moderate rain', 'light rain', 'light rain', 'light rain', 'moderate rain', 'moderate rain', 'rain and snow', 'moderate rain', 'moderate rain', 'light rain', 'light rain', 'rain and snow', 'rain and snow', 'rain and snow', 'light rain', 'moderate rain', 'moderate rain', 'light rain', 'rain and snow', 'rain and snow', 'rain and snow', 'moderate rain', 'moderate rain', 'light rain', 'light rain', 'rain and snow', 'rain and snow', 'rain and snow', 'light rain', 'moderate rain', 'light rain', 'light rain', 'rain and snow', 'light rain', 'rain and snow', 'overcast clouds', 'moderate rain', 'moderate rain', 'moderate rain', 'rain and snow']
# ['moderate rain', 'light rain', 'moderate rain', 'light rain', 'moderate rain', 'light rain', 'rain and snow', 'moderate rain', 'broken clouds', 'moderate rain', 'light rain', 'moderate rain', 'light rain', 'rain and snow', 'moderate rain', 'clear sky', 'light rain', 'rain and snow', 'rain and snow', 'moderate rain', 'rain and snow', 'moderate rain', 'light rain', 'light rain', 'light rain', 'moderate rain', 'moderate rain', 'rain and snow', 'moderate rain', 'moderate rain', 'light rain', 'light rain', 'rain and snow', 'rain and snow', 'rain and snow', 'light rain', 'moderate rain', 'moderate rain', 'light rain', 'rain and snow', 'rain and snow', 'rain and snow', 'moderate rain', 'moderate rain', 'light rain', 'light rain', 'rain and snow', 'rain and snow', 'rain and snow', 'light rain', 'moderate rain', 'light rain', 'light rain', 'rain and snow', 'light rain', 'rain and snow', 'overcast clouds', 'moderate rain', 'moderate rain', 'moderate rain', 'rain and snow', 'moderate rain']
# ['moderate rain', 'light rain', 'moderate rain', 'light rain', 'moderate rain', 'light rain', 'rain and snow', 'moderate rain', 'broken clouds', 'moderate rain', 'light rain', 'moderate rain', 'light rain', 'rain and snow', 'moderate rain', 'clear sky', 'light rain', 'rain and snow', 'rain and snow', 'moderate rain', 'rain and snow', 'moderate rain', 'light rain', 'light rain', 'light rain', 'moderate rain', 'moderate rain', 'rain and snow', 'moderate rain', 'moderate rain', 'light rain', 'light rain', 'rain and snow', 'rain and snow', 'rain and snow', 'light rain', 'moderate rain', 'moderate rain', 'light rain', 'rain and snow', 'rain and snow', 'rain and snow', 'moderate rain', 'moderate rain', 'light rain', 'light rain', 'rain and snow', 'rain and snow', 'rain and snow', 'light rain', 'moderate rain', 'light rain', 'light rain', 'rain and snow', 'light rain', 'rain and snow', 'overcast clouds', 'moderate rain', 'moderate rain', 'moderate rain', 'rain and snow', 'moderate rain', 'moderate rain']
# ['moderate rain', 'light rain', 'moderate rain', 'light rain', 'moderate rain', 'light rain', 'rain and snow', 'moderate rain', 'broken clouds', 'moderate rain', 'light rain', 'moderate rain', 'light rain', 'rain and snow', 'moderate rain', 'clear sky', 'light rain', 'rain and snow', 'rain and snow', 'moderate rain', 'rain and snow', 'moderate rain', 'light rain', 'light rain', 'light rain', 'moderate rain', 'moderate rain', 'rain and snow', 'moderate rain', 'moderate rain', 'light rain', 'light rain', 'rain and snow', 'rain and snow', 'rain and snow', 'light rain', 'moderate rain', 'moderate rain', 'light rain', 'rain and snow', 'rain and snow', 'rain and snow', 'moderate rain', 'moderate rain', 'light rain', 'light rain', 'rain and snow', 'rain and snow', 'rain and snow', 'light rain', 'moderate rain', 'light rain', 'light rain', 'rain and snow', 'light rain', 'rain and snow', 'overcast clouds', 'moderate rain', 'moderate rain', 'moderate rain', 'rain and snow', 'moderate rain', 'moderate rain', 'overcast clouds']
# ['moderate rain', 'light rain', 'moderate rain', 'light rain', 'moderate rain', 'light rain', 'rain and snow', 'moderate rain', 'broken clouds', 'moderate rain', 'light rain', 'moderate rain', 'light rain', 'rain and snow', 'moderate rain', 'clear sky', 'light rain', 'rain and snow', 'rain and snow', 'moderate rain', 'rain and snow', 'moderate rain', 'light rain', 'light rain', 'light rain', 'moderate rain', 'moderate rain', 'rain and snow', 'moderate rain', 'moderate rain', 'light rain', 'light rain', 'rain and snow', 'rain and snow', 'rain and snow', 'light rain', 'moderate rain', 'moderate rain', 'light rain', 'rain and snow', 'rain and snow', 'rain and snow', 'moderate rain', 'moderate rain', 'light rain', 'light rain', 'rain and snow', 'rain and snow', 'rain and snow', 'light rain', 'moderate rain', 'light rain', 'light rain', 'rain and snow', 'light rain', 'rain and snow', 'overcast clouds', 'moderate rain', 'moderate rain', 'moderate rain', 'rain and snow', 'moderate rain', 'moderate rain', 'overcast clouds', 'moderate rain']
# ['moderate rain', 'light rain', 'moderate rain', 'light rain', 'moderate rain', 'light rain', 'rain and snow', 'moderate rain', 'broken clouds', 'moderate rain', 'light rain', 'moderate rain', 'light rain', 'rain and snow', 'moderate rain', 'clear sky', 'light rain', 'rain and snow', 'rain and snow', 'moderate rain', 'rain and snow', 'moderate rain', 'light rain', 'light rain', 'light rain', 'moderate rain', 'moderate rain', 'rain and snow', 'moderate rain', 'moderate rain', 'light rain', 'light rain', 'rain and snow', 'rain and snow', 'rain and snow', 'light rain', 'moderate rain', 'moderate rain', 'light rain', 'rain and snow', 'rain and snow', 'rain and snow', 'moderate rain', 'moderate rain', 'light rain', 'light rain', 'rain and snow', 'rain and snow', 'rain and snow', 'light rain', 'moderate rain', 'light rain', 'light rain', 'rain and snow', 'light rain', 'rain and snow', 'overcast clouds', 'moderate rain', 'moderate rain', 'moderate rain', 'rain and snow', 'moderate rain', 'moderate rain', 'overcast clouds', 'moderate rain', 'moderate rain']
# ['moderate rain', 'light rain', 'moderate rain', 'light rain', 'moderate rain', 'light rain', 'rain and snow', 'moderate rain', 'broken clouds', 'moderate rain', 'light rain', 'moderate rain', 'light rain', 'rain and snow', 'moderate rain', 'clear sky', 'light rain', 'rain and snow', 'rain and snow', 'moderate rain', 'rain and snow', 'moderate rain', 'light rain', 'light rain', 'light rain', 'moderate rain', 'moderate rain', 'rain and snow', 'moderate rain', 'moderate rain', 'light rain', 'light rain', 'rain and snow', 'rain and snow', 'rain and snow', 'light rain', 'moderate rain', 'moderate rain', 'light rain', 'rain and snow', 'rain and snow', 'rain and snow', 'moderate rain', 'moderate rain', 'light rain', 'light rain', 'rain and snow', 'rain and snow', 'rain and snow', 'light rain', 'moderate rain', 'light rain', 'light rain', 'rain and snow', 'light rain', 'rain and snow', 'overcast clouds', 'moderate rain', 'moderate rain', 'moderate rain', 'rain and snow', 'moderate rain', 'moderate rain', 'overcast clouds', 'moderate rain', 'moderate rain', 'moderate rain']
# ['moderate rain', 'light rain', 'moderate rain', 'light rain', 'moderate rain', 'light rain', 'rain and snow', 'moderate rain', 'broken clouds', 'moderate rain', 'light rain', 'moderate rain', 'light rain', 'rain and snow', 'moderate rain', 'clear sky', 'light rain', 'rain and snow', 'rain and snow', 'moderate rain', 'rain and snow', 'moderate rain', 'light rain', 'light rain', 'light rain', 'moderate rain', 'moderate rain', 'rain and snow', 'moderate rain', 'moderate rain', 'light rain', 'light rain', 'rain and snow', 'rain and snow', 'rain and snow', 'light rain', 'moderate rain', 'moderate rain', 'light rain', 'rain and snow', 'rain and snow', 'rain and snow', 'moderate rain', 'moderate rain', 'light rain', 'light rain', 'rain and snow', 'rain and snow', 'rain and snow', 'light rain', 'moderate rain', 'light rain', 'light rain', 'rain and snow', 'light rain', 'rain and snow', 'overcast clouds', 'moderate rain', 'moderate rain', 'moderate rain', 'rain and snow', 'moderate rain', 'moderate rain', 'overcast clouds', 'moderate rain', 'moderate rain', 'moderate rain', 'light snow']
# ['moderate rain', 'light rain', 'moderate rain', 'light rain', 'moderate rain', 'light rain', 'rain and snow', 'moderate rain', 'broken clouds', 'moderate rain', 'light rain', 'moderate rain', 'light rain', 'rain and snow', 'moderate rain', 'clear sky', 'light rain', 'rain and snow', 'rain and snow', 'moderate rain', 'rain and snow', 'moderate rain', 'light rain', 'light rain', 'light rain', 'moderate rain', 'moderate rain', 'rain and snow', 'moderate rain', 'moderate rain', 'light rain', 'light rain', 'rain and snow', 'rain and snow', 'rain and snow', 'light rain', 'moderate rain', 'moderate rain', 'light rain', 'rain and snow', 'rain and snow', 'rain and snow', 'moderate rain', 'moderate rain', 'light rain', 'light rain', 'rain and snow', 'rain and snow', 'rain and snow', 'light rain', 'moderate rain', 'light rain', 'light rain', 'rain and snow', 'light rain', 'rain and snow', 'overcast clouds', 'moderate rain', 'moderate rain', 'moderate rain', 'rain and snow', 'moderate rain', 'moderate rain', 'overcast clouds', 'moderate rain', 'moderate rain', 'moderate rain', 'light snow', 'rain and snow']
# ['moderate rain', 'light rain', 'moderate rain', 'light rain', 'moderate rain', 'light rain', 'rain and snow', 'moderate rain', 'broken clouds', 'moderate rain', 'light rain', 'moderate rain', 'light rain', 'rain and snow', 'moderate rain', 'clear sky', 'light rain', 'rain and snow', 'rain and snow', 'moderate rain', 'rain and snow', 'moderate rain', 'light rain', 'light rain', 'light rain', 'moderate rain', 'moderate rain', 'rain and snow', 'moderate rain', 'moderate rain', 'light rain', 'light rain', 'rain and snow', 'rain and snow', 'rain and snow', 'light rain', 'moderate rain', 'moderate rain', 'light rain', 'rain and snow', 'rain and snow', 'rain and snow', 'moderate rain', 'moderate rain', 'light rain', 'light rain', 'rain and snow', 'rain and snow', 'rain and snow', 'light rain', 'moderate rain', 'light rain', 'light rain', 'rain and snow', 'light rain', 'rain and snow', 'overcast clouds', 'moderate rain', 'moderate rain', 'moderate rain', 'rain and snow', 'moderate rain', 'moderate rain', 'overcast clouds', 'moderate rain', 'moderate rain', 'moderate rain', 'light snow', 'rain and snow', 'rain and snow']
# ['moderate rain', 'light rain', 'moderate rain', 'light rain', 'moderate rain', 'light rain', 'rain and snow', 'moderate rain', 'broken clouds', 'moderate rain', 'light rain', 'moderate rain', 'light rain', 'rain and snow', 'moderate rain', 'clear sky', 'light rain', 'rain and snow', 'rain and snow', 'moderate rain', 'rain and snow', 'moderate rain', 'light rain', 'light rain', 'light rain', 'moderate rain', 'moderate rain', 'rain and snow', 'moderate rain', 'moderate rain', 'light rain', 'light rain', 'rain and snow', 'rain and snow', 'rain and snow', 'light rain', 'moderate rain', 'moderate rain', 'light rain', 'rain and snow', 'rain and snow', 'rain and snow', 'moderate rain', 'moderate rain', 'light rain', 'light rain', 'rain and snow', 'rain and snow', 'rain and snow', 'light rain', 'moderate rain', 'light rain', 'light rain', 'rain and snow', 'light rain', 'rain and snow', 'overcast clouds', 'moderate rain', 'moderate rain', 'moderate rain', 'rain and snow', 'moderate rain', 'moderate rain', 'overcast clouds', 'moderate rain', 'moderate rain', 'moderate rain', 'light snow', 'rain and snow', 'rain and snow', 'overcast clouds']
# ['moderate rain', 'light rain', 'moderate rain', 'light rain', 'moderate rain', 'light rain', 'rain and snow', 'moderate rain', 'broken clouds', 'moderate rain', 'light rain', 'moderate rain', 'light rain', 'rain and snow', 'moderate rain', 'clear sky', 'light rain', 'rain and snow', 'rain and snow', 'moderate rain', 'rain and snow', 'moderate rain', 'light rain', 'light rain', 'light rain', 'moderate rain', 'moderate rain', 'rain and snow', 'moderate rain', 'moderate rain', 'light rain', 'light rain', 'rain and snow', 'rain and snow', 'rain and snow', 'light rain', 'moderate rain', 'moderate rain', 'light rain', 'rain and snow', 'rain and snow', 'rain and snow', 'moderate rain', 'moderate rain', 'light rain', 'light rain', 'rain and snow', 'rain and snow', 'rain and snow', 'light rain', 'moderate rain', 'light rain', 'light rain', 'rain and snow', 'light rain', 'rain and snow', 'overcast clouds', 'moderate rain', 'moderate rain', 'moderate rain', 'rain and snow', 'moderate rain', 'moderate rain', 'overcast clouds', 'moderate rain', 'moderate rain', 'moderate rain', 'light snow', 'rain and snow', 'rain and snow', 'overcast clouds', 'moderate rain']
# ['moderate rain', 'light rain', 'moderate rain', 'light rain', 'moderate rain', 'light rain', 'rain and snow', 'moderate rain', 'broken clouds', 'moderate rain', 'light rain', 'moderate rain', 'light rain', 'rain and snow', 'moderate rain', 'clear sky', 'light rain', 'rain and snow', 'rain and snow', 'moderate rain', 'rain and snow', 'moderate rain', 'light rain', 'light rain', 'light rain', 'moderate rain', 'moderate rain', 'rain and snow', 'moderate rain', 'moderate rain', 'light rain', 'light rain', 'rain and snow', 'rain and snow', 'rain and snow', 'light rain', 'moderate rain', 'moderate rain', 'light rain', 'rain and snow', 'rain and snow', 'rain and snow', 'moderate rain', 'moderate rain', 'light rain', 'light rain', 'rain and snow', 'rain and snow', 'rain and snow', 'light rain', 'moderate rain', 'light rain', 'light rain', 'rain and snow', 'light rain', 'rain and snow', 'overcast clouds', 'moderate rain', 'moderate rain', 'moderate rain', 'rain and snow', 'moderate rain', 'moderate rain', 'overcast clouds', 'moderate rain', 'moderate rain', 'moderate rain', 'light snow', 'rain and snow', 'rain and snow', 'overcast clouds', 'moderate rain', 'moderate rain']
# ['moderate rain', 'light rain', 'moderate rain', 'light rain', 'moderate rain', 'light rain', 'rain and snow', 'moderate rain', 'broken clouds', 'moderate rain', 'light rain', 'moderate rain', 'light rain', 'rain and snow', 'moderate rain', 'clear sky', 'light rain', 'rain and snow', 'rain and snow', 'moderate rain', 'rain and snow', 'moderate rain', 'light rain', 'light rain', 'light rain', 'moderate rain', 'moderate rain', 'rain and snow', 'moderate rain', 'moderate rain', 'light rain', 'light rain', 'rain and snow', 'rain and snow', 'rain and snow', 'light rain', 'moderate rain', 'moderate rain', 'light rain', 'rain and snow', 'rain and snow', 'rain and snow', 'moderate rain', 'moderate rain', 'light rain', 'light rain', 'rain and snow', 'rain and snow', 'rain and snow', 'light rain', 'moderate rain', 'light rain', 'light rain', 'rain and snow', 'light rain', 'rain and snow', 'overcast clouds', 'moderate rain', 'moderate rain', 'moderate rain', 'rain and snow', 'moderate rain', 'moderate rain', 'overcast clouds', 'moderate rain', 'moderate rain', 'moderate rain', 'light snow', 'rain and snow', 'rain and snow', 'overcast clouds', 'moderate rain', 'moderate rain', 'moderate rain']
# ['moderate rain', 'light rain', 'moderate rain', 'light rain', 'moderate rain', 'light rain', 'rain and snow', 'moderate rain', 'broken clouds', 'moderate rain', 'light rain', 'moderate rain', 'light rain', 'rain and snow', 'moderate rain', 'clear sky', 'light rain', 'rain and snow', 'rain and snow', 'moderate rain', 'rain and snow', 'moderate rain', 'light rain', 'light rain', 'light rain', 'moderate rain', 'moderate rain', 'rain and snow', 'moderate rain', 'moderate rain', 'light rain', 'light rain', 'rain and snow', 'rain and snow', 'rain and snow', 'light rain', 'moderate rain', 'moderate rain', 'light rain', 'rain and snow', 'rain and snow', 'rain and snow', 'moderate rain', 'moderate rain', 'light rain', 'light rain', 'rain and snow', 'rain and snow', 'rain and snow', 'light rain', 'moderate rain', 'light rain', 'light rain', 'rain and snow', 'light rain', 'rain and snow', 'overcast clouds', 'moderate rain', 'moderate rain', 'moderate rain', 'rain and snow', 'moderate rain', 'moderate rain', 'overcast clouds', 'moderate rain', 'moderate rain', 'moderate rain', 'light snow', 'rain and snow', 'rain and snow', 'overcast clouds', 'moderate rain', 'moderate rain', 'moderate rain', 'light snow']
# ['moderate rain', 'light rain', 'moderate rain', 'light rain', 'moderate rain', 'light rain', 'rain and snow', 'moderate rain', 'broken clouds', 'moderate rain', 'light rain', 'moderate rain', 'light rain', 'rain and snow', 'moderate rain', 'clear sky', 'light rain', 'rain and snow', 'rain and snow', 'moderate rain', 'rain and snow', 'moderate rain', 'light rain', 'light rain', 'light rain', 'moderate rain', 'moderate rain', 'rain and snow', 'moderate rain', 'moderate rain', 'light rain', 'light rain', 'rain and snow', 'rain and snow', 'rain and snow', 'light rain', 'moderate rain', 'moderate rain', 'light rain', 'rain and snow', 'rain and snow', 'rain and snow', 'moderate rain', 'moderate rain', 'light rain', 'light rain', 'rain and snow', 'rain and snow', 'rain and snow', 'light rain', 'moderate rain', 'light rain', 'light rain', 'rain and snow', 'light rain', 'rain and snow', 'overcast clouds', 'moderate rain', 'moderate rain', 'moderate rain', 'rain and snow', 'moderate rain', 'moderate rain', 'overcast clouds', 'moderate rain', 'moderate rain', 'moderate rain', 'light snow', 'rain and snow', 'rain and snow', 'overcast clouds', 'moderate rain', 'moderate rain', 'moderate rain', 'light snow', 'rain and snow']
# ...
# ['moderate rain', 'light rain', 'moderate rain', 'light rain', 'moderate rain', 'light rain', 'rain and snow', 'moderate rain', 'broken clouds', 'moderate rain', 'light rain', 'moderate rain', 'light rain', 'rain and snow', 'moderate rain', 'clear sky', 'light rain', 'rain and snow', 'rain and snow', 'moderate rain', 'rain and snow', 'moderate rain', 'light rain', 'light rain', 'light rain', 'moderate rain', 'moderate rain', 'rain and snow', 'moderate rain', 'moderate rain', 'light rain', 'light rain', 'rain and snow', 'rain and snow', 'rain and snow', 'light rain', 'moderate rain', 'moderate rain', 'light rain', 'rain and snow', 'rain and snow', 'rain and snow', 'moderate rain', 'moderate rain', 'light rain', 'light rain', 'rain and snow', 'rain and snow', 'rain and snow', 'light rain', 'moderate rain', 'light rain', 'light rain', 'rain and snow', 'light rain', 'rain and snow', 'overcast clouds', 'moderate rain', 'moderate rain', 'moderate rain', 'rain and snow', 'moderate rain', 'moderate rain', 'overcast clouds', 'moderate rain', 'moderate rain', 'moderate rain', 'light snow', 'rain and snow', 'rain and snow', 'overcast clouds', 'moderate rain', 'moderate rain', 'moderate rain', 'light snow', 'rain and snow', 'rain and snow', 'overcast clouds', 'moderate rain', 'moderate rain', 'moderate rain', 'light snow', 'rain and snow', 'rain and snow', 'overcast clouds', 'moderate rain', 'light rain', 'rain and snow', 'snow', 'moderate rain', 'rain and snow', 'overcast clouds', 'moderate rain', 'light rain', 'moderate rain', 'light snow', 'rain and snow', 'moderate rain', 'overcast clouds', 'moderate rain', 'light rain', 'rain and snow', 'snow', 'rain and snow', 'rain and snow', 'overcast clouds', 'moderate rain', 'light rain', 'rain and snow', 'light snow', 'rain and snow', 'rain and snow', 'overcast clouds', 'light rain', 'light rain', 'moderate rain', 'rain and snow', 'light rain', 'light rain', 'overcast clouds', 'broken clouds', 'broken clouds', 'overcast clouds', 'clear sky', 'rain and snow', 'light rain', 'overcast clouds', 'broken clouds', 'overcast clouds', 'light rain', 'clear sky', 'light rain', 'light rain', 'broken clouds', 'broken clouds', 'overcast clouds', 'overcast clouds', 'clear sky', 'moderate rain', 'light rain', 'broken clouds', 'broken clouds', 'overcast clouds', 'overcast clouds', 'clear sky', 'moderate rain', 'light rain', 'broken clouds', 'broken clouds', 'overcast clouds', 'overcast clouds', 'clear sky', 'moderate rain', 'light rain', 'overcast clouds', 'overcast clouds', 'broken clouds', 'overcast clouds', 'clear sky', 'light rain', 'light rain', 'overcast clouds', 'overcast clouds', 'overcast clouds', 'overcast clouds', 'light rain', 'light rain', 'light rain', 'overcast clouds', 'overcast clouds', 'overcast clouds', 'overcast clouds', 'clear sky', 'light rain', 'light rain', 'broken clouds', 'overcast clouds', 'overcast clouds', 'light rain', 'clear sky', 'light rain', 'light rain', 'overcast clouds', 'overcast clouds', 'overcast clouds', 'light rain', 'clear sky', 'light rain', 'light rain', 'broken clouds', 'overcast clouds', 'broken clouds', 'light rain', 'light rain', 'light rain', 'light rain', 'broken clouds', 'overcast clouds', 'overcast clouds', 'light rain', 'light rain', 'light rain', 'light rain', 'broken clouds', 'overcast clouds', 'overcast clouds', 'rain and snow', 'light snow', 'rain and snow', 'snow', 'overcast clouds', 'overcast clouds', 'overcast clouds', 'light rain', 'light rain', 'light rain', 'moderate rain', 'overcast clouds', 'light rain', 'overcast clouds', 'light rain', 'broken clouds', 'light rain', 'moderate rain', 'overcast clouds', 'overcast clouds', 'overcast clouds', 'moderate rain', 'light rain', 'moderate rain', 'moderate rain', 'overcast clouds', 'overcast clouds', 'overcast clouds', 'moderate rain', 'moderate rain', 'moderate rain', 'moderate rain', 'moderate rain', 'light rain', 'moderate rain', 'moderate rain', 'moderate rain']
# ['moderate rain', 'light rain', 'moderate rain', 'light rain', 'moderate rain', 'light rain', 'rain and snow', 'moderate rain', 'broken clouds', 'moderate rain', 'light rain', 'moderate rain', 'light rain', 'rain and snow', 'moderate rain', 'clear sky', 'light rain', 'rain and snow', 'rain and snow', 'moderate rain', 'rain and snow', 'moderate rain', 'light rain', 'light rain', 'light rain', 'moderate rain', 'moderate rain', 'rain and snow', 'moderate rain', 'moderate rain', 'light rain', 'light rain', 'rain and snow', 'rain and snow', 'rain and snow', 'light rain', 'moderate rain', 'moderate rain', 'light rain', 'rain and snow', 'rain and snow', 'rain and snow', 'moderate rain', 'moderate rain', 'light rain', 'light rain', 'rain and snow', 'rain and snow', 'rain and snow', 'light rain', 'moderate rain', 'light rain', 'light rain', 'rain and snow', 'light rain', 'rain and snow', 'overcast clouds', 'moderate rain', 'moderate rain', 'moderate rain', 'rain and snow', 'moderate rain', 'moderate rain', 'overcast clouds', 'moderate rain', 'moderate rain', 'moderate rain', 'light snow', 'rain and snow', 'rain and snow', 'overcast clouds', 'moderate rain', 'moderate rain', 'moderate rain', 'light snow', 'rain and snow', 'rain and snow', 'overcast clouds', 'moderate rain', 'moderate rain', 'moderate rain', 'light snow', 'rain and snow', 'rain and snow', 'overcast clouds', 'moderate rain', 'light rain', 'rain and snow', 'snow', 'moderate rain', 'rain and snow', 'overcast clouds', 'moderate rain', 'light rain', 'moderate rain', 'light snow', 'rain and snow', 'moderate rain', 'overcast clouds', 'moderate rain', 'light rain', 'rain and snow', 'snow', 'rain and snow', 'rain and snow', 'overcast clouds', 'moderate rain', 'light rain', 'rain and snow', 'light snow', 'rain and snow', 'rain and snow', 'overcast clouds', 'light rain', 'light rain', 'moderate rain', 'rain and snow', 'light rain', 'light rain', 'overcast clouds', 'broken clouds', 'broken clouds', 'overcast clouds', 'clear sky', 'rain and snow', 'light rain', 'overcast clouds', 'broken clouds', 'overcast clouds', 'light rain', 'clear sky', 'light rain', 'light rain', 'broken clouds', 'broken clouds', 'overcast clouds', 'overcast clouds', 'clear sky', 'moderate rain', 'light rain', 'broken clouds', 'broken clouds', 'overcast clouds', 'overcast clouds', 'clear sky', 'moderate rain', 'light rain', 'broken clouds', 'broken clouds', 'overcast clouds', 'overcast clouds', 'clear sky', 'moderate rain', 'light rain', 'overcast clouds', 'overcast clouds', 'broken clouds', 'overcast clouds', 'clear sky', 'light rain', 'light rain', 'overcast clouds', 'overcast clouds', 'overcast clouds', 'overcast clouds', 'light rain', 'light rain', 'light rain', 'overcast clouds', 'overcast clouds', 'overcast clouds', 'overcast clouds', 'clear sky', 'light rain', 'light rain', 'broken clouds', 'overcast clouds', 'overcast clouds', 'light rain', 'clear sky', 'light rain', 'light rain', 'overcast clouds', 'overcast clouds', 'overcast clouds', 'light rain', 'clear sky', 'light rain', 'light rain', 'broken clouds', 'overcast clouds', 'broken clouds', 'light rain', 'light rain', 'light rain', 'light rain', 'broken clouds', 'overcast clouds', 'overcast clouds', 'light rain', 'light rain', 'light rain', 'light rain', 'broken clouds', 'overcast clouds', 'overcast clouds', 'rain and snow', 'light snow', 'rain and snow', 'snow', 'overcast clouds', 'overcast clouds', 'overcast clouds', 'light rain', 'light rain', 'light rain', 'moderate rain', 'overcast clouds', 'light rain', 'overcast clouds', 'light rain', 'broken clouds', 'light rain', 'moderate rain', 'overcast clouds', 'overcast clouds', 'overcast clouds', 'moderate rain', 'light rain', 'moderate rain', 'moderate rain', 'overcast clouds', 'overcast clouds', 'overcast clouds', 'moderate rain', 'moderate rain', 'moderate rain', 'moderate rain', 'moderate rain', 'light rain', 'moderate rain', 'moderate rain', 'moderate rain', 'moderate rain']
# ['moderate rain', 'light rain', 'moderate rain', 'light rain', 'moderate rain', 'light rain', 'rain and snow', 'moderate rain', 'broken clouds', 'moderate rain', 'light rain', 'moderate rain', 'light rain', 'rain and snow', 'moderate rain', 'clear sky', 'light rain', 'rain and snow', 'rain and snow', 'moderate rain', 'rain and snow', 'moderate rain', 'light rain', 'light rain', 'light rain', 'moderate rain', 'moderate rain', 'rain and snow', 'moderate rain', 'moderate rain', 'light rain', 'light rain', 'rain and snow', 'rain and snow', 'rain and snow', 'light rain', 'moderate rain', 'moderate rain', 'light rain', 'rain and snow', 'rain and snow', 'rain and snow', 'moderate rain', 'moderate rain', 'light rain', 'light rain', 'rain and snow', 'rain and snow', 'rain and snow', 'light rain', 'moderate rain', 'light rain', 'light rain', 'rain and snow', 'light rain', 'rain and snow', 'overcast clouds', 'moderate rain', 'moderate rain', 'moderate rain', 'rain and snow', 'moderate rain', 'moderate rain', 'overcast clouds', 'moderate rain', 'moderate rain', 'moderate rain', 'light snow', 'rain and snow', 'rain and snow', 'overcast clouds', 'moderate rain', 'moderate rain', 'moderate rain', 'light snow', 'rain and snow', 'rain and snow', 'overcast clouds', 'moderate rain', 'moderate rain', 'moderate rain', 'light snow', 'rain and snow', 'rain and snow', 'overcast clouds', 'moderate rain', 'light rain', 'rain and snow', 'snow', 'moderate rain', 'rain and snow', 'overcast clouds', 'moderate rain', 'light rain', 'moderate rain', 'light snow', 'rain and snow', 'moderate rain', 'overcast clouds', 'moderate rain', 'light rain', 'rain and snow', 'snow', 'rain and snow', 'rain and snow', 'overcast clouds', 'moderate rain', 'light rain', 'rain and snow', 'light snow', 'rain and snow', 'rain and snow', 'overcast clouds', 'light rain', 'light rain', 'moderate rain', 'rain and snow', 'light rain', 'light rain', 'overcast clouds', 'broken clouds', 'broken clouds', 'overcast clouds', 'clear sky', 'rain and snow', 'light rain', 'overcast clouds', 'broken clouds', 'overcast clouds', 'light rain', 'clear sky', 'light rain', 'light rain', 'broken clouds', 'broken clouds', 'overcast clouds', 'overcast clouds', 'clear sky', 'moderate rain', 'light rain', 'broken clouds', 'broken clouds', 'overcast clouds', 'overcast clouds', 'clear sky', 'moderate rain', 'light rain', 'broken clouds', 'broken clouds', 'overcast clouds', 'overcast clouds', 'clear sky', 'moderate rain', 'light rain', 'overcast clouds', 'overcast clouds', 'broken clouds', 'overcast clouds', 'clear sky', 'light rain', 'light rain', 'overcast clouds', 'overcast clouds', 'overcast clouds', 'overcast clouds', 'light rain', 'light rain', 'light rain', 'overcast clouds', 'overcast clouds', 'overcast clouds', 'overcast clouds', 'clear sky', 'light rain', 'light rain', 'broken clouds', 'overcast clouds', 'overcast clouds', 'light rain', 'clear sky', 'light rain', 'light rain', 'overcast clouds', 'overcast clouds', 'overcast clouds', 'light rain', 'clear sky', 'light rain', 'light rain', 'broken clouds', 'overcast clouds', 'broken clouds', 'light rain', 'light rain', 'light rain', 'light rain', 'broken clouds', 'overcast clouds', 'overcast clouds', 'light rain', 'light rain', 'light rain', 'light rain', 'broken clouds', 'overcast clouds', 'overcast clouds', 'rain and snow', 'light snow', 'rain and snow', 'snow', 'overcast clouds', 'overcast clouds', 'overcast clouds', 'light rain', 'light rain', 'light rain', 'moderate rain', 'overcast clouds', 'light rain', 'overcast clouds', 'light rain', 'broken clouds', 'light rain', 'moderate rain', 'overcast clouds', 'overcast clouds', 'overcast clouds', 'moderate rain', 'light rain', 'moderate rain', 'moderate rain', 'overcast clouds', 'overcast clouds', 'overcast clouds', 'moderate rain', 'moderate rain', 'moderate rain', 'moderate rain', 'moderate rain', 'light rain', 'moderate rain', 'moderate rain', 'moderate rain', 'moderate rain', 'moderate rain']
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [18], in <cell line: 19>()
#      15     date.append(_dict['Date'])
#      17     print(weather)
# ---> 19 lat_lon['Weather'] = weather
#      20 lat_lon['Temperature (°C)'] = temp
#      21 lat_lon['Humidity'] = hum
#
# File /opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py:3655, in DataFrame.__setitem__(self, key, value)
#    3652     self._setitem_array([key], value)
#    3653 else:
#    3654     # set column
# -> 3655     self._set_item(key, value)
#
# File /opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py:3832, in DataFrame._set_item(self, key, value)
#    3822 def _set_item(self, key, value) -> None:
#    3823     """
#    3824     Add series to DataFrame in specified column.
#    3825
#    (...)
#    3830     ensure homogeneity.
#    3831     """
# -> 3832     value = self._sanitize_column(value)
#    3834     if (
#    3835         key in self.columns
#    3836         and value.ndim == 1
#    3837         and not is_extension_array_dtype(value)
#    3838     ):
#    3839         # broadcast across multiple columns if necessary
#    3840         if not self.columns.is_unique or isinstance(self.columns, MultiIndex):
#
# File /opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py:4529, in DataFrame._sanitize_column(self, value)
#    4526     return _reindex_for_setitem(value, self.index)
#    4528 if is_list_like(value):
# -> 4529     com.require_length_match(value, self.index)
#    4530 return sanitize_array(value, self.index, copy=True, allow_2d=True)
#
# File /opt/anaconda3/lib/python3.8/site-packages/pandas/core/common.py:557, in require_length_match(data, index)
#     553 """
#     554 Check the length of data matches the length of the index.
#     555 """
#     556 if len(data) != len(index):
# --> 557     raise ValueError(
#     558         "Length of values "
#     559         f"({len(data)}) "
#     560         "does not match length of index "
#     561         f"({len(index)})"
#     562     )
#
# ValueError: Length of values (245) does not match length of index (35)

# %%
# Tableau final météo des 35 villes (cities_list) sur 7j :

final_result

# %%
# Liste des villes avec meilleur météo les 7 prochains jours

best_cities_list = final_result.groupby('Cities').agg({'Temperature': [max]})
best_cities_list.columns
# Out:
# MultiIndex([('Temperature', 'max')],
#            )

# %%
# Liste des 5  villes avec meilleure météo les 7 prochains jours

best_five = best_cities_list.sort_values([("Temperature", "max")], ascending = False)

best_five = best_five.head()

best_five
# Out:
#                   Temperature
#                           max
# Cities
# La Rochelle             14.07
# Mont Saint Michel       13.39
# Bayeux                  13.14
# St Malo                 13.13
# Rouen                   12.79

# %%
# Download IMDB's Top 250 data
url = 'https://www.booking.com/searchresults.fr.html?ss=Paris'
#url = "https://www.kayak.fr/hotels/Paris,France-c36014/2023-01-13/2023-01-15/1adults"

#url = "https://www.trivago.fr/fr/odr/h%C3%B4tels-france?search=200-56"
r_booking = requests.get(url, headers = {'User-Agent': 'Mozilla/5.0 (Linux; Android 6.0; Nexus 5 Build/MRA58N) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/108.0.0.0 Mobile Safari/537.36'})
# Instanciate BeautifulSoup class
soup = BeautifulSoup(r_booking.content, "html.parser") # Here we used an HTML Parser
link = soup.a

#ce print permet d’afficher la page html du site a partir
#de la div de la classe=“hotel_summary”
#soup.select(".bg-white.rounded.SlideoutContainer_shadow__CA7DE.2xl:rounded-sm")

# %%
soup.head()
# Out:
# [<link crossorigin="" href="https://cf.bstatic.com" rel="dns-prefetch"/>,
#  <link crossorigin="" href="https://cf.bstatic.com" rel="dns-prefetch"/>,
#  <script nonce="WtWEDzpC6GZb9pD" type="text/javascript">
#  document.addEventListener('DOMContentLoaded', function () {
#  /**
#  * provides the current user's cookie consent
#  * in order to use it:
#  * 1. inline privacy/cookieConsent.js in the page you need to use it.
#  * please note that this library relies on window.PCM.isCountryNeedCookieBanner to be initialised
#  * before using (calling getValue function) it
#  * 2. in your js file:
#  *
#  * var privacyCookieConsent = B.require('privacyCookieConsent');
#  * var consent = privacyCookieConsent.getValue();
#  */
#  B.define('privacyCookieConsent', function () {
#  var consentGroupIsAllowed = {
#  analytical: 'C0002%3A1',
#  marketing: 'C0004%3A1'
#  };
#  var optanonConsentCookieName = 'OptanonConsent';
#  var optanonBoxClosedCookieName = 'OptanonAlertBoxClosed';
#  var halfOfYearMillis = 180 * 24 * 60 * 60 * 1000;
#  function isDefined(value) {
#  return value && value !== "undefined";
#  }
#  function parseConsentToObject(consent) {
#  var result = {};
#  if (typeof consent === 'string') {
#  var parts = consent.split('&');
#  parts.forEach(function (part) {
#  var keyAndValue = part.split('=');
#  result[keyAndValue[0]] = keyAndValue[1];
#  });
#  }
#  return result;
#  }
#  function isConsentValid(consent, alertBoxClosed) {
#  return isDefined(consent) &&
#  isDefined(alertBoxClosed) &&
#  new Date() - new Date(alertBoxClosed) <= halfOfYearMillis;
#  }
#  function getCookie(name) {
#  name += "=";
#  var cookies = document.cookie.split(";");
#  for (var i = 0; i < cookies.length; i += 1) {
#  var cookie = cookies[i];
#  while (cookie.charAt(0) === " ") {
#  cookie = cookie.substring(1, cookie.length);
#  }
#  if (cookie.indexOf(name) === 0) {
#  return cookie.substring(name.length, cookie.length);
#  }
#  }
#  return null;
#  }
#  function doesGeolocationRequireBanner() {
#  // In case window.PCM is not defined, fallback to opt-out
#  return window.PCM ? window.PCM.isCountryNeedCookieBanner : true;
#  }
#  function getExplicitConsent() {
#  var consent = getCookie(optanonConsentCookieName);
#  var alertBoxClosed = getCookie(optanonBoxClosedCookieName);
#  if (isConsentValid(consent, alertBoxClosed)) {
#  var consentObject = parseConsentToObject(consent);
#  return Object
#  .keys(consentGroupIsAllowed)
#  .map(function (purpose) {
#  var result = {};
#  result[purpose] = consentObject.groups.indexOf(consentGroupIsAllowed[purpose]) > -1;
#  return result;
#  })
#  .reduce(
#  function (result, currentValue) {
#  return Object.assign(result, currentValue);
#  }, {
#  functional: true
#  }
#  );
#  }
#  }
#  function getImplicitConsent() {
#  var consentValue = !doesGeolocationRequireBanner();
#  return {
#  functional: true,
#  analytical: consentValue,
#  marketing: consentValue
#  };
#  }
#  function getValue() {
#  var consent = getExplicitConsent();
#  if (!consent) {
#  consent = getImplicitConsent();
#  }
#  return consent;
#  }
#  return {
#  getValue: getValue
#  };
#  });
#  //c360 javascript tracker first iteration
#  //sends a track request to c360 http tracker
#  //in order to use it:
#  //1. inline the c360Tracker.js in the page you need to use it
#  //2. in your js file:
#  //
#  // var c360Tracker = B.require('c360Tracker');
#  // var event = {
#  // action_name:"accommodation_checkout_confirmation_viewed",
#  // action_version :"0.2.0",
#  // content : { "transaction_id" : 123434},
#  // user : { "BKNG_user_id": 123434}
#  // };
#  // c360Tracker.track(event);
#  B.define('c360Tracker', function () {
#  var enrichedContext = {};
#  var configuration = {
#  validateInput: false
#  };
#  var track = function (event) {
#  if (event == null) {
#  return "event object is null or empty";
#  } else {
#  //if (enrichedContext.userID != null) {
#  // event.user = {BKNG_user_id: enrichedContext.userID};
#  //}
#  var validationResult = new ValidationResult(true);
#  if (configuration.validateInput) {
#  validationResult = validateInput(event);
#  }
#  if (!validationResult.success) {
#  return validationResult.message;
#  }
#  send(event);
#  }
#  };
#  function send(data) {
#  data.context = enrichedContext;
#  data.tracker = {
#  tracker_name: "C360JSTracker",
#  tracker_type: "Client",
#  tracker_version: "0.1.0"
#  };
#  return $.ajax({
#  url: '/c360/v1/track',
#  type: 'POST',
#  data: JSON.stringify(data),
#  });
#  }
#  enrich();
#  var scheme =
#  {
#  "type": "object",
#  "properties": {
#  "action_name": {
#  "type": "string",
#  "description": "action name (ex. element viewed)",
#  },
#  "action_version": {
#  "type": "string",
#  "description": "action version"
#  },
#  "content": {
#  "type": "object",
#  "description": "content defined by the registered producer scheme"
#  }
#  }
#  };
#  function ValidationResult(success, message) {
#  this.success = success;
#  this.message = message;
#  }
#  function validateInput(event) {
#  var result = validateObject(event, scheme);
#  return result;
#  }
#  function validateObject(obj, scheme) {
#  if (scheme.properties != null) {
#  var propsArray = Object.getOwnPropertyNames(scheme.properties);
#  for (var i = 0; i < propsArray.length; i++) {
#  var propertyName = propsArray[i];
#  if (obj[propertyName] == null) {
#  return new ValidationResult(false, "property " + propertyName + " is not defined");
#  }
#  if (scheme.properties[propertyName].type == "object") {
#  var validationResult = validateObject(obj[propertyName], scheme.properties[propertyName]);
#  if (validationResult.success === false) {
#  return validationResult;
#  }
#  }
#  }
#  }
#  return new ValidationResult(true);
#  }
#  function enrich() {
#  enrichedContext = {
#  page: {
#  page_referrer: document.referrer,
#  page_url: window.location.href,
#  page_title: document.title
#  },
#  local: {
#  currency: B.env.b_selected_currency
#  },
#  };
#  //if (B.env.b_user_genius_status != null && B.env.b_user_genius_status.b_user_id != null)
#  // enrichedContext.userID = B.env.b_user_genius_status.b_user_id;
#  }
#  return {
#  track: track
#  };
#  });
#  })
#  </script>,
#  <script nonce="WtWEDzpC6GZb9pD" src="https://cdn.cookielaw.org/consent/3ea94870-d4b1-483a-b1d2-faf1d982bb31/OtAutoBlock.js" type="text/javascript"></script>,
#  <script nonce="WtWEDzpC6GZb9pD" type="text/javascript">
#  (function () {
#  document.addEventListener('cookie_banner_closed', function(e) {
#  if (window.PCM && window.B && window.B.et) {
#  window.B.et.goal((window.PCM.Marketing || window.PCM.Analytical) ? 'cookie_consent_accepted_policy_banner' : 'cookie_consent_declined_policy_banner');
#  }
#  });
#  document.addEventListener('click', function(e) {
#  if (e.target && e.target.classList.contains('ot-preference-center-footer')) {
#  e.preventDefault();
#  Optanon && Optanon.ToggleInfoDisplay();
#  }
#  });
#  })();
#  </script>,
#  <script nonce="WtWEDzpC6GZb9pD" type="text/javascript">
#  window.PCM = {
#  isCountryNeedCookieBanner: 1,
#  loadStartedAt: 1673393590
#  }
#  </script>,
#  <script data-domain-script="3ea94870-d4b1-483a-b1d2-faf1d982bb31" nonce="WtWEDzpC6GZb9pD" src="https://cf.bstatic.com/libs/privacy-consent/releases/2.1.36/customer/cookie-banner.min.js" type="text/javascript"></script>,
#  <link crossorigin="" href="https://shelves.booking.com/" rel="preconnect"/>,
#  <meta charset="utf-8"/>,
#  <script nonce="WtWEDzpC6GZb9pD">
#  document.documentElement.className = document.documentElement.className.replace(/\bno-js\b/, 'has-js css-is-loading js-is-loading');
#  </script>,
#  <meta content="origin-when-cross-origin" name="referrer"/>,
#  <meta content="width=device-width, initial-scale=1.0" name="viewport"/>,
#  <script nonce="WtWEDzpC6GZb9pD"> function b_cors_check(supported) { var value = supported ? 1 : 0; if (!/(^|;)\s*cors_js=/.test(document.cookie)) { var d = new Date(); d.setTime(d.getTime() + 60 * 60 * 24 * 365 * 1000); var cookieDomain = '.booking.com' || '.booking.com'; document.cookie = 'cors_js=' + value +'; domain=' + cookieDomain + '; path=/; expires=' + d.toGMTString(); } if (!value) { location.reload(); } } </script>,
#  <script nonce="WtWEDzpC6GZb9pD">(function(d) { d.addEventListener('error', function(e) { if (e.target && e.target.classList.contains('crossorigin-check-js')) { b_cors_check(false); } }, true); })(document); </script>,
#  <script async="" class="crossorigin-check-js" crossorigin="" nonce="WtWEDzpC6GZb9pD" src="https://cf.bstatic.com/static/js/crossorigin_check_cloudfront_sd/2454015045ef79168d452ff4e7f30bdadff0aa81.js"></script>,
#  <script nonce="WtWEDzpC6GZb9pD">
#  ;(function() {
#  window.b_early_errors = window.b_early_errors || [];
#  window.onerror = function() {
#  window.b_early_errors.push(arguments);
#  };
#  }());
#   </script>,
#  <script nonce="WtWEDzpC6GZb9pD">(function(d) { d.addEventListener('load', function(e) { if (e.target && e.target.classList.contains('stylesheet-preload')) { e.target.rel='stylesheet'; } }, true); })(document); </script>,
#  <style nonce="WtWEDzpC6GZb9pD">template,.g-hidden{display:none !important}p.error{line-height:18px;color:#A30000;font-weight:bold;margin:10px}html.no-js .no-js-hidden{display:none}body.rtlcss{direction:rtl}.no-js .js-loading-hidden,.js-is-loading .js-loading-hidden,.css-is-loading .css-loading-hidden{display:none !important}.no-js .js-loading-invisible,.js-is-loading .js-loading-invisible,.css-is-loading .css-loading-invisible{visibility:hidden !important}.css-loading-inline-visible{display:none !important}.css-is-loading .css-loading-inline-visible{display:inline-block !important}.searchbox_redesign select[disabled]{color:#BDBDBD}body,div,dl,dt,dd,ul,ol,li,h1,h2,h3,h4,h5,h6,pre,form,fieldset,input,textarea,p,blockquote,th,td{margin:0;padding:0}fieldset,img{border:0}address,caption,cite,code,dfn,em,strong,th,var{font-style:normal;font-weight:normal}q:before,q:after{content:''}abbr,acronym{border:0}body,input,select,button,textarea{font-family:BlinkMacSystemFont,-apple-system,Segoe UI,Roboto,Helvetica,Arial,sans-serif}.rtl,.rtlcss{direction:rtl}.ltr{direction:ltr}.rtlcss .bui-carousel__next,.rtlcss .bui-carousel__prev{transform:scaleX(-1)}body>img,body>iframe[src*="doubleclick.net"]{display:block;margin-top:-1px}a{color:var(--bui_color_action_foreground)}a:link{text-decoration:underline}ol,ul{list-style:none}body{background:var(--bui_color_white);color:#333333;-webkit-text-size-adjust:100%}table{border-collapse:collapse;border-spacing:0}th{text-align:left}.rtlcss th{text-align:right}h1,h2,h3,h4,h5,h6{font-weight:normal}h1{font-weight:bold;margin:10px}h2{font-weight:bold;display:block;margin:0;padding-left:10px;padding-top:2px}.header_profile_btn{font-size:22px;font-weight:normal;padding-left:10px;padding-right:10px;width:auto}.header_profile_btn__genius{font-size:13px}.header_profile_btn .bicon{color:var(--bui_color_white)}.header_profile_btn__genius--svg{padding:0 3px}.genius-profile-icon--svg{margin-top:5px}.searchbox_dest.input_clear_button_input::-webkit-search-cancel-button,.input_destination.input_clear_button_input::-webkit-search-cancel-button{display:none}.input_clear_button{-webkit-tap-highlight-color:rgba(0,0,0,0);background:transparent;border:0;color:#999999;height:100%;font-size:12px;padding:0;opacity:0;outline:none;position:absolute;top:0;transition:opacity .25s;width:38px;z-index:5}.ltr .input_clear_button{padding-left:7px;right:0}.rtl .input_clear_button{padding-right:7px;left:0}.rtlcss .input_clear_button{padding-right:7px;left:0}.searchbox_redesign--destination-focused .input_clear_button,.has-dest-value .input_clear_button,.gps-possible .input_clear_button{opacity:1}.input_clear_button:active{color:var(--bui_color_black);background-color:transparent}.cookie-warning{font-size:13px;display:flex;overflow:hidden;max-height:500px;transition:opacity .3s,max-height 0s .3s;color:var(--bui_color_white);background:#212121;box-shadow:inset 0 -1px var(--bui_color_black);flex-flow:row-reverse nowrap;align-items:center}.cookie-warning__flag{position:absolute;opacity:0}.cookie-warning__flag:checked + .cookie-warning{max-height:0;opacity:0}.cookie-warning__text{overflow:hidden;flex:1 1 auto}.cookie-warning__text,.cookie-warning__close{margin:10px}.cookie-warning__close{padding:4px 6px;border-radius:5px;background:#0071C2;flex:0 0 auto}.cookie-warning__close:active{background:#BAD4F7}.cookie-warning.site-header--sticky{margin-top:40px}.cookie-warning-v2{z-index:1003;position:fixed;bottom:0;left:0;width:100%;background-color:var(--bui_color_white);border-top:1px solid #E6E6E6;text-align:left;color:#333333}.cookie-warning-v2__banner{padding:4px 10px 0 10px;@apply --bui_font_body_2}.cookie-warning-v2__banner-title{margin-bottom:8px}.cookie-warning-v2__more-details,.cookie-warning-v2__settings{z-index:400;overflow-x:auto}.cookie-warning-v2__footer{margin-top:16px}.cookie-warning-v2__footer--text-center{text-align:center}.cookie-warning-v2__header{margin-top:16px}.cookie-warning-v2__header-paragraph{margin:14px 0}.cookie-warning- ...
#  <style nonce="WtWEDzpC6GZb9pD">.sr-card__price--red .sr-card__price-rack-discount{padding:1px 4px;display:inline-block;background:#A30000;color:var(--bui_color_white);border-radius:2px}.sr-card__price-cheapest--red{color:#A30000}.sr-card__price--red .sr_price_wrap span,.sr-card__price--red .sr_simple_card_group_rec span,.sr-card__price--red .sr_combine_gsn-align span{vertical-align:middle}.sr-card__price--red .sr_price_wrap span span,.sr-card__price--red .sr_simple_card_group_rec span span,.sr-card__price--red .sr_combine_gsn-align span span{vertical-align:initial}.sr-card__price--red .sr_combine_gsn{vertical-align:middle;margin-bottom:initial}.sr-card__price--red .sr_combine_gsn,.sr-card__details .sr-card__price--red .sr_combine_gsn,.sr-card__price--red .sr_simple_card_group_rec.sr_make_the_price_stand_out-group.sr_combine_gsn,.sr-card__price--red .sr_combine_gsn.sr_make_the_price_stand_out-urgency,.sr-card__price--red .sr-card__price--urgency .sr-card__price-rack-rate,.sr-card__price--red .sr-card__price-rack-rate{color:#6B6B6B}.sr-card__price--red .sr-card__price-rack-rate:after,.sr-card__price--red .sr-card__price--urgency .sr-card__price-rack-rate:after{background:#6B6B6B}.sr-card__price--red .sr_simple_card_group_rec .sr-card__item--strong,.sr-card__price--red .sr_make_the_price_stand_out-urgency .sr-card__item--strong{color:#333333}.sr-rooms-selector{padding-right:10px;padding-left:6px}.rtlcss .sr-rooms-selector{padding-right:6px;padding-left:10px}.sr-rooms-selector__select{position:absolute;top:0;left:0;display:block;width:100%;height:100%;opacity:0}.sr-rooms-selector__icon{font-size:4px;position:absolute;top:50%;right:2px;margin-top:-1px;color:#7c90a6}.rtlcss .sr-rooms-selector__icon{right:auto;left:2px}.sr_last_minute_drop{color:#008009;@apply --bui_font_small_1;text-decoration:none;margin:-2px 0 3px 0}.sr_last_minute_drop__body{display:inline-block}.sr_last_minute_drop__icon{transform:rotate(180deg);fill:#008009;margin-right:3px;margin-top:-2px;position:relative;top:3px}.rtlcss .sr_last_minute_drop__icon{transform:rotate(180deg) scale(-1,1)}.sr-svg--header_icon_search{display:inline-block;left:8px;top:32%;position:absolute}.rtlcss .sr-svg--header_icon_search{left:auto;right:8px}.sr_svg__card_icon{margin-top:2px}.ltr .sr_svg__card_icon{float:left}.rtlcss .sr_svg__card_icon{float:right}.sr_svg__header_item{display:inline-block;top:18%;position:absolute}.ltr .sr_svg__header_item{left:8px}.rtlcss .sr_svg__header_item{right:8px}.sr_svg__top_reasons_checkmark{background:#FEBB02;border-radius:100px;color:var(--bui_color_white);height:21px;margin-top:-12px;position:absolute;text-align:center;top:50%;width:24px;padding-top:3px;line-height:24px}.ltr .sr_svg__top_reasons_checkmark{left:10px}.rtlcss .sr_svg__top_reasons_checkmark{right:10px}.sr_card_urgency_icon{position:relative;top:1px}.sr-card__item--just-booked .sr_svg__card_icon{fill:#A30000}.bk-icon.pp-icon-mobile-sr{position:relative;top:1px}.svg-lang-arrows{float:right;margin-top:-10px}.rtlcss .svg-lang-arrows{float:left}.sr-list{background-color:#F5F5F5;overflow:auto}.sr-card-list.bui-container{padding-top:0}.sr-card{display:block;position:relative;background-color:var(--bui_color_white);margin:0 8px 8px;border-bottom:1px solid #DDDDDD}.sr-notices .bui-banner~.bui-banner{margin-top:-1px}.sr-notices .bui-banner:last-child{margin-bottom:8px}.sr-notices .bui-banner__content{padding-right:32px}.sr-notices a{font-weight:normal;text-decoration:none}.sr-notices #sr_notice_sr_legal_commission_accommodation_ranking.is-bottom-stick{bottom:0;left:0;margin:0 !important;position:fixed;right:0;z-index:99}.sr-card:last-child{margin-bottom:0}.sr-card--highlight{box-shadow:0 0 10px #BAD4F7;background:#FAFCFF;border-color:#EBF3FF;margin-top:5px;margin-bottom:15px}.sr-card--highlight-genius{background:#FEFBF0;border-color:#DDDDDD}.sr-card__row{font-size:12px;display:block;color:#333333;line-height:normal;position:relative;cursor:pointer}.sr-card__row-inner{position:relative}.sr-card__ro ...
#  <link as="style" class="stylesheet-preload" data-async="" data-main-css="" href="https://cf.bstatic.com/mobile/css/core_cloudfront_sd.iq_ltr/3bb21c0e928d519db4d47c8cfd94e312a3ab3967.css" rel="preload"/>,
#  <noscript><link href="https://cf.bstatic.com/mobile/css/core_cloudfront_sd.iq_ltr/3bb21c0e928d519db4d47c8cfd94e312a3ab3967.css" rel="stylesheet"/></noscript>,
#  <link href="https://cf.bstatic.com/mobile/css/core_cloudfront_sd.iq_ltr/3bb21c0e928d519db4d47c8cfd94e312a3ab3967.css" rel="stylesheet"/>,
#  <link as="style" class="stylesheet-preload" data-async="" data-main-css="" href="https://cf.bstatic.com/mobile/css/app_cloudfront_sd.iq_ltr/e16be98e129831fa6c30dbd237d88e38571b5ec1.css" rel="preload"/>,
#  <noscript><link href="https://cf.bstatic.com/mobile/css/app_cloudfront_sd.iq_ltr/e16be98e129831fa6c30dbd237d88e38571b5ec1.css" rel="stylesheet"/></noscript>,
#  <link href="https://cf.bstatic.com/mobile/css/app_cloudfront_sd.iq_ltr/e16be98e129831fa6c30dbd237d88e38571b5ec1.css" rel="stylesheet"/>,
#  <link as="style" class="stylesheet-preload" data-async="" data-main-css="" href="https://cf.bstatic.com/mobile/css/searchresults_no_filters_cloudfront_sd.iq_ltr/d7a795e9664724c6be913d6ef3718c1ba995f91e.css" rel="preload"/>,
#  <noscript><link href="https://cf.bstatic.com/mobile/css/searchresults_no_filters_cloudfront_sd.iq_ltr/d7a795e9664724c6be913d6ef3718c1ba995f91e.css" rel="stylesheet"/></noscript>,
#  <link href="https://cf.bstatic.com/mobile/css/searchresults_no_filters_cloudfront_sd.iq_ltr/d7a795e9664724c6be913d6ef3718c1ba995f91e.css" rel="stylesheet"/>,
#  <link as="style" class="stylesheet-preload" data-async="" data-main-css="" href="https://cf.bstatic.com/mobile/css/iq_m_type_overrides_cloudfront_sd.iq_ltr/f02caf6b2406afbf6d7eb2fa20a77b92f18d062f.css" rel="preload"/>,
#  <noscript><link href="https://cf.bstatic.com/mobile/css/iq_m_type_overrides_cloudfront_sd.iq_ltr/f02caf6b2406afbf6d7eb2fa20a77b92f18d062f.css" rel="stylesheet"/></noscript>,
#  <link href="https://cf.bstatic.com/mobile/css/iq_m_type_overrides_cloudfront_sd.iq_ltr/f02caf6b2406afbf6d7eb2fa20a77b92f18d062f.css" rel="stylesheet"/>,
#  <script id="preload" nonce="WtWEDzpC6GZb9pD">
#  (function(d){
#  var cs = d.getElementById('preload');
#  var load = function (href) {
#  var l = d.createElement('link');
#  l.rel = 'stylesheet';
#  l.setAttribute('data-async', '');
#  l.href = href;
#  if (l.addEventListener) {
#  l.media = 'none';
#  l.addEventListener('load', function onLoad() {
#  l.removeEventListener('load', onLoad);
#  l.removeAttribute('media');
#  });
#  }
#  cs.parentNode.insertBefore(l, cs);
#  };
#  var supportsPreload = false;
#  try {
#  supportsPreload = d.createElement('link').relList.supports('preload');
#  } catch (e) {}
#  if (!supportsPreload) {
#  Array.prototype.forEach.call(d.getElementsByTagName('link'), function (l) {
#  if (l.getAttribute('rel') === 'preload' && l.hasAttribute('data-main-css')) {
#  l.removeAttribute('data-async');
#  load(l.getAttribute('href'));
#  }
#  });
#  }
#  }(document));
#  </script>,
#  <link as="script" crossorigin="" href="https://cf.bstatic.com/mobile/js/core-deps-inlinedet_cloudfront_sd/97754f5bf295ed27240e6fb859eb624545b055b1.js" nonce="WtWEDzpC6GZb9pD" rel="preload"/>,
#  <link as="script" crossorigin="" href="https://cf.bstatic.com/mobile/js/core_cloudfront_sd/d3f18df59f626fe9824a288059ff18e54ff0e45f.js" nonce="WtWEDzpC6GZb9pD" rel="preload"/>,
#  <link as="script" crossorigin="" href="https://cf.bstatic.com/mobile/js/app_cloudfront_sd/bb33649b75c2b045c42414344e1ad03c5ff509ca.js" nonce="WtWEDzpC6GZb9pD" rel="preload"/>,
#  <link as="script" crossorigin="" href="https://cf.bstatic.com/mobile/js/searchresults_cloudfront_sd/f363de7fb0dba77ff856788400d5adc9dce825ec.js" nonce="WtWEDzpC6GZb9pD" rel="preload"/>,
#  <link as="script" crossorigin="" href="https://cf.bstatic.com/static/js/error_catcher_bec_cloudfront_sd/0acd2ada6c74d5dec978a04ea837952bdf050cd2.js" nonce="WtWEDzpC6GZb9pD" rel="preload"/>,
#  <script nonce="WtWEDzpC6GZb9pD"> if( window.performance && performance.measure && 'b-stylesheets') { performance.measure('b-stylesheets'); } </script>,
#  <script nonce="WtWEDzpC6GZb9pD"> var lzimg = function(state){lzimg.state = state}; </script>,
#  <script nonce="WtWEDzpC6GZb9pD">function ImageLazyLoader(){this.highResQueue=[];this.shouldLoadHighRes=false;this.viewPortExtendedHeight=null;this.isWatchingForNewImages=false;this.supportsIntersectionObserver='IntersectionObserver'in window&&'IntersectionObserverEntry'in window&&'intersectionRatio'in IntersectionObserverEntry.prototype&&'isIntersecting'in IntersectionObserverEntry.prototype}ImageLazyLoader.prototype={SCREEN_HEIGHT_COEFFICIENT:1.4,SCREEN_SIDE_COEFFICIENT:1.33,LAZY_IMAGE_CLASS:'.js-lazy-image',init:function(){this.watcher=this.getWatcher();if(!this.supportsIntersectionObserver){var updateViewportHeight=function(){this.viewPortExtendedHeight=(window.innerHeight||document.documentElement.clientHeight)*this.SCREEN_HEIGHT_COEFFICIENT}.bind(this);window.addEventListener('resize',updateViewportHeight);window.addEventListener('orientationchange',updateViewportHeight);updateViewportHeight()}document.addEventListener('readystatechange',this.enableHighResImagesLoading.bind(this));if(window.lzimg&&window.lzimg.state){this.documentLoadingStateChanged(window.lzimg.state)}window.lzimg=this.documentLoadingStateChanged.bind(this)},enableHighResImagesLoading:function(){if('complete'!==document.readyState)return;document.removeEventListener('readystatechange',this.enableHighResImagesLoading.bind(this));this.shouldLoadHighRes=true;this.highResQueue.forEach(function(lazyImage){this.watcher.add(lazyImage)}.bind(this));this.highResQueue=[]},loadLazyImage:function(lazyImage){var paths=this.parseDataSrc(lazyImage);if(this.shouldLoadHighRes&&2===paths.length){this.loadImageAndInsert(paths[1],lazyImage)}else{this.loadImageAndInsert(paths[0],lazyImage)}if(!this.shouldLoadHighRes&&2===paths.length){this.highResQueue.push(lazyImage)}},observeMutations:function(){if('MutationObserver'in window){this.isWatchingForNewImages=true;var observer=new MutationObserver(function(mutations){mutations.forEach(function(mutation){Array.prototype.forEach.call(mutation.addedNodes,function(node){if(1!==node.nodeType)return;this.addToWatch(node)}.bind(this))}.bind(this))}.bind(this));observer.observe(document.body,{childList:true,subtree:true,characterData:false})}},documentLoadingStateChanged:function(state){if(!this.isWatchingForNewImages){this.observeMutations();this.addToWatch(document.body);if(!this.isWatchingForNewImages&&state==='ready'){this.addToWatch(document.body);this.listenMutationEvents();this.isWatchingForNewImages=true}}},addToWatch:function(el){if(this.isValidLazyImage(el)){this.watcher.add(el)}var imageList=el.querySelectorAll(this.LAZY_IMAGE_CLASS);for(var i=0;i<imageList.length;i++){var image=imageList[i];if(this.isValidLazyImage(image)){this.watcher.add(image)}}},isValidLazyImage:function(el){return el.getAttribute('data-src')&&!el.getAttribute('data-lazy')&&el.classList.contains('js-lazy-image')},parseDataSrc:function(el){var paths=el.getAttribute('data-src').split(',');for(var i=0;i<paths.length;i++){paths[i]=paths[i].trim()}return paths},loadImageAndInsert:function(src,el){var img=new Image();var encodedSRC=encodeURI(src);img.onload=function imageLoadedHandler(){if(el.tagName==="IMG"){el.src=encodedSRC}else{el.style.backgroundImage='url(\"'+encodedSRC+'\")'}};img.src=encodedSRC},listenMutationEvents:function(){if('MutationEvent'in window){document.body.addEventListener('DOMNodeInserted',function(event){var node=event.target;if(1!==node.nodeType)return;this.addToWatch(node)}.bind(this))}},getWatcher:function(){if(this.supportsIntersectionObserver){return this.intersectionObserverWatcher()}else{return this.vanillaJSWatcher()}},intersectionObserverWatcher:function(){var intersectionObserverHandler=function(entries){entries.forEach(function(entry){if(entry.isIntersecting){this.loadLazyImage(entry.target);intersectionObserver.unobserve(entry.target)}}.bind(this))}.bind(this);var intersectionObserverProps={rootMargin:'0% '+(100*this.SCREEN_SIDE_COEFFICIENT-100)+'% '+(100*this.SCREEN_HEIGHT_COEFFICIENT-100)+'% '+(100*this.SCREEN_SIDE_COEFFI ...
#  return window.matchMedia && window.matchMedia(mediaQuery).matches;
#  };
#  // eslint-disable-next-line no-undef
#  ImageLazyLoader.prototype.enableHighResImagesLoading = function () {
#  if ('complete' !== document.readyState) return;
#  document.removeEventListener('readystatechange',this.enableHighResImagesLoading);if(this.isHiDPI()){this.shouldLoadHighRes=true}this.highResQueue.forEach(function(lazyImage){this.watcher.add(lazyImage)}.bind(this));this.highResQueue=[]};new ImageLazyLoader().init();</script>,
#  <link href="https://www.booking.com/city/fr/paris.fr.html" hreflang="en-gb" rel="alternate" title="English (UK)" type="text/html">
#  <link href="https://www.booking.com/city/fr/paris.fr.html" hreflang="en-us" rel="alternate" title="English (US)" type="text/html">
#  <link href="https://www.booking.com/city/fr/paris.fr.html" hreflang="de" rel="alternate" title="Deutsch" type="text/html">
#  <link href="https://www.booking.com/city/fr/paris.fr.html" hreflang="nl" rel="alternate" title="Nederlands" type="text/html">
#  <link href="https://www.booking.com/city/fr/paris.fr.html" hreflang="fr" rel="alternate" title="Français" type="text/html">
#  <link href="https://www.booking.com/city/fr/paris.fr.html" hreflang="es" rel="alternate" title="Español" type="text/html">
#  <link href="https://www.booking.com/city/fr/paris.fr.html" hreflang="es-ar" rel="alternate" title="Español (AR)" type="text/html">
#  <link href="https://www.booking.com/city/fr/paris.fr.html" hreflang="es-mx" rel="alternate" title="Español (MX)" type="text/html">
#  <link href="https://www.booking.com/city/fr/paris.fr.html" hreflang="ca" rel="alternate" title="Català" type="text/html">
#  <link href="https://www.booking.com/city/fr/paris.fr.html" hreflang="it" rel="alternate" title="Italiano" type="text/html">
#  <link href="https://www.booking.com/city/fr/paris.fr.html" hreflang="pt-pt" rel="alternate" title="Português (PT)" type="text/html">
#  <link href="https://www.booking.com/city/fr/paris.fr.html" hreflang="pt-br" rel="alternate" title="Português (BR)" type="text/html">
#  <link href="https://www.booking.com/city/fr/paris.fr.html" hreflang="no" rel="alternate" title="Norsk" type="text/html">
#  <link href="https://www.booking.com/city/fr/paris.fr.html" hreflang="fi" rel="alternate" title="Suomi" type="text/html">
#  <link href="https://www.booking.com/city/fr/paris.fr.html" hreflang="sv" rel="alternate" title="Svenska" type="text/html">
#  <link href="https://www.booking.com/city/fr/paris.fr.html" hreflang="da" rel="alternate" title="Dansk" type="text/html">
#  <link href="https://www.booking.com/city/fr/paris.fr.html" hreflang="cs" rel="alternate" title="Čeština" type="text/html"/>
#  <link href="https://www.booking.com/city/fr/paris.fr.html" hreflang="hu" rel="alternate" title="Magyar" type="text/html"/>
#  <link href="https://www.booking.com/city/fr/paris.fr.html" hreflang="ro" rel="alternate" title="Română" type="text/html"/>
#  <link href="https://www.booking.com/city/fr/paris.fr.html" hreflang="ja" rel="alternate" title="日本語" type="text/html"/>
#  <link href="https://www.booking.com/city/fr/paris.fr.html" hreflang="zh-cn" rel="alternate" title="简体中文" type="text/html"/>
#  <link href="https://www.booking.com/city/fr/paris.fr.html" hreflang="zh-tw" rel="alternate" title="繁體中文" type="text/html"/>
#  <link href="https://www.booking.com/city/fr/paris.fr.html" hreflang="pl" rel="alternate" title="Polski" type="text/html"/>
#  <link href="https://www.booking.com/city/fr/paris.fr.html" hreflang="el" rel="alternate" title="Ελληνικά" type="text/html"/>
#  <link href="https://www.booking.com/city/fr/paris.fr.html" hreflang="ru" rel="alternate" title="Русский" type="text/html"/>
#  <link href="https://www.booking.com/city/fr/paris.fr.html" hreflang="tr" rel="alternate" title="Türkçe" type="text/html"/>
#  <link href="https://www.booking.com/city/fr/paris.fr.html" hreflang="bg" rel="alternate" title="Български" type="text/html"/>
#  <link href="https://www.booking.com/city/fr/paris.fr.html" hreflang="ar" rel="alternate" title="العربية" type="text/html"/>
#  <link href="https://www.booking.com/city/fr/paris.fr.html" hreflang="ko" rel="alternate" title="한국어" type="text/html"/>
#  <link href="https://www.booking.com/city/fr/paris.fr.html" hreflang="he" rel="alternate" title="עברית" type="text/html"/>
#  <link href="https://www.booking.com/city/fr/paris.fr.html" hreflang="lv" rel="alternate" title="Latviski" type="text/html"/>
#  <link href="https://www.booking.com/city/fr/paris.fr.html" hreflang="uk" rel="alternate" title="Українська" type="text/html"/>
#  <link href="https://www.booking.com/city/fr/paris.fr.html" hreflang="hi" rel="alternate" title="हिन्दी" type="text/html"/>
#  <link href="https://www.booking.com/city/fr/paris.fr.html" hreflang="id" rel="alternate" title="Bahasa Indonesia" type="text/html"/>
#  <link href="https://www.booking.com/city/fr/paris.fr.html" hreflang="ms" rel="alternate" title="Bahasa Malaysia" type="text/html"/>
#  <link href="https://www.booking.com/city/fr/paris.fr.html" hreflang="th" rel="alternate" title="ภาษาไทย" type="text/html"/>
#  <link href="https://www.booking.com/city/fr/paris.fr.html" hreflang="et" rel="alternate" title="Eesti" type="text/html"/>
#  <link href="https://www.booking.com/city/fr/paris.fr.html" hreflang="hr" rel="alternate" title="Hrvatski" type="text/html"/>
#  <link href="https://www.booking.com/city/fr/paris.fr.html" hreflang="lt" rel="alternate" title="Lietuvių" type="text/html"/>
#  <link href="https://www.booking.com/city/fr/paris.fr.html" hreflang="sk" rel="alternate" title="Slovenčina" type="text/html"/>
#  <link href="https://www.booking.com/city/fr/paris.fr.html" hreflang="sr" rel="alternate" title="Srpski" type="text/html"/>
#  <link href="https://www.booking.com/city/fr/paris.fr.html" hreflang="sl" rel="alternate" title="Slovenščina" type="text/html"/>
#  <link href="https://www.booking.com/city/fr/paris.fr.html" hreflang="vi" rel="alternate" title="Tiếng Việt" type="text/html"/>
#  <link href="https://www.booking.com/city/fr/paris.fr.html" hreflang="tl" rel="alternate" title="Filipino" type="text/html"/>
#  <link href="https://www.booking.com/city/fr/paris.fr.html" hreflang="is" rel="alternate" title="Íslenska" type="text/html"/>
#  <script nonce="WtWEDzpC6GZb9pD">
#  (function(){
#  document.addEventListener('DOMContentLoaded', function(e) {
#  window._pxAppId = 'PXikKuL2RM';
#  setTimeout(function() {
#  var pxs = document.createElement('script');
#  pxs.crossOrigin = 'anonymous';
#  pxs.nonce = 'WtWEDzpC6GZb9pD';
#  pxs.src = 'https://cf.bstatic.com/libs/perimeterx/px.v7.6.9.min.js';
#  document.head.appendChild(pxs);
#  }, 750);
#  });
#  }());
#  </script>
#  <script nonce="WtWEDzpC6GZb9pD" type="text/javascript">
#  window.cspViolationsCount = 0;
#  if ('SecurityPolicyViolationEvent' in window) {
#  document.addEventListener("securitypolicyviolation", (e) => {
#  if (navigator.userAgent.indexOf('Safari') != -1 && navigator.userAgent.indexOf('Chrome') == -1) {
#  window.cspViolationsCount++;
#  } else if (e.disposition === 'enforce') {
#  window.cspViolationsCount++;
#  }
#  });
#  }
#  </script>
#  <link data-chunk="client" href="https://cf.bstatic.com/psb/capla/static/css/bui-react.1a9a97ad.css" nonce="WtWEDzpC6GZb9pD" rel="stylesheet"/><link data-chunk="src-components-FiltersMobile-FiltersMobile" href="https://cf.bstatic.com/psb/capla/static/css/3557.6e49dbf9.chunk.css" nonce="WtWEDzpC6GZb9pD" rel="stylesheet"/><link data-chunk="src-components-LoadingOverlayMobile-LoadingOverlayMobile" href="https://cf.bstatic.com/psb/capla/static/css/5338.284f1561.chunk.css" nonce="WtWEDzpC6GZb9pD" rel="stylesheet"/><link data-chunk="src-components-TripTypePilotBeachMobileHeader-TripTypePilotBeachMobileHeader" href="https://cf.bstatic.com/psb/capla/static/css/6493.4af61583.chunk.css" nonce="WtWEDzpC6GZb9pD" rel="stylesheet"/><link data-chunk="src-components-TripTypeSki-UfiHeaderMobile-TripTypeSkiUfiHeaderMobile" href="https://cf.bstatic.com/psb/capla/static/css/2863.31a4ae57.chunk.css" nonce="WtWEDzpC6GZb9pD" rel="stylesheet"/><link data-chunk="src-components-TripTypeSki-LandmarkHeaderMobile-TripTypeSkiLandmarkHeaderMobile" href="https://cf.bstatic.com/psb/capla/static/css/358.17753b14.chunk.css" nonce="WtWEDzpC6GZb9pD" rel="stylesheet"/><link data-chunk="src-components-PropertiesListMobile-PropertiesListMobile" href="https://cf.bstatic.com/psb/capla/static/css/9958.c6f958bd.chunk.css" nonce="WtWEDzpC6GZb9pD" rel="stylesheet"/><link data-chunk="bookingcom-alpaca-patterns-SearchResultsBanners-BHQualityClassification-BHQualityClassificationCard-BHQualityClassificationCard" href="https://cf.bstatic.com/psb/capla/static/css/4114.07e7db64.chunk.css" nonce="WtWEDzpC6GZb9pD" rel="stylesheet"/><link data-chunk="common-genius-patterns-GeniusOnboardingSheet-GeniusOnboardingSheet" href="https://cf.bstatic.com/psb/capla/static/css/5738.c8c52fba.chunk.css" nonce="WtWEDzpC6GZb9pD" rel="stylesheet"/><link data-chunk="src-components-SearchBoxMobile-SearchBoxMobile" href="https://cf.bstatic.com/psb/capla/static/css/313.42a5bc69.chunk.css" nonce="WtWEDzpC6GZb9pD" rel="stylesheet"/><link data-chunk="src-components-SearchBoxMinifiedMobile-SearchBoxMinifiedMobile" href="https://cf.bstatic.com/psb/capla/static/css/9540.f5cab9ff.chunk.css" nonce="WtWEDzpC6GZb9pD" rel="stylesheet"/><link data-chunk="src-components-SortersFiltersMapTriggersMobile-SortersFiltersMapTriggersMobile" href="https://cf.bstatic.com/psb/capla/static/css/9473.2abf389c.chunk.css" nonce="WtWEDzpC6GZb9pD" rel="stylesheet"/><link data-chunk="bookingcom-web-shell-header-mfe-components-AccommodationHeader-SearchResultHeader" href="https://cf.bstatic.com/psb/capla/static/css/1238.50787710.chunk.css" nonce="WtWEDzpC6GZb9pD" rel="stylesheet"/><link data-chunk="bookingcom-web-shell-header-mfe-components-GlobalAlerts" href="https://cf.bstatic.com/psb/capla/static/css/3665.6913b2e2.chunk.css" nonce="WtWEDzpC6GZb9pD" rel="stylesheet"/>
#  <title>
#  Booking.com
#  :
#  Hôtels Paris
#  .
#  Réservez votre hôtel dès maintenant !
#  </title>
#  <meta content="Hôtel, Paris,  Hôtels, hébergement, logement, Offres spéciales, promotions, offres week-ends, Prix compétitifs, réductions, prix bon marché" name="keywords">
#  <meta content="index,follow" name="robots">
#  <link href="https://www.booking.com/city/fr/paris.fr.html" rel="canonical">
#  <meta content="UmFuZG9tSVbswUMIJb9y447nac2upTDqzdVfeycMdpc27iffwGs_6KtOGJwBNtcuyVwZTWaOPPohKSWGwjhHavHalyY9LDk2_oaUoC4r8wB4-Z61UlVmDexKPW8DdigEs8VkpLy5WDwCoOSZehui09slGap6gyhE-N2Ukr7b5EwGqyHJ9QJRFkkR1IK-tYUfgnrkCnSK8mmIivpxvIH6b4vj3DEQXkoxWr7xnnR1GpmsUyFCVk9uvD1X9P3NeAjqMSQKtN2l1MYZf5Rp0RBB33QS_LPhdGc_ie0Gj7_kb7BnzDbw2leUjtpJDL08sn-GU6vPgD9TBcYsSZSo7nB0g_eLEEIjLFIxXseDhkxnw2V9Fy0ySNT_RpuQEb57E_7wM0AA53EAgEyNO7ZBQoNFkm78HLuPaQPISZ8JJx5TT1663Onp7fiwJJiotDVeZSFTAu4TtSy_VGo" name="booking-verification">
#  <meta content="367003839" name="twitter:app:id:iphone"/>
#  <meta content="Booking.com Hotel Reservations Worldwide &amp; Hotel Deals" name="twitter:app:name:ipad"/>
#  <meta content="367003839" name="twitter:app:id:ipad"/>
#  <meta content="Booking.com Hotel Reservations" name="twitter:app:name:googleplay"/>
#  <meta content="com.booking" name="twitter:app:id:googleplay"/>
#  <meta content="367003839" property="al:ios:app_store_id"/>
#  <meta content="Booking.com Hotel Reservations" property="al:ios:app_name"/>
#  <meta content="Booking.com Hotel Reservation" property="al:android:app_name"/>
#  <meta content="com.booking" property="al:android:package"/>
#  <meta content="" name="twitter:title">
#  <meta content="booking://searchresults?dest_id=-1456928&amp;dest_type=city&amp;affiliate_id=375119&amp;source=gen173nr-1VCAQoggJCDHNlYXJjaF9wYXJpc0gNWARoTYgBApgBDbgBCcgBEdgBAegBAfgBA4gCAagCA7gCtuv3nQbAAgLSAiRlNDMzZWMzZC02YTM5LTQwNTYtOGI1MS1mMWNjNzc2MjVkMjnYAgbgAgE" property="al:ios:url">
#  <meta content="booking://searchresults?dest_id=-1456928&amp;dest_type=city&amp;affiliate_id=375119&amp;source=gen173nr-1VCAQoggJCDHNlYXJjaF9wYXJpc0gNWARoTYgBApgBDbgBCcgBEdgBAegBAfgBA4gCAagCA7gCtuv3nQbAAgLSAiRlNDMzZWMzZC02YTM5LTQwNTYtOGI1MS1mMWNjNzc2MjVkMjnYAgbgAgE" property="al:android:url">
#  <meta content="yes" name="apple-touch-fullscreen"/>
#  <meta content="no" name="apple-mobile-web-app-capable">
#  <meta content="telephone=no" name="format-detection"/>
#  <link href="https://cf.bstatic.com/static/img/favicon/ebc77706da3aae4aee7b05dadf182390f0d26d11.ico" rel="shortcut icon">
#  <link href="https://cf.bstatic.com/static/img/apple-touch-icon_new_lrg/c9b35bf29a75cac2f430f80a5d4bc7fd961d21a7.png" rel="apple-touch-icon">
#  </link></link></meta></meta></meta></meta></meta></link></meta></meta></link></link></link></link></link></link></link></link></link></link></link></link></link></link></link></link>,
#  <link href="https://www.booking.com/city/fr/paris.fr.html" hreflang="en-us" rel="alternate" title="English (US)" type="text/html">
#  <link href="https://www.booking.com/city/fr/paris.fr.html" hreflang="de" rel="alternate" title="Deutsch" type="text/html">
#  <link href="https://www.booking.com/city/fr/paris.fr.html" hreflang="nl" rel="alternate" title="Nederlands" type="text/html">
#  <link href="https://www.booking.com/city/fr/paris.fr.html" hreflang="fr" rel="alternate" title="Français" type="text/html">
#  <link href="https://www.booking.com/city/fr/paris.fr.html" hreflang="es" rel="alternate" title="Español" type="text/html">
#  <link href="https://www.booking.com/city/fr/paris.fr.html" hreflang="es-ar" rel="alternate" title="Español (AR)" type="text/html">
#  <link href="https://www.booking.com/city/fr/paris.fr.html" hreflang="es-mx" rel="alternate" title="Español (MX)" type="text/html">
#  <link href="https://www.booking.com/city/fr/paris.fr.html" hreflang="ca" rel="alternate" title="Català" type="text/html">
#  <link href="https://www.booking.com/city/fr/paris.fr.html" hreflang="it" rel="alternate" title="Italiano" type="text/html">
#  <link href="https://www.booking.com/city/fr/paris.fr.html" hreflang="pt-pt" rel="alternate" title="Português (PT)" type="text/html">
#  <link href="https://www.booking.com/city/fr/paris.fr.html" hreflang="pt-br" rel="alternate" title="Português (BR)" type="text/html">
#  <link href="https://www.booking.com/city/fr/paris.fr.html" hreflang="no" rel="alternate" title="Norsk" type="text/html">
#  <link href="https://www.booking.com/city/fr/paris.fr.html" hreflang="fi" rel="alternate" title="Suomi" type="text/html">
#  <link href="https://www.booking.com/city/fr/paris.fr.html" hreflang="sv" rel="alternate" title="Svenska" type="text/html">
#  <link href="https://www.booking.com/city/fr/paris.fr.html" hreflang="da" rel="alternate" title="Dansk" type="text/html">
#  <link href="https://www.booking.com/city/fr/paris.fr.html" hreflang="cs" rel="alternate" title="Čeština" type="text/html"/>
#  <link href="https://www.booking.com/city/fr/paris.fr.html" hreflang="hu" rel="alternate" title="Magyar" type="text/html"/>
#  <link href="https://www.booking.com/city/fr/paris.fr.html" hreflang="ro" rel="alternate" title="Română" type="text/html"/>
#  <link href="https://www.booking.com/city/fr/paris.fr.html" hreflang="ja" rel="alternate" title="日本語" type="text/html"/>
#  <link href="https://www.booking.com/city/fr/paris.fr.html" hreflang="zh-cn" rel="alternate" title="简体中文" type="text/html"/>
#  <link href="https://www.booking.com/city/fr/paris.fr.html" hreflang="zh-tw" rel="alternate" title="繁體中文" type="text/html"/>
#  <link href="https://www.booking.com/city/fr/paris.fr.html" hreflang="pl" rel="alternate" title="Polski" type="text/html"/>
#  <link href="https://www.booking.com/city/fr/paris.fr.html" hreflang="el" rel="alternate" title="Ελληνικά" type="text/html"/>
#  <link href="https://www.booking.com/city/fr/paris.fr.html" hreflang="ru" rel="alternate" title="Русский" type="text/html"/>
#  <link href="https://www.booking.com/city/fr/paris.fr.html" hreflang="tr" rel="alternate" title="Türkçe" type="text/html"/>
#  <link href="https://www.booking.com/city/fr/paris.fr.html" hreflang="bg" rel="alternate" title="Български" type="text/html"/>
#  <link href="https://www.booking.com/city/fr/paris.fr.html" hreflang="ar" rel="alternate" title="العربية" type="text/html"/>
#  <link href="https://www.booking.com/city/fr/paris.fr.html" hreflang="ko" rel="alternate" title="한국어" type="text/html"/>
#  <link href="https://www.booking.com/city/fr/paris.fr.html" hreflang="he" rel="alternate" title="עברית" type="text/html"/>
#  <link href="https://www.booking.com/city/fr/paris.fr.html" hreflang="lv" rel="alternate" title="Latviski" type="text/html"/>
#  <link href="https://www.booking.com/city/fr/paris.fr.html" hreflang="uk" rel="alternate" title="Українська" type="text/html"/>
#  <link href="https://www.booking.com/city/fr/paris.fr.html" hreflang="hi" rel="alternate" title="हिन्दी" type="text/html"/>
#  <link href="https://www.booking.com/city/fr/paris.fr.html" hreflang="id" rel="alternate" title="Bahasa Indonesia" type="text/html"/>
#  <link href="https://www.booking.com/city/fr/paris.fr.html" hreflang="ms" rel="alternate" title="Bahasa Malaysia" type="text/html"/>
#  <link href="https://www.booking.com/city/fr/paris.fr.html" hreflang="th" rel="alternate" title="ภาษาไทย" type="text/html"/>
#  <link href="https://www.booking.com/city/fr/paris.fr.html" hreflang="et" rel="alternate" title="Eesti" type="text/html"/>
#  <link href="https://www.booking.com/city/fr/paris.fr.html" hreflang="hr" rel="alternate" title="Hrvatski" type="text/html"/>
#  <link href="https://www.booking.com/city/fr/paris.fr.html" hreflang="lt" rel="alternate" title="Lietuvių" type="text/html"/>
#  <link href="https://www.booking.com/city/fr/paris.fr.html" hreflang="sk" rel="alternate" title="Slovenčina" type="text/html"/>
#  <link href="https://www.booking.com/city/fr/paris.fr.html" hreflang="sr" rel="alternate" title="Srpski" type="text/html"/>
#  <link href="https://www.booking.com/city/fr/paris.fr.html" hreflang="sl" rel="alternate" title="Slovenščina" type="text/html"/>
#  <link href="https://www.booking.com/city/fr/paris.fr.html" hreflang="vi" rel="alternate" title="Tiếng Việt" type="text/html"/>
#  <link href="https://www.booking.com/city/fr/paris.fr.html" hreflang="tl" rel="alternate" title="Filipino" type="text/html"/>
#  <link href="https://www.booking.com/city/fr/paris.fr.html" hreflang="is" rel="alternate" title="Íslenska" type="text/html"/>
#  <script nonce="WtWEDzpC6GZb9pD">
#  (function(){
#  document.addEventListener('DOMContentLoaded', function(e) {
#  window._pxAppId = 'PXikKuL2RM';
#  setTimeout(function() {
#  var pxs = document.createElement('script');
#  pxs.crossOrigin = 'anonymous';
#  pxs.nonce = 'WtWEDzpC6GZb9pD';
#  pxs.src = 'https://cf.bstatic.com/libs/perimeterx/px.v7.6.9.min.js';
#  document.head.appendChild(pxs);
#  }, 750);
#  });
#  }());
#  </script>
#  <script nonce="WtWEDzpC6GZb9pD" type="text/javascript">
#  window.cspViolationsCount = 0;
#  if ('SecurityPolicyViolationEvent' in window) {
#  document.addEventListener("securitypolicyviolation", (e) => {
#  if (navigator.userAgent.indexOf('Safari') != -1 && navigator.userAgent.indexOf('Chrome') == -1) {
#  window.cspViolationsCount++;
#  } else if (e.disposition === 'enforce') {
#  window.cspViolationsCount++;
#  }
#  });
#  }
#  </script>
#  <link data-chunk="client" href="https://cf.bstatic.com/psb/capla/static/css/bui-react.1a9a97ad.css" nonce="WtWEDzpC6GZb9pD" rel="stylesheet"/><link data-chunk="src-components-FiltersMobile-FiltersMobile" href="https://cf.bstatic.com/psb/capla/static/css/3557.6e49dbf9.chunk.css" nonce="WtWEDzpC6GZb9pD" rel="stylesheet"/><link data-chunk="src-components-LoadingOverlayMobile-LoadingOverlayMobile" href="https://cf.bstatic.com/psb/capla/static/css/5338.284f1561.chunk.css" nonce="WtWEDzpC6GZb9pD" rel="stylesheet"/><link data-chunk="src-components-TripTypePilotBeachMobileHeader-TripTypePilotBeachMobileHeader" href="https://cf.bstatic.com/psb/capla/static/css/6493.4af61583.chunk.css" nonce="WtWEDzpC6GZb9pD" rel="stylesheet"/><link data-chunk="src-components-TripTypeSki-UfiHeaderMobile-TripTypeSkiUfiHeaderMobile" href="https://cf.bstatic.com/psb/capla/static/css/2863.31a4ae57.chunk.css" nonce="WtWEDzpC6GZb9pD" rel="stylesheet"/><link data-chunk="src-components-TripTypeSki-LandmarkHeaderMobile-TripTypeSkiLandmarkHeaderMobile" href="https://cf.bstatic.com/psb/capla/static/css/358.17753b14.chunk.css" nonce="WtWEDzpC6GZb9pD" rel="stylesheet"/><link data-chunk="src-components-PropertiesListMobile-PropertiesListMobile" href="https://cf.bstatic.com/psb/capla/static/css/9958.c6f958bd.chunk.css" nonce="WtWEDzpC6GZb9pD" rel="stylesheet"/><link data-chunk="bookingcom-alpaca-patterns-SearchResultsBanners-BHQualityClassification-BHQualityClassificationCard-BHQualityClassificationCard" href="https://cf.bstatic.com/psb/capla/static/css/4114.07e7db64.chunk.css" nonce="WtWEDzpC6GZb9pD" rel="stylesheet"/><link data-chunk="common-genius-patterns-GeniusOnboardingSheet-GeniusOnboardingSheet" href="https://cf.bstatic.com/psb/capla/static/css/5738.c8c52fba.chunk.css" nonce="WtWEDzpC6GZb9pD" rel="stylesheet"/><link data-chunk="src-components-SearchBoxMobile-SearchBoxMobile" href="https://cf.bstatic.com/psb/capla/static/css/313.42a5bc69.chunk.css" nonce="WtWEDzpC6GZb9pD" rel="stylesheet"/><link data-chunk="src-components-SearchBoxMinifiedMobile-SearchBoxMinifiedMobile" href="https://cf.bstatic.com/psb/capla/static/css/9540.f5cab9ff.chunk.css" nonce="WtWEDzpC6GZb9pD" rel="stylesheet"/><link data-chunk="src-components-SortersFiltersMapTriggersMobile-SortersFiltersMapTriggersMobile" href="https://cf.bstatic.com/psb/capla/static/css/9473.2abf389c.chunk.css" nonce="WtWEDzpC6GZb9pD" rel="stylesheet"/><link data-chunk="bookingcom-web-shell-header-mfe-components-AccommodationHeader-SearchResultHeader" href="https://cf.bstatic.com/psb/capla/static/css/1238.50787710.chunk.css" nonce="WtWEDzpC6GZb9pD" rel="stylesheet"/><link data-chunk="bookingcom-web-shell-header-mfe-components-GlobalAlerts" href="https://cf.bstatic.com/psb/capla/static/css/3665.6913b2e2.chunk.css" nonce="WtWEDzpC6GZb9pD" rel="stylesheet"/>
#  <title>
#  Booking.com
#  :
#  Hôtels Paris
#  .
#  Réservez votre hôtel dès maintenant !
#  </title>
#  <meta content="Hôtel, Paris,  Hôtels, hébergement, logement, Offres spéciales, promotions, offres week-ends, Prix compétitifs, réductions, prix bon marché" name="keywords">
#  <meta content="index,follow" name="robots">
#  <link href="https://www.booking.com/city/fr/paris.fr.html" rel="canonical">
#  <meta content="UmFuZG9tSVbswUMIJb9y447nac2upTDqzdVfeycMdpc27iffwGs_6KtOGJwBNtcuyVwZTWaOPPohKSWGwjhHavHalyY9LDk2_oaUoC4r8wB4-Z61UlVmDexKPW8DdigEs8VkpLy5WDwCoOSZehui09slGap6gyhE-N2Ukr7b5EwGqyHJ9QJRFkkR1IK-tYUfgnrkCnSK8mmIivpxvIH6b4vj3DEQXkoxWr7xnnR1GpmsUyFCVk9uvD1X9P3NeAjqMSQKtN2l1MYZf5Rp0RBB33QS_LPhdGc_ie0Gj7_kb7BnzDbw2leUjtpJDL08sn-GU6vPgD9TBcYsSZSo7nB0g_eLEEIjLFIxXseDhkxnw2V9Fy0ySNT_RpuQEb57E_7wM0AA53EAgEyNO7ZBQoNFkm78HLuPaQPISZ8JJx5TT1663Onp7fiwJJiotDVeZSFTAu4TtSy_VGo" name="booking-verification">
#  <meta content="367003839" name="twitter:app:id:iphone"/>
#  <meta content="Booking.com Hotel Reservations Worldwide &amp; Hotel Deals" name="twitter:app:name:ipad"/>
#  <meta content="367003839" name="twitter:app:id:ipad"/>
#  <meta content="Booking.com Hotel Reservations" name="twitter:app:name:googleplay"/>
#  <meta content="com.booking" name="twitter:app:id:googleplay"/>
#  <meta content="367003839" property="al:ios:app_store_id"/>
#  <meta content="Booking.com Hotel Reservations" property="al:ios:app_name"/>
# ...
#  <link data-chunk="src-components-PropertiesListMobile-PropertiesListMobile" href="https://cf.bstatic.com/psb/capla/static/css/9958.c6f958bd.chunk.css" nonce="WtWEDzpC6GZb9pD" rel="stylesheet"/>,
#  <link data-chunk="bookingcom-alpaca-patterns-SearchResultsBanners-BHQualityClassification-BHQualityClassificationCard-BHQualityClassificationCard" href="https://cf.bstatic.com/psb/capla/static/css/4114.07e7db64.chunk.css" nonce="WtWEDzpC6GZb9pD" rel="stylesheet"/>,
#  <link data-chunk="common-genius-patterns-GeniusOnboardingSheet-GeniusOnboardingSheet" href="https://cf.bstatic.com/psb/capla/static/css/5738.c8c52fba.chunk.css" nonce="WtWEDzpC6GZb9pD" rel="stylesheet"/>,
#  <link data-chunk="src-components-SearchBoxMobile-SearchBoxMobile" href="https://cf.bstatic.com/psb/capla/static/css/313.42a5bc69.chunk.css" nonce="WtWEDzpC6GZb9pD" rel="stylesheet"/>,
#  <link data-chunk="src-components-SearchBoxMinifiedMobile-SearchBoxMinifiedMobile" href="https://cf.bstatic.com/psb/capla/static/css/9540.f5cab9ff.chunk.css" nonce="WtWEDzpC6GZb9pD" rel="stylesheet"/>,
#  <link data-chunk="src-components-SortersFiltersMapTriggersMobile-SortersFiltersMapTriggersMobile" href="https://cf.bstatic.com/psb/capla/static/css/9473.2abf389c.chunk.css" nonce="WtWEDzpC6GZb9pD" rel="stylesheet"/>,
#  <link data-chunk="bookingcom-web-shell-header-mfe-components-AccommodationHeader-SearchResultHeader" href="https://cf.bstatic.com/psb/capla/static/css/1238.50787710.chunk.css" nonce="WtWEDzpC6GZb9pD" rel="stylesheet"/>,
#  <link data-chunk="bookingcom-web-shell-header-mfe-components-GlobalAlerts" href="https://cf.bstatic.com/psb/capla/static/css/3665.6913b2e2.chunk.css" nonce="WtWEDzpC6GZb9pD" rel="stylesheet"/>,
#  <title>
#  Booking.com
#  :
#  Hôtels Paris
#  .
#  Réservez votre hôtel dès maintenant !
#  </title>,
#  <meta content="Hôtel, Paris,  Hôtels, hébergement, logement, Offres spéciales, promotions, offres week-ends, Prix compétitifs, réductions, prix bon marché" name="keywords">
#  <meta content="index,follow" name="robots">
#  <link href="https://www.booking.com/city/fr/paris.fr.html" rel="canonical">
#  <meta content="UmFuZG9tSVbswUMIJb9y447nac2upTDqzdVfeycMdpc27iffwGs_6KtOGJwBNtcuyVwZTWaOPPohKSWGwjhHavHalyY9LDk2_oaUoC4r8wB4-Z61UlVmDexKPW8DdigEs8VkpLy5WDwCoOSZehui09slGap6gyhE-N2Ukr7b5EwGqyHJ9QJRFkkR1IK-tYUfgnrkCnSK8mmIivpxvIH6b4vj3DEQXkoxWr7xnnR1GpmsUyFCVk9uvD1X9P3NeAjqMSQKtN2l1MYZf5Rp0RBB33QS_LPhdGc_ie0Gj7_kb7BnzDbw2leUjtpJDL08sn-GU6vPgD9TBcYsSZSo7nB0g_eLEEIjLFIxXseDhkxnw2V9Fy0ySNT_RpuQEb57E_7wM0AA53EAgEyNO7ZBQoNFkm78HLuPaQPISZ8JJx5TT1663Onp7fiwJJiotDVeZSFTAu4TtSy_VGo" name="booking-verification">
#  <meta content="367003839" name="twitter:app:id:iphone"/>
#  <meta content="Booking.com Hotel Reservations Worldwide &amp; Hotel Deals" name="twitter:app:name:ipad"/>
#  <meta content="367003839" name="twitter:app:id:ipad"/>
#  <meta content="Booking.com Hotel Reservations" name="twitter:app:name:googleplay"/>
#  <meta content="com.booking" name="twitter:app:id:googleplay"/>
#  <meta content="367003839" property="al:ios:app_store_id"/>
#  <meta content="Booking.com Hotel Reservations" property="al:ios:app_name"/>
#  <meta content="Booking.com Hotel Reservation" property="al:android:app_name"/>
#  <meta content="com.booking" property="al:android:package"/>
#  <meta content="" name="twitter:title">
#  <meta content="booking://searchresults?dest_id=-1456928&amp;dest_type=city&amp;affiliate_id=375119&amp;source=gen173nr-1VCAQoggJCDHNlYXJjaF9wYXJpc0gNWARoTYgBApgBDbgBCcgBEdgBAegBAfgBA4gCAagCA7gCtuv3nQbAAgLSAiRlNDMzZWMzZC02YTM5LTQwNTYtOGI1MS1mMWNjNzc2MjVkMjnYAgbgAgE" property="al:ios:url">
#  <meta content="booking://searchresults?dest_id=-1456928&amp;dest_type=city&amp;affiliate_id=375119&amp;source=gen173nr-1VCAQoggJCDHNlYXJjaF9wYXJpc0gNWARoTYgBApgBDbgBCcgBEdgBAegBAfgBA4gCAagCA7gCtuv3nQbAAgLSAiRlNDMzZWMzZC02YTM5LTQwNTYtOGI1MS1mMWNjNzc2MjVkMjnYAgbgAgE" property="al:android:url">
#  <meta content="yes" name="apple-touch-fullscreen"/>
#  <meta content="no" name="apple-mobile-web-app-capable">
#  <meta content="telephone=no" name="format-detection"/>
#  <link href="https://cf.bstatic.com/static/img/favicon/ebc77706da3aae4aee7b05dadf182390f0d26d11.ico" rel="shortcut icon">
#  <link href="https://cf.bstatic.com/static/img/apple-touch-icon_new_lrg/c9b35bf29a75cac2f430f80a5d4bc7fd961d21a7.png" rel="apple-touch-icon">
#  </link></link></meta></meta></meta></meta></meta></link></meta></meta>,
#  <meta content="index,follow" name="robots">
#  <link href="https://www.booking.com/city/fr/paris.fr.html" rel="canonical">
#  <meta content="UmFuZG9tSVbswUMIJb9y447nac2upTDqzdVfeycMdpc27iffwGs_6KtOGJwBNtcuyVwZTWaOPPohKSWGwjhHavHalyY9LDk2_oaUoC4r8wB4-Z61UlVmDexKPW8DdigEs8VkpLy5WDwCoOSZehui09slGap6gyhE-N2Ukr7b5EwGqyHJ9QJRFkkR1IK-tYUfgnrkCnSK8mmIivpxvIH6b4vj3DEQXkoxWr7xnnR1GpmsUyFCVk9uvD1X9P3NeAjqMSQKtN2l1MYZf5Rp0RBB33QS_LPhdGc_ie0Gj7_kb7BnzDbw2leUjtpJDL08sn-GU6vPgD9TBcYsSZSo7nB0g_eLEEIjLFIxXseDhkxnw2V9Fy0ySNT_RpuQEb57E_7wM0AA53EAgEyNO7ZBQoNFkm78HLuPaQPISZ8JJx5TT1663Onp7fiwJJiotDVeZSFTAu4TtSy_VGo" name="booking-verification">
#  <meta content="367003839" name="twitter:app:id:iphone"/>
#  <meta content="Booking.com Hotel Reservations Worldwide &amp; Hotel Deals" name="twitter:app:name:ipad"/>
#  <meta content="367003839" name="twitter:app:id:ipad"/>
#  <meta content="Booking.com Hotel Reservations" name="twitter:app:name:googleplay"/>
#  <meta content="com.booking" name="twitter:app:id:googleplay"/>
#  <meta content="367003839" property="al:ios:app_store_id"/>
#  <meta content="Booking.com Hotel Reservations" property="al:ios:app_name"/>
#  <meta content="Booking.com Hotel Reservation" property="al:android:app_name"/>
#  <meta content="com.booking" property="al:android:package"/>
#  <meta content="" name="twitter:title">
#  <meta content="booking://searchresults?dest_id=-1456928&amp;dest_type=city&amp;affiliate_id=375119&amp;source=gen173nr-1VCAQoggJCDHNlYXJjaF9wYXJpc0gNWARoTYgBApgBDbgBCcgBEdgBAegBAfgBA4gCAagCA7gCtuv3nQbAAgLSAiRlNDMzZWMzZC02YTM5LTQwNTYtOGI1MS1mMWNjNzc2MjVkMjnYAgbgAgE" property="al:ios:url">
#  <meta content="booking://searchresults?dest_id=-1456928&amp;dest_type=city&amp;affiliate_id=375119&amp;source=gen173nr-1VCAQoggJCDHNlYXJjaF9wYXJpc0gNWARoTYgBApgBDbgBCcgBEdgBAegBAfgBA4gCAagCA7gCtuv3nQbAAgLSAiRlNDMzZWMzZC02YTM5LTQwNTYtOGI1MS1mMWNjNzc2MjVkMjnYAgbgAgE" property="al:android:url">
#  <meta content="yes" name="apple-touch-fullscreen"/>
#  <meta content="no" name="apple-mobile-web-app-capable">
#  <meta content="telephone=no" name="format-detection"/>
#  <link href="https://cf.bstatic.com/static/img/favicon/ebc77706da3aae4aee7b05dadf182390f0d26d11.ico" rel="shortcut icon">
#  <link href="https://cf.bstatic.com/static/img/apple-touch-icon_new_lrg/c9b35bf29a75cac2f430f80a5d4bc7fd961d21a7.png" rel="apple-touch-icon">
#  </link></link></meta></meta></meta></meta></meta></link></meta>,
#  <link href="https://www.booking.com/city/fr/paris.fr.html" rel="canonical">
#  <meta content="UmFuZG9tSVbswUMIJb9y447nac2upTDqzdVfeycMdpc27iffwGs_6KtOGJwBNtcuyVwZTWaOPPohKSWGwjhHavHalyY9LDk2_oaUoC4r8wB4-Z61UlVmDexKPW8DdigEs8VkpLy5WDwCoOSZehui09slGap6gyhE-N2Ukr7b5EwGqyHJ9QJRFkkR1IK-tYUfgnrkCnSK8mmIivpxvIH6b4vj3DEQXkoxWr7xnnR1GpmsUyFCVk9uvD1X9P3NeAjqMSQKtN2l1MYZf5Rp0RBB33QS_LPhdGc_ie0Gj7_kb7BnzDbw2leUjtpJDL08sn-GU6vPgD9TBcYsSZSo7nB0g_eLEEIjLFIxXseDhkxnw2V9Fy0ySNT_RpuQEb57E_7wM0AA53EAgEyNO7ZBQoNFkm78HLuPaQPISZ8JJx5TT1663Onp7fiwJJiotDVeZSFTAu4TtSy_VGo" name="booking-verification">
#  <meta content="367003839" name="twitter:app:id:iphone"/>
#  <meta content="Booking.com Hotel Reservations Worldwide &amp; Hotel Deals" name="twitter:app:name:ipad"/>
#  <meta content="367003839" name="twitter:app:id:ipad"/>
#  <meta content="Booking.com Hotel Reservations" name="twitter:app:name:googleplay"/>
#  <meta content="com.booking" name="twitter:app:id:googleplay"/>
#  <meta content="367003839" property="al:ios:app_store_id"/>
#  <meta content="Booking.com Hotel Reservations" property="al:ios:app_name"/>
#  <meta content="Booking.com Hotel Reservation" property="al:android:app_name"/>
#  <meta content="com.booking" property="al:android:package"/>
#  <meta content="" name="twitter:title">
#  <meta content="booking://searchresults?dest_id=-1456928&amp;dest_type=city&amp;affiliate_id=375119&amp;source=gen173nr-1VCAQoggJCDHNlYXJjaF9wYXJpc0gNWARoTYgBApgBDbgBCcgBEdgBAegBAfgBA4gCAagCA7gCtuv3nQbAAgLSAiRlNDMzZWMzZC02YTM5LTQwNTYtOGI1MS1mMWNjNzc2MjVkMjnYAgbgAgE" property="al:ios:url">
#  <meta content="booking://searchresults?dest_id=-1456928&amp;dest_type=city&amp;affiliate_id=375119&amp;source=gen173nr-1VCAQoggJCDHNlYXJjaF9wYXJpc0gNWARoTYgBApgBDbgBCcgBEdgBAegBAfgBA4gCAagCA7gCtuv3nQbAAgLSAiRlNDMzZWMzZC02YTM5LTQwNTYtOGI1MS1mMWNjNzc2MjVkMjnYAgbgAgE" property="al:android:url">
#  <meta content="yes" name="apple-touch-fullscreen"/>
#  <meta content="no" name="apple-mobile-web-app-capable">
#  <meta content="telephone=no" name="format-detection"/>
#  <link href="https://cf.bstatic.com/static/img/favicon/ebc77706da3aae4aee7b05dadf182390f0d26d11.ico" rel="shortcut icon">
#  <link href="https://cf.bstatic.com/static/img/apple-touch-icon_new_lrg/c9b35bf29a75cac2f430f80a5d4bc7fd961d21a7.png" rel="apple-touch-icon">
#  </link></link></meta></meta></meta></meta></meta></link>,
#  <meta content="UmFuZG9tSVbswUMIJb9y447nac2upTDqzdVfeycMdpc27iffwGs_6KtOGJwBNtcuyVwZTWaOPPohKSWGwjhHavHalyY9LDk2_oaUoC4r8wB4-Z61UlVmDexKPW8DdigEs8VkpLy5WDwCoOSZehui09slGap6gyhE-N2Ukr7b5EwGqyHJ9QJRFkkR1IK-tYUfgnrkCnSK8mmIivpxvIH6b4vj3DEQXkoxWr7xnnR1GpmsUyFCVk9uvD1X9P3NeAjqMSQKtN2l1MYZf5Rp0RBB33QS_LPhdGc_ie0Gj7_kb7BnzDbw2leUjtpJDL08sn-GU6vPgD9TBcYsSZSo7nB0g_eLEEIjLFIxXseDhkxnw2V9Fy0ySNT_RpuQEb57E_7wM0AA53EAgEyNO7ZBQoNFkm78HLuPaQPISZ8JJx5TT1663Onp7fiwJJiotDVeZSFTAu4TtSy_VGo" name="booking-verification">
#  <meta content="367003839" name="twitter:app:id:iphone"/>
#  <meta content="Booking.com Hotel Reservations Worldwide &amp; Hotel Deals" name="twitter:app:name:ipad"/>
#  <meta content="367003839" name="twitter:app:id:ipad"/>
#  <meta content="Booking.com Hotel Reservations" name="twitter:app:name:googleplay"/>
#  <meta content="com.booking" name="twitter:app:id:googleplay"/>
#  <meta content="367003839" property="al:ios:app_store_id"/>
#  <meta content="Booking.com Hotel Reservations" property="al:ios:app_name"/>
#  <meta content="Booking.com Hotel Reservation" property="al:android:app_name"/>
#  <meta content="com.booking" property="al:android:package"/>
#  <meta content="" name="twitter:title">
#  <meta content="booking://searchresults?dest_id=-1456928&amp;dest_type=city&amp;affiliate_id=375119&amp;source=gen173nr-1VCAQoggJCDHNlYXJjaF9wYXJpc0gNWARoTYgBApgBDbgBCcgBEdgBAegBAfgBA4gCAagCA7gCtuv3nQbAAgLSAiRlNDMzZWMzZC02YTM5LTQwNTYtOGI1MS1mMWNjNzc2MjVkMjnYAgbgAgE" property="al:ios:url">
#  <meta content="booking://searchresults?dest_id=-1456928&amp;dest_type=city&amp;affiliate_id=375119&amp;source=gen173nr-1VCAQoggJCDHNlYXJjaF9wYXJpc0gNWARoTYgBApgBDbgBCcgBEdgBAegBAfgBA4gCAagCA7gCtuv3nQbAAgLSAiRlNDMzZWMzZC02YTM5LTQwNTYtOGI1MS1mMWNjNzc2MjVkMjnYAgbgAgE" property="al:android:url">
#  <meta content="yes" name="apple-touch-fullscreen"/>
#  <meta content="no" name="apple-mobile-web-app-capable">
#  <meta content="telephone=no" name="format-detection"/>
#  <link href="https://cf.bstatic.com/static/img/favicon/ebc77706da3aae4aee7b05dadf182390f0d26d11.ico" rel="shortcut icon">
#  <link href="https://cf.bstatic.com/static/img/apple-touch-icon_new_lrg/c9b35bf29a75cac2f430f80a5d4bc7fd961d21a7.png" rel="apple-touch-icon">
#  </link></link></meta></meta></meta></meta></meta>,
#  <meta content="367003839" name="twitter:app:id:iphone"/>,
#  <meta content="Booking.com Hotel Reservations Worldwide &amp; Hotel Deals" name="twitter:app:name:ipad"/>,
#  <meta content="367003839" name="twitter:app:id:ipad"/>,
#  <meta content="Booking.com Hotel Reservations" name="twitter:app:name:googleplay"/>,
#  <meta content="com.booking" name="twitter:app:id:googleplay"/>,
#  <meta content="367003839" property="al:ios:app_store_id"/>,
#  <meta content="Booking.com Hotel Reservations" property="al:ios:app_name"/>,
#  <meta content="Booking.com Hotel Reservation" property="al:android:app_name"/>,
#  <meta content="com.booking" property="al:android:package"/>,
#  <meta content="" name="twitter:title">
#  <meta content="booking://searchresults?dest_id=-1456928&amp;dest_type=city&amp;affiliate_id=375119&amp;source=gen173nr-1VCAQoggJCDHNlYXJjaF9wYXJpc0gNWARoTYgBApgBDbgBCcgBEdgBAegBAfgBA4gCAagCA7gCtuv3nQbAAgLSAiRlNDMzZWMzZC02YTM5LTQwNTYtOGI1MS1mMWNjNzc2MjVkMjnYAgbgAgE" property="al:ios:url">
#  <meta content="booking://searchresults?dest_id=-1456928&amp;dest_type=city&amp;affiliate_id=375119&amp;source=gen173nr-1VCAQoggJCDHNlYXJjaF9wYXJpc0gNWARoTYgBApgBDbgBCcgBEdgBAegBAfgBA4gCAagCA7gCtuv3nQbAAgLSAiRlNDMzZWMzZC02YTM5LTQwNTYtOGI1MS1mMWNjNzc2MjVkMjnYAgbgAgE" property="al:android:url">
#  <meta content="yes" name="apple-touch-fullscreen"/>
#  <meta content="no" name="apple-mobile-web-app-capable">
#  <meta content="telephone=no" name="format-detection"/>
#  <link href="https://cf.bstatic.com/static/img/favicon/ebc77706da3aae4aee7b05dadf182390f0d26d11.ico" rel="shortcut icon">
#  <link href="https://cf.bstatic.com/static/img/apple-touch-icon_new_lrg/c9b35bf29a75cac2f430f80a5d4bc7fd961d21a7.png" rel="apple-touch-icon">
#  </link></link></meta></meta></meta></meta>,
#  <meta content="booking://searchresults?dest_id=-1456928&amp;dest_type=city&amp;affiliate_id=375119&amp;source=gen173nr-1VCAQoggJCDHNlYXJjaF9wYXJpc0gNWARoTYgBApgBDbgBCcgBEdgBAegBAfgBA4gCAagCA7gCtuv3nQbAAgLSAiRlNDMzZWMzZC02YTM5LTQwNTYtOGI1MS1mMWNjNzc2MjVkMjnYAgbgAgE" property="al:ios:url">
#  <meta content="booking://searchresults?dest_id=-1456928&amp;dest_type=city&amp;affiliate_id=375119&amp;source=gen173nr-1VCAQoggJCDHNlYXJjaF9wYXJpc0gNWARoTYgBApgBDbgBCcgBEdgBAegBAfgBA4gCAagCA7gCtuv3nQbAAgLSAiRlNDMzZWMzZC02YTM5LTQwNTYtOGI1MS1mMWNjNzc2MjVkMjnYAgbgAgE" property="al:android:url">
#  <meta content="yes" name="apple-touch-fullscreen"/>
#  <meta content="no" name="apple-mobile-web-app-capable">
#  <meta content="telephone=no" name="format-detection"/>
#  <link href="https://cf.bstatic.com/static/img/favicon/ebc77706da3aae4aee7b05dadf182390f0d26d11.ico" rel="shortcut icon">
#  <link href="https://cf.bstatic.com/static/img/apple-touch-icon_new_lrg/c9b35bf29a75cac2f430f80a5d4bc7fd961d21a7.png" rel="apple-touch-icon">
#  </link></link></meta></meta></meta>,
#  <meta content="booking://searchresults?dest_id=-1456928&amp;dest_type=city&amp;affiliate_id=375119&amp;source=gen173nr-1VCAQoggJCDHNlYXJjaF9wYXJpc0gNWARoTYgBApgBDbgBCcgBEdgBAegBAfgBA4gCAagCA7gCtuv3nQbAAgLSAiRlNDMzZWMzZC02YTM5LTQwNTYtOGI1MS1mMWNjNzc2MjVkMjnYAgbgAgE" property="al:android:url">
#  <meta content="yes" name="apple-touch-fullscreen"/>
#  <meta content="no" name="apple-mobile-web-app-capable">
#  <meta content="telephone=no" name="format-detection"/>
#  <link href="https://cf.bstatic.com/static/img/favicon/ebc77706da3aae4aee7b05dadf182390f0d26d11.ico" rel="shortcut icon">
#  <link href="https://cf.bstatic.com/static/img/apple-touch-icon_new_lrg/c9b35bf29a75cac2f430f80a5d4bc7fd961d21a7.png" rel="apple-touch-icon">
#  </link></link></meta></meta>,
#  <meta content="yes" name="apple-touch-fullscreen"/>,
#  <meta content="no" name="apple-mobile-web-app-capable">
#  <meta content="telephone=no" name="format-detection"/>
#  <link href="https://cf.bstatic.com/static/img/favicon/ebc77706da3aae4aee7b05dadf182390f0d26d11.ico" rel="shortcut icon">
#  <link href="https://cf.bstatic.com/static/img/apple-touch-icon_new_lrg/c9b35bf29a75cac2f430f80a5d4bc7fd961d21a7.png" rel="apple-touch-icon">
#  </link></link></meta>,
#  <meta content="telephone=no" name="format-detection"/>,
#  <link href="https://cf.bstatic.com/static/img/favicon/ebc77706da3aae4aee7b05dadf182390f0d26d11.ico" rel="shortcut icon">
#  <link href="https://cf.bstatic.com/static/img/apple-touch-icon_new_lrg/c9b35bf29a75cac2f430f80a5d4bc7fd961d21a7.png" rel="apple-touch-icon">
#  </link></link>,
#  <link href="https://cf.bstatic.com/static/img/apple-touch-icon_new_lrg/c9b35bf29a75cac2f430f80a5d4bc7fd961d21a7.png" rel="apple-touch-icon">
#  </link>]

# %%
print(soup.select(".flex.flex-grow-1.justify-between.accomodation-item_infoSection__jtzM6.flex-1"))
# Out:
# []

# %%
soup
# Out:
# <!DOCTYPE html>
#
# <!--
# You know you could be getting paid to poke around in our code?
# We're hiring designers and developers to work in Amsterdam:
# https://careers.booking.com/
# -->
# <!-- mdot-548 -->
# <html class="no-js" lang="fr">
# <head>
# <link crossorigin="" href="https://cf.bstatic.com" rel="dns-prefetch"/>
# <link crossorigin="" href="https://cf.bstatic.com" rel="dns-prefetch"/>
# <script nonce="WtWEDzpC6GZb9pD" type="text/javascript">
# document.addEventListener('DOMContentLoaded', function () {
# /**
# * provides the current user's cookie consent
# * in order to use it:
# * 1. inline privacy/cookieConsent.js in the page you need to use it.
# * please note that this library relies on window.PCM.isCountryNeedCookieBanner to be initialised
# * before using (calling getValue function) it
# * 2. in your js file:
# *
# * var privacyCookieConsent = B.require('privacyCookieConsent');
# * var consent = privacyCookieConsent.getValue();
# */
# B.define('privacyCookieConsent', function () {
# var consentGroupIsAllowed = {
# analytical: 'C0002%3A1',
# marketing: 'C0004%3A1'
# };
# var optanonConsentCookieName = 'OptanonConsent';
# var optanonBoxClosedCookieName = 'OptanonAlertBoxClosed';
# var halfOfYearMillis = 180 * 24 * 60 * 60 * 1000;
# function isDefined(value) {
# return value && value !== "undefined";
# }
# function parseConsentToObject(consent) {
# var result = {};
# if (typeof consent === 'string') {
# var parts = consent.split('&');
# parts.forEach(function (part) {
# var keyAndValue = part.split('=');
# result[keyAndValue[0]] = keyAndValue[1];
# });
# }
# return result;
# }
# function isConsentValid(consent, alertBoxClosed) {
# return isDefined(consent) &&
# isDefined(alertBoxClosed) &&
# new Date() - new Date(alertBoxClosed) <= halfOfYearMillis;
# }
# function getCookie(name) {
# name += "=";
# var cookies = document.cookie.split(";");
# for (var i = 0; i < cookies.length; i += 1) {
# var cookie = cookies[i];
# while (cookie.charAt(0) === " ") {
# cookie = cookie.substring(1, cookie.length);
# }
# if (cookie.indexOf(name) === 0) {
# return cookie.substring(name.length, cookie.length);
# }
# }
# return null;
# }
# function doesGeolocationRequireBanner() {
# // In case window.PCM is not defined, fallback to opt-out
# return window.PCM ? window.PCM.isCountryNeedCookieBanner : true;
# }
# function getExplicitConsent() {
# var consent = getCookie(optanonConsentCookieName);
# var alertBoxClosed = getCookie(optanonBoxClosedCookieName);
# if (isConsentValid(consent, alertBoxClosed)) {
# var consentObject = parseConsentToObject(consent);
# return Object
# .keys(consentGroupIsAllowed)
# .map(function (purpose) {
# var result = {};
# result[purpose] = consentObject.groups.indexOf(consentGroupIsAllowed[purpose]) > -1;
# return result;
# })
# .reduce(
# function (result, currentValue) {
# return Object.assign(result, currentValue);
# }, {
# functional: true
# }
# );
# }
# }
# function getImplicitConsent() {
# var consentValue = !doesGeolocationRequireBanner();
# return {
# functional: true,
# analytical: consentValue,
# marketing: consentValue
# };
# }
# function getValue() {
# var consent = getExplicitConsent();
# if (!consent) {
# consent = getImplicitConsent();
# }
# return consent;
# }
# return {
# getValue: getValue
# };
# });
# //c360 javascript tracker first iteration
# //sends a track request to c360 http tracker
# //in order to use it:
# //1. inline the c360Tracker.js in the page you need to use it
# //2. in your js file:
# //
# // var c360Tracker = B.require('c360Tracker');
# // var event = {
# // action_name:"accommodation_checkout_confirmation_viewed",
# // action_version :"0.2.0",
# // content : { "transaction_id" : 123434},
# // user : { "BKNG_user_id": 123434}
# // };
# // c360Tracker.track(event);
# B.define('c360Tracker', function () {
# var enrichedContext = {};
# var configuration = {
# validateInput: false
# };
# var track = function (event) {
# if (event == null) {
# return "event object is null or empty";
# } else {
# //if (enrichedContext.userID != null) {
# // event.user = {BKNG_user_id: enrichedContext.userID};
# //}
# var validationResult = new ValidationResult(true);
# if (configuration.validateInput) {
# validationResult = validateInput(event);
# }
# if (!validationResult.success) {
# return validationResult.message;
# }
# send(event);
# }
# };
# function send(data) {
# data.context = enrichedContext;
# data.tracker = {
# tracker_name: "C360JSTracker",
# tracker_type: "Client",
# tracker_version: "0.1.0"
# };
# return $.ajax({
# url: '/c360/v1/track',
# type: 'POST',
# data: JSON.stringify(data),
# });
# }
# enrich();
# var scheme =
# {
# "type": "object",
# "properties": {
# "action_name": {
# "type": "string",
# "description": "action name (ex. element viewed)",
# },
# "action_version": {
# "type": "string",
# "description": "action version"
# },
# "content": {
# "type": "object",
# "description": "content defined by the registered producer scheme"
# }
# }
# };
# function ValidationResult(success, message) {
# this.success = success;
# this.message = message;
# }
# function validateInput(event) {
# var result = validateObject(event, scheme);
# return result;
# }
# function validateObject(obj, scheme) {
# if (scheme.properties != null) {
# var propsArray = Object.getOwnPropertyNames(scheme.properties);
# for (var i = 0; i < propsArray.length; i++) {
# var propertyName = propsArray[i];
# if (obj[propertyName] == null) {
# return new ValidationResult(false, "property " + propertyName + " is not defined");
# }
# if (scheme.properties[propertyName].type == "object") {
# var validationResult = validateObject(obj[propertyName], scheme.properties[propertyName]);
# if (validationResult.success === false) {
# return validationResult;
# }
# }
# }
# }
# return new ValidationResult(true);
# }
# function enrich() {
# enrichedContext = {
# page: {
# page_referrer: document.referrer,
# page_url: window.location.href,
# page_title: document.title
# },
# local: {
# currency: B.env.b_selected_currency
# },
# };
# //if (B.env.b_user_genius_status != null && B.env.b_user_genius_status.b_user_id != null)
# // enrichedContext.userID = B.env.b_user_genius_status.b_user_id;
# }
# return {
# track: track
# };
# });
# })
# </script>
# <script nonce="WtWEDzpC6GZb9pD" src="https://cdn.cookielaw.org/consent/3ea94870-d4b1-483a-b1d2-faf1d982bb31/OtAutoBlock.js" type="text/javascript"></script>
# <script nonce="WtWEDzpC6GZb9pD" type="text/javascript">
# (function () {
# document.addEventListener('cookie_banner_closed', function(e) {
# if (window.PCM && window.B && window.B.et) {
# window.B.et.goal((window.PCM.Marketing || window.PCM.Analytical) ? 'cookie_consent_accepted_policy_banner' : 'cookie_consent_declined_policy_banner');
# }
# });
# document.addEventListener('click', function(e) {
# if (e.target && e.target.classList.contains('ot-preference-center-footer')) {
# e.preventDefault();
# Optanon && Optanon.ToggleInfoDisplay();
# }
# });
# })();
# </script>
# <script nonce="WtWEDzpC6GZb9pD" type="text/javascript">
# window.PCM = {
# isCountryNeedCookieBanner: 1,
# loadStartedAt: 1673393590
# }
# </script>
# <script data-domain-script="3ea94870-d4b1-483a-b1d2-faf1d982bb31" nonce="WtWEDzpC6GZb9pD" src="https://cf.bstatic.com/libs/privacy-consent/releases/2.1.36/customer/cookie-banner.min.js" type="text/javascript"></script>
# <link crossorigin="" href="https://shelves.booking.com/" rel="preconnect"/>
# <meta charset="utf-8"/>
# <script nonce="WtWEDzpC6GZb9pD">
# document.documentElement.className = document.documentElement.className.replace(/\bno-js\b/, 'has-js css-is-loading js-is-loading');
# </script>
# <meta content="origin-when-cross-origin" name="referrer"/>
# <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <script nonce="WtWEDzpC6GZb9pD"> function b_cors_check(supported) { var value = supported ? 1 : 0; if (!/(^|;)\s*cors_js=/.test(document.cookie)) { var d = new Date(); d.setTime(d.getTime() + 60 * 60 * 24 * 365 * 1000); var cookieDomain = '.booking.com' || '.booking.com'; document.cookie = 'cors_js=' + value +'; domain=' + cookieDomain + '; path=/; expires=' + d.toGMTString(); } if (!value) { location.reload(); } } </script>
# <script nonce="WtWEDzpC6GZb9pD">(function(d) { d.addEventListener('error', function(e) { if (e.target && e.target.classList.contains('crossorigin-check-js')) { b_cors_check(false); } }, true); })(document); </script>
# <script async="" class="crossorigin-check-js" crossorigin="" nonce="WtWEDzpC6GZb9pD" src="https://cf.bstatic.com/static/js/crossorigin_check_cloudfront_sd/2454015045ef79168d452ff4e7f30bdadff0aa81.js"></script>
# <script nonce="WtWEDzpC6GZb9pD">
# ;(function() {
# window.b_early_errors = window.b_early_errors || [];
# window.onerror = function() {
# window.b_early_errors.push(arguments);
# };
# }());
#  </script>
# <script nonce="WtWEDzpC6GZb9pD">(function(d) { d.addEventListener('load', function(e) { if (e.target && e.target.classList.contains('stylesheet-preload')) { e.target.rel='stylesheet'; } }, true); })(document); </script>
# <style nonce="WtWEDzpC6GZb9pD">template,.g-hidden{display:none !important}p.error{line-height:18px;color:#A30000;font-weight:bold;margin:10px}html.no-js .no-js-hidden{display:none}body.rtlcss{direction:rtl}.no-js .js-loading-hidden,.js-is-loading .js-loading-hidden,.css-is-loading .css-loading-hidden{display:none !important}.no-js .js-loading-invisible,.js-is-loading .js-loading-invisible,.css-is-loading .css-loading-invisible{visibility:hidden !important}.css-loading-inline-visible{display:none !important}.css-is-loading .css-loading-inline-visible{display:inline-block !important}.searchbox_redesign select[disabled]{color:#BDBDBD}body,div,dl,dt,dd,ul,ol,li,h1,h2,h3,h4,h5,h6,pre,form,fieldset,input,textarea,p,blockquote,th,td{margin:0;padding:0}fieldset,img{border:0}address,caption,cite,code,dfn,em,strong,th,var{font-style:normal;font-weight:normal}q:before,q:after{content:''}abbr,acronym{border:0}body,input,select,button,textarea{font-family:BlinkMacSystemFont,-apple-system,Segoe UI,Roboto,Helvetica,Arial,sans-serif}.rtl,.rtlcss{direction:rtl}.ltr{direction:ltr}.rtlcss .bui-carousel__next,.rtlcss .bui-carousel__prev{transform:scaleX(-1)}body>img,body>iframe[src*="doubleclick.net"]{display:block;margin-top:-1px}a{color:var(--bui_color_action_foreground)}a:link{text-decoration:underline}ol,ul{list-style:none}body{background:var(--bui_color_white);color:#333333;-webkit-text-size-adjust:100%}table{border-collapse:collapse;border-spacing:0}th{text-align:left}.rtlcss th{text-align:right}h1,h2,h3,h4,h5,h6{font-weight:normal}h1{font-weight:bold;margin:10px}h2{font-weight:bold;display:block;margin:0;padding-left:10px;padding-top:2px}.header_profile_btn{font-size:22px;font-weight:normal;padding-left:10px;padding-right:10px;width:auto}.header_profile_btn__genius{font-size:13px}.header_profile_btn .bicon{color:var(--bui_color_white)}.header_profile_btn__genius--svg{padding:0 3px}.genius-profile-icon--svg{margin-top:5px}.searchbox_dest.input_clear_button_input::-webkit-search-cancel-button,.input_destination.input_clear_button_input::-webkit-search-cancel-button{display:none}.input_clear_button{-webkit-tap-highlight-color:rgba(0,0,0,0);background:transparent;border:0;color:#999999;height:100%;font-size:12px;padding:0;opacity:0;outline:none;position:absolute;top:0;transition:opacity .25s;width:38px;z-index:5}.ltr .input_clear_button{padding-left:7px;right:0}.rtl .input_clear_button{padding-right:7px;left:0}.rtlcss .input_clear_button{padding-right:7px;left:0}.searchbox_redesign--destination-focused .input_clear_button,.has-dest-value .input_clear_button,.gps-possible .input_clear_button{opacity:1}.input_clear_button:active{color:var(--bui_color_black);background-color:transparent}.cookie-warning{font-size:13px;display:flex;overflow:hidden;max-height:500px;transition:opacity .3s,max-height 0s .3s;color:var(--bui_color_white);background:#212121;box-shadow:inset 0 -1px var(--bui_color_black);flex-flow:row-reverse nowrap;align-items:center}.cookie-warning__flag{position:absolute;opacity:0}.cookie-warning__flag:checked + .cookie-warning{max-height:0;opacity:0}.cookie-warning__text{overflow:hidden;flex:1 1 auto}.cookie-warning__text,.cookie-warning__close{margin:10px}.cookie-warning__close{padding:4px 6px;border-radius:5px;background:#0071C2;flex:0 0 auto}.cookie-warning__close:active{background:#BAD4F7}.cookie-warning.site-header--sticky{margin-top:40px}.cookie-warning-v2{z-index:1003;position:fixed;bottom:0;left:0;width:100%;background-color:var(--bui_color_white);border-top:1px solid #E6E6E6;text-align:left;color:#333333}.cookie-warning-v2__banner{padding:4px 10px 0 10px;@apply --bui_font_body_2}.cookie-warning-v2__banner-title{margin-bottom:8px}.cookie-warning-v2__more-details,.cookie-warning-v2__settings{z-index:400;overflow-x:auto}.cookie-warning-v2__footer{margin-top:16px}.cookie-warning-v2__footer--text-center{text-align:center}.cookie-warning-v2__header{margin-top:16px}.cookie-warning-v2__header-paragraph{margin:14px 0}.cookie-warning-v ...
# <style nonce="WtWEDzpC6GZb9pD">.sr-card__price--red .sr-card__price-rack-discount{padding:1px 4px;display:inline-block;background:#A30000;color:var(--bui_color_white);border-radius:2px}.sr-card__price-cheapest--red{color:#A30000}.sr-card__price--red .sr_price_wrap span,.sr-card__price--red .sr_simple_card_group_rec span,.sr-card__price--red .sr_combine_gsn-align span{vertical-align:middle}.sr-card__price--red .sr_price_wrap span span,.sr-card__price--red .sr_simple_card_group_rec span span,.sr-card__price--red .sr_combine_gsn-align span span{vertical-align:initial}.sr-card__price--red .sr_combine_gsn{vertical-align:middle;margin-bottom:initial}.sr-card__price--red .sr_combine_gsn,.sr-card__details .sr-card__price--red .sr_combine_gsn,.sr-card__price--red .sr_simple_card_group_rec.sr_make_the_price_stand_out-group.sr_combine_gsn,.sr-card__price--red .sr_combine_gsn.sr_make_the_price_stand_out-urgency,.sr-card__price--red .sr-card__price--urgency .sr-card__price-rack-rate,.sr-card__price--red .sr-card__price-rack-rate{color:#6B6B6B}.sr-card__price--red .sr-card__price-rack-rate:after,.sr-card__price--red .sr-card__price--urgency .sr-card__price-rack-rate:after{background:#6B6B6B}.sr-card__price--red .sr_simple_card_group_rec .sr-card__item--strong,.sr-card__price--red .sr_make_the_price_stand_out-urgency .sr-card__item--strong{color:#333333}.sr-rooms-selector{padding-right:10px;padding-left:6px}.rtlcss .sr-rooms-selector{padding-right:6px;padding-left:10px}.sr-rooms-selector__select{position:absolute;top:0;left:0;display:block;width:100%;height:100%;opacity:0}.sr-rooms-selector__icon{font-size:4px;position:absolute;top:50%;right:2px;margin-top:-1px;color:#7c90a6}.rtlcss .sr-rooms-selector__icon{right:auto;left:2px}.sr_last_minute_drop{color:#008009;@apply --bui_font_small_1;text-decoration:none;margin:-2px 0 3px 0}.sr_last_minute_drop__body{display:inline-block}.sr_last_minute_drop__icon{transform:rotate(180deg);fill:#008009;margin-right:3px;margin-top:-2px;position:relative;top:3px}.rtlcss .sr_last_minute_drop__icon{transform:rotate(180deg) scale(-1,1)}.sr-svg--header_icon_search{display:inline-block;left:8px;top:32%;position:absolute}.rtlcss .sr-svg--header_icon_search{left:auto;right:8px}.sr_svg__card_icon{margin-top:2px}.ltr .sr_svg__card_icon{float:left}.rtlcss .sr_svg__card_icon{float:right}.sr_svg__header_item{display:inline-block;top:18%;position:absolute}.ltr .sr_svg__header_item{left:8px}.rtlcss .sr_svg__header_item{right:8px}.sr_svg__top_reasons_checkmark{background:#FEBB02;border-radius:100px;color:var(--bui_color_white);height:21px;margin-top:-12px;position:absolute;text-align:center;top:50%;width:24px;padding-top:3px;line-height:24px}.ltr .sr_svg__top_reasons_checkmark{left:10px}.rtlcss .sr_svg__top_reasons_checkmark{right:10px}.sr_card_urgency_icon{position:relative;top:1px}.sr-card__item--just-booked .sr_svg__card_icon{fill:#A30000}.bk-icon.pp-icon-mobile-sr{position:relative;top:1px}.svg-lang-arrows{float:right;margin-top:-10px}.rtlcss .svg-lang-arrows{float:left}.sr-list{background-color:#F5F5F5;overflow:auto}.sr-card-list.bui-container{padding-top:0}.sr-card{display:block;position:relative;background-color:var(--bui_color_white);margin:0 8px 8px;border-bottom:1px solid #DDDDDD}.sr-notices .bui-banner~.bui-banner{margin-top:-1px}.sr-notices .bui-banner:last-child{margin-bottom:8px}.sr-notices .bui-banner__content{padding-right:32px}.sr-notices a{font-weight:normal;text-decoration:none}.sr-notices #sr_notice_sr_legal_commission_accommodation_ranking.is-bottom-stick{bottom:0;left:0;margin:0 !important;position:fixed;right:0;z-index:99}.sr-card:last-child{margin-bottom:0}.sr-card--highlight{box-shadow:0 0 10px #BAD4F7;background:#FAFCFF;border-color:#EBF3FF;margin-top:5px;margin-bottom:15px}.sr-card--highlight-genius{background:#FEFBF0;border-color:#DDDDDD}.sr-card__row{font-size:12px;display:block;color:#333333;line-height:normal;position:relative;cursor:pointer}.sr-card__row-inner{position:relative}.sr-card__row ...
# <link as="style" class="stylesheet-preload" data-async="" data-main-css="" href="https://cf.bstatic.com/mobile/css/core_cloudfront_sd.iq_ltr/3bb21c0e928d519db4d47c8cfd94e312a3ab3967.css" rel="preload"/>
# <noscript><link href="https://cf.bstatic.com/mobile/css/core_cloudfront_sd.iq_ltr/3bb21c0e928d519db4d47c8cfd94e312a3ab3967.css" rel="stylesheet"/></noscript>
# <link as="style" class="stylesheet-preload" data-async="" data-main-css="" href="https://cf.bstatic.com/mobile/css/app_cloudfront_sd.iq_ltr/e16be98e129831fa6c30dbd237d88e38571b5ec1.css" rel="preload"/>
# <noscript><link href="https://cf.bstatic.com/mobile/css/app_cloudfront_sd.iq_ltr/e16be98e129831fa6c30dbd237d88e38571b5ec1.css" rel="stylesheet"/></noscript>
# <link as="style" class="stylesheet-preload" data-async="" data-main-css="" href="https://cf.bstatic.com/mobile/css/searchresults_no_filters_cloudfront_sd.iq_ltr/d7a795e9664724c6be913d6ef3718c1ba995f91e.css" rel="preload"/>
# <noscript><link href="https://cf.bstatic.com/mobile/css/searchresults_no_filters_cloudfront_sd.iq_ltr/d7a795e9664724c6be913d6ef3718c1ba995f91e.css" rel="stylesheet"/></noscript>
# <link as="style" class="stylesheet-preload" data-async="" data-main-css="" href="https://cf.bstatic.com/mobile/css/iq_m_type_overrides_cloudfront_sd.iq_ltr/f02caf6b2406afbf6d7eb2fa20a77b92f18d062f.css" rel="preload"/>
# <noscript><link href="https://cf.bstatic.com/mobile/css/iq_m_type_overrides_cloudfront_sd.iq_ltr/f02caf6b2406afbf6d7eb2fa20a77b92f18d062f.css" rel="stylesheet"/></noscript>
# <script id="preload" nonce="WtWEDzpC6GZb9pD">
# (function(d){
# var cs = d.getElementById('preload');
# var load = function (href) {
# var l = d.createElement('link');
# l.rel = 'stylesheet';
# l.setAttribute('data-async', '');
# l.href = href;
# if (l.addEventListener) {
# l.media = 'none';
# l.addEventListener('load', function onLoad() {
# l.removeEventListener('load', onLoad);
# l.removeAttribute('media');
# });
# }
# cs.parentNode.insertBefore(l, cs);
# };
# var supportsPreload = false;
# try {
# supportsPreload = d.createElement('link').relList.supports('preload');
# } catch (e) {}
# if (!supportsPreload) {
# Array.prototype.forEach.call(d.getElementsByTagName('link'), function (l) {
# if (l.getAttribute('rel') === 'preload' && l.hasAttribute('data-main-css')) {
# l.removeAttribute('data-async');
# load(l.getAttribute('href'));
# }
# });
# }
# }(document));
# </script>
# <link as="script" crossorigin="" href="https://cf.bstatic.com/mobile/js/core-deps-inlinedet_cloudfront_sd/97754f5bf295ed27240e6fb859eb624545b055b1.js" nonce="WtWEDzpC6GZb9pD" rel="preload"/>
# <link as="script" crossorigin="" href="https://cf.bstatic.com/mobile/js/core_cloudfront_sd/d3f18df59f626fe9824a288059ff18e54ff0e45f.js" nonce="WtWEDzpC6GZb9pD" rel="preload"/>
# <link as="script" crossorigin="" href="https://cf.bstatic.com/mobile/js/app_cloudfront_sd/bb33649b75c2b045c42414344e1ad03c5ff509ca.js" nonce="WtWEDzpC6GZb9pD" rel="preload"/>
# <link as="script" crossorigin="" href="https://cf.bstatic.com/mobile/js/searchresults_cloudfront_sd/f363de7fb0dba77ff856788400d5adc9dce825ec.js" nonce="WtWEDzpC6GZb9pD" rel="preload"/>
# <link as="script" crossorigin="" href="https://cf.bstatic.com/static/js/error_catcher_bec_cloudfront_sd/0acd2ada6c74d5dec978a04ea837952bdf050cd2.js" nonce="WtWEDzpC6GZb9pD" rel="preload"/>
# <script nonce="WtWEDzpC6GZb9pD"> if( window.performance && performance.measure && 'b-stylesheets') { performance.measure('b-stylesheets'); } </script>
# <script nonce="WtWEDzpC6GZb9pD"> var lzimg = function(state){lzimg.state = state}; </script> <script nonce="WtWEDzpC6GZb9pD">function ImageLazyLoader(){this.highResQueue=[];this.shouldLoadHighRes=false;this.viewPortExtendedHeight=null;this.isWatchingForNewImages=false;this.supportsIntersectionObserver='IntersectionObserver'in window&&'IntersectionObserverEntry'in window&&'intersectionRatio'in IntersectionObserverEntry.prototype&&'isIntersecting'in IntersectionObserverEntry.prototype}ImageLazyLoader.prototype={SCREEN_HEIGHT_COEFFICIENT:1.4,SCREEN_SIDE_COEFFICIENT:1.33,LAZY_IMAGE_CLASS:'.js-lazy-image',init:function(){this.watcher=this.getWatcher();if(!this.supportsIntersectionObserver){var updateViewportHeight=function(){this.viewPortExtendedHeight=(window.innerHeight||document.documentElement.clientHeight)*this.SCREEN_HEIGHT_COEFFICIENT}.bind(this);window.addEventListener('resize',updateViewportHeight);window.addEventListener('orientationchange',updateViewportHeight);updateViewportHeight()}document.addEventListener('readystatechange',this.enableHighResImagesLoading.bind(this));if(window.lzimg&&window.lzimg.state){this.documentLoadingStateChanged(window.lzimg.state)}window.lzimg=this.documentLoadingStateChanged.bind(this)},enableHighResImagesLoading:function(){if('complete'!==document.readyState)return;document.removeEventListener('readystatechange',this.enableHighResImagesLoading.bind(this));this.shouldLoadHighRes=true;this.highResQueue.forEach(function(lazyImage){this.watcher.add(lazyImage)}.bind(this));this.highResQueue=[]},loadLazyImage:function(lazyImage){var paths=this.parseDataSrc(lazyImage);if(this.shouldLoadHighRes&&2===paths.length){this.loadImageAndInsert(paths[1],lazyImage)}else{this.loadImageAndInsert(paths[0],lazyImage)}if(!this.shouldLoadHighRes&&2===paths.length){this.highResQueue.push(lazyImage)}},observeMutations:function(){if('MutationObserver'in window){this.isWatchingForNewImages=true;var observer=new MutationObserver(function(mutations){mutations.forEach(function(mutation){Array.prototype.forEach.call(mutation.addedNodes,function(node){if(1!==node.nodeType)return;this.addToWatch(node)}.bind(this))}.bind(this))}.bind(this));observer.observe(document.body,{childList:true,subtree:true,characterData:false})}},documentLoadingStateChanged:function(state){if(!this.isWatchingForNewImages){this.observeMutations();this.addToWatch(document.body);if(!this.isWatchingForNewImages&&state==='ready'){this.addToWatch(document.body);this.listenMutationEvents();this.isWatchingForNewImages=true}}},addToWatch:function(el){if(this.isValidLazyImage(el)){this.watcher.add(el)}var imageList=el.querySelectorAll(this.LAZY_IMAGE_CLASS);for(var i=0;i<imageList.length;i++){var image=imageList[i];if(this.isValidLazyImage(image)){this.watcher.add(image)}}},isValidLazyImage:function(el){return el.getAttribute('data-src')&&!el.getAttribute('data-lazy')&&el.classList.contains('js-lazy-image')},parseDataSrc:function(el){var paths=el.getAttribute('data-src').split(',');for(var i=0;i<paths.length;i++){paths[i]=paths[i].trim()}return paths},loadImageAndInsert:function(src,el){var img=new Image();var encodedSRC=encodeURI(src);img.onload=function imageLoadedHandler(){if(el.tagName==="IMG"){el.src=encodedSRC}else{el.style.backgroundImage='url(\"'+encodedSRC+'\")'}};img.src=encodedSRC},listenMutationEvents:function(){if('MutationEvent'in window){document.body.addEventListener('DOMNodeInserted',function(event){var node=event.target;if(1!==node.nodeType)return;this.addToWatch(node)}.bind(this))}},getWatcher:function(){if(this.supportsIntersectionObserver){return this.intersectionObserverWatcher()}else{return this.vanillaJSWatcher()}},intersectionObserverWatcher:function(){var intersectionObserverHandler=function(entries){entries.forEach(function(entry){if(entry.isIntersecting){this.loadLazyImage(entry.target);intersectionObserver.unobserve(entry.target)}}.bind(this))}.bind(this);var intersectionObserverProps={rootMargin:'0% '+(100*this.SCREEN_SIDE_COEF ...
# return window.matchMedia && window.matchMedia(mediaQuery).matches;
# };
# // eslint-disable-next-line no-undef
# ImageLazyLoader.prototype.enableHighResImagesLoading = function () {
# if ('complete' !== document.readyState) return;
# document.removeEventListener('readystatechange',this.enableHighResImagesLoading);if(this.isHiDPI()){this.shouldLoadHighRes=true}this.highResQueue.forEach(function(lazyImage){this.watcher.add(lazyImage)}.bind(this));this.highResQueue=[]};new ImageLazyLoader().init();</script><link href="https://www.booking.com/city/fr/paris.fr.html" hreflang="en-gb" rel="alternate" title="English (UK)" type="text/html">
# <link href="https://www.booking.com/city/fr/paris.fr.html" hreflang="en-us" rel="alternate" title="English (US)" type="text/html">
# <link href="https://www.booking.com/city/fr/paris.fr.html" hreflang="de" rel="alternate" title="Deutsch" type="text/html">
# <link href="https://www.booking.com/city/fr/paris.fr.html" hreflang="nl" rel="alternate" title="Nederlands" type="text/html">
# <link href="https://www.booking.com/city/fr/paris.fr.html" hreflang="fr" rel="alternate" title="Français" type="text/html">
# <link href="https://www.booking.com/city/fr/paris.fr.html" hreflang="es" rel="alternate" title="Español" type="text/html">
# <link href="https://www.booking.com/city/fr/paris.fr.html" hreflang="es-ar" rel="alternate" title="Español (AR)" type="text/html">
# <link href="https://www.booking.com/city/fr/paris.fr.html" hreflang="es-mx" rel="alternate" title="Español (MX)" type="text/html">
# <link href="https://www.booking.com/city/fr/paris.fr.html" hreflang="ca" rel="alternate" title="Català" type="text/html">
# <link href="https://www.booking.com/city/fr/paris.fr.html" hreflang="it" rel="alternate" title="Italiano" type="text/html">
# <link href="https://www.booking.com/city/fr/paris.fr.html" hreflang="pt-pt" rel="alternate" title="Português (PT)" type="text/html">
# <link href="https://www.booking.com/city/fr/paris.fr.html" hreflang="pt-br" rel="alternate" title="Português (BR)" type="text/html">
# <link href="https://www.booking.com/city/fr/paris.fr.html" hreflang="no" rel="alternate" title="Norsk" type="text/html">
# <link href="https://www.booking.com/city/fr/paris.fr.html" hreflang="fi" rel="alternate" title="Suomi" type="text/html">
# <link href="https://www.booking.com/city/fr/paris.fr.html" hreflang="sv" rel="alternate" title="Svenska" type="text/html">
# <link href="https://www.booking.com/city/fr/paris.fr.html" hreflang="da" rel="alternate" title="Dansk" type="text/html">
# <link href="https://www.booking.com/city/fr/paris.fr.html" hreflang="cs" rel="alternate" title="Čeština" type="text/html"/>
# <link href="https://www.booking.com/city/fr/paris.fr.html" hreflang="hu" rel="alternate" title="Magyar" type="text/html"/>
# <link href="https://www.booking.com/city/fr/paris.fr.html" hreflang="ro" rel="alternate" title="Română" type="text/html"/>
# <link href="https://www.booking.com/city/fr/paris.fr.html" hreflang="ja" rel="alternate" title="日本語" type="text/html"/>
# <link href="https://www.booking.com/city/fr/paris.fr.html" hreflang="zh-cn" rel="alternate" title="简体中文" type="text/html"/>
# <link href="https://www.booking.com/city/fr/paris.fr.html" hreflang="zh-tw" rel="alternate" title="繁體中文" type="text/html"/>
# <link href="https://www.booking.com/city/fr/paris.fr.html" hreflang="pl" rel="alternate" title="Polski" type="text/html"/>
# <link href="https://www.booking.com/city/fr/paris.fr.html" hreflang="el" rel="alternate" title="Ελληνικά" type="text/html"/>
# <link href="https://www.booking.com/city/fr/paris.fr.html" hreflang="ru" rel="alternate" title="Русский" type="text/html"/>
# <link href="https://www.booking.com/city/fr/paris.fr.html" hreflang="tr" rel="alternate" title="Türkçe" type="text/html"/>
# <link href="https://www.booking.com/city/fr/paris.fr.html" hreflang="bg" rel="alternate" title="Български" type="text/html"/>
# <link href="https://www.booking.com/city/fr/paris.fr.html" hreflang="ar" rel="alternate" title="العربية" type="text/html"/>
# <link href="https://www.booking.com/city/fr/paris.fr.html" hreflang="ko" rel="alternate" title="한국어" type="text/html"/>
# <link href="https://www.booking.com/city/fr/paris.fr.html" hreflang="he" rel="alternate" title="עברית" type="text/html"/>
# <link href="https://www.booking.com/city/fr/paris.fr.html" hreflang="lv" rel="alternate" title="Latviski" type="text/html"/>
# <link href="https://www.booking.com/city/fr/paris.fr.html" hreflang="uk" rel="alternate" title="Українська" type="text/html"/>
# <link href="https://www.booking.com/city/fr/paris.fr.html" hreflang="hi" rel="alternate" title="हिन्दी" type="text/html"/>
# <link href="https://www.booking.com/city/fr/paris.fr.html" hreflang="id" rel="alternate" title="Bahasa Indonesia" type="text/html"/>
# <link href="https://www.booking.com/city/fr/paris.fr.html" hreflang="ms" rel="alternate" title="Bahasa Malaysia" type="text/html"/>
# <link href="https://www.booking.com/city/fr/paris.fr.html" hreflang="th" rel="alternate" title="ภาษาไทย" type="text/html"/>
# <link href="https://www.booking.com/city/fr/paris.fr.html" hreflang="et" rel="alternate" title="Eesti" type="text/html"/>
# <link href="https://www.booking.com/city/fr/paris.fr.html" hreflang="hr" rel="alternate" title="Hrvatski" type="text/html"/>
# <link href="https://www.booking.com/city/fr/paris.fr.html" hreflang="lt" rel="alternate" title="Lietuvių" type="text/html"/>
# <link href="https://www.booking.com/city/fr/paris.fr.html" hreflang="sk" rel="alternate" title="Slovenčina" type="text/html"/>
# <link href="https://www.booking.com/city/fr/paris.fr.html" hreflang="sr" rel="alternate" title="Srpski" type="text/html"/>
# <link href="https://www.booking.com/city/fr/paris.fr.html" hreflang="sl" rel="alternate" title="Slovenščina" type="text/html"/>
# <link href="https://www.booking.com/city/fr/paris.fr.html" hreflang="vi" rel="alternate" title="Tiếng Việt" type="text/html"/>
# <link href="https://www.booking.com/city/fr/paris.fr.html" hreflang="tl" rel="alternate" title="Filipino" type="text/html"/>
# <link href="https://www.booking.com/city/fr/paris.fr.html" hreflang="is" rel="alternate" title="Íslenska" type="text/html"/>
# <script nonce="WtWEDzpC6GZb9pD">
# (function(){
# document.addEventListener('DOMContentLoaded', function(e) {
# window._pxAppId = 'PXikKuL2RM';
# setTimeout(function() {
# var pxs = document.createElement('script');
# pxs.crossOrigin = 'anonymous';
# pxs.nonce = 'WtWEDzpC6GZb9pD';
# pxs.src = 'https://cf.bstatic.com/libs/perimeterx/px.v7.6.9.min.js';
# document.head.appendChild(pxs);
# }, 750);
# });
# }());
# </script>
# <script nonce="WtWEDzpC6GZb9pD" type="text/javascript">
# window.cspViolationsCount = 0;
# if ('SecurityPolicyViolationEvent' in window) {
# document.addEventListener("securitypolicyviolation", (e) => {
# if (navigator.userAgent.indexOf('Safari') != -1 && navigator.userAgent.indexOf('Chrome') == -1) {
# window.cspViolationsCount++;
# } else if (e.disposition === 'enforce') {
# window.cspViolationsCount++;
# }
# });
# }
# </script>
# <link data-chunk="client" href="https://cf.bstatic.com/psb/capla/static/css/bui-react.1a9a97ad.css" nonce="WtWEDzpC6GZb9pD" rel="stylesheet"/><link data-chunk="src-components-FiltersMobile-FiltersMobile" href="https://cf.bstatic.com/psb/capla/static/css/3557.6e49dbf9.chunk.css" nonce="WtWEDzpC6GZb9pD" rel="stylesheet"/><link data-chunk="src-components-LoadingOverlayMobile-LoadingOverlayMobile" href="https://cf.bstatic.com/psb/capla/static/css/5338.284f1561.chunk.css" nonce="WtWEDzpC6GZb9pD" rel="stylesheet"/><link data-chunk="src-components-TripTypePilotBeachMobileHeader-TripTypePilotBeachMobileHeader" href="https://cf.bstatic.com/psb/capla/static/css/6493.4af61583.chunk.css" nonce="WtWEDzpC6GZb9pD" rel="stylesheet"/><link data-chunk="src-components-TripTypeSki-UfiHeaderMobile-TripTypeSkiUfiHeaderMobile" href="https://cf.bstatic.com/psb/capla/static/css/2863.31a4ae57.chunk.css" nonce="WtWEDzpC6GZb9pD" rel="stylesheet"/><link data-chunk="src-components-TripTypeSki-LandmarkHeaderMobile-TripTypeSkiLandmarkHeaderMobile" href="https://cf.bstatic.com/psb/capla/static/css/358.17753b14.chunk.css" nonce="WtWEDzpC6GZb9pD" rel="stylesheet"/><link data-chunk="src-components-PropertiesListMobile-PropertiesListMobile" href="https://cf.bstatic.com/psb/capla/static/css/9958.c6f958bd.chunk.css" nonce="WtWEDzpC6GZb9pD" rel="stylesheet"/><link data-chunk="bookingcom-alpaca-patterns-SearchResultsBanners-BHQualityClassification-BHQualityClassificationCard-BHQualityClassificationCard" href="https://cf.bstatic.com/psb/capla/static/css/4114.07e7db64.chunk.css" nonce="WtWEDzpC6GZb9pD" rel="stylesheet"/><link data-chunk="common-genius-patterns-GeniusOnboardingSheet-GeniusOnboardingSheet" href="https://cf.bstatic.com/psb/capla/static/css/5738.c8c52fba.chunk.css" nonce="WtWEDzpC6GZb9pD" rel="stylesheet"/><link data-chunk="src-components-SearchBoxMobile-SearchBoxMobile" href="https://cf.bstatic.com/psb/capla/static/css/313.42a5bc69.chunk.css" nonce="WtWEDzpC6GZb9pD" rel="stylesheet"/><link data-chunk="src-components-SearchBoxMinifiedMobile-SearchBoxMinifiedMobile" href="https://cf.bstatic.com/psb/capla/static/css/9540.f5cab9ff.chunk.css" nonce="WtWEDzpC6GZb9pD" rel="stylesheet"/><link data-chunk="src-components-SortersFiltersMapTriggersMobile-SortersFiltersMapTriggersMobile" href="https://cf.bstatic.com/psb/capla/static/css/9473.2abf389c.chunk.css" nonce="WtWEDzpC6GZb9pD" rel="stylesheet"/><link data-chunk="bookingcom-web-shell-header-mfe-components-AccommodationHeader-SearchResultHeader" href="https://cf.bstatic.com/psb/capla/static/css/1238.50787710.chunk.css" nonce="WtWEDzpC6GZb9pD" rel="stylesheet"/><link data-chunk="bookingcom-web-shell-header-mfe-components-GlobalAlerts" href="https://cf.bstatic.com/psb/capla/static/css/3665.6913b2e2.chunk.css" nonce="WtWEDzpC6GZb9pD" rel="stylesheet"/>
# <title>
# Booking.com
# :
# Hôtels Paris
# .
# Réservez votre hôtel dès maintenant !
# </title>
# <meta content="Hôtel, Paris,  Hôtels, hébergement, logement, Offres spéciales, promotions, offres week-ends, Prix compétitifs, réductions, prix bon marché" name="keywords">
# <meta content="index,follow" name="robots">
# <link href="https://www.booking.com/city/fr/paris.fr.html" rel="canonical">
# <meta content="UmFuZG9tSVbswUMIJb9y447nac2upTDqzdVfeycMdpc27iffwGs_6KtOGJwBNtcuyVwZTWaOPPohKSWGwjhHavHalyY9LDk2_oaUoC4r8wB4-Z61UlVmDexKPW8DdigEs8VkpLy5WDwCoOSZehui09slGap6gyhE-N2Ukr7b5EwGqyHJ9QJRFkkR1IK-tYUfgnrkCnSK8mmIivpxvIH6b4vj3DEQXkoxWr7xnnR1GpmsUyFCVk9uvD1X9P3NeAjqMSQKtN2l1MYZf5Rp0RBB33QS_LPhdGc_ie0Gj7_kb7BnzDbw2leUjtpJDL08sn-GU6vPgD9TBcYsSZSo7nB0g_eLEEIjLFIxXseDhkxnw2V9Fy0ySNT_RpuQEb57E_7wM0AA53EAgEyNO7ZBQoNFkm78HLuPaQPISZ8JJx5TT1663Onp7fiwJJiotDVeZSFTAu4TtSy_VGo" name="booking-verification">
# <meta content="367003839" name="twitter:app:id:iphone"/>
# <meta content="Booking.com Hotel Reservations Worldwide &amp; Hotel Deals" name="twitter:app:name:ipad"/>
# <meta content="367003839" name="twitter:app:id:ipad"/>
# <meta content="Booking.com Hotel Reservations" name="twitter:app:name:googleplay"/>
# <meta content="com.booking" name="twitter:app:id:googleplay"/>
# <meta content="367003839" property="al:ios:app_store_id"/>
# <meta content="Booking.com Hotel Reservations" property="al:ios:app_name"/>
# <meta content="Booking.com Hotel Reservation" property="al:android:app_name"/>
# <meta content="com.booking" property="al:android:package"/>
# <meta content="" name="twitter:title">
# <meta content="booking://searchresults?dest_id=-1456928&amp;dest_type=city&amp;affiliate_id=375119&amp;source=gen173nr-1VCAQoggJCDHNlYXJjaF9wYXJpc0gNWARoTYgBApgBDbgBCcgBEdgBAegBAfgBA4gCAagCA7gCtuv3nQbAAgLSAiRlNDMzZWMzZC02YTM5LTQwNTYtOGI1MS1mMWNjNzc2MjVkMjnYAgbgAgE" property="al:ios:url">
# <meta content="booking://searchresults?dest_id=-1456928&amp;dest_type=city&amp;affiliate_id=375119&amp;source=gen173nr-1VCAQoggJCDHNlYXJjaF9wYXJpc0gNWARoTYgBApgBDbgBCcgBEdgBAegBAfgBA4gCAagCA7gCtuv3nQbAAgLSAiRlNDMzZWMzZC02YTM5LTQwNTYtOGI1MS1mMWNjNzc2MjVkMjnYAgbgAgE" property="al:android:url">
# <meta content="yes" name="apple-touch-fullscreen"/>
# <meta content="no" name="apple-mobile-web-app-capable">
# <meta content="telephone=no" name="format-detection"/>
# <link href="https://cf.bstatic.com/static/img/favicon/ebc77706da3aae4aee7b05dadf182390f0d26d11.ico" rel="shortcut icon">
# <link href="https://cf.bstatic.com/static/img/apple-touch-icon_new_lrg/c9b35bf29a75cac2f430f80a5d4bc7fd961d21a7.png" rel="apple-touch-icon">
# </link></link></meta></meta></meta></meta></meta></link></meta></meta></link></link></link></link></link></link></link></link></link></link></link></link></link></link></link></link></head>
# <body class="bookings2 searchresults colada fr b_lang_fr new_cta not_webview supportsfixed sevenup ltr mobile_progressive_device offline-message-alternative m_user_select_none bp-temp-old-base site_is_mdot m_neutral_bg" data-bui-theme="legacy-light" id="b2searchresultsPage">
# <div style="display:none;">Gog_sr_cc_less</div>
# <svg style="display: none"><symbol aria-hidden="true" focusable="false" id="icon-streamline-booking_logo_dark_bg_mono" role="presentation" viewbox="0 0 180 30">
# <path d="M70.6 2.73999C70.602 2.19808 70.7646 1.66892 71.0673 1.21943C71.3701 0.769947 71.7993 0.420321 72.3007 0.214768C72.8021 0.00921437 73.3532 -0.0430342 73.8843 0.064629C74.4155 0.172292 74.9027 0.435032 75.2845 0.819622C75.6663 1.20421 75.9255 1.69338 76.0293 2.22527C76.133 2.75716 76.0768 3.30788 75.8676 3.80779C75.6584 4.3077 75.3056 4.73434 74.8539 5.03377C74.4022 5.3332 73.8719 5.49197 73.33 5.48999C72.9702 5.48868 72.6141 5.41651 72.2822 5.2776C71.9503 5.13869 71.649 4.93576 71.3955 4.6804C71.1419 4.42504 70.9412 4.12225 70.8047 3.78931C70.6683 3.45637 70.5987 3.09982 70.6 2.73999V2.73999ZM116.5 23.77C117.044 23.772 117.577 23.6124 118.031 23.3114C118.484 23.0104 118.838 22.5816 119.048 22.0793C119.257 21.577 119.313 21.0238 119.208 20.4897C119.103 19.9555 118.842 19.4646 118.458 19.079C118.074 18.6934 117.584 18.4305 117.05 18.3236C116.516 18.2167 115.963 18.2705 115.46 18.4784C114.957 18.6862 114.527 19.0387 114.224 19.4911C113.922 19.9436 113.76 20.4757 113.76 21.02C113.76 21.7476 114.048 22.4456 114.562 22.961C115.075 23.4764 115.772 23.7673 116.5 23.77V23.77ZM25.7 6.72999C24.0129 6.74775 22.3688 7.26426 20.9746 8.21447C19.5805 9.16469 18.4986 10.5061 17.8653 12.0699C17.2319 13.6337 17.0754 15.3499 17.4154 17.0025C17.7554 18.6551 18.5767 20.1701 19.776 21.3569C20.9752 22.5436 22.4988 23.349 24.1548 23.6717C25.8108 23.9944 27.5253 23.8199 29.0824 23.1702C30.6395 22.5205 31.9695 21.4247 32.9051 20.0206C33.8406 18.6166 34.3399 16.9672 34.34 15.28C34.3768 14.1396 34.1778 13.0038 33.7555 11.9438C33.3331 10.8839 32.6965 9.92248 31.8855 9.11989C31.0744 8.3173 30.1064 7.69078 29.0421 7.27955C27.9778 6.86831 26.84 6.68122 25.7 6.72999V6.72999ZM25.7 19.83C23.35 19.83 21.7 17.96 21.7 15.28C21.7 12.6 23.34 10.73 25.7 10.73C28.06 10.73 29.7 12.6 29.7 15.28C29.7 17.96 28.11 19.83 25.7 19.83ZM65.3 15.71C65.1321 15.3716 64.9128 15.0613 64.65 14.79L64.5 14.63L64.66 14.48C64.9116 14.2078 65.1423 13.917 65.35 13.61L69.74 7.05999H64.41L61.1 12.19C60.9586 12.3442 60.782 12.4621 60.5852 12.5334C60.3885 12.6048 60.1774 12.6277 59.97 12.6H59.22V2.90999C59.22 0.979993 58.01 0.709993 56.71 0.709993H54.48V23.58H59.21V16.72H59.65C60.19 16.72 60.56 16.78 60.73 17.08L63.35 21.97C63.5773 22.5089 63.9785 22.9563 64.4895 23.2408C65.0006 23.5253 65.5922 23.6306 66.17 23.54H69.8L67.09 19.07L65.3 15.71ZM88.27 6.68999C87.3747 6.67014 86.4851 6.83782 85.6584 7.18226C84.8318 7.5267 84.0863 8.04028 83.47 8.68999L83.18 8.97999L83.08 8.57999C82.9261 8.08803 82.6021 7.66692 82.166 7.39207C81.7299 7.11723 81.2102 7.0066 80.7 7.07999H78.57V23.57H83.29V15.97C83.275 15.2919 83.373 14.6159 83.58 13.97C83.7979 13.1302 84.2923 12.3883 84.9836 11.8639C85.6748 11.3396 86.5225 11.0634 87.39 11.08C88.85 11.08 89.39 11.85 89.39 13.86V21.05C89.335 21.3921 89.3619 21.7424 89.4686 22.072C89.5753 22.4017 89.7586 22.7013 90.0036 22.9463C90.2487 23.1914 90.5483 23.3747 90.878 23.4814C91.2076 23.5881 91.5579 23.615 91.9 23.56H94.12V13.07C94.15 8.89999 92.12 6.68999 88.27 6.68999V6.68999ZM73.39 7.05999H71.17V23.58H75.87V9.57999C75.9234 9.24041 75.8964 8.89304 75.7913 8.56576C75.6862 8.23848 75.5058 7.94038 75.2647 7.69537C75.0236 7.45037 74.7284 7.26527 74.4028 7.15493C74.0773 7.04459 73.7304 7.01208 73.39 7.05999V7.05999ZM44.16 6.72999C42.4729 6.74775 40.8288 7.26426 39.4346 8.21447C38.0405 9.16469 36.9586 10.5061 36.3253 12.0699C35.6919 13.6337 35.5354 15.3499 35.8754 17.0025C36.2154 18.6551 37.0367 20.1701 38.236 21.3569C39.4352 22.5436 40.9588 23.349 42.6148 23.6717C44.2708 23.9944 45.9853 23.8199 47.5424 23.1702C49.0995 22.5205 50.4295 21.4247 51.3651 20.0206C52.3006 18.6166 52.7999 16.9672 52.8 15.28C52.8368 14.1396 52.6378 13.0038 52.2155 11.9438C51.7931 10.8839 51.1565 9.92248 50.3455 9.11989C49.5344 8.3173 48.5664 7.69078 47.5021 7.27955C46.4378 6.86831 45.3 6.68122 44.16 6.72999V6.72999ZM44.16 19.83C41.81 19.83 40.16 17.96 40.16 15.28C40.16 12.6 41.8 10.73 44.16 10.73C46.52 10.73 48.16 12.6 48.16 15.28C48.16 17.96 46.57 19.83 44.16 19.83ZM144.89 6.72999C143.203 6 ...
# </symbol><symbol aria-hidden="true" focusable="false" id="icon-streamline-arrow_nav_left" role="presentation" viewbox="0 0 24 24"><path d="M14.55 18a.74.74 0 0 1-.53-.22l-5-5A1.08 1.08 0 0 1 8.7 12a1.1 1.1 0 0 1 .3-.78l5-5a.75.75 0 0 1 1.06 0 .74.74 0 0 1 0 1.06L10.36 12l4.72 4.72a.74.74 0 0 1 0 1.06.73.73 0 0 1-.53.22zm-4.47-5.72zm0-.57z"></path></symbol><symbol aria-hidden="true" focusable="false" id="icon-streamline-account_user" role="presentation" viewbox="0 0 24 24"><path d="M16.5 9.75a4.5 4.5 0 1 1-9 0 4.5 4.5 0 0 1 9 0zm1.5 0a6 6 0 1 0-12 0 6 6 0 0 0 12 0zm1.445 10.597c-4.086-4.111-10.732-4.132-14.844-.046l-.046.046a.75.75 0 0 0 1.064 1.058l.04-.04a8.996 8.996 0 0 1 12.722.04.75.75 0 0 0 1.064-1.058zM22.5 12c0 5.799-4.701 10.5-10.5 10.5S1.5 17.799 1.5 12 6.201 1.5 12 1.5 22.5 6.201 22.5 12zm1.5 0c0-6.627-5.373-12-12-12S0 5.373 0 12s5.373 12 12 12 12-5.373 12-12z"></path></symbol><symbol aria-hidden="true" focusable="false" id="icon-streamline-lines_horizontal" role="presentation" viewbox="0 0 24 24"><path d="M2.25 18.753h19.5a.75.75 0 0 0 0-1.5H2.25a.75.75 0 0 0 0 1.5zm0-6h19.5a.75.75 0 0 0 0-1.5H2.25a.75.75 0 0 0 0 1.5zm0-6h19.5a.75.75 0 0 0 0-1.5H2.25a.75.75 0 0 0 0 1.5z"></path></symbol></svg>
# <script nonce="WtWEDzpC6GZb9pD">window.lzimg && lzimg('loading')</script>
# <div class="gta-header-banner" data-component="dismissible-item/block" data-item-id="gta_smart_banner">
# <button aria-label="Fermer" class="gta-header-banner__close js-close" type="button">
# <svg class="bk-icon -iconset-close" fill="#333333" height="20" role="presentation" width="20"><use xlink:href="#icon-iconset-close"></use></svg>
# </button>
# <div class="gta-header-banner__icon">
# <img alt="Booking" height="60" src="https://cf.bstatic.com/mobile/images/gta/iphone_app_icon/6a9bd9ce320f24431aa007112917bc9d029be5e0.png" width="60"/>
# </div>
# <div class="gta-header-banner__info">
# <div class="gta-header-banner__title">
# Booking.com
# </div>
# <div class="gta-header-banner__rating-stars">
# <img alt="" border="0" height="15" src="https://cf.bstatic.com/mobile/images/app-marketing/5_stars_2x/aadd2a6faac828024cfa33a8a13dd0b49332e317.png" width="81"/>
# 4,8
# </div>
# <div class="gta-header-banner__rating-nr">
# 785 k notes
# </div>
# </div>
# <div class="gta-header-banner__cta">
# <a class="gta-header-banner__btn" href="https://www.booking.com/apps.fr.html?label=gen173nr-1FCAQoggJCDHNlYXJjaF9wYXJpc0gNWARoTYgBApgBDbgBCcgBEdgBAegBAfgBA4gCAagCA7gCtuv3nQbAAgHSAiRlNDMzZWMzZC02YTM5LTQwNTYtOGI1MS1mMWNjNzc2MjVkMjnYAgXgAgE&amp;amp;sid=6f557435e60ac150cc81b850d8ada931&amp;amp;srpvid=c028a59b5b770291&amp;amp;&amp;amp;app_install=1&amp;amp;lang=fr&amp;amp;site=mdot&amp;amp;page=searchresults&amp;amp;placement=GeneralHeaderNew&amp;amp;device=direct&amp;amp;etseed=52616e646f6d49562473646523287d61b0b93a4c52dec184b39d3ba14f289762a67365c400c3bbd574f9feecb3bc6ea020a2c3c821c68e5f61c3d17d1c09dce0&amp;amp;hoff=sr&amp;amp;dest_countrycode=fr&amp;amp;dest_id=-1456928&amp;amp;dest_type=city&amp;amp;room1=A,A" target="_blank">
# Installer
# </a>
# </div>
# </div>
# <div data-component="security/csp_exp_tracker" data-exp-hash="dLcXJeITPMObVcKNMfXLMEO" style="display: none;"></div>
# <div id="main_container">
# <div class="js-main-content m_static_search_results consistent_section_headers" id="main_content">
# <header class="bui-header bui-header--logo-large js-site-header bui-u-hidden-print">
# <nav class="bui-header__bar">
# <div class="bui-header__main">
# <div class="bui-header__logo js-header-logo">
# <a aria-label="Booking.com réservations d'hébergements en ligne" data-et-click="
# customGoal:YTTHbXNLPVIRPQHUYJWcRQFdLHe:2
# customGoal:YTBUIHOdVLBQRMebfTINfTKe:2
# YTBUIHOdVLBLKAMZUC:1
# YTBUIHOdVLBLKAMZUC:3
# " href="https://www.booking.com/index.fr.html?label=gen173nr-1FCAQoggJCDHNlYXJjaF9wYXJpc0gNWARoTYgBApgBDbgBCcgBEdgBAegBAfgBA4gCAagCA7gCtuv3nQbAAgHSAiRlNDMzZWMzZC02YTM5LTQwNTYtOGI1MS1mMWNjNzc2MjVkMjnYAgXgAgE&amp;sid=6f557435e60ac150cc81b850d8ada931&amp;srpvid=c028a59b5b770291&amp;">
# <svg class="bk-icon -streamline-booking_logo_dark_bg_mono" height="20" width="120"><use xlink:href="#icon-streamline-booking_logo_dark_bg_mono"></use></svg>
# </a>
# </div>
# <a aria-label="Retour" class="bui-button bui-button--light bui-traveller-header__back-dynamic js-site-header--back">
# <span aria-hidden="true" class="bui-button__icon bui-icon bui-icon--larger">
# <svg class="bk-icon -streamline-arrow_nav_left" height="24" width="24"><use xlink:href="#icon-streamline-arrow_nav_left"></use></svg>
# </span>
# </a>
# </div>
# <div class="bui-group bui-group--inline bui-group--small bui-group--align-end bui-group--vertical-align-middle bui-button-group">
# <div class="bui-group__item">
# <a aria-label="Se connecter" class="bui-button bui-traveller-header__profile bui-button--light bui-button--large js-header-login-link js-header-signin-notification" data-et-click="
# customGoal:YTTHbXNLPVIRPQHUYJWcRQFdLHe:3
# customGoal:YTBUIHOdVLBQRMebfTINfTKe:3
# " data-track-event="header_profile_btn" href="https://account.booking.com/auth/oauth2?client_id=vO1Kblk7xX9tUn2cpZLS&amp;bkng_action=searchresults&amp;dt=1673393590&amp;response_type=code&amp;redirect_uri=https%3A%2F%2Fsecure.booking.com%2Flogin.html%3Fop%3Doauth_return&amp;state=UuIBwnt65h0Yw0MjTJ0RTmgowLB4052jwHlci85tCUnA1s2k_khVBv-OioN6WIjVj2LdS8-bTHqMpv1K4SNBHH4ZkF15JDRSIttKW-Y3MfbMjZxUM5MlZZjZhxFOgYP2qVUrRyxO81r1YyYMRrwu4_mqYaBwh2tTLDtXcf_LS7E9UB8hGjtTPuu_YKY_tIyMto4OJVvNT60UyZGb1qLN4RBPoRxtBKBEy9ZdSQTgO1H8Rq1il1n76DNeBpbmbntUon-1jBwbz85L0vLQFVNsTWELrW3y6z-JcDl4hjADMAJUdWa1Uw&amp;aid=304142&amp;lang=fr" type="button">
# <span class="bui-button__icon bui-bubble-container">
# <span aria-hidden="true" class="bui-icon bui-icon--large">
# <svg class="bk-icon -streamline-account_user" height="24" width="24"><use xlink:href="#icon-streamline-account_user"></use></svg>
# </span>
# <span class="bui-bubble bui-bubble-container__value bui-bubble--destructive bui-u-hidden js-bui-traveller-header__profile-icon"></span>
# </span>
# </a>
# </div>
# <div class="bui-group__item">
# <button aria-label="Plus de liens, paramètres et assistance" class="bui-button bui-button--light bui-button--large" data-bui-component="Modal.HeaderAsync" data-et-click="
# customGoal:YTTHbXNLPVIRPQHUYJWcRQFdLHe:1
# customGoal:YTBUIHOdBOcaGPaVHXT:5
# customGoal:YTBUIHOdVLBQRMebfTINfTKe:1
# ...
# <svg style="display: none"><symbol aria-hidden="true" focusable="false" id="icon-streamline-close" role="presentation" viewbox="0 0 24 24"><path d="M13.31 12l6.89-6.89a.93.93 0 1 0-1.31-1.31L12 10.69 5.11 3.8A.93.93 0 0 0 3.8 5.11L10.69 12 3.8 18.89a.93.93 0 0 0 1.31 1.31L12 13.31l6.89 6.89a.93.93 0 1 0 1.31-1.31z"></path></symbol><symbol aria-hidden="true" focusable="false" id="icon-iconset-update" role="presentation" viewbox="0 0 128 128"><path d="M116 60a4 4 0 0 0-4 4 48 48 0 1 1-48-48 46 46 0 0 1 26 8.4l-8.8 8.8a4 4 0 0 0 2.2 6.8l28 4h.9a4 4 0 0 0 .4 0h.4a4 4 0 0 0 .4-.2l.3-.2a4 4 0 0 0 .4-.2 4 4 0 0 0 .3-.2l.3-.2v-.2a4 4 0 0 0 .5-.5l.1-.2a4 4 0 0 0 .3-.5v-.3a4 4 0 0 0 .2-.6v-.3a4 4 0 0 0 0-.6v-.2l-4-28a4 4 0 0 0-6.8-2.3l-9.5 9.5A54.2 54.2 0 0 0 64 8a56 56 0 0 0-39.6 95.6A56 56 0 0 0 120 64a4 4 0 0 0-4-4z"></path></symbol><symbol aria-hidden="true" focusable="false" id="icon-sprite-ratings_stars_4_half" role="presentation" viewbox="0 0 65 12"><path d="m13 4.6c0-.1-.1-.2-.2-.2l-4.5-.3-1.5-4c-.1-.1-.5-.1-.5 0l-1.5 4-4.6.3c-.1 0-.2.1-.2.2s0 .2.1.3l3.5 2.5-1.2 4.3c0 .1 0 .2.1.3h.3l3.7-2.6 3.7 2.6h.3c.1-.1.1-.2.1-.3l-1.2-4.4 3.5-2.5c.1 0 .1-.1.1-.2zm13 0c0-.1-.1-.2-.2-.2l-4.5-.3-1.5-4c-.1-.2-.4-.2-.5 0l-1.5 4-4.5.3c-.1 0-.2.1-.2.2s0 .2.1.3l3.5 2.5-1.2 4.3c0 .1 0 .2.1.3s.2.1.3 0l3.7-2.6 3.7 2.6h.3c.1-.1.1-.2.1-.3l-1.2-4.3 3.5-2.5zm13 0c0-.1-.1-.2-.2-.2l-4.5-.3-1.5-4c-.1-.2-.4-.2-.5 0l-1.5 4-4.5.3c-.1 0-.2.1-.2.2s0 .2.1.3l3.5 2.5-1.2 4.3c0 .1 0 .2.1.3s.2.1.3 0l3.7-2.6 3.7 2.6h.3c.1-.1.1-.2.1-.3l-1.2-4.3 3.5-2.5zm13 0c0-.1-.1-.2-.2-.2l-4.5-.3-1.5-4c-.1-.2-.4-.2-.5 0l-1.5 4-4.5.3c-.1 0-.2.1-.2.2s0 .2.1.3l3.5 2.5-1.2 4.3c0 .1 0 .2.1.3s.2.1.3 0l3.7-2.6 3.7 2.6h.3c.1-.1.1-.2.1-.3l-1.2-4.3 3.5-2.5zm13 0c0-.1-.1-.2-.2-.2l-4.5-.3-1.5-4c-.1-.1-.2-.1-.3-.1s-.2 0-.2.1l-1.5 4-4.5.3c-.1 0-.2.1-.2.2s0 .2.1.3l3.5 2.5-1.2 4.3c0 .1 0 .2.1.3h.3l3.7-2.6 3.7 2.6h.3c.1-.1.1-.2.1-.3l-1.2-4.3 3.5-2.5zm-3.9 2.3-.3.2.1.3 1.1 3.7-3.1-2.2-.3-.2v-7.8l1.3 3.4.1.3h.3l3.7.2z" fill="#feba02"></path></symbol><symbol aria-hidden="true" focusable="false" id="icon-streamline-person_half" role="presentation" viewbox="0 0 24 24"><path d="M16.5 6a4.5 4.5 0 1 1-9 0 4.5 4.5 0 0 1 9 0zM18 6A6 6 0 1 0 6 6a6 6 0 0 0 12 0zM3 23.25a9 9 0 1 1 18 0 .75.75 0 0 0 1.5 0c0-5.799-4.701-10.5-10.5-10.5S1.5 17.451 1.5 23.25a.75.75 0 0 0 1.5 0z"></path></symbol><symbol aria-hidden="true" focusable="false" id="icon-iconset-arrow_left" role="presentation" viewbox="0 0 128 128"><path d="M108 60H31.3l29.2-29.2a4 4 0 0 0-5.7-5.6L16 64l38.8 38.8a4 4 0 1 0 5.7-5.6L31.3 68H108a4 4 0 0 0 0-8z"></path></symbol><symbol aria-hidden="true" focusable="false" id="icon-sprite-usp-tick2-small" role="presentation" viewbox="0 -1.5 43 36"><path d="m36.6 12.4c-3.5 0-6.4-2.8-6.4-6.2s2.9-6.2 6.4-6.2 6.4 2.8 6.4 6.2-2.9 6.2-6.4 6.2" fill="#34a833"></path><path d="m28.5 8.3-12.4 12-9.6-9.3-6.5 6.3 16.2 15.7 19.3-18.7c-3.4-.4-6.2-2.8-7-6" fill="#336e3f"></path></symbol><symbol aria-hidden="true" focusable="false" id="icon-iconset-close" role="presentation" viewbox="0 0 128 128"><path d="M69.7 64l33.1-33.2a4 4 0 0 0-5.6-5.6L64 58.3 30.8 25.2a4 4 0 1 0-5.6 5.6L58.3 64 25.2 97.2a4 4 0 1 0 5.6 5.6L64 69.7l33.2 33.1a4 4 0 0 0 5.6-5.6z"></path></symbol></svg>
# <link href="https://cf.bstatic.com/mobile/css/core_critical_cloudfront_sd.iq_ltr/9470bc8e42256b88b55fa309bed04c4c811e76b5.css" rel="prefetch"/>
# <link href="https://cf.bstatic.com/mobile/css/searchresults_critical_cloudfront_sd.iq_ltr/11214c6dc8da392bc845bbd9c303b70646c2a86d.css" rel="prefetch"/>
# <link href="https://cf.bstatic.com/mobile/css/hotel_cloudfront_sd.iq_ltr/75ef1bd9193a6bbd6a7c51a81739887cd181cf62.css" rel="prefetch"/>
# <link href="https://cf.bstatic.com/mobile/js/hotel_cloudfront_sd/97f17ca1b98d3c589759912079788ee1175dbfda.js" rel="prefetch"/>
# <link href="https://cf.bstatic.com/mobile/js/lazy_load_images_cloudfront_sd/c8236136c6e15180a2242e1835915e94db13acfd.js" rel="prefetch"/>
# <link href="https://cf.bstatic.com/static/js/et_cloudfront_sd/a5c838dc6079df69f699e35761fd372c0f92ce73.js" rel="prefetch"/>
# <script nonce="WtWEDzpC6GZb9pD">/*eslint no-console: "off"*/
# (function() {
# // Impact mesurement
# window.addEventListener('load', impactRecordLoadTime);
# function impactRecordLoadTime() {
# try {
# if (performance.timing.loadEventEnd == 0) return setTimeout(impactRecordLoadTime, 1000);
# var delta = performance.timing.loadEventEnd - performance.timing.connectStart;
# localStorage.reloadClock = parseInt(localStorage.reloadClock || 0, 10) + delta;
# localStorage.reloadCount = parseInt(localStorage.reloadCount || 0, 10) + 1;
# } catch (o_O) {}
# }
# function impactHasHotReloadActive() {
# try {
# localStorage.reloadHasUsedHotComponent = true;
# } catch (o_O) {}
# }
# var loader = B.require('component/loader');
# // ------------------------------------------------------------------------
# // Toast Config
# function toast(message) {
# var id = 'hot-reload-toast';
# var previousToast = document.getElementById(id);
# if (previousToast) previousToast.remove();
# var toast = document.createElement('div');
# toast.id = id;
# Object.assign(toast.style, {
# background: 'rgba(0,0,0,0.9)',
# boxShadow: '0 2px -2px rgba(0,0,0,0.4)',
# color: '#fff',
# font: 'normal 14px/1.5 sans-serif',
# padding: '8px 12px',
# borderRadius: '4px',
# position: 'fixed',
# bottom: '-30px',
# left: '50%',
# transform: 'translateX(-50%)',
# transition: 'all .2s ease-in-out',
# zIndex: 999999
# });
# toast.textContent = message;
# console.info(message);
# document.body.appendChild(toast);
# setTimeout(function() {
# toast.style.bottom = '40px';
# }, 10);
# setTimeout(function() {
# toast.style.bottom = '-50px';
# }, 2200);
# setTimeout(function() {
# toast.remove();
# }, 2500);
# }
# var Toast = {
# wsStarted: function() {
# toast('Hot reload started');
# },
# wsDisconnected: function() {
# toast('WebSocket server disconnected');
# },
# wsSuccess: function() {
# toast('Hot Reload starting');
# },
# wsFail: function() {
# toast('Failed starting hot reload');
# },
# reloadHTML: function(id) {
# toast('HTML code reloaded - id: ' + id);
# },
# reloadCSS: function() {
# toast('CSS code reloaded');
# },
# reloadJS: function(file, name) {
# toast('JS code reloaded - ' + file + ' - ' + name);
# }
# };
# // ------------------------------------------------------------------------
# // Reload actions
# var Reload = {
# HTML: function reloadHTML(newComponent, attributes) {
# var componentsToReload = [].slice.call(document.querySelectorAll('[data-hot-reload-id]'));
# componentsToReload.forEach(function(componentToReload) {
# if (componentToReload.dataset.hotReloadId === attributes['id']) {
# fetch('https://book.dqs.booking.com/dev/render_tmpl_fiddle', {
# method: 'POST',
# mode: 'cors',
# headers: {
# 'Content-Type': 'application/json; charset=utf-8'
# },
# body: JSON.stringify({
# tmpl: newComponent,
# tmpl_data: JSON.stringify(attributes)
# })
# })
# .then(function(response) {
# return response.json();
# })
# .then(function _reloadHTML(response) {
# componentToReload.innerHTML = response.result;
# Toast.reloadHTML(attributes['id']);
# });
# }
# });
# },
# CSS: function reloadCSS() {
# var links = [].slice.call(document.querySelectorAll('link[rel="stylesheet"][href*="bstatic.com"]'));
# var newLinksOnload = links.map(function(link) {
# return new Promise(function(resolve, reject) {
# var newLink = link.cloneNode();
# document.head.appendChild(newLink);
# newLink.onload = resolve;
# newLink.onerror = resolve;
# return newLink;
# });
# });
# Promise.all(newLinksOnload).then(function() {
# links.forEach(function(link) {
# if (link.parentNode) {
# link.parentNode.removeChild(link);
# }
# });
# });
# Toast.reloadCSS();
# },
# JS: function reloadJS(file, name) {
# var id = btoa(name);
# var url = hotURL(file);
# var elements = $('[data-component=' + name + ']');
# var script = document.getElementById(id);
# if (script) script.remove();
# // 1. destroy existing instances
# elements.each(function(i, node) {
# var self = $(node);
# var c = loader.getComponent(node);
# c && c._destroy && c._destroy();
# self.removeData('component-instance-' + name);
# // Remove event-map delegate listeners
# self.off('*');
# // Clone root node to get rid of all DOM modifications / event listeners
# self.replaceWith(this.cloneNode(true));
# });
# // damn you component-loader.loadAsync !
# setTimeout(function() {
# var componentName = 'component/' + name;
# // 2. remove component module definition
# delete B.require._defined[componentName];
# // 3. load new definition and initialize
# script = document.createElement('script');
# script.onload = function() {
# elements = $('[data-component=' + name + ']');
# if (elements.length) {
# elements.component(name);
# }
# // elements.component(name);
# };
# script.src = url;
# document.getElementsByTagName('head')[0].appendChild(script);
# Toast.reloadJS(file, componentName);
# }, 20);
# }
# };
# function hotReloadCSS(file) {
# var id = btoa(file);
# var url = hotURL(file);
# var link = document.getElementById(id);
# if (!link) {
# var link = createLinkStylesheet(url, id);
# } else {
# forceLinkReload(link);
# }
# }
# function reloadRequestHandler(message) {
# var data = parseJSON(message.data);
# console.info('hot-reload:', data);
# if (!data) return console.error('Could not parse message', message);
# switch (data.type) {
# case 'reload-html':
# return Reload.HTML(data.data.source, data.data.attributes);
# case 'reload-css':
# return Reload.CSS();
# case 'reload-css-inline':
# return hotReloadCSS(data.path);
# case 'reload-js-component':
# return Reload.JS(data.path, data.component);
# case 'full':
# window.location.reload();
# }
# }
# // ------------------------------------------------------------------------
# // WebSocket Config
# function Watcher(options) {
# this.host = (options && options.host) || 'wss://' + location.hostname;
# this.port = (options && options.port) || '3000';
# this.ws = null;
# this.wsURL = this.host + ':' + this.port;
# this.timer = null;
# this.pingInterval = 5000;
# }
# Watcher.prototype.connect = function() {
# if (!window.WebSocket) return Toast.wsStarted();
# if (this.connected) return Toast.wsSuccess();
# var ws = (this.ws = new WebSocket(this.wsURL));
# ws.onopen = this.openHandler.bind(this);
# ws.onclose = this.closeHandler.bind(this);
# ws.onmessage = this.messageHandler.bind(this);
# ws.onerror = this.errorHandler.bind(this);
# };
# Watcher.prototype.disconnect = function() {
# this.ws.close();
# this.connected = false;
# Toast.wsDisconnected();
# };
# Watcher.prototype.start = function() {
# this.connect();
# };
# Watcher.prototype.stop = function() {
# this.disconnect();
# Toast.wsDisconnected();
# };
# Watcher.prototype.openHandler = function() {
# this.connected = true;
# Toast.wsStarted();
# impactHasHotReloadActive();
# };
# Watcher.prototype.closeHandler = function() {
# if (this.connected) Toast.wsDisconnected();
# this.connected = false;
# };
# Watcher.prototype.errorHandler = function(err) {
# if (this.ws.readyState == WebSocket.CLOSING || this.ws.readyState == WebSocket.CLOSED) {
# Toast.wsFail();
# }
# };
# Watcher.prototype.messageHandler = reloadRequestHandler;
# // ------------------------------------------------------------------------
# // Helpers
# function parseJSON(data) {
# try {
# return JSON.parse(data);
# } catch (o_O) {}
# }
# function hotURL(file) {
# return '//' + location.host.replace('booking.com', 'bstatic.com') + '/dev/' + file + '?t=' + Date.now();
# }
# // ------------------------------------------------------------------------
# // CSS Link Helpers
# function forceLinkReload(linkElement) {
# linkElement.href = linkElement.href.replace(/\?.*|$/m, '?t=' + Date.now());
# }
# function createLinkStylesheet(url, id) {
# var link = document.createElement('link');
# if (id) link.id = id;
# link.rel = 'stylesheet';
# link.href = url;
# document.getElementsByTagName('head')[0].appendChild(link);
# }
# // ------------------------------------------------------------------------
# // Hot Reload Config
# window.hotreload = function() {
# var isLocal = /[?&]hotreload=localhost/.test(location.search);
# var kvmAddress = 'https://cf.bstatic.com'.replace('https://', 'wss://').replace('bstatic', 'booking');
# var options = isLocal ? { host: 'ws://localhost' } : { host: kvmAddress };
# new Watcher(options).start();
# };
# var keys = [];
# window.addEventListener(
# 'keydown',
# function(e) {
# if (e.key === 'r') {
# keys.push('r');
# if (keys.length === 3) {
# window.hotreload();
# keys.length = 0;
# }
# } else {
# keys.length = 0;
# }
# },
# false
# );
# if (/[?&]hotreload/.test(location.search)) {
# window.hotreload();
# }
# }());
# </script>
# <span id="req_info" style="display:none;">1655430|1,1655430|2,1624570,1625600,1655430</span>
# <div aria-hidden="" class="js-lavish-loader lavish-loader" style="display: none;">
# <div class="lavish-loader__popup">
# <div class="lavish-loader__popup-spinner-container">
# <div class="bui-spinner bui-spinner--size-large">
# <div class="bui-spinner__inner"></div>
# </div>
# </div>
# <div class="js-lavish-loader-text lavish-loader__popup-text">
# Chargement des établissements...
# </div>
# <div class="lavish-loader__popup-footer">
# Nous proposons des millions d'hébergements indépendants
# </div>
# </div>
# </div>
# <div data-block="b_env" style="display: none;"></div>
# </body>
# </html>

# %%
soup.select('a.f348c1e3be')
# Out:
# [<a class="f348c1e3be" data-testid="title" href="https://www.booking.com/hotel/fr/ucpa-sport-station-hostel-paris.fr.html?aid=304142&amp;label=gen173nr-1FCAQoggJCDHNlYXJjaF9wYXJpc0gNWARoTYgBApgBDbgBCcgBEdgBAegBAfgBA4gCAagCA7gCubHynQbAAgHSAiQxYzE0ZWFiYy1iZTk3LTRmYjUtOTU3Yi1iYmY4MTViNjRmYjnYAgXgAgE&amp;ucfs=1&amp;arphpl=1&amp;group_adults=2&amp;req_adults=2&amp;no_rooms=1&amp;group_children=0&amp;req_children=0&amp;hpos=1&amp;hapos=1&amp;sr_order=popularity&amp;srpvid=8c9d9fdcb1f2011f&amp;srepoch=1673304250&amp;from_sustainable_property_sr=1"><div class="b3d1cacd40"><h2 class="f9afbb0024 f0d4d6a2f5 fda3b74d0d">UCPA SPORT STATION HOSTEL PARIS</h2></div></a>,
#  <a class="f348c1e3be" data-testid="title" href="https://www.booking.com/hotel/fr/emeraude-louvre-montana.fr.html?aid=304142&amp;label=gen173nr-1FCAQoggJCDHNlYXJjaF9wYXJpc0gNWARoTYgBApgBDbgBCcgBEdgBAegBAfgBA4gCAagCA7gCubHynQbAAgHSAiQxYzE0ZWFiYy1iZTk3LTRmYjUtOTU3Yi1iYmY4MTViNjRmYjnYAgXgAgE&amp;ucfs=1&amp;arphpl=1&amp;group_adults=2&amp;req_adults=2&amp;no_rooms=1&amp;group_children=0&amp;req_children=0&amp;hpos=2&amp;hapos=2&amp;sr_order=popularity&amp;srpvid=8c9d9fdcb1f2011f&amp;srepoch=1673304250"><div class="b3d1cacd40"><h2 class="f9afbb0024 f0d4d6a2f5 fda3b74d0d">Hotel Louvre Montana</h2></div></a>,
#  <a class="f348c1e3be" data-testid="title" href="https://www.booking.com/hotel/fr/america.fr.html?aid=304142&amp;label=gen173nr-1FCAQoggJCDHNlYXJjaF9wYXJpc0gNWARoTYgBApgBDbgBCcgBEdgBAegBAfgBA4gCAagCA7gCubHynQbAAgHSAiQxYzE0ZWFiYy1iZTk3LTRmYjUtOTU3Yi1iYmY4MTViNjRmYjnYAgXgAgE&amp;ucfs=1&amp;arphpl=1&amp;group_adults=2&amp;req_adults=2&amp;no_rooms=1&amp;group_children=0&amp;req_children=0&amp;hpos=3&amp;hapos=3&amp;sr_order=popularity&amp;srpvid=8c9d9fdcb1f2011f&amp;srepoch=1673304250&amp;from_sustainable_property_sr=1"><div class="b3d1cacd40"><h2 class="f9afbb0024 f0d4d6a2f5 fda3b74d0d">Hotel Elysees Opera</h2></div></a>,
#  <a class="f348c1e3be" data-testid="title" href="https://www.booking.com/hotel/fr/d-amiens.fr.html?aid=304142&amp;label=gen173nr-1FCAQoggJCDHNlYXJjaF9wYXJpc0gNWARoTYgBApgBDbgBCcgBEdgBAegBAfgBA4gCAagCA7gCubHynQbAAgHSAiQxYzE0ZWFiYy1iZTk3LTRmYjUtOTU3Yi1iYmY4MTViNjRmYjnYAgXgAgE&amp;ucfs=1&amp;arphpl=1&amp;group_adults=2&amp;req_adults=2&amp;no_rooms=1&amp;group_children=0&amp;req_children=0&amp;hpos=4&amp;hapos=4&amp;sr_order=popularity&amp;srpvid=8c9d9fdcb1f2011f&amp;srepoch=1673304250&amp;from_sustainable_property_sr=1"><div class="b3d1cacd40"><h2 class="f9afbb0024 f0d4d6a2f5 fda3b74d0d">Hotel d'Amiens</h2></div></a>,
#  <a class="f348c1e3be" data-testid="title" href="https://www.booking.com/hotel/fr/grand-amelot-paris4.fr.html?aid=304142&amp;label=gen173nr-1FCAQoggJCDHNlYXJjaF9wYXJpc0gNWARoTYgBApgBDbgBCcgBEdgBAegBAfgBA4gCAagCA7gCubHynQbAAgHSAiQxYzE0ZWFiYy1iZTk3LTRmYjUtOTU3Yi1iYmY4MTViNjRmYjnYAgXgAgE&amp;ucfs=1&amp;arphpl=1&amp;group_adults=2&amp;req_adults=2&amp;no_rooms=1&amp;group_children=0&amp;req_children=0&amp;hpos=5&amp;hapos=5&amp;sr_order=popularity&amp;srpvid=8c9d9fdcb1f2011f&amp;srepoch=1673304250&amp;from_sustainable_property_sr=1"><div class="b3d1cacd40"><h2 class="f9afbb0024 f0d4d6a2f5 fda3b74d0d">Grand Hôtel Amelot</h2></div></a>,
#  <a class="f348c1e3be" data-testid="title" href="https://www.booking.com/hotel/fr/motel-one-paris-porte-doree.fr.html?aid=304142&amp;label=gen173nr-1FCAQoggJCDHNlYXJjaF9wYXJpc0gNWARoTYgBApgBDbgBCcgBEdgBAegBAfgBA4gCAagCA7gCubHynQbAAgHSAiQxYzE0ZWFiYy1iZTk3LTRmYjUtOTU3Yi1iYmY4MTViNjRmYjnYAgXgAgE&amp;ucfs=1&amp;arphpl=1&amp;group_adults=2&amp;req_adults=2&amp;no_rooms=1&amp;group_children=0&amp;req_children=0&amp;hpos=6&amp;hapos=6&amp;sr_order=popularity&amp;srpvid=8c9d9fdcb1f2011f&amp;srepoch=1673304250&amp;from_sustainable_property_sr=1"><div class="b3d1cacd40"><h2 class="f9afbb0024 f0d4d6a2f5 fda3b74d0d">Motel One Paris-Porte Dorée</h2></div></a>,
#  <a class="f348c1e3be" data-testid="title" href="https://www.booking.com/hotel/fr/ra-c-sidence-cisp-kellermann.fr.html?aid=304142&amp;label=gen173nr-1FCAQoggJCDHNlYXJjaF9wYXJpc0gNWARoTYgBApgBDbgBCcgBEdgBAegBAfgBA4gCAagCA7gCubHynQbAAgHSAiQxYzE0ZWFiYy1iZTk3LTRmYjUtOTU3Yi1iYmY4MTViNjRmYjnYAgXgAgE&amp;ucfs=1&amp;arphpl=1&amp;group_adults=2&amp;req_adults=2&amp;no_rooms=1&amp;group_children=0&amp;req_children=0&amp;hpos=7&amp;hapos=7&amp;sr_order=popularity&amp;srpvid=8c9d9fdcb1f2011f&amp;srepoch=1673304250"><div class="b3d1cacd40"><h2 class="f9afbb0024 f0d4d6a2f5 fda3b74d0d">Hotel CIS Paris Kellermann</h2></div></a>,
#  <a class="f348c1e3be" data-testid="title" href="https://www.booking.com/hotel/fr/austin-s-saint-lazare.fr.html?aid=304142&amp;label=gen173nr-1FCAQoggJCDHNlYXJjaF9wYXJpc0gNWARoTYgBApgBDbgBCcgBEdgBAegBAfgBA4gCAagCA7gCubHynQbAAgHSAiQxYzE0ZWFiYy1iZTk3LTRmYjUtOTU3Yi1iYmY4MTViNjRmYjnYAgXgAgE&amp;ucfs=1&amp;arphpl=1&amp;group_adults=2&amp;req_adults=2&amp;no_rooms=1&amp;group_children=0&amp;req_children=0&amp;hpos=8&amp;hapos=8&amp;sr_order=popularity&amp;srpvid=8c9d9fdcb1f2011f&amp;srepoch=1673304250&amp;from_sustainable_property_sr=1"><div class="b3d1cacd40"><h2 class="f9afbb0024 f0d4d6a2f5 fda3b74d0d">Austin's Saint Lazare Hotel</h2></div></a>,
#  <a class="f348c1e3be" data-testid="title" href="https://www.booking.com/hotel/fr/de-l-39-esperance.fr.html?aid=304142&amp;label=gen173nr-1FCAQoggJCDHNlYXJjaF9wYXJpc0gNWARoTYgBApgBDbgBCcgBEdgBAegBAfgBA4gCAagCA7gCubHynQbAAgHSAiQxYzE0ZWFiYy1iZTk3LTRmYjUtOTU3Yi1iYmY4MTViNjRmYjnYAgXgAgE&amp;ucfs=1&amp;arphpl=1&amp;group_adults=2&amp;req_adults=2&amp;no_rooms=1&amp;group_children=0&amp;req_children=0&amp;hpos=9&amp;hapos=9&amp;sr_order=popularity&amp;srpvid=8c9d9fdcb1f2011f&amp;srepoch=1673304250"><div class="b3d1cacd40"><h2 class="f9afbb0024 f0d4d6a2f5 fda3b74d0d">Hotel de L'Esperance</h2></div></a>,
#  <a class="f348c1e3be" data-testid="title" href="https://www.booking.com/hotel/fr/austin-s-arts-et-metiers.fr.html?aid=304142&amp;label=gen173nr-1FCAQoggJCDHNlYXJjaF9wYXJpc0gNWARoTYgBApgBDbgBCcgBEdgBAegBAfgBA4gCAagCA7gCubHynQbAAgHSAiQxYzE0ZWFiYy1iZTk3LTRmYjUtOTU3Yi1iYmY4MTViNjRmYjnYAgXgAgE&amp;ucfs=1&amp;arphpl=1&amp;group_adults=2&amp;req_adults=2&amp;no_rooms=1&amp;group_children=0&amp;req_children=0&amp;hpos=10&amp;hapos=10&amp;sr_order=popularity&amp;srpvid=8c9d9fdcb1f2011f&amp;srepoch=1673304250&amp;from_sustainable_property_sr=1"><div class="b3d1cacd40"><h2 class="f9afbb0024 f0d4d6a2f5 fda3b74d0d">Austin's Arts Et Metiers Hotel</h2></div></a>,
#  <a class="f348c1e3be" data-testid="title" href="https://www.booking.com/hotel/fr/hotelpavillonmonceau.fr.html?aid=304142&amp;label=gen173nr-1FCAQoggJCDHNlYXJjaF9wYXJpc0gNWARoTYgBApgBDbgBCcgBEdgBAegBAfgBA4gCAagCA7gCubHynQbAAgHSAiQxYzE0ZWFiYy1iZTk3LTRmYjUtOTU3Yi1iYmY4MTViNjRmYjnYAgXgAgE&amp;ucfs=1&amp;arphpl=1&amp;group_adults=2&amp;req_adults=2&amp;no_rooms=1&amp;group_children=0&amp;req_children=0&amp;hpos=11&amp;hapos=11&amp;sr_order=popularity&amp;srpvid=8c9d9fdcb1f2011f&amp;srepoch=1673304250"><div class="b3d1cacd40"><h2 class="f9afbb0024 f0d4d6a2f5 fda3b74d0d">Pavillon Monceau</h2></div></a>,
#  <a class="f348c1e3be" data-testid="title" href="https://www.booking.com/hotel/fr/secret-de-paris-design-boutique.fr.html?aid=304142&amp;label=gen173nr-1FCAQoggJCDHNlYXJjaF9wYXJpc0gNWARoTYgBApgBDbgBCcgBEdgBAegBAfgBA4gCAagCA7gCubHynQbAAgHSAiQxYzE0ZWFiYy1iZTk3LTRmYjUtOTU3Yi1iYmY4MTViNjRmYjnYAgXgAgE&amp;ucfs=1&amp;arphpl=1&amp;group_adults=2&amp;req_adults=2&amp;no_rooms=1&amp;group_children=0&amp;req_children=0&amp;hpos=12&amp;hapos=12&amp;sr_order=popularity&amp;srpvid=8c9d9fdcb1f2011f&amp;srepoch=1673304250"><div class="b3d1cacd40"><h2 class="f9afbb0024 f0d4d6a2f5 fda3b74d0d">Secret de Paris - Hotel &amp; Spa</h2></div></a>,
#  <a class="f348c1e3be" data-testid="title" href="https://www.booking.com/hotel/fr/holiday-inn-express-paris-canal-de-la-villette.fr.html?aid=304142&amp;label=gen173nr-1FCAQoggJCDHNlYXJjaF9wYXJpc0gNWARoTYgBApgBDbgBCcgBEdgBAegBAfgBA4gCAagCA7gCubHynQbAAgHSAiQxYzE0ZWFiYy1iZTk3LTRmYjUtOTU3Yi1iYmY4MTViNjRmYjnYAgXgAgE&amp;ucfs=1&amp;arphpl=1&amp;group_adults=2&amp;req_adults=2&amp;no_rooms=1&amp;group_children=0&amp;req_children=0&amp;hpos=13&amp;hapos=13&amp;sr_order=popularity&amp;srpvid=8c9d9fdcb1f2011f&amp;srepoch=1673304250&amp;from_sustainable_property_sr=1"><div class="b3d1cacd40"><h2 class="f9afbb0024 f0d4d6a2f5 fda3b74d0d">Holiday Inn Express Paris-Canal De La Villette, an IHG Hotel</h2></div></a>,
#  <a class="f348c1e3be" data-testid="title" href="https://www.booking.com/hotel/fr/le-villiers.fr.html?aid=304142&amp;label=gen173nr-1FCAQoggJCDHNlYXJjaF9wYXJpc0gNWARoTYgBApgBDbgBCcgBEdgBAegBAfgBA4gCAagCA7gCubHynQbAAgHSAiQxYzE0ZWFiYy1iZTk3LTRmYjUtOTU3Yi1iYmY4MTViNjRmYjnYAgXgAgE&amp;ucfs=1&amp;arphpl=1&amp;group_adults=2&amp;req_adults=2&amp;no_rooms=1&amp;group_children=0&amp;req_children=0&amp;hpos=14&amp;hapos=14&amp;sr_order=popularity&amp;srpvid=8c9d9fdcb1f2011f&amp;srepoch=1673304250&amp;from_sustainable_property_sr=1"><div class="b3d1cacd40"><h2 class="f9afbb0024 f0d4d6a2f5 fda3b74d0d">Hôtel Korner Etoile</h2></div></a>,
#  <a class="f348c1e3be" data-testid="title" href="https://www.booking.com/hotel/fr/meininger-paris-porte-de-vincennes.fr.html?aid=304142&amp;label=gen173nr-1FCAQoggJCDHNlYXJjaF9wYXJpc0gNWARoTYgBApgBDbgBCcgBEdgBAegBAfgBA4gCAagCA7gCubHynQbAAgHSAiQxYzE0ZWFiYy1iZTk3LTRmYjUtOTU3Yi1iYmY4MTViNjRmYjnYAgXgAgE&amp;ucfs=1&amp;arphpl=1&amp;group_adults=2&amp;req_adults=2&amp;no_rooms=1&amp;group_children=0&amp;req_children=0&amp;hpos=15&amp;hapos=15&amp;sr_order=popularity&amp;srpvid=8c9d9fdcb1f2011f&amp;srepoch=1673304250&amp;from_sustainable_property_sr=1"><div class="b3d1cacd40"><h2 class="f9afbb0024 f0d4d6a2f5 fda3b74d0d">MEININGER Hotel Paris Porte de Vincennes</h2></div></a>,
#  <a class="f348c1e3be" data-testid="title" href="https://www.booking.com/hotel/fr/beauchamps.fr.html?aid=304142&amp;label=gen173nr-1FCAQoggJCDHNlYXJjaF9wYXJpc0gNWARoTYgBApgBDbgBCcgBEdgBAegBAfgBA4gCAagCA7gCubHynQbAAgHSAiQxYzE0ZWFiYy1iZTk3LTRmYjUtOTU3Yi1iYmY4MTViNjRmYjnYAgXgAgE&amp;ucfs=1&amp;arphpl=1&amp;group_adults=2&amp;req_adults=2&amp;no_rooms=1&amp;group_children=0&amp;req_children=0&amp;hpos=16&amp;hapos=16&amp;sr_order=popularity&amp;srpvid=8c9d9fdcb1f2011f&amp;srepoch=1673304250&amp;from_sustainable_property_sr=1"><div class="b3d1cacd40"><h2 class="f9afbb0024 f0d4d6a2f5 fda3b74d0d">Hôtel Beauchamps</h2></div></a>,
#  <a class="f348c1e3be" data-testid="title" href="https://www.booking.com/hotel/fr/hotel-elysees-paris-france.fr.html?aid=304142&amp;label=gen173nr-1FCAQoggJCDHNlYXJjaF9wYXJpc0gNWARoTYgBApgBDbgBCcgBEdgBAegBAfgBA4gCAagCA7gCubHynQbAAgHSAiQxYzE0ZWFiYy1iZTk3LTRmYjUtOTU3Yi1iYmY4MTViNjRmYjnYAgXgAgE&amp;ucfs=1&amp;arphpl=1&amp;group_adults=2&amp;req_adults=2&amp;no_rooms=1&amp;group_children=0&amp;req_children=0&amp;hpos=17&amp;hapos=17&amp;sr_order=popularity&amp;srpvid=8c9d9fdcb1f2011f&amp;srepoch=1673304250"><div class="b3d1cacd40"><h2 class="f9afbb0024 f0d4d6a2f5 fda3b74d0d">Hôtel Elysées Paris</h2></div></a>,
#  <a class="f348c1e3be" data-testid="title" href="https://www.booking.com/hotel/fr/b55-paris12.fr.html?aid=304142&amp;label=gen173nr-1FCAQoggJCDHNlYXJjaF9wYXJpc0gNWARoTYgBApgBDbgBCcgBEdgBAegBAfgBA4gCAagCA7gCubHynQbAAgHSAiQxYzE0ZWFiYy1iZTk3LTRmYjUtOTU3Yi1iYmY4MTViNjRmYjnYAgXgAgE&amp;ucfs=1&amp;arphpl=1&amp;group_adults=2&amp;req_adults=2&amp;no_rooms=1&amp;group_children=0&amp;req_children=0&amp;hpos=18&amp;hapos=18&amp;sr_order=popularity&amp;srpvid=8c9d9fdcb1f2011f&amp;srepoch=1673304250"><div class="b3d1cacd40"><h2 class="f9afbb0024 f0d4d6a2f5 fda3b74d0d">Hôtel B55</h2></div></a>,
#  <a class="f348c1e3be" data-testid="title" href="https://www.booking.com/hotel/fr/scarlett.fr.html?aid=304142&amp;label=gen173nr-1FCAQoggJCDHNlYXJjaF9wYXJpc0gNWARoTYgBApgBDbgBCcgBEdgBAegBAfgBA4gCAagCA7gCubHynQbAAgHSAiQxYzE0ZWFiYy1iZTk3LTRmYjUtOTU3Yi1iYmY4MTViNjRmYjnYAgXgAgE&amp;ucfs=1&amp;arphpl=1&amp;group_adults=2&amp;req_adults=2&amp;no_rooms=1&amp;group_children=0&amp;req_children=0&amp;hpos=19&amp;hapos=19&amp;sr_order=popularity&amp;srpvid=8c9d9fdcb1f2011f&amp;srepoch=1673304250"><div class="b3d1cacd40"><h2 class="f9afbb0024 f0d4d6a2f5 fda3b74d0d">Hotel Scarlett</h2></div></a>,
#  <a class="f348c1e3be" data-testid="title" href="https://www.booking.com/hotel/fr/virgina.fr.html?aid=304142&amp;label=gen173nr-1FCAQoggJCDHNlYXJjaF9wYXJpc0gNWARoTYgBApgBDbgBCcgBEdgBAegBAfgBA4gCAagCA7gCubHynQbAAgHSAiQxYzE0ZWFiYy1iZTk3LTRmYjUtOTU3Yi1iYmY4MTViNjRmYjnYAgXgAgE&amp;ucfs=1&amp;arphpl=1&amp;group_adults=2&amp;req_adults=2&amp;no_rooms=1&amp;group_children=0&amp;req_children=0&amp;hpos=20&amp;hapos=20&amp;sr_order=popularity&amp;srpvid=8c9d9fdcb1f2011f&amp;srepoch=1673304250"><div class="b3d1cacd40"><h2 class="f9afbb0024 f0d4d6a2f5 fda3b74d0d">Virgina</h2></div></a>]

# %%
soup.select('span', class_ = "d8eab2cf7f f0d4d6a2f5 e46e88563a")
# Out:
# [<span aria-hidden="true" class="bui-button__icon bui-icon bui-icon--larger">
#  <svg class="bk-icon -streamline-arrow_nav_left" height="24" width="24"><use xlink:href="#icon-streamline-arrow_nav_left"></use></svg>
#  </span>,
#  <span class="bui-button__icon bui-bubble-container">
#  <span aria-hidden="true" class="bui-icon bui-icon--large">
#  <svg class="bk-icon -streamline-account_user" height="24" width="24"><use xlink:href="#icon-streamline-account_user"></use></svg>
#  </span>
#  <span class="bui-bubble bui-bubble-container__value bui-bubble--destructive bui-u-hidden js-bui-traveller-header__profile-icon"></span>
#  </span>,
#  <span aria-hidden="true" class="bui-icon bui-icon--large">
#  <svg class="bk-icon -streamline-account_user" height="24" width="24"><use xlink:href="#icon-streamline-account_user"></use></svg>
#  </span>,
#  <span class="bui-bubble bui-bubble-container__value bui-bubble--destructive bui-u-hidden js-bui-traveller-header__profile-icon"></span>,
#  <span class="bui-button__icon">
#  <span aria-hidden="true" class="bui-icon bui-icon--large">
#  <svg class="bk-icon -streamline-lines_horizontal" height="24" width="24"><use xlink:href="#icon-streamline-lines_horizontal"></use></svg>
#  </span>
#  </span>,
#  <span aria-hidden="true" class="bui-icon bui-icon--large">
#  <svg class="bk-icon -streamline-lines_horizontal" height="24" width="24"><use xlink:href="#icon-streamline-lines_horizontal"></use></svg>
#  </span>,
#  <span aria-hidden="true" class="b6dc9a9e69 ec1b6253a6 f86806591e"><svg height="1em" viewbox="0 0 128 128" width="1em"><path d="M118.8 113.2l-31-31A4 4 0 0 0 85 81a44 44 0 1 0-4 4 4 4 0 0 0 1.2 2.8l31 31a4 4 0 0 0 5.6-5.7zM52 88a36 36 0 1 1 36-36 36 36 0 0 1-36 36z"></path></svg></span>,
#  <span aria-hidden="true" class="b6dc9a9e69 e25355d3ee" data-testid="input-clear"><svg height="1em" viewbox="0 0 128 128" width="1em"><path d="M69.7 64l33.1-33.2a4 4 0 0 0-5.6-5.6L64 58.3 30.8 25.2a4 4 0 1 0-5.6 5.6L58.3 64 25.2 97.2a4 4 0 1 0 5.6 5.6L64 69.7l33.2 33.1a4 4 0 0 0 5.6-5.6z"></path></svg></span>,
#  <span><span class="ee746850b6">Adultes</span></span>,
#  <span class="ee746850b6">Adultes</span>,
#  <span class="df5494c6c7"><span aria-hidden="true" class="b6dc9a9e69 c42ce17094 e6c50852bd f86806591e"><svg viewbox="0 0 24 24" xmlns="http://www.w3.org/2000/svg"><path d="M18 9.45c0 .2-.078.39-.22.53l-5 5a1.08 1.08 0 0 1-.78.32 1.1 1.1 0 0 1-.78-.32l-5-5a.75.75 0 0 1 0-1.06.74.74 0 0 1 1.06 0L12 13.64l4.72-4.72a.74.74 0 0 1 1.06 0 .73.73 0 0 1 .22.53zm-5.72 4.47zm-.57 0z"></path></svg></span></span>,
#  <span aria-hidden="true" class="b6dc9a9e69 c42ce17094 e6c50852bd f86806591e"><svg viewbox="0 0 24 24" xmlns="http://www.w3.org/2000/svg"><path d="M18 9.45c0 .2-.078.39-.22.53l-5 5a1.08 1.08 0 0 1-.78.32 1.1 1.1 0 0 1-.78-.32l-5-5a.75.75 0 0 1 0-1.06.74.74 0 0 1 1.06 0L12 13.64l4.72-4.72a.74.74 0 0 1 1.06 0 .73.73 0 0 1 .22.53zm-5.72 4.47zm-.57 0z"></path></svg></span>,
#  <span><span class="ee746850b6">Enfants</span></span>,
#  <span class="ee746850b6">Enfants</span>,
#  <span class="df5494c6c7"><span aria-hidden="true" class="b6dc9a9e69 c42ce17094 e6c50852bd f86806591e"><svg viewbox="0 0 24 24" xmlns="http://www.w3.org/2000/svg"><path d="M18 9.45c0 .2-.078.39-.22.53l-5 5a1.08 1.08 0 0 1-.78.32 1.1 1.1 0 0 1-.78-.32l-5-5a.75.75 0 0 1 0-1.06.74.74 0 0 1 1.06 0L12 13.64l4.72-4.72a.74.74 0 0 1 1.06 0 .73.73 0 0 1 .22.53zm-5.72 4.47zm-.57 0z"></path></svg></span></span>,
#  <span aria-hidden="true" class="b6dc9a9e69 c42ce17094 e6c50852bd f86806591e"><svg viewbox="0 0 24 24" xmlns="http://www.w3.org/2000/svg"><path d="M18 9.45c0 .2-.078.39-.22.53l-5 5a1.08 1.08 0 0 1-.78.32 1.1 1.1 0 0 1-.78-.32l-5-5a.75.75 0 0 1 0-1.06.74.74 0 0 1 1.06 0L12 13.64l4.72-4.72a.74.74 0 0 1 1.06 0 .73.73 0 0 1 .22.53zm-5.72 4.47zm-.57 0z"></path></svg></span>,
#  <span><span class="ee746850b6">Chambres</span></span>,
#  <span class="ee746850b6">Chambres</span>,
#  <span class="df5494c6c7"><span aria-hidden="true" class="b6dc9a9e69 c42ce17094 e6c50852bd f86806591e"><svg viewbox="0 0 24 24" xmlns="http://www.w3.org/2000/svg"><path d="M18 9.45c0 .2-.078.39-.22.53l-5 5a1.08 1.08 0 0 1-.78.32 1.1 1.1 0 0 1-.78-.32l-5-5a.75.75 0 0 1 0-1.06.74.74 0 0 1 1.06 0L12 13.64l4.72-4.72a.74.74 0 0 1 1.06 0 .73.73 0 0 1 .22.53zm-5.72 4.47zm-.57 0z"></path></svg></span></span>,
#  <span aria-hidden="true" class="b6dc9a9e69 c42ce17094 e6c50852bd f86806591e"><svg viewbox="0 0 24 24" xmlns="http://www.w3.org/2000/svg"><path d="M18 9.45c0 .2-.078.39-.22.53l-5 5a1.08 1.08 0 0 1-.78.32 1.1 1.1 0 0 1-.78-.32l-5-5a.75.75 0 0 1 0-1.06.74.74 0 0 1 1.06 0L12 13.64l4.72-4.72a.74.74 0 0 1 1.06 0 .73.73 0 0 1 .22.53zm-5.72 4.47zm-.57 0z"></path></svg></span>,
#  <span aria-hidden="true" class="b6dc9a9e69 aa4de547ee e25355d3ee f86806591e"><svg height="1em" viewbox="0 0 128 128" width="1em"><path d="M64 8a56 56 0 1 0 56 56A56 56 0 0 0 64 8zm0 100a8 8 0 1 1 8-8 8 8 0 0 1-8 8zm18.4-39.6A32.6 32.6 0 0 1 74 74l-2 1.1V82a2 2 0 0 1-2 2H58a2 2 0 0 1-2-2v-8.8c0-7.8 6.7-11.3 10.7-13.4a20.5 20.5 0 0 0 4.4-2.7 10 10 0 1 0-15-13.2 10.3 10.3 0 0 0-2.1 6.4V54a2 2 0 0 1-2 2H40a2 2 0 0 1-2-2v-3.5a26.7 26.7 0 0 1 6.9-18.1 26 26 0 0 1 22.6-8.2 25.5 25.5 0 0 1 12.2 5 26 26 0 0 1 2.7 39.2z"></path></svg></span>,
#  <span class="ba0052c122"></span>,
#  <span class="e50b5c7936"></span>,
#  <span class="fcb404aeaf"><div class="db29ecfbe2 f0d4d6a2f5"><div class="ac78a73c96">Oui</div></div></span>,
#  <span class="ba0052c122"></span>,
#  <span class="e50b5c7936"></span>,
#  <span class="fcb404aeaf"><div class="db29ecfbe2 f0d4d6a2f5"><div class="ac78a73c96">Non</div></div></span>,
#  <span class="e57ffa4eb5">Rechercher</span>,
#  <span class="fed83f0f9b"><span class="db29ecfbe2">Le montant de la commission payée et d'autres facteurs peuvent affecter le classement d'un hébergement.<!-- --> </span><a class="fc63351294 a168c6f285 cd6351bb3b a25b1d9e47" href="https://www.booking.com/content/how_we_work.html?aid=304142&amp;label=gen173nr-1FCAQoggJCDHNlYXJjaF9wYXJpc0gNWARoTYgBApgBDbgBCcgBEdgBAegBAfgBA4gCAagCA7gCubHynQbAAgHSAiQxYzE0ZWFiYy1iZTk3LTRmYjUtOTU3Yi1iYmY4MTViNjRmYjnYAgXgAgE#nov2021_how_we_work_accommodations_ranking_subheading" target="_blank"><span>En savoir plus.</span></a></span>,
#  <span class="db29ecfbe2">Le montant de la commission payée et d'autres facteurs peuvent affecter le classement d'un hébergement.<!-- --> </span>,
#  <span>En savoir plus.</span>,
#  <span class="b9def0936d"><span aria-hidden="true" class="b6dc9a9e69 e25355d3ee"><svg viewbox="0 0 24 24" xmlns="http://www.w3.org/2000/svg"><path d="M13.31 12l6.89-6.89a.93.93 0 1 0-1.31-1.31L12 10.69 5.11 3.8A.93.93 0 0 0 3.8 5.11L10.69 12 3.8 18.89a.93.93 0 0 0 1.31 1.31L12 13.31l6.89 6.89a.93.93 0 1 0 1.31-1.31z"></path></svg></span></span>,
#  <span aria-hidden="true" class="b6dc9a9e69 e25355d3ee"><svg viewbox="0 0 24 24" xmlns="http://www.w3.org/2000/svg"><path d="M13.31 12l6.89-6.89a.93.93 0 1 0-1.31-1.31L12 10.69 5.11 3.8A.93.93 0 0 0 3.8 5.11L10.69 12 3.8 18.89a.93.93 0 0 0 1.31 1.31L12 13.31l6.89 6.89a.93.93 0 1 0 1.31-1.31z"></path></svg></span>,
#  <span aria-hidden="true" class="b6dc9a9e69 a637eeb339 d05b9c02a2 b8c9de5937"><svg data-rtl-flip="true" viewbox="0 0 24 24" xmlns="http://www.w3.org/2000/svg"><path d="M9.45 6c.2 0 .39.078.53.22l5 5c.208.206.323.487.32.78a1.1 1.1 0 0 1-.32.78l-5 5a.75.75 0 0 1-1.06 0 .74.74 0 0 1 0-1.06L13.64 12 8.92 7.28a.74.74 0 0 1 0-1.06.73.73 0 0 1 .53-.22zm4.47 5.72zm0 .57z"></path></svg></span>,
#  <span aria-label="Très bien" class="d8eab2cf7f f0d4d6a2f5 e46e88563a"> <!-- -->Très bien</span>,
#  <span class="d8eab2cf7f c90c0a70d3 db63693c62"> · <!-- -->2 083 expériences vécues</span>,
#  <span aria-hidden="true" class="b6dc9a9e69 e492382468 a98180785f e25355d3ee" data-testid="icon-with-text-icon"><svg viewbox="0 0 24 24" xmlns="http://www.w3.org/2000/svg"><path d="M15 8.25a3 3 0 1 1-6 0 3 3 0 0 1 6 0zm1.5 0a4.5 4.5 0 1 0-9 0 4.5 4.5 0 0 0 9 0zM12 1.5a6.75 6.75 0 0 1 6.75 6.75c0 2.537-3.537 9.406-6.75 14.25-3.214-4.844-6.75-11.713-6.75-14.25A6.75 6.75 0 0 1 12 1.5zM12 0a8.25 8.25 0 0 0-8.25 8.25c0 2.965 3.594 9.945 7 15.08a1.5 1.5 0 0 0 2.5 0c3.406-5.135 7-12.115 7-15.08A8.25 8.25 0 0 0 12 0z"></path></svg></span>,
#  <span class="a51f4b5adb">19e arr., Paris • 4,8 km du centre</span>,
#  <span aria-hidden="true" class="b6dc9a9e69 e492382468 a98180785f e25355d3ee" data-testid="icon-with-text-icon"><svg viewbox="0 0 24 24" xmlns="http://www.w3.org/2000/svg"><path d="M21.22 3.37a.75.75 0 0 0-.6-.59c-4.85-.9-10.6.55-13.37 3.36S3.1 14.39 3.88 19.05L2 21a.75.75 0 0 0 0 1 .74.74 0 0 0 .53.22A.71.71 0 0 0 3 22l2-1.9a16.94 16.94 0 0 0 2.76.23c4.09 0 8.19-1.33 10.35-3.52 2.71-2.81 4.07-8.59 3.11-13.44zM17 15.75c-2.11 2.14-6.59 3.36-10.7 3L16.59 8.47a.75.75 0 0 0 0 -1.06.77.77 0 0 0-1.07 0l-10.3 10.3c-.33-3.91.91-8.31 3.1-10.52s7.29-3.63 11.52-3c.67 4.22-.54 9.22-2.84 11.56z"></path></svg></span>,
#  <span class="a51f4b5adb">Établissement Voyage Durable</span>,
#  <span aria-hidden="true" class="b6dc9a9e69 a637eeb339 d05b9c02a2 b8c9de5937"><svg data-rtl-flip="true" viewbox="0 0 24 24" xmlns="http://www.w3.org/2000/svg"><path d="M9.45 6c.2 0 .39.078.53.22l5 5c.208.206.323.487.32.78a1.1 1.1 0 0 1-.32.78l-5 5a.75.75 0 0 1-1.06 0 .74.74 0 0 1 0-1.06L13.64 12 8.92 7.28a.74.74 0 0 1 0-1.06.73.73 0 0 1 .53-.22zm4.47 5.72zm0 .57z"></path></svg></span>,
#  <span aria-hidden="true" class="b6dc9a9e69 adc357e4f1 fe621d6382"><svg viewbox="0 0 24 24" xmlns="http://www.w3.org/2000/svg"><path d="M23.555 8.729a1.505 1.505 0 0 0-1.406-.98h-6.087a.5.5 0 0 1-.472-.334l-2.185-6.193a1.5 1.5 0 0 0-2.81 0l-.005.016-2.18 6.177a.5.5 0 0 1-.471.334H1.85A1.5 1.5 0 0 0 .887 10.4l5.184 4.3a.5.5 0 0 1 .155.543l-2.178 6.531a1.5 1.5 0 0 0 2.31 1.684l5.346-3.92a.5.5 0 0 1 .591 0l5.344 3.919a1.5 1.5 0 0 0 2.312-1.683l-2.178-6.535a.5.5 0 0 1 .155-.543l5.194-4.306a1.5 1.5 0 0 0 .433-1.661z"></path></svg></span>,
#  <span aria-hidden="true" class="b6dc9a9e69 adc357e4f1 fe621d6382"><svg viewbox="0 0 24 24" xmlns="http://www.w3.org/2000/svg"><path d="M23.555 8.729a1.505 1.505 0 0 0-1.406-.98h-6.087a.5.5 0 0 1-.472-.334l-2.185-6.193a1.5 1.5 0 0 0-2.81 0l-.005.016-2.18 6.177a.5.5 0 0 1-.471.334H1.85A1.5 1.5 0 0 0 .887 10.4l5.184 4.3a.5.5 0 0 1 .155.543l-2.178 6.531a1.5 1.5 0 0 0 2.31 1.684l5.346-3.92a.5.5 0 0 1 .591 0l5.344 3.919a1.5 1.5 0 0 0 2.312-1.683l-2.178-6.535a.5.5 0 0 1 .155-.543l5.194-4.306a1.5 1.5 0 0 0 .433-1.661z"></path></svg></span>,
#  <span aria-hidden="true" class="b6dc9a9e69 adc357e4f1 fe621d6382"><svg viewbox="0 0 24 24" xmlns="http://www.w3.org/2000/svg"><path d="M23.555 8.729a1.505 1.505 0 0 0-1.406-.98h-6.087a.5.5 0 0 1-.472-.334l-2.185-6.193a1.5 1.5 0 0 0-2.81 0l-.005.016-2.18 6.177a.5.5 0 0 1-.471.334H1.85A1.5 1.5 0 0 0 .887 10.4l5.184 4.3a.5.5 0 0 1 .155.543l-2.178 6.531a1.5 1.5 0 0 0 2.31 1.684l5.346-3.92a.5.5 0 0 1 .591 0l5.344 3.919a1.5 1.5 0 0 0 2.312-1.683l-2.178-6.535a.5.5 0 0 1 .155-.543l5.194-4.306a1.5 1.5 0 0 0 .433-1.661z"></path></svg></span>,
#  <span aria-hidden="true" class="b6dc9a9e69 adc357e4f1 fe621d6382"><svg viewbox="0 0 24 24" xmlns="http://www.w3.org/2000/svg"><path d="M23.555 8.729a1.505 1.505 0 0 0-1.406-.98h-6.087a.5.5 0 0 1-.472-.334l-2.185-6.193a1.5 1.5 0 0 0-2.81 0l-.005.016-2.18 6.177a.5.5 0 0 1-.471.334H1.85A1.5 1.5 0 0 0 .887 10.4l5.184 4.3a.5.5 0 0 1 .155.543l-2.178 6.531a1.5 1.5 0 0 0 2.31 1.684l5.346-3.92a.5.5 0 0 1 .591 0l5.344 3.919a1.5 1.5 0 0 0 2.312-1.683l-2.178-6.535a.5.5 0 0 1 .155-.543l5.194-4.306a1.5 1.5 0 0 0 .433-1.661z"></path></svg></span>,
#  <span aria-label="Superbe" class="d8eab2cf7f f0d4d6a2f5 e46e88563a"> <!-- -->Superbe</span>,
#  <span class="d8eab2cf7f c90c0a70d3 db63693c62"> · <!-- -->396 expériences vécues</span>,
#  <span aria-hidden="true" class="b6dc9a9e69 e492382468 a98180785f e25355d3ee" data-testid="icon-with-text-icon"><svg viewbox="0 0 24 24" xmlns="http://www.w3.org/2000/svg"><path d="M15 8.25a3 3 0 1 1-6 0 3 3 0 0 1 6 0zm1.5 0a4.5 4.5 0 1 0-9 0 4.5 4.5 0 0 0 9 0zM12 1.5a6.75 6.75 0 0 1 6.75 6.75c0 2.537-3.537 9.406-6.75 14.25-3.214-4.844-6.75-11.713-6.75-14.25A6.75 6.75 0 0 1 12 1.5zM12 0a8.25 8.25 0 0 0-8.25 8.25c0 2.965 3.594 9.945 7 15.08a1.5 1.5 0 0 0 2.5 0c3.406-5.135 7-12.115 7-15.08A8.25 8.25 0 0 0 12 0z"></path></svg></span>,
#  <span class="a51f4b5adb">1er arr., Paris • 1,7 km du centre</span>,
#  <span aria-hidden="true" class="b6dc9a9e69 a637eeb339 d05b9c02a2 b8c9de5937"><svg data-rtl-flip="true" viewbox="0 0 24 24" xmlns="http://www.w3.org/2000/svg"><path d="M9.45 6c.2 0 .39.078.53.22l5 5c.208.206.323.487.32.78a1.1 1.1 0 0 1-.32.78l-5 5a.75.75 0 0 1-1.06 0 .74.74 0 0 1 0-1.06L13.64 12 8.92 7.28a.74.74 0 0 1 0-1.06.73.73 0 0 1 .53-.22zm4.47 5.72zm0 .57z"></path></svg></span>,
#  <span aria-hidden="true" class="b6dc9a9e69 adc357e4f1 fe621d6382"><svg viewbox="0 0 24 24" xmlns="http://www.w3.org/2000/svg"><path d="M23.555 8.729a1.505 1.505 0 0 0-1.406-.98h-6.087a.5.5 0 0 1-.472-.334l-2.185-6.193a1.5 1.5 0 0 0-2.81 0l-.005.016-2.18 6.177a.5.5 0 0 1-.471.334H1.85A1.5 1.5 0 0 0 .887 10.4l5.184 4.3a.5.5 0 0 1 .155.543l-2.178 6.531a1.5 1.5 0 0 0 2.31 1.684l5.346-3.92a.5.5 0 0 1 .591 0l5.344 3.919a1.5 1.5 0 0 0 2.312-1.683l-2.178-6.535a.5.5 0 0 1 .155-.543l5.194-4.306a1.5 1.5 0 0 0 .433-1.661z"></path></svg></span>,
#  <span aria-hidden="true" class="b6dc9a9e69 adc357e4f1 fe621d6382"><svg viewbox="0 0 24 24" xmlns="http://www.w3.org/2000/svg"><path d="M23.555 8.729a1.505 1.505 0 0 0-1.406-.98h-6.087a.5.5 0 0 1-.472-.334l-2.185-6.193a1.5 1.5 0 0 0-2.81 0l-.005.016-2.18 6.177a.5.5 0 0 1-.471.334H1.85A1.5 1.5 0 0 0 .887 10.4l5.184 4.3a.5.5 0 0 1 .155.543l-2.178 6.531a1.5 1.5 0 0 0 2.31 1.684l5.346-3.92a.5.5 0 0 1 .591 0l5.344 3.919a1.5 1.5 0 0 0 2.312-1.683l-2.178-6.535a.5.5 0 0 1 .155-.543l5.194-4.306a1.5 1.5 0 0 0 .433-1.661z"></path></svg></span>,
#  <span aria-hidden="true" class="b6dc9a9e69 adc357e4f1 fe621d6382"><svg viewbox="0 0 24 24" xmlns="http://www.w3.org/2000/svg"><path d="M23.555 8.729a1.505 1.505 0 0 0-1.406-.98h-6.087a.5.5 0 0 1-.472-.334l-2.185-6.193a1.5 1.5 0 0 0-2.81 0l-.005.016-2.18 6.177a.5.5 0 0 1-.471.334H1.85A1.5 1.5 0 0 0 .887 10.4l5.184 4.3a.5.5 0 0 1 .155.543l-2.178 6.531a1.5 1.5 0 0 0 2.31 1.684l5.346-3.92a.5.5 0 0 1 .591 0l5.344 3.919a1.5 1.5 0 0 0 2.312-1.683l-2.178-6.535a.5.5 0 0 1 .155-.543l5.194-4.306a1.5 1.5 0 0 0 .433-1.661z"></path></svg></span>,
#  <span aria-label="Très bien" class="d8eab2cf7f f0d4d6a2f5 e46e88563a"> <!-- -->Très bien</span>,
#  <span class="d8eab2cf7f c90c0a70d3 db63693c62"> · <!-- -->1 858 expériences vécues</span>,
#  <span aria-hidden="true" class="b6dc9a9e69 e492382468 a98180785f e25355d3ee" data-testid="icon-with-text-icon"><svg viewbox="0 0 24 24" xmlns="http://www.w3.org/2000/svg"><path d="M15 8.25a3 3 0 1 1-6 0 3 3 0 0 1 6 0zm1.5 0a4.5 4.5 0 1 0-9 0 4.5 4.5 0 0 0 9 0zM12 1.5a6.75 6.75 0 0 1 6.75 6.75c0 2.537-3.537 9.406-6.75 14.25-3.214-4.844-6.75-11.713-6.75-14.25A6.75 6.75 0 0 1 12 1.5zM12 0a8.25 8.25 0 0 0-8.25 8.25c0 2.965 3.594 9.945 7 15.08a1.5 1.5 0 0 0 2.5 0c3.406-5.135 7-12.115 7-15.08A8.25 8.25 0 0 0 12 0z"></path></svg></span>,
#  <span class="a51f4b5adb">8e arr., Paris • 3,4 km du centre</span>,
#  <span aria-hidden="true" class="b6dc9a9e69 e492382468 a98180785f e25355d3ee" data-testid="icon-with-text-icon"><svg viewbox="0 0 24 24" xmlns="http://www.w3.org/2000/svg"><path d="M21.22 3.37a.75.75 0 0 0-.6-.59c-4.85-.9-10.6.55-13.37 3.36S3.1 14.39 3.88 19.05L2 21a.75.75 0 0 0 0 1 .74.74 0 0 0 .53.22A.71.71 0 0 0 3 22l2-1.9a16.94 16.94 0 0 0 2.76.23c4.09 0 8.19-1.33 10.35-3.52 2.71-2.81 4.07-8.59 3.11-13.44zM17 15.75c-2.11 2.14-6.59 3.36-10.7 3L16.59 8.47a.75.75 0 0 0 0 -1.06.77.77 0 0 0-1.07 0l-10.3 10.3c-.33-3.91.91-8.31 3.1-10.52s7.29-3.63 11.52-3c.67 4.22-.54 9.22-2.84 11.56z"></path></svg></span>,
#  <span class="a51f4b5adb">Établissement Voyage Durable</span>,
#  <span aria-hidden="true" class="b6dc9a9e69 a637eeb339 d05b9c02a2 b8c9de5937"><svg data-rtl-flip="true" viewbox="0 0 24 24" xmlns="http://www.w3.org/2000/svg"><path d="M9.45 6c.2 0 .39.078.53.22l5 5c.208.206.323.487.32.78a1.1 1.1 0 0 1-.32.78l-5 5a.75.75 0 0 1-1.06 0 .74.74 0 0 1 0-1.06L13.64 12 8.92 7.28a.74.74 0 0 1 0-1.06.73.73 0 0 1 .53-.22zm4.47 5.72zm0 .57z"></path></svg></span>,
#  <span aria-hidden="true" class="b6dc9a9e69 adc357e4f1 fe621d6382"><svg viewbox="0 0 24 24" xmlns="http://www.w3.org/2000/svg"><path d="M23.555 8.729a1.505 1.505 0 0 0-1.406-.98h-6.087a.5.5 0 0 1-.472-.334l-2.185-6.193a1.5 1.5 0 0 0-2.81 0l-.005.016-2.18 6.177a.5.5 0 0 1-.471.334H1.85A1.5 1.5 0 0 0 .887 10.4l5.184 4.3a.5.5 0 0 1 .155.543l-2.178 6.531a1.5 1.5 0 0 0 2.31 1.684l5.346-3.92a.5.5 0 0 1 .591 0l5.344 3.919a1.5 1.5 0 0 0 2.312-1.683l-2.178-6.535a.5.5 0 0 1 .155-.543l5.194-4.306a1.5 1.5 0 0 0 .433-1.661z"></path></svg></span>,
#  <span aria-hidden="true" class="b6dc9a9e69 adc357e4f1 fe621d6382"><svg viewbox="0 0 24 24" xmlns="http://www.w3.org/2000/svg"><path d="M23.555 8.729a1.505 1.505 0 0 0-1.406-.98h-6.087a.5.5 0 0 1-.472-.334l-2.185-6.193a1.5 1.5 0 0 0-2.81 0l-.005.016-2.18 6.177a.5.5 0 0 1-.471.334H1.85A1.5 1.5 0 0 0 .887 10.4l5.184 4.3a.5.5 0 0 1 .155.543l-2.178 6.531a1.5 1.5 0 0 0 2.31 1.684l5.346-3.92a.5.5 0 0 1 .591 0l5.344 3.919a1.5 1.5 0 0 0 2.312-1.683l-2.178-6.535a.5.5 0 0 1 .155-.543l5.194-4.306a1.5 1.5 0 0 0 .433-1.661z"></path></svg></span>,
#  <span aria-hidden="true" class="b6dc9a9e69 adc357e4f1 fe621d6382"><svg viewbox="0 0 24 24" xmlns="http://www.w3.org/2000/svg"><path d="M23.555 8.729a1.505 1.505 0 0 0-1.406-.98h-6.087a.5.5 0 0 1-.472-.334l-2.185-6.193a1.5 1.5 0 0 0-2.81 0l-.005.016-2.18 6.177a.5.5 0 0 1-.471.334H1.85A1.5 1.5 0 0 0 .887 10.4l5.184 4.3a.5.5 0 0 1 .155.543l-2.178 6.531a1.5 1.5 0 0 0 2.31 1.684l5.346-3.92a.5.5 0 0 1 .591 0l5.344 3.919a1.5 1.5 0 0 0 2.312-1.683l-2.178-6.535a.5.5 0 0 1 .155-.543l5.194-4.306a1.5 1.5 0 0 0 .433-1.661z"></path></svg></span>,
#  <span aria-label="Très bien" class="d8eab2cf7f f0d4d6a2f5 e46e88563a"> <!-- -->Très bien</span>,
#  <span class="d8eab2cf7f c90c0a70d3 db63693c62"> · <!-- -->942 expériences vécues</span>,
#  <span aria-hidden="true" class="b6dc9a9e69 e492382468 a98180785f e25355d3ee" data-testid="icon-with-text-icon"><svg viewbox="0 0 24 24" xmlns="http://www.w3.org/2000/svg"><path d="M15 8.25a3 3 0 1 1-6 0 3 3 0 0 1 6 0zm1.5 0a4.5 4.5 0 1 0-9 0 4.5 4.5 0 0 0 9 0zM12 1.5a6.75 6.75 0 0 1 6.75 6.75c0 2.537-3.537 9.406-6.75 14.25-3.214-4.844-6.75-11.713-6.75-14.25A6.75 6.75 0 0 1 12 1.5zM12 0a8.25 8.25 0 0 0-8.25 8.25c0 2.965 3.594 9.945 7 15.08a1.5 1.5 0 0 0 2.5 0c3.406-5.135 7-12.115 7-15.08A8.25 8.25 0 0 0 12 0z"></path></svg></span>,
#  <span class="a51f4b5adb">10e arr., Paris • 2,5 km du centre</span>,
#  <span aria-hidden="true" class="b6dc9a9e69 e492382468 a98180785f e25355d3ee" data-testid="icon-with-text-icon"><svg viewbox="0 0 24 24" xmlns="http://www.w3.org/2000/svg"><path d="M21.22 3.37a.75.75 0 0 0-.6-.59c-4.85-.9-10.6.55-13.37 3.36S3.1 14.39 3.88 19.05L2 21a.75.75 0 0 0 0 1 .74.74 0 0 0 .53.22A.71.71 0 0 0 3 22l2-1.9a16.94 16.94 0 0 0 2.76.23c4.09 0 8.19-1.33 10.35-3.52 2.71-2.81 4.07-8.59 3.11-13.44zM17 15.75c-2.11 2.14-6.59 3.36-10.7 3L16.59 8.47a.75.75 0 0 0 0 -1.06.77.77 0 0 0-1.07 0l-10.3 10.3c-.33-3.91.91-8.31 3.1-10.52s7.29-3.63 11.52-3c.67 4.22-.54 9.22-2.84 11.56z"></path></svg></span>,
#  <span class="a51f4b5adb">Établissement Voyage Durable</span>,
#  <span aria-hidden="true" class="b6dc9a9e69 a637eeb339 d05b9c02a2 b8c9de5937"><svg data-rtl-flip="true" viewbox="0 0 24 24" xmlns="http://www.w3.org/2000/svg"><path d="M9.45 6c.2 0 .39.078.53.22l5 5c.208.206.323.487.32.78a1.1 1.1 0 0 1-.32.78l-5 5a.75.75 0 0 1-1.06 0 .74.74 0 0 1 0-1.06L13.64 12 8.92 7.28a.74.74 0 0 1 0-1.06.73.73 0 0 1 .53-.22zm4.47 5.72zm0 .57z"></path></svg></span>,
#  <span aria-hidden="true" class="b6dc9a9e69 adc357e4f1 fe621d6382"><svg viewbox="0 0 24 24" xmlns="http://www.w3.org/2000/svg"><path d="M23.555 8.729a1.505 1.505 0 0 0-1.406-.98h-6.087a.5.5 0 0 1-.472-.334l-2.185-6.193a1.5 1.5 0 0 0-2.81 0l-.005.016-2.18 6.177a.5.5 0 0 1-.471.334H1.85A1.5 1.5 0 0 0 .887 10.4l5.184 4.3a.5.5 0 0 1 .155.543l-2.178 6.531a1.5 1.5 0 0 0 2.31 1.684l5.346-3.92a.5.5 0 0 1 .591 0l5.344 3.919a1.5 1.5 0 0 0 2.312-1.683l-2.178-6.535a.5.5 0 0 1 .155-.543l5.194-4.306a1.5 1.5 0 0 0 .433-1.661z"></path></svg></span>,
#  <span aria-hidden="true" class="b6dc9a9e69 adc357e4f1 fe621d6382"><svg viewbox="0 0 24 24" xmlns="http://www.w3.org/2000/svg"><path d="M23.555 8.729a1.505 1.505 0 0 0-1.406-.98h-6.087a.5.5 0 0 1-.472-.334l-2.185-6.193a1.5 1.5 0 0 0-2.81 0l-.005.016-2.18 6.177a.5.5 0 0 1-.471.334H1.85A1.5 1.5 0 0 0 .887 10.4l5.184 4.3a.5.5 0 0 1 .155.543l-2.178 6.531a1.5 1.5 0 0 0 2.31 1.684l5.346-3.92a.5.5 0 0 1 .591 0l5.344 3.919a1.5 1.5 0 0 0 2.312-1.683l-2.178-6.535a.5.5 0 0 1 .155-.543l5.194-4.306a1.5 1.5 0 0 0 .433-1.661z"></path></svg></span>,
#  <span aria-hidden="true" class="b6dc9a9e69 adc357e4f1 fe621d6382"><svg viewbox="0 0 24 24" xmlns="http://www.w3.org/2000/svg"><path d="M23.555 8.729a1.505 1.505 0 0 0-1.406-.98h-6.087a.5.5 0 0 1-.472-.334l-2.185-6.193a1.5 1.5 0 0 0-2.81 0l-.005.016-2.18 6.177a.5.5 0 0 1-.471.334H1.85A1.5 1.5 0 0 0 .887 10.4l5.184 4.3a.5.5 0 0 1 .155.543l-2.178 6.531a1.5 1.5 0 0 0 2.31 1.684l5.346-3.92a.5.5 0 0 1 .591 0l5.344 3.919a1.5 1.5 0 0 0 2.312-1.683l-2.178-6.535a.5.5 0 0 1 .155-.543l5.194-4.306a1.5 1.5 0 0 0 .433-1.661z"></path></svg></span>,
#  <span aria-label="Très bien" class="d8eab2cf7f f0d4d6a2f5 e46e88563a"> <!-- -->Très bien</span>,
#  <span class="d8eab2cf7f c90c0a70d3 db63693c62"> · <!-- -->2 961 expériences vécues</span>,
#  <span aria-hidden="true" class="b6dc9a9e69 e492382468 a98180785f e25355d3ee" data-testid="icon-with-text-icon"><svg viewbox="0 0 24 24" xmlns="http://www.w3.org/2000/svg"><path d="M15 8.25a3 3 0 1 1-6 0 3 3 0 0 1 6 0zm1.5 0a4.5 4.5 0 1 0-9 0 4.5 4.5 0 0 0 9 0zM12 1.5a6.75 6.75 0 0 1 6.75 6.75c0 2.537-3.537 9.406-6.75 14.25-3.214-4.844-6.75-11.713-6.75-14.25A6.75 6.75 0 0 1 12 1.5zM12 0a8.25 8.25 0 0 0-8.25 8.25c0 2.965 3.594 9.945 7 15.08a1.5 1.5 0 0 0 2.5 0c3.406-5.135 7-12.115 7-15.08A8.25 8.25 0 0 0 12 0z"></path></svg></span>,
#  <span class="a51f4b5adb">11e arr., Paris • 1,3 km du centre</span>,
#  <span aria-hidden="true" class="b6dc9a9e69 e492382468 a98180785f e25355d3ee" data-testid="icon-with-text-icon"><svg viewbox="0 0 24 24" xmlns="http://www.w3.org/2000/svg"><path d="M21.22 3.37a.75.75 0 0 0-.6-.59c-4.85-.9-10.6.55-13.37 3.36S3.1 14.39 3.88 19.05L2 21a.75.75 0 0 0 0 1 .74.74 0 0 0 .53.22A.71.71 0 0 0 3 22l2-1.9a16.94 16.94 0 0 0 2.76.23c4.09 0 8.19-1.33 10.35-3.52 2.71-2.81 4.07-8.59 3.11-13.44zM17 15.75c-2.11 2.14-6.59 3.36-10.7 3L16.59 8.47a.75.75 0 0 0 0 -1.06.77.77 0 0 0-1.07 0l-10.3 10.3c-.33-3.91.91-8.31 3.1-10.52s7.29-3.63 11.52-3c.67 4.22-.54 9.22-2.84 11.56z"></path></svg></span>,
#  <span class="a51f4b5adb">Établissement Voyage Durable</span>,
#  <span aria-hidden="true" class="b6dc9a9e69 a637eeb339 d05b9c02a2 b8c9de5937"><svg data-rtl-flip="true" viewbox="0 0 24 24" xmlns="http://www.w3.org/2000/svg"><path d="M9.45 6c.2 0 .39.078.53.22l5 5c.208.206.323.487.32.78a1.1 1.1 0 0 1-.32.78l-5 5a.75.75 0 0 1-1.06 0 .74.74 0 0 1 0-1.06L13.64 12 8.92 7.28a.74.74 0 0 1 0-1.06.73.73 0 0 1 .53-.22zm4.47 5.72zm0 .57z"></path></svg></span>,
#  <span aria-hidden="true" class="b6dc9a9e69 adc357e4f1 fe621d6382"><svg viewbox="0 0 24 24" xmlns="http://www.w3.org/2000/svg"><path d="M23.555 8.729a1.505 1.505 0 0 0-1.406-.98h-6.087a.5.5 0 0 1-.472-.334l-2.185-6.193a1.5 1.5 0 0 0-2.81 0l-.005.016-2.18 6.177a.5.5 0 0 1-.471.334H1.85A1.5 1.5 0 0 0 .887 10.4l5.184 4.3a.5.5 0 0 1 .155.543l-2.178 6.531a1.5 1.5 0 0 0 2.31 1.684l5.346-3.92a.5.5 0 0 1 .591 0l5.344 3.919a1.5 1.5 0 0 0 2.312-1.683l-2.178-6.535a.5.5 0 0 1 .155-.543l5.194-4.306a1.5 1.5 0 0 0 .433-1.661z"></path></svg></span>,
#  <span aria-hidden="true" class="b6dc9a9e69 adc357e4f1 fe621d6382"><svg viewbox="0 0 24 24" xmlns="http://www.w3.org/2000/svg"><path d="M23.555 8.729a1.505 1.505 0 0 0-1.406-.98h-6.087a.5.5 0 0 1-.472-.334l-2.185-6.193a1.5 1.5 0 0 0-2.81 0l-.005.016-2.18 6.177a.5.5 0 0 1-.471.334H1.85A1.5 1.5 0 0 0 .887 10.4l5.184 4.3a.5.5 0 0 1 .155.543l-2.178 6.531a1.5 1.5 0 0 0 2.31 1.684l5.346-3.92a.5.5 0 0 1 .591 0l5.344 3.919a1.5 1.5 0 0 0 2.312-1.683l-2.178-6.535a.5.5 0 0 1 .155-.543l5.194-4.306a1.5 1.5 0 0 0 .433-1.661z"></path></svg></span>,
#  <span aria-hidden="true" class="b6dc9a9e69 adc357e4f1 fe621d6382"><svg viewbox="0 0 24 24" xmlns="http://www.w3.org/2000/svg"><path d="M23.555 8.729a1.505 1.505 0 0 0-1.406-.98h-6.087a.5.5 0 0 1-.472-.334l-2.185-6.193a1.5 1.5 0 0 0-2.81 0l-.005.016-2.18 6.177a.5.5 0 0 1-.471.334H1.85A1.5 1.5 0 0 0 .887 10.4l5.184 4.3a.5.5 0 0 1 .155.543l-2.178 6.531a1.5 1.5 0 0 0 2.31 1.684l5.346-3.92a.5.5 0 0 1 .591 0l5.344 3.919a1.5 1.5 0 0 0 2.312-1.683l-2.178-6.535a.5.5 0 0 1 .155-.543l5.194-4.306a1.5 1.5 0 0 0 .433-1.661z"></path></svg></span>,
#  <span aria-label="Superbe" class="d8eab2cf7f f0d4d6a2f5 e46e88563a"> <!-- -->Superbe</span>,
#  <span class="d8eab2cf7f c90c0a70d3 db63693c62"> · <!-- -->5 078 expériences vécues</span>,
#  <span aria-hidden="true" class="b6dc9a9e69 e492382468 a98180785f e25355d3ee" data-testid="icon-with-text-icon"><svg viewbox="0 0 24 24" xmlns="http://www.w3.org/2000/svg"><path d="M15 8.25a3 3 0 1 1-6 0 3 3 0 0 1 6 0zm1.5 0a4.5 4.5 0 1 0-9 0 4.5 4.5 0 0 0 9 0zM12 1.5a6.75 6.75 0 0 1 6.75 6.75c0 2.537-3.537 9.406-6.75 14.25-3.214-4.844-6.75-11.713-6.75-14.25A6.75 6.75 0 0 1 12 1.5zM12 0a8.25 8.25 0 0 0-8.25 8.25c0 2.965 3.594 9.945 7 15.08a1.5 1.5 0 0 0 2.5 0c3.406-5.135 7-12.115 7-15.08A8.25 8.25 0 0 0 12 0z"></path></svg></span>,
#  <span class="a51f4b5adb">12e arr., Paris • 4,9 km du centre</span>,
#  <span aria-hidden="true" class="b6dc9a9e69 e492382468 a98180785f e25355d3ee" data-testid="icon-with-text-icon"><svg viewbox="0 0 24 24" xmlns="http://www.w3.org/2000/svg"><path d="M21.22 3.37a.75.75 0 0 0-.6-.59c-4.85-.9-10.6.55-13.37 3.36S3.1 14.39 3.88 19.05L2 21a.75.75 0 0 0 0 1 .74.74 0 0 0 .53.22A.71.71 0 0 0 3 22l2-1.9a16.94 16.94 0 0 0 2.76.23c4.09 0 8.19-1.33 10.35-3.52 2.71-2.81 4.07-8.59 3.11-13.44zM17 15.75c-2.11 2.14-6.59 3.36-10.7 3L16.59 8.47a.75.75 0 0 0 0 -1.06.77.77 0 0 0-1.07 0l-10.3 10.3c-.33-3.91.91-8.31 3.1-10.52s7.29-3.63 11.52-3c.67 4.22-.54 9.22-2.84 11.56z"></path></svg></span>,
#  <span class="a51f4b5adb">Établissement Voyage Durable</span>,
#  <span aria-hidden="true" class="b6dc9a9e69 a637eeb339 d05b9c02a2 b8c9de5937"><svg data-rtl-flip="true" viewbox="0 0 24 24" xmlns="http://www.w3.org/2000/svg"><path d="M9.45 6c.2 0 .39.078.53.22l5 5c.208.206.323.487.32.78a1.1 1.1 0 0 1-.32.78l-5 5a.75.75 0 0 1-1.06 0 .74.74 0 0 1 0-1.06L13.64 12 8.92 7.28a.74.74 0 0 1 0-1.06.73.73 0 0 1 .53-.22zm4.47 5.72zm0 .57z"></path></svg></span>,
#  <span aria-label="Bien " class="d8eab2cf7f f0d4d6a2f5 e46e88563a"> <!-- -->Bien </span>,
#  <span class="d8eab2cf7f c90c0a70d3 db63693c62"> · <!-- -->3 021 expériences vécues</span>,
#  <span aria-hidden="true" class="b6dc9a9e69 e492382468 a98180785f e25355d3ee" data-testid="icon-with-text-icon"><svg viewbox="0 0 24 24" xmlns="http://www.w3.org/2000/svg"><path d="M15 8.25a3 3 0 1 1-6 0 3 3 0 0 1 6 0zm1.5 0a4.5 4.5 0 1 0-9 0 4.5 4.5 0 0 0 9 0zM12 1.5a6.75 6.75 0 0 1 6.75 6.75c0 2.537-3.537 9.406-6.75 14.25-3.214-4.844-6.75-11.713-6.75-14.25A6.75 6.75 0 0 1 12 1.5zM12 0a8.25 8.25 0 0 0-8.25 8.25c0 2.965 3.594 9.945 7 15.08a1.5 1.5 0 0 0 2.5 0c3.406-5.135 7-12.115 7-15.08A8.25 8.25 0 0 0 12 0z"></path></svg></span>,
#  <span class="a51f4b5adb">13e arr., Paris • 4,1 km du centre</span>,
#  <span aria-hidden="true" class="b6dc9a9e69 a637eeb339 d05b9c02a2 b8c9de5937"><svg data-rtl-flip="true" viewbox="0 0 24 24" xmlns="http://www.w3.org/2000/svg"><path d="M9.45 6c.2 0 .39.078.53.22l5 5c.208.206.323.487.32.78a1.1 1.1 0 0 1-.32.78l-5 5a.75.75 0 0 1-1.06 0 .74.74 0 0 1 0-1.06L13.64 12 8.92 7.28a.74.74 0 0 1 0-1.06.73.73 0 0 1 .53-.22zm4.47 5.72zm0 .57z"></path></svg></span>,
#  <span aria-hidden="true" class="b6dc9a9e69 adc357e4f1 fe621d6382"><svg viewbox="0 0 24 24" xmlns="http://www.w3.org/2000/svg"><path d="M23.555 8.729a1.505 1.505 0 0 0-1.406-.98h-6.087a.5.5 0 0 1-.472-.334l-2.185-6.193a1.5 1.5 0 0 0-2.81 0l-.005.016-2.18 6.177a.5.5 0 0 1-.471.334H1.85A1.5 1.5 0 0 0 .887 10.4l5.184 4.3a.5.5 0 0 1 .155.543l-2.178 6.531a1.5 1.5 0 0 0 2.31 1.684l5.346-3.92a.5.5 0 0 1 .591 0l5.344 3.919a1.5 1.5 0 0 0 2.312-1.683l-2.178-6.535a.5.5 0 0 1 .155-.543l5.194-4.306a1.5 1.5 0 0 0 .433-1.661z"></path></svg></span>,
#  <span aria-hidden="true" class="b6dc9a9e69 adc357e4f1 fe621d6382"><svg viewbox="0 0 24 24" xmlns="http://www.w3.org/2000/svg"><path d="M23.555 8.729a1.505 1.505 0 0 0-1.406-.98h-6.087a.5.5 0 0 1-.472-.334l-2.185-6.193a1.5 1.5 0 0 0-2.81 0l-.005.016-2.18 6.177a.5.5 0 0 1-.471.334H1.85A1.5 1.5 0 0 0 .887 10.4l5.184 4.3a.5.5 0 0 1 .155.543l-2.178 6.531a1.5 1.5 0 0 0 2.31 1.684l5.346-3.92a.5.5 0 0 1 .591 0l5.344 3.919a1.5 1.5 0 0 0 2.312-1.683l-2.178-6.535a.5.5 0 0 1 .155-.543l5.194-4.306a1.5 1.5 0 0 0 .433-1.661z"></path></svg></span>,
#  <span aria-hidden="true" class="b6dc9a9e69 adc357e4f1 fe621d6382"><svg viewbox="0 0 24 24" xmlns="http://www.w3.org/2000/svg"><path d="M23.555 8.729a1.505 1.505 0 0 0-1.406-.98h-6.087a.5.5 0 0 1-.472-.334l-2.185-6.193a1.5 1.5 0 0 0-2.81 0l-.005.016-2.18 6.177a.5.5 0 0 1-.471.334H1.85A1.5 1.5 0 0 0 .887 10.4l5.184 4.3a.5.5 0 0 1 .155.543l-2.178 6.531a1.5 1.5 0 0 0 2.31 1.684l5.346-3.92a.5.5 0 0 1 .591 0l5.344 3.919a1.5 1.5 0 0 0 2.312-1.683l-2.178-6.535a.5.5 0 0 1 .155-.543l5.194-4.306a1.5 1.5 0 0 0 .433-1.661z"></path></svg></span>,
#  <span aria-label="Très bien" class="d8eab2cf7f f0d4d6a2f5 e46e88563a"> <!-- -->Très bien</span>,
#  <span class="d8eab2cf7f c90c0a70d3 db63693c62"> · <!-- -->1 552 expériences vécues</span>,
#  <span aria-hidden="true" class="b6dc9a9e69 e492382468 a98180785f e25355d3ee" data-testid="icon-with-text-icon"><svg viewbox="0 0 24 24" xmlns="http://www.w3.org/2000/svg"><path d="M15 8.25a3 3 0 1 1-6 0 3 3 0 0 1 6 0zm1.5 0a4.5 4.5 0 1 0-9 0 4.5 4.5 0 0 0 9 0zM12 1.5a6.75 6.75 0 0 1 6.75 6.75c0 2.537-3.537 9.406-6.75 14.25-3.214-4.844-6.75-11.713-6.75-14.25A6.75 6.75 0 0 1 12 1.5zM12 0a8.25 8.25 0 0 0-8.25 8.25c0 2.965 3.594 9.945 7 15.08a1.5 1.5 0 0 0 2.5 0c3.406-5.135 7-12.115 7-15.08A8.25 8.25 0 0 0 12 0z"></path></svg></span>,
#  <span class="a51f4b5adb">9e arr., Paris • 2,9 km du centre</span>,
#  <span aria-hidden="true" class="b6dc9a9e69 e492382468 a98180785f e25355d3ee" data-testid="icon-with-text-icon"><svg viewbox="0 0 24 24" xmlns="http://www.w3.org/2000/svg"><path d="M21.22 3.37a.75.75 0 0 0-.6-.59c-4.85-.9-10.6.55-13.37 3.36S3.1 14.39 3.88 19.05L2 21a.75.75 0 0 0 0 1 .74.74 0 0 0 .53.22A.71.71 0 0 0 3 22l2-1.9a16.94 16.94 0 0 0 2.76.23c4.09 0 8.19-1.33 10.35-3.52 2.71-2.81 4.07-8.59 3.11-13.44zM17 15.75c-2.11 2.14-6.59 3.36-10.7 3L16.59 8.47a.75.75 0 0 0 0 -1.06.77.77 0 0 0-1.07 0l-10.3 10.3c-.33-3.91.91-8.31 3.1-10.52s7.29-3.63 11.52-3c.67 4.22-.54 9.22-2.84 11.56z"></path></svg></span>,
#  <span class="a51f4b5adb">Établissement Voyage Durable</span>,
#  <span aria-hidden="true" class="b6dc9a9e69 a637eeb339 d05b9c02a2 b8c9de5937"><svg data-rtl-flip="true" viewbox="0 0 24 24" xmlns="http://www.w3.org/2000/svg"><path d="M9.45 6c.2 0 .39.078.53.22l5 5c.208.206.323.487.32.78a1.1 1.1 0 0 1-.32.78l-5 5a.75.75 0 0 1-1.06 0 .74.74 0 0 1 0-1.06L13.64 12 8.92 7.28a.74.74 0 0 1 0-1.06.73.73 0 0 1 .53-.22zm4.47 5.72zm0 .57z"></path></svg></span>,
#  <span aria-hidden="true" class="b6dc9a9e69 adc357e4f1 fe621d6382"><svg viewbox="0 0 24 24" xmlns="http://www.w3.org/2000/svg"><path d="M23.555 8.729a1.505 1.505 0 0 0-1.406-.98h-6.087a.5.5 0 0 1-.472-.334l-2.185-6.193a1.5 1.5 0 0 0-2.81 0l-.005.016-2.18 6.177a.5.5 0 0 1-.471.334H1.85A1.5 1.5 0 0 0 .887 10.4l5.184 4.3a.5.5 0 0 1 .155.543l-2.178 6.531a1.5 1.5 0 0 0 2.31 1.684l5.346-3.92a.5.5 0 0 1 .591 0l5.344 3.919a1.5 1.5 0 0 0 2.312-1.683l-2.178-6.535a.5.5 0 0 1 .155-.543l5.194-4.306a1.5 1.5 0 0 0 .433-1.661z"></path></svg></span>,
#  <span aria-hidden="true" class="b6dc9a9e69 adc357e4f1 fe621d6382"><svg viewbox="0 0 24 24" xmlns="http://www.w3.org/2000/svg"><path d="M23.555 8.729a1.505 1.505 0 0 0-1.406-.98h-6.087a.5.5 0 0 1-.472-.334l-2.185-6.193a1.5 1.5 0 0 0-2.81 0l-.005.016-2.18 6.177a.5.5 0 0 1-.471.334H1.85A1.5 1.5 0 0 0 .887 10.4l5.184 4.3a.5.5 0 0 1 .155.543l-2.178 6.531a1.5 1.5 0 0 0 2.31 1.684l5.346-3.92a.5.5 0 0 1 .591 0l5.344 3.919a1.5 1.5 0 0 0 2.312-1.683l-2.178-6.535a.5.5 0 0 1 .155-.543l5.194-4.306a1.5 1.5 0 0 0 .433-1.661z"></path></svg></span>,
#  <span aria-hidden="true" class="b6dc9a9e69 adc357e4f1 fe621d6382"><svg viewbox="0 0 24 24" xmlns="http://www.w3.org/2000/svg"><path d="M23.555 8.729a1.505 1.505 0 0 0-1.406-.98h-6.087a.5.5 0 0 1-.472-.334l-2.185-6.193a1.5 1.5 0 0 0-2.81 0l-.005.016-2.18 6.177a.5.5 0 0 1-.471.334H1.85A1.5 1.5 0 0 0 .887 10.4l5.184 4.3a.5.5 0 0 1 .155.543l-2.178 6.531a1.5 1.5 0 0 0 2.31 1.684l5.346-3.92a.5.5 0 0 1 .591 0l5.344 3.919a1.5 1.5 0 0 0 2.312-1.683l-2.178-6.535a.5.5 0 0 1 .155-.543l5.194-4.306a1.5 1.5 0 0 0 .433-1.661z"></path></svg></span>,
#  <span aria-hidden="true" class="b6dc9a9e69 adc357e4f1 fe621d6382"><svg viewbox="0 0 24 24" xmlns="http://www.w3.org/2000/svg"><path d="M23.555 8.729a1.505 1.505 0 0 0-1.406-.98h-6.087a.5.5 0 0 1-.472-.334l-2.185-6.193a1.5 1.5 0 0 0-2.81 0l-.005.016-2.18 6.177a.5.5 0 0 1-.471.334H1.85A1.5 1.5 0 0 0 .887 10.4l5.184 4.3a.5.5 0 0 1 .155.543l-2.178 6.531a1.5 1.5 0 0 0 2.31 1.684l5.346-3.92a.5.5 0 0 1 .591 0l5.344 3.919a1.5 1.5 0 0 0 2.312-1.683l-2.178-6.535a.5.5 0 0 1 .155-.543l5.194-4.306a1.5 1.5 0 0 0 .433-1.661z"></path></svg></span>,
#  <span aria-label="Très bien" class="d8eab2cf7f f0d4d6a2f5 e46e88563a"> <!-- -->Très bien</span>,
#  <span class="d8eab2cf7f c90c0a70d3 db63693c62"> · <!-- -->1 947 expériences vécues</span>,
#  <span aria-hidden="true" class="b6dc9a9e69 e492382468 a98180785f e25355d3ee" data-testid="icon-with-text-icon"><svg viewbox="0 0 24 24" xmlns="http://www.w3.org/2000/svg"><path d="M15 8.25a3 3 0 1 1-6 0 3 3 0 0 1 6 0zm1.5 0a4.5 4.5 0 1 0-9 0 4.5 4.5 0 0 0 9 0zM12 1.5a6.75 6.75 0 0 1 6.75 6.75c0 2.537-3.537 9.406-6.75 14.25-3.214-4.844-6.75-11.713-6.75-14.25A6.75 6.75 0 0 1 12 1.5zM12 0a8.25 8.25 0 0 0-8.25 8.25c0 2.965 3.594 9.945 7 15.08a1.5 1.5 0 0 0 2.5 0c3.406-5.135 7-12.115 7-15.08A8.25 8.25 0 0 0 12 0z"></path></svg></span>,
#  <span class="a51f4b5adb">5e arr., Paris • 2,1 km du centre</span>,
#  <span aria-hidden="true" class="b6dc9a9e69 a637eeb339 d05b9c02a2 b8c9de5937"><svg data-rtl-flip="true" viewbox="0 0 24 24" xmlns="http://www.w3.org/2000/svg"><path d="M9.45 6c.2 0 .39.078.53.22l5 5c.208.206.323.487.32.78a1.1 1.1 0 0 1-.32.78l-5 5a.75.75 0 0 1-1.06 0 .74.74 0 0 1 0-1.06L13.64 12 8.92 7.28a.74.74 0 0 1 0-1.06.73.73 0 0 1 .53-.22zm4.47 5.72zm0 .57z"></path></svg></span>,
#  <span aria-hidden="true" class="b6dc9a9e69 adc357e4f1 fe621d6382"><svg viewbox="0 0 24 24" xmlns="http://www.w3.org/2000/svg"><path d="M23.555 8.729a1.505 1.505 0 0 0-1.406-.98h-6.087a.5.5 0 0 1-.472-.334l-2.185-6.193a1.5 1.5 0 0 0-2.81 0l-.005.016-2.18 6.177a.5.5 0 0 1-.471.334H1.85A1.5 1.5 0 0 0 .887 10.4l5.184 4.3a.5.5 0 0 1 .155.543l-2.178 6.531a1.5 1.5 0 0 0 2.31 1.684l5.346-3.92a.5.5 0 0 1 .591 0l5.344 3.919a1.5 1.5 0 0 0 2.312-1.683l-2.178-6.535a.5.5 0 0 1 .155-.543l5.194-4.306a1.5 1.5 0 0 0 .433-1.661z"></path></svg></span>,
#  <span aria-hidden="true" class="b6dc9a9e69 adc357e4f1 fe621d6382"><svg viewbox="0 0 24 24" xmlns="http://www.w3.org/2000/svg"><path d="M23.555 8.729a1.505 1.505 0 0 0-1.406-.98h-6.087a.5.5 0 0 1-.472-.334l-2.185-6.193a1.5 1.5 0 0 0-2.81 0l-.005.016-2.18 6.177a.5.5 0 0 1-.471.334H1.85A1.5 1.5 0 0 0 .887 10.4l5.184 4.3a.5.5 0 0 1 .155.543l-2.178 6.531a1.5 1.5 0 0 0 2.31 1.684l5.346-3.92a.5.5 0 0 1 .591 0l5.344 3.919a1.5 1.5 0 0 0 2.312-1.683l-2.178-6.535a.5.5 0 0 1 .155-.543l5.194-4.306a1.5 1.5 0 0 0 .433-1.661z"></path></svg></span>,
#  <span aria-hidden="true" class="b6dc9a9e69 adc357e4f1 fe621d6382"><svg viewbox="0 0 24 24" xmlns="http://www.w3.org/2000/svg"><path d="M23.555 8.729a1.505 1.505 0 0 0-1.406-.98h-6.087a.5.5 0 0 1-.472-.334l-2.185-6.193a1.5 1.5 0 0 0-2.81 0l-.005.016-2.18 6.177a.5.5 0 0 1-.471.334H1.85A1.5 1.5 0 0 0 .887 10.4l5.184 4.3a.5.5 0 0 1 .155.543l-2.178 6.531a1.5 1.5 0 0 0 2.31 1.684l5.346-3.92a.5.5 0 0 1 .591 0l5.344 3.919a1.5 1.5 0 0 0 2.312-1.683l-2.178-6.535a.5.5 0 0 1 .155-.543l5.194-4.306a1.5 1.5 0 0 0 .433-1.661z"></path></svg></span>,
#  <span aria-label="Très bien" class="d8eab2cf7f f0d4d6a2f5 e46e88563a"> <!-- -->Très bien</span>,
#  <span class="d8eab2cf7f c90c0a70d3 db63693c62"> · <!-- -->1 267 expériences vécues</span>,
#  <span aria-hidden="true" class="b6dc9a9e69 e492382468 a98180785f e25355d3ee" data-testid="icon-with-text-icon"><svg viewbox="0 0 24 24" xmlns="http://www.w3.org/2000/svg"><path d="M15 8.25a3 3 0 1 1-6 0 3 3 0 0 1 6 0zm1.5 0a4.5 4.5 0 1 0-9 0 4.5 4.5 0 0 0 9 0zM12 1.5a6.75 6.75 0 0 1 6.75 6.75c0 2.537-3.537 9.406-6.75 14.25-3.214-4.844-6.75-11.713-6.75-14.25A6.75 6.75 0 0 1 12 1.5zM12 0a8.25 8.25 0 0 0-8.25 8.25c0 2.965 3.594 9.945 7 15.08a1.5 1.5 0 0 0 2.5 0c3.406-5.135 7-12.115 7-15.08A8.25 8.25 0 0 0 12 0z"></path></svg></span>,
#  <span class="a51f4b5adb">3e arr., Paris • 1,1 km du centre</span>,
#  <span aria-hidden="true" class="b6dc9a9e69 e492382468 a98180785f e25355d3ee" data-testid="icon-with-text-icon"><svg viewbox="0 0 24 24" xmlns="http://www.w3.org/2000/svg"><path d="M21.22 3.37a.75.75 0 0 0-.6-.59c-4.85-.9-10.6.55-13.37 3.36S3.1 14.39 3.88 19.05L2 21a.75.75 0 0 0 0 1 .74.74 0 0 0 .53.22A.71.71 0 0 0 3 22l2-1.9a16.94 16.94 0 0 0 2.76.23c4.09 0 8.19-1.33 10.35-3.52 2.71-2.81 4.07-8.59 3.11-13.44zM17 15.75c-2.11 2.14-6.59 3.36-10.7 3L16.59 8.47a.75.75 0 0 0 0 -1.06.77.77 0 0 0-1.07 0l-10.3 10.3c-.33-3.91.91-8.31 3.1-10.52s7.29-3.63 11.52-3c.67 4.22-.54 9.22-2.84 11.56z"></path></svg></span>,
#  <span class="a51f4b5adb">Établissement Voyage Durable</span>,
#  <span aria-hidden="true" class="b6dc9a9e69 a637eeb339 d05b9c02a2 b8c9de5937"><svg data-rtl-flip="true" viewbox="0 0 24 24" xmlns="http://www.w3.org/2000/svg"><path d="M9.45 6c.2 0 .39.078.53.22l5 5c.208.206.323.487.32.78a1.1 1.1 0 0 1-.32.78l-5 5a.75.75 0 0 1-1.06 0 .74.74 0 0 1 0-1.06L13.64 12 8.92 7.28a.74.74 0 0 1 0-1.06.73.73 0 0 1 .53-.22zm4.47 5.72zm0 .57z"></path></svg></span>,
#  <span aria-hidden="true" class="b6dc9a9e69 adc357e4f1 fe621d6382"><svg viewbox="0 0 24 24" xmlns="http://www.w3.org/2000/svg"><path d="M23.555 8.729a1.505 1.505 0 0 0-1.406-.98h-6.087a.5.5 0 0 1-.472-.334l-2.185-6.193a1.5 1.5 0 0 0-2.81 0l-.005.016-2.18 6.177a.5.5 0 0 1-.471.334H1.85A1.5 1.5 0 0 0 .887 10.4l5.184 4.3a.5.5 0 0 1 .155.543l-2.178 6.531a1.5 1.5 0 0 0 2.31 1.684l5.346-3.92a.5.5 0 0 1 .591 0l5.344 3.919a1.5 1.5 0 0 0 2.312-1.683l-2.178-6.535a.5.5 0 0 1 .155-.543l5.194-4.306a1.5 1.5 0 0 0 .433-1.661z"></path></svg></span>,
#  <span aria-hidden="true" class="b6dc9a9e69 adc357e4f1 fe621d6382"><svg viewbox="0 0 24 24" xmlns="http://www.w3.org/2000/svg"><path d="M23.555 8.729a1.505 1.505 0 0 0-1.406-.98h-6.087a.5.5 0 0 1-.472-.334l-2.185-6.193a1.5 1.5 0 0 0-2.81 0l-.005.016-2.18 6.177a.5.5 0 0 1-.471.334H1.85A1.5 1.5 0 0 0 .887 10.4l5.184 4.3a.5.5 0 0 1 .155.543l-2.178 6.531a1.5 1.5 0 0 0 2.31 1.684l5.346-3.92a.5.5 0 0 1 .591 0l5.344 3.919a1.5 1.5 0 0 0 2.312-1.683l-2.178-6.535a.5.5 0 0 1 .155-.543l5.194-4.306a1.5 1.5 0 0 0 .433-1.661z"></path></svg></span>,
#  <span aria-hidden="true" class="b6dc9a9e69 adc357e4f1 fe621d6382"><svg viewbox="0 0 24 24" xmlns="http://www.w3.org/2000/svg"><path d="M23.555 8.729a1.505 1.505 0 0 0-1.406-.98h-6.087a.5.5 0 0 1-.472-.334l-2.185-6.193a1.5 1.5 0 0 0-2.81 0l-.005.016-2.18 6.177a.5.5 0 0 1-.471.334H1.85A1.5 1.5 0 0 0 .887 10.4l5.184 4.3a.5.5 0 0 1 .155.543l-2.178 6.531a1.5 1.5 0 0 0 2.31 1.684l5.346-3.92a.5.5 0 0 1 .591 0l5.344 3.919a1.5 1.5 0 0 0 2.312-1.683l-2.178-6.535a.5.5 0 0 1 .155-.543l5.194-4.306a1.5 1.5 0 0 0 .433-1.661z"></path></svg></span>,
#  <span aria-label="Très bien" class="d8eab2cf7f f0d4d6a2f5 e46e88563a"> <!-- -->Très bien</span>,
#  <span class="d8eab2cf7f c90c0a70d3 db63693c62"> · <!-- -->1 116 expériences vécues</span>,
#  <span aria-hidden="true" class="b6dc9a9e69 e492382468 a98180785f e25355d3ee" data-testid="icon-with-text-icon"><svg viewbox="0 0 24 24" xmlns="http://www.w3.org/2000/svg"><path d="M15 8.25a3 3 0 1 1-6 0 3 3 0 0 1 6 0zm1.5 0a4.5 4.5 0 1 0-9 0 4.5 4.5 0 0 0 9 0zM12 1.5a6.75 6.75 0 0 1 6.75 6.75c0 2.537-3.537 9.406-6.75 14.25-3.214-4.844-6.75-11.713-6.75-14.25A6.75 6.75 0 0 1 12 1.5zM12 0a8.25 8.25 0 0 0-8.25 8.25c0 2.965 3.594 9.945 7 15.08a1.5 1.5 0 0 0 2.5 0c3.406-5.135 7-12.115 7-15.08A8.25 8.25 0 0 0 12 0z"></path></svg></span>,
#  <span class="a51f4b5adb">17e arr., Paris • 4,5 km du centre</span>,
#  <span aria-hidden="true" class="b6dc9a9e69 a637eeb339 d05b9c02a2 b8c9de5937"><svg data-rtl-flip="true" viewbox="0 0 24 24" xmlns="http://www.w3.org/2000/svg"><path d="M9.45 6c.2 0 .39.078.53.22l5 5c.208.206.323.487.32.78a1.1 1.1 0 0 1-.32.78l-5 5a.75.75 0 0 1-1.06 0 .74.74 0 0 1 0-1.06L13.64 12 8.92 7.28a.74.74 0 0 1 0-1.06.73.73 0 0 1 .53-.22zm4.47 5.72zm0 .57z"></path></svg></span>,
#  <span aria-hidden="true" class="b6dc9a9e69 adc357e4f1 fe621d6382"><svg viewbox="0 0 24 24" xmlns="http://www.w3.org/2000/svg"><path d="M23.555 8.729a1.505 1.505 0 0 0-1.406-.98h-6.087a.5.5 0 0 1-.472-.334l-2.185-6.193a1.5 1.5 0 0 0-2.81 0l-.005.016-2.18 6.177a.5.5 0 0 1-.471.334H1.85A1.5 1.5 0 0 0 .887 10.4l5.184 4.3a.5.5 0 0 1 .155.543l-2.178 6.531a1.5 1.5 0 0 0 2.31 1.684l5.346-3.92a.5.5 0 0 1 .591 0l5.344 3.919a1.5 1.5 0 0 0 2.312-1.683l-2.178-6.535a.5.5 0 0 1 .155-.543l5.194-4.306a1.5 1.5 0 0 0 .433-1.661z"></path></svg></span>,
#  <span aria-hidden="true" class="b6dc9a9e69 adc357e4f1 fe621d6382"><svg viewbox="0 0 24 24" xmlns="http://www.w3.org/2000/svg"><path d="M23.555 8.729a1.505 1.505 0 0 0-1.406-.98h-6.087a.5.5 0 0 1-.472-.334l-2.185-6.193a1.5 1.5 0 0 0-2.81 0l-.005.016-2.18 6.177a.5.5 0 0 1-.471.334H1.85A1.5 1.5 0 0 0 .887 10.4l5.184 4.3a.5.5 0 0 1 .155.543l-2.178 6.531a1.5 1.5 0 0 0 2.31 1.684l5.346-3.92a.5.5 0 0 1 .591 0l5.344 3.919a1.5 1.5 0 0 0 2.312-1.683l-2.178-6.535a.5.5 0 0 1 .155-.543l5.194-4.306a1.5 1.5 0 0 0 .433-1.661z"></path></svg></span>,
#  <span aria-hidden="true" class="b6dc9a9e69 adc357e4f1 fe621d6382"><svg viewbox="0 0 24 24" xmlns="http://www.w3.org/2000/svg"><path d="M23.555 8.729a1.505 1.505 0 0 0-1.406-.98h-6.087a.5.5 0 0 1-.472-.334l-2.185-6.193a1.5 1.5 0 0 0-2.81 0l-.005.016-2.18 6.177a.5.5 0 0 1-.471.334H1.85A1.5 1.5 0 0 0 .887 10.4l5.184 4.3a.5.5 0 0 1 .155.543l-2.178 6.531a1.5 1.5 0 0 0 2.31 1.684l5.346-3.92a.5.5 0 0 1 .591 0l5.344 3.919a1.5 1.5 0 0 0 2.312-1.683l-2.178-6.535a.5.5 0 0 1 .155-.543l5.194-4.306a1.5 1.5 0 0 0 .433-1.661z"></path></svg></span>,
#  <span aria-hidden="true" class="b6dc9a9e69 adc357e4f1 fe621d6382"><svg viewbox="0 0 24 24" xmlns="http://www.w3.org/2000/svg"><path d="M23.555 8.729a1.505 1.505 0 0 0-1.406-.98h-6.087a.5.5 0 0 1-.472-.334l-2.185-6.193a1.5 1.5 0 0 0-2.81 0l-.005.016-2.18 6.177a.5.5 0 0 1-.471.334H1.85A1.5 1.5 0 0 0 .887 10.4l5.184 4.3a.5.5 0 0 1 .155.543l-2.178 6.531a1.5 1.5 0 0 0 2.31 1.684l5.346-3.92a.5.5 0 0 1 .591 0l5.344 3.919a1.5 1.5 0 0 0 2.312-1.683l-2.178-6.535a.5.5 0 0 1 .155-.543l5.194-4.306a1.5 1.5 0 0 0 .433-1.661z"></path></svg></span>,
#  <span aria-label="Superbe" class="d8eab2cf7f f0d4d6a2f5 e46e88563a"> <!-- -->Superbe</span>,
#  <span class="d8eab2cf7f c90c0a70d3 db63693c62"> · <!-- -->1 553 expériences vécues</span>,
#  <span aria-hidden="true" class="b6dc9a9e69 e492382468 a98180785f e25355d3ee" data-testid="icon-with-text-icon"><svg viewbox="0 0 24 24" xmlns="http://www.w3.org/2000/svg"><path d="M15 8.25a3 3 0 1 1-6 0 3 3 0 0 1 6 0zm1.5 0a4.5 4.5 0 1 0-9 0 4.5 4.5 0 0 0 9 0zM12 1.5a6.75 6.75 0 0 1 6.75 6.75c0 2.537-3.537 9.406-6.75 14.25-3.214-4.844-6.75-11.713-6.75-14.25A6.75 6.75 0 0 1 12 1.5zM12 0a8.25 8.25 0 0 0-8.25 8.25c0 2.965 3.594 9.945 7 15.08a1.5 1.5 0 0 0 2.5 0c3.406-5.135 7-12.115 7-15.08A8.25 8.25 0 0 0 12 0z"></path></svg></span>,
#  <span class="a51f4b5adb">9e arr., Paris • 3,2 km du centre</span>,
#  <span aria-hidden="true" class="b6dc9a9e69 a637eeb339 d05b9c02a2 b8c9de5937"><svg data-rtl-flip="true" viewbox="0 0 24 24" xmlns="http://www.w3.org/2000/svg"><path d="M9.45 6c.2 0 .39.078.53.22l5 5c.208.206.323.487.32.78a1.1 1.1 0 0 1-.32.78l-5 5a.75.75 0 0 1-1.06 0 .74.74 0 0 1 0-1.06L13.64 12 8.92 7.28a.74.74 0 0 1 0-1.06.73.73 0 0 1 .53-.22zm4.47 5.72zm0 .57z"></path></svg></span>,
#  <span aria-hidden="true" class="b6dc9a9e69 adc357e4f1 fe621d6382"><svg viewbox="0 0 24 24" xmlns="http://www.w3.org/2000/svg"><path d="M23.555 8.729a1.505 1.505 0 0 0-1.406-.98h-6.087a.5.5 0 0 1-.472-.334l-2.185-6.193a1.5 1.5 0 0 0-2.81 0l-.005.016-2.18 6.177a.5.5 0 0 1-.471.334H1.85A1.5 1.5 0 0 0 .887 10.4l5.184 4.3a.5.5 0 0 1 .155.543l-2.178 6.531a1.5 1.5 0 0 0 2.31 1.684l5.346-3.92a.5.5 0 0 1 .591 0l5.344 3.919a1.5 1.5 0 0 0 2.312-1.683l-2.178-6.535a.5.5 0 0 1 .155-.543l5.194-4.306a1.5 1.5 0 0 0 .433-1.661z"></path></svg></span>,
#  <span aria-hidden="true" class="b6dc9a9e69 adc357e4f1 fe621d6382"><svg viewbox="0 0 24 24" xmlns="http://www.w3.org/2000/svg"><path d="M23.555 8.729a1.505 1.505 0 0 0-1.406-.98h-6.087a.5.5 0 0 1-.472-.334l-2.185-6.193a1.5 1.5 0 0 0-2.81 0l-.005.016-2.18 6.177a.5.5 0 0 1-.471.334H1.85A1.5 1.5 0 0 0 .887 10.4l5.184 4.3a.5.5 0 0 1 .155.543l-2.178 6.531a1.5 1.5 0 0 0 2.31 1.684l5.346-3.92a.5.5 0 0 1 .591 0l5.344 3.919a1.5 1.5 0 0 0 2.312-1.683l-2.178-6.535a.5.5 0 0 1 .155-.543l5.194-4.306a1.5 1.5 0 0 0 .433-1.661z"></path></svg></span>,
#  <span aria-hidden="true" class="b6dc9a9e69 adc357e4f1 fe621d6382"><svg viewbox="0 0 24 24" xmlns="http://www.w3.org/2000/svg"><path d="M23.555 8.729a1.505 1.505 0 0 0-1.406-.98h-6.087a.5.5 0 0 1-.472-.334l-2.185-6.193a1.5 1.5 0 0 0-2.81 0l-.005.016-2.18 6.177a.5.5 0 0 1-.471.334H1.85A1.5 1.5 0 0 0 .887 10.4l5.184 4.3a.5.5 0 0 1 .155.543l-2.178 6.531a1.5 1.5 0 0 0 2.31 1.684l5.346-3.92a.5.5 0 0 1 .591 0l5.344 3.919a1.5 1.5 0 0 0 2.312-1.683l-2.178-6.535a.5.5 0 0 1 .155-.543l5.194-4.306a1.5 1.5 0 0 0 .433-1.661z"></path></svg></span>,
#  <span aria-label="Très bien" class="d8eab2cf7f f0d4d6a2f5 e46e88563a"> <!-- -->Très bien</span>,
#  <span class="d8eab2cf7f c90c0a70d3 db63693c62"> · <!-- -->3 089 expériences vécues</span>,
#  <span aria-hidden="true" class="b6dc9a9e69 e492382468 a98180785f e25355d3ee" data-testid="icon-with-text-icon"><svg viewbox="0 0 24 24" xmlns="http://www.w3.org/2000/svg"><path d="M15 8.25a3 3 0 1 1-6 0 3 3 0 0 1 6 0zm1.5 0a4.5 4.5 0 1 0-9 0 4.5 4.5 0 0 0 9 0zM12 1.5a6.75 6.75 0 0 1 6.75 6.75c0 2.537-3.537 9.406-6.75 14.25-3.214-4.844-6.75-11.713-6.75-14.25A6.75 6.75 0 0 1 12 1.5zM12 0a8.25 8.25 0 0 0-8.25 8.25c0 2.965 3.594 9.945 7 15.08a1.5 1.5 0 0 0 2.5 0c3.406-5.135 7-12.115 7-15.08A8.25 8.25 0 0 0 12 0z"></path></svg></span>,
#  <span class="a51f4b5adb">19e arr., Paris • 4 km du centre</span>,
#  <span aria-hidden="true" class="b6dc9a9e69 e492382468 a98180785f e25355d3ee" data-testid="icon-with-text-icon"><svg viewbox="0 0 24 24" xmlns="http://www.w3.org/2000/svg"><path d="M21.22 3.37a.75.75 0 0 0-.6-.59c-4.85-.9-10.6.55-13.37 3.36S3.1 14.39 3.88 19.05L2 21a.75.75 0 0 0 0 1 .74.74 0 0 0 .53.22A.71.71 0 0 0 3 22l2-1.9a16.94 16.94 0 0 0 2.76.23c4.09 0 8.19-1.33 10.35-3.52 2.71-2.81 4.07-8.59 3.11-13.44zM17 15.75c-2.11 2.14-6.59 3.36-10.7 3L16.59 8.47a.75.75 0 0 0 0 -1.06.77.77 0 0 0-1.07 0l-10.3 10.3c-.33-3.91.91-8.31 3.1-10.52s7.29-3.63 11.52-3c.67 4.22-.54 9.22-2.84 11.56z"></path></svg></span>,
#  <span class="a51f4b5adb">Établissement Voyage Durable</span>,
#  <span aria-hidden="true" class="b6dc9a9e69 a637eeb339 d05b9c02a2 b8c9de5937"><svg data-rtl-flip="true" viewbox="0 0 24 24" xmlns="http://www.w3.org/2000/svg"><path d="M9.45 6c.2 0 .39.078.53.22l5 5c.208.206.323.487.32.78a1.1 1.1 0 0 1-.32.78l-5 5a.75.75 0 0 1-1.06 0 .74.74 0 0 1 0-1.06L13.64 12 8.92 7.28a.74.74 0 0 1 0-1.06.73.73 0 0 1 .53-.22zm4.47 5.72zm0 .57z"></path></svg></span>,
# ...
#  <span aria-label="Bien " class="d8eab2cf7f f0d4d6a2f5 e46e88563a"> <!-- -->Bien </span>,
#  <span class="d8eab2cf7f c90c0a70d3 db63693c62"> · <!-- -->1 247 expériences vécues</span>,
#  <span aria-hidden="true" class="b6dc9a9e69 e492382468 a98180785f e25355d3ee" data-testid="icon-with-text-icon"><svg viewbox="0 0 24 24" xmlns="http://www.w3.org/2000/svg"><path d="M15 8.25a3 3 0 1 1-6 0 3 3 0 0 1 6 0zm1.5 0a4.5 4.5 0 1 0-9 0 4.5 4.5 0 0 0 9 0zM12 1.5a6.75 6.75 0 0 1 6.75 6.75c0 2.537-3.537 9.406-6.75 14.25-3.214-4.844-6.75-11.713-6.75-14.25A6.75 6.75 0 0 1 12 1.5zM12 0a8.25 8.25 0 0 0-8.25 8.25c0 2.965 3.594 9.945 7 15.08a1.5 1.5 0 0 0 2.5 0c3.406-5.135 7-12.115 7-15.08A8.25 8.25 0 0 0 12 0z"></path></svg></span>,
#  <span class="a51f4b5adb">17e arr., Paris • 4,6 km du centre</span>,
#  <span aria-hidden="true" class="b6dc9a9e69 a637eeb339 d05b9c02a2 b8c9de5937"><svg data-rtl-flip="true" viewbox="0 0 24 24" xmlns="http://www.w3.org/2000/svg"><path d="M9.45 6c.2 0 .39.078.53.22l5 5c.208.206.323.487.32.78a1.1 1.1 0 0 1-.32.78l-5 5a.75.75 0 0 1-1.06 0 .74.74 0 0 1 0-1.06L13.64 12 8.92 7.28a.74.74 0 0 1 0-1.06.73.73 0 0 1 .53-.22zm4.47 5.72zm0 .57z"></path></svg></span>,
#  <span aria-hidden="true" class="b6dc9a9e69 adc357e4f1 fe621d6382"><svg viewbox="0 0 24 24" xmlns="http://www.w3.org/2000/svg"><path d="M23.555 8.729a1.505 1.505 0 0 0-1.406-.98h-6.087a.5.5 0 0 1-.472-.334l-2.185-6.193a1.5 1.5 0 0 0-2.81 0l-.005.016-2.18 6.177a.5.5 0 0 1-.471.334H1.85A1.5 1.5 0 0 0 .887 10.4l5.184 4.3a.5.5 0 0 1 .155.543l-2.178 6.531a1.5 1.5 0 0 0 2.31 1.684l5.346-3.92a.5.5 0 0 1 .591 0l5.344 3.919a1.5 1.5 0 0 0 2.312-1.683l-2.178-6.535a.5.5 0 0 1 .155-.543l5.194-4.306a1.5 1.5 0 0 0 .433-1.661z"></path></svg></span>,
#  <span aria-hidden="true" class="b6dc9a9e69 adc357e4f1 fe621d6382"><svg viewbox="0 0 24 24" xmlns="http://www.w3.org/2000/svg"><path d="M23.555 8.729a1.505 1.505 0 0 0-1.406-.98h-6.087a.5.5 0 0 1-.472-.334l-2.185-6.193a1.5 1.5 0 0 0-2.81 0l-.005.016-2.18 6.177a.5.5 0 0 1-.471.334H1.85A1.5 1.5 0 0 0 .887 10.4l5.184 4.3a.5.5 0 0 1 .155.543l-2.178 6.531a1.5 1.5 0 0 0 2.31 1.684l5.346-3.92a.5.5 0 0 1 .591 0l5.344 3.919a1.5 1.5 0 0 0 2.312-1.683l-2.178-6.535a.5.5 0 0 1 .155-.543l5.194-4.306a1.5 1.5 0 0 0 .433-1.661z"></path></svg></span>,
#  <span aria-hidden="true" class="b6dc9a9e69 adc357e4f1 fe621d6382"><svg viewbox="0 0 24 24" xmlns="http://www.w3.org/2000/svg"><path d="M23.555 8.729a1.505 1.505 0 0 0-1.406-.98h-6.087a.5.5 0 0 1-.472-.334l-2.185-6.193a1.5 1.5 0 0 0-2.81 0l-.005.016-2.18 6.177a.5.5 0 0 1-.471.334H1.85A1.5 1.5 0 0 0 .887 10.4l5.184 4.3a.5.5 0 0 1 .155.543l-2.178 6.531a1.5 1.5 0 0 0 2.31 1.684l5.346-3.92a.5.5 0 0 1 .591 0l5.344 3.919a1.5 1.5 0 0 0 2.312-1.683l-2.178-6.535a.5.5 0 0 1 .155-.543l5.194-4.306a1.5 1.5 0 0 0 .433-1.661z"></path></svg></span>,
#  <span aria-hidden="true" class="b6dc9a9e69 adc357e4f1 fe621d6382"><svg viewbox="0 0 24 24" xmlns="http://www.w3.org/2000/svg"><path d="M23.555 8.729a1.505 1.505 0 0 0-1.406-.98h-6.087a.5.5 0 0 1-.472-.334l-2.185-6.193a1.5 1.5 0 0 0-2.81 0l-.005.016-2.18 6.177a.5.5 0 0 1-.471.334H1.85A1.5 1.5 0 0 0 .887 10.4l5.184 4.3a.5.5 0 0 1 .155.543l-2.178 6.531a1.5 1.5 0 0 0 2.31 1.684l5.346-3.92a.5.5 0 0 1 .591 0l5.344 3.919a1.5 1.5 0 0 0 2.312-1.683l-2.178-6.535a.5.5 0 0 1 .155-.543l5.194-4.306a1.5 1.5 0 0 0 .433-1.661z"></path></svg></span>,
#  <span aria-label="Superbe" class="d8eab2cf7f f0d4d6a2f5 e46e88563a"> <!-- -->Superbe</span>,
#  <span class="d8eab2cf7f c90c0a70d3 db63693c62"> · <!-- -->729 expériences vécues</span>,
#  <span aria-hidden="true" class="b6dc9a9e69 e492382468 a98180785f e25355d3ee" data-testid="icon-with-text-icon"><svg viewbox="0 0 24 24" xmlns="http://www.w3.org/2000/svg"><path d="M15 8.25a3 3 0 1 1-6 0 3 3 0 0 1 6 0zm1.5 0a4.5 4.5 0 1 0-9 0 4.5 4.5 0 0 0 9 0zM12 1.5a6.75 6.75 0 0 1 6.75 6.75c0 2.537-3.537 9.406-6.75 14.25-3.214-4.844-6.75-11.713-6.75-14.25A6.75 6.75 0 0 1 12 1.5zM12 0a8.25 8.25 0 0 0-8.25 8.25c0 2.965 3.594 9.945 7 15.08a1.5 1.5 0 0 0 2.5 0c3.406-5.135 7-12.115 7-15.08A8.25 8.25 0 0 0 12 0z"></path></svg></span>,
#  <span class="a51f4b5adb">13e arr., Paris • 3,5 km du centre</span>,
#  <span aria-hidden="true" class="b6dc9a9e69 a637eeb339 d05b9c02a2 b8c9de5937"><svg data-rtl-flip="true" viewbox="0 0 24 24" xmlns="http://www.w3.org/2000/svg"><path d="M9.45 6c.2 0 .39.078.53.22l5 5c.208.206.323.487.32.78a1.1 1.1 0 0 1-.32.78l-5 5a.75.75 0 0 1-1.06 0 .74.74 0 0 1 0-1.06L13.64 12 8.92 7.28a.74.74 0 0 1 0-1.06.73.73 0 0 1 .53-.22zm4.47 5.72zm0 .57z"></path></svg></span>,
#  <span aria-hidden="true" class="b6dc9a9e69 adc357e4f1 fe621d6382"><svg viewbox="0 0 24 24" xmlns="http://www.w3.org/2000/svg"><path d="M23.555 8.729a1.505 1.505 0 0 0-1.406-.98h-6.087a.5.5 0 0 1-.472-.334l-2.185-6.193a1.5 1.5 0 0 0-2.81 0l-.005.016-2.18 6.177a.5.5 0 0 1-.471.334H1.85A1.5 1.5 0 0 0 .887 10.4l5.184 4.3a.5.5 0 0 1 .155.543l-2.178 6.531a1.5 1.5 0 0 0 2.31 1.684l5.346-3.92a.5.5 0 0 1 .591 0l5.344 3.919a1.5 1.5 0 0 0 2.312-1.683l-2.178-6.535a.5.5 0 0 1 .155-.543l5.194-4.306a1.5 1.5 0 0 0 .433-1.661z"></path></svg></span>,
#  <span aria-hidden="true" class="b6dc9a9e69 adc357e4f1 fe621d6382"><svg viewbox="0 0 24 24" xmlns="http://www.w3.org/2000/svg"><path d="M23.555 8.729a1.505 1.505 0 0 0-1.406-.98h-6.087a.5.5 0 0 1-.472-.334l-2.185-6.193a1.5 1.5 0 0 0-2.81 0l-.005.016-2.18 6.177a.5.5 0 0 1-.471.334H1.85A1.5 1.5 0 0 0 .887 10.4l5.184 4.3a.5.5 0 0 1 .155.543l-2.178 6.531a1.5 1.5 0 0 0 2.31 1.684l5.346-3.92a.5.5 0 0 1 .591 0l5.344 3.919a1.5 1.5 0 0 0 2.312-1.683l-2.178-6.535a.5.5 0 0 1 .155-.543l5.194-4.306a1.5 1.5 0 0 0 .433-1.661z"></path></svg></span>,
#  <span aria-hidden="true" class="b6dc9a9e69 adc357e4f1 fe621d6382"><svg viewbox="0 0 24 24" xmlns="http://www.w3.org/2000/svg"><path d="M23.555 8.729a1.505 1.505 0 0 0-1.406-.98h-6.087a.5.5 0 0 1-.472-.334l-2.185-6.193a1.5 1.5 0 0 0-2.81 0l-.005.016-2.18 6.177a.5.5 0 0 1-.471.334H1.85A1.5 1.5 0 0 0 .887 10.4l5.184 4.3a.5.5 0 0 1 .155.543l-2.178 6.531a1.5 1.5 0 0 0 2.31 1.684l5.346-3.92a.5.5 0 0 1 .591 0l5.344 3.919a1.5 1.5 0 0 0 2.312-1.683l-2.178-6.535a.5.5 0 0 1 .155-.543l5.194-4.306a1.5 1.5 0 0 0 .433-1.661z"></path></svg></span>,
#  <span aria-label="Très bien" class="d8eab2cf7f f0d4d6a2f5 e46e88563a"> <!-- -->Très bien</span>,
#  <span class="d8eab2cf7f c90c0a70d3 db63693c62"> · <!-- -->1 044 expériences vécues</span>,
#  <span aria-hidden="true" class="b6dc9a9e69 e492382468 a98180785f e25355d3ee" data-testid="icon-with-text-icon"><svg viewbox="0 0 24 24" xmlns="http://www.w3.org/2000/svg"><path d="M15 8.25a3 3 0 1 1-6 0 3 3 0 0 1 6 0zm1.5 0a4.5 4.5 0 1 0-9 0 4.5 4.5 0 0 0 9 0zM12 1.5a6.75 6.75 0 0 1 6.75 6.75c0 2.537-3.537 9.406-6.75 14.25-3.214-4.844-6.75-11.713-6.75-14.25A6.75 6.75 0 0 1 12 1.5zM12 0a8.25 8.25 0 0 0-8.25 8.25c0 2.965 3.594 9.945 7 15.08a1.5 1.5 0 0 0 2.5 0c3.406-5.135 7-12.115 7-15.08A8.25 8.25 0 0 0 12 0z"></path></svg></span>,
#  <span class="a51f4b5adb">20e arr., Paris • 2,9 km du centre</span>,
#  <span aria-hidden="true" class="b6dc9a9e69 a637eeb339 d05b9c02a2 b8c9de5937"><svg data-rtl-flip="true" viewbox="0 0 24 24" xmlns="http://www.w3.org/2000/svg"><path d="M9.45 6c.2 0 .39.078.53.22l5 5c.208.206.323.487.32.78a1.1 1.1 0 0 1-.32.78l-5 5a.75.75 0 0 1-1.06 0 .74.74 0 0 1 0-1.06L13.64 12 8.92 7.28a.74.74 0 0 1 0-1.06.73.73 0 0 1 .53-.22zm4.47 5.72zm0 .57z"></path></svg></span>,
#  <span aria-hidden="true" class="b6dc9a9e69 adc357e4f1 fe621d6382"><svg viewbox="0 0 24 24" xmlns="http://www.w3.org/2000/svg"><path d="M23.555 8.729a1.505 1.505 0 0 0-1.406-.98h-6.087a.5.5 0 0 1-.472-.334l-2.185-6.193a1.5 1.5 0 0 0-2.81 0l-.005.016-2.18 6.177a.5.5 0 0 1-.471.334H1.85A1.5 1.5 0 0 0 .887 10.4l5.184 4.3a.5.5 0 0 1 .155.543l-2.178 6.531a1.5 1.5 0 0 0 2.31 1.684l5.346-3.92a.5.5 0 0 1 .591 0l5.344 3.919a1.5 1.5 0 0 0 2.312-1.683l-2.178-6.535a.5.5 0 0 1 .155-.543l5.194-4.306a1.5 1.5 0 0 0 .433-1.661z"></path></svg></span>,
#  <span aria-hidden="true" class="b6dc9a9e69 adc357e4f1 fe621d6382"><svg viewbox="0 0 24 24" xmlns="http://www.w3.org/2000/svg"><path d="M23.555 8.729a1.505 1.505 0 0 0-1.406-.98h-6.087a.5.5 0 0 1-.472-.334l-2.185-6.193a1.5 1.5 0 0 0-2.81 0l-.005.016-2.18 6.177a.5.5 0 0 1-.471.334H1.85A1.5 1.5 0 0 0 .887 10.4l5.184 4.3a.5.5 0 0 1 .155.543l-2.178 6.531a1.5 1.5 0 0 0 2.31 1.684l5.346-3.92a.5.5 0 0 1 .591 0l5.344 3.919a1.5 1.5 0 0 0 2.312-1.683l-2.178-6.535a.5.5 0 0 1 .155-.543l5.194-4.306a1.5 1.5 0 0 0 .433-1.661z"></path></svg></span>,
#  <span aria-hidden="true" class="b6dc9a9e69 adc357e4f1 fe621d6382"><svg viewbox="0 0 24 24" xmlns="http://www.w3.org/2000/svg"><path d="M23.555 8.729a1.505 1.505 0 0 0-1.406-.98h-6.087a.5.5 0 0 1-.472-.334l-2.185-6.193a1.5 1.5 0 0 0-2.81 0l-.005.016-2.18 6.177a.5.5 0 0 1-.471.334H1.85A1.5 1.5 0 0 0 .887 10.4l5.184 4.3a.5.5 0 0 1 .155.543l-2.178 6.531a1.5 1.5 0 0 0 2.31 1.684l5.346-3.92a.5.5 0 0 1 .591 0l5.344 3.919a1.5 1.5 0 0 0 2.312-1.683l-2.178-6.535a.5.5 0 0 1 .155-.543l5.194-4.306a1.5 1.5 0 0 0 .433-1.661z"></path></svg></span>,
#  <span aria-label="Très bien" class="d8eab2cf7f f0d4d6a2f5 e46e88563a"> <!-- -->Très bien</span>,
#  <span class="d8eab2cf7f c90c0a70d3 db63693c62"> · <!-- -->2 142 expériences vécues</span>,
#  <span aria-hidden="true" class="b6dc9a9e69 e492382468 a98180785f e25355d3ee" data-testid="icon-with-text-icon"><svg viewbox="0 0 24 24" xmlns="http://www.w3.org/2000/svg"><path d="M15 8.25a3 3 0 1 1-6 0 3 3 0 0 1 6 0zm1.5 0a4.5 4.5 0 1 0-9 0 4.5 4.5 0 0 0 9 0zM12 1.5a6.75 6.75 0 0 1 6.75 6.75c0 2.537-3.537 9.406-6.75 14.25-3.214-4.844-6.75-11.713-6.75-14.25A6.75 6.75 0 0 1 12 1.5zM12 0a8.25 8.25 0 0 0-8.25 8.25c0 2.965 3.594 9.945 7 15.08a1.5 1.5 0 0 0 2.5 0c3.406-5.135 7-12.115 7-15.08A8.25 8.25 0 0 0 12 0z"></path></svg></span>,
#  <span class="a51f4b5adb">14e arr., Paris • 4 km du centre</span>,
#  <span class="e57ffa4eb5">Suivant</span>,
#  <span class="b9def0936d aff03b959f"><span aria-hidden="true" class="b6dc9a9e69 e6c50852bd"><svg data-rtl-flip="true" viewbox="0 0 24 24" xmlns="http://www.w3.org/2000/svg"><path d="M9.45 6c.2 0 .39.078.53.22l5 5c.208.206.323.487.32.78a1.1 1.1 0 0 1-.32.78l-5 5a.75.75 0 0 1-1.06 0 .74.74 0 0 1 0-1.06L13.64 12 8.92 7.28a.74.74 0 0 1 0-1.06.73.73 0 0 1 .53-.22zm4.47 5.72zm0 .57z"></path></svg></span></span>,
#  <span aria-hidden="true" class="b6dc9a9e69 e6c50852bd"><svg data-rtl-flip="true" viewbox="0 0 24 24" xmlns="http://www.w3.org/2000/svg"><path d="M9.45 6c.2 0 .39.078.53.22l5 5c.208.206.323.487.32.78a1.1 1.1 0 0 1-.32.78l-5 5a.75.75 0 0 1-1.06 0 .74.74 0 0 1 0-1.06L13.64 12 8.92 7.28a.74.74 0 0 1 0-1.06.73.73 0 0 1 .53-.22zm4.47 5.72zm0 .57z"></path></svg></span>,
#  <span class="bui-u-sr-only" id="tabbed_nav_search_description">Destination, établissement ou même une adresse</span>,
#  <span aria-hidden="true" class="b6dc9a9e69 ec1b6253a6 f86806591e"><svg height="1em" viewbox="0 0 128 128" width="1em"><path d="M118.8 113.2l-31-31A4 4 0 0 0 85 81a44 44 0 1 0-4 4 4 4 0 0 0 1.2 2.8l31 31a4 4 0 0 0 5.6-5.7zM52 88a36 36 0 1 1 36-36 36 36 0 0 1-36 36z"></path></svg></span>,
#  <span aria-hidden="true" class="b6dc9a9e69 e25355d3ee" data-testid="input-clear"><svg height="1em" viewbox="0 0 128 128" width="1em"><path d="M69.7 64l33.1-33.2a4 4 0 0 0-5.6-5.6L64 58.3 30.8 25.2a4 4 0 1 0-5.6 5.6L58.3 64 25.2 97.2a4 4 0 1 0 5.6 5.6L64 69.7l33.2 33.1a4 4 0 0 0 5.6-5.6z"></path></svg></span>,
#  <span><span class="ee746850b6">Adultes</span></span>,
#  <span class="ee746850b6">Adultes</span>,
#  <span class="df5494c6c7"><span aria-hidden="true" class="b6dc9a9e69 c42ce17094 e6c50852bd f86806591e"><svg viewbox="0 0 24 24" xmlns="http://www.w3.org/2000/svg"><path d="M18 9.45c0 .2-.078.39-.22.53l-5 5a1.08 1.08 0 0 1-.78.32 1.1 1.1 0 0 1-.78-.32l-5-5a.75.75 0 0 1 0-1.06.74.74 0 0 1 1.06 0L12 13.64l4.72-4.72a.74.74 0 0 1 1.06 0 .73.73 0 0 1 .22.53zm-5.72 4.47zm-.57 0z"></path></svg></span></span>,
#  <span aria-hidden="true" class="b6dc9a9e69 c42ce17094 e6c50852bd f86806591e"><svg viewbox="0 0 24 24" xmlns="http://www.w3.org/2000/svg"><path d="M18 9.45c0 .2-.078.39-.22.53l-5 5a1.08 1.08 0 0 1-.78.32 1.1 1.1 0 0 1-.78-.32l-5-5a.75.75 0 0 1 0-1.06.74.74 0 0 1 1.06 0L12 13.64l4.72-4.72a.74.74 0 0 1 1.06 0 .73.73 0 0 1 .22.53zm-5.72 4.47zm-.57 0z"></path></svg></span>,
#  <span><span class="ee746850b6">Enfants</span></span>,
#  <span class="ee746850b6">Enfants</span>,
#  <span class="df5494c6c7"><span aria-hidden="true" class="b6dc9a9e69 c42ce17094 e6c50852bd f86806591e"><svg viewbox="0 0 24 24" xmlns="http://www.w3.org/2000/svg"><path d="M18 9.45c0 .2-.078.39-.22.53l-5 5a1.08 1.08 0 0 1-.78.32 1.1 1.1 0 0 1-.78-.32l-5-5a.75.75 0 0 1 0-1.06.74.74 0 0 1 1.06 0L12 13.64l4.72-4.72a.74.74 0 0 1 1.06 0 .73.73 0 0 1 .22.53zm-5.72 4.47zm-.57 0z"></path></svg></span></span>,
#  <span aria-hidden="true" class="b6dc9a9e69 c42ce17094 e6c50852bd f86806591e"><svg viewbox="0 0 24 24" xmlns="http://www.w3.org/2000/svg"><path d="M18 9.45c0 .2-.078.39-.22.53l-5 5a1.08 1.08 0 0 1-.78.32 1.1 1.1 0 0 1-.78-.32l-5-5a.75.75 0 0 1 0-1.06.74.74 0 0 1 1.06 0L12 13.64l4.72-4.72a.74.74 0 0 1 1.06 0 .73.73 0 0 1 .22.53zm-5.72 4.47zm-.57 0z"></path></svg></span>,
#  <span><span class="ee746850b6">Chambres</span></span>,
#  <span class="ee746850b6">Chambres</span>,
#  <span class="df5494c6c7"><span aria-hidden="true" class="b6dc9a9e69 c42ce17094 e6c50852bd f86806591e"><svg viewbox="0 0 24 24" xmlns="http://www.w3.org/2000/svg"><path d="M18 9.45c0 .2-.078.39-.22.53l-5 5a1.08 1.08 0 0 1-.78.32 1.1 1.1 0 0 1-.78-.32l-5-5a.75.75 0 0 1 0-1.06.74.74 0 0 1 1.06 0L12 13.64l4.72-4.72a.74.74 0 0 1 1.06 0 .73.73 0 0 1 .22.53zm-5.72 4.47zm-.57 0z"></path></svg></span></span>,
#  <span aria-hidden="true" class="b6dc9a9e69 c42ce17094 e6c50852bd f86806591e"><svg viewbox="0 0 24 24" xmlns="http://www.w3.org/2000/svg"><path d="M18 9.45c0 .2-.078.39-.22.53l-5 5a1.08 1.08 0 0 1-.78.32 1.1 1.1 0 0 1-.78-.32l-5-5a.75.75 0 0 1 0-1.06.74.74 0 0 1 1.06 0L12 13.64l4.72-4.72a.74.74 0 0 1 1.06 0 .73.73 0 0 1 .22.53zm-5.72 4.47zm-.57 0z"></path></svg></span>,
#  <span aria-hidden="true" class="b6dc9a9e69 aa4de547ee e25355d3ee f86806591e"><svg height="1em" viewbox="0 0 128 128" width="1em"><path d="M64 8a56 56 0 1 0 56 56A56 56 0 0 0 64 8zm0 100a8 8 0 1 1 8-8 8 8 0 0 1-8 8zm18.4-39.6A32.6 32.6 0 0 1 74 74l-2 1.1V82a2 2 0 0 1-2 2H58a2 2 0 0 1-2-2v-8.8c0-7.8 6.7-11.3 10.7-13.4a20.5 20.5 0 0 0 4.4-2.7 10 10 0 1 0-15-13.2 10.3 10.3 0 0 0-2.1 6.4V54a2 2 0 0 1-2 2H40a2 2 0 0 1-2-2v-3.5a26.7 26.7 0 0 1 6.9-18.1 26 26 0 0 1 22.6-8.2 25.5 25.5 0 0 1 12.2 5 26 26 0 0 1 2.7 39.2z"></path></svg></span>,
#  <span class="ba0052c122"></span>,
#  <span class="e50b5c7936"></span>,
#  <span class="fcb404aeaf"><div class="db29ecfbe2 f0d4d6a2f5"><div class="ac78a73c96">Oui</div></div></span>,
#  <span class="ba0052c122"></span>,
#  <span class="e50b5c7936"></span>,
#  <span class="fcb404aeaf"><div class="db29ecfbe2 f0d4d6a2f5"><div class="ac78a73c96">Non</div></div></span>,
#  <span class="e57ffa4eb5">Rechercher</span>,
#  <span class="bui-banner__icon">
#  <svg class="bk-icon -streamline-person_half" height="24" width="24"><use xlink:href="#icon-streamline-person_half"></use></svg>
#  </span>,
#  <span class="bui-button__text">Se connecter</span>,
#  <span class="bui-button__icon">
#  <svg class="bk-icon -iconset-update" height="16" width="16"><use xlink:href="#icon-iconset-update"></use></svg>
#  </span>,
#  <span class="bui-button__text">Recommencer</span>,
#  <span class="bui-u-sr-only" id="tabbed_nav_menu_description">, PROFIL, </span>,
#  <span class="u-sr-only">Note de 4.5 étoiles sur 5 </span>,
#  <span class="bui-button__text">
#  Installer
#  </span>,
#  <span class="bui-button__text">
#  Ajoutez votre établissement
#  </span>,
#  <span>Chargement...</span>,
#  <span id="req_info" style="display:none;">1625600,1655430|2,1655430|1,1655430</span>]

# %%
[element.get_text().replace('\n','') for element in soup.find_all('a["data-atlas-latlng"]', attrs={'id': 'hotel_header'})]
# Out:
# []

# %%
adresse_hotel = soup.find_all("a")[0].get_text().replace('\n','')
adresse_hotel
# Out:
# 'Installer'

# %%
soup.select("a")
# Out:
# [<a class="gta-header-banner__btn" href="https://www.booking.com/apps.fr.html?label=gen173nr-1FCAQoggJCDHNlYXJjaF9wYXJpc0gNWARoTYgBApgBDbgBCcgBEdgBAegBAfgBA4gCAagCA7gCubHynQbAAgHSAiQxYzE0ZWFiYy1iZTk3LTRmYjUtOTU3Yi1iYmY4MTViNjRmYjnYAgXgAgE&amp;amp;sid=90b13d9acb07cfbe92c13567b44289eb&amp;amp;srpvid=8c9d9fdcb1f2011f&amp;amp;&amp;amp;app_install=1&amp;amp;lang=fr&amp;amp;site=mdot&amp;amp;page=searchresults&amp;amp;placement=GeneralHeaderNew&amp;amp;device=direct&amp;amp;etseed=52616e646f6d49562473646523287d61e9b10a5ec037a5b8e3418bd1b5132103955b3cfc17b3c03a0ebdb97a5fb23460eb563aaf44f402ba702d2cab53c2e5e8&amp;amp;hoff=sr&amp;amp;dest_countrycode=fr&amp;amp;dest_id=-1456928&amp;amp;dest_type=city&amp;amp;room1=A,A" target="_blank">
#  Installer
#  </a>,
#  <a aria-label="Booking.com réservations d'hébergements en ligne" data-et-click="
#  customGoal:YTTHbXNLPVIRPQHUYJWcRQFdLHe:2
#  customGoal:YTBUIHOdVLBQRMebfTINfTKe:2
#  YTBUIHOdVLBLKAMZUC:1
#  YTBUIHOdVLBLKAMZUC:3
#  " href="https://www.booking.com/index.fr.html?label=gen173nr-1FCAQoggJCDHNlYXJjaF9wYXJpc0gNWARoTYgBApgBDbgBCcgBEdgBAegBAfgBA4gCAagCA7gCubHynQbAAgHSAiQxYzE0ZWFiYy1iZTk3LTRmYjUtOTU3Yi1iYmY4MTViNjRmYjnYAgXgAgE&amp;sid=90b13d9acb07cfbe92c13567b44289eb&amp;srpvid=8c9d9fdcb1f2011f&amp;">
#  <svg class="bk-icon -streamline-booking_logo_dark_bg_mono" height="20" width="120"><use xlink:href="#icon-streamline-booking_logo_dark_bg_mono"></use></svg>
#  </a>,
#  <a aria-label="Retour" class="bui-button bui-button--light bui-traveller-header__back-dynamic js-site-header--back">
#  <span aria-hidden="true" class="bui-button__icon bui-icon bui-icon--larger">
#  <svg class="bk-icon -streamline-arrow_nav_left" height="24" width="24"><use xlink:href="#icon-streamline-arrow_nav_left"></use></svg>
#  </span>
#  </a>,
#  <a aria-label="Se connecter" class="bui-button bui-traveller-header__profile bui-button--light bui-button--large js-header-login-link js-header-signin-notification" data-et-click="
#  customGoal:YTTHbXNLPVIRPQHUYJWcRQFdLHe:3
#  customGoal:YTBUIHOdVLBQRMebfTINfTKe:3
#  " data-track-event="header_profile_btn" href="https://account.booking.com/auth/oauth2?redirect_uri=https%3A%2F%2Fsecure.booking.com%2Flogin.html%3Fop%3Doauth_return&amp;client_id=vO1Kblk7xX9tUn2cpZLS&amp;aid=304142&amp;dt=1673304249&amp;bkng_action=searchresults&amp;state=UuIBogA4v8XA-1xuHjeHvRnEj98-PQwnSz7VDCpJ0gK0MHV0cfaYZSAFk18OWdzaHeIdPRD5SKY_Yv3wtCrKBY9KUpkiPOZDLQ0EqbgfMAsCM4yJcVUUeh8mymM5ssAXKRE_kvsEl8UivHcV-cQPNH48jS7mmelNlCdb4RP069iM82ToB-ZsO4hpGCLaRKspfvIwHk4iplBz6PuVWipQnS2q8PfCV_0wYYkP7C3IGDAqoVtb6d72aOLLiyaNIVF6EKX-bZ7ITRbLXHt2ISnWP0pvamcvINFzrqxTyUmjMRzrYA9OJQ&amp;lang=fr&amp;response_type=code" type="button">
#  <span class="bui-button__icon bui-bubble-container">
#  <span aria-hidden="true" class="bui-icon bui-icon--large">
#  <svg class="bk-icon -streamline-account_user" height="24" width="24"><use xlink:href="#icon-streamline-account_user"></use></svg>
#  </span>
#  <span class="bui-bubble bui-bubble-container__value bui-bubble--destructive bui-u-hidden js-bui-traveller-header__profile-icon"></span>
#  </span>
#  </a>,
#  <a class="fc63351294 a168c6f285 cd6351bb3b a25b1d9e47" href="https://www.booking.com/content/how_we_work.html?aid=304142&amp;label=gen173nr-1FCAQoggJCDHNlYXJjaF9wYXJpc0gNWARoTYgBApgBDbgBCcgBEdgBAegBAfgBA4gCAagCA7gCubHynQbAAgHSAiQxYzE0ZWFiYy1iZTk3LTRmYjUtOTU3Yi1iYmY4MTViNjRmYjnYAgXgAgE#nov2021_how_we_work_accommodations_ranking_subheading" target="_blank"><span>En savoir plus.</span></a>,
#  <a class="f348c1e3be" data-testid="title" href="https://www.booking.com/hotel/fr/ucpa-sport-station-hostel-paris.fr.html?aid=304142&amp;label=gen173nr-1FCAQoggJCDHNlYXJjaF9wYXJpc0gNWARoTYgBApgBDbgBCcgBEdgBAegBAfgBA4gCAagCA7gCubHynQbAAgHSAiQxYzE0ZWFiYy1iZTk3LTRmYjUtOTU3Yi1iYmY4MTViNjRmYjnYAgXgAgE&amp;ucfs=1&amp;arphpl=1&amp;group_adults=2&amp;req_adults=2&amp;no_rooms=1&amp;group_children=0&amp;req_children=0&amp;hpos=1&amp;hapos=1&amp;sr_order=popularity&amp;srpvid=8c9d9fdcb1f2011f&amp;srepoch=1673304250&amp;from_sustainable_property_sr=1"><div class="b3d1cacd40"><h2 class="f9afbb0024 f0d4d6a2f5 fda3b74d0d">UCPA SPORT STATION HOSTEL PARIS</h2></div></a>,
#  <a class="f348c1e3be" data-testid="title" href="https://www.booking.com/hotel/fr/emeraude-louvre-montana.fr.html?aid=304142&amp;label=gen173nr-1FCAQoggJCDHNlYXJjaF9wYXJpc0gNWARoTYgBApgBDbgBCcgBEdgBAegBAfgBA4gCAagCA7gCubHynQbAAgHSAiQxYzE0ZWFiYy1iZTk3LTRmYjUtOTU3Yi1iYmY4MTViNjRmYjnYAgXgAgE&amp;ucfs=1&amp;arphpl=1&amp;group_adults=2&amp;req_adults=2&amp;no_rooms=1&amp;group_children=0&amp;req_children=0&amp;hpos=2&amp;hapos=2&amp;sr_order=popularity&amp;srpvid=8c9d9fdcb1f2011f&amp;srepoch=1673304250"><div class="b3d1cacd40"><h2 class="f9afbb0024 f0d4d6a2f5 fda3b74d0d">Hotel Louvre Montana</h2></div></a>,
#  <a class="f348c1e3be" data-testid="title" href="https://www.booking.com/hotel/fr/america.fr.html?aid=304142&amp;label=gen173nr-1FCAQoggJCDHNlYXJjaF9wYXJpc0gNWARoTYgBApgBDbgBCcgBEdgBAegBAfgBA4gCAagCA7gCubHynQbAAgHSAiQxYzE0ZWFiYy1iZTk3LTRmYjUtOTU3Yi1iYmY4MTViNjRmYjnYAgXgAgE&amp;ucfs=1&amp;arphpl=1&amp;group_adults=2&amp;req_adults=2&amp;no_rooms=1&amp;group_children=0&amp;req_children=0&amp;hpos=3&amp;hapos=3&amp;sr_order=popularity&amp;srpvid=8c9d9fdcb1f2011f&amp;srepoch=1673304250&amp;from_sustainable_property_sr=1"><div class="b3d1cacd40"><h2 class="f9afbb0024 f0d4d6a2f5 fda3b74d0d">Hotel Elysees Opera</h2></div></a>,
#  <a class="f348c1e3be" data-testid="title" href="https://www.booking.com/hotel/fr/d-amiens.fr.html?aid=304142&amp;label=gen173nr-1FCAQoggJCDHNlYXJjaF9wYXJpc0gNWARoTYgBApgBDbgBCcgBEdgBAegBAfgBA4gCAagCA7gCubHynQbAAgHSAiQxYzE0ZWFiYy1iZTk3LTRmYjUtOTU3Yi1iYmY4MTViNjRmYjnYAgXgAgE&amp;ucfs=1&amp;arphpl=1&amp;group_adults=2&amp;req_adults=2&amp;no_rooms=1&amp;group_children=0&amp;req_children=0&amp;hpos=4&amp;hapos=4&amp;sr_order=popularity&amp;srpvid=8c9d9fdcb1f2011f&amp;srepoch=1673304250&amp;from_sustainable_property_sr=1"><div class="b3d1cacd40"><h2 class="f9afbb0024 f0d4d6a2f5 fda3b74d0d">Hotel d'Amiens</h2></div></a>,
#  <a class="f348c1e3be" data-testid="title" href="https://www.booking.com/hotel/fr/grand-amelot-paris4.fr.html?aid=304142&amp;label=gen173nr-1FCAQoggJCDHNlYXJjaF9wYXJpc0gNWARoTYgBApgBDbgBCcgBEdgBAegBAfgBA4gCAagCA7gCubHynQbAAgHSAiQxYzE0ZWFiYy1iZTk3LTRmYjUtOTU3Yi1iYmY4MTViNjRmYjnYAgXgAgE&amp;ucfs=1&amp;arphpl=1&amp;group_adults=2&amp;req_adults=2&amp;no_rooms=1&amp;group_children=0&amp;req_children=0&amp;hpos=5&amp;hapos=5&amp;sr_order=popularity&amp;srpvid=8c9d9fdcb1f2011f&amp;srepoch=1673304250&amp;from_sustainable_property_sr=1"><div class="b3d1cacd40"><h2 class="f9afbb0024 f0d4d6a2f5 fda3b74d0d">Grand Hôtel Amelot</h2></div></a>,
#  <a class="f348c1e3be" data-testid="title" href="https://www.booking.com/hotel/fr/motel-one-paris-porte-doree.fr.html?aid=304142&amp;label=gen173nr-1FCAQoggJCDHNlYXJjaF9wYXJpc0gNWARoTYgBApgBDbgBCcgBEdgBAegBAfgBA4gCAagCA7gCubHynQbAAgHSAiQxYzE0ZWFiYy1iZTk3LTRmYjUtOTU3Yi1iYmY4MTViNjRmYjnYAgXgAgE&amp;ucfs=1&amp;arphpl=1&amp;group_adults=2&amp;req_adults=2&amp;no_rooms=1&amp;group_children=0&amp;req_children=0&amp;hpos=6&amp;hapos=6&amp;sr_order=popularity&amp;srpvid=8c9d9fdcb1f2011f&amp;srepoch=1673304250&amp;from_sustainable_property_sr=1"><div class="b3d1cacd40"><h2 class="f9afbb0024 f0d4d6a2f5 fda3b74d0d">Motel One Paris-Porte Dorée</h2></div></a>,
#  <a class="f348c1e3be" data-testid="title" href="https://www.booking.com/hotel/fr/ra-c-sidence-cisp-kellermann.fr.html?aid=304142&amp;label=gen173nr-1FCAQoggJCDHNlYXJjaF9wYXJpc0gNWARoTYgBApgBDbgBCcgBEdgBAegBAfgBA4gCAagCA7gCubHynQbAAgHSAiQxYzE0ZWFiYy1iZTk3LTRmYjUtOTU3Yi1iYmY4MTViNjRmYjnYAgXgAgE&amp;ucfs=1&amp;arphpl=1&amp;group_adults=2&amp;req_adults=2&amp;no_rooms=1&amp;group_children=0&amp;req_children=0&amp;hpos=7&amp;hapos=7&amp;sr_order=popularity&amp;srpvid=8c9d9fdcb1f2011f&amp;srepoch=1673304250"><div class="b3d1cacd40"><h2 class="f9afbb0024 f0d4d6a2f5 fda3b74d0d">Hotel CIS Paris Kellermann</h2></div></a>,
#  <a class="f348c1e3be" data-testid="title" href="https://www.booking.com/hotel/fr/austin-s-saint-lazare.fr.html?aid=304142&amp;label=gen173nr-1FCAQoggJCDHNlYXJjaF9wYXJpc0gNWARoTYgBApgBDbgBCcgBEdgBAegBAfgBA4gCAagCA7gCubHynQbAAgHSAiQxYzE0ZWFiYy1iZTk3LTRmYjUtOTU3Yi1iYmY4MTViNjRmYjnYAgXgAgE&amp;ucfs=1&amp;arphpl=1&amp;group_adults=2&amp;req_adults=2&amp;no_rooms=1&amp;group_children=0&amp;req_children=0&amp;hpos=8&amp;hapos=8&amp;sr_order=popularity&amp;srpvid=8c9d9fdcb1f2011f&amp;srepoch=1673304250&amp;from_sustainable_property_sr=1"><div class="b3d1cacd40"><h2 class="f9afbb0024 f0d4d6a2f5 fda3b74d0d">Austin's Saint Lazare Hotel</h2></div></a>,
#  <a class="f348c1e3be" data-testid="title" href="https://www.booking.com/hotel/fr/de-l-39-esperance.fr.html?aid=304142&amp;label=gen173nr-1FCAQoggJCDHNlYXJjaF9wYXJpc0gNWARoTYgBApgBDbgBCcgBEdgBAegBAfgBA4gCAagCA7gCubHynQbAAgHSAiQxYzE0ZWFiYy1iZTk3LTRmYjUtOTU3Yi1iYmY4MTViNjRmYjnYAgXgAgE&amp;ucfs=1&amp;arphpl=1&amp;group_adults=2&amp;req_adults=2&amp;no_rooms=1&amp;group_children=0&amp;req_children=0&amp;hpos=9&amp;hapos=9&amp;sr_order=popularity&amp;srpvid=8c9d9fdcb1f2011f&amp;srepoch=1673304250"><div class="b3d1cacd40"><h2 class="f9afbb0024 f0d4d6a2f5 fda3b74d0d">Hotel de L'Esperance</h2></div></a>,
#  <a class="f348c1e3be" data-testid="title" href="https://www.booking.com/hotel/fr/austin-s-arts-et-metiers.fr.html?aid=304142&amp;label=gen173nr-1FCAQoggJCDHNlYXJjaF9wYXJpc0gNWARoTYgBApgBDbgBCcgBEdgBAegBAfgBA4gCAagCA7gCubHynQbAAgHSAiQxYzE0ZWFiYy1iZTk3LTRmYjUtOTU3Yi1iYmY4MTViNjRmYjnYAgXgAgE&amp;ucfs=1&amp;arphpl=1&amp;group_adults=2&amp;req_adults=2&amp;no_rooms=1&amp;group_children=0&amp;req_children=0&amp;hpos=10&amp;hapos=10&amp;sr_order=popularity&amp;srpvid=8c9d9fdcb1f2011f&amp;srepoch=1673304250&amp;from_sustainable_property_sr=1"><div class="b3d1cacd40"><h2 class="f9afbb0024 f0d4d6a2f5 fda3b74d0d">Austin's Arts Et Metiers Hotel</h2></div></a>,
#  <a class="f348c1e3be" data-testid="title" href="https://www.booking.com/hotel/fr/hotelpavillonmonceau.fr.html?aid=304142&amp;label=gen173nr-1FCAQoggJCDHNlYXJjaF9wYXJpc0gNWARoTYgBApgBDbgBCcgBEdgBAegBAfgBA4gCAagCA7gCubHynQbAAgHSAiQxYzE0ZWFiYy1iZTk3LTRmYjUtOTU3Yi1iYmY4MTViNjRmYjnYAgXgAgE&amp;ucfs=1&amp;arphpl=1&amp;group_adults=2&amp;req_adults=2&amp;no_rooms=1&amp;group_children=0&amp;req_children=0&amp;hpos=11&amp;hapos=11&amp;sr_order=popularity&amp;srpvid=8c9d9fdcb1f2011f&amp;srepoch=1673304250"><div class="b3d1cacd40"><h2 class="f9afbb0024 f0d4d6a2f5 fda3b74d0d">Pavillon Monceau</h2></div></a>,
#  <a class="f348c1e3be" data-testid="title" href="https://www.booking.com/hotel/fr/secret-de-paris-design-boutique.fr.html?aid=304142&amp;label=gen173nr-1FCAQoggJCDHNlYXJjaF9wYXJpc0gNWARoTYgBApgBDbgBCcgBEdgBAegBAfgBA4gCAagCA7gCubHynQbAAgHSAiQxYzE0ZWFiYy1iZTk3LTRmYjUtOTU3Yi1iYmY4MTViNjRmYjnYAgXgAgE&amp;ucfs=1&amp;arphpl=1&amp;group_adults=2&amp;req_adults=2&amp;no_rooms=1&amp;group_children=0&amp;req_children=0&amp;hpos=12&amp;hapos=12&amp;sr_order=popularity&amp;srpvid=8c9d9fdcb1f2011f&amp;srepoch=1673304250"><div class="b3d1cacd40"><h2 class="f9afbb0024 f0d4d6a2f5 fda3b74d0d">Secret de Paris - Hotel &amp; Spa</h2></div></a>,
#  <a class="f348c1e3be" data-testid="title" href="https://www.booking.com/hotel/fr/holiday-inn-express-paris-canal-de-la-villette.fr.html?aid=304142&amp;label=gen173nr-1FCAQoggJCDHNlYXJjaF9wYXJpc0gNWARoTYgBApgBDbgBCcgBEdgBAegBAfgBA4gCAagCA7gCubHynQbAAgHSAiQxYzE0ZWFiYy1iZTk3LTRmYjUtOTU3Yi1iYmY4MTViNjRmYjnYAgXgAgE&amp;ucfs=1&amp;arphpl=1&amp;group_adults=2&amp;req_adults=2&amp;no_rooms=1&amp;group_children=0&amp;req_children=0&amp;hpos=13&amp;hapos=13&amp;sr_order=popularity&amp;srpvid=8c9d9fdcb1f2011f&amp;srepoch=1673304250&amp;from_sustainable_property_sr=1"><div class="b3d1cacd40"><h2 class="f9afbb0024 f0d4d6a2f5 fda3b74d0d">Holiday Inn Express Paris-Canal De La Villette, an IHG Hotel</h2></div></a>,
#  <a class="f348c1e3be" data-testid="title" href="https://www.booking.com/hotel/fr/le-villiers.fr.html?aid=304142&amp;label=gen173nr-1FCAQoggJCDHNlYXJjaF9wYXJpc0gNWARoTYgBApgBDbgBCcgBEdgBAegBAfgBA4gCAagCA7gCubHynQbAAgHSAiQxYzE0ZWFiYy1iZTk3LTRmYjUtOTU3Yi1iYmY4MTViNjRmYjnYAgXgAgE&amp;ucfs=1&amp;arphpl=1&amp;group_adults=2&amp;req_adults=2&amp;no_rooms=1&amp;group_children=0&amp;req_children=0&amp;hpos=14&amp;hapos=14&amp;sr_order=popularity&amp;srpvid=8c9d9fdcb1f2011f&amp;srepoch=1673304250&amp;from_sustainable_property_sr=1"><div class="b3d1cacd40"><h2 class="f9afbb0024 f0d4d6a2f5 fda3b74d0d">Hôtel Korner Etoile</h2></div></a>,
#  <a class="f348c1e3be" data-testid="title" href="https://www.booking.com/hotel/fr/meininger-paris-porte-de-vincennes.fr.html?aid=304142&amp;label=gen173nr-1FCAQoggJCDHNlYXJjaF9wYXJpc0gNWARoTYgBApgBDbgBCcgBEdgBAegBAfgBA4gCAagCA7gCubHynQbAAgHSAiQxYzE0ZWFiYy1iZTk3LTRmYjUtOTU3Yi1iYmY4MTViNjRmYjnYAgXgAgE&amp;ucfs=1&amp;arphpl=1&amp;group_adults=2&amp;req_adults=2&amp;no_rooms=1&amp;group_children=0&amp;req_children=0&amp;hpos=15&amp;hapos=15&amp;sr_order=popularity&amp;srpvid=8c9d9fdcb1f2011f&amp;srepoch=1673304250&amp;from_sustainable_property_sr=1"><div class="b3d1cacd40"><h2 class="f9afbb0024 f0d4d6a2f5 fda3b74d0d">MEININGER Hotel Paris Porte de Vincennes</h2></div></a>,
#  <a class="f348c1e3be" data-testid="title" href="https://www.booking.com/hotel/fr/beauchamps.fr.html?aid=304142&amp;label=gen173nr-1FCAQoggJCDHNlYXJjaF9wYXJpc0gNWARoTYgBApgBDbgBCcgBEdgBAegBAfgBA4gCAagCA7gCubHynQbAAgHSAiQxYzE0ZWFiYy1iZTk3LTRmYjUtOTU3Yi1iYmY4MTViNjRmYjnYAgXgAgE&amp;ucfs=1&amp;arphpl=1&amp;group_adults=2&amp;req_adults=2&amp;no_rooms=1&amp;group_children=0&amp;req_children=0&amp;hpos=16&amp;hapos=16&amp;sr_order=popularity&amp;srpvid=8c9d9fdcb1f2011f&amp;srepoch=1673304250&amp;from_sustainable_property_sr=1"><div class="b3d1cacd40"><h2 class="f9afbb0024 f0d4d6a2f5 fda3b74d0d">Hôtel Beauchamps</h2></div></a>,
#  <a class="f348c1e3be" data-testid="title" href="https://www.booking.com/hotel/fr/hotel-elysees-paris-france.fr.html?aid=304142&amp;label=gen173nr-1FCAQoggJCDHNlYXJjaF9wYXJpc0gNWARoTYgBApgBDbgBCcgBEdgBAegBAfgBA4gCAagCA7gCubHynQbAAgHSAiQxYzE0ZWFiYy1iZTk3LTRmYjUtOTU3Yi1iYmY4MTViNjRmYjnYAgXgAgE&amp;ucfs=1&amp;arphpl=1&amp;group_adults=2&amp;req_adults=2&amp;no_rooms=1&amp;group_children=0&amp;req_children=0&amp;hpos=17&amp;hapos=17&amp;sr_order=popularity&amp;srpvid=8c9d9fdcb1f2011f&amp;srepoch=1673304250"><div class="b3d1cacd40"><h2 class="f9afbb0024 f0d4d6a2f5 fda3b74d0d">Hôtel Elysées Paris</h2></div></a>,
#  <a class="f348c1e3be" data-testid="title" href="https://www.booking.com/hotel/fr/b55-paris12.fr.html?aid=304142&amp;label=gen173nr-1FCAQoggJCDHNlYXJjaF9wYXJpc0gNWARoTYgBApgBDbgBCcgBEdgBAegBAfgBA4gCAagCA7gCubHynQbAAgHSAiQxYzE0ZWFiYy1iZTk3LTRmYjUtOTU3Yi1iYmY4MTViNjRmYjnYAgXgAgE&amp;ucfs=1&amp;arphpl=1&amp;group_adults=2&amp;req_adults=2&amp;no_rooms=1&amp;group_children=0&amp;req_children=0&amp;hpos=18&amp;hapos=18&amp;sr_order=popularity&amp;srpvid=8c9d9fdcb1f2011f&amp;srepoch=1673304250"><div class="b3d1cacd40"><h2 class="f9afbb0024 f0d4d6a2f5 fda3b74d0d">Hôtel B55</h2></div></a>,
#  <a class="f348c1e3be" data-testid="title" href="https://www.booking.com/hotel/fr/scarlett.fr.html?aid=304142&amp;label=gen173nr-1FCAQoggJCDHNlYXJjaF9wYXJpc0gNWARoTYgBApgBDbgBCcgBEdgBAegBAfgBA4gCAagCA7gCubHynQbAAgHSAiQxYzE0ZWFiYy1iZTk3LTRmYjUtOTU3Yi1iYmY4MTViNjRmYjnYAgXgAgE&amp;ucfs=1&amp;arphpl=1&amp;group_adults=2&amp;req_adults=2&amp;no_rooms=1&amp;group_children=0&amp;req_children=0&amp;hpos=19&amp;hapos=19&amp;sr_order=popularity&amp;srpvid=8c9d9fdcb1f2011f&amp;srepoch=1673304250"><div class="b3d1cacd40"><h2 class="f9afbb0024 f0d4d6a2f5 fda3b74d0d">Hotel Scarlett</h2></div></a>,
#  <a class="f348c1e3be" data-testid="title" href="https://www.booking.com/hotel/fr/virgina.fr.html?aid=304142&amp;label=gen173nr-1FCAQoggJCDHNlYXJjaF9wYXJpc0gNWARoTYgBApgBDbgBCcgBEdgBAegBAfgBA4gCAagCA7gCubHynQbAAgHSAiQxYzE0ZWFiYy1iZTk3LTRmYjUtOTU3Yi1iYmY4MTViNjRmYjnYAgXgAgE&amp;ucfs=1&amp;arphpl=1&amp;group_adults=2&amp;req_adults=2&amp;no_rooms=1&amp;group_children=0&amp;req_children=0&amp;hpos=20&amp;hapos=20&amp;sr_order=popularity&amp;srpvid=8c9d9fdcb1f2011f&amp;srepoch=1673304250"><div class="b3d1cacd40"><h2 class="f9afbb0024 f0d4d6a2f5 fda3b74d0d">Virgina</h2></div></a>,
#  <a class="fc63351294 a822bdf511 d4b6b7a9e7 cfb238afa1 f4605622ad" href="https://www.booking.com/searchresults.fr.html?aid=304142&amp;label=gen173nr-1FCAQoggJCDHNlYXJjaF9wYXJpc0gNWARoTYgBApgBDbgBCcgBEdgBAegBAfgBA4gCAagCA7gCubHynQbAAgHSAiQxYzE0ZWFiYy1iZTk3LTRmYjUtOTU3Yi1iYmY4MTViNjRmYjnYAgXgAgE&amp;ss=Paris&amp;offset=20" title="Page suivante"><span class="e57ffa4eb5">Suivant</span><span class="b9def0936d aff03b959f"><span aria-hidden="true" class="b6dc9a9e69 e6c50852bd"><svg data-rtl-flip="true" viewbox="0 0 24 24" xmlns="http://www.w3.org/2000/svg"><path d="M9.45 6c.2 0 .39.078.53.22l5 5c.208.206.323.487.32.78a1.1 1.1 0 0 1-.32.78l-5 5a.75.75 0 0 1-1.06 0 .74.74 0 0 1 0-1.06L13.64 12 8.92 7.28a.74.74 0 0 1 0-1.06.73.73 0 0 1 .53-.22zm4.47 5.72zm0 .57z"></path></svg></span></span></a>,
#  <a class="bui-button bui-banner__button bui-button--secondary" href="https://account.booking.com/auth/oauth2?lang=fr&amp;state=UuUBogA4v8XA-1z_vWjIR6macSiJaYuaRLTiqZohyNSt6uQ1f9cDP6CRKoazJyLTnJvwxiSAXtxfSc6JP5dgHSgMzo3Z0qwyyl3IwX2IoVdHPe2nvt-0FdzoaxrWt4btPXR0LnEwdoKKdTIq2pU84QulimNjf6Ej0CtrehL47goHrQOo3X_z-GsiDl5bnJAqwDLuifoUmiZhn-5oRm-bPnuqbEf_sQgKdMtDQdToJ4cANR8a4GvYGhzqJCIsIfR9dm_HsPv6SDeYrD3iDG9rlZ-hseRRVEA1s10rxhqn441NKobhli7PRg&amp;response_type=code&amp;aid=304142&amp;client_id=vO1Kblk7xX9tUn2cpZLS&amp;redirect_uri=https%3A%2F%2Fsecure.booking.com%2Flogin.html%3Fop%3Doauth_return&amp;bkng_action=searchresults&amp;dt=1673304249">
#  <span class="bui-button__text">Se connecter</span>
#  </a>,
#  <a aria-describedby="app-banner-desc" aria-label="Téléchargez l'appli GRATUITE" class="appacq-banner-rating gta-banner-link gta-link-track footer-banner-common" data-et-click="customGoal:cCHObTRVDEZRdPQBcGCfTKYCcZeKe:2 goal:mdot_download_app_click" data-et-view="dLYHMRFeRLBBVYUTDXbEaBVLCBLREHGC:3" data-event-label="android" data-placement="GeneralFooterAndroid" data-track-event="android_footer_app_link_v1" href="https://www.booking.com/apps.fr.html?label=gen173nr-1FCAQoggJCDHNlYXJjaF9wYXJpc0gNWARoTYgBApgBDbgBCcgBEdgBAegBAfgBA4gCAagCA7gCubHynQbAAgHSAiQxYzE0ZWFiYy1iZTk3LTRmYjUtOTU3Yi1iYmY4MTViNjRmYjnYAgXgAgE&amp;sid=90b13d9acb07cfbe92c13567b44289eb&amp;srpvid=8c9d9fdcb1f2011f&amp;&amp;app_install=1&amp;lang=fr&amp;site=mdot&amp;page=searchresults&amp;placement=GeneralFooterAndroid&amp;device=direct&amp;etseed=52616e646f6d49562473646523287d61e9b10a5ec037a5b8e3418bd1b5132103955b3cfc17b3c03a0ebdb97a5fb23460eb563aaf44f402ba702d2cab53c2e5e8&amp;hoff=sr&amp;dest_countrycode=fr&amp;dest_id=-1456928&amp;dest_type=city&amp;room1=A,A" target="_blank">
#  <div class="app-icon">
#  <img alt="Booking" src="https://cf.bstatic.com/mobile/images/gta/booking-app-logo-128/8c0a29a0f8657ad4d395e725225770a6d2b7904c.png"/>
#  </div>
#  <div class="app-info">
#  <div class="bui-text bui-text--color-neutral bui-text--variant-strong_2" id="truncate-title">Téléchargez l'appli GRATUITE</div>
#  <div class="app-rating">
#  <div class="app-rating-stars">
#  <svg aria-hidden="true" class="bk-icon -sprite-ratings_stars_4_half" focusable="false" height="13" width="69"><use xlink:href="#icon-sprite-ratings_stars_4_half"></use></svg>
#  <span class="u-sr-only">Note de 4.5 étoiles sur 5 </span>
#  </div>
#  </div>
#  <div class="app-sub">
#  <div class="bui-text bui-text--color-neutral bui-text--variant-small_1" id="app-banner-desc">
#  Recherchez, réservez et gérez vos séjours sur l'appli
#  </div>
#  </div>
#  </div>
#  <div class="app-get">
#  <button class="bui-button" data-et-click="customGoal:dLYHMRFeRLBBVYUTDXbEaBVLCBLREHGC:1" id="track-get-button" type="button">
#  <span class="bui-button__text">
#  Installer
#  </span>
#  </button>
#  </div>
#  </a>,
#  <a class="bui-button bui-button--secondary" data-et-click=" customGoal:HCZVfDaYHZeKGTafWe:1 customGoal:cCHObTRVDEZRdPQBcGCfTKYCcZeKe:4  " data-et-view="HCZEZUaNZIUONSFTUQODZEYTYeYINXGET:5" data-ga="Joinapp_link" href="https://join.booking.com?utm_source=mobilefooter&amp;utm_medium=frontend&amp;aid=304142&amp;lang=fr&amp;mdot_footer_add_prop=1&amp;contact_details=&amp;new_pg=1&amp;label=gen173nr-1FCAQoggJCDHNlYXJjaF9wYXJpc0gNWARoTYgBApgBDbgBCcgBEdgBAegBAfgBA4gCAagCA7gCubHynQbAAgHSAiQxYzE0ZWFiYy1iZTk3LTRmYjUtOTU3Yi1iYmY4MTViNjRmYjnYAgXgAgE" rel="nofollow" target="_blank">
#  <span class="bui-button__text">
#  Ajoutez votre établissement
#  </span>
#  </a>,
#  <a class="u-display:inline-block u-color:white u-padding:5 u-font-weight:bold" href="https://www.booking.com/searchresults.fr.html?ss=Paris&amp;prefer_site_type=www" rel="nofollow">
#  Version ordinateur
#  </a>,
#  <a class="u-display:inline-block u-color:white u-padding:5 u-font-weight:bold" href="/content/terms.fr.html?label=gen173nr-1FCAQoggJCDHNlYXJjaF9wYXJpc0gNWARoTYgBApgBDbgBCcgBEdgBAegBAfgBA4gCAagCA7gCubHynQbAAgHSAiQxYzE0ZWFiYy1iZTk3LTRmYjUtOTU3Yi1iYmY4MTViNjRmYjnYAgXgAgE&amp;sid=90b13d9acb07cfbe92c13567b44289eb&amp;srpvid=8c9d9fdcb1f2011f&amp;&amp;new_pg=1" rel="nofollow">Conditions générales d'utilisation</a>,
#  <a class="u-display:inline-block u-color:white u-padding:5 u-font-weight:bold" href="/content/how_we_work.fr.html?label=gen173nr-1FCAQoggJCDHNlYXJjaF9wYXJpc0gNWARoTYgBApgBDbgBCcgBEdgBAegBAfgBA4gCAagCA7gCubHynQbAAgHSAiQxYzE0ZWFiYy1iZTk3LTRmYjUtOTU3Yi1iYmY4MTViNjRmYjnYAgXgAgE&amp;sid=90b13d9acb07cfbe92c13567b44289eb&amp;srpvid=8c9d9fdcb1f2011f&amp;&amp;new_pg=1" rel="nofollow" target="_blank">Fonctionnement de notre site</a>,
#  <a class="u-display:inline-block u-color:white u-padding:5 u-font-weight:bold" href="https://www.booking.com/content/privacy.fr.html?label=gen173nr-1FCAQoggJCDHNlYXJjaF9wYXJpc0gNWARoTYgBApgBDbgBCcgBEdgBAegBAfgBA4gCAagCA7gCubHynQbAAgHSAiQxYzE0ZWFiYy1iZTk3LTRmYjUtOTU3Yi1iYmY4MTViNjRmYjnYAgXgAgE&amp;sid=90b13d9acb07cfbe92c13567b44289eb&amp;srpvid=8c9d9fdcb1f2011f&amp;&amp;new_pg=1" rel="nofollow">Confidentialité et Cookies</a>,
#  <a class="u-display:inline-block u-color:white u-padding:5 ot-preference-center-footer" href="#">
#  Gérer les paramètres relatifs aux cookies
#  </a>,
#  <a class="u-display:inline-block u-color:white u-padding:5 u-font-weight:bold" href="https://www.bookingholdings.com/about/compliance-and-ethics/" rel="nofollow" target="_blank">Charte MSA</a>,
#  <a class="u-display:inline-block u-color:white u-padding:5 u-font-weight:bold" href="https://www.booking.com/general.fr.html?label=gen173nr-1FCAQoggJCDHNlYXJjaF9wYXJpc0gNWARoTYgBApgBDbgBCcgBEdgBAegBAfgBA4gCAagCA7gCubHynQbAAgHSAiQxYzE0ZWFiYy1iZTk3LTRmYjUtOTU3Yi1iYmY4MTViNjRmYjnYAgXgAgE&amp;sid=90b13d9acb07cfbe92c13567b44289eb&amp;srpvid=8c9d9fdcb1f2011f&amp;&amp;tmpl=docs/about;bk_ft_about=0&amp;new_pg=1" rel="nofollow">
#  À propos de Booking.com
#  </a>,
#  <a class="u-padding:5 u-color:white u-font-weight:normal" data-et-click=" BHDTJdReLLCBLZBeMbFMOFIbeDUHYKe:1 BHDTJdReLLCBLZBeMbFMOFIbeDUHYKe:5 " data-toggle="true" data-toggle-target=".site-footer__meta-links" href="#site-footer__meta-links">Plan du site</a>,
#  <a class="u-display:inline-block u-padding:5 u-color:white u-font-weight:normal" href="https://www.booking.com/discover.fr.html?srpvid=8c9d9fdcb1f2011f&amp;">Découvrir des destinations</a>,
#  <a class="u-display:inline-block u-padding:5 u-color:white u-font-weight:normal" href="https://www.booking.com/destination.fr.html?srpvid=8c9d9fdcb1f2011f&amp;">Répertoire de pays</a>,
#  <a class="u-display:inline-block u-padding:5 u-color:white u-font-weight:normal" href="https://www.booking.com/hotel/index.fr.html?label=gen173nr-1FCAQoggJCDHNlYXJjaF9wYXJpc0gNWARoTYgBApgBDbgBCcgBEdgBAegBAfgBA4gCAagCA7gCubHynQbAAgHSAiQxYzE0ZWFiYy1iZTk3LTRmYjUtOTU3Yi1iYmY4MTViNjRmYjnYAgXgAgE&amp;sid=90b13d9acb07cfbe92c13567b44289eb&amp;srpvid=8c9d9fdcb1f2011f&amp;">Hôtels</a>,
#  <a class="u-display:inline-block u-padding:5 u-color:white u-font-weight:normal" href="/apartments/index.fr.html?label=gen173nr-1FCAQoggJCDHNlYXJjaF9wYXJpc0gNWARoTYgBApgBDbgBCcgBEdgBAegBAfgBA4gCAagCA7gCubHynQbAAgHSAiQxYzE0ZWFiYy1iZTk3LTRmYjUtOTU3Yi1iYmY4MTViNjRmYjnYAgXgAgE&amp;sid=90b13d9acb07cfbe92c13567b44289eb&amp;srpvid=8c9d9fdcb1f2011f&amp;">Appartements
#  </a>,
#  <a class="u-display:inline-block u-padding:5 u-color:white u-font-weight:normal" href="/resorts/index.fr.html?label=gen173nr-1FCAQoggJCDHNlYXJjaF9wYXJpc0gNWARoTYgBApgBDbgBCcgBEdgBAegBAfgBA4gCAagCA7gCubHynQbAAgHSAiQxYzE0ZWFiYy1iZTk3LTRmYjUtOTU3Yi1iYmY4MTViNjRmYjnYAgXgAgE&amp;sid=90b13d9acb07cfbe92c13567b44289eb&amp;srpvid=8c9d9fdcb1f2011f&amp;">Complexes hôteliers
#  </a>,
#  <a class="u-display:inline-block u-padding:5 u-color:white u-font-weight:normal" href="/motels/index.fr.html?label=gen173nr-1FCAQoggJCDHNlYXJjaF9wYXJpc0gNWARoTYgBApgBDbgBCcgBEdgBAegBAfgBA4gCAagCA7gCubHynQbAAgHSAiQxYzE0ZWFiYy1iZTk3LTRmYjUtOTU3Yi1iYmY4MTViNjRmYjnYAgXgAgE&amp;sid=90b13d9acb07cfbe92c13567b44289eb&amp;srpvid=8c9d9fdcb1f2011f&amp;">Motels
#  </a>,
#  <a class="u-display:inline-block u-padding:5 u-color:white u-font-weight:normal" href="/booking-home/index.fr.html?label=gen173nr-1FCAQoggJCDHNlYXJjaF9wYXJpc0gNWARoTYgBApgBDbgBCcgBEdgBAegBAfgBA4gCAagCA7gCubHynQbAAgHSAiQxYzE0ZWFiYy1iZTk3LTRmYjUtOTU3Yi1iYmY4MTViNjRmYjnYAgXgAgE&amp;sid=90b13d9acb07cfbe92c13567b44289eb&amp;srpvid=8c9d9fdcb1f2011f&amp;">Locations de vacances
#  </a>,
#  <a class="u-display:inline-block u-padding:5 u-color:white u-font-weight:normal" href="/pets/index.fr.html?label=gen173nr-1FCAQoggJCDHNlYXJjaF9wYXJpc0gNWARoTYgBApgBDbgBCcgBEdgBAegBAfgBA4gCAagCA7gCubHynQbAAgHSAiQxYzE0ZWFiYy1iZTk3LTRmYjUtOTU3Yi1iYmY4MTViNjRmYjnYAgXgAgE&amp;sid=90b13d9acb07cfbe92c13567b44289eb&amp;srpvid=8c9d9fdcb1f2011f&amp;">Hôtels acceptant les animaux domestiques
#  </a>,
#  <a class="u-display:inline-block u-padding:5 u-color:white u-font-weight:normal" href="/spa/index.fr.html?label=gen173nr-1FCAQoggJCDHNlYXJjaF9wYXJpc0gNWARoTYgBApgBDbgBCcgBEdgBAegBAfgBA4gCAagCA7gCubHynQbAAgHSAiQxYzE0ZWFiYy1iZTk3LTRmYjUtOTU3Yi1iYmY4MTViNjRmYjnYAgXgAgE&amp;sid=90b13d9acb07cfbe92c13567b44289eb&amp;srpvid=8c9d9fdcb1f2011f&amp;">Hôtels &amp; spas
#  </a>,
#  <a class="u-display:inline-block u-padding:5 u-color:white u-font-weight:normal" href="/luxury/index.fr.html?label=gen173nr-1FCAQoggJCDHNlYXJjaF9wYXJpc0gNWARoTYgBApgBDbgBCcgBEdgBAegBAfgBA4gCAagCA7gCubHynQbAAgHSAiQxYzE0ZWFiYy1iZTk3LTRmYjUtOTU3Yi1iYmY4MTViNjRmYjnYAgXgAgE&amp;sid=90b13d9acb07cfbe92c13567b44289eb&amp;srpvid=8c9d9fdcb1f2011f&amp;">Hôtels de luxe
#  </a>,
#  <a class="u-display:inline-block u-padding:5 u-color:white u-font-weight:normal" href="/reviews.fr.html?label=gen173nr-1FCAQoggJCDHNlYXJjaF9wYXJpc0gNWARoTYgBApgBDbgBCcgBEdgBAegBAfgBA4gCAagCA7gCubHynQbAAgHSAiQxYzE0ZWFiYy1iZTk3LTRmYjUtOTU3Yi1iYmY4MTViNjRmYjnYAgXgAgE&amp;sid=90b13d9acb07cfbe92c13567b44289eb&amp;srpvid=8c9d9fdcb1f2011f&amp;">Commentaires
#  </a>,
#  <a class="u-display:inline-block u-padding:5 u-color:white u-font-weight:normal" href="/articles.fr.html?label=gen173nr-1FCAQoggJCDHNlYXJjaF9wYXJpc0gNWARoTYgBApgBDbgBCcgBEdgBAegBAfgBA4gCAagCA7gCubHynQbAAgHSAiQxYzE0ZWFiYy1iZTk3LTRmYjUtOTU3Yi1iYmY4MTViNjRmYjnYAgXgAgE&amp;sid=90b13d9acb07cfbe92c13567b44289eb&amp;srpvid=8c9d9fdcb1f2011f&amp;">Articles
#  </a>]

# %%
best_five_list = ['Bormes les Mimosas', 'Cassis', 'Marseille', 'Aix en Provence', 'Saintes Maries de la mer']
best_five_list
# Out:
# ['Bormes les Mimosas',
#  'Cassis',
#  'Marseille',
#  'Aix en Provence',
#  'Saintes Maries de la mer']

# %%
'''booking_list = []

for hotels in range(len(best_five_list)):
    villes = best_five_list[hotels]
    Id = hotels
    r_booking = requests.get('https://www.booking.com/searchresults.fr.html?ss={}'.format(best_five_list[hotels]), headers = {'User-Agent': 'Mozilla/5.0 (Linux; Android 6.0; Nexus 5 Build/MRA58N) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/108.0.0.0 Mobile Safari/537.36'})
    soup = BeautifulSoup(r_booking.content)
    link=soup.a
    hotel_address = [element.get_text().replace('\n','') for element in soup.find_all('span','a51f4b5adb')]
    hotel_description = [element.get_text().replace('\n','') for element in soup.find_all('div','d8eab2cf7f')]
    hotel_url = soup.select('h3 a')
    hotels_url = [x.get('href') for x in hotel_url]
    hotel_score = soup.find_all('span','d8eab2cf7f f0d4d6a2f5 e46e88563a')
    hotels_score = [x.get('alt') for x in hotel_score]
    nom_hotel= soup.select('h2', class_ = "f9afbb0024 f0d4d6a2f5 fda3b74d0d")
    name_hotels = [x.get('title') for x in nom_hotel]
    
    booking_dict = {'ID': Id,
                        'Cities': best_five_list,
                        'Hotels': name_hotels,
                        'Hotel addresses': hotel_address,
                        'Hotels URL': hotels_url,
                        'Hotels description': hotel_description,
                        'Hotels rating': hotels_score

                        }

    # récupération de tous les résultats
    booking_list.append(booking_dict)
    '''
# Out:
# 'booking_list = []\n\nfor hotels in range(len(best_five_list)):\n    villes = best_five_list[hotels]\n    Id = hotels\n    r_booking = requests.get(\'https://www.booking.com/searchresults.fr.html?ss={}\'.format(best_five_list[hotels]), headers = {\'User-Agent\': \'Mozilla/5.0 (Linux; Android 6.0; Nexus 5 Build/MRA58N) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/108.0.0.0 Mobile Safari/537.36\'})\n    soup = BeautifulSoup(r_booking.content)\n    link=soup.a\n    hotel_address = [element.get_text().replace(\'\n\',\'\') for element in soup.find_all(\'span\',\'a51f4b5adb\')]\n    hotel_description = [element.get_text().replace(\'\n\',\'\') for element in soup.find_all(\'div\',\'d8eab2cf7f\')]\n    hotel_url = soup.select(\'h3 a\')\n    hotels_url = [x.get(\'href\') for x in hotel_url]\n    hotel_score = soup.find_all(\'span\',\'d8eab2cf7f f0d4d6a2f5 e46e88563a\')\n    hotels_score = [x.get(\'alt\') for x in hotel_score]\n    nom_hotel= soup.select(\'h2\', class_ = "f9afbb0024 f0d4d6a2f5 fda3b74d0d")\n    name_hotels = [x.get(\'title\') for x in nom_hotel]\n    \n    booking_dict = {\'ID\': Id,\n                        \'Cities\': best_five_list,\n                        \'Hotels\': name_hotels,\n                        \'Hotel addresses\': hotel_address,\n                        \'Hotels URL\': hotels_url,\n                        \'Hotels description\': hotel_description,\n                        \'Hotels rating\': hotels_score\n\n                        }\n\n    # récupération de tous les résultats\n    booking_list.append(booking_dict)\n    '

# %%
booking_list = []

for hotels in range(len(best_five_list)):
    villes = best_five_list[hotels]
    Id = hotels
    r_booking = requests.get('https://www.booking.com/searchresults.fr.html?ss={}'.format(best_five_list[hotels]), headers = {'User-Agent': 'Mozilla/5.0 (Linux; Android 6.0; Nexus 5 Build/MRA58N) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/108.0.0.0 Mobile Safari/537.36'})
    soup = BeautifulSoup(r_booking.content)
    link=soup.a
    hotel_url = soup.select('a.f348c1e3be')
    hotels_url = [x.get('href') for x in hotel_url]
    hotel_description = [element.get_text().replace('\n','') for element in soup.find_all('div','d8eab2cf7f')]
    hotel_address = [element.get_text().replace('\n','') for element in soup.find_all('span','a51f4b5adb')]
    hotel_score = [element.get_text().replace('\n','') for element in soup.find_all('span','d8eab2cf7f f0d4d6a2f5 e46e88563a')]
    nom_hotel= [element.get_text().replace('\n','') for element in soup.find_all('h2','f9afbb0024 f0d4d6a2f5 fda3b74d0d')]
    
    booking_dict = {'ID': Id,
                        'Cities': best_five_list,
                        'Hotels': nom_hotel,
                        'Hotels URL': hotels_url,
                        'Hotel addresses': hotel_address,
                        'Hotels description': hotel_description,
                        'Hotels rating': hotel_score

                        }

    # récupération de tous les résultats
    booking_list.append(booking_dict)

# %%
# Conversion de notre liste scrappy en DF
booking_soup = DataFrame(booking_list)
booking_soup
# Out:
#    ID                                             Cities  \
# 0   0  [Bormes les Mimosas, Cassis, Marseille, Aix en...
# 1   1  [Bormes les Mimosas, Cassis, Marseille, Aix en...
# 2   2  [Bormes les Mimosas, Cassis, Marseille, Aix en...
# 3   3  [Bormes les Mimosas, Cassis, Marseille, Aix en...
# 4   4  [Bormes les Mimosas, Cassis, Marseille, Aix en...
#
#                                               Hotels  \
# 0  [La Lavandière, HomeStay Bormes, Le petit atel...
# 1  [LE REVE BLEU, Le Cleli, Villa l'Icône, appart...
# 2  [Hôtel Maison Montgrand - Vieux Port, Maisons ...
# 3  [Appartements Lucas de Montigny, Appartement L...
# 4  [Le Castelet, Hôtel Casa Marina, Thalacap Cama...
#
#                                           Hotels URL  \
# 0  [https://www.booking.com/hotel/fr/la-lavandier...
# 1  [https://www.booking.com/hotel/fr/le-reve-bleu...
# 2  [https://www.booking.com/hotel/fr/montgrand.fr...
# 3  [https://www.booking.com/hotel/fr/appartements...
# 4  [https://www.booking.com/hotel/fr/le-castelet-...
#
#                                      Hotel addresses  \
# 0  [Bormes-les-Mimosas • 1,1 km du centre, À 1,5 ...
# 1  [Cassis • 0,7 km du centre, À 850 m de la plag...
# 2  [Vieux Port - La Canebière, Marseille • 0,8 km...
# 3  [Centre historique d'Aix-en-Provence • 0,5 km ...
# 4  [Les Saintes-Maries-de-la-Mer • 300 m du centr...
#
#                                   Hotels description  \
# 0  [, Bormes-les-Mimosas • 1,1 km du centre, À 1,...
# 1  [, 8,6, Cassis • 0,7 km du centre, À 850 m de ...
# 2  [, 8,0, Vieux Port - La Canebière, Marseille •...
# 3  [, 10 Exceptionnel, Centre historique d'Aix-en...
# 4  [7,0, Les Saintes-Maries-de-la-Mer • 300 m du ...
#
#                                        Hotels rating
# 0  [ Exceptionnel,  Superbe,  Bien ,  Très bien, ...
# 1  [ Superbe,  Très bien,  Bien ,  Superbe,  Fabu...
# 2  [ Très bien,  Très bien,  Bien ,  Bien ,  Bien...
# 3  [ Fabuleux ,  Exceptionnel,  Exceptionnel,  Tr...
# 4  [ Bien ,  Superbe,  Bien ,  Très bien,  Bien ,...

# %%
# Explode sur nos colonnes pour briser les listes comprises dans chaque cellule du DF

booking1 = booking_soup['Hotels'].explode('Hotels').reset_index()
print(booking1)

booking2 = booking_soup['Hotel addresses'].explode('Hotel addresses').reset_index()
print(booking2)

booking3 = booking_soup['Hotels URL'].explode('Hotels URL').reset_index()
print(booking3)

booking4 = booking_soup['Hotels description'].explode('Hotels description').reset_index()
#print(booking4)

booking5 = booking_soup['Hotels rating'].explode('Hotels rating').reset_index()
print(booking5)
# Out:
#     index                                             Hotels
# 0       0                                      La Lavandière
# 1       1                                    HomeStay Bormes
# 2       2                                   Le petit atelier
# 3       3  Charmant Appartement avec Vue panoramique Mer ...
# 4       4                                      Hôtel Paradis
# ..    ...                                                ...
# 95     95                                      Hotel Camille
# 96     96             Appartement calme à deux pas de la mer
# 97     97                              Oh! Campings La Brise
# 98     98                              Auberge de la Fadaise
# 99     99                           L'Estrambord de Camargue
#
# [100 rows x 2 columns]
#      index                                  Hotel addresses
# 0        0            Bormes-les-Mimosas • 1,1 km du centre
# 1        1                             À 1,5 km de la plage
# 2        2            Bormes-les-Mimosas • 1,2 km du centre
# 3        3            Bormes-les-Mimosas • 1,1 km du centre
# 4        4                             À 1,6 km de la plage
# ..     ...                                              ...
# 181    181  Les Saintes-Maries-de-la-Mer • 0,7 km du centre
# 182    182                                     Front de mer
# 183    183  Les Saintes-Maries-de-la-Mer • 4,3 km du centre
# 184    184   Les Saintes-Maries-de-la-Mer • 250 m du centre
# 185    185                              À 250 m de la plage
#
# [186 rows x 2 columns]
#     index                                         Hotels URL
# 0       0  https://www.booking.com/hotel/fr/la-lavandiere...
# 1       1  https://www.booking.com/hotel/fr/homestay-borm...
# 2       2  https://www.booking.com/hotel/fr/le-petit-atel...
# 3       3  https://www.booking.com/hotel/fr/bormes-les-mi...
# 4       4  https://www.booking.com/hotel/fr/paradis.fr.ht...
# ..    ...                                                ...
# 95     95  https://www.booking.com/hotel/fr/camille.fr.ht...
# 96     96  https://www.booking.com/hotel/fr/appartement-c...
# 97     97  https://www.booking.com/hotel/fr/oh-campings-l...
# 98     98  https://www.booking.com/hotel/fr/auberge-de-la...
# 99     99  https://www.booking.com/hotel/fr/l-39-estrambo...
#
# [100 rows x 2 columns]
#     index  Hotels rating
# 0       0   Exceptionnel
# 1       1        Superbe
# 2       2          Bien
# 3       3      Très bien
# 4       4      Fabuleux
# ..    ...            ...
# 91     91          Bien
# 92     92      Très bien
# 93     93          Bien
# 94     94      Très bien
# 95     95      Très bien
#
# [96 rows x 2 columns]

# %%
# On merge nos DF grâce à la colonne commune : 'index'

booking_test = booking1.merge(booking2).merge(booking3).merge(booking4)

booking_test
# Out:
#     index                                             Hotels  \
# 0       0                                      La Lavandière
# 1       1                                    HomeStay Bormes
# 2       2                                   Le petit atelier
# 3       3  Charmant Appartement avec Vue panoramique Mer ...
# 4       4                                      Hôtel Paradis
# ..    ...                                                ...
# 95     95                                      Hotel Camille
# 96     96             Appartement calme à deux pas de la mer
# 97     97                              Oh! Campings La Brise
# 98     98                              Auberge de la Fadaise
# 99     99                           L'Estrambord de Camargue
#
#                                       Hotel addresses  \
# 0               Bormes-les-Mimosas • 1,1 km du centre
# 1                                À 1,5 km de la plage
# 2               Bormes-les-Mimosas • 1,2 km du centre
# 3               Bormes-les-Mimosas • 1,1 km du centre
# 4                                À 1,6 km de la plage
# ..                                                ...
# 95        Saint-Charles, Marseille • 0,7 km du centre
# 96         Prado - Périer, Marseille • 2 km du centre
# 97  Vieux Port - La Canebière, Marseille • 1,6 km ...
# 98        Saint-Charles, Marseille • 0,5 km du centre
# 99  Vieux Port - La Canebière, Marseille • 0,5 km ...
#
#                                            Hotels URL  \
# 0   https://www.booking.com/hotel/fr/la-lavandiere...
# 1   https://www.booking.com/hotel/fr/homestay-borm...
# 2   https://www.booking.com/hotel/fr/le-petit-atel...
# 3   https://www.booking.com/hotel/fr/bormes-les-mi...
# 4   https://www.booking.com/hotel/fr/paradis.fr.ht...
# ..                                                ...
# 95  https://www.booking.com/hotel/fr/camille.fr.ht...
# 96  https://www.booking.com/hotel/fr/appartement-c...
# 97  https://www.booking.com/hotel/fr/oh-campings-l...
# 98  https://www.booking.com/hotel/fr/auberge-de-la...
# 99  https://www.booking.com/hotel/fr/l-39-estrambo...
#
#                        Hotels description
# 0
# 1   Bormes-les-Mimosas • 1,1 km du centre
# 2                    À 1,5 km de la plage
# 3                                     9,6
# 4   Bormes-les-Mimosas • 1,2 km du centre
# ..                                    ...
# 95    Hébergement géré par un particulier
# 96                                    7,7
# 97               Cassis • 100 m du centre
# 98                    À 150 m de la plage
# 99    Hébergement géré par un particulier
#
# [100 rows x 5 columns]

# %%
# On attribue les villes aux lignes respectives

booking_test.loc[:20, 'Cities'] = 'Bormes les Mimosas'

booking_test.loc[20:39, 'Cities'] = 'Cassis'

booking_test.loc[40:59, 'Cities'] = 'Marseille'

booking_test.loc[60:79, 'Cities'] = 'Aix en Provence'

booking_test.loc[80:99, 'Cities'] = 'Saintes Maries de la mer'

# %%
# On réorganise l'ordre des colonnes pour un df plus esthétique
booking_test = booking_test.iloc[:, [0,5,1,2,3,4]]

booking_test
# Out:
#     index                                         Hotels URL  \
# 0       0  https://www.booking.com/hotel/fr/la-lavandiere...
# 1       1  https://www.booking.com/hotel/fr/homestay-borm...
# 2       2  https://www.booking.com/hotel/fr/le-petit-atel...
# 3       3  https://www.booking.com/hotel/fr/bormes-les-mi...
# 4       4  https://www.booking.com/hotel/fr/paradis.fr.ht...
# ..    ...                                                ...
# 95     95  https://www.booking.com/hotel/fr/camille.fr.ht...
# 96     96  https://www.booking.com/hotel/fr/appartement-c...
# 97     97  https://www.booking.com/hotel/fr/oh-campings-l...
# 98     98  https://www.booking.com/hotel/fr/auberge-de-la...
# 99     99  https://www.booking.com/hotel/fr/l-39-estrambo...
#
#                        Hotels description                    Cities  \
# 0                                                Bormes les Mimosas
# 1   Bormes-les-Mimosas • 1,1 km du centre        Bormes les Mimosas
# 2                    À 1,5 km de la plage        Bormes les Mimosas
# 3                                     9,6        Bormes les Mimosas
# 4   Bormes-les-Mimosas • 1,2 km du centre        Bormes les Mimosas
# ..                                    ...                       ...
# 95    Hébergement géré par un particulier  Saintes Maries de la mer
# 96                                    7,7  Saintes Maries de la mer
# 97               Cassis • 100 m du centre  Saintes Maries de la mer
# 98                    À 150 m de la plage  Saintes Maries de la mer
# 99    Hébergement géré par un particulier  Saintes Maries de la mer
#
#                                                Hotels  \
# 0                                       La Lavandière
# 1                                     HomeStay Bormes
# 2                                    Le petit atelier
# 3   Charmant Appartement avec Vue panoramique Mer ...
# 4                                       Hôtel Paradis
# ..                                                ...
# 95                                      Hotel Camille
# 96             Appartement calme à deux pas de la mer
# 97                              Oh! Campings La Brise
# 98                              Auberge de la Fadaise
# 99                           L'Estrambord de Camargue
#
#                                       Hotel addresses
# 0               Bormes-les-Mimosas • 1,1 km du centre
# 1                                À 1,5 km de la plage
# 2               Bormes-les-Mimosas • 1,2 km du centre
# 3               Bormes-les-Mimosas • 1,1 km du centre
# 4                                À 1,6 km de la plage
# ..                                                ...
# 95        Saint-Charles, Marseille • 0,7 km du centre
# 96         Prado - Périer, Marseille • 2 km du centre
# 97  Vieux Port - La Canebière, Marseille • 1,6 km ...
# 98        Saint-Charles, Marseille • 0,5 km du centre
# 99  Vieux Port - La Canebière, Marseille • 0,5 km ...
#
# [100 rows x 6 columns]

# %%
# !pip install plotly
# !pip install cufflinks
# Out:
# Collecting plotly
#   Downloading plotly-5.11.0-py2.py3-none-any.whl (15.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.3/15.3 MB 10.1 MB/s eta 0:00:0000:0100:01
# Collecting tenacity>=6.2.0
#   Downloading tenacity-8.1.0-py3-none-any.whl (23 kB)
# Installing collected packages: tenacity, plotly
# Successfully installed plotly-5.11.0 tenacity-8.1.0
# WARNING: You are using pip version 22.0.4; however, version 22.3.1 is available.
# You should consider upgrading via the '/Library/Frameworks/Python.framework/Versions/3.10/bin/python3.10 -m pip install --upgrade pip' command.
# Collecting cufflinks
#   Downloading cufflinks-0.17.3.tar.gz (81 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.7/81.7 KB 4.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy>=1.9.2 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from cufflinks) (1.23.5)
# Collecting pandas>=0.19.2
#   Downloading pandas-1.5.2-cp310-cp310-macosx_10_9_x86_64.whl (12.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.0/12.0 MB 8.5 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: plotly>=4.1.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from cufflinks) (5.11.0)
# Requirement already satisfied: six>=1.9.0 in /Users/macbook/Library/Python/3.10/lib/python/site-packages (from cufflinks) (1.16.0)
# Collecting colorlover>=0.2.1
#   Downloading colorlover-0.3.0-py3-none-any.whl (8.9 kB)
# Requirement already satisfied: setuptools>=34.4.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from cufflinks) (58.1.0)
# Collecting ipython>=5.3.0
#   Downloading ipython-8.8.0-py3-none-any.whl (775 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 775.8/775.8 KB 9.0 MB/s eta 0:00:0000:0100:01
# Collecting ipywidgets>=7.0.0
#   Downloading ipywidgets-8.0.4-py3-none-any.whl (137 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 137.8/137.8 KB 11.2 MB/s eta 0:00:00
# Collecting jedi>=0.16
#   Downloading jedi-0.18.2-py2.py3-none-any.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 11.5 MB/s eta 0:00:0000:0100:01
# Collecting pickleshare
#   Downloading pickleshare-0.7.5-py2.py3-none-any.whl (6.9 kB)
# Collecting appnope
#   Downloading appnope-0.1.3-py2.py3-none-any.whl (4.4 kB)
# Collecting pexpect>4.3
#   Downloading pexpect-4.8.0-py2.py3-none-any.whl (59 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.0/59.0 KB 5.2 MB/s eta 0:00:00
# Collecting pygments>=2.4.0
#   Downloading Pygments-2.14.0-py3-none-any.whl (1.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 7.4 MB/s eta 0:00:0000:0100:01m
# Collecting matplotlib-inline
#   Downloading matplotlib_inline-0.1.6-py3-none-any.whl (9.4 kB)
# Collecting backcall
#   Downloading backcall-0.2.0-py2.py3-none-any.whl (11 kB)
# Collecting traitlets>=5
#   Downloading traitlets-5.8.1-py3-none-any.whl (116 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.8/116.8 KB 10.0 MB/s eta 0:00:00
# Collecting prompt-toolkit<3.1.0,>=3.0.11
#   Downloading prompt_toolkit-3.0.36-py3-none-any.whl (386 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 386.4/386.4 KB 10.2 MB/s eta 0:00:0000:01
# Collecting stack-data
#   Downloading stack_data-0.6.2-py3-none-any.whl (24 kB)
# Collecting decorator
#   Downloading decorator-5.1.1-py3-none-any.whl (9.1 kB)
# Collecting jupyterlab-widgets~=3.0
#   Downloading jupyterlab_widgets-3.0.5-py3-none-any.whl (384 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 384.3/384.3 KB 8.9 MB/s eta 0:00:0000:01
# Collecting widgetsnbextension~=4.0
#   Downloading widgetsnbextension-4.0.5-py3-none-any.whl (2.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 10.6 MB/s eta 0:00:00a 0:00:01
# Collecting ipykernel>=4.5.1
#   Downloading ipykernel-6.20.1-py3-none-any.whl (149 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 149.2/149.2 KB 8.1 MB/s eta 0:00:00
# Collecting pytz>=2020.1
#   Downloading pytz-2022.7-py2.py3-none-any.whl (499 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 499.4/499.4 KB 7.5 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: python-dateutil>=2.8.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pandas>=0.19.2->cufflinks) (2.8.2)
# Requirement already satisfied: tenacity>=6.2.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from plotly>=4.1.1->cufflinks) (8.1.0)
# Collecting debugpy>=1.0
#   Downloading debugpy-1.6.5-py2.py3-none-any.whl (4.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 9.6 MB/s eta 0:00:00:00:0100:01
# Collecting jupyter-client>=6.1.12
#   Downloading jupyter_client-7.4.8-py3-none-any.whl (133 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 133.5/133.5 KB 6.3 MB/s eta 0:00:00
# Collecting nest-asyncio
#   Downloading nest_asyncio-1.5.6-py3-none-any.whl (5.2 kB)
# Collecting comm>=0.1.1
#   Downloading comm-0.1.2-py3-none-any.whl (6.5 kB)
# Collecting psutil
#   Downloading psutil-5.9.4-cp36-abi3-macosx_10_9_x86_64.whl (243 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 243.5/243.5 KB 9.5 MB/s eta 0:00:00
# Collecting pyzmq>=17
#   Downloading pyzmq-24.0.1-cp310-cp310-macosx_10_15_universal2.whl (1.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 7.3 MB/s eta 0:00:0000:0100:01
# Collecting tornado>=6.1
#   Downloading tornado-6.2-cp37-abi3-macosx_10_9_x86_64.whl (419 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 419.7/419.7 KB 4.5 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: packaging in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->cufflinks) (21.3)
# Collecting parso<0.9.0,>=0.8.0
#   Downloading parso-0.8.3-py2.py3-none-any.whl (100 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100.8/100.8 KB 7.0 MB/s eta 0:00:00
# Collecting ptyprocess>=0.5
#   Downloading ptyprocess-0.7.0-py2.py3-none-any.whl (13 kB)
# Collecting wcwidth
#   Downloading wcwidth-0.2.5-py2.py3-none-any.whl (30 kB)
# Collecting asttokens>=2.1.0
#   Downloading asttokens-2.2.1-py2.py3-none-any.whl (26 kB)
# Collecting executing>=1.2.0
#   Downloading executing-1.2.0-py2.py3-none-any.whl (24 kB)
# Collecting pure-eval
#   Downloading pure_eval-0.2.2-py3-none-any.whl (11 kB)
# Collecting jupyter-core>=4.9.2
#   Downloading jupyter_core-5.1.3-py3-none-any.whl (93 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 93.5/93.5 KB 6.9 MB/s eta 0:00:00
# Collecting entrypoints
#   Downloading entrypoints-0.4-py3-none-any.whl (5.3 kB)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from packaging->ipykernel>=4.5.1->ipywidgets>=7.0.0->cufflinks) (3.0.9)
# Requirement already satisfied: platformdirs>=2.5 in /Users/macbook/Library/Python/3.10/lib/python/site-packages (from jupyter-core>=4.9.2->jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets>=7.0.0->cufflinks) (2.5.1)
# Using legacy 'setup.py install' for cufflinks, since package 'wheel' is not installed.
# Installing collected packages: wcwidth, pytz, pure-eval, ptyprocess, pickleshare, executing, colorlover, backcall, appnope, widgetsnbextension, traitlets, tornado, pyzmq, pygments, psutil, prompt-toolkit, pexpect, parso, nest-asyncio, jupyterlab-widgets, entrypoints, decorator, debugpy, asttokens, stack-data, pandas, matplotlib-inline, jupyter-core, jedi, comm, jupyter-client, ipython, ipykernel, ipywidgets, cufflinks
#   Running setup.py install for cufflinks ... done
# Successfully installed appnope-0.1.3 asttokens-2.2.1 backcall-0.2.0 colorlover-0.3.0 comm-0.1.2 cufflinks-0.17.3 debugpy-1.6.5 decorator-5.1.1 entrypoints-0.4 executing-1.2.0 ipykernel-6.20.1 ipython-8.8.0 ipywidgets-8.0.4 jedi-0.18.2 jupyter-client-7.4.8 jupyter-core-5.1.3 jupyterlab-widgets-3.0.5 matplotlib-inline-0.1.6 nest-asyncio-1.5.6 pandas-1.5.2 parso-0.8.3 pexpect-4.8.0 pickleshare-0.7.5 prompt-toolkit-3.0.36 psutil-5.9.4 ptyprocess-0.7.0 pure-eval-0.2.2 pygments-2.14.0 pytz-2022.7 pyzmq-24.0.1 stack-data-0.6.2 tornado-6.2 traitlets-5.8.1 wcwidth-0.2.5 widgetsnbextension-4.0.5
# WARNING: You are using pip version 22.0.4; however, version 22.3.1 is available.
# You should consider upgrading via the '/Library/Frameworks/Python.framework/Versions/3.10/bin/python3.10 -m pip install --upgrade pip' command.

# %%
import plotly.express as px
from plotly import graph_objs as go
import plotly.io as pio
pio.renderers.default = "iframe" # to be replaced by "iframe" if working on JULIE

# %%
list_column = ['Cities', 'Weather']

fig = px.scatter_mapbox(final_result, 
                        lat="Latitude", 
                        lon="Longitude", 
                        color="Temperature", 
                        size="Latitude", 
                        zoom=3.5, 
                        mapbox_style = "carto-positron",
                        hover_data=list_column,
                    )
fig.show()
# Out:
# <iframe
#     scrolling="no"
#     width="100%"
#     height="545px"
#     src="iframe_figures/figure_29.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
url_list = booking3['Hotels URL'].tolist()

modified_url_list = []
for url in url_list:
    index = url.index('?')
    modified_url = url[:index]
    modified_url_list.append(modified_url)
    
url_list = modified_url_list

url_list
# Out:
# ['https://www.booking.com/hotel/fr/la-lavandiere-bormes-les-mimosas.fr.html',
#  'https://www.booking.com/hotel/fr/homestay-bormes-bormes-les-mimosas.fr.html',
#  'https://www.booking.com/hotel/fr/le-petit-atelier-bormes-les-mimosas1234567891011121314151617.fr.html',
#  'https://www.booking.com/hotel/fr/bormes-les-mimosas-appartement-vue-mer-4-pers.fr.html',
#  'https://www.booking.com/hotel/fr/paradis.fr.html',
#  'https://www.booking.com/hotel/fr/studio-spacieux-proche-plage-wi-fi-climatisation.fr.html',
#  'https://www.booking.com/hotel/fr/hostellerie-du-cigalou.fr.html',
#  'https://www.booking.com/hotel/fr/hotel-la-voile-fr.fr.html',
#  'https://www.booking.com/hotel/fr/coeur-de-village-bormes-les-mimosas.fr.html',
#  'https://www.booking.com/hotel/fr/appart-isa-amp-marc-t2-avec-rez-de-jardin-bus-aeroport-tout-equipe-pour-4-person.fr.html',
#  'https://www.booking.com/hotel/fr/les-terrasses-bormes-les-mimosas.fr.html',
#  'https://www.booking.com/hotel/fr/eden-rose-grand-bw-premier-collection.fr.html',
#  'https://www.booking.com/hotel/fr/le-domaine-du-mirage.fr.html',
#  'https://www.booking.com/hotel/fr/magnifique-maison-de-village-clim-vue-mer-8-pers.fr.html',
#  'https://www.booking.com/hotel/fr/new-life.fr.html',
#  'https://www.booking.com/hotel/fr/le-hameau-de-la-nicolinia-re.fr.html',
#  'https://www.booking.com/hotel/fr/apartement-la-faviere-bormes-les-mimosas.fr.html',
#  'https://www.booking.com/hotel/fr/217-rue-des-iris.fr.html',
#  'https://www.booking.com/hotel/fr/maison-bormes-les-mimosas-3-pieces-4-personnes-fr-1-308-141.fr.html',
#  'https://www.booking.com/hotel/fr/assklan.fr.html',
#  'https://www.booking.com/hotel/fr/le-reve-bleu-cassis.fr.html',
#  'https://www.booking.com/hotel/fr/le-cleli.fr.html',
#  'https://www.booking.com/hotel/fr/villa-l-39-icone.fr.html',
#  'https://www.booking.com/hotel/fr/appartement-du-pecheur-a-cassis-a-10-metres-du-port.fr.html',
#  'https://www.booking.com/hotel/fr/la-douceur-de-cassis.fr.html',
#  'https://www.booking.com/hotel/fr/la-perle-de-cassis-47-grande-terrasse-vue-mer-centre-ville-spacieux-sur-le-port.fr.html',
#  'https://www.booking.com/hotel/fr/le-duplex-cassis.fr.html',
#  'https://www.booking.com/hotel/fr/echo-des-flots.fr.html',
#  'https://www.booking.com/hotel/fr/le-camelia-cassis.fr.html',
#  'https://www.booking.com/hotel/fr/le-chemin-de-belle-fille.fr.html',
#  'https://www.booking.com/hotel/fr/clos-du-petit-ja-c-sus.fr.html',
#  'https://www.booking.com/hotel/fr/cassis-jardin-prive-ds-le-centre-parking-plage-a-500m.fr.html',
#  'https://www.booking.com/hotel/fr/sea-and-sun-cassis.fr.html',
#  'https://www.booking.com/hotel/fr/une-terrasse-sur-la-mer-cassis.fr.html',
#  'https://www.booking.com/hotel/fr/du-grand-jardin.fr.html',
#  'https://www.booking.com/hotel/fr/cassis-4pers-vue-mer-wifi-tennis-parking-piscine.fr.html',
#  'https://www.booking.com/hotel/fr/chez-mamouska.fr.html',
#  'https://www.booking.com/hotel/fr/la-rade-centre-ville-balcon-clim-neuf.fr.html',
#  'https://www.booking.com/hotel/fr/cassisdream.fr.html',
#  'https://www.booking.com/hotel/fr/sea-home.fr.html',
#  'https://www.booking.com/hotel/fr/montgrand.fr.html',
#  'https://www.booking.com/hotel/fr/maisondumondehotelandsuitesmarseille.fr.html',
#  'https://www.booking.com/hotel/fr/le-panier-enchante-suites-amp-spa.fr.html',
#  'https://www.booking.com/hotel/fr/toyoko-inn-marseille-saint-charles.fr.html',
#  'https://www.booking.com/hotel/fr/appt-t3-tout-neuf-metro-perier-calme-parking.fr.html',
#  'https://www.booking.com/hotel/fr/charmant-appartement-4-pers-2-ch-centre-proche-mer.fr.html',
#  'https://www.booking.com/hotel/fr/holiday-inn-express-marseille-saint-charles.fr.html',
#  'https://www.booking.com/hotel/fr/hermes.fr.html',
#  'https://www.booking.com/hotel/fr/premiere-classe-marseille-centre-xml.fr.html',
#  'https://www.booking.com/hotel/fr/montempo-marseille-centre.fr.html',
#  'https://www.booking.com/hotel/fr/residhome-marseille-saint-charles.fr.html',
#  'https://www.booking.com/hotel/fr/seven-urban-suites.fr.html',
#  'https://www.booking.com/hotel/fr/vieux-port-47-les-augustins.fr.html',
#  'https://www.booking.com/hotel/fr/residhotel-vieux-port.fr.html',
#  'https://www.booking.com/hotel/fr/les-jardins-du-ga-c-na-c-ral.fr.html',
#  'https://www.booking.com/hotel/fr/pullman-palm-beach-marseille.fr.html',
#  'https://www.booking.com/hotel/fr/citadines-aparthotel-marseilleprado.fr.html',
#  'https://www.booking.com/hotel/fr/staycity-aparthotels-centre-vieux-port.fr.html',
#  'https://www.booking.com/hotel/fr/vertigo-vieux-port-marseille.fr.html',
#  'https://www.booking.com/hotel/fr/citadines-aparthotel-marseillepradochanot.fr.html',
#  'https://www.booking.com/hotel/fr/appartements-lucas-de-montigny.fr.html',
#  'https://www.booking.com/hotel/fr/appartement-le-paradiso-le-charme-et-le-calme-en-plein-centre-ville.fr.html',
#  'https://www.booking.com/hotel/fr/une-oasis-au-pays-de-cezanne.fr.html',
#  'https://www.booking.com/hotel/fr/le-mas-des-pignes.fr.html',
#  'https://www.booking.com/hotel/fr/ersextius-ib-aix-en-provence.fr.html',
#  'https://www.booking.com/hotel/fr/luxueux-studio-aix-historique-pavillon-vendome.fr.html',
#  'https://www.booking.com/hotel/fr/t2-aix-en-provence-aix-en-provence1.fr.html',
#  'https://www.booking.com/hotel/fr/studio-centre-historique.fr.html',
#  'https://www.booking.com/hotel/fr/granet-studio.fr.html',
#  'https://www.booking.com/hotel/fr/ma-place-au-sud-aix-centre.fr.html',
#  'https://www.booking.com/hotel/fr/appartement-coeur-historique-aix.fr.html',
#  'https://www.booking.com/hotel/fr/le-bedarride.fr.html',
#  'https://www.booking.com/hotel/fr/appartement-luxe-terrasse-climatisation-centre-d-aix.fr.html',
#  'https://www.booking.com/hotel/fr/aix-en-provence-charmant-studio-proche-toutes-comodites-et-axes-routiers-linges.fr.html',
#  'https://www.booking.com/hotel/fr/renaissance-aix-en-provence.fr.html',
#  'https://www.booking.com/hotel/fr/a-balcony-in-the-heart-of-aix-en-provence.fr.html',
#  'https://www.booking.com/hotel/fr/charming-apartment-with-balcony-and-garage-near-the-city-center-of-aix.fr.html',
#  'https://www.booking.com/hotel/fr/appartement-aix-centre-historique-sauna-jacuzzi-balneo-privatif.fr.html',
#  'https://www.booking.com/hotel/fr/zola-studio.fr.html',
#  'https://www.booking.com/hotel/fr/royal-mirabeau.fr.html',
#  'https://www.booking.com/hotel/fr/le-castelet-les-saintes-maries-de-la-mer.fr.html',
#  'https://www.booking.com/hotel/fr/casa-marina-saintes-maries-de-la-mer.fr.html',
#  'https://www.booking.com/hotel/fr/thalacap-camargue.fr.html',
#  'https://www.booking.com/hotel/fr/le-dauphin-bleu.fr.html',
#  'https://www.booking.com/hotel/fr/oh-campings.fr.html',
#  'https://www.booking.com/hotel/fr/mas-de-pioch.fr.html',
#  'https://www.booking.com/hotel/fr/les-palmiers-en-camargue.fr.html',
#  'https://www.booking.com/hotel/fr/les-rizieres.fr.html',
#  'https://www.booking.com/hotel/fr/ra-c-sidence-palma.fr.html',
#  'https://www.booking.com/hotel/fr/abrivado.fr.html',
#  'https://www.booking.com/hotel/fr/auberge-cavaliere-saintes-maries-de-la-mer.fr.html',
#  'https://www.booking.com/hotel/fr/ha-tel-les-arcades.fr.html',
#  'https://www.booking.com/hotel/fr/mangio-fango.fr.html',
#  'https://www.booking.com/hotel/fr/le-neptune-en-camargue.fr.html',
#  'https://www.booking.com/hotel/fr/l-39-appartement-de-l-39-eglise.fr.html',
#  'https://www.booking.com/hotel/fr/camille.fr.html',
#  'https://www.booking.com/hotel/fr/appartement-calme-a-deux-pas-de-la-mer.fr.html',
#  'https://www.booking.com/hotel/fr/oh-campings-la-brise.fr.html',
#  'https://www.booking.com/hotel/fr/auberge-de-la-fadaise.fr.html',
#  'https://www.booking.com/hotel/fr/l-39-estrambord-de-camargue.fr.html']

# %%
r_adresses = requests.get('{}'.format(url_list[0]), headers = {'User-Agent': 'Mozilla/5.0 (Linux; Android 6.0; Nexus 5 Build/MRA58N) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/108.0.0.0 Mobile Safari/537.36'})
soup = BeautifulSoup(r_adresses.content, "html.parser")

# %%
link = soup.find_all('p',{"class":"address address_clean"})

# %%
link = soup.find('p', class_='address address_clean').find(id='hotel_address')
# Out:
#   Input In [108]
#     link = soup.find('p', class='address address_clean').find(id='hotel_address')
#                           ^
# SyntaxError: invalid syntax

# %%
print(link)
# Out:
# None

# %%
from lxml import etree

# %%
dom = etree.HTML(str(soup))
dom
# Out:
# <Element html at 0x7f973d951fc0>

# %%
dom = etree.HTML(str(soup))
print(dom.xpath('//*[@id="hotel_address"]'))
# Out:
# []

# %%
latlng = link['data-atlas-latlng']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [55], in <cell line: 1>()
# ----> 1 latlng = link['data-atlas-latlng']
#
# TypeError: 'NoneType' object is not subscriptable

# %%
soup.select('#show_map')
# Out:
# <!DOCTYPE html>
# <!--
# You know you could be getting paid to poke around in our code?
# We're hiring designers and developers to work in Amsterdam:
# https://careers.booking.com/
# --><!-- mdot-548 --><html class="no-js" lang="fr">
# <head>
# <link crossorigin="" href="https://cf.bstatic.com" rel="dns-prefetch"/>
# <link crossorigin="" href="https://cf.bstatic.com" rel="dns-prefetch"/>
# <script nonce="jsicrug1FljeF7D" type="text/javascript">
# document.addEventListener('DOMContentLoaded', function () {
# /**
# * provides the current user's cookie consent
# * in order to use it:
# * 1. inline privacy/cookieConsent.js in the page you need to use it.
# * please note that this library relies on window.PCM.isCountryNeedCookieBanner to be initialised
# * before using (calling getValue function) it
# * 2. in your js file:
# *
# * var privacyCookieConsent = B.require('privacyCookieConsent');
# * var consent = privacyCookieConsent.getValue();
# */
# B.define('privacyCookieConsent', function () {
# var consentGroupIsAllowed = {
# analytical: 'C0002%3A1',
# marketing: 'C0004%3A1'
# };
# var optanonConsentCookieName = 'OptanonConsent';
# var optanonBoxClosedCookieName = 'OptanonAlertBoxClosed';
# var halfOfYearMillis = 180 * 24 * 60 * 60 * 1000;
# function isDefined(value) {
# return value && value !== "undefined";
# }
# function parseConsentToObject(consent) {
# var result = {};
# if (typeof consent === 'string') {
# var parts = consent.split('&');
# parts.forEach(function (part) {
# var keyAndValue = part.split('=');
# result[keyAndValue[0]] = keyAndValue[1];
# });
# }
# return result;
# }
# function isConsentValid(consent, alertBoxClosed) {
# return isDefined(consent) &&
# isDefined(alertBoxClosed) &&
# new Date() - new Date(alertBoxClosed) <= halfOfYearMillis;
# }
# function getCookie(name) {
# name += "=";
# var cookies = document.cookie.split(";");
# for (var i = 0; i < cookies.length; i += 1) {
# var cookie = cookies[i];
# while (cookie.charAt(0) === " ") {
# cookie = cookie.substring(1, cookie.length);
# }
# if (cookie.indexOf(name) === 0) {
# return cookie.substring(name.length, cookie.length);
# }
# }
# return null;
# }
# function doesGeolocationRequireBanner() {
# // In case window.PCM is not defined, fallback to opt-out
# return window.PCM ? window.PCM.isCountryNeedCookieBanner : true;
# }
# function getExplicitConsent() {
# var consent = getCookie(optanonConsentCookieName);
# var alertBoxClosed = getCookie(optanonBoxClosedCookieName);
# if (isConsentValid(consent, alertBoxClosed)) {
# var consentObject = parseConsentToObject(consent);
# return Object
# .keys(consentGroupIsAllowed)
# .map(function (purpose) {
# var result = {};
# result[purpose] = consentObject.groups.indexOf(consentGroupIsAllowed[purpose]) > -1;
# return result;
# })
# .reduce(
# function (result, currentValue) {
# return Object.assign(result, currentValue);
# }, {
# functional: true
# }
# );
# }
# }
# function getImplicitConsent() {
# var consentValue = !doesGeolocationRequireBanner();
# return {
# functional: true,
# analytical: consentValue,
# marketing: consentValue
# };
# }
# function getValue() {
# var consent = getExplicitConsent();
# if (!consent) {
# consent = getImplicitConsent();
# }
# return consent;
# }
# return {
# getValue: getValue
# };
# });
# //c360 javascript tracker first iteration
# //sends a track request to c360 http tracker
# //in order to use it:
# //1. inline the c360Tracker.js in the page you need to use it
# //2. in your js file:
# //
# // var c360Tracker = B.require('c360Tracker');
# // var event = {
# // action_name:"accommodation_checkout_confirmation_viewed",
# // action_version :"0.2.0",
# // content : { "transaction_id" : 123434},
# // user : { "BKNG_user_id": 123434}
# // };
# // c360Tracker.track(event);
# B.define('c360Tracker', function () {
# var enrichedContext = {};
# var configuration = {
# validateInput: false
# };
# var track = function (event) {
# if (event == null) {
# return "event object is null or empty";
# } else {
# //if (enrichedContext.userID != null) {
# // event.user = {BKNG_user_id: enrichedContext.userID};
# //}
# var validationResult = new ValidationResult(true);
# if (configuration.validateInput) {
# validationResult = validateInput(event);
# }
# if (!validationResult.success) {
# return validationResult.message;
# }
# send(event);
# }
# };
# function send(data) {
# data.context = enrichedContext;
# data.tracker = {
# tracker_name: "C360JSTracker",
# tracker_type: "Client",
# tracker_version: "0.1.0"
# };
# return $.ajax({
# url: '/c360/v1/track',
# type: 'POST',
# data: JSON.stringify(data),
# });
# }
# enrich();
# var scheme =
# {
# "type": "object",
# "properties": {
# "action_name": {
# "type": "string",
# "description": "action name (ex. element viewed)",
# },
# "action_version": {
# "type": "string",
# "description": "action version"
# },
# "content": {
# "type": "object",
# "description": "content defined by the registered producer scheme"
# }
# }
# };
# function ValidationResult(success, message) {
# this.success = success;
# this.message = message;
# }
# function validateInput(event) {
# var result = validateObject(event, scheme);
# return result;
# }
# function validateObject(obj, scheme) {
# if (scheme.properties != null) {
# var propsArray = Object.getOwnPropertyNames(scheme.properties);
# for (var i = 0; i < propsArray.length; i++) {
# var propertyName = propsArray[i];
# if (obj[propertyName] == null) {
# return new ValidationResult(false, "property " + propertyName + " is not defined");
# }
# if (scheme.properties[propertyName].type == "object") {
# var validationResult = validateObject(obj[propertyName], scheme.properties[propertyName]);
# if (validationResult.success === false) {
# return validationResult;
# }
# }
# }
# }
# return new ValidationResult(true);
# }
# function enrich() {
# enrichedContext = {
# page: {
# page_referrer: document.referrer,
# page_url: window.location.href,
# page_title: document.title
# },
# local: {
# currency: B.env.b_selected_currency
# },
# };
# //if (B.env.b_user_genius_status != null && B.env.b_user_genius_status.b_user_id != null)
# // enrichedContext.userID = B.env.b_user_genius_status.b_user_id;
# }
# return {
# track: track
# };
# });
# })
# </script>
# <script nonce="jsicrug1FljeF7D" src="https://cdn.cookielaw.org/consent/3ea94870-d4b1-483a-b1d2-faf1d982bb31/OtAutoBlock.js" type="text/javascript"></script>
# <script nonce="jsicrug1FljeF7D" type="text/javascript">
# (function () {
# document.addEventListener('cookie_banner_closed', function(e) {
# if (window.PCM && window.B && window.B.et) {
# window.B.et.goal((window.PCM.Marketing || window.PCM.Analytical) ? 'cookie_consent_accepted_policy_banner' : 'cookie_consent_declined_policy_banner');
# }
# });
# document.addEventListener('click', function(e) {
# if (e.target && e.target.classList.contains('ot-preference-center-footer')) {
# e.preventDefault();
# Optanon && Optanon.ToggleInfoDisplay();
# }
# });
# })();
# </script>
# <script nonce="jsicrug1FljeF7D" type="text/javascript">
# window.PCM = {
# isCountryNeedCookieBanner: 1,
# loadStartedAt: 1673304642
# }
# </script>
# <script data-domain-script="3ea94870-d4b1-483a-b1d2-faf1d982bb31" nonce="jsicrug1FljeF7D" src="https://cf.bstatic.com/libs/privacy-consent/releases/2.1.36/customer/cookie-banner.min.js" type="text/javascript"></script>
# <link crossorigin="" href="https://shelves.booking.com/" rel="preconnect"/>
# <meta charset="utf-8"/>
# <script nonce="jsicrug1FljeF7D">
# document.documentElement.className = document.documentElement.className.replace(/\bno-js\b/, 'has-js js-is-loading');
# </script>
# <meta content="origin-when-cross-origin" name="referrer"/>
# <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <style id="top_bar_inline_style"> html {  background: url("...") 0 0 repeat-x;  } </style><script nonce="jsicrug1FljeF7D">(function(d) { var b = d.createElement('body'); d.documentElement.appendChild(b); window.__temporary_body = b; }(document));</script>
# <script nonce="jsicrug1FljeF7D"> function b_cors_check(supported) { var value = supported ? 1 : 0; if (!/(^|;)\s*cors_js=/.test(document.cookie)) { var d = new Date(); d.setTime(d.getTime() + 60 * 60 * 24 * 365 * 1000); var cookieDomain = '.booking.com' || '.booking.com'; document.cookie = 'cors_js=' + value +'; domain=' + cookieDomain + '; path=/; expires=' + d.toGMTString(); } if (!value) { location.reload(); } } </script>
# <script nonce="jsicrug1FljeF7D">(function(d) { d.addEventListener('error', function(e) { if (e.target && e.target.classList.contains('crossorigin-check-js')) { b_cors_check(false); } }, true); })(document); </script>
# <script async="" class="crossorigin-check-js" crossorigin="" nonce="jsicrug1FljeF7D" src="https://cf.bstatic.com/static/js/crossorigin_check_cloudfront_sd/2454015045ef79168d452ff4e7f30bdadff0aa81.js"></script>
# <script nonce="jsicrug1FljeF7D">
# ;(function() {
# window.b_early_errors = window.b_early_errors || [];
# window.onerror = function() {
# window.b_early_errors.push(arguments);
# };
# }());
#  </script>
# <script nonce="jsicrug1FljeF7D">(function(d) { d.addEventListener('load', function(e) { if (e.target && e.target.classList.contains('stylesheet-preload')) { e.target.rel='stylesheet'; } }, true); })(document); </script>
# <style nonce="jsicrug1FljeF7D">template,.g-hidden{display:none !important}p.error{line-height:18px;color:#A30000;font-weight:bold;margin:10px}html.no-js .no-js-hidden{display:none}body.rtlcss{direction:rtl}.no-js .js-loading-hidden,.js-is-loading .js-loading-hidden,.css-is-loading .css-loading-hidden{display:none !important}.no-js .js-loading-invisible,.js-is-loading .js-loading-invisible,.css-is-loading .css-loading-invisible{visibility:hidden !important}.css-loading-inline-visible{display:none !important}.css-is-loading .css-loading-inline-visible{display:inline-block !important}.searchbox_redesign select[disabled]{color:#BDBDBD}body,div,dl,dt,dd,ul,ol,li,h1,h2,h3,h4,h5,h6,pre,form,fieldset,input,textarea,p,blockquote,th,td{margin:0;padding:0}fieldset,img{border:0}address,caption,cite,code,dfn,em,strong,th,var{font-style:normal;font-weight:normal}q:before,q:after{content:''}abbr,acronym{border:0}body,input,select,button,textarea{font-family:BlinkMacSystemFont,-apple-system,Segoe UI,Roboto,Helvetica,Arial,sans-serif}.rtl,.rtlcss{direction:rtl}.ltr{direction:ltr}.rtlcss .bui-carousel__next,.rtlcss .bui-carousel__prev{transform:scaleX(-1)}body>img,body>iframe[src*="doubleclick.net"]{display:block;margin-top:-1px}a{color:var(--bui_color_action_foreground)}a:link{text-decoration:underline}ol,ul{list-style:none}body{background:var(--bui_color_white);color:#333333;-webkit-text-size-adjust:100%}table{border-collapse:collapse;border-spacing:0}th{text-align:left}.rtlcss th{text-align:right}h1,h2,h3,h4,h5,h6{font-weight:normal}h1{font-weight:bold;margin:10px}h2{font-weight:bold;display:block;margin:0;padding-left:10px;padding-top:2px}.header_profile_btn{font-size:22px;font-weight:normal;padding-left:10px;padding-right:10px;width:auto}.header_profile_btn__genius{font-size:13px}.header_profile_btn .bicon{color:var(--bui_color_white)}.header_profile_btn__genius--svg{padding:0 3px}.genius-profile-icon--svg{margin-top:5px}.searchbox_dest.input_clear_button_input::-webkit-search-cancel-button,.input_destination.input_clear_button_input::-webkit-search-cancel-button{display:none}.input_clear_button{-webkit-tap-highlight-color:rgba(0,0,0,0);background:transparent;border:0;color:#999999;height:100%;font-size:12px;padding:0;opacity:0;outline:none;position:absolute;top:0;transition:opacity .25s;width:38px;z-index:5}.ltr .input_clear_button{padding-left:7px;right:0}.rtl .input_clear_button{padding-right:7px;left:0}.rtlcss .input_clear_button{padding-right:7px;left:0}.searchbox_redesign--destination-focused .input_clear_button,.has-dest-value .input_clear_button,.gps-possible .input_clear_button{opacity:1}.input_clear_button:active{color:var(--bui_color_black);background-color:transparent}.cookie-warning{font-size:13px;display:flex;overflow:hidden;max-height:500px;transition:opacity .3s,max-height 0s .3s;color:var(--bui_color_white);background:#212121;box-shadow:inset 0 -1px var(--bui_color_black);flex-flow:row-reverse nowrap;align-items:center}.cookie-warning__flag{position:absolute;opacity:0}.cookie-warning__flag:checked + .cookie-warning{max-height:0;opacity:0}.cookie-warning__text{overflow:hidden;flex:1 1 auto}.cookie-warning__text,.cookie-warning__close{margin:10px}.cookie-warning__close{padding:4px 6px;border-radius:5px;background:#0071C2;flex:0 0 auto}.cookie-warning__close:active{background:#BAD4F7}.cookie-warning.site-header--sticky{margin-top:40px}.cookie-warning-v2{z-index:1003;position:fixed;bottom:0;left:0;width:100%;background-color:var(--bui_color_white);border-top:1px solid #E6E6E6;text-align:left;color:#333333}.cookie-warning-v2__banner{padding:4px 10px 0 10px;@apply --bui_font_body_2}.cookie-warning-v2__banner-title{margin-bottom:8px}.cookie-warning-v2__more-details,.cookie-warning-v2__settings{z-index:400;overflow-x:auto}.cookie-warning-v2__footer{margin-top:16px}.cookie-warning-v2__footer--text-center{text-align:center}.cookie-warning-v2__header{margin-top:16px}.cookie-warning-v2__header-paragraph{margin:14px 0}.cookie-warning-v ...
# <link href="https://cf.bstatic.com/mobile/css/core_cloudfront_sd.iq_ltr/3bb21c0e928d519db4d47c8cfd94e312a3ab3967.css" rel="stylesheet"/>
# <link href="https://cf.bstatic.com/mobile/css/app_cloudfront_sd.iq_ltr/e16be98e129831fa6c30dbd237d88e38571b5ec1.css" rel="stylesheet"/>
# <link href="https://cf.bstatic.com/mobile/css/hotel_cloudfront_sd.iq_ltr/75ef1bd9193a6bbd6a7c51a81739887cd181cf62.css" rel="stylesheet"/>
# <link href="https://cf.bstatic.com/mobile/css/iq_m_type_overrides_cloudfront_sd.iq_ltr/f02caf6b2406afbf6d7eb2fa20a77b92f18d062f.css" rel="stylesheet"/>
# <link as="script" crossorigin="" href="https://cf.bstatic.com/mobile/js/core-deps-inlinedet_cloudfront_sd/97754f5bf295ed27240e6fb859eb624545b055b1.js" nonce="jsicrug1FljeF7D" rel="preload"/>
# <link as="script" crossorigin="" href="https://cf.bstatic.com/mobile/js/core_cloudfront_sd/d3f18df59f626fe9824a288059ff18e54ff0e45f.js" nonce="jsicrug1FljeF7D" rel="preload"/>
# <link as="script" crossorigin="" href="https://cf.bstatic.com/mobile/js/app_cloudfront_sd/bb33649b75c2b045c42414344e1ad03c5ff509ca.js" nonce="jsicrug1FljeF7D" rel="preload"/>
# <link as="script" crossorigin="" href="https://cf.bstatic.com/mobile/js/hotel_cloudfront_sd/97f17ca1b98d3c589759912079788ee1175dbfda.js" nonce="jsicrug1FljeF7D" rel="preload"/>
# <link as="script" crossorigin="" href="https://cf.bstatic.com/static/js/error_catcher_bec_cloudfront_sd/0acd2ada6c74d5dec978a04ea837952bdf050cd2.js" nonce="jsicrug1FljeF7D" rel="preload"/>
# <script nonce="jsicrug1FljeF7D"> if( window.performance && performance.measure && 'b-stylesheets') { performance.measure('b-stylesheets'); } </script><link href="https://www.booking.com/hotel/fr/homestay-bormes-bormes-les-mimosas.en-gb.html" hreflang="en-gb" rel="alternate" title="English (UK)" type="text/html"/>
# <link href="https://www.booking.com/hotel/fr/homestay-bormes-bormes-les-mimosas.html" hreflang="en-us" rel="alternate" title="English (US)" type="text/html"/>
# <link href="https://www.booking.com/hotel/fr/homestay-bormes-bormes-les-mimosas.de.html" hreflang="de" rel="alternate" title="Deutsch" type="text/html"/>
# <link href="https://www.booking.com/hotel/fr/homestay-bormes-bormes-les-mimosas.nl.html" hreflang="nl" rel="alternate" title="Nederlands" type="text/html"/>
# <link href="https://www.booking.com/hotel/fr/homestay-bormes-bormes-les-mimosas.fr.html" hreflang="fr" rel="alternate" title="Français" type="text/html"/>
# <link href="https://www.booking.com/hotel/fr/homestay-bormes-bormes-les-mimosas.es.html" hreflang="es" rel="alternate" title="Español" type="text/html"/>
# <link href="https://www.booking.com/hotel/fr/homestay-bormes-bormes-les-mimosas.es-ar.html" hreflang="es-ar" rel="alternate" title="Español (AR)" type="text/html"/>
# <link href="https://www.booking.com/hotel/fr/homestay-bormes-bormes-les-mimosas.es-mx.html" hreflang="es-mx" rel="alternate" title="Español (MX)" type="text/html"/>
# <link href="https://www.booking.com/hotel/fr/homestay-bormes-bormes-les-mimosas.ca.html" hreflang="ca" rel="alternate" title="Català" type="text/html"/>
# <link href="https://www.booking.com/hotel/fr/homestay-bormes-bormes-les-mimosas.it.html" hreflang="it" rel="alternate" title="Italiano" type="text/html"/>
# <link href="https://www.booking.com/hotel/fr/homestay-bormes-bormes-les-mimosas.pt-pt.html" hreflang="pt-pt" rel="alternate" title="Português (PT)" type="text/html"/>
# <link href="https://www.booking.com/hotel/fr/homestay-bormes-bormes-les-mimosas.pt-br.html" hreflang="pt-br" rel="alternate" title="Português (BR)" type="text/html"/>
# <link href="https://www.booking.com/hotel/fr/homestay-bormes-bormes-les-mimosas.no.html" hreflang="no" rel="alternate" title="Norsk" type="text/html"/>
# <link href="https://www.booking.com/hotel/fr/homestay-bormes-bormes-les-mimosas.fi.html" hreflang="fi" rel="alternate" title="Suomi" type="text/html"/>
# <link href="https://www.booking.com/hotel/fr/homestay-bormes-bormes-les-mimosas.sv.html" hreflang="sv" rel="alternate" title="Svenska" type="text/html"/>
# <link href="https://www.booking.com/hotel/fr/homestay-bormes-bormes-les-mimosas.da.html" hreflang="da" rel="alternate" title="Dansk" type="text/html"/>
# <link href="https://www.booking.com/hotel/fr/homestay-bormes-bormes-les-mimosas.cs.html" hreflang="cs" rel="alternate" title="Čeština" type="text/html"/>
# <link href="https://www.booking.com/hotel/fr/homestay-bormes-bormes-les-mimosas.hu.html" hreflang="hu" rel="alternate" title="Magyar" type="text/html"/>
# <link href="https://www.booking.com/hotel/fr/homestay-bormes-bormes-les-mimosas.ro.html" hreflang="ro" rel="alternate" title="Română" type="text/html"/>
# <link href="https://www.booking.com/hotel/fr/homestay-bormes-bormes-les-mimosas.ja.html" hreflang="ja" rel="alternate" title="日本語" type="text/html"/>
# <link href="https://www.booking.com/hotel/fr/homestay-bormes-bormes-les-mimosas.zh-cn.html" hreflang="zh-cn" rel="alternate" title="简体中文" type="text/html"/>
# <link href="https://www.booking.com/hotel/fr/homestay-bormes-bormes-les-mimosas.zh-tw.html" hreflang="zh-tw" rel="alternate" title="繁體中文" type="text/html"/>
# <link href="https://www.booking.com/hotel/fr/homestay-bormes-bormes-les-mimosas.pl.html" hreflang="pl" rel="alternate" title="Polski" type="text/html"/>
# <link href="https://www.booking.com/hotel/fr/homestay-bormes-bormes-les-mimosas.el.html" hreflang="el" rel="alternate" title="Ελληνικά" type="text/html"/>
# <link href="https://www.booking.com/hotel/fr/homestay-bormes-bormes-les-mimosas.ru.html" hreflang="ru" rel="alternate" title="Русский" type="text/html"/>
# <link href="https://www.booking.com/hotel/fr/homestay-bormes-bormes-les-mimosas.tr.html" hreflang="tr" rel="alternate" title="Türkçe" type="text/html"/>
# <link href="https://www.booking.com/hotel/fr/homestay-bormes-bormes-les-mimosas.bg.html" hreflang="bg" rel="alternate" title="Български" type="text/html"/>
# <link href="https://www.booking.com/hotel/fr/homestay-bormes-bormes-les-mimosas.ar.html" hreflang="ar" rel="alternate" title="العربية" type="text/html"/>
# <link href="https://www.booking.com/hotel/fr/homestay-bormes-bormes-les-mimosas.ko.html" hreflang="ko" rel="alternate" title="한국어" type="text/html"/>
# <link href="https://www.booking.com/hotel/fr/homestay-bormes-bormes-les-mimosas.he.html" hreflang="he" rel="alternate" title="עברית" type="text/html"/>
# <link href="https://www.booking.com/hotel/fr/homestay-bormes-bormes-les-mimosas.lv.html" hreflang="lv" rel="alternate" title="Latviski" type="text/html"/>
# <link href="https://www.booking.com/hotel/fr/homestay-bormes-bormes-les-mimosas.uk.html" hreflang="uk" rel="alternate" title="Українська" type="text/html"/>
# <link href="https://www.booking.com/hotel/fr/homestay-bormes-bormes-les-mimosas.id.html" hreflang="id" rel="alternate" title="Bahasa Indonesia" type="text/html"/>
# <link href="https://www.booking.com/hotel/fr/homestay-bormes-bormes-les-mimosas.ms.html" hreflang="ms" rel="alternate" title="Bahasa Malaysia" type="text/html"/>
# <link href="https://www.booking.com/hotel/fr/homestay-bormes-bormes-les-mimosas.th.html" hreflang="th" rel="alternate" title="ภาษาไทย" type="text/html"/>
# <link href="https://www.booking.com/hotel/fr/homestay-bormes-bormes-les-mimosas.et.html" hreflang="et" rel="alternate" title="Eesti" type="text/html"/>
# <link href="https://www.booking.com/hotel/fr/homestay-bormes-bormes-les-mimosas.hr.html" hreflang="hr" rel="alternate" title="Hrvatski" type="text/html"/>
# <link href="https://www.booking.com/hotel/fr/homestay-bormes-bormes-les-mimosas.lt.html" hreflang="lt" rel="alternate" title="Lietuvių" type="text/html"/>
# <link href="https://www.booking.com/hotel/fr/homestay-bormes-bormes-les-mimosas.sk.html" hreflang="sk" rel="alternate" title="Slovenčina" type="text/html"/>
# <link href="https://www.booking.com/hotel/fr/homestay-bormes-bormes-les-mimosas.sr.html" hreflang="sr" rel="alternate" title="Srpski" type="text/html"/>
# <link href="https://www.booking.com/hotel/fr/homestay-bormes-bormes-les-mimosas.sl.html" hreflang="sl" rel="alternate" title="Slovenščina" type="text/html"/>
# <link href="https://www.booking.com/hotel/fr/homestay-bormes-bormes-les-mimosas.vi.html" hreflang="vi" rel="alternate" title="Tiếng Việt" type="text/html"/>
# <link href="https://www.booking.com/hotel/fr/homestay-bormes-bormes-les-mimosas.tl.html" hreflang="tl" rel="alternate" title="Filipino" type="text/html"/>
# <link href="https://www.booking.com/hotel/fr/homestay-bormes-bormes-les-mimosas.is.html" hreflang="is" rel="alternate" title="Íslenska" type="text/html"/>
# <script nonce="jsicrug1FljeF7D">
# (function(){
# document.addEventListener('DOMContentLoaded', function(e) {
# window._pxAppId = 'PXikKuL2RM';
# setTimeout(function() {
# var pxs = document.createElement('script');
# pxs.crossOrigin = 'anonymous';
# pxs.nonce = 'jsicrug1FljeF7D';
# pxs.src = 'https://cf.bstatic.com/libs/perimeterx/px.v7.6.9.min.js';
# document.head.appendChild(pxs);
# }, 750);
# });
# }());
# </script>
# <script nonce="jsicrug1FljeF7D" type="text/javascript">
# window.cspViolationsCount = 0;
# if ('SecurityPolicyViolationEvent' in window) {
# document.addEventListener("securitypolicyviolation", (e) => {
# if (navigator.userAgent.indexOf('Safari') != -1 && navigator.userAgent.indexOf('Chrome') == -1) {
# window.cspViolationsCount++;
# } else if (e.disposition === 'enforce') {
# window.cspViolationsCount++;
# }
# });
# }
# </script>
# <script nonce="jsicrug1FljeF7D" type="application/ld+json">
# {
#    "url" : "https://www.booking.com/hotel/fr/homestay-bormes-bormes-les-mimosas.fr.html",
#    "hasMap" : "https://maps.googleapis.com/maps/api/staticmap?zoom=15&center=43.1464450,6.3277240&markers=color:blue%7c43.1464450,6.3277240&sensor=false&size=1600x1200&client=gme-booking&channel=booking-frontend&signature=Iq2nVOOxsPTbDosqGMXeKhM7KXY=",
#    "aggregateRating" : {
#       "bestRating" : 10,
#       "@type" : "AggregateRating",
#       "ratingValue" : 9.6,
#       "reviewCount" : 115
#    },
#    "name" : "HomeStay Bormes",
#    "description" : "Offrant une vue sur la piscine, le HomeStay Bormes est situé à Bormes-les-Mimosas, à 37 km de la gare de Toulon.",
#    "@type" : "Hotel",
#    "address" : {
#       "@type" : "PostalAddress",
#       "postalCode" : "83230",
#       "addressCountry" : "France",
#       "addressLocality" : "322 Rue des Icares",
#       "addressRegion" : "Provence-Alpes-Côte d'Azur",
#       "streetAddress" : "322 Rue des Icares, 83230 Bormes-les-Mimosas, France"
#    },
#    "@context" : "http://schema.org",
#    "priceRange" : "Tarifs à partir de € 144 par nuit pour les dates à venir (nous ajustons nos tarifs)",
#    "image" : "https://cf.bstatic.com/xdata/images/hotel/max500/253944201.jpg?k=9d5245f251e0484f75a38c814d4026c5b034626e2901466e6106eade750b9046&o=&hp=1"
# }
# </script>
# <script nonce="jsicrug1FljeF7D">(function(b, s) { if (b) { document.documentElement.removeChild(b); if (s) { setTimeout(function() { s.parentNode.removeChild(s); }, 0); } delete window.__temporary_body; } }(window.__temporary_body, document.getElementById('top_bar_inline_style')));</script>
# <link data-chunk="client" href="https://cf.bstatic.com/psb/capla/static/css/bui-react.9ad30b1f.css" nonce="jsicrug1FljeF7D" rel="stylesheet"/><link data-chunk="components-PropertyHighlights-PropertyHighlights" href="https://cf.bstatic.com/psb/capla/static/css/759.68faa5a3.chunk.css" nonce="jsicrug1FljeF7D" rel="stylesheet"/><link data-chunk="components-PropertyTypeBadge-PropertyTypeBadge" href="https://cf.bstatic.com/psb/capla/static/css/1159.644068bb.chunk.css" nonce="jsicrug1FljeF7D" rel="stylesheet"/><link data-chunk="components-BHQualityClassificationBanner-BHQualityClassificationBannerMobile" href="https://cf.bstatic.com/psb/capla/static/css/2417.53844c65.chunk.css" nonce="jsicrug1FljeF7D" rel="stylesheet"/><link data-chunk="components-ReviewBlock-ReviewBlockHeaderMobile-ReviewBlockHeaderMobile" href="https://cf.bstatic.com/psb/capla/static/css/5258.cc2a9c52.chunk.css" nonce="jsicrug1FljeF7D" rel="stylesheet"/><link data-chunk="components-PropertyFeaturedReviews-PropertyFeaturedReviewsMobile-PropertyFeaturedReviewsMobile" href="https://cf.bstatic.com/psb/capla/static/css/9340.c6d5f2bc.chunk.css" nonce="jsicrug1FljeF7D" rel="stylesheet"/><link data-chunk="components-PropertyReviewSubscores-PropertyReviewSubscores" href="https://cf.bstatic.com/psb/capla/static/css/9563.31e4e34d.chunk.css" nonce="jsicrug1FljeF7D" rel="stylesheet"/><link data-chunk="components-PropertyReviewSubscoresPanel-PropertyReviewSubscoresPanel" href="https://cf.bstatic.com/psb/capla/static/css/2659.31e4e34d.chunk.css" nonce="jsicrug1FljeF7D" rel="stylesheet"/><link data-chunk="components-PropertyHealthSafety-PropertyHealthSafetyMobile-PropertyHealthSafetyMobile" href="https://cf.bstatic.com/psb/capla/static/css/4945.c1757387.chunk.css" nonce="jsicrug1FljeF7D" rel="stylesheet"/><link data-chunk="components-PropertyHeaderName-PropertyHeaderName" href="https://cf.bstatic.com/psb/capla/static/css/9599.da64fcc8.chunk.css" nonce="jsicrug1FljeF7D" rel="stylesheet"/><link data-chunk="components-QualityRating-QualityRating" href="https://cf.bstatic.com/psb/capla/static/css/6389.e079c644.chunk.css" nonce="jsicrug1FljeF7D" rel="stylesheet"/><link data-chunk="components-PropertySectionCPC-PropertySectionCPCMobile-PropertySectionCPCMobile" href="https://cf.bstatic.com/psb/capla/static/css/9863.29dc74b7.chunk.css" nonce="jsicrug1FljeF7D" rel="stylesheet"/><link data-chunk="components-PropertyHostProfile-PropertyHostProfileMobile-PropertyHostProfileMobile" href="https://cf.bstatic.com/psb/capla/static/css/4952.a200b848.chunk.css" nonce="jsicrug1FljeF7D" rel="stylesheet"/><link data-chunk="components-PropertyLocationBlock-PropertyLocationBlockMobile-PropertyLocationBlockMobile" href="https://cf.bstatic.com/psb/capla/static/css/1267.e09e75df.chunk.css" nonce="jsicrug1FljeF7D" rel="stylesheet"/><link data-chunk="components-SustainabilityBanner-SustainabilityBannerMobile-SustainabilityBannerMobile" href="https://cf.bstatic.com/psb/capla/static/css/8822.6be19048.chunk.css" nonce="jsicrug1FljeF7D" rel="stylesheet"/><link data-chunk="components-TravelProud-TravelProudBannerMobile" href="https://cf.bstatic.com/psb/capla/static/css/7027.9938cd01.chunk.css" nonce="jsicrug1FljeF7D" rel="stylesheet"/><link data-chunk="components-SustainabilityBadge-SustainabilityBadge" href="https://cf.bstatic.com/psb/capla/static/css/4093.af1418b5.chunk.css" nonce="jsicrug1FljeF7D" rel="stylesheet"/><link data-chunk="components-TripTypeLabelsInfo-PilotBeachBannerMobile-PilotBeachBannerMobile" href="https://cf.bstatic.com/psb/capla/static/css/7918.2b450a0d.chunk.css" nonce="jsicrug1FljeF7D" rel="stylesheet"/><link data-chunk="components-TripTypeLabelsInfo-NonPilotBeachBannerMobile-NonPilotBeachBannerMobile" href="https://cf.bstatic.com/psb/capla/static/css/7439.9938cd01.chunk.css" nonce="jsicrug1FljeF7D" rel="stylesheet"/><link data-chunk="components-TripTypesHotelPage-TopBeachNearbyEntryPointMobile-TopBeachNearbyEntryPointMobile" href="https://cf.bstatic.com/psb/capla/static/css/8355.9938cd01.c ...
# <title>HomeStay Bormes, Bormes-les-Mimosas – Tarifs 2023</title>
# <meta content="Offrant une vue sur la piscine, le HomeStay Bormes est situé à Bormes-les-Mimosas, à 37 km de la gare de Toulon." name="description"/>
# <meta content="HomeStay Bormes, Bormes-les-Mimosas, France, R:Provence-Alpes-Côte d'Azur, Hôtel, Hôtels" name="keywords"/>
# <meta content="index,follow" name="robots"/>
# <link href="https://www.booking.com/hotel/fr/homestay-bormes-bormes-les-mimosas.fr.html" rel="canonical"/>
# <link href="android-app://com.booking/booking/hotel/3981214?affiliate_id=375119" rel="alternate"/>
# <meta content="UmFuZG9tSVYw-47krxxm3fMvCx0niQQiqmo_q9kY7jlXCHm01agqNW3lt34sBzAe7DU3CFPb9ikSQ5nqgSDyjtgH1HNNDjE5oJRtRQV0FsBui8KnIgG4VuAO5CYW0YdRTNqL1WaM14VmOBjkX-lQmlWuLKc3e2Mis4oqW69IU0ZW8264VwPeUYOMTo4xpp2M6EXr-jPt1r3G-VZFHc2bDCPWht_MhFkRDrOh8gWGOK7SyDQpp9Ct4PsShs_FCwsr2q4GkCfV2hU-Uy9mWftQEBsk72PF4-B_ZGoDZf6qu5iPy2lSiYmNH9f6nno80JHRTFiaWBSoK_pPLPcdM9u1D9QEYxmGl7Irw4-J35iMvCxcqI04B1JfA8Tso6vWNTL3XLcE8bF7BUroz4tvcMHIQxkGKmjkAPdfS4CxMNKrbiHUlugqCq4fVR_EPd1yzv3wBNZbSF2vKUo0tqKmPAipzr1cUOibaMseX0ACN7VBdjs" name="booking-verification"/>
# <meta content="367003839" name="twitter:app:id:iphone"/>
# <meta content="Booking.com Hotel Reservations Worldwide &amp; Hotel Deals" name="twitter:app:name:ipad"/>
# <meta content="367003839" name="twitter:app:id:ipad"/>
# <meta content="Booking.com Hotel Reservations" name="twitter:app:name:googleplay"/>
# <meta content="com.booking" name="twitter:app:id:googleplay"/>
# <meta content="367003839" property="al:ios:app_store_id"/>
# <meta content="Booking.com Hotel Reservations" property="al:ios:app_name"/>
# <meta content="Booking.com Hotel Reservation" property="al:android:app_name"/>
# <meta content="com.booking" property="al:android:package"/>
# <meta content="HomeStay Bormes, Bormes-les-Mimosas, France" name="twitter:title"/>
# <meta content="Offrant une vue sur la piscine, le HomeStay Bormes est situé à Bormes-les-Mimosas, à 37 km de la gare de Toulon." name="twitter:description"/>
# <meta content="https://cf.bstatic.com/xdata/images/hotel/max1024x768/253944201.jpg?k=9d5245f251e0484f75a38c814d4026c5b034626e2901466e6106eade750b9046&amp;o=&amp;hp=1" name="twitter:image"/>
# <meta content="https://www.booking.com/hotel/fr/homestay-bormes-bormes-les-mimosas.html?aid=375119&amp;label=gen173nr-1VCAsoTUIiaG9tZXN0YXktYm9ybWVzLWJvcm1lcy1sZXMtbWltb3Nhc0gNWARoTYgBApgBDbgBCcgBEdgBAegBAfgBAogCAagCA7gCwrTynQbAAgLSAiRkZmY4ZTRmMC0wNmJmLTQyMzYtYjJhNi01MTdmNmY3NTNjZmHYAgbgAgE" name="twitter:app:url:iphone"/>
# <meta content="https://www.booking.com/hotel/fr/homestay-bormes-bormes-les-mimosas.html?aid=375119&amp;label=gen173nr-1VCAsoTUIiaG9tZXN0YXktYm9ybWVzLWJvcm1lcy1sZXMtbWltb3Nhc0gNWARoTYgBApgBDbgBCcgBEdgBAegBAfgBAogCAagCA7gCwrTynQbAAgLSAiRkZmY4ZTRmMC0wNmJmLTQyMzYtYjJhNi01MTdmNmY3NTNjZmHYAgbgAgE" name="twitter:app:url:ipad"/>
# <meta content="https://www.booking.com/hotel/fr/homestay-bormes-bormes-les-mimosas.html?aid=375119&amp;label=gen173nr-1VCAsoTUIiaG9tZXN0YXktYm9ybWVzLWJvcm1lcy1sZXMtbWltb3Nhc0gNWARoTYgBApgBDbgBCcgBEdgBAegBAfgBAogCAagCA7gCwrTynQbAAgLSAiRkZmY4ZTRmMC0wNmJmLTQyMzYtYjJhNi01MTdmNmY3NTNjZmHYAgbgAgE" name="twitter:app:url:googleplay"/>
# <meta content="https://www.booking.com/hotel/fr/homestay-bormes-bormes-les-mimosas.html?aid=375119&amp;label=gen173nr-1VCAsoTUIiaG9tZXN0YXktYm9ybWVzLWJvcm1lcy1sZXMtbWltb3Nhc0gNWARoTYgBApgBDbgBCcgBEdgBAegBAfgBAogCAagCA7gCwrTynQbAAgLSAiRkZmY4ZTRmMC0wNmJmLTQyMzYtYjJhNi01MTdmNmY3NTNjZmHYAgbgAgE" property="al:ios:url"/>
# <meta content="https://www.booking.com/hotel/fr/homestay-bormes-bormes-les-mimosas.html?aid=375119&amp;label=gen173nr-1VCAsoTUIiaG9tZXN0YXktYm9ybWVzLWJvcm1lcy1sZXMtbWltb3Nhc0gNWARoTYgBApgBDbgBCcgBEdgBAegBAfgBAogCAagCA7gCwrTynQbAAgLSAiRkZmY4ZTRmMC0wNmJmLTQyMzYtYjJhNi01MTdmNmY3NTNjZmHYAgbgAgE" property="al:android:url"/>
# <meta content="website" property="og:type"/>
# <meta content="HomeStay Bormes" property="og:title"/>
# <meta content="Offrant une vue sur la piscine, le HomeStay Bormes est situ&amp;eacute; &amp;agrave; Bormes-les-Mimosas, &amp;agrave; 37 km de la gare de Toulon." property="og:description"/>
# <meta content="https://cf.bstatic.com/xdata/images/hotel/max1024x768/253944201.jpg?k=9d5245f251e0484f75a38c814d4026c5b034626e2901466e6106eade750b9046&amp;o=&amp;hp=1" property="og:image"/>
# <meta content="https://www.booking.com/hotel/fr/homestay-bormes-bormes-les-mimosas.fr.html" property="og:url"/>
# <meta content="summary_large_image" name="twitter:card"/>
# <meta content="@bookingcom" name="twitter:site"/>
# <meta content="@bookingcom" name="twitter:creator"/>
# <meta content="yes" name="apple-touch-fullscreen"/>
# <meta content="no" name="apple-mobile-web-app-capable"/>
# <meta content="telephone=no" name="format-detection"/>
# <link href="https://cf.bstatic.com/static/img/favicon/ebc77706da3aae4aee7b05dadf182390f0d26d11.ico" rel="shortcut icon"/>
# <link href="https://cf.bstatic.com/static/img/apple-touch-icon_new_lrg/c9b35bf29a75cac2f430f80a5d4bc7fd961d21a7.png" rel="apple-touch-icon"/>
# </head>
# <body class="bookings2 hotel colada fr b_lang_fr new_cta not_webview supportsfixed sevenup ltr mobile_progressive_device offline-message-alternative bp-temp-old-base site_is_mdot m_neutral_bg" data-bui-theme="legacy-light" id="b2hotelPage">
# <div style="display:none;">gogless</div>
# <svg style="display: none"><symbol aria-hidden="true" focusable="false" id="icon-streamline-account_user" role="presentation" viewbox="0 0 24 24"><path d="M16.5 9.75a4.5 4.5 0 1 1-9 0 4.5 4.5 0 0 1 9 0zm1.5 0a6 6 0 1 0-12 0 6 6 0 0 0 12 0zm1.445 10.597c-4.086-4.111-10.732-4.132-14.844-.046l-.046.046a.75.75 0 0 0 1.064 1.058l.04-.04a8.996 8.996 0 0 1 12.722.04.75.75 0 0 0 1.064-1.058zM22.5 12c0 5.799-4.701 10.5-10.5 10.5S1.5 17.799 1.5 12 6.201 1.5 12 1.5 22.5 6.201 22.5 12zm1.5 0c0-6.627-5.373-12-12-12S0 5.373 0 12s5.373 12 12 12 12-5.373 12-12z"></path></symbol><symbol aria-hidden="true" focusable="false" id="icon-streamline-lines_horizontal" role="presentation" viewbox="0 0 24 24"><path d="M2.25 18.753h19.5a.75.75 0 0 0 0-1.5H2.25a.75.75 0 0 0 0 1.5zm0-6h19.5a.75.75 0 0 0 0-1.5H2.25a.75.75 0 0 0 0 1.5zm0-6h19.5a.75.75 0 0 0 0-1.5H2.25a.75.75 0 0 0 0 1.5z"></path></symbol><symbol aria-hidden="true" focusable="false" id="icon-iconset-navarrow_down" role="presentation" viewbox="0 0 128 128"><path d="M64 88L33.2 57.2a4 4 0 0 1 5.6-5.7L64 76.7l25.2-25.2a4 4 0 0 1 5.6 5.7z"></path></symbol><symbol aria-hidden="true" focusable="false" id="icon-fonticon-occupancy" role="presentation" viewbox="0 0 32 32">
# <path d="M21.545 7.285c0 4.032-3.264 7.29-7.29 7.29s-7.29-3.258-7.29-7.29C6.964 3.259 10.229 0 14.254 0s7.291 3.259 7.291 7.285z"></path>
# <path d="M26.378 19.219c-2.041-.952-6.945-1.525-12.035-1.507h-.191c-5.083-.016-9.987.555-12.029 1.507-1.217.555-2.143 1.989-1.999 3.317L.622 32h27.255l.499-9.464c.14-1.329-.787-2.761-1.998-3.317z"></path>
# </symbol><symbol aria-hidden="true" focusable="false" id="icon-iconset-thumbs_up_square" role="presentation" viewbox="0 0 128 128"><path d="M112 8H16a8 8 0 0 0-8 8v96a8 8 0 0 0 8 8h96a8 8 0 0 0 8-8V16a8 8 0 0 0-8-8zM48 96H24V58h24zm56-25a8.7 8.7 0 0 1-2 6 8.9 8.9 0 0 1 1 4 6.9 6.9 0 0 1-5 7c-.5 4-4.8 8-9 8H56V58l10.3-23.3a5.4 5.4 0 0 1 10.1 2.7 10.3 10.3 0 0 1-.6 2.7L72 52h23c4.5 0 9 3.5 9 8a9.2 9.2 0 0 1-2 5.3 7.5 7.5 0 0 1 2 5.7z"></path></symbol><symbol aria-hidden="true" focusable="false" id="icon-streamline-arrow_nav_left" role="presentation" viewbox="0 0 24 24"><path d="M14.55 18a.74.74 0 0 1-.53-.22l-5-5A1.08 1.08 0 0 1 8.7 12a1.1 1.1 0 0 1 .3-.78l5-5a.75.75 0 0 1 1.06 0 .74.74 0 0 1 0 1.06L10.36 12l4.72 4.72a.74.74 0 0 1 0 1.06.73.73 0 0 1-.53.22zm-4.47-5.72zm0-.57z"></path></symbol><symbol aria-hidden="true" focusable="false" id="icon-iconset-navarrow_left" role="presentation" viewbox="0 0 128 128"><path d="M73.7 96a4 4 0 0 1-2.9-1.2L40 64l30.8-30.8a4 4 0 0 1 5.7 5.6L51.3 64l25.2 25.2a4 4 0 0 1-2.8 6.8z"></path></symbol><symbol aria-hidden="true" focusable="false" id="icon-fonticon-search" role="presentation" viewbox="0 0 33 32">
# <path d="M31.909 27.615L21.725 17.431a11.284 11.284 0 0 0 1.727-5.994C23.452 5.121 18.277 0 11.895 0 5.512 0 .339 5.121.339 11.437c0 6.32 5.173 11.439 11.556 11.439 2.287 0 4.413-.666 6.207-1.8l10.174 10.173a2.567 2.567 0 0 0 3.631-.001 2.568 2.568 0 0 0 .002-3.633zm-20.014-9.098c-3.95 0-7.151-3.17-7.151-7.08 0-3.909 3.201-7.078 7.151-7.078s7.152 3.17 7.152 7.078c0 3.91-3.202 7.08-7.152 7.08z"></path>
# </symbol><symbol aria-hidden="true" focusable="false" id="icon-iconset-navarrow_right" role="presentation" viewbox="0 0 128 128"><path d="M54.3 96a4 4 0 0 1-2.8-6.8L76.7 64 51.5 38.8a4 4 0 0 1 5.7-5.6L88 64 57.2 94.8a4 4 0 0 1-2.9 1.2z"></path></symbol></svg>
# <div class="gta-header-banner" data-component="dismissible-item/block" data-item-id="gta_smart_banner">
# <button aria-label="Fermer" class="gta-header-banner__close js-close" type="button">
# <svg class="bk-icon -iconset-close" fill="#333333" height="20" role="presentation" width="20"><use xlink:href="#icon-iconset-close"></use></svg>
# </button>
# <div class="gta-header-banner__icon">
# <img alt="Booking" height="60" src="https://cf.bstatic.com/mobile/images/gta/iphone_app_icon/6a9bd9ce320f24431aa007112917bc9d029be5e0.png" width="60"/>
# </div>
# <div class="gta-header-banner__info">
# <div class="gta-header-banner__title">
# Booking.com
# </div>
# <div class="gta-header-banner__rating-stars">
# <img alt="" border="0" height="15" src="https://cf.bstatic.com/mobile/images/app-marketing/5_stars_2x/aadd2a6faac828024cfa33a8a13dd0b49332e317.png" width="81"/>
# 4,8
# </div>
# <div class="gta-header-banner__rating-nr">
# 785 k notes
# </div>
# </div>
# <div class="gta-header-banner__cta">
# <a class="gta-header-banner__btn" href="https://www.booking.com/apps.fr.html?label=gen173nr-1FCAsoTUIiaG9tZXN0YXktYm9ybWVzLWJvcm1lcy1sZXMtbWltb3Nhc0gNWARoTYgBApgBDbgBCcgBEdgBAegBAfgBAogCAagCA7gCwrTynQbAAgHSAiRkZmY4ZTRmMC0wNmJmLTQyMzYtYjJhNi01MTdmNmY3NTNjZmHYAgXgAgE&amp;amp;sid=63cdf545ef892bc149a03bff162aaa08&amp;amp;app_install=1&amp;amp;lang=fr&amp;amp;site=mdot&amp;amp;page=hotel&amp;amp;placement=GeneralHeaderNew&amp;amp;device=direct&amp;amp;etseed=52616e646f6d49562473646523287d610aca762bfbc0adb16e6182a17b05f533ad6174b83a4bf3f0a9261b77040652a9a1964eecd17341fe425d78559b19d23b&amp;amp;hoff=hotel&amp;amp;dest_countrycode=fr&amp;amp;hotel_id=3981214&amp;amp;room1=A,A" target="_blank">
# Installer
# </a>
# </div>
# </div>
# <div data-component="security/csp_exp_tracker" data-exp-hash="dLcXJeITPMOaOMfXLMEO" style="display: none;"></div>
# <div id="main_container">
# <div class="js-main-content" id="main_content">
# <header class="bui-header bui-header--logo-large js-site-header bui-u-hidden-print">
# <nav class="bui-header__bar">
# <div class="bui-header__main">
# <div class="bui-group bui-group--inline bui-group--small bui-button-group">
# <div class="bui-group__item">
# <a aria-label="Retour" class="bui-button bui-button--light bui-traveller-header__back" href="/searchresults.fr.html?label=gen173nr-1FCAsoTUIiaG9tZXN0YXktYm9ybWVzLWJvcm1lcy1sZXMtbWltb3Nhc0gNWARoTYgBApgBDbgBCcgBEdgBAegBAfgBAogCAagCA7gCwrTynQbAAgHSAiRkZmY4ZTRmMC0wNmJmLTQyMzYtYjJhNi01MTdmNmY3NTNjZmHYAgXgAgE&amp;sid=63cdf545ef892bc149a03bff162aaa08&amp;city=-1413801;checkin=;checkout=;highlighted_hotels=3981214;">
# <span aria-hidden="true" class="bui-button__icon bui-icon bui-icon--larger">
# <svg class="bk-icon -streamline-arrow_nav_left" height="24" width="24"><use xlink:href="#icon-streamline-arrow_nav_left"></use></svg>
# </span>
# </a>
# </div>
# </div>
# <a aria-label="Retour" class="bui-button bui-button--light bui-traveller-header__back-dynamic js-site-header--back">
# <span aria-hidden="true" class="bui-button__icon bui-icon bui-icon--larger">
# <svg class="bk-icon -streamline-arrow_nav_left" height="24" width="24"><use xlink:href="#icon-streamline-arrow_nav_left"></use></svg>
# </span>
# </a>
# </div>
# <div class="bui-group bui-group--inline bui-group--small bui-group--align-end bui-group--vertical-align-middle bui-button-group">
# <div class="bui-group__item">
# <a aria-label="Se connecter" class="bui-button bui-traveller-header__profile bui-button--light bui-button--large js-header-login-link js-header-signin-notification" data-et-click="
# customGoal:YTTHbXNLPVIRPQHUYJWcRQFdLHe:3
# customGoal:YTBUIHOdVLBQRMebfTINfTKe:3
# " data-track-event="header_profile_btn" href="https://account.booking.com/auth/oauth2?state=UvABogA4v8XA-1zqIi292gLzyx9kmmIUcpjBfFgYFHsuLU0N5BGfsXaKM6ZWO-iTLPVtmK9BD5EmYqpLNbcQLqm-LxoDSHR7xJKVjeeYSmlnsfsKbt0NGhiaaGquyV3YrYc5eBarMxZj-1aY0DaHoLeXI9JUjy4E0FejupUZ99G-UA6aUWi4ZgVM00NttmtJ78ayCJIzBcZ_CI9gC0Wvv7eevd2wh33Moo-oZZLow-Hp58s8AyzP_FmzWbexaiZ6ou9I2o3e-C7ZlhAzJrtkfbFF_AIGJLpT7Oxv97hyoalDD74Ox-PDdysPZgyELtMvUdc7&amp;response_type=code&amp;aid=304142&amp;lang=fr&amp;bkng_action=hotel&amp;dt=1673304643&amp;redirect_uri=https%3A%2F%2Fsecure.booking.com%2Flogin.html%3Fop%3Doauth_return&amp;client_id=vO1Kblk7xX9tUn2cpZLS" type="button">
# <span class="bui-button__icon bui-bubble-container">
# <span aria-hidden="true" class="bui-icon bui-icon--large">
# <svg class="bk-icon -streamline-account_user" height="24" width="24"><use xlink:href="#icon-streamline-account_user"></use></svg>
# </span>
# <span class="bui-bubble bui-bubble-container__value bui-bubble--destructive bui-u-hidden js-bui-traveller-header__profile-icon"></span>
# </span>
# </a>
# </div>
# <div class="bui-group__item">
# <button aria-label="Plus de liens, paramètres et assistance" class="bui-button bui-button--light bui-button--large" data-bui-component="Modal.HeaderAsync" data-et-click="
# customGoal:YTTHbXNLPVIRPQHUYJWcRQFdLHe:1
# customGoal:YTBUIHOdBOcaGPaVHXT:5
# customGoal:YTBUIHOdVLBQRMebfTINfTKe:1
# " data-modal-aria-label="Plus de liens, paramètres et assistance" data-modal-arrow-navigation="true" data-modal-close-aria-label="Ferme le menu" data-modal-fill="true" data-modal-full-screen="true" data-modal-header-async-url="/navigation.fr.html?label=gen173nr-1FCAsoTUIiaG9tZXN0YXktYm9ybWVzLWJvcm1lcy1sZXMtbWltb3Nhc0gNWARoTYgBApgBDbgBCcgBEdgBAegBAfgBAogCAagCA7gCwrTynQbAAgHSAiRkZmY4ZTRmMC0wNmJmLTQyMzYtYjJhNi01MTdmNmY3NTNjZmHYAgXgAgE&amp;sid=63cdf545ef892bc149a03bff162aaa08&amp;lang=fr&amp;origin=%2Fhotel%2Ffr%2Fhomestay-bormes-bormes-les-mimosas.fr.html%3Flabel%3Dgen173nr-1FCAsoTUIiaG9tZXN0YXktYm9ybWVzLWJvcm1lcy1sZXMtbWltb3Nhc0gNWARoTYgBApgBDbgBCcgBEdgBAegBAfgBAogCAagCA7gCwrTynQbAAgHSAiRkZmY4ZTRmMC0wNmJmLTQyMzYtYjJhNi01MTdmNmY3NTNjZmHYAgXgAgE%26sid%3D63cdf545ef892bc149a03bff162aaa08%26dist%3D0%3Broom1%3DA%252CA%3Bsb_price_type%3Dtotal%3Btype%3Dtotal%26&amp;origin_action=hotel&amp;;is_ajax=1">
# <span class="bui-button__icon">
# <span aria-hidden="true" class="bui-icon bui-icon--large">
# <svg class="bk-icon -streamline-lines_horizontal" height="24" width="24"><use xlink:href="#icon-streamline-lines_horizontal"></use></svg>
# </span>
# </span>
# </button>
# </div>
# </div>
# </nav>
# </header>
# <div class="tabbed-nav--content tab-active" data-tab-id="main">
# <div class="coronavirus-main-funnel-banner bui-alert--info">
# <div class="bui-alert bui-alert--info" role="status">
# <span class="bui-alert__icon" role="presentation">
# <svg class="bk-icon -streamline-info_sign" fill="&lt;TMPL_V bui_color_complement&gt;" height="24" width="24"><use xlink:href="#icon-streamline-info_sign"></use></svg>
# </span>
# <div class="bui-alert__description js-coronavirus-banner is-collapsed">
# <span class="bui-alert__title js-coronavirus-banner-collapse-button">
# Assistance coronavirus (COVID-19)
# <svg class="bk-icon -streamline-arrow_nav_up" height="24" width="24"><use xlink:href="#icon-streamline-arrow_nav_up"></use></svg>
# </span>
# <p class="bui-alert__text">
# Obtenez les conseils de voyage dont vous avez besoin et consultez les éventuelles restrictions de déplacements avant de partir.
# </p>
# <p class="bui-alert__text">
# <a class="bui-link bui-link--primary" href="https://www.booking.com/covid-19.html?aid=304142&amp;label=gen173nr-1FCAsoTUIiaG9tZXN0YXktYm9ybWVzLWJvcm1lcy1sZXMtbWltb3Nhc0gNWARoTYgBApgBDbgBCcgBEdgBAegBAfgBAogCAagCA7gCwrTynQbAAgHSAiRkZmY4ZTRmMC0wNmJmLTQyMzYtYjJhNi01MTdmNmY3NTNjZmHYAgXgAgE" target="_blank">
# En savoir plus
# </a>
# </p>
# </div>
# </div>
# </div>
# <style>
# .partner_header_wrapper .sw_loyalty_copy { display: none; }
# </style>
# <svg aria-hidden="true" class="bk-icon -genius-new_identity-genius_badge" focusable="false" height="174" role="presentation" style="display:none;" viewbox="0 0 434 174" width="434">
# <g>
# <path d="M418.964 0H14.6335C6.65829 0 0.193115 6.46518 0.193115 14.4404V158.844C0.193115 166.819 6.65829 173.285 14.6335 173.285H418.964C426.939 173.285 433.404 166.819 433.404 158.844V14.4404C433.404 6.46518 426.939 0 418.964 0Z" fill="#004CB8"></path>
# <path d="M375.643 112.057C375.651 112.911 375.418 113.75 374.971 114.478C374.524 115.206 373.881 115.793 373.116 116.173C371.061 117.213 368.774 117.71 366.473 117.617C363.367 117.862 360.262 117.13 357.592 115.523C355.323 114.154 353.571 112.072 352.611 109.602C352.551 109.35 352.431 109.116 352.26 108.921C352.09 108.726 351.874 108.575 351.632 108.483C351.39 108.39 351.129 108.358 350.871 108.39C350.614 108.421 350.368 108.515 350.156 108.664L341.13 112.635C340.869 112.706 340.627 112.837 340.425 113.019C340.223 113.2 340.067 113.426 339.969 113.679C339.87 113.932 339.833 114.205 339.859 114.475C339.885 114.745 339.975 115.005 340.12 115.234C342.038 119.7 345.325 123.441 349.506 125.92C354.638 128.933 360.527 130.412 366.473 130.18C372.448 130.368 378.324 128.621 383.224 125.198C385.473 123.727 387.315 121.711 388.577 119.338C389.839 116.965 390.481 114.312 390.444 111.624C390.444 101.997 383.657 96.1488 370.083 94.079C366.842 93.6288 363.696 92.6533 360.769 91.1909C358.603 90.1801 356.148 88.8082 356.148 87.2198C356.194 86.4783 356.458 85.7669 356.908 85.1757C357.358 84.5845 357.973 84.14 358.676 83.8985C360.848 83.0046 363.187 82.5861 365.535 82.6711C367.779 82.6622 370.001 83.1271 372.054 84.0353C374.107 84.9435 375.945 86.2747 377.448 87.9418C377.63 88.1318 377.849 88.283 378.09 88.3863C378.332 88.4896 378.593 88.5429 378.856 88.5429C379.119 88.5429 379.379 88.4896 379.621 88.3863C379.863 88.283 380.082 88.1318 380.264 87.9418L386.69 82.1657C386.936 82.0362 387.148 81.8492 387.307 81.6204C387.466 81.3917 387.568 81.128 387.603 80.8517C387.639 80.5754 387.607 80.2946 387.511 80.0331C387.415 79.7717 387.257 79.5373 387.051 79.3498C382.053 74.4653 375.569 71.3872 368.625 70.6026C361.681 69.8179 354.673 71.3716 348.712 75.0177C346.74 76.4007 345.146 78.2548 344.074 80.4112C343.002 82.5675 342.487 84.9577 342.574 87.3642C342.567 89.4267 343.001 91.4669 343.848 93.3475C344.695 95.2281 345.935 96.9054 347.484 98.2667C351.292 101.398 355.888 103.422 360.769 104.115C364.771 104.676 368.681 105.769 372.394 107.364C373.334 107.744 374.143 108.391 374.72 109.225C375.297 110.059 375.618 111.043 375.643 112.057Z" fill="white"></path>
# <path d="M282.575 107.509C282.412 110.486 282.839 113.467 283.83 116.279C284.821 119.092 286.358 121.681 288.351 123.899C290.419 125.929 292.885 127.51 295.594 128.541C298.303 129.573 301.196 130.032 304.091 129.891C306.536 129.936 308.973 129.595 311.311 128.881C313.006 128.39 314.631 127.686 316.149 126.787C317.577 125.778 318.951 124.693 320.264 123.538L321.636 126.859C321.861 127.389 322.248 127.834 322.74 128.132C323.232 128.43 323.806 128.566 324.38 128.52H333.766C334.021 128.556 334.281 128.532 334.525 128.451C334.769 128.369 334.991 128.232 335.173 128.05C335.355 127.868 335.493 127.646 335.574 127.401C335.656 127.157 335.679 126.897 335.643 126.642V73.7906C335.635 73.5591 335.579 73.3319 335.478 73.1236C335.377 72.9152 335.233 72.7303 335.056 72.5807C334.879 72.4312 334.673 72.3202 334.451 72.255C334.229 72.1898 333.996 72.1718 333.766 72.2021H321.853C321.598 72.166 321.338 72.1897 321.094 72.2712C320.849 72.3528 320.627 72.49 320.445 72.6721C320.263 72.8542 320.126 73.0761 320.044 73.3203C319.963 73.5646 319.939 73.8244 319.975 74.0794V110.18C318.697 112.152 316.942 113.768 314.871 114.879C312.801 115.99 310.484 116.559 308.134 116.534C306.791 116.632 305.442 116.423 304.191 115.922C302.94 115.422 301.82 114.644 300.914 113.646C299.138 111.504 298.235 108.771 298.387 105.993V73.7906C298.387 72.5631 297.665 71.9133 296.365 71.9133H284.596C283.297 71.9133 282.575 72.5631 282.575 73.7906V107.509Z" fill="white"></path>
# ...
# <path d="M26.347 18.465V-.049H8.531s-4.97.233-4.97 4.745h4.273v13.769h18.514z"></path>
# <path d="M29.196 18.465V-.049h17.816s4.97.233 4.97 4.745h-4.273v13.769H29.195z"></path>
# <path d="M50.558 7.784s.712-2.136 2.848-2.136 2.848 2.136 2.848 2.136v21.363s0 2.136-3.56 2.136H1.424s-2.136.712-2.136-2.848V7.784S0 5.648 2.136 5.648s2.848 2.136 2.848 2.136V23.45c0 .075-.712 2.136 2.136 2.136h40.589c2.974 0 2.848-2.848 2.848-2.848V7.784z"></path>
# <path d="M26.347 23.841v-3.24H7.833v1.424s.071 1.815 1.815 1.815h16.699z"></path>
# <path d="M29.196 23.841v-3.24H47.71v1.424s-.071 1.815-1.815 1.815H29.196z"></path>
# </symbol><symbol aria-hidden="true" focusable="false" id="icon-iconset-city" role="presentation" viewbox="0 0 128 128"><path d="M24 88h8v16h-8zm0-16h8V56h-8zm32 32h8V88h-8zm0-32h8V56h-8zm0-32h8V24h-8zm64 16v60a4 4 0 0 1-4 4H12a4 4 0 0 1-4-4V44a4 4 0 0 1 4-4h28V12a4 4 0 0 1 4-4h32a4 4 0 0 1 4 4v58.3l5.2-5.1a4 4 0 0 1 5.6 0l5.2 5.1V56a4 4 0 0 1 .3-1.5l8-20a4 4 0 0 1 7.4 0l8 20a4 4 0 0 1 .3 1.5zM16 112h24V48H16zm32 0h24V16H48v96zm32 0h16V81.7l-8-8-8 8zm32-55.2l-4-10-4 10V112h8z"></path></symbol><symbol aria-hidden="true" focusable="false" id="icon-iconset-warning" role="presentation" viewbox="0 0 128 128"><path d="M64 8a56 56 0 1 0 56 56A56 56 0 0 0 64 8zm0 91a8 8 0 1 1 8-8 8 8 0 0 1-8 8zm8-61l-5 39h-6l-5-39a8 8 0 1 1 16 0z"></path></symbol><symbol aria-hidden="true" focusable="false" id="icon-streamline-transport_bus_front" role="presentation" viewbox="0 0 24 24"><path d="M4.5 20.213v1.5a2.25 2.25 0 0 0 4.5 0v-1.5a.75.75 0 0 0-1.5 0v1.5a.75.75 0 0 1-1.5 0v-1.5a.75.75 0 0 0-1.5 0zm13.5 0v1.5a.75.75 0 0 1-1.5 0v-1.5a.75.75 0 0 0-1.5 0v1.5a2.25 2.25 0 0 0 4.5 0v-1.5a.75.75 0 0 0-1.5 0zm1.5-1.5a.75.75 0 0 1-.75.75H5.25a.75.75 0 0 1-.75-.75v-13.5a3.75 3.75 0 0 1 3.75-3.75h7.5a3.75 3.75 0 0 1 3.75 3.75v13.5zm1.5 0v-13.5c0-2.9-2.35-5.25-5.25-5.25h-7.5A5.25 5.25 0 0 0 3 5.213v13.5a2.25 2.25 0 0 0 2.25 2.25h13.5a2.25 2.25 0 0 0 2.25-2.25zM9.75 4.463h4.5a.75.75 0 0 0 0-1.5h-4.5a.75.75 0 0 0 0 1.5zm-6 3h16.5l-.75-.75v7.5l.75-.75H3.75l.75.75v-7.5l-.75.75zm0-1.5a.75.75 0 0 0-.75.75v7.5c0 .414.336.75.75.75h16.5a.75.75 0 0 0 .75-.75v-7.5a.75.75 0 0 0-.75-.75H3.75zm3 12h3a.75.75 0 0 0 0-1.5h-3a.75.75 0 0 0 0 1.5zm7.5 0h3a.75.75 0 0 0 0-1.5h-3a.75.75 0 0 0 0 1.5zm-10.5-10.5h-1.5A2.25 2.25 0 0 0 0 9.713v4.5a.75.75 0 0 0 1.5 0v-4.5a.75.75 0 0 1 .75-.75h1.5a.75.75 0 0 0 0-1.5zm16.5 1.5h1.5a.75.75 0 0 1 .75.75v4.5a.75.75 0 0 0 1.5 0v-4.5a2.25 2.25 0 0 0-2.25-2.25h-1.5a.75.75 0 0 0 0 1.5z"></path></symbol><symbol aria-hidden="true" focusable="false" id="icon-iconset-compass" role="presentation" viewbox="0 0 128 128"><path d="M64 8a56 56 0 1 0 56 56A56 56 0 0 0 64 8zm0 104a48 48 0 1 1 48-48 48 48 0 0 1-48 48zm-6-84a6 6 0 1 1 6 6 6 6 0 0 1-6-6zm12 72a6 6 0 1 1-6-6 6 6 0 0 1 6 6zM28 70a6 6 0 1 1 6-6 6 6 0 0 1-6 6zm78-6a6 6 0 1 1-6-6 6 6 0 0 1 6 6zM95.5 35.7a2 2 0 0 0-.2-2.6l-.4-.4a2 2 0 0 0-2.6-.2L66.7 48.2a16 16 0 0 0-18.5 18.5L32.5 92.3a2 2 0 0 0 .2 2.6l.4.4a2 2 0 0 0 2.6.2l25.6-15.7a16 16 0 0 0 18.5-18.5zM64 72a8 8 0 1 1 8-8 8 8 0 0 1-8 8z"></path></symbol><symbol aria-hidden="true" focusable="false" id="icon-streamline-house-chimney-alt" role="presentation" viewbox="0 0 24 24"><path d="M3.004 13.923v8.25c0 .414.336.75.75.75h6a.75.75 0 0 0 .75-.75v-6a.75.75 0 0 1 .75-.75h1.5a.75.75 0 0 1 .75.75v6c0 .414.336.75.75.75h6a.75.75 0 0 0 .75-.75v-8.25a.75.75 0 0 0-1.5 0v8.25l.75-.75h-6l.75.75v-6a2.25 2.25 0 0 0-2.25-2.25h-1.5a2.25 2.25 0 0 0-2.25 2.25v6l.75-.75h-6l.75.75v-8.25a.75.75 0 0 0-1.5 0zm-1.72-.97l10.19-10.189a.75.75 0 0 1 1.06 0l10.19 10.19a.75.75 0 1 0 1.06-1.061L13.595 1.703a2.25 2.25 0 0 0-3.181 0L.224 11.894a.75.75 0 0 0 1.06 1.06zm15.97-7.28v-1.5l-.75.75h3.75l-.75-.75v5.25a.75.75 0 0 0 1.5 0v-5.25a.75.75 0 0 0-.75-.75h-3.75a.75.75 0 0 0-.75.75v1.5a.75.75 0 0 0 1.5 0z"></path></symbol><symbol aria-hidden="true" focusable="false" id="icon-streamline-fridge" role="presentation" viewbox="0 0 24 24"><path d="M19.5 11.25v9.451a.299.299 0 0 1-.299.299H4.799a.299.299 0 0 1-.299-.299V1.799c0-.165.134-.299.299-.299h14.402c.165 0 .299.134.299.299v9.451zm1.5 0V1.799C21 .805 20.195 0 19.201 0H4.799C3.805 0 3 .805 3 1.799v18.902c0 .994.805 1.799 1.799 1.799h14.402c.994 0 1.799-.805 1.799-1.799V11.25zM6 21.75v1.5a.75.75 0 0 0 1.5 0v-1.5a.75.75 0 0 0-1.5 0zm10.5 0v1.5a.75.75 0 0 0 1.5 0v-1.5a.75.75 0 0 0-1.5 0zM3.75 9h16.5a.75.75 0 0 0 0-1.5H3.75a.75.75 0 0 0 0 1.5zM6 12.75v4.5a.75.75 0 0 0 1.5 0v-4.5a.75.75 0 0 0-1.5 0zm0-9v1.5a.75.75 0 0 0 1.5 0v-1.5a.75.75 0 0 0-1.5 0z"></path></symbol><symbol aria-hidden="true" focusable="false" id="icon-streamline-spa_c ...
# <link href="https://cf.bstatic.com/mobile/css/core_critical_cloudfront_sd.iq_ltr/9470bc8e42256b88b55fa309bed04c4c811e76b5.css" rel="prefetch"/>
# <link href="https://cf.bstatic.com/mobile/css/searchresults_no_filters_cloudfront_sd.iq_ltr/d7a795e9664724c6be913d6ef3718c1ba995f91e.css" rel="prefetch"/>
# <link href="https://cf.bstatic.com/mobile/js/searchresults_cloudfront_sd/f363de7fb0dba77ff856788400d5adc9dce825ec.js" rel="prefetch"/>
# <link href="https://cf.bstatic.com/static/js/et_cloudfront_sd/a5c838dc6079df69f699e35761fd372c0f92ce73.js" rel="prefetch"/>
# <script nonce="jsicrug1FljeF7D">/*eslint no-console: "off"*/
# (function() {
# // Impact mesurement
# window.addEventListener('load', impactRecordLoadTime);
# function impactRecordLoadTime() {
# try {
# if (performance.timing.loadEventEnd == 0) return setTimeout(impactRecordLoadTime, 1000);
# var delta = performance.timing.loadEventEnd - performance.timing.connectStart;
# localStorage.reloadClock = parseInt(localStorage.reloadClock || 0, 10) + delta;
# localStorage.reloadCount = parseInt(localStorage.reloadCount || 0, 10) + 1;
# } catch (o_O) {}
# }
# function impactHasHotReloadActive() {
# try {
# localStorage.reloadHasUsedHotComponent = true;
# } catch (o_O) {}
# }
# var loader = B.require('component/loader');
# // ------------------------------------------------------------------------
# // Toast Config
# function toast(message) {
# var id = 'hot-reload-toast';
# var previousToast = document.getElementById(id);
# if (previousToast) previousToast.remove();
# var toast = document.createElement('div');
# toast.id = id;
# Object.assign(toast.style, {
# background: 'rgba(0,0,0,0.9)',
# boxShadow: '0 2px -2px rgba(0,0,0,0.4)',
# color: '#fff',
# font: 'normal 14px/1.5 sans-serif',
# padding: '8px 12px',
# borderRadius: '4px',
# position: 'fixed',
# bottom: '-30px',
# left: '50%',
# transform: 'translateX(-50%)',
# transition: 'all .2s ease-in-out',
# zIndex: 999999
# });
# toast.textContent = message;
# console.info(message);
# document.body.appendChild(toast);
# setTimeout(function() {
# toast.style.bottom = '40px';
# }, 10);
# setTimeout(function() {
# toast.style.bottom = '-50px';
# }, 2200);
# setTimeout(function() {
# toast.remove();
# }, 2500);
# }
# var Toast = {
# wsStarted: function() {
# toast('Hot reload started');
# },
# wsDisconnected: function() {
# toast('WebSocket server disconnected');
# },
# wsSuccess: function() {
# toast('Hot Reload starting');
# },
# wsFail: function() {
# toast('Failed starting hot reload');
# },
# reloadHTML: function(id) {
# toast('HTML code reloaded - id: ' + id);
# },
# reloadCSS: function() {
# toast('CSS code reloaded');
# },
# reloadJS: function(file, name) {
# toast('JS code reloaded - ' + file + ' - ' + name);
# }
# };
# // ------------------------------------------------------------------------
# // Reload actions
# var Reload = {
# HTML: function reloadHTML(newComponent, attributes) {
# var componentsToReload = [].slice.call(document.querySelectorAll('[data-hot-reload-id]'));
# componentsToReload.forEach(function(componentToReload) {
# if (componentToReload.dataset.hotReloadId === attributes['id']) {
# fetch('https://book.dqs.booking.com/dev/render_tmpl_fiddle', {
# method: 'POST',
# mode: 'cors',
# headers: {
# 'Content-Type': 'application/json; charset=utf-8'
# },
# body: JSON.stringify({
# tmpl: newComponent,
# tmpl_data: JSON.stringify(attributes)
# })
# })
# .then(function(response) {
# return response.json();
# })
# .then(function _reloadHTML(response) {
# componentToReload.innerHTML = response.result;
# Toast.reloadHTML(attributes['id']);
# });
# }
# });
# },
# CSS: function reloadCSS() {
# var links = [].slice.call(document.querySelectorAll('link[rel="stylesheet"][href*="bstatic.com"]'));
# var newLinksOnload = links.map(function(link) {
# return new Promise(function(resolve, reject) {
# var newLink = link.cloneNode();
# document.head.appendChild(newLink);
# newLink.onload = resolve;
# newLink.onerror = resolve;
# return newLink;
# });
# });
# Promise.all(newLinksOnload).then(function() {
# links.forEach(function(link) {
# if (link.parentNode) {
# link.parentNode.removeChild(link);
# }
# });
# });
# Toast.reloadCSS();
# },
# JS: function reloadJS(file, name) {
# var id = btoa(name);
# var url = hotURL(file);
# var elements = $('[data-component=' + name + ']');
# var script = document.getElementById(id);
# if (script) script.remove();
# // 1. destroy existing instances
# elements.each(function(i, node) {
# var self = $(node);
# var c = loader.getComponent(node);
# c && c._destroy && c._destroy();
# self.removeData('component-instance-' + name);
# // Remove event-map delegate listeners
# self.off('*');
# // Clone root node to get rid of all DOM modifications / event listeners
# self.replaceWith(this.cloneNode(true));
# });
# // damn you component-loader.loadAsync !
# setTimeout(function() {
# var componentName = 'component/' + name;
# // 2. remove component module definition
# delete B.require._defined[componentName];
# // 3. load new definition and initialize
# script = document.createElement('script');
# script.onload = function() {
# elements = $('[data-component=' + name + ']');
# if (elements.length) {
# elements.component(name);
# }
# // elements.component(name);
# };
# script.src = url;
# document.getElementsByTagName('head')[0].appendChild(script);
# Toast.reloadJS(file, componentName);
# }, 20);
# }
# };
# function hotReloadCSS(file) {
# var id = btoa(file);
# var url = hotURL(file);
# var link = document.getElementById(id);
# if (!link) {
# var link = createLinkStylesheet(url, id);
# } else {
# forceLinkReload(link);
# }
# }
# function reloadRequestHandler(message) {
# var data = parseJSON(message.data);
# console.info('hot-reload:', data);
# if (!data) return console.error('Could not parse message', message);
# switch (data.type) {
# case 'reload-html':
# return Reload.HTML(data.data.source, data.data.attributes);
# case 'reload-css':
# return Reload.CSS();
# case 'reload-css-inline':
# return hotReloadCSS(data.path);
# case 'reload-js-component':
# return Reload.JS(data.path, data.component);
# case 'full':
# window.location.reload();
# }
# }
# // ------------------------------------------------------------------------
# // WebSocket Config
# function Watcher(options) {
# this.host = (options && options.host) || 'wss://' + location.hostname;
# this.port = (options && options.port) || '3000';
# this.ws = null;
# this.wsURL = this.host + ':' + this.port;
# this.timer = null;
# this.pingInterval = 5000;
# }
# Watcher.prototype.connect = function() {
# if (!window.WebSocket) return Toast.wsStarted();
# if (this.connected) return Toast.wsSuccess();
# var ws = (this.ws = new WebSocket(this.wsURL));
# ws.onopen = this.openHandler.bind(this);
# ws.onclose = this.closeHandler.bind(this);
# ws.onmessage = this.messageHandler.bind(this);
# ws.onerror = this.errorHandler.bind(this);
# };
# Watcher.prototype.disconnect = function() {
# this.ws.close();
# this.connected = false;
# Toast.wsDisconnected();
# };
# Watcher.prototype.start = function() {
# this.connect();
# };
# Watcher.prototype.stop = function() {
# this.disconnect();
# Toast.wsDisconnected();
# };
# Watcher.prototype.openHandler = function() {
# this.connected = true;
# Toast.wsStarted();
# impactHasHotReloadActive();
# };
# Watcher.prototype.closeHandler = function() {
# if (this.connected) Toast.wsDisconnected();
# this.connected = false;
# };
# Watcher.prototype.errorHandler = function(err) {
# if (this.ws.readyState == WebSocket.CLOSING || this.ws.readyState == WebSocket.CLOSED) {
# Toast.wsFail();
# }
# };
# Watcher.prototype.messageHandler = reloadRequestHandler;
# // ------------------------------------------------------------------------
# // Helpers
# function parseJSON(data) {
# try {
# return JSON.parse(data);
# } catch (o_O) {}
# }
# function hotURL(file) {
# return '//' + location.host.replace('booking.com', 'bstatic.com') + '/dev/' + file + '?t=' + Date.now();
# }
# // ------------------------------------------------------------------------
# // CSS Link Helpers
# function forceLinkReload(linkElement) {
# linkElement.href = linkElement.href.replace(/\?.*|$/m, '?t=' + Date.now());
# }
# function createLinkStylesheet(url, id) {
# var link = document.createElement('link');
# if (id) link.id = id;
# link.rel = 'stylesheet';
# link.href = url;
# document.getElementsByTagName('head')[0].appendChild(link);
# }
# // ------------------------------------------------------------------------
# // Hot Reload Config
# window.hotreload = function() {
# var isLocal = /[?&]hotreload=localhost/.test(location.search);
# var kvmAddress = 'https://cf.bstatic.com'.replace('https://', 'wss://').replace('bstatic', 'booking');
# var options = isLocal ? { host: 'ws://localhost' } : { host: kvmAddress };
# new Watcher(options).start();
# };
# var keys = [];
# window.addEventListener(
# 'keydown',
# function(e) {
# if (e.key === 'r') {
# keys.push('r');
# if (keys.length === 3) {
# window.hotreload();
# keys.length = 0;
# }
# } else {
# keys.length = 0;
# }
# },
# false
# );
# if (/[?&]hotreload/.test(location.search)) {
# window.hotreload();
# }
# }());
# </script>
# <span id="req_info" style="display:none;">1657630,1656050|2,1655910,1656050,1625600,1656050|4,1657780</span>
# </div></div></body>
# </html>

# %%
'''adresses_json = []

for i in range(len(url_list)):
    ID = i
    r_adresses = requests.get('https://www.booking.com{}'.format(url_list[i]), headers = {'User-Agent': 'Mozilla/5.0 (Linux; Android 6.0; Nexus 5 Build/MRA58N) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/108.0.0.0 Mobile Safari/537.36'})
    soup = BeautifulSoup(r_adresses.content)
    link = soup.select('a.show_map')
    hotel_adresse = [element.get('data-coords') for element in soup.select('#show_map')][0]
    adresse_lat = float(hotel_adresse.split(",")[1])
    adresse_lon = float(hotel_adresse.split(",")[0])
    adresses_json.append([adresse_lat,adresse_lon])
    
adresses_json

# Conversion de notre liste de coordonnées en DF
hotels_lat_lon = DataFrame(adresses_json)'''
# Out:
# 'adresses_json = []\n\nfor i in range(len(url_list)):\n    ID = i\n    r_adresses = requests.get(\'https://www.booking.com{}\'.format(url_list[i]), headers = {\'User-Agent\': \'Mozilla/5.0 (Linux; Android 6.0; Nexus 5 Build/MRA58N) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/108.0.0.0 Mobile Safari/537.36\'})\n    soup = BeautifulSoup(r_adresses.content)\n    link = soup.select(\'a.show_map\')\n    hotel_adresse = [element.get(\'data-coords\') for element in soup.select(\'#show_map\')][0]\n    adresse_lat = float(hotel_adresse.split(",")[1])\n    adresse_lon = float(hotel_adresse.split(",")[0])\n    adresses_json.append([adresse_lat,adresse_lon])\n    \nadresses_json\n\n# Conversion de notre liste de coordonnées en DF\nhotels_lat_lon = DataFrame(adresses_json)'

# %%
r_adresses = requests.get(URL, headers = {'User-Agent': 'Mozilla/5.0 (Linux; Android 6.0; Nexus 5 Build/MRA58N) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/108.0.0.0 Mobile Safari/537.36'})
soup = BeautifulSoup(r_adresses.content, "html.parser")

# %%
URL
# Out:
# 'https://www.booking.com/hotel/fr/la-lavandiere-bormes-les-mimosas.fr.html'

# %%
soup.findAll('p',{'class',"address address_clean"})[0].find('a').get('data-atlas-latlng')
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Input In [59], in <cell line: 1>()
# ----> 1 soup.findAll('p',{'class',"address address_clean"})[0].find('a').get('data-atlas-latlng')
#
# IndexError: list index out of range

# %%
import requests
from bs4 import BeautifulSoup

URL = 'https://www.booking.com/hotel/fr/la-lavandiere-bormes-les-mimosas.fr.html'
page = requests.get(URL)

soup = BeautifulSoup(page.content, "html.parser")
soup.findAll('p',{'class',"address address_clean"})[0].find('a').get('data-atlas-latlng')
# Out:
# '43.14385490,6.35181560'

# %%
start = time.time()
adresses_json = []

for URL in url_list:
    ID = i
    r_adresses = requests.get(URL)
    soup = BeautifulSoup(r_adresses.content, "html.parser")
    #link = soup.find_all('a', attrs={'id': 'hotel_header'})
    #hotel_loc = soup.find_all('a.jq_tooltip loc_block_link_underline_fix bui-link show_on_map_hp_link show_map_hp_link')
    #hotel_adresse = [x.get('data-atlas-latlng') for x in hotel_loc][0]
    hotel_adresse=soup.findAll('p',{'class',"address address_clean"})[0].find('a').get('data-atlas-latlng')
    #print(hotel_adresse)
    adresse_lat = float(hotel_adresse.split(",")[0])
    adresse_lon = float(hotel_adresse.split(",")[1])
    adresses_json.append([adresse_lat,adresse_lon])
    
adresses_json
end = time.time()
print('Elapsed time: {}'.format(end - start))

# Conversion de notre liste de coordonnées en DF
hotels_lat_lon = DataFrame(adresses_json)
# Out:
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# File /opt/anaconda3/lib/python3.8/site-packages/urllib3/connection.py:174, in HTTPConnection._new_conn(self)
#     173 try:
# --> 174     conn = connection.create_connection(
#     175         (self._dns_host, self.port), self.timeout, **extra_kw
#     176     )
#     178 except SocketTimeout:
#
# File /opt/anaconda3/lib/python3.8/site-packages/urllib3/util/connection.py:72, in create_connection(address, timeout, source_address, socket_options)
#      68     return six.raise_from(
#      69         LocationParseError(u"'%s', label empty or too long" % host), None
#      70     )
# ---> 72 for res in socket.getaddrinfo(host, port, family, socket.SOCK_STREAM):
#      73     af, socktype, proto, canonname, sa = res
#
# File /opt/anaconda3/lib/python3.8/socket.py:918, in getaddrinfo(host, port, family, type, proto, flags)
#     917 addrlist = []
# --> 918 for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
#     919     af, socktype, proto, canonname, sa = res
#
# gaierror: [Errno 8] nodename nor servname provided, or not known
#
# During handling of the above exception, another exception occurred:
#
# NewConnectionError                        Traceback (most recent call last)
# File /opt/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py:703, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     702 # Make the request on the httplib connection object.
# --> 703 httplib_response = self._make_request(
#     704     conn,
#     705     method,
#     706     url,
#     707     timeout=timeout_obj,
#     708     body=body,
#     709     headers=headers,
#     710     chunked=chunked,
#     711 )
#     713 # If we're going to release the connection in ``finally:``, then
#     714 # the response doesn't need to know about the connection. Otherwise
#     715 # it will also try to release it and we'll have a double-release
#     716 # mess.
#
# File /opt/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py:386, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     385 try:
# --> 386     self._validate_conn(conn)
#     387 except (SocketTimeout, BaseSSLError) as e:
#     388     # Py2 raises this as a BaseSSLError, Py3 raises it as socket timeout.
#
# File /opt/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py:1040, in HTTPSConnectionPool._validate_conn(self, conn)
#    1039 if not getattr(conn, "sock", None):  # AppEngine might not have  `.sock`
# -> 1040     conn.connect()
#    1042 if not conn.is_verified:
#
# File /opt/anaconda3/lib/python3.8/site-packages/urllib3/connection.py:358, in HTTPSConnection.connect(self)
#     356 def connect(self):
#     357     # Add certificate verification
# --> 358     conn = self._new_conn()
#     359     hostname = self.host
#
# File /opt/anaconda3/lib/python3.8/site-packages/urllib3/connection.py:186, in HTTPConnection._new_conn(self)
#     185 except SocketError as e:
# --> 186     raise NewConnectionError(
#     187         self, "Failed to establish a new connection: %s" % e
#     188     )
#     190 return conn
#
# NewConnectionError: <urllib3.connection.HTTPSConnection object at 0x7f96c14a91c0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known
#
# During handling of the above exception, another exception occurred:
#
# MaxRetryError                             Traceback (most recent call last)
# File /opt/anaconda3/lib/python3.8/site-packages/requests/adapters.py:440, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     439 if not chunked:
# --> 440     resp = conn.urlopen(
#     441         method=request.method,
#     442         url=url,
#     443         body=request.body,
#     444         headers=request.headers,
#     445         redirect=False,
#     446         assert_same_host=False,
#     447         preload_content=False,
#     448         decode_content=False,
#     449         retries=self.max_retries,
#     450         timeout=timeout
#     451     )
#     453 # Send the request.
#     454 else:
#
# File /opt/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py:785, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     783     e = ProtocolError("Connection aborted.", e)
# --> 785 retries = retries.increment(
#     786     method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#     787 )
#     788 retries.sleep()
#
# File /opt/anaconda3/lib/python3.8/site-packages/urllib3/util/retry.py:592, in Retry.increment(self, method, url, response, error, _pool, _stacktrace)
#     591 if new_retry.is_exhausted():
# --> 592     raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     594 log.debug("Incremented Retry for (url='%s'): %r", url, new_retry)
#
# MaxRetryError: HTTPSConnectionPool(host='www.booking.com', port=443): Max retries exceeded with url: /hotel/fr/paradis.fr.html (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7f96c14a91c0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# Input In [99], in <cell line: 4>()
#       4 for URL in url_list:
#       5     ID = i
# ----> 6     r_adresses = requests.get(URL)
#       7     soup = BeautifulSoup(r_adresses.content, "html.parser")
#       8     #link = soup.find_all('a', attrs={'id': 'hotel_header'})
#       9     #hotel_loc = soup.find_all('a.jq_tooltip loc_block_link_underline_fix bui-link show_on_map_hp_link show_map_hp_link')
#      10     #hotel_adresse = [x.get('data-atlas-latlng') for x in hotel_loc][0]
#
# File /opt/anaconda3/lib/python3.8/site-packages/requests/api.py:75, in get(url, params, **kwargs)
#      64 def get(url, params=None, **kwargs):
#      65     r"""Sends a GET request.
#      66
#      67     :param url: URL for the new :class:`Request` object.
#    (...)
#      72     :rtype: requests.Response
#      73     """
# ---> 75     return request('get', url, params=params, **kwargs)
#
# File /opt/anaconda3/lib/python3.8/site-packages/requests/api.py:61, in request(method, url, **kwargs)
#      57 # By using the 'with' statement we are sure the session is closed, thus we
#      58 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      59 # cases, and look like a memory leak in others.
#      60 with sessions.Session() as session:
# ---> 61     return session.request(method=method, url=url, **kwargs)
#
# File /opt/anaconda3/lib/python3.8/site-packages/requests/sessions.py:529, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     524 send_kwargs = {
#     525     'timeout': timeout,
#     526     'allow_redirects': allow_redirects,
#     527 }
#     528 send_kwargs.update(settings)
# --> 529 resp = self.send(prep, **send_kwargs)
#     531 return resp
#
# File /opt/anaconda3/lib/python3.8/site-packages/requests/sessions.py:645, in Session.send(self, request, **kwargs)
#     642 start = preferred_clock()
#     644 # Send the request
# --> 645 r = adapter.send(request, **kwargs)
#     647 # Total elapsed time of the request (approximately)
#     648 elapsed = preferred_clock() - start
#
# File /opt/anaconda3/lib/python3.8/site-packages/requests/adapters.py:519, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     515     if isinstance(e.reason, _SSLError):
#     516         # This branch is for urllib3 v1.22 and later.
#     517         raise SSLError(e, request=request)
# --> 519     raise ConnectionError(e, request=request)
#     521 except ClosedPoolError as e:
#     522     raise ConnectionError(e, request=request)
#
# ConnectionError: HTTPSConnectionPool(host='www.booking.com', port=443): Max retries exceeded with url: /hotel/fr/paradis.fr.html (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7f96c14a91c0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))

# %%
# On nomme nos colonnes pour pouvoir merger par la suite avec le DF précédent
hotels_lat_lon.columns = ['Latitude', 'Longitude']

hotels_lat_lon.columns

# %%
# Afin de pouvoir merger, il faut une colonne en commun, donc on crée une colonne 'index'
hotels_lat_lon['index'] = hotels_lat_lon.index
hotels_lat_lon

# %%
# On merge notre nouveau DF (lat-long des hotels) avec celui des infos_hotels
booking_adress_result = booking_test.merge(hotels_lat_lon)

# On réorganise l'ordre des colonnes pour un df plus esthétique
booking_adress_result = booking_adress_result.iloc[:, [0,6,7,1,5,2,3,4]]

booking_adress_result

# %%
hotels_column = ['Cities','Hotels']

fig = px.scatter_mapbox(booking_adress_result, 
                        lat="Latitude", 
                        lon="Longitude", 
                        color="note", 
                        size="Longitude", 
                        zoom=3.5, 
                        mapbox_style = "carto-positron",
                        hover_data=hotels_column,
                    )
fig.show()
# Out:
# <iframe
#     scrolling="no"
#     width="100%"
#     height="545px"
#     src="iframe_figures/figure_72.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
import time

# %%
start = time.time()
notes_json = []

for URL in url_list:
    ID = i
    r_adresses = requests.get(URL)
    soup = BeautifulSoup(r_adresses.content, "html.parser")
    elm=soup.findAll('div',{'class',"hotel_large_photp_score featured_review_score js-fly-content-tooltip hp_lightbox_score_block"})
    if len(elm)!=0:
        hotel_note=elm[0].get('data-review-score')

    else :
        hotel_note=' '
    notes_json.append([hotel_note])

#notes_json
end = time.time()
print('Elapsed time: {}'.format(end - start))

# Conversion de notre liste de coordonnées en DF
DF_notes = DataFrame(notes_json)
# Out:
# Elapsed time: 350.2283868789673

# %%
DF_notes.columns = ['note']
DF_notes.columns
# Out:
# Index(['note'], dtype='object')

# %%
booking_adress_result = pd.merge(booking_adress_result,DF_notes, left_index = True, right_index = True)

# %%
booking_adress_result
# Out:
#                                               Hotels URL  \
# index
# 0      https://www.booking.com/hotel/fr/la-lavandiere...
# 1      https://www.booking.com/hotel/fr/homestay-borm...
# 2      https://www.booking.com/hotel/fr/le-petit-atel...
# 3      https://www.booking.com/hotel/fr/bormes-les-mi...
# 4      https://www.booking.com/hotel/fr/paradis.fr.ht...
# ...                                                  ...
# 95     https://www.booking.com/hotel/fr/camille.fr.ht...
# 96     https://www.booking.com/hotel/fr/appartement-c...
# 97     https://www.booking.com/hotel/fr/oh-campings-l...
# 98     https://www.booking.com/hotel/fr/auberge-de-la...
# 99     https://www.booking.com/hotel/fr/l-39-estrambo...
#
#                           Hotels description                    Cities  \
# index
# 0                                                   Bormes les Mimosas
# 1      Bormes-les-Mimosas • 1,1 km du centre        Bormes les Mimosas
# 2                       À 1,5 km de la plage        Bormes les Mimosas
# 3                                        9,6        Bormes les Mimosas
# 4      Bormes-les-Mimosas • 1,2 km du centre        Bormes les Mimosas
# ...                                      ...                       ...
# 95       Hébergement géré par un particulier  Saintes Maries de la mer
# 96                                       7,7  Saintes Maries de la mer
# 97                  Cassis • 100 m du centre  Saintes Maries de la mer
# 98                       À 150 m de la plage  Saintes Maries de la mer
# 99       Hébergement géré par un particulier  Saintes Maries de la mer
#
#                                                   Hotels  \
# index
# 0                                          La Lavandière
# 1                                        HomeStay Bormes
# 2                                       Le petit atelier
# 3      Charmant Appartement avec Vue panoramique Mer ...
# 4                                          Hôtel Paradis
# ...                                                  ...
# 95                                         Hotel Camille
# 96                Appartement calme à deux pas de la mer
# 97                                 Oh! Campings La Brise
# 98                                 Auberge de la Fadaise
# 99                              L'Estrambord de Camargue
#
#                                          Hotel addresses  note    0
# index
# 0                  Bormes-les-Mimosas • 1,1 km du centre   0.0
# 1                                   À 1,5 km de la plage   9.6  9.6
# 2                  Bormes-les-Mimosas • 1,2 km du centre   8.9  8.9
# 3                  Bormes-les-Mimosas • 1,1 km du centre   7.7  7.7
# 4                                   À 1,6 km de la plage   8.0    8
# ...                                                  ...   ...  ...
# 95           Saint-Charles, Marseille • 0,7 km du centre   7.9  7.9
# 96            Prado - Périer, Marseille • 2 km du centre   8.2  8.2
# 97     Vieux Port - La Canebière, Marseille • 1,6 km ...   7.6  7.6
# 98           Saint-Charles, Marseille • 0,5 km du centre   8.3  8.3
# 99     Vieux Port - La Canebière, Marseille • 0,5 km ...   8.4  8.4
#
# [100 rows x 7 columns]

# %%
booking_adress_result["note"]=booking_adress_result["note"].replace('None',0).replace('',0).apply(lambda x : float(x))

# %%
booking_adress_result
# Out:
#                                               Hotels URL  \
# index
# 0      https://www.booking.com/hotel/fr/la-lavandiere...
# 1      https://www.booking.com/hotel/fr/homestay-borm...
# 2      https://www.booking.com/hotel/fr/le-petit-atel...
# 3      https://www.booking.com/hotel/fr/bormes-les-mi...
# 4      https://www.booking.com/hotel/fr/paradis.fr.ht...
# ...                                                  ...
# 95     https://www.booking.com/hotel/fr/camille.fr.ht...
# 96     https://www.booking.com/hotel/fr/appartement-c...
# 97     https://www.booking.com/hotel/fr/oh-campings-l...
# 98     https://www.booking.com/hotel/fr/auberge-de-la...
# 99     https://www.booking.com/hotel/fr/l-39-estrambo...
#
#                           Hotels description                    Cities  \
# index
# 0                                                   Bormes les Mimosas
# 1      Bormes-les-Mimosas • 1,1 km du centre        Bormes les Mimosas
# 2                       À 1,5 km de la plage        Bormes les Mimosas
# 3                                        9,6        Bormes les Mimosas
# 4      Bormes-les-Mimosas • 1,2 km du centre        Bormes les Mimosas
# ...                                      ...                       ...
# 95       Hébergement géré par un particulier  Saintes Maries de la mer
# 96                                       7,7  Saintes Maries de la mer
# 97                  Cassis • 100 m du centre  Saintes Maries de la mer
# 98                       À 150 m de la plage  Saintes Maries de la mer
# 99       Hébergement géré par un particulier  Saintes Maries de la mer
#
#                                                   Hotels  \
# index
# 0                                          La Lavandière
# 1                                        HomeStay Bormes
# 2                                       Le petit atelier
# 3      Charmant Appartement avec Vue panoramique Mer ...
# 4                                          Hôtel Paradis
# ...                                                  ...
# 95                                         Hotel Camille
# 96                Appartement calme à deux pas de la mer
# 97                                 Oh! Campings La Brise
# 98                                 Auberge de la Fadaise
# 99                              L'Estrambord de Camargue
#
#                                          Hotel addresses  note    0
# index
# 0                  Bormes-les-Mimosas • 1,1 km du centre   0.0
# 1                                   À 1,5 km de la plage   9.6  9.6
# 2                  Bormes-les-Mimosas • 1,2 km du centre   8.9  8.9
# 3                  Bormes-les-Mimosas • 1,1 km du centre   7.7  7.7
# 4                                   À 1,6 km de la plage   8.0    8
# ...                                                  ...   ...  ...
# 95           Saint-Charles, Marseille • 0,7 km du centre   7.9  7.9
# 96            Prado - Périer, Marseille • 2 km du centre   8.2  8.2
# 97     Vieux Port - La Canebière, Marseille • 1,6 km ...   7.6  7.6
# 98           Saint-Charles, Marseille • 0,5 km du centre   8.3  8.3
# 99     Vieux Port - La Canebière, Marseille • 0,5 km ...   8.4  8.4
#
# [100 rows x 7 columns]

# %%
hotels_column = ['Cities','Hotels']

fig = px.scatter_mapbox(booking_adress_result, 
                        lat="Latitude", 
                        lon="Longitude", 
                        color="note", 
                        size="Longitude", 
                        zoom=3.5, 
                        mapbox_style = "carto-positron",
                        hover_data=hotels_column,
                    )
fig.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [96], in <cell line: 3>()
#       1 hotels_column = ['Cities','Hotels']
# ----> 3 fig = px.scatter_mapbox(booking_adress_result,
#       4                         lat="Latitude",
#       5                         lon="Longitude",
#       6                         color="note",
#       7                         size="Longitude",
#       8                         zoom=3.5,
#       9                         mapbox_style = "carto-positron",
#      10                         hover_data=hotels_column,
#      11                     )
#      12 fig.show()
#
# File /opt/anaconda3/lib/python3.8/site-packages/plotly/express/_chart_types.py:1126, in scatter_mapbox(data_frame, lat, lon, color, text, hover_name, hover_data, custom_data, size, animation_frame, animation_group, category_orders, labels, color_discrete_sequence, color_discrete_map, color_continuous_scale, range_color, color_continuous_midpoint, opacity, size_max, zoom, center, mapbox_style, title, template, width, height)
#    1093 def scatter_mapbox(
#    1094     data_frame=None,
#    1095     lat=None,
#    (...)
#    1120     height=None,
#    1121 ):
#    1122     """
#    1123     In a Mapbox scatter plot, each row of `data_frame` is represented by a
#    1124     symbol mark on a Mapbox map.
#    1125     """
# -> 1126     return make_figure(args=locals(), constructor=go.Scattermapbox)
#
# File /opt/anaconda3/lib/python3.8/site-packages/plotly/express/_core.py:1861, in make_figure(args, constructor, trace_patch, layout_patch)
#    1858 layout_patch = layout_patch or {}
#    1859 apply_default_cascade(args)
# -> 1861 args = build_dataframe(args, constructor)
#    1862 if constructor in [go.Treemap, go.Sunburst] and args["path"] is not None:
#    1863     args = process_dataframe_hierarchy(args)
#
# File /opt/anaconda3/lib/python3.8/site-packages/plotly/express/_core.py:1377, in build_dataframe(args, constructor)
#    1374     args["color"] = None
#    1375 # now that things have been prepped, we do the systematic rewriting of `args`
# -> 1377 df_output, wide_id_vars = process_args_into_dataframe(
#    1378     args, wide_mode, var_name, value_name
#    1379 )
#    1381 # now that `df_output` exists and `args` contains only references, we complete
#    1382 # the special-case and wide-mode handling by further rewriting args and/or mutating
#    1383 # df_output
#    1385 count_name = _escape_col_name(df_output, "count", [var_name, value_name])
#
# File /opt/anaconda3/lib/python3.8/site-packages/plotly/express/_core.py:1183, in process_args_into_dataframe(args, wide_mode, var_name, value_name)
#    1181         if argument == "index":
#    1182             err_msg += "\n To use the index, pass it in directly as `df.index`."
# -> 1183         raise ValueError(err_msg)
#    1184 elif length and len(df_input[argument]) != length:
#    1185     raise ValueError(
#    1186         "All arguments should have the same length. "
#    1187         "The length of column argument `df[%s]` is %d, whereas the "
#    (...)
#    1194         )
#    1195     )
#
# ValueError: Value of 'size' is not the name of a column in 'data_frame'. Expected one of ['Hotels URL', 'Hotels description', 'Cities', 'Hotels', 'Hotel addresses', 'note', 0] but received: Longitude

# %%
booking_adress_result
# Out:
#     index                                         Hotels URL  \
# 0       0  https://www.booking.com/hotel/fr/la-lavandiere...
# 1       1  https://www.booking.com/hotel/fr/homestay-borm...
# 2       2  https://www.booking.com/hotel/fr/le-petit-atel...
# 3       3  https://www.booking.com/hotel/fr/bormes-les-mi...
# 4       4  https://www.booking.com/hotel/fr/paradis.fr.ht...
# ..    ...                                                ...
# 95     95  https://www.booking.com/hotel/fr/camille.fr.ht...
# 96     96  https://www.booking.com/hotel/fr/appartement-c...
# 97     97  https://www.booking.com/hotel/fr/oh-campings-l...
# 98     98  https://www.booking.com/hotel/fr/auberge-de-la...
# 99     99  https://www.booking.com/hotel/fr/l-39-estrambo...
#
#                        Hotels description                    Cities  \
# 0                                                Bormes les Mimosas
# 1   Bormes-les-Mimosas • 1,1 km du centre        Bormes les Mimosas
# 2                    À 1,5 km de la plage        Bormes les Mimosas
# 3                                     9,6        Bormes les Mimosas
# 4   Bormes-les-Mimosas • 1,2 km du centre        Bormes les Mimosas
# ..                                    ...                       ...
# 95    Hébergement géré par un particulier  Saintes Maries de la mer
# 96                                    7,7  Saintes Maries de la mer
# 97               Cassis • 100 m du centre  Saintes Maries de la mer
# 98                    À 150 m de la plage  Saintes Maries de la mer
# 99    Hébergement géré par un particulier  Saintes Maries de la mer
#
#                                                Hotels  \
# 0                                       La Lavandière
# 1                                     HomeStay Bormes
# 2                                    Le petit atelier
# 3   Charmant Appartement avec Vue panoramique Mer ...
# 4                                       Hôtel Paradis
# ..                                                ...
# 95                                      Hotel Camille
# 96             Appartement calme à deux pas de la mer
# 97                              Oh! Campings La Brise
# 98                              Auberge de la Fadaise
# 99                           L'Estrambord de Camargue
#
#                                       Hotel addresses  note
# 0               Bormes-les-Mimosas • 1,1 km du centre   0.0
# 1                                À 1,5 km de la plage   9.6
# 2               Bormes-les-Mimosas • 1,2 km du centre   8.9
# 3               Bormes-les-Mimosas • 1,1 km du centre   7.7
# 4                                À 1,6 km de la plage   8.0
# ..                                                ...   ...
# 95        Saint-Charles, Marseille • 0,7 km du centre   7.9
# 96         Prado - Périer, Marseille • 2 km du centre   8.2
# 97  Vieux Port - La Canebière, Marseille • 1,6 km ...   7.6
# 98        Saint-Charles, Marseille • 0,5 km du centre   8.3
# 99  Vieux Port - La Canebière, Marseille • 0,5 km ...   8.4
#
# [100 rows x 7 columns]

# %%
booking_adress_result.set_index('index',inplace=True)

# %%
a=booking_adress_result.groupby('Cities').mean().sort_values('note',ascending=False)
a
# Out:
#                            note
# Cities
# Cassis                    8.385
# Saintes Maries de la mer  8.105
# Aix en Provence           7.930
# Bormes les Mimosas        7.645
# Marseille                 7.480

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
fig;ax = plt.subplots(figsize=(20,10))
ax=sns.barplot(x=a.index,y=a["note"])
plt.setp(ax.get_xticklabels(), rotation=30)
plt.show()

# %%
from geolocation.main import Geolocation
geo_location = Geolocation()
location = geo_location.get_geolocation()
print(location)

# %%
#dataset.to_csv(csv_geolocalisation, sep=‘\t’)
lat_lon.to_csv('geolocalisation.csv',encoding='utf-8',index=False)
final_result.to_csv('meteo.csv',encoding='utf-8',index=False)
booking_test.to_csv('booking_test.csv',encoding='utf-8',index=False)
booking_adress_result.to_csv('booking_adress_result.csv',encoding='utf-8',index=False, sep='\t')

# %%
# !pip install boto3 -q

import boto3

# %%
session = boto3.Session(aws_access_key_id= 'AKIARSCTXCHBRSH442PH',
                        aws_secret_access_key= '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')

# %%
s3 = session.resource("s3")
bucket = s3.create_bucket(Bucket="api-kayak-project")

# %%
import pandas as pd

data = pd.read_csv('meteo.csv')
csv = data.to_csv()
put_object = bucket.put_object(Key="meteo.csv", Body=csv)

# %%
data = pd.read_csv('booking_test.csv')
csv = data.to_csv()
put_object = bucket.put_object(Key="booking_test.csv", Body=csv)

# %%
data = pd.read_csv('booking_adress_result.csv', delimiter='tab')
csv = data.to_csv()
put_object = bucket.put_object(Key="booking_adress_result.csv", Body=csv)

# %%
# !pip install psycopg2-binary -q
from sqlalchemy import create_engine
engine = create_engine('postgresql+psycopg2://postgres:berechit95170!@database-1.cvqthc8jtrkz.eu-west-3.rds.amazonaws.com/postgres', echo=True)

# %%
meteo = pd.read_csv('meteo.csv')
booking_hotels = pd.read_csv('booking_test.csv')

# %%
meteo.to_sql('35cities_weather', engine)
booking_hotels.to_sql('5best_cities_hotels',engine)
